# %% [markdown]
# ### Tests

# %%
from fabrictestbed.slice_editor import Labels, ExperimentTopology, Capacities, ComponentType, ComponentModelType, ServiceType, ComponentCatalog

for value in ComponentModelType:
    print(value)
    
comp = ComponentModelType.NVME_P4510
print(str(comp))

# %% [markdown]
# ### TEST 3.1.2 - NVME

# %%
from fabrictestbed_extensions.tests.nvme_benchmark import NVMEBenchmark

#sites=['UTAH', 'MAX', 'TACC', 'NCSA', 'MICH', 'STAR']
sites=['STAR' ]
slice_name='Test-1.0.2-nvme'
node_count=2

NVMEBenchmark().run_all(slice_name=slice_name, sites=sites, node_count=node_count, delete=False)

# %% [markdown]
# ### TEST 3.1.2 - Tesla T4

# %%
from fabrictestbed_extensions.tests.gpu_tesla_t4_benchmark import GPUTeslaT4Benchmark

#sites=['UTAH', 'MAX', 'TACC', 'NCSA', 'MICH', 'STAR']
sites=[('UTAH', 4), ('MAX', 4), ('TACC', 4), ('NCSA', 2),('MICH', 2),('STAR', 6) ]
#sites=[ ('MAX', 4) ]
slice_name='Test-1.0.2-tesla_t4'

GPUTeslaT4Benchmark().run_all(slice_name=slice_name, sites=sites, create_slice=True, delete=False)

# %% [markdown]
# ### TEST 3.1.2 -  ALL

# %%
from fabrictestbed_extensions.tests.component_tests import ComponentTest

#tests=['UTAH', 'MAX', 'TACC', 'NCSA', 'MICH', 'STAR']
#tests=[('UTAH', 4), ('MAX', 4), ('TACC', 4), ('NCSA', 2),('MICH', 2),('STAR', 6) ]
tests=[ 
        #('NCSA', 'GPU_Tesla_T4', 2), 
        #('NCSA', 'GPU_RTX6000', 3), 
        #('NCSA', 'SharedNIC_ConnectX_6', 20), 
        #('NCSA', 'SmartNIC_ConnectX_6', 2), 
        #('NCSA', 'SmartNIC_ConnectX_5', 2), 
        #('NCSA', 'NVME_P4510', 10), 


        ('UTAH', 'GPU_Tesla_T4', 4), 
        ('UTAH', 'GPU_RTX6000', 5), 
        ('UTAH', 'SharedNIC_ConnectX_6', 20), 
        ('UTAH', 'SmartNIC_ConnectX_6', 2), 
        ('UTAH', 'SmartNIC_ConnectX_5', 4), 
        ('UTAH', 'NVME_P4510', 16),  #/16
    

        #('TACC', 'GPU_Tesla_T4', 4), 
        #('TACC', 'GPU_RTX6000', 6), 
        #('TACC', 'SharedNIC_ConnectX_6', 20), 
        #('TACC', 'SmartNIC_ConnectX_6', 2), 
        #('TACC', 'SmartNIC_ConnectX_5', 4), 
        #('TACC', 'NVME_P4510', 16), 
        ]
test_name='Test-3_1_2_small'

ComponentTest().run_all(test_name=test_name, tests=tests, create_slice=True, delete=False)

# %%
from fabrictestbed_extensions.tests.component_tests import ComponentTest

#tests=['UTAH', 'MAX', 'TACC', 'NCSA', 'MICH', 'STAR']
#tests=[('UTAH', 4), ('MAX', 4), ('TACC', 4), ('NCSA', 2),('MICH', 2),('STAR', 6) ]
tests=[ 
        ('UTAH', 'GPU_Tesla_T4', 4), 
        ('UTAH', 'GPU_RTX6000', 5), 
        ('UTAH', 'SharedNIC_ConnectX_6', 20), 
        ('UTAH', 'SmartNIC_ConnectX_6', 2), 
        ('UTAH', 'SmartNIC_ConnectX_5', 4), 
        ('UTAH', 'NVME_P4510', 15),  #/16

        ('MAX', 'GPU_Tesla_T4', 4), 
        ('MAX', 'GPU_RTX6000', 6), 
        ('MAX', 'SharedNIC_ConnectX_6', 20), 
        ('MAX', 'SmartNIC_ConnectX_6', 1), #/2
        ('MAX', 'SmartNIC_ConnectX_5', 3),  #/4
        ('MAX', 'NVME_P4510', 15), #/16

        ('TACC', 'GPU_Tesla_T4', 4), 
        ('TACC', 'GPU_RTX6000', 6), 
        ('TACC', 'SharedNIC_ConnectX_6', 20), 
        ('TACC', 'SmartNIC_ConnectX_6', 2), 
        ('TACC', 'SmartNIC_ConnectX_5', 4), 
        ('TACC', 'NVME_P4510', 16), 

        ('NCSA', 'GPU_Tesla_T4', 2), 
        ('NCSA', 'GPU_RTX6000', 3), 
        ('NCSA', 'SharedNIC_ConnectX_6', 20), 
        ('NCSA', 'SmartNIC_ConnectX_6', 2), 
        ('NCSA', 'SmartNIC_ConnectX_5', 2), 
        ('NCSA', 'NVME_P4510', 10), 

        ('MICH', 'GPU_Tesla_T4', 2), 
        ('MICH', 'GPU_RTX6000', 3), 
        ('MICH', 'SharedNIC_ConnectX_6', 20), 
        ('MICH', 'SmartNIC_ConnectX_6', 2), 
        ('MICH', 'SmartNIC_ConnectX_5', 2), 
        ('MICH', 'NVME_P4510', 10),

        ('STAR', 'GPU_Tesla_T4', 3), #/6 
        ('STAR', 'GPU_RTX6000', 4), #/6
        ('STAR', 'SharedNIC_ConnectX_6', 20), 
        ('STAR', 'SmartNIC_ConnectX_6', 1), #/2 
        #####('STAR', 'SmartNIC_ConnectX_5', 6), #? 
        ('STAR', 'NVME_P4510', 17) , #/20
 
        ]
test_name='Test-3_1_2_all'

ComponentTest().run_all(test_name=test_name, tests=tests, create_slice=True, delete=False)

# %% [markdown]
# ### Network Benchmarks

# %%
from fabrictestbed_extensions.tests.network_benchmark_tests import NetworkBencharks


 #('MAX', 'SharedNIC_ConnectX_6', 20), 
 #('MAX', 'SmartNIC_ConnectX_6', 2), 
 #('MAX', 'SmartNIC_ConnectX_5', 4), 

core=2
ram=2
disk=10
    
tacc=  { 'site' : 'TACC',
             'server' :  {'node_name':'TACC_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [ 

                        {'node_name':'TACC_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        {'node_name':'TACC_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        {'node_name':'TACC_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        {'node_name':'TACC_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                        {'node_name':'TACC_6_1', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        {'node_name':'TACC_6_2', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 


                        {'node_name':'TACC_5_1', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        {'node_name':'TACC_5_2', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        {'node_name':'TACC_5_3', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        {'node_name':'TACC_5_4', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},


                        ]
       }



max =     { 'site' : 'MAX',
             'server' :  {'node_name':'MAX_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [ 
                            {'node_name':'MAX_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                            {'node_name':'MAX_6_1', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_6_2', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                            {'node_name':'MAX_5_1', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'MAX_5_2', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'MAX_5_3', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'MAX_5_4', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        ]
           }

max_shared =     { 'site' : 'MAX',
             'server' :  {'node_name':'MAX_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [ 
                            {'node_name':'MAX_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic5', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic6', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic7', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic8', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic9', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic10', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic11', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic12', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic13', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic14', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic15', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'MAX_sharednic16', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        ]
           }

ncsa=  { 'site' : 'NCSA',
             'server' :  {'node_name':'NCSA_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [ 
                            {'node_name':'NCSA_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'NCSA_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'NCSA_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'NCSA_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                            {'node_name':'NCSA_6_1', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                            {'node_name':'NCSA_6_2', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                            {'node_name':'NCSA_5_1', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'NCSA_5_2', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                            ]
       }

utah =     { 'site' : 'UTAH',
             'server' :  {'node_name':'UTAH_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [{'node_name':'UTAH_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        {'node_name':'UTAH_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic5', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic6', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic7', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic8', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic9', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic10', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic11', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic12', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic13', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic14', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic15', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic16', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic17', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic18', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic19', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic20', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic21', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic22', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic23', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic24', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic25', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic26', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic27', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic28', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic29', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic30', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic41', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic42', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic43', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic44', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic45', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic46', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic47', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic48', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic49', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                        {'node_name':'UTAH_6_1', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_6_2', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                        #{'node_name':'UTAH_5_1', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        #{'node_name':'UTAH_5_2', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        {'node_name':'UTAH_5_3', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        {'node_name':'UTAH_5_4', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        ]
           }

utah_shared =     { 'site' : 'UTAH',
             'server' :  {'node_name':'UTAH_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [#{'node_name':'UTAH_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic5', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic6', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic7', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic8', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic9', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic10', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic11', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic12', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic13', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic14', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic15', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_sharednic16', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                        #{'node_name':'UTAH_6_1', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                        #{'node_name':'UTAH_6_2', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 

                        #{'node_name':'UTAH_5_1', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        #{'node_name':'UTAH_5_2', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        #{'node_name':'UTAH_5_3', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        #{'node_name':'UTAH_5_4', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                        ]
           }

mich=  { 'site' : 'MICH',
             'server' :  {'node_name':'MICH_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [ 
                            {'node_name':'mich_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'mich_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'mich_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'mich_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},

                            {'node_name':'mich_6_1', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'mich_6_2', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},

                            {'node_name':'mich_5_1', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                            {'node_name':'mich_5_2', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                            ]
               }



star =     { 'site' : 'STAR',
             'server' :  {'node_name':'STAR_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [        {'node_name':'star_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic5', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic6', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic7', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic8', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_sharednic9', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_sharednic10', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_sharednic11', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_sharednic12', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_sharednic13', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_sharednic14', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_sharednic15', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_sharednic16', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},    

                                {'node_name':'star_6_1', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                                #{'node_name':'star_6_2', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},

                                {'node_name':'star_5_1', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_5_2', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                #{'node_name':'star_5_3', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_5_4', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                #{'node_name':'star_5_5', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                #{'node_name':'star_5_6', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                        ]
           }


star_one =     { 'site' : 'STAR',
             'server' :  {'node_name':'STAR_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [        {'node_name':'star_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                        ]}

star_shared =     { 'site' : 'STAR',
             'server' :  {'node_name':'STAR_server', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
             'clients': [        {'node_name':'star_sharednic1', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic2', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic3', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic4', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic5', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic6', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic7', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic8', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic9', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic10', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic11', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic12', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic13', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic14', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic15', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic16', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},    
                                {'node_name':'star_sharednic17', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic18', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic19', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic20', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic21', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic22', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic23', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic24', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic25', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic26', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic27', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic28', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic29', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic30', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},                   
                                {'node_name':'star_sharednic31', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic32', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic33', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic34', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic35', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic36', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic37', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic38', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic39', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                {'node_name':'star_sharednic40', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},                        
                         

                        ]
           }



#test_name='Test-Network_star'
#results = NetworkBencharks().test_l2bridge(test_name, test=star_shared, create_slice=True)
#NetworkBencharks().print_summary(results)

#for i in range(0,20):
#    test_name='Test-NetworkB_'+str(i)
#    results = NetworkBencharks().test_l2bridge(test_name, test=star_one, create_slice=True)
#    NetworkBencharks().print_summary(results)



# l2bridge does not pass traffic
#test_name='Test-Network_mich'
#results = NetworkBencharks().test_l2bridge(test_name, test=mich, create_slice=True)
#NetworkBencharks().print_summary(results)


#floating ips do not work
test_name='Test-Network_utah1'
results = NetworkBencharks().test_l2bridge(test_name, test=utah, create_slice=True)
NetworkBencharks().print_summary(results)



# l2bridge does not pass traffic
#test_name='Test-Network_ncsa'
#results = NetworkBencharks().test_bridge_one_site(test_name, test=ncsa, create_slice=True)
#NetworkBencharks().print_summary(results)


# One cx6 fails, no network traffic
#test_name='Test-Network_tacc'
#results = NetworkBencharks().test_bridge_one_site(test_name, test=tacc, create_slice=True)
#NetworkBencharks().print_summary(results)


#everything works
#test_name='Test-Network_max_shared'
#results = NetworkBencharks().test_l2bridge(test_name, test=max_shared, create_slice=True)
#NetworkBencharks().print_summary(results)

# %%
from fabrictestbed_extensions.utils.slice import SliceUtils
import time



from fabrictestbed_extensions.tests.network_benchmark_tests import NetworkBencharks

core=8
ram=32
disk=100

tests5=[ 
        {'test_name' : 'p2p_x5_MAX_UTAH',
         'src': {'site':'MAX','nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
         'dst': {'site':'UTAH','nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk} },
         
        {'test_name' : 'p2p_x5_STAR_MAX',
         'src': {'site':'STAR','nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
         'dst': {'site':'MAX','nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk} },
    
        {'test_name' : 'p2p_x5_STAR_UTAH',
         'src': {'site':'STAR','nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
         'dst': {'site':'UTAH','nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk} },
       
    ]

tests6=[ 
        {'test_name' : 'p2p_x6_MAX_UTAH',
         'src': {'site':'MAX','nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
         'dst': {'site':'UTAH','nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk} },
       
        {'test_name' : 'p2p_x6_STAR_MAX',
         'src': {'site':'STAR','nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
         'dst': {'site':'MAX','nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk} },
    
        {'test_name' : 'p2p_x6_STAR_UTAH',
         'src': {'site':'STAR','nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
         'dst': {'site':'UTAH','nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk} },
       
    ]

#NetworkBencharks().test_ptp_across_two_sites_all_tests("p2p_cx6_1",'UTAH', 'STAR')
#NetworkBencharks().test_ptp_across_two_sites_all_tests("p2p_cx6_2",'STAR', 'MAX')
#NetworkBencharks().test_ptp_across_two_sites_all_tests("p2p_cx6_3",'UTAH', 'MAX')

#NetworkBencharks().test_all_ptp([ ('UTAH', 'STAR'),('STAR', 'MAX'),('UTAH', 'MAX')])

try:
    SliceUtils.delete_all()
except Exception as e:
    print (e)
    
#time.sleep(300)


results = NetworkBencharks().test_all_ptp(tests6, create_slices=True)
NetworkBencharks().print_summary(results)

try:
    SliceUtils.delete_all()
except Exception as e:
    print (e)
    
time.sleep(300)

#results = NetworkBencharks().test_all_ptp(tests5, create_slices=True)


#NetworkBencharks().print_summary(results)

# %%
from fabrictestbed_extensions.utils.slice import SliceUtils
import time

from fabrictestbed_extensions.tests.network_benchmark_tests import NetworkBencharks


core=8
ram=32
disk=100

test_star_max =  {  'server' :  {'node_name':'STAR_server', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                    'clients': [       {'node_name':'star_sharednic1', 'site': 'STAR', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'star_sharednic2', 'site': 'STAR', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'star_sharednic3', 'site': 'STAR', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'star_sharednic4', 'site': 'STAR', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       
                        
                                       {'node_name':'star_5_1', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'star_5_2', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'star_5_3', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'star_5_4', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},

                                       #{'node_name':'star_6_1', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'star_6_2', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
          
                                       {'node_name':'max_sharednic1', 'site': 'MAX', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'max_sharednic2', 'site': 'MAX', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'max_sharednic3', 'site': 'MAX', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'max_sharednic4', 'site': 'MAX', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},

                                       {'node_name':'max_5_1', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'max_5_2', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'max_5_3', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'max_5_4', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    

                                       {'node_name':'max_6_1', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'max_6_2', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},    

                               ]
           }

test_star_utah =  {  'server' :  {'node_name':'STAR_server', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                    'clients': [       {'node_name':'star_sharednic1', 'site': 'STAR', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'star_sharednic2', 'site': 'STAR', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'star_sharednic3', 'site': 'STAR', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'star_sharednic4', 'site': 'STAR', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       
                        
                                       {'node_name':'star_5_1', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'star_5_2', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'star_5_3', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'star_5_4', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},

                                       #{'node_name':'star_6_1', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'star_6_2', 'site': 'STAR', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},

                                
                                       {'node_name':'utah_sharednic1', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'utah_sharednic2', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'utah_sharednic3', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       #{'node_name':'utah_sharednic4', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},

                                       {'node_name':'utah_5_1', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'utah_5_2', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'utah_5_3', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'utah_5_4', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    

                                       {'node_name':'utah_6_1', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'utah_6_2', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},    

                               ]
           }


test_utah_max =  {  'server' :  {'node_name':'UTAH_server', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk}, 
                    'clients': [       {'node_name':'utah_sharednic1', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'utah_sharednic2', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'utah_sharednic3', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'utah_sharednic4', 'site': 'UTAH', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       
                        
                                       {'node_name':'utah_5_1', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'utah_5_2', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'utah_5_3', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'utah_5_4', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},

                                       {'node_name':'utah_6_1', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'utah_6_2', 'site': 'UTAH', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},

                                
                                       {'node_name':'max_sharednic1', 'site': 'MAX', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'max_sharednic2', 'site': 'MAX', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'max_sharednic3', 'site': 'MAX', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},
                                       {'node_name':'max_sharednic4', 'site': 'MAX', 'nic':'SharedNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},

                                       {'node_name':'max_5_1', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'max_5_2', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'max_5_3', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'max_5_4', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_5', 'core':core, 'ram':ram, 'disk':disk},    

                                       {'node_name':'max_6_1', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},    
                                       {'node_name':'max_6_2', 'site': 'MAX', 'nic':'SmartNIC_ConnectX_6', 'core':core, 'ram':ram, 'disk':disk},    

                               ]
           }

try:
    SliceUtils.delete_all()
except Exception as e:
    print (e)
    
time.sleep(120)
test_name='s2s_star_utah'
results = NetworkBencharks().test_s2s(test_name, test=test_star_utah, create_slice=True)


NetworkBencharks().print_summary(results)

# %%
try:
    SliceUtils.delete_all()
except Exception as e:
    print (e)
    
time.sleep(300)

test_name='s2s_star_utah'
results = NetworkBencharks().test_s2s(test_name, test=test_star_max, create_slice=True)
NetworkBencharks().print_summary(results)

try:
    SliceUtils.delete_all()
except Exception as e:
    print (e)
    
time.sleep(300)



test_name='s2s_star_max'
results = NetworkBencharks().test_s2s(test_name, test=test_star_max, create_slice=True)
NetworkBencharks().print_summary(results)



try:
    SliceUtils.delete_all()
except Exception as e:
    print (e)
    
time.sleep(300)
