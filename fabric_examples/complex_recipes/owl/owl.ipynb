# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # One-Way Latency Measurements (OWL)
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook walks you through measuring **one-way network latency** between FABRIC nodes using the OWL (One-Way Latency) tool. Unlike round-trip measurements (`ping`), one-way latency reveals **asymmetric path delays** that are invisible to bidirectional tools. OWL achieves this by leveraging **PTP (Precision Time Protocol)** synchronized clocks on FABRIC nodes.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Identify **PTP-capable** FABRIC sites and explain why clock synchronization matters for one-way measurements
# 2. Create a multi-site slice with **PTP-synchronized nodes** connected via FABnetv4
# 3. Install and configure the **LinuxPTP** software using Ansible playbooks
# 4. Run **OWL** to measure one-way latency between any pair of nodes
# 5. Collect and download **pcap files** for offline latency analysis
# 6. Choose between **automated** (all-to-all) and **manual** (specific pair) OWL measurement modes
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../fablib_api/configure_environment/configure_environment.ipynb) notebook
# 2. Be familiar with creating basic FABRIC slices (see [Hello, FABRIC](../../fablib_api/hello_fabric/hello_fabric.ipynb))
# 3. Have the **mflib** Python library installed (`pip install mflib`)
#
# **Tip:** Not all FABRIC sites support PTP. The notebook automatically filters for PTP-capable sites, but if you want to test specific sites, verify PTP support first using `fablib.list_sites()`.
#
# **Tip:** PTP installation via Ansible takes several minutes per node. The process runs in parallel across all nodes, but be patient.
#
# </div>

# %% [markdown]
# ## Background: Why One-Way Latency?
#
# Traditional network latency measurement uses **round-trip time (RTT)** -- a packet goes from A to B and back. RTT assumes the forward and return paths take equal time, but this is often **not true**:
#
# ```
# Round-Trip Time (RTT) = 10ms
# Assumption: A→B = 5ms, B→A = 5ms  (symmetric)
# Reality:    A→B = 3ms, B→A = 7ms  (asymmetric!)
# ```
#
# **One-way latency** measures the actual time for a packet to travel in a single direction. This requires:
#
# 1. **Highly synchronized clocks** at both endpoints (PTP provides sub-microsecond accuracy)
# 2. **Timestamping at send and receive** -- OWL embeds the send timestamp in the UDP payload and uses `tcpdump` to capture the receive timestamp
#
#
# **Use cases** for one-way latency measurement include:
# - Detecting asymmetric routing
# - Characterizing network paths for time-sensitive applications
# - Measuring jitter and latency distributions
# - Validating QoS policies

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a sender and receiver node for precise one-way latency measurement.
#
# <img src="./figs/slice_topology.png" width="50%">

# %% [markdown]
# ---
#
# ## Step 1: Import Libraries and Verify Configuration
#
# Import FABlib for slice management and the OWL module from **mflib** for latency measurement.

# %%
# Import FABlib for FABRIC testbed interaction
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Import OWL (One-Way Latency) from the FABRIC Measurement Framework library
from mflib import owl as owl

try:
    # Create a FABlib manager instance
    fm = fablib_manager()
                     
    # Display configuration to verify tokens and keys
    fm.show_config()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Step 2: Select PTP-Capable Sites
#
# OWL requires highly synchronized clocks, which means we must deploy nodes only on **PTP-capable** sites. PTP (Precision Time Protocol, IEEE 1588) provides sub-microsecond clock accuracy -- far better than NTP (which only achieves millisecond accuracy).
#
# <div class="fab-danger">
#
# **Important:** Deploying OWL on non-PTP sites will produce **inaccurate results** because the clock drift between nodes can be larger than the actual network latency.
#
# </div>

# %% [markdown]
# ### (Optional) Find ALL PTP-Capable Sites
#
# If you want to choose specific sites, this cell lists all currently available PTP-capable sites.

# %%
# Get the total number of FABRIC sites for comparison
sites = fm.get_site_names()
print(f"all FABRIC sites: {len(sites)} ({sites})")

# Filter for sites that are both PTP-capable and currently Active
ptp_sites = fm.list_sites(
    output="list",
    quiet=True,
    filter_function = lambda x:x['ptp_capable'] is True and x['state'] == 'Active',
)
ptp_site_names = [x['name'] for x in ptp_sites]

print(f"PTP-enabled and active sites: {len(ptp_site_names)} ({ptp_site_names})")

# %% [markdown]
# ### Choose 2 PTP-Capable Sites
#
# Randomly select two PTP-capable sites for our experiment. You can change this to use specific sites if desired.

# %%
# Randomly select 2 PTP-capable, active sites
ptp_site_names = fm.get_random_sites(count=2, filter_function=lambda x: x['ptp_capable'] is True and x['state'] == 'Active')

# %%
# Display the selected sites
print(f"Selected PTP-enabled and active sites: {len(ptp_site_names)} ({ptp_site_names})")

# %% [markdown]
# ---
#
# ## Step 3: Create the Slice
#
# Create a slice with one node at each PTP-capable site. Nodes use the `docker_rocky_8` image (which includes Docker pre-installed) and are connected via **FABnetv4** -- FABRIC's Layer 3 routed network that provides automatic IP addressing across sites.

# %%
# Define the slice name
slice_name = "owl-slice"

# %%
# Create a new slice
slice = fm.new_slice(name=slice_name)

# Add one node at each selected PTP site
for i, site_name in enumerate(ptp_site_names):
    # Use docker_rocky_8 image which has Docker pre-installed
    node = slice.add_node(name=f"node{i}", site=site_name, image='docker_rocky_8')
    # Add FABnetv4 networking (automatic L3 connectivity across sites)
    node.add_fabnet()
    print(f"adding node{i} at {site_name}")

# Submit the slice request and wait for provisioning
slice.submit();

# %% [markdown]
# ### (Optional) Inspect the Slice
#
# Verify the slice is active and examine the node placement, network configuration, and interface details.

# %%
try:
    slice = fm.get_slice(name=slice_name)
    # Display slice-level information (state, expiration, etc.)
    slice.show()
    # List all nodes with their details
    slice.list_nodes()
    # List all networks
    slice.list_networks()
    # List all interfaces with IP assignments
    slice.list_interfaces()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Step 4: Install and Configure PTP on Each Node
#
# This is the most critical step. We install the **LinuxPTP** software package on each node using an Ansible playbook from the [FABRIC PTP repository](https://github.com/fabric-testbed/ptp). This configures `ptp4l` and `phc2sys` daemons that synchronize the node's system clock to the PTP grandmaster clock at each site.
#
# <div class="fab-danger">
#
# **Important:** Do not modify the PTP installation cells unless you understand PTP configuration. Incorrect settings can lead to inaccurate measurements.
#
# </div>

# %%
# Get node objects for later use
nodes = slice.get_nodes()

# %% [markdown]
# ### Set Up PTP Repository and Ansible Playbook
#
# Download the Ansible role to configure and install the LinuxPTP software. For more details regarding the steps performed in the playbook, please refer to the repo at [https://github.com/fabric-testbed/ptp](https://github.com/fabric-testbed/ptp)

# %%
pre_requisites = None

# Set Deployment tool repository details
repo_branch = 'main'
repo_name = 'ptp'
destination_folder = f"""/tmp/{repo_name}-{repo_branch}"""
clone_instructions = f"""
cd /tmp/;rm -rf /tmp/{repo_name}-{repo_branch};git clone --branch {repo_branch} https://github.com/fabric-testbed/{repo_name}.git {destination_folder};
"""

# %% [markdown]
# ### Setting PTP Install Restrictions (Leave it blank)
#
# * If you do not want all interfaces synchronized to PTP, add the name of interfaces to avoid as shown
# * Management interfaces are not considered and are avoided by default
# * If you do not want the system clock synchronized to PTP set the 'SYNC_SYSTEM_CLOCK' to False
# * If you do not have any restrictions for a node, you can omit that node from the list
#
# Example:
# ```
# NODE_RESTRICTIONS = {
#    'node1' : { 'AVOID_IFACES': ['enp6s0'],'SYNC_SYSTEM_CLOCK': False},
#    'node2' : { 'AVOID_IFACES': ['enp6s0','enp7s0']},
# }
# ```

# %%
# No restrictions -- all interfaces will be PTP-synchronized
NODE_RESTRICTIONS = {}

# %% [markdown]
# ### Restrict Ansible operation based on tags (Leave it blank!!!)
#
# * Possible values are ptp_stop,ptp_start,ptp_install
# * Only one tag is allowed
# * If empty then all three are performed in the right sequence
# * If NODE_RESTRICTIONS are applied along with the tags, the operations will not be performed on the AVOIDED INTERFACES
#
# Example
# ```
# ansible_tags = 'ptp_stop'
# ```

# %%
# Empty means: install, configure, and start PTP (all steps)
ansible_tags = ''

# %% [markdown]
# ### Run Ansible playbook on each node (Leave it exactly as it is!)
#
# This cell runs the PTP installation playbook on all nodes in parallel using threaded execution. The process takes several minutes per node.

# %%
# Build the Ansible command to run locally on each node
ansible_instructions = f"""
cd {destination_folder}/ansible;ansible-playbook --connection=local --inventory 127.0.0.1, --limit 127.0.0.1 playbook_fabric_experiment_ptp.yml"""

# Dictionary to track execution threads (one per node)
execute_threads = {}

for node in nodes:
    # Install Ansible and Git prerequisites based on the node's OS
    if [ele for ele in ["rocky", "centos"] if (ele in node.get_image())]:
        pre_requisites = f"""
        sudo dnf -y install epel-release ; sudo dnf -y install ansible git;
        """
    elif [ele for ele in ["ubuntu", "debian"] if (ele in node.get_image())]:
        pre_requisites = f"""sudo apt-get update;sudo apt-get -y install ansible git;"""
    else:
        pre_requisites = None
    node_name = node.get_name()
    
    # Create JSON files for extra params that will be provided to ansible
    if node_name in NODE_RESTRICTIONS.keys():    
        extra_ansible_params = f""" --extra-vars @parameters.json""";
        with open('/tmp/'+node_name+'-parameters.json', 'w') as f:
            json.dump(NODE_RESTRICTIONS[node_name], f)
        print (f"Uploading install restrictions for {node_name}")    
        node.upload_file('/tmp/'+node_name+'-parameters.json',destination_folder+'/ansible/parameters.json')
    else:
        extra_ansible_params = ''
    if ansible_tags != '':
        extra_ansible_params = extra_ansible_params + ' --tags '+ansible_tags
        
    print (f"Running the PTP Deployment Ansible Playbook on {node.get_name()}")
    # Execute the full PTP installation pipeline in a background thread
    execute_threads[node] = node.execute_thread(\
                f"{pre_requisites}"\
                f"{clone_instructions}"\
                f"{ansible_instructions}"\
                f"{extra_ansible_params}",\
                output_file=f"/tmp/{node.get_name()}_ptpinstall.log"\
                )

    # Wait for all threads to complete
for node,thread in execute_threads.items():
    print(f"Waiting for result from node {node.get_name()}")
    stdout,stderr = thread.result()

print (f"Ansible Playbook run on all nodes completed\n")

# %% [markdown]
# ### Start Docker on Each Node
#
# Ensure Docker is running on all nodes. The output of `docker ps` should show an empty container list (no errors).

# %%
for node in nodes:
    # Start and enable Docker service
    node.execute("sudo systemctl start docker")
    node.execute("sudo systemctl enable docker")
    # Add the rocky user to the docker group (avoids needing sudo for docker commands)
    node.execute("sudo usermod -aG docker rocky")
    
    # Verify Docker is running correctly
    print(f"\n Verify installtion... on {node.get_name()}")
    node.execute("docker ps")

# %% [markdown]
# <div class="fab-success">
#
# **Setup complete!** All nodes now have PTP-synchronized clocks and Docker running. The nodes are ready for OWL measurements.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 5: Run OWL Measurements
#
# OWL provides two usage modes:
#
# - **Option 1: Automated all-to-all** -- `start_owl_all()` starts senders and capturers on every node, measuring latency between all pairs
# - **Option 2: Manual specific pairs** -- Start senders and capturers individually for targeted measurements
#
# ### Specify the OWL Docker Image
#
# The OWL Docker images are published on [Docker Hub](https://hub.docker.com/r/fabrictestbed/owl).

# %%
# Specify the OWL Docker image version
# Check Docker Hub for the latest version: https://hub.docker.com/r/fabrictestbed/owl
image_name="fabrictestbed/owl:0.2.0"

# %% [markdown]
# #### (Optional) Pre-pull the Docker Image
#
# Docker start (in the cells below) should pull the image automatically. But if pulling the image is necessary, uncomment and use these lines.

# %%
# for node in nodes:
#     print(node.get_name())
#     node.execute(f"sudo docker pull {image_name}")

# %% [markdown]
# ### Option 1: Automated All-to-All Measurement
#
# Use `start_owl_all()` to automatically start senders and capturers on every node. This measures one-way latency between all pairs of nodes.
#
# **Parameters:**
# - `probe_freq=10` : Send one probe packet every 10 seconds
# - `duration=600` : Run for 600 seconds (10 minutes)
# - `delete_previous=True` : Remove any pcap files from previous runs

# %%
# Start OWL senders and capturers on all nodes
# Each node sends probes to every other node and captures incoming probes
owl.start_owl_all(slice, img_name=image_name, probe_freq=10, duration=600, delete_previous=True)

# %% [markdown]
# #### Check OWL Status on All Nodes
#
# Verify that OWL containers are running on each node.

# %%
# Display the status of OWL containers across all nodes
owl.check_owl_all(slice)

# %% [markdown]
# #### Verify pcap Files Are Being Generated
#
# OWL writes packet captures to `~/owl-output/` on each node. Check that files are being created and growing in size.

# %%
# List the pcap output files on each node
for node in nodes:
    node.execute("hostname")
    node.execute("ls -lh ~/owl-output/")

# %% [markdown]
# #### Stop OWL Containers on All Nodes
#
# When you have collected enough data, stop all OWL containers.

# %%
# Stop all OWL sender and capturer containers
owl.stop_owl_all(slice)

# %% [markdown]
# ---
#
# ### Option 2: Manual Sender/Capturer Control
#
# For more targeted measurements, you can start senders and capturers individually. This is useful when you want to measure latency for a **specific direction** (e.g., only node1 to node0).

# %%
# Start capturer on node0 -- this node will receive and timestamp probe packets
owl.start_owl_capturer(slice, dst_node=slice.get_node(name="node0"), img_name=image_name, duration=60)

# %%
# Start sender on node1 to send probe packets TO node0
# This measures the one-way latency from node1 → node0
owl.start_owl_sender(slice, src_node=slice.get_node(name="node1"), dst_node=slice.get_node(name="node0"), img_name=image_name, duration=60)

# %% [markdown]
# #### Check Container Status

# %%
# Check running OWL containers on all nodes
owl.check_owl_all(slice)

# %% [markdown]
# #### Verify pcap Files

# %%
# Check pcap file generation
for node in nodes:
    node.execute("ls -lh ~/owl-output/")

# %% [markdown]
# #### Stop Individual Containers

# %%
# Stop sender on node1 (sending to node0)
owl.stop_owl_sender(slice, src_node=slice.get_node(name="node1"), dst_node=slice.get_node(name="node0"))

# %%
# Stop capturer on node0
owl.stop_owl_capturer(slice, dst_node=slice.get_node(name="node0"))

# %% [markdown]
# ---
#
# ## Step 6 (Optional): Download pcap Files for Analysis
#
# Download the pcap files from each node to your local machine for offline analysis. You can use tools like **Wireshark**, **tshark**, or the OWL analysis scripts to compute latency statistics from these captures.

# %%
# Download pcap files from each node to the current directory
for node in nodes:
    pcap_name, _ = node.execute("ls ~/owl-output")
    node.download_file(f"./{pcap_name.strip()}", f"/home/rocky/owl-output/{pcap_name.strip()}",)

# %% [markdown]
# ---
#
# ## Step 7: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. Make sure to download any pcap files you need before deleting.
#
# </div>

# %%
# try:
#     slice = fm.get_slice(name=slice_name)
#     slice.delete()
# except Exception as e:
#     print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | No PTP-capable sites found | Sites may be in maintenance | Check site status at [FABRIC Portal](https://portal.fabric-testbed.net/) |
# | PTP Ansible playbook fails | Network issues during git clone | Re-run the Ansible cell; it will re-clone the repository |
# | Docker not running | Service did not start | Run `sudo systemctl start docker` on the affected node |
# | OWL containers exit immediately | Docker image pull failed | Pre-pull the image manually: `sudo docker pull fabrictestbed/owl:0.2.0` |
# | pcap files are empty | Sender and capturer not on correct nodes | Verify that the sender's destination matches the capturer's node |
# | Negative latency values | PTP clocks not yet synchronized | Wait 5-10 minutes after PTP installation for clocks to converge |
# | Very high latency values (>1s) | PTP not running or misconfigured | Check `ptp4l` and `phc2sys` services: `sudo systemctl status ptp4l` |
# | `mflib` import error | Library not installed | Install with `pip install mflib` |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib and mflib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_sites(count)` | Select random sites matching filter criteria | [get_random_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_sites) |
# | `fablib.list_sites()` | List all FABRIC sites with filtering | [list_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.list_sites) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_node()` | Add a compute node | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_fabnet()` | Add FABnetv4 L3 networking to a node | [add_fabnet](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_fabnet) |
# | `node.execute()` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `node.execute_thread()` | Execute a command in a background thread | [execute_thread](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute_thread) |
# | `node.download_file()` | Download a file from a node | [download_file](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.download_file) |
# | `owl.start_owl_all()` | Start OWL senders and capturers on all nodes | [mflib OWL docs](https://github.com/fabric-testbed/mflib) |
# | `owl.stop_owl_all()` | Stop all OWL containers | [mflib OWL docs](https://github.com/fabric-testbed/mflib) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you can measure one-way latency, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Network Throughput** | [iPerf3 Optimized](../iPerf3/iperf3_optimized.ipynb) | Measure and optimize throughput with CPU pinning and NUMA tuning |
# | **Smart NIC Performance** | [iPerf3 Smart NIC](../iPerf3/iperf3_optimized_smart_nic.ipynb) | High-speed 25 Gbps testing with ConnectX-5 NICs |
# | **Facility Ports** | [Chameleon L2 Stitch](../Chameleon_Facility_Port/Chameleon_Facility_Port_L2.ipynb) | Connect FABRIC to external testbeds |
# | **FABnet Networking** | [FABnet IPv4](../../fablib_api/create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb) | Learn about FABRIC's Layer 3 networking |
