# %% [markdown]
# # Routing Topology: OSPF using FRRouting
#
# This notebook is an example of how to create a FABRIC routing experiment topology comprising nodes at three different sites. Each site has a local layer 2 (Ethernet) network connecting a set of local nodes and one gateway router. The three gateway routers connect to each other and use the [FRRouting](https://frrouting.org/) protocol suite to deploy [OSPF](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) dameons to propagate route updates across the topology.
#
# You might be familiar with the [Quagga](https://www.quagga.net/) router suite.  FRRouting is based on Quagga but has a more active upstream community including many large companies working on cloud networking.
#
#
# <img src="./figs/frr.png" width="90%"><br>

# %% [markdown]
# ## Import the FABlib Library

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_be533 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_be533 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_be533 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_be533_row0_col0, #T_be533_row0_col1, #T_be533_row1_col0, #T_be533_row1_col1, #T_be533_row2_col0, #T_be533_row2_col1, #T_be533_row3_col0, #T_be533_row3_col1, #T_be533_row4_col0, #T_be533_row4_col1, #T_be533_row5_col0, #T_be533_row5_col1, #T_be533_row6_col0, #T_be533_row6_col1, #T_be533_row7_col0, #T_be533_row7_col1, #T_be533_row8_col0, #T_be533_row8_col1, #T_be533_row9_col0, #T_be533_row9_col1, #T_be533_row10_col0, #T_be533_row10_col1, #T_be533_row11_col0, #T_be533_row11_col1, #T_be533_row12_col0, #T_be533_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_be533">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_be533_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_be533_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_be533_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_be533_row2_col1" class="data row2 col1" >/home/fabric/work/fabric_config/tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_be533_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_be533_row4_col1" class="data row4 col1" >pruth_0031379841</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_be533_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_be533_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_be533_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_be533_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_be533_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_be533_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_be533_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_be533_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_be533_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates private layer 2 networks on three sites including OSPF gateway routers that propagate routes across the topology.

# %%
slice_name = 'OSPF_Routing_Topology'

sites= fablib.get_random_sites(count=3, avoid=[])

print(f"Sites: {sites}")

router_base_name='router'
router_link_base_name='link'

node_base_name='node'
local_network_base_name='net_local'

site_node_count=2
# Out:
# Sites: ['STAR', 'DALL', 'UTAH']

# %%
slice = fablib.new_slice(name=slice_name)

# Create Routers
routers = []
frr_user_data = {}
for i, site in enumerate(sites):
    router_name = f"{router_base_name}{site}"
    frr_user_data[router_name] = {}
    local_subnet = IPv4Network(f"192.168.{i+1}.0/24")
    local_gateway = local_subnet[1]
    
    router = slice.add_node(name=router_name, site=site, cores=8, ram=16, disk=100, image='docker_rocky_8')
    router.add_fabnet()
    
    # Add experiment nets
    iface_local = router.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]
    iface_local.set_mode('config')
    
    local_net = slice.add_l2network(name=f'{local_network_base_name}{site}', subnet=local_subnet, gateway=local_gateway)
    local_net.add_interface(iface_local)
    iface_local.set_ip_addr(local_gateway)
    
    frr_user_data[router_name]['local_iface'] = iface_local.get_name()
    frr_user_data[router_name]['link_ifaces'] = []
    
    router.add_post_boot_upload_directory('node_tools','.')    
    router.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }}')
    router.add_post_boot_upload_directory('docker_containers','.')
    
    iface_template = f"{{{{ interfaces['{iface_local.get_name()}'].dev }}}}"
    
    router.add_post_boot_execute(f"./docker_containers/fabric_frrouting/node_tools/frr_config_docker.sh {iface_template} {local_gateway} '192.168.0.0'")    
    routers.append(router)
    


# Create Links between routers (ring)
links = []
for i, site in enumerate(sites):
    
    link_info = {}
    link_subnet = IPv4Network(f"192.168.10{i+1}.0/24")
    
    router1 = routers[i]
    router2 = routers[(i+1)%len(sites)]
    
    print(f"link: {router1.get_name()} -> {router2.get_name()}")
    
    #link_info['name'] = f'{router_link_base_name}{i+1}'
    link_info['name'] = f'{router1.get_site()}-{router2.get_site()}-{router_link_base_name}{i+1}'
    
    link = slice.add_l2network(name=link_info['name'], subnet=link_subnet)
    links.append(link)
    
    iface1 = router1.add_component(model='NIC_Basic', name=f'{router1.get_site()}-{router2.get_site()}').get_interfaces()[0]
    iface2 = router2.add_component(model='NIC_Basic', name=f'{router2.get_site()}-{router1.get_site()}').get_interfaces()[0]
    
    iface1.set_mode('config')
    iface2.set_mode('config')

    print(f"iface1: {iface1.get_name()}")
    link.add_interface(iface1)
    print(f"iface2: {iface2.get_name()}")
    link.add_interface(iface2)
    
    iface1.set_ip_addr(link_subnet[1])
    iface2.set_ip_addr(link_subnet[2])
        
    frr_user_data[router1.get_name()]['link_ifaces'].append(iface1.get_name()) 
    frr_user_data[router2.get_name()]['link_ifaces'].append(iface2.get_name()) 
    
    iface1_template = f"{{{{ interfaces['{iface1.get_name()}'].dev }}}}"
    iface2_template = f"{{{{ interfaces['{iface2.get_name()}'].dev }}}}"

    router1.add_post_boot_execute(f'./docker_containers/fabric_frrouting/node_tools/add_ospf_neighbor.sh {iface1_template} {link_subnet[1]} ')
    router2.add_post_boot_execute(f'./docker_containers/fabric_frrouting/node_tools/add_ospf_neighbor.sh {iface2_template} {link_subnet[2]} ')

# Set frr user_data
for router in slice.get_nodes():
    user_data = router.get_user_data()
    user_data['frr'] = frr_user_data[router.get_name()]
    router.set_user_data(user_data)
    
    all_devs_template = ''
    for iface in router.get_interfaces():
        all_devs_template +=  f" {{{{ interfaces['{iface.get_name()}'].dev }}}} "

    router.add_post_boot_execute(f'./docker_containers/fabric_frrouting/start.sh {all_devs_template} ')
    
slice_id = slice.submit()
# Out:
# Retry: 13, Time: 377 sec
# <style type="text/css">
# #T_26f22 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_26f22 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_26f22 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_26f22_row0_col0, #T_26f22_row0_col1, #T_26f22_row1_col0, #T_26f22_row1_col1, #T_26f22_row2_col0, #T_26f22_row2_col1, #T_26f22_row3_col0, #T_26f22_row3_col1, #T_26f22_row4_col0, #T_26f22_row4_col1, #T_26f22_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_26f22_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_26f22">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_26f22_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_26f22_row0_col1" class="data row0 col1" >14e0d411-4043-48ac-895b-f4ac6573cebc</td>
#     </tr>
#     <tr>
#       <td id="T_26f22_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_26f22_row1_col1" class="data row1 col1" >OSPF_Routing_Topology</td>
#     </tr>
#     <tr>
#       <td id="T_26f22_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_26f22_row2_col1" class="data row2 col1" >2023-04-23 16:06:35 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_26f22_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_26f22_row3_col1" class="data row3 col1" >2023-04-22 16:06:36 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_26f22_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_26f22_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_26f22_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_26f22_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_33a03 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_33a03 th {
#   text-align: left;
# }
# #T_33a03 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_33a03 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_33a03 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_33a03_row0_col0, #T_33a03_row0_col1, #T_33a03_row0_col2, #T_33a03_row0_col3, #T_33a03_row0_col4, #T_33a03_row0_col5, #T_33a03_row0_col6, #T_33a03_row0_col7, #T_33a03_row0_col8, #T_33a03_row0_col9, #T_33a03_row0_col10, #T_33a03_row0_col13, #T_33a03_row0_col14, #T_33a03_row0_col15, #T_33a03_row1_col0, #T_33a03_row1_col1, #T_33a03_row1_col2, #T_33a03_row1_col3, #T_33a03_row1_col4, #T_33a03_row1_col5, #T_33a03_row1_col6, #T_33a03_row1_col7, #T_33a03_row1_col8, #T_33a03_row1_col9, #T_33a03_row1_col10, #T_33a03_row1_col13, #T_33a03_row1_col14, #T_33a03_row1_col15, #T_33a03_row2_col0, #T_33a03_row2_col1, #T_33a03_row2_col2, #T_33a03_row2_col3, #T_33a03_row2_col4, #T_33a03_row2_col5, #T_33a03_row2_col6, #T_33a03_row2_col7, #T_33a03_row2_col8, #T_33a03_row2_col9, #T_33a03_row2_col10, #T_33a03_row2_col13, #T_33a03_row2_col14, #T_33a03_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_33a03_row0_col11, #T_33a03_row1_col11, #T_33a03_row2_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_33a03_row0_col12, #T_33a03_row1_col12, #T_33a03_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_33a03">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_33a03_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_33a03_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_33a03_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_33a03_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_33a03_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_33a03_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_33a03_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_33a03_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_33a03_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_33a03_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_33a03_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_33a03_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_33a03_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_33a03_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_33a03_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_33a03_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_33a03_row0_col0" class="data row0 col0" >605643a4-d9e3-43ae-a65b-5d7927c15f5e</td>
#       <td id="T_33a03_row0_col1" class="data row0 col1" >routerDALL</td>
#       <td id="T_33a03_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_33a03_row0_col3" class="data row0 col3" >16</td>
#       <td id="T_33a03_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_33a03_row0_col5" class="data row0 col5" >docker_rocky_8</td>
#       <td id="T_33a03_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_33a03_row0_col7" class="data row0 col7" >dall-w3.fabric-testbed.net</td>
#       <td id="T_33a03_row0_col8" class="data row0 col8" >DALL</td>
#       <td id="T_33a03_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_33a03_row0_col10" class="data row0 col10" >2001:400:a100:3000:f816:3eff:fea2:f664</td>
#       <td id="T_33a03_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_33a03_row0_col12" class="data row0 col12" ></td>
#       <td id="T_33a03_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fea2:f664</td>
#       <td id="T_33a03_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_33a03_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_33a03_row1_col0" class="data row1 col0" >c3101d96-e96a-46b5-9350-9f97ec1fa528</td>
#       <td id="T_33a03_row1_col1" class="data row1 col1" >routerSTAR</td>
#       <td id="T_33a03_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_33a03_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_33a03_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_33a03_row1_col5" class="data row1 col5" >docker_rocky_8</td>
#       <td id="T_33a03_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_33a03_row1_col7" class="data row1 col7" >star-w3.fabric-testbed.net</td>
#       <td id="T_33a03_row1_col8" class="data row1 col8" >STAR</td>
#       <td id="T_33a03_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_33a03_row1_col10" class="data row1 col10" >2001:400:a100:3030:f816:3eff:fe27:c0c2</td>
#       <td id="T_33a03_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_33a03_row1_col12" class="data row1 col12" ></td>
#       <td id="T_33a03_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3030:f816:3eff:fe27:c0c2</td>
#       <td id="T_33a03_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_33a03_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_33a03_row2_col0" class="data row2 col0" >72a53436-d7ed-4235-9955-3e2400dff4f0</td>
#       <td id="T_33a03_row2_col1" class="data row2 col1" >routerUTAH</td>
#       <td id="T_33a03_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_33a03_row2_col3" class="data row2 col3" >16</td>
#       <td id="T_33a03_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_33a03_row2_col5" class="data row2 col5" >docker_rocky_8</td>
#       <td id="T_33a03_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_33a03_row2_col7" class="data row2 col7" >utah-w3.fabric-testbed.net</td>
#       <td id="T_33a03_row2_col8" class="data row2 col8" >UTAH</td>
#       <td id="T_33a03_row2_col9" class="data row2 col9" >rocky</td>
#       <td id="T_33a03_row2_col10" class="data row2 col10" >2001:1948:417:7:f816:3eff:fe58:9366</td>
#       <td id="T_33a03_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_33a03_row2_col12" class="data row2 col12" ></td>
#       <td id="T_33a03_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:1948:417:7:f816:3eff:fe58:9366</td>
#       <td id="T_33a03_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_33a03_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_87810 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_87810 th {
#   text-align: left;
# }
# #T_87810 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_87810 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_87810 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_87810_row0_col0, #T_87810_row0_col1, #T_87810_row0_col2, #T_87810_row0_col3, #T_87810_row0_col4, #T_87810_row0_col5, #T_87810_row0_col6, #T_87810_row1_col0, #T_87810_row1_col1, #T_87810_row1_col2, #T_87810_row1_col3, #T_87810_row1_col4, #T_87810_row1_col5, #T_87810_row1_col6, #T_87810_row2_col0, #T_87810_row2_col1, #T_87810_row2_col2, #T_87810_row2_col3, #T_87810_row2_col4, #T_87810_row2_col5, #T_87810_row2_col6, #T_87810_row3_col0, #T_87810_row3_col1, #T_87810_row3_col2, #T_87810_row3_col3, #T_87810_row3_col4, #T_87810_row3_col5, #T_87810_row3_col6, #T_87810_row4_col0, #T_87810_row4_col1, #T_87810_row4_col2, #T_87810_row4_col3, #T_87810_row4_col4, #T_87810_row4_col5, #T_87810_row4_col6, #T_87810_row5_col0, #T_87810_row5_col1, #T_87810_row5_col2, #T_87810_row5_col3, #T_87810_row5_col4, #T_87810_row5_col5, #T_87810_row5_col6, #T_87810_row6_col0, #T_87810_row6_col1, #T_87810_row6_col2, #T_87810_row6_col3, #T_87810_row6_col4, #T_87810_row6_col5, #T_87810_row6_col6, #T_87810_row7_col0, #T_87810_row7_col1, #T_87810_row7_col2, #T_87810_row7_col3, #T_87810_row7_col4, #T_87810_row7_col5, #T_87810_row7_col6, #T_87810_row8_col0, #T_87810_row8_col1, #T_87810_row8_col2, #T_87810_row8_col3, #T_87810_row8_col4, #T_87810_row8_col5, #T_87810_row8_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_87810_row0_col7, #T_87810_row1_col7, #T_87810_row2_col7, #T_87810_row3_col7, #T_87810_row4_col7, #T_87810_row5_col7, #T_87810_row6_col7, #T_87810_row7_col7, #T_87810_row8_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_87810_row0_col8, #T_87810_row1_col8, #T_87810_row2_col8, #T_87810_row3_col8, #T_87810_row4_col8, #T_87810_row5_col8, #T_87810_row6_col8, #T_87810_row7_col8, #T_87810_row8_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_87810">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_87810_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_87810_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_87810_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_87810_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_87810_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_87810_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_87810_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_87810_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_87810_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87810_row0_col0" class="data row0 col0" >6e9a26f5-53ec-40c4-9c06-aa02ba80d0dd</td>
#       <td id="T_87810_row0_col1" class="data row0 col1" >DALL-UTAH-link2</td>
#       <td id="T_87810_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_87810_row0_col3" class="data row0 col3" >L2STS</td>
#       <td id="T_87810_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_87810_row0_col5" class="data row0 col5" >192.168.102.0/24</td>
#       <td id="T_87810_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_87810_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_87810_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_87810_row1_col0" class="data row1 col0" >0da75737-c1f9-4500-a6d0-2a6609b9d0ea</td>
#       <td id="T_87810_row1_col1" class="data row1 col1" >FABNET_IPv4_DALL</td>
#       <td id="T_87810_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_87810_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_87810_row1_col4" class="data row1 col4" >DALL</td>
#       <td id="T_87810_row1_col5" class="data row1 col5" >10.133.131.0/24</td>
#       <td id="T_87810_row1_col6" class="data row1 col6" >10.133.131.1</td>
#       <td id="T_87810_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_87810_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_87810_row2_col0" class="data row2 col0" >03cb8db5-ce7b-4ac3-be90-97c407803f05</td>
#       <td id="T_87810_row2_col1" class="data row2 col1" >FABNET_IPv4_STAR</td>
#       <td id="T_87810_row2_col2" class="data row2 col2" >L3</td>
#       <td id="T_87810_row2_col3" class="data row2 col3" >FABNetv4</td>
#       <td id="T_87810_row2_col4" class="data row2 col4" >STAR</td>
#       <td id="T_87810_row2_col5" class="data row2 col5" >10.129.139.0/24</td>
#       <td id="T_87810_row2_col6" class="data row2 col6" >10.129.139.1</td>
#       <td id="T_87810_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_87810_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_87810_row3_col0" class="data row3 col0" >df9d1b46-673b-4466-8af1-7f3c72d5f2a0</td>
#       <td id="T_87810_row3_col1" class="data row3 col1" >FABNET_IPv4_UTAH</td>
#       <td id="T_87810_row3_col2" class="data row3 col2" >L3</td>
#       <td id="T_87810_row3_col3" class="data row3 col3" >FABNetv4</td>
#       <td id="T_87810_row3_col4" class="data row3 col4" >UTAH</td>
#       <td id="T_87810_row3_col5" class="data row3 col5" >10.132.18.0/24</td>
#       <td id="T_87810_row3_col6" class="data row3 col6" >10.132.18.1</td>
#       <td id="T_87810_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_87810_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_87810_row4_col0" class="data row4 col0" >739273fb-b5fb-40bd-8288-8518064233cb</td>
#       <td id="T_87810_row4_col1" class="data row4 col1" >STAR-DALL-link1</td>
#       <td id="T_87810_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_87810_row4_col3" class="data row4 col3" >L2STS</td>
#       <td id="T_87810_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_87810_row4_col5" class="data row4 col5" >192.168.101.0/24</td>
#       <td id="T_87810_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_87810_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_87810_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_87810_row5_col0" class="data row5 col0" >0428c760-aac1-450f-9f23-0a8fcf30a61e</td>
#       <td id="T_87810_row5_col1" class="data row5 col1" >UTAH-STAR-link3</td>
#       <td id="T_87810_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_87810_row5_col3" class="data row5 col3" >L2STS</td>
#       <td id="T_87810_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_87810_row5_col5" class="data row5 col5" >192.168.103.0/24</td>
#       <td id="T_87810_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_87810_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_87810_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_87810_row6_col0" class="data row6 col0" >b5ccfa79-0425-4be5-a420-997579283492</td>
#       <td id="T_87810_row6_col1" class="data row6 col1" >net_localDALL</td>
#       <td id="T_87810_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_87810_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_87810_row6_col4" class="data row6 col4" >DALL</td>
#       <td id="T_87810_row6_col5" class="data row6 col5" >192.168.2.0/24</td>
#       <td id="T_87810_row6_col6" class="data row6 col6" >192.168.2.1</td>
#       <td id="T_87810_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_87810_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_87810_row7_col0" class="data row7 col0" >1e4dd10c-614e-4b74-a5f3-2b063056af95</td>
#       <td i
# <style type="text/css">
# #T_0a6f9 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0a6f9 th {
#   text-align: left;
# }
# #T_0a6f9 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0a6f9 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0a6f9 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0a6f9_row0_col0, #T_0a6f9_row0_col1, #T_0a6f9_row0_col2, #T_0a6f9_row0_col3, #T_0a6f9_row0_col4, #T_0a6f9_row0_col5, #T_0a6f9_row0_col6, #T_0a6f9_row0_col7, #T_0a6f9_row0_col8, #T_0a6f9_row0_col9, #T_0a6f9_row0_col10, #T_0a6f9_row1_col0, #T_0a6f9_row1_col1, #T_0a6f9_row1_col2, #T_0a6f9_row1_col3, #T_0a6f9_row1_col4, #T_0a6f9_row1_col5, #T_0a6f9_row1_col6, #T_0a6f9_row1_col7, #T_0a6f9_row1_col8, #T_0a6f9_row1_col9, #T_0a6f9_row1_col10, #T_0a6f9_row2_col0, #T_0a6f9_row2_col1, #T_0a6f9_row2_col2, #T_0a6f9_row2_col3, #T_0a6f9_row2_col4, #T_0a6f9_row2_col5, #T_0a6f9_row2_col6, #T_0a6f9_row2_col7, #T_0a6f9_row2_col8, #T_0a6f9_row2_col9, #T_0a6f9_row2_col10, #T_0a6f9_row3_col0, #T_0a6f9_row3_col1, #T_0a6f9_row3_col2, #T_0a6f9_row3_col3, #T_0a6f9_row3_col4, #T_0a6f9_row3_col5, #T_0a6f9_row3_col6, #T_0a6f9_row3_col7, #T_0a6f9_row3_col8, #T_0a6f9_row3_col9, #T_0a6f9_row3_col10, #T_0a6f9_row4_col0, #T_0a6f9_row4_col1, #T_0a6f9_row4_col2, #T_0a6f9_row4_col3, #T_0a6f9_row4_col4, #T_0a6f9_row4_col5, #T_0a6f9_row4_col6, #T_0a6f9_row4_col7, #T_0a6f9_row4_col8, #T_0a6f9_row4_col9, #T_0a6f9_row4_col10, #T_0a6f9_row5_col0, #T_0a6f9_row5_col1, #T_0a6f9_row5_col2, #T_0a6f9_row5_col3, #T_0a6f9_row5_col4, #T_0a6f9_row5_col5, #T_0a6f9_row5_col6, #T_0a6f9_row5_col7, #T_0a6f9_row5_col8, #T_0a6f9_row5_col9, #T_0a6f9_row5_col10, #T_0a6f9_row6_col0, #T_0a6f9_row6_col1, #T_0a6f9_row6_col2, #T_0a6f9_row6_col3, #T_0a6f9_row6_col4, #T_0a6f9_row6_col5, #T_0a6f9_row6_col6, #T_0a6f9_row6_col7, #T_0a6f9_row6_col8, #T_0a6f9_row6_col9, #T_0a6f9_row6_col10, #T_0a6f9_row7_col0, #T_0a6f9_row7_col1, #T_0a6f9_row7_col2, #T_0a6f9_row7_col3, #T_0a6f9_row7_col4, #T_0a6f9_row7_col5, #T_0a6f9_row7_col6, #T_0a6f9_row7_col7, #T_0a6f9_row7_col8, #T_0a6f9_row7_col9, #T_0a6f9_row7_col10, #T_0a6f9_row8_col0, #T_0a6f9_row8_col1, #T_0a6f9_row8_col2, #T_0a6f9_row8_col3, #T_0a6f9_row8_col4, #T_0a6f9_row8_col5, #T_0a6f9_row8_col6, #T_0a6f9_row8_col7, #T_0a6f9_row8_col8, #T_0a6f9_row8_col9, #T_0a6f9_row8_col10, #T_0a6f9_row9_col0, #T_0a6f9_row9_col1, #T_0a6f9_row9_col2, #T_0a6f9_row9_col3, #T_0a6f9_row9_col4, #T_0a6f9_row9_col5, #T_0a6f9_row9_col6, #T_0a6f9_row9_col7, #T_0a6f9_row9_col8, #T_0a6f9_row9_col9, #T_0a6f9_row9_col10, #T_0a6f9_row10_col0, #T_0a6f9_row10_col1, #T_0a6f9_row10_col2, #T_0a6f9_row10_col3, #T_0a6f9_row10_col4, #T_0a6f9_row10_col5, #T_0a6f9_row10_col6, #T_0a6f9_row10_col7, #T_0a6f9_row10_col8, #T_0a6f9_row10_col9, #T_0a6f9_row10_col10, #T_0a6f9_row11_col0, #T_0a6f9_row11_col1, #T_0a6f9_row11_col2, #T_0a6f9_row11_col3, #T_0a6f9_row11_col4, #T_0a6f9_row11_col5, #T_0a6f9_row11_col6, #T_0a6f9_row11_col7, #T_0a6f9_row11_col8, #T_0a6f9_row11_col9, #T_0a6f9_row11_col10 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_0a6f9">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_0a6f9_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_0a6f9_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_0a6f9_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_0a6f9_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_0a6f9_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_0a6f9_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_0a6f9_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_0a6f9_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_0a6f9_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_0a6f9_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_0a6f9_level0_col10" class="col_heading level0 col10" >IP Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0a6f9_row0_col0" class="data row0 col0" >routerSTAR-STAR-DALL-p1</td>
#       <td id="T_0a6f9_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_0a6f9_row0_col2" class="data row0 col2" >routerSTAR</td>
#       <td id="T_0a6f9_row0_col3" class="data row0 col3" >STAR-DALL-link1</td>
#       <td id="T_0a6f9_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_0a6f9_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_0a6f9_row0_col6" class="data row0 col6" ></td>
#       <td id="T_0a6f9_row0_col7" class="data row0 col7" >22:66:05:94:42:14</td>
#       <td id="T_0a6f9_row0_col8" class="data row0 col8" >None</td>
#       <td id="T_0a6f9_row0_col9" class="data row0 col9" >None</td>
#       <td id="T_0a6f9_row0_col10" class="data row0 col10" >192.168.101.1</td>
#     </tr>
#     <tr>
#       <td id="T_0a6f9_row1_col0" class="data row1 col0" >routerSTAR-STAR-UTAH-p1</td>
#       <td id="T_0a6f9_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_0a6f9_row1_col2" class="data row1 col2" >routerSTAR</td>
#       <td id="T_0a6f9_row1_col3" class="data row1 col3" >UTAH-STAR-link3</td>
#       <td id="T_0a6f9_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_0a6f9_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_0a6f9_row1_col6" class="data row1 col6" ></td>
#       <td id="T_0a6f9_row1_col7" class="data row1 col7" >26:45:34:52:C7:56</td>
#       <td id="T_0a6f9_row1_col8" class="data row1 col8" >None</td>
#       <td id="T_0a6f9_row1_col9" class="data row1 col9" >None</td>
#       <td id="T_0a6f9_row1_col10" class="data row1 col10" >192.168.103.2</td>
#     </tr>
#     <tr>
#       <td id="T_0a6f9_row2_col0" class="data row2 col0" >routerSTAR-FABNET_IPv4_STAR_nic-p1</td>
#       <td id="T_0a6f9_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_0a6f9_row2_col2" class="data row2 col2" >routerSTAR</td>
#       <td id="T_0a6f9_row2_col3" class="data row2 col3" >FABNET_IPv4_STAR</td>
#       <td id="T_0a6f9_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_0a6f9_row2_col5" class="data row2 col5" >auto</td>
#       <td id="T_0a6f9_row2_col6" class="data row2 col6" ></td>
#       <td id="T_0a6f9_row2_col7" class="data row2 col7" >22:D3:E1:C7:45:DE</td>
#       <td id="T_0a6f9_row2_col8" class="data row2 col8" >None</td>
#       <td id="T_0a6f9_row2_col9" class="data row2 col9" >None</td>
#       <td id="T_0a6f9_row2_col10" class="data row2 col10" >10.129.139.2</td>
#     </tr>
#     <tr>
#       <td id="T_0a6f9_row3_col0" class="data row3 col0" >routerSTAR-nic_local-p1</td>
#       <td id="T_0a6f9_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_0a6f9_row3_col2" class="data row3 col2" >routerSTAR</td>
#       <td id="T_0a6f9_row3_col3" class="data row3 col3" >net_localSTAR</td>
#       <td id="T_0a6f9_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_0a6f9_row3_col5" class="data row3 col5" >config</td>
#       <td id="T_0a6f9_row3_col6" class="data row3 col6" ></td>
#       <td id="T_0a6f9_row3_col7" class="data row3 col7" >12:C5:55:4E:39:B3</td>
#       <td id="T_0a6f9_row3_col8" class="data row3 col8" >None</td>
#       <td id="T_0a6f9_row3_col9" class="data row3 col9" >None</td>
#       <td id="T_0a6f9_row3_col10" class="data row3 col10" >192.168.1.1</td>
#     </tr>
#     <tr>
#       <td id="T_0a6f9_row4_col0" class="data row4 col0" >routerDALL-FABNET_IPv4_DALL_nic-p1</td>
#       <td id="T_0a6f9_row4_col1" class="data row4 col1" >p1</td>
#       <td id="T_0a6f9_row4_col2" class="data row4 col2" >routerDALL</td>
#       <td id="T_0a6f9_row4_col3" class="data row4 col3" >FABNET_IPv4_DALL</td>
#       <td id="T_0a6f9_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_0a6f9_row4_col5" class="data row4 col5" >auto</td>
#       <td id="T_0a6f9_row4_col6" class="data row4 col6" ></td>
#       <td id="T_0a6f9_row4_col7" class="data row4 col7" >16:8D:92:B5:DC:B3</td>
# Time to print interfaces 377 seconds

# %%
for i, site in enumerate(sites):
    print(f"Adding nodes to {site}")
    print(f"update_count: {slice.update_count}, update_topology_count: {slice.update_topology_count}, update_slivers_count: {slice.update_slivers_count},  update_slice_count: {slice.update_slice_count}")
    for node_num in range(site_node_count):

        node_name = f"{site.lower()}{node_num+1}"
        node = slice.add_node(name=node_name, site=site, cores=8, ram=16, disk=100, image='docker_rocky_8')
        
        iface = node.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
        network = slice.get_network(name=f'{local_network_base_name}{site}')

        network.add_interface(iface)
        iface.set_mode('auto')
        node.add_route(subnet=IPv4Network('192.168.0.0/16'), next_hop=network.get_gateway())
        
        print(f"Adding control plane to node {node_name}")
        #add_control_plane(slice, node)
        node.add_fabnet()


        print(f"Getting  all_devs_template: {node_name}")

        all_devs_template = ''
        for iface in node.get_interfaces():
            all_devs_template +=  f" {{{{ interfaces['{iface.get_name()}'].dev }}}} "
        
        print(f"Adding post boot tasks: {node_name}")

        # Add post boot config    
        node.add_post_boot_upload_directory('node_tools','.')
        node.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }}')
        node.add_post_boot_upload_directory('docker_containers','.')
        node.add_post_boot_execute(f'cd docker_containers/fabric_multitool; docker compose up -d ')

#slice.save('frrouting.graphml')
print("submitting...")

slice.submit()
# Out:
# Retry: 12, Time: 714 sec
# <style type="text/css">
# #T_7587e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7587e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7587e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_7587e_row0_col0, #T_7587e_row0_col1, #T_7587e_row1_col0, #T_7587e_row1_col1, #T_7587e_row2_col0, #T_7587e_row2_col1, #T_7587e_row3_col0, #T_7587e_row3_col1, #T_7587e_row4_col0, #T_7587e_row4_col1, #T_7587e_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_7587e_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_7587e">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7587e_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_7587e_row0_col1" class="data row0 col1" >14e0d411-4043-48ac-895b-f4ac6573cebc</td>
#     </tr>
#     <tr>
#       <td id="T_7587e_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_7587e_row1_col1" class="data row1 col1" >OSPF_Routing_Topology</td>
#     </tr>
#     <tr>
#       <td id="T_7587e_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_7587e_row2_col1" class="data row2 col1" >2023-04-23 16:06:35 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_7587e_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_7587e_row3_col1" class="data row3 col1" >2023-04-22 16:06:36 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_7587e_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_7587e_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_7587e_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_7587e_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_38019 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_38019 th {
#   text-align: left;
# }
# #T_38019 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_38019 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_38019 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_38019_row0_col0, #T_38019_row0_col1, #T_38019_row0_col2, #T_38019_row0_col3, #T_38019_row0_col4, #T_38019_row0_col5, #T_38019_row0_col6, #T_38019_row0_col7, #T_38019_row0_col8, #T_38019_row0_col9, #T_38019_row0_col10, #T_38019_row0_col13, #T_38019_row0_col14, #T_38019_row0_col15, #T_38019_row1_col0, #T_38019_row1_col1, #T_38019_row1_col2, #T_38019_row1_col3, #T_38019_row1_col4, #T_38019_row1_col5, #T_38019_row1_col6, #T_38019_row1_col7, #T_38019_row1_col8, #T_38019_row1_col9, #T_38019_row1_col10, #T_38019_row1_col13, #T_38019_row1_col14, #T_38019_row1_col15, #T_38019_row2_col0, #T_38019_row2_col1, #T_38019_row2_col2, #T_38019_row2_col3, #T_38019_row2_col4, #T_38019_row2_col5, #T_38019_row2_col6, #T_38019_row2_col7, #T_38019_row2_col8, #T_38019_row2_col9, #T_38019_row2_col10, #T_38019_row2_col13, #T_38019_row2_col14, #T_38019_row2_col15, #T_38019_row3_col0, #T_38019_row3_col1, #T_38019_row3_col2, #T_38019_row3_col3, #T_38019_row3_col4, #T_38019_row3_col5, #T_38019_row3_col6, #T_38019_row3_col7, #T_38019_row3_col8, #T_38019_row3_col9, #T_38019_row3_col10, #T_38019_row3_col13, #T_38019_row3_col14, #T_38019_row3_col15, #T_38019_row4_col0, #T_38019_row4_col1, #T_38019_row4_col2, #T_38019_row4_col3, #T_38019_row4_col4, #T_38019_row4_col5, #T_38019_row4_col6, #T_38019_row4_col7, #T_38019_row4_col8, #T_38019_row4_col9, #T_38019_row4_col10, #T_38019_row4_col13, #T_38019_row4_col14, #T_38019_row4_col15, #T_38019_row5_col0, #T_38019_row5_col1, #T_38019_row5_col2, #T_38019_row5_col3, #T_38019_row5_col4, #T_38019_row5_col5, #T_38019_row5_col6, #T_38019_row5_col7, #T_38019_row5_col8, #T_38019_row5_col9, #T_38019_row5_col10, #T_38019_row5_col13, #T_38019_row5_col14, #T_38019_row5_col15, #T_38019_row6_col0, #T_38019_row6_col1, #T_38019_row6_col2, #T_38019_row6_col3, #T_38019_row6_col4, #T_38019_row6_col5, #T_38019_row6_col6, #T_38019_row6_col7, #T_38019_row6_col8, #T_38019_row6_col9, #T_38019_row6_col10, #T_38019_row6_col13, #T_38019_row6_col14, #T_38019_row6_col15, #T_38019_row7_col0, #T_38019_row7_col1, #T_38019_row7_col2, #T_38019_row7_col3, #T_38019_row7_col4, #T_38019_row7_col5, #T_38019_row7_col6, #T_38019_row7_col7, #T_38019_row7_col8, #T_38019_row7_col9, #T_38019_row7_col10, #T_38019_row7_col13, #T_38019_row7_col14, #T_38019_row7_col15, #T_38019_row8_col0, #T_38019_row8_col1, #T_38019_row8_col2, #T_38019_row8_col3, #T_38019_row8_col4, #T_38019_row8_col5, #T_38019_row8_col6, #T_38019_row8_col7, #T_38019_row8_col8, #T_38019_row8_col9, #T_38019_row8_col10, #T_38019_row8_col13, #T_38019_row8_col14, #T_38019_row8_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_38019_row0_col11, #T_38019_row1_col11, #T_38019_row2_col11, #T_38019_row3_col11, #T_38019_row4_col11, #T_38019_row5_col11, #T_38019_row6_col11, #T_38019_row7_col11, #T_38019_row8_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_38019_row0_col12, #T_38019_row1_col12, #T_38019_row2_col12, #T_38019_row3_col12, #T_38019_row4_col12, #T_38019_row5_col12, #T_38019_row6_col12, #T_38019_row7_col12, #T_38019_row8_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_38019">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_38019_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_38019_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_38019_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_38019_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_38019_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_38019_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_38019_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_38019_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_38019_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_38019_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_38019_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_38019_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_38019_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_38019_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_38019_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_38019_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38019_row0_col0" class="data row0 col0" >8e6de413-cf00-484c-83bf-fa0c0171312a</td>
#       <td id="T_38019_row0_col1" class="data row0 col1" >dall1</td>
#       <td id="T_38019_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_38019_row0_col3" class="data row0 col3" >16</td>
#       <td id="T_38019_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_38019_row0_col5" class="data row0 col5" >docker_rocky_8</td>
#       <td id="T_38019_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_38019_row0_col7" class="data row0 col7" >dall-w3.fabric-testbed.net</td>
#       <td id="T_38019_row0_col8" class="data row0 col8" >DALL</td>
#       <td id="T_38019_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_38019_row0_col10" class="data row0 col10" >2001:400:a100:3000:f816:3eff:fe7a:b4e2</td>
#       <td id="T_38019_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_38019_row0_col12" class="data row0 col12" ></td>
#       <td id="T_38019_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fe7a:b4e2</td>
#       <td id="T_38019_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_38019_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_38019_row1_col0" class="data row1 col0" >6b59863a-63a3-4f95-8fa8-fbdbddf99a58</td>
#       <td id="T_38019_row1_col1" class="data row1 col1" >dall2</td>
#       <td id="T_38019_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_38019_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_38019_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_38019_row1_col5" class="data row1 col5" >docker_rocky_8</td>
#       <td id="T_38019_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_38019_row1_col7" class="data row1 col7" >dall-w3.fabric-testbed.net</td>
#       <td id="T_38019_row1_col8" class="data row1 col8" >DALL</td>
#       <td id="T_38019_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_38019_row1_col10" class="data row1 col10" >2001:400:a100:3000:f816:3eff:fe34:e4a7</td>
#       <td id="T_38019_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_38019_row1_col12" class="data row1 col12" ></td>
#       <td id="T_38019_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fe34:e4a7</td>
#       <td id="T_38019_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_38019_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_38019_row2_col0" class="data row2 col0" >605643a4-d9e3-43ae-a65b-5d7927c15f5e</td>
#       <td id="T_38019_row2_
# <style type="text/css">
# #T_30bbb caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_30bbb th {
#   text-align: left;
# }
# #T_30bbb tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_30bbb tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_30bbb .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_30bbb_row0_col0, #T_30bbb_row0_col1, #T_30bbb_row0_col2, #T_30bbb_row0_col3, #T_30bbb_row0_col4, #T_30bbb_row0_col5, #T_30bbb_row0_col6, #T_30bbb_row1_col0, #T_30bbb_row1_col1, #T_30bbb_row1_col2, #T_30bbb_row1_col3, #T_30bbb_row1_col4, #T_30bbb_row1_col5, #T_30bbb_row1_col6, #T_30bbb_row2_col0, #T_30bbb_row2_col1, #T_30bbb_row2_col2, #T_30bbb_row2_col3, #T_30bbb_row2_col4, #T_30bbb_row2_col5, #T_30bbb_row2_col6, #T_30bbb_row3_col0, #T_30bbb_row3_col1, #T_30bbb_row3_col2, #T_30bbb_row3_col3, #T_30bbb_row3_col4, #T_30bbb_row3_col5, #T_30bbb_row3_col6, #T_30bbb_row4_col0, #T_30bbb_row4_col1, #T_30bbb_row4_col2, #T_30bbb_row4_col3, #T_30bbb_row4_col4, #T_30bbb_row4_col5, #T_30bbb_row4_col6, #T_30bbb_row5_col0, #T_30bbb_row5_col1, #T_30bbb_row5_col2, #T_30bbb_row5_col3, #T_30bbb_row5_col4, #T_30bbb_row5_col5, #T_30bbb_row5_col6, #T_30bbb_row6_col0, #T_30bbb_row6_col1, #T_30bbb_row6_col2, #T_30bbb_row6_col3, #T_30bbb_row6_col4, #T_30bbb_row6_col5, #T_30bbb_row6_col6, #T_30bbb_row7_col0, #T_30bbb_row7_col1, #T_30bbb_row7_col2, #T_30bbb_row7_col3, #T_30bbb_row7_col4, #T_30bbb_row7_col5, #T_30bbb_row7_col6, #T_30bbb_row8_col0, #T_30bbb_row8_col1, #T_30bbb_row8_col2, #T_30bbb_row8_col3, #T_30bbb_row8_col4, #T_30bbb_row8_col5, #T_30bbb_row8_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_30bbb_row0_col7, #T_30bbb_row1_col7, #T_30bbb_row2_col7, #T_30bbb_row3_col7, #T_30bbb_row4_col7, #T_30bbb_row5_col7, #T_30bbb_row6_col7, #T_30bbb_row7_col7, #T_30bbb_row8_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_30bbb_row0_col8, #T_30bbb_row1_col8, #T_30bbb_row2_col8, #T_30bbb_row3_col8, #T_30bbb_row4_col8, #T_30bbb_row5_col8, #T_30bbb_row6_col8, #T_30bbb_row7_col8, #T_30bbb_row8_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_30bbb">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_30bbb_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_30bbb_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_30bbb_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_30bbb_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_30bbb_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_30bbb_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_30bbb_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_30bbb_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_30bbb_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_30bbb_row0_col0" class="data row0 col0" >6e9a26f5-53ec-40c4-9c06-aa02ba80d0dd</td>
#       <td id="T_30bbb_row0_col1" class="data row0 col1" >DALL-UTAH-link2</td>
#       <td id="T_30bbb_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_30bbb_row0_col3" class="data row0 col3" >L2STS</td>
#       <td id="T_30bbb_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_30bbb_row0_col5" class="data row0 col5" >192.168.102.0/24</td>
#       <td id="T_30bbb_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_30bbb_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_30bbb_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_30bbb_row1_col0" class="data row1 col0" >0da75737-c1f9-4500-a6d0-2a6609b9d0ea</td>
#       <td id="T_30bbb_row1_col1" class="data row1 col1" >FABNET_IPv4_DALL</td>
#       <td id="T_30bbb_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_30bbb_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_30bbb_row1_col4" class="data row1 col4" >DALL</td>
#       <td id="T_30bbb_row1_col5" class="data row1 col5" >10.133.131.0/24</td>
#       <td id="T_30bbb_row1_col6" class="data row1 col6" >10.133.131.1</td>
#       <td id="T_30bbb_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_30bbb_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_30bbb_row2_col0" class="data row2 col0" >03cb8db5-ce7b-4ac3-be90-97c407803f05</td>
#       <td id="T_30bbb_row2_col1" class="data row2 col1" >FABNET_IPv4_STAR</td>
#       <td id="T_30bbb_row2_col2" class="data row2 col2" >L3</td>
#       <td id="T_30bbb_row2_col3" class="data row2 col3" >FABNetv4</td>
#       <td id="T_30bbb_row2_col4" class="data row2 col4" >STAR</td>
#       <td id="T_30bbb_row2_col5" class="data row2 col5" >10.129.139.0/24</td>
#       <td id="T_30bbb_row2_col6" class="data row2 col6" >10.129.139.1</td>
#       <td id="T_30bbb_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_30bbb_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_30bbb_row3_col0" class="data row3 col0" >df9d1b46-673b-4466-8af1-7f3c72d5f2a0</td>
#       <td id="T_30bbb_row3_col1" class="data row3 col1" >FABNET_IPv4_UTAH</td>
#       <td id="T_30bbb_row3_col2" class="data row3 col2" >L3</td>
#       <td id="T_30bbb_row3_col3" class="data row3 col3" >FABNetv4</td>
#       <td id="T_30bbb_row3_col4" class="data row3 col4" >UTAH</td>
#       <td id="T_30bbb_row3_col5" class="data row3 col5" >10.132.18.0/24</td>
#       <td id="T_30bbb_row3_col6" class="data row3 col6" >10.132.18.1</td>
#       <td id="T_30bbb_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_30bbb_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_30bbb_row4_col0" class="data row4 col0" >739273fb-b5fb-40bd-8288-8518064233cb</td>
#       <td id="T_30bbb_row4_col1" class="data row4 col1" >STAR-DALL-link1</td>
#       <td id="T_30bbb_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_30bbb_row4_col3" class="data row4 col3" >L2STS</td>
#       <td id="T_30bbb_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_30bbb_row4_col5" class="data row4 col5" >192.168.101.0/24</td>
#       <td id="T_30bbb_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_30bbb_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_30bbb_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_30bbb_row5_col0" class="data row5 col0" >0428c760-aac1-450f-9f23-0a8fcf30a61e</td>
#       <td id="T_30bbb_row5_col1" class="data row5 col1" >UTAH-STAR-link3</td>
#       <td id="T_30bbb_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_30bbb_row5_col3" class="data row5 col3" >L2STS</td>
#       <td id="T_30bbb_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_30bbb_row5_col5" class="data row5 col5" >192.168.103.0/24</td>
#       <td id="T_30bbb_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_30bbb_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_30bbb_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_30bbb_row6_col0" class="data row6 col0" >b5ccfa79-0425-4be5-a420-997579283492</td>
#       <td id="T_30bbb_row6_col1" class="data row6 col1" >net_localDALL</td>
#       <td id="T_30bbb_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_30bbb_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_30bbb_row6_col4" class="data row6 col4" >DALL</td>
#       <td id="T_30bbb_row6_col5" class="data row6 col5" >192.168.2.0/24</td>
#       <td id="T_30bbb_row6_col6" class="data row6 col6" >192.168.2.1</td>
#       <td id="T_30bbb_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_30bbb_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_30bbb_row7_col0" class="data row7 col0" >1e4dd10c-614e-4b74-a5f3-2b063056af95</td>
#       <td i
# <style type="text/css">
# #T_e4511 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e4511 th {
#   text-align: left;
# }
# #T_e4511 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e4511 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e4511 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e4511_row0_col0, #T_e4511_row0_col1, #T_e4511_row0_col2, #T_e4511_row0_col3, #T_e4511_row0_col4, #T_e4511_row0_col5, #T_e4511_row0_col6, #T_e4511_row0_col7, #T_e4511_row0_col8, #T_e4511_row0_col9, #T_e4511_row0_col10, #T_e4511_row1_col0, #T_e4511_row1_col1, #T_e4511_row1_col2, #T_e4511_row1_col3, #T_e4511_row1_col4, #T_e4511_row1_col5, #T_e4511_row1_col6, #T_e4511_row1_col7, #T_e4511_row1_col8, #T_e4511_row1_col9, #T_e4511_row1_col10, #T_e4511_row2_col0, #T_e4511_row2_col1, #T_e4511_row2_col2, #T_e4511_row2_col3, #T_e4511_row2_col4, #T_e4511_row2_col5, #T_e4511_row2_col6, #T_e4511_row2_col7, #T_e4511_row2_col8, #T_e4511_row2_col9, #T_e4511_row2_col10, #T_e4511_row3_col0, #T_e4511_row3_col1, #T_e4511_row3_col2, #T_e4511_row3_col3, #T_e4511_row3_col4, #T_e4511_row3_col5, #T_e4511_row3_col6, #T_e4511_row3_col7, #T_e4511_row3_col8, #T_e4511_row3_col9, #T_e4511_row3_col10, #T_e4511_row4_col0, #T_e4511_row4_col1, #T_e4511_row4_col2, #T_e4511_row4_col3, #T_e4511_row4_col4, #T_e4511_row4_col5, #T_e4511_row4_col6, #T_e4511_row4_col7, #T_e4511_row4_col8, #T_e4511_row4_col9, #T_e4511_row4_col10, #T_e4511_row5_col0, #T_e4511_row5_col1, #T_e4511_row5_col2, #T_e4511_row5_col3, #T_e4511_row5_col4, #T_e4511_row5_col5, #T_e4511_row5_col6, #T_e4511_row5_col7, #T_e4511_row5_col8, #T_e4511_row5_col9, #T_e4511_row5_col10, #T_e4511_row6_col0, #T_e4511_row6_col1, #T_e4511_row6_col2, #T_e4511_row6_col3, #T_e4511_row6_col4, #T_e4511_row6_col5, #T_e4511_row6_col6, #T_e4511_row6_col7, #T_e4511_row6_col8, #T_e4511_row6_col9, #T_e4511_row6_col10, #T_e4511_row7_col0, #T_e4511_row7_col1, #T_e4511_row7_col2, #T_e4511_row7_col3, #T_e4511_row7_col4, #T_e4511_row7_col5, #T_e4511_row7_col6, #T_e4511_row7_col7, #T_e4511_row7_col8, #T_e4511_row7_col9, #T_e4511_row7_col10, #T_e4511_row8_col0, #T_e4511_row8_col1, #T_e4511_row8_col2, #T_e4511_row8_col3, #T_e4511_row8_col4, #T_e4511_row8_col5, #T_e4511_row8_col6, #T_e4511_row8_col7, #T_e4511_row8_col8, #T_e4511_row8_col9, #T_e4511_row8_col10, #T_e4511_row9_col0, #T_e4511_row9_col1, #T_e4511_row9_col2, #T_e4511_row9_col3, #T_e4511_row9_col4, #T_e4511_row9_col5, #T_e4511_row9_col6, #T_e4511_row9_col7, #T_e4511_row9_col8, #T_e4511_row9_col9, #T_e4511_row9_col10, #T_e4511_row10_col0, #T_e4511_row10_col1, #T_e4511_row10_col2, #T_e4511_row10_col3, #T_e4511_row10_col4, #T_e4511_row10_col5, #T_e4511_row10_col6, #T_e4511_row10_col7, #T_e4511_row10_col8, #T_e4511_row10_col9, #T_e4511_row10_col10, #T_e4511_row11_col0, #T_e4511_row11_col1, #T_e4511_row11_col2, #T_e4511_row11_col3, #T_e4511_row11_col4, #T_e4511_row11_col5, #T_e4511_row11_col6, #T_e4511_row11_col7, #T_e4511_row11_col8, #T_e4511_row11_col9, #T_e4511_row11_col10, #T_e4511_row12_col0, #T_e4511_row12_col1, #T_e4511_row12_col2, #T_e4511_row12_col3, #T_e4511_row12_col4, #T_e4511_row12_col5, #T_e4511_row12_col6, #T_e4511_row12_col7, #T_e4511_row12_col8, #T_e4511_row12_col9, #T_e4511_row12_col10, #T_e4511_row13_col0, #T_e4511_row13_col1, #T_e4511_row13_col2, #T_e4511_row13_col3, #T_e4511_row13_col4, #T_e4511_row13_col5, #T_e4511_row13_col6, #T_e4511_row13_col7, #T_e4511_row13_col8, #T_e4511_row13_col9, #T_e4511_row13_col10, #T_e4511_row14_col0, #T_e4511_row14_col1, #T_e4511_row14_col2, #T_e4511_row14_col3, #T_e4511_row14_col4, #T_e4511_row14_col5, #T_e4511_row14_col6, #T_e4511_row14_col7, #T_e4511_row14_col8, #T_e4511_row14_col9, #T_e4511_row14_col10, #T_e4511_row15_col0, #T_e4511_row15_col1, #T_e4511_row15_col2, #T_e4511_row15_col3, #T_e4511_row15_col4, #T_e4511_row15_col5, #T_e4511_row15_col6, #T_e4511_row15_col7, #T_e4511_row15_col8, #T_e4511_row15_col9, #T_e4511_row15_col10, #T_e4511_row16_col0, #T_e4511_row16_col1, #T_e4511_row16_col2, #T_e4511_row16_col3, #T_e4511_row16_col4, #T_e4511_row16_col5, #T_e4511_row16_col6, #T_e4511_row16_col7, #T_e4511_row16_col8, #T_e4511_row16_col9, #T_e4511_row16_col10, #T_e4511_row17_col0, #T_e4511_row17_col1, #T_e4511_row17_col2, #T_e4511_row17_col3, #T_e4511_row17_col4, #T_e4511_row17_col5, #T_e4511_row17_col6, #T_e4511_row17_col7 ...
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_e4511">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_e4511_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_e4511_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_e4511_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_e4511_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_e4511_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_e4511_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_e4511_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_e4511_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_e4511_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_e4511_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_e4511_level0_col10" class="col_heading level0 col10" >IP Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e4511_row0_col0" class="data row0 col0" >routerSTAR-STAR-DALL-p1</td>
#       <td id="T_e4511_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_e4511_row0_col2" class="data row0 col2" >routerSTAR</td>
#       <td id="T_e4511_row0_col3" class="data row0 col3" >STAR-DALL-link1</td>
#       <td id="T_e4511_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_e4511_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_e4511_row0_col6" class="data row0 col6" ></td>
#       <td id="T_e4511_row0_col7" class="data row0 col7" >22:66:05:94:42:14</td>
#       <td id="T_e4511_row0_col8" class="data row0 col8" >None</td>
#       <td id="T_e4511_row0_col9" class="data row0 col9" >None</td>
#       <td id="T_e4511_row0_col10" class="data row0 col10" >192.168.101.1</td>
#     </tr>
#     <tr>
#       <td id="T_e4511_row1_col0" class="data row1 col0" >routerSTAR-STAR-UTAH-p1</td>
#       <td id="T_e4511_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_e4511_row1_col2" class="data row1 col2" >routerSTAR</td>
#       <td id="T_e4511_r
# Time to print interfaces 714 seconds
# '14e0d411-4043-48ac-895b-f4ac6573cebc'

# %% [markdown]
# ## Run the Experiment
#
# We will just test `ping` RTT and look at `tracepath`. Your experiment should be more interesting!
#
# Notice that if you run this quickly and repeatedly run this test against a specific target, you may see changes to the tracepath.  Initially the ping may even fail.  Why do you think this is happening?

# %%
slice = fablib.get_slice(slice_name)

    
source_node = slice.get_node(name=f'{sites[0].lower()}1')

target_node = slice.get_node(name=f'{sites[1].lower()}1')
target_ip=target_node.get_interface(network_name=f'net_local{sites[1]}').get_ip_addr()

print(f"Testing target node: {target_node.get_name()}, target IP: {target_ip}")

stdout1, stderr1 = target_node.execute("docker run -d --rm "
                                "--network host "
                                "pruth/fabric-multitool-rockylinux8:latest "
                                "iperf3 -s -1"
                                , quiet=True, output_file=f"{target_node.get_name()}.log");

stdout2, stderr2 = source_node.execute("docker run --rm "
                                "--network host "
                                "pruth/fabric-multitool-rockylinux8:latest "
                                f"iperf3 -c {target_ip} -P 8 -t 60 -i 60 -O 10"
                                , quiet=False, output_file=f"{node.get_name()}.log");
# Out:
# Testing target node: dall1, target IP: 192.168.2.3
# Connecting to host 192.168.2.3, port 5201
# [  5] local 192.168.1.3 port 35758 connected to 192.168.2.3 port 5201
# [  7] local 192.168.1.3 port 35768 connected to 192.168.2.3 port 5201
# [  9] local 192.168.1.3 port 35772 connected to 192.168.2.3 port 5201
# [ 11] local 192.168.1.3 port 35784 connected to 192.168.2.3 port 5201
# [ 13] local 192.168.1.3 port 35794 connected to 192.168.2.3 port 5201
# [ 15] local 192.168.1.3 port 35804 connected to 192.168.2.3 port 5201
# [ 17] local 192.168.1.3 port 35816 connected to 192.168.2.3 port 5201
# [ 19] local 192.168.1.3 port 35830 connected to 192.168.2.3 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-60.05  sec  8.60 GBytes  1.23 Gbits/sec   80   4.12 MBytes
# [  7]   0.00-60.05  sec  8.66 GBytes  1.24 Gbits/sec    4   4.22 MBytes
# [  9]   0.00-60.05  sec  7.84 GBytes  1.12 Gbits/sec   45   3.10 MBytes
# [ 11]   0.00-60.05  sec  8.25 GBytes  1.18 Gbits/sec   45   3.01 MBytes
# [ 13]   0.00-60.05  sec  5.63 GBytes   805 Mbits/sec  1389   1.91 MBytes
# [ 15]   0.00-60.05  sec  8.63 GBytes  1.23 Gbits/sec    0   4.21 MBytes
# [ 17]   0.00-60.05  sec  8.62 GBytes  1.23 Gbits/sec   45   4.24 MBytes
# [ 19]   0.00-60.05  sec  3.15 GBytes   451 Mbits/sec  596   2.21 MBytes
# [SUM]   0.00-60.05  sec  59.4 GBytes  8.49 Gbits/sec  2204
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-60.05  sec  8.60 GBytes  1.23 Gbits/sec   80             sender
# [  5]   0.00-60.08  sec  8.61 GBytes  1.23 Gbits/sec                  receiver
# [  7]   0.00-60.05  sec  8.66 GBytes  1.24 Gbits/sec    4             sender
# [  7]   0.00-60.08  sec  8.67 GBytes  1.24 Gbits/sec                  receiver
# [  9]   0.00-60.05  sec  7.84 GBytes  1.12 Gbits/sec   45             sender
# [  9]   0.00-60.08  sec  7.84 GBytes  1.12 Gbits/sec                  receiver
# [ 11]   0.00-60.05  sec  8.25 GBytes  1.18 Gbits/sec   45             sender
# [ 11]   0.00-60.08  sec  8.26 GBytes  1.18 Gbits/sec                  receiver
# [ 13]   0.00-60.05  sec  5.63 GBytes   805 Mbits/sec  1389             sender
# [ 13]   0.00-60.08  sec  5.63 GBytes   805 Mbits/sec                  receiver
# [ 15]   0.00-60.05  sec  8.63 GBytes  1.23 Gbits/sec    0             sender
# [ 15]   0.00-60.08  sec  8.63 GBytes  1.23 Gbits/sec                  receiver
# [ 17]   0.00-60.05  sec  8.62 GBytes  1.23 Gbits/sec   45             sender
# [ 17]   0.00-60.08  sec  8.62 GBytes  1.23 Gbits/sec                  receiver
# [ 19]   0.00-60.05  sec  3.15 GBytes   451 Mbits/sec  596             sender
# [ 19]   0.00-60.08  sec  3.15 GBytes   451 Mbits/sec                  receiver
# [SUM]   0.00-60.05  sec  59.4 GBytes  8.49 Gbits/sec  2204             sender
# [SUM]   0.00-60.08  sec  59.4 GBytes  8.49 Gbits/sec                  receiver
#
# iperf Done.

# %%
try:
    slice = fablib.get_slice(slice_name)

    
    source_node = slice.get_node(name=f'{sites[0].lower()}1')
    
    target_node = slice.get_node(name=f'{sites[1].lower()}1')
    target_ip=target_node.get_interface(network_name=f'net_local{sites[0]}').get_ip_addr()
    
    print(f"Testing target node: {target_node.get_name()}, target IP: {target_ip}")

    stdout, stderr = source_node.execute(f'ping -c 5 {target_ip}')

    stdout, stderr = source_node.execute(f'tracepath {target_ip}')
    
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
