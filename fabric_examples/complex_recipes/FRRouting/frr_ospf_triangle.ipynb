# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # OSPF Routing with FRRouting Software Routers
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to deploy a **triangle topology** of FRRouting software routers on FABRIC, using the **OSPF** (Open Shortest Path First) routing protocol. You will create three routers at different FABRIC sites, connect them with dedicated Layer 2 links, configure OSPF to automatically propagate routes, and test end-to-end connectivity between hosts at each site.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Design a **multi-site triangle routing topology** with local LANs and inter-router links
# 2. Deploy **FRRouting** as a Docker container with host networking for software-based routing
# 3. Use **templated post-boot tasks** to automate router and network configuration
# 4. Configure **OSPF** to automatically distribute routes across a multi-router topology
# 5. Verify routing with `ping` and `tracepath` to observe OSPF path selection
# 6. Measure bandwidth through software routers using **iPerf3**
# 7. Apply **NUMA tuning** (CPU pinning and memory affinity) to improve network performance
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be familiar with creating FABRIC slices (see [Hello FABRIC](../../fablib_api/hello_fabric/hello_fabric.ipynb))
# 3. Understand basic IP networking concepts (subnets, gateways, routing)
# 4. Have the `node_tools/` and `docker_containers/` directories (included alongside this notebook)
#
# **Tip:** This is an advanced example that combines several FABRIC features: post-boot task templates, Docker containers, L2 networks, IP address configuration, NUMA tuning, and iPerf3 testing. If you are new to these features, review the linked examples in the Additional Features section below.
#
# </div>

# %% [markdown]
# ## Background: FRRouting and OSPF
#
# ### FRRouting
#
# [FRRouting (FRR)](https://frrouting.org/) is an open-source software router suite for Linux. It provides implementations of all major routing protocols including BGP, OSPF, IS-IS, RIP, and more. FRR is the successor to [Quagga](https://www.quagga.net/) and has an active upstream community backed by many companies working on cloud networking.
#
# ### OSPF (Open Shortest Path First)
#
# [OSPF](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) is a link-state routing protocol widely used in enterprise and ISP networks. Each router:
# 1. Discovers its neighbors via Hello packets
# 2. Builds a complete map of the network topology (Link-State Database)
# 3. Runs Dijkstra's algorithm to compute the shortest path to every destination
# 4. Installs the resulting routes in the forwarding table
#
# ### Target Topology
#
# This notebook creates a triangle of routers, each at a different FABRIC site. Each router connects to:
# - A **local LAN** (L2Bridge) serving end hosts at that site
# - **Two inter-router links** forming the triangle
#
# <img src="./figs/frr.png" width="70%"><br>
#
# ### Subnet Addressing Plan
#
# | Network | Subnet | Purpose |
# |---------|--------|---------|
# | net1 (Site 1 LAN) | 192.168.1.0/24 | Router1 gateway: 192.168.1.1 |
# | net2 (Site 2 LAN) | 192.168.2.0/24 | Router2 gateway: 192.168.2.1 |
# | net3 (Site 3 LAN) | 192.168.3.0/24 | Router3 gateway: 192.168.3.1 |
# | Router1-Router2 link | 192.168.101.0/24 | Point-to-point |
# | Router2-Router3 link | 192.168.102.0/24 | Point-to-point |
# | Router3-Router1 link | 192.168.103.0/24 | Point-to-point |
#
# ### Additional Features Used
#
# This notebook demonstrates several advanced FABRIC features:
#
# - **Templated post-boot tasks**: Variables like `{{ interfaces['name'].dev }}` are resolved at boot time ([example](../../../fabric_examples/fablib_api/post_boot_task_templates/post_boot_task_templates.ipynb))
# - **Docker containers with host networking**: FRR runs as a container with direct access to the host's network stack ([example](../../../fabric_examples/fablib_api/docker_containers/docker_containers.ipynb))
# - **iPerf3 performance testing**: Measure bandwidth through the routed topology ([example](../../../fabric_examples/complex_recipes/iPerf3/iperf3.ipynb))
# - **NUMA tuning**: Pin CPU and memory to the same NUMA domain as the NIC for better performance ([example](../../../fabric_examples/complex_recipes/iPerf3/iperf3_optimized_smart_nic.ipynb))

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a triangle of three FRRouting routers with OSPF, each with a local host node.
#
# <img src="./figs/slice_topology.png" width="55%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration
#
# In addition to FABlib, we import Python's `ipaddress` module for subnet and IP address calculations.

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance
fablib = fablib_manager()
                     
fablib.show_config();

# %% [markdown]
# ## Step 2: Define the Topology
#
# ### 2a: General Configuration
#
# Select three random FABRIC sites and set the number of end-host nodes per site.
#
# <img src="./figs/frr_detailed.png" width="90%"><br>

# %%
# Slice name for easy identification
slice_name = 'OSPF_Routing_Topology'

# Select 3 random FABRIC sites for the triangle topology
sites = [site1, site2, site3] = fablib.get_random_sites(count=3, avoid=[])
print(f"Sites: {sites}")

# Number of additional end-host nodes at each site (beyond the router)
site_node_count=1

# %% [markdown]
# ### 2b: Create the Slice

# %%
# Create a new empty slice
slice = fablib.new_slice(name=slice_name)

# %% [markdown]
# ## Step 3: Add the Routers
#
# Each router gets:
# - A **local NIC** connected to its site's LAN (L2Bridge)
# - The `docker_rocky_8` image (pre-installed with Docker for running FRR)
# - Manual IP configuration (`set_mode('config')`) for the local interface
#
# <img src="./figs/router.png" width="40%"><br>
#
# ### Router 1 (Site 1)
#
# Local LAN subnet: `192.168.1.0/24`, gateway: `192.168.1.1`

# %%
# --- Router 1: Site 1 LAN (192.168.1.0/24) ---
subnet1 = IPv4Network("192.168.1.0/24")
gateway1 = subnet1[1]  # 192.168.1.1

# Create the local L2 network with subnet and gateway info
net1 = slice.add_l2network(name='net1', subnet=subnet1, gateway=gateway1)

# Add router1 VM with Docker support
router1 = slice.add_node(name='router1', site=site1, cores=4, ram=8, disk=100, image='docker_rocky_8', host=f'{site1.lower()}-w1.fabric-testbed.net')

# Add a NIC for the local LAN and set its IP manually
router1_local_iface = router1.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]
router1_local_iface.set_mode('config')       # Manual IP configuration
net1.add_interface(router1_local_iface)       # Connect to the local LAN
router1_local_iface.set_ip_addr(gateway1);    # Assign 192.168.1.1

# %% [markdown]
# ### Router 2 (Site 2)
#
# Local LAN subnet: `192.168.2.0/24`, gateway: `192.168.2.1`

# %%
# --- Router 2: Site 2 LAN (192.168.2.0/24) ---
subnet2 = IPv4Network("192.168.2.0/24")
gateway2 = subnet2[1]  # 192.168.2.1

net2 = slice.add_l2network(name='net2', subnet=subnet2, gateway=gateway2)

router2 = slice.add_node(name='router2', site=site2, cores=4, ram=8, disk=100, image='docker_rocky_8', host=f'{site2.lower()}-w1.fabric-testbed.net')
router2_local_iface = router2.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]
router2_local_iface.set_mode('config')
net2.add_interface(router2_local_iface)
router2_local_iface.set_ip_addr(gateway2);

# %% [markdown]
# ### Router 3 (Site 3)
#
# Local LAN subnet: `192.168.3.0/24`, gateway: `192.168.3.1`

# %%
# --- Router 3: Site 3 LAN (192.168.3.0/24) ---
subnet3 = IPv4Network("192.168.3.0/24")
gateway3 = subnet3[1]  # 192.168.3.1

net3 = slice.add_l2network(name='net3', subnet=subnet3, gateway=gateway3)

router3 = slice.add_node(name='router3', site=site3, cores=4, ram=8, disk=100, image='docker_rocky_8', host=f'{site3.lower()}-w1.fabric-testbed.net')
router3_local_iface = router3.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]
router3_local_iface.set_mode('config')
net3.add_interface(router3_local_iface)
router3_local_iface.set_ip_addr(gateway3);

# %% [markdown]
# ## Step 4: Add Post-Boot Configuration Tasks for Routers
#
# Each router receives post-boot tasks that:
# 1. **Upload scripts**: `node_tools/` (host tuning, Docker enablement) and `docker_containers/` (FRR configuration)
# 2. **Enable Docker**: Activate the pre-installed Docker service
# 3. **Configure FRR**: Run the FRR config script with the local interface device name and gateway IP
#
# <div class="fab-warning">
#
# **Tip:** The `{{ interfaces['name'].dev }}` syntax is a **post-boot template variable**. At boot time, FABlib resolves this to the actual Linux device name (e.g., `ens7`) that was assigned to the interface. This is necessary because device names are not known until the VM is provisioned. See the [post-boot task templates example](../../../fabric_examples/fablib_api/post_boot_task_templates/post_boot_task_templates.ipynb) for details.
#
# </div>
#
# ### Router 1 Post-Boot Tasks

# %%
# Upload helper scripts and Docker container files to Router 1
router1.add_post_boot_upload_directory('node_tools','.')   
router1.add_post_boot_upload_directory('docker_containers','.')

# Enable Docker (template variable resolves the image name at boot time)
router1.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }}')

# Build the device name template for the local interface
# This resolves to the actual Linux device name (e.g., ens7) at boot time
dev_template = f"{{{{ interfaces['{router1_local_iface.get_name()}'].dev }}}}"

print(f'{router1.get_name()}: dev_template: {dev_template}, local_gateway: {gateway1}')

# Configure FRR with the local interface and the OSPF network range
router1.add_post_boot_execute(f"./docker_containers/fabric_frrouting/config.sh {dev_template} {gateway1} '192.168.0.0'")

# %% [markdown]
# ### Router 2 Post-Boot Tasks

# %%
# Upload scripts and enable Docker on Router 2
router2.add_post_boot_upload_directory('node_tools','.')    
router2.add_post_boot_upload_directory('docker_containers','.')
router2.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }}')

# Build device name template and configure FRR
dev_template = f"{{{{ interfaces['{router2_local_iface.get_name()}'].dev }}}}"

print(f'{router2.get_name()}: dev_template: {dev_template}, local_gateway: {gateway2}')

router2.add_post_boot_execute(f"./docker_containers/fabric_frrouting/config.sh {dev_template} {gateway2} '192.168.0.0'")

# %% [markdown]
# ### Router 3 Post-Boot Tasks

# %%
# Upload scripts and enable Docker on Router 3
router3.add_post_boot_upload_directory('node_tools','.')  
router3.add_post_boot_upload_directory('docker_containers','.')
router3.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }}')

# Build device name template and configure FRR
dev_template = f"{{{{ interfaces['{router3_local_iface.get_name()}'].dev }}}}"

print(f'{router3.get_name()}: dev_template: {dev_template}, local_gateway: {gateway3}')

router3.add_post_boot_execute(f"./docker_containers/fabric_frrouting/config.sh {dev_template} {gateway3} '192.168.0.0'")

# %% [markdown]
# ## Step 5: Add Inter-Router Links
#
# Create point-to-point L2 links between each pair of routers, forming the triangle. Each link gets its own `/24` subnet. After adding a link, a post-boot task registers the new OSPF neighbor on each router.
#
# <img src="./figs/add_links.png" width="70%"><br>
#
# ### Link: Router1 -- Router2 (192.168.101.0/24)

# %%
# --- Link: Router1 <-> Router2 ---
link_info = {}
link_subnet = IPv4Network("192.168.101.0/24")
ip_addr1=link_subnet[1]  # 192.168.101.1 (Router1 end)
ip_addr2=link_subnet[2]  # 192.168.101.2 (Router2 end)

# Create the point-to-point L2 network
link = slice.add_l2network(name='router1_router2', subnet=link_subnet)

# Router1 side: add NIC, set IP, register OSPF neighbor
iface1 = router1.add_component(model='NIC_Basic', name=f'router1-router2').get_interfaces()[0]
iface1.set_mode('config')
link.add_interface(iface1)
iface1.set_ip_addr(ip_addr1)
iface1_dev = f"{{{{ interfaces['{iface1.get_name()}'].dev }}}}"
router1.add_post_boot_execute(f'./docker_containers/fabric_frrouting/node_tools/add_ospf_neighbor.sh {iface1_dev} {ip_addr1} ')

# Router2 side: add NIC, set IP, register OSPF neighbor
iface2 = router2.add_component(model='NIC_Basic', name=f'router2-router1').get_interfaces()[0]
iface2.set_mode('config')
link.add_interface(iface2)
iface2.set_ip_addr(ip_addr2)    
iface2_dev = f"{{{{ interfaces['{iface2.get_name()}'].dev }}}}"
router2.add_post_boot_execute(f'./docker_containers/fabric_frrouting/node_tools/add_ospf_neighbor.sh {iface2_dev} {ip_addr2} ')

# %% [markdown]
# ### Link: Router2 -- Router3 (192.168.102.0/24)

# %%
# --- Link: Router2 <-> Router3 ---
link_info = {}
link_subnet = IPv4Network("192.168.102.0/24")
ip_addr1=link_subnet[1]  # 192.168.102.1 (Router2 end)
ip_addr2=link_subnet[2]  # 192.168.102.2 (Router3 end)

link = slice.add_l2network(name='router2_router3', subnet=link_subnet)

# Router2 side
iface1 = router2.add_component(model='NIC_Basic', name=f'router2-router3').get_interfaces()[0]
iface1.set_mode('config')
link.add_interface(iface1)
iface1.set_ip_addr(ip_addr1)
iface1_dev = f"{{{{ interfaces['{iface1.get_name()}'].dev }}}}"
router2.add_post_boot_execute(f'./docker_containers/fabric_frrouting/node_tools/add_ospf_neighbor.sh {iface1_dev} {ip_addr1} ')

# Router3 side
iface2 = router3.add_component(model='NIC_Basic', name=f'router3-router2').get_interfaces()[0]
iface2.set_mode('config')
link.add_interface(iface2)
iface2.set_ip_addr(ip_addr2)    
iface2_dev = f"{{{{ interfaces['{iface2.get_name()}'].dev }}}}"
router3.add_post_boot_execute(f'./docker_containers/fabric_frrouting/node_tools/add_ospf_neighbor.sh {iface2_dev} {ip_addr2} ')

# %% [markdown]
# ### Link: Router3 -- Router1 (192.168.103.0/24)

# %%
# --- Link: Router3 <-> Router1 ---
link_info = {}
link_subnet = IPv4Network("192.168.103.0/24")
ip_addr1=link_subnet[1]  # 192.168.103.1 (Router3 end)
ip_addr2=link_subnet[2]  # 192.168.103.2 (Router1 end)

link = slice.add_l2network(name='router3_router1', subnet=link_subnet)

# Router3 side
iface1 = router3.add_component(model='NIC_Basic', name=f'router3-router1').get_interfaces()[0]
iface1.set_mode('config')
link.add_interface(iface1)
iface1.set_ip_addr(ip_addr1)
iface1_dev = f"{{{{ interfaces['{iface1.get_name()}'].dev }}}}"
router3.add_post_boot_execute(f'./docker_containers/fabric_frrouting/node_tools/add_ospf_neighbor.sh {iface1_dev} {ip_addr1} ')

# Router1 side
iface2 = router1.add_component(model='NIC_Basic', name=f'router1-router3').get_interfaces()[0]
iface2.set_mode('config')
link.add_interface(iface2)
iface2.set_ip_addr(ip_addr2)    
iface2_dev = f"{{{{ interfaces['{iface2.get_name()}'].dev }}}}"
router1.add_post_boot_execute(f'./docker_containers/fabric_frrouting/node_tools/add_ospf_neighbor.sh {iface2_dev} {ip_addr2} ')

# %% [markdown]
# ## Step 6: Start FRRouting on Each Router
#
# Add a final post-boot task that starts the FRRouting Docker container with access to **all** of the router's data plane interfaces (local LAN + inter-router links). The template variables ensure the correct device names are passed to the start script.

# %%
# Build a space-separated list of all interface device templates for each router
# and add a post-boot task to start FRR with those interfaces

# Router 1: start FRR with all its interfaces
all_devs_template = ''
for iface in router1.get_interfaces():
    all_devs_template +=  f" {{{{ interfaces['{iface.get_name()}'].dev }}}} "
router1.add_post_boot_execute(f'./docker_containers/fabric_frrouting/start.sh {all_devs_template} ')

# Router 2: start FRR with all its interfaces
all_devs_template = ''
for iface in router2.get_interfaces():
    all_devs_template +=  f" {{{{ interfaces['{iface.get_name()}'].dev }}}} "
router2.add_post_boot_execute(f'./docker_containers/fabric_frrouting/start.sh {all_devs_template} ')

# Router 3: start FRR with all its interfaces
all_devs_template = ''
for iface in router3.get_interfaces():
    all_devs_template +=  f" {{{{ interfaces['{iface.get_name()}'].dev }}}} "
router3.add_post_boot_execute(f'./docker_containers/fabric_frrouting/start.sh {all_devs_template} ')

# %% [markdown]
# ## Step 7: Add End-Host Nodes
#
# Add one end-host node per site, connected to the local LAN. Each host is configured to route `192.168.0.0/16` traffic through the local FRRouter gateway, enabling inter-site communication through the OSPF-routed network.

# %%
# Add end-host nodes to each site's local LAN
for i, site in enumerate([site1, site2, site3]):
    print(f"Adding nodes to {site}")
    for node_num in range(site_node_count):
        node_name = f"{site.lower()}{node_num+1}"
        
        # Create the end-host on a different physical host (-w2) than the router (-w1)
        node = slice.add_node(name=node_name, site=site, cores=4, ram=8, disk=100, image='docker_rocky_8', host=f'{site.lower()}-w2.fabric-testbed.net')
        
        # Connect to the site's local LAN with auto-assigned IP
        iface = node.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]
        network = slice.get_network(name=f'net{i+1}')
        network.add_interface(iface)
        iface.set_mode('auto')  # Let FABlib assign an IP from the subnet
        
        # Route all 192.168.x.x traffic through the local FRRouter gateway
        node.add_route(subnet=IPv4Network('192.168.0.0/16'), next_hop=network.get_gateway())
    
        # Post-boot setup: enable Docker and pull the multitool container
        node.add_post_boot_upload_directory('node_tools','.')
        node.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }}')
        node.add_post_boot_upload_directory('docker_containers','.')
        node.add_post_boot_execute('docker pull fabrictestbed/slice-vm-rocky8-multitool:0.0.2 ')

# %% [markdown]
# ## Step 8: Submit the Slice
#
# <img src="./figs/frr_detailed.png" width="90%"><br>
#
# Submit the complete topology for provisioning. This may take 10-15 minutes due to the number of nodes and post-boot tasks.
#
# <div class="fab-danger">
#
# **Important:** The post-boot tasks run in order on each node. OSPF convergence begins after FRR starts on all three routers. It may take an additional 30-60 seconds after the slice is ready for OSPF to fully converge and all routes to be available.
#
# </div>

# %%
# Submit the slice request and wait for provisioning
slice.submit();

# %% [markdown]
# ## Step 9: Test Connectivity
#
# Test the OSPF-routed network by pinging from an end host at Site 1 to an end host at Site 2, and examining the path with `tracepath`.
#
# <div class="fab-warning">
#
# **Tip:** If you run this test immediately after the slice becomes ready, the first few pings may fail while OSPF is still converging. Wait 30-60 seconds and retry. You may also observe `tracepath` showing different routes as OSPF recalculates paths.
#
# </div>

# %%
try:
    slice = fablib.get_slice(slice_name)

    # Source: end host at Site 1
    source_node = slice.get_node(name=f'{sites[0].lower()}1')
    
    # Target: end host at Site 2
    target_node = slice.get_node(name=f'{sites[1].lower()}1')
    target_ip=target_node.get_interface(network_name=f'net2').get_ip_addr()
    
    print(f"Testing target node: {target_node.get_name()}, target IP: {target_ip}")

    # Ping test: verify basic connectivity through the OSPF-routed network
    stdout, stderr = source_node.execute(f'ping -c 5 {target_ip}')

    # Tracepath: observe the routing path (should go through the FRRouters)
    stdout, stderr = source_node.execute(f'tracepath {target_ip}')
    
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 10: Bandwidth Test with iPerf3
#
# Measure the bandwidth achievable through the software routers using iPerf3 in Docker containers. This gives you a baseline for understanding the overhead of software-based routing.
#
# **Think about:** What bandwidth do you expect through software routers compared to direct L2/L3 links? What factors affect performance?

# %%
slice = fablib.get_slice(slice_name)

# Source and target: end hosts at Site 1 and Site 2
source_node = slice.get_node(name=f'{sites[0].lower()}1')
target_node = slice.get_node(name=f'{sites[1].lower()}1')
target_ip=target_node.get_interface(network_name=f'net2').get_ip_addr()

print(f"Testing target node: {target_node.get_name()}, target IP: {target_ip}")

# Start iPerf3 server on the target node (detached, one-shot)
stdout1, stderr1 = target_node.execute("docker run -d --rm "
                                "--network host "
                                "fabrictestbed/slice-vm-rocky8-multitool:0.0.2  "
                                "iperf3 -s -1"
                                , quiet=True, output_file=f"{target_node.get_name()}.log");

# Run iPerf3 client from source node with 4 parallel streams, 30s duration
stdout2, stderr2 = source_node.execute("docker run --rm "
                                "--network host "
                                "fabrictestbed/slice-vm-rocky8-multitool:0.0.2  "
                                f"iperf3 -c {target_ip} -P 4 -t 30 -i 10 -O 10"
                                , quiet=False, output_file=f"{node.get_name()}.log");

# %% [markdown]
# ## Step 11 (Optional): NUMA Tuning for Better Performance
#
# Pin each VM's CPU cores and memory to the same NUMA domain as its network card. This reduces memory access latency for network I/O and can significantly improve throughput.
#
# <div class="fab-warning">
#
# **Tip:** NUMA tuning requires a VM reboot. After rebooting, you need to reconfigure the network and restart FRRouting. Some pinning failures are normal if other experiments have already claimed the target NUMA domain.
#
# </div>

# %%
slice = fablib.get_slice(slice_name)

for node in slice.get_nodes():

    print(f'----- Pinning for node {node.get_name()} ------')

    try:
        print(f'Pinning vCPUs ')
        # Pin all vCPUs to the same NUMA node as the NIC
        node.pin_cpu(component_name='nic_local')

        print(f'Pinning memory ')
        # Pin memory to the same NUMA node as the NIC
        node.numa_tune()

        # Reboot the VM to apply NUMA changes
        node.os_reboot()
    except Exception as e:
        print(f'{e}')

# %% [markdown]
# ### Reconfigure After Reboot
#
# After the VMs reboot, wait for SSH connectivity and reconfigure the network and FRRouting.

# %%
slice = fablib.get_slice(slice_name)

# Wait for all nodes to be reachable via SSH
slice.wait_ssh()

print("Nodes are back up!")

# Re-apply network configuration and restart services
for node in slice.get_nodes():
    print(f'Reconfiguring node {node.get_name()}')
    node.config()  # Re-apply IP addresses and routes

    # Restart Docker service
    stdout1, stderr1 = node.execute(f"sudo systemctl start docker", output_file=f'{node.get_name()}.log', quiet=True)    
    
    # Re-apply host tuning
    stdout1, stderr1 = node.execute(f"sudo ./docker_containers/fabric_frrouting/node_tools/host_tune.sh", 
                                    output_file=f'{node.get_name()}.log', quiet=True)
    
    # Restart FRRouting on router nodes
    if 'router' in node.get_name():
        stdout1, stderr1 = node.execute(f'sudo ./docker_containers/fabric_frrouting/restart.sh', 
                                    output_file=f'{node.get_name()}.log', quiet=True)

# %% [markdown]
# ## Step 12: Re-Test After NUMA Tuning
#
# Run the same connectivity and bandwidth tests to see if NUMA tuning improved performance.
#
# ### Connectivity Test

# %%
try:
    slice = fablib.get_slice(slice_name)

    source_node = slice.get_node(name=f'{sites[0].lower()}1')
    
    target_node = slice.get_node(name=f'{sites[1].lower()}1')
    target_ip=target_node.get_interface(network_name=f'net2').get_ip_addr()
    
    print(f"Testing target node: {target_node.get_name()}, target IP: {target_ip}")

    # Ping test after NUMA tuning
    stdout, stderr = source_node.execute(f'ping -c 5 {target_ip}')

    # Tracepath after NUMA tuning
    stdout, stderr = source_node.execute(f'tracepath {target_ip}')
    
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Bandwidth Test After NUMA Tuning
#
# **Think about:** Did NUMA tuning improve bandwidth? By how much? With 8 parallel streams instead of 4, do you see better utilization?

# %%
slice = fablib.get_slice(slice_name)

source_node = slice.get_node(name=f'{sites[0].lower()}1')
target_node = slice.get_node(name=f'{sites[1].lower()}1')
target_ip=target_node.get_interface(network_name=f'net2').get_ip_addr()

print(f"Testing target node: {target_node.get_name()}, target IP: {target_ip}")

# Start iPerf3 server
stdout1, stderr1 = target_node.execute("docker run -d --rm "
                                "--network host "
                                "fabrictestbed/slice-vm-rocky8-multitool:0.0.2  "
                                "iperf3 -s -1"
                                , quiet=True, output_file=f"{target_node.get_name()}.log");

# Run iPerf3 client with 8 parallel streams (increased from 4)
stdout2, stderr2 = source_node.execute("docker run --rm "
                                "--network host "
                                "fabrictestbed/slice-vm-rocky8-multitool:0.0.2  "
                                f"iperf3 -c {target_ip} -P 8 -t 30 -i 10 -O 10"
                                , quiet=False, output_file=f"{node.get_name()}.log");

# %% [markdown]
# ## Step 13: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. FABRIC is a shared resource -- leaving slices running prevents other researchers from using those resources.
#
# </div>

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | Ping fails between end hosts | OSPF has not converged yet | Wait 30-60 seconds and retry; check FRR logs with `docker logs <frr_container>` on a router |
# | `tracepath` shows unexpected hops | OSPF is recalculating paths | This is normal during convergence; wait and retry |
# | FRR container not running | Docker not enabled or post-boot task failed | SSH to the router and run `docker ps`; manually start with `./docker_containers/fabric_frrouting/restart.sh` |
# | Low bandwidth through routers | Software routing overhead; no NUMA tuning | Apply NUMA tuning (Step 11); increase parallel streams |
# | NUMA pinning fails | NUMA domain already claimed by other experiments | This is expected on busy hosts; try a different site |
# | Network not working after reboot | IP configuration lost | Run `node.config()` to re-apply; restart Docker and FRR |
# | End hosts cannot reach remote subnets | Default route not set or gateway unreachable | Verify `ip route` on the end host includes `192.168.0.0/16 via <gateway>` |
# | Template variable not resolved | Incorrect interface name in template | Check `node.get_interfaces()` and verify the interface name matches the template |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_sites(count)` | Select random available FABRIC sites | [get_random_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_sites) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `fablib.get_slice(name)` | Retrieve an existing slice by name | [get_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_slice) |
# | `slice.add_l2network(name, subnet, gateway)` | Create a Layer 2 network with addressing | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `slice.add_node(...)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component(model, name)` | Add a NIC or other component | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `node.add_post_boot_upload_directory()` | Upload a directory after boot | [add_post_boot_upload_directory](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_post_boot_upload_directory) |
# | `node.add_post_boot_execute()` | Execute a command after boot | [add_post_boot_execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_post_boot_execute) |
# | `node.add_route(subnet, next_hop)` | Add a static route | [add_route](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_route) |
# | `node.pin_cpu(component_name)` | Pin vCPUs to NIC's NUMA domain | [pin_cpu](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.pin_cpu) |
# | `node.numa_tune()` | Pin memory to NIC's NUMA domain | [numa_tune](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.numa_tune) |
# | `node.os_reboot()` | Reboot the VM | [os_reboot](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.os_reboot) |
# | `interface.set_mode(mode)` | Set interface IP assignment mode | [set_mode](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_mode) |
# | `interface.set_ip_addr(ip)` | Assign an IP address to an interface | [set_ip_addr](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_ip_addr) |
# | `slice.submit()` | Submit the slice for provisioning | [submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit) |
# | `slice.wait_ssh()` | Wait for SSH access to all nodes | [wait_ssh](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.wait_ssh) |
# | `node.config()` | Re-apply network configuration | [config](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.config) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you have deployed OSPF routers, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **iPerf3 Bandwidth Testing** | [iperf3](../iPerf3/iperf3.ipynb) | Baseline bandwidth measurement without software routers |
# | **Optimized iPerf3 with SmartNICs** | [iperf3_optimized_smart_nic](../iPerf3/iperf3_optimized_smart_nic.ipynb) | Maximum throughput with NUMA tuning and SmartNICs |
# | **Open vSwitch** | [openvswitch](../openvswitch/openvswitch.ipynb) | Layer 2 virtual switching with OVS |
# | **Post Boot Task Templates** | [post_boot_task_templates](../../fablib_api/post_boot_task_templates/post_boot_task_templates.ipynb) | Deep dive into template variables and automation |
# | **Docker Containers** | [docker_containers](../../fablib_api/docker_containers/docker_containers.ipynb) | Running containerized services on FABRIC nodes |
