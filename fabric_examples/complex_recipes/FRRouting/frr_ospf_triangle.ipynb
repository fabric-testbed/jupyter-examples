# %% [markdown]
# # Routing Topology: OSPF using FRRouting
#
# This notebook is an example of how to create a FABRIC routing experiment topology comprising nodes at three different sites. Each site has a local layer 2 (Ethernet) network connecting a set of local nodes and one gateway router. The three gateway routers connect to each other and use the [FRRouting](https://frrouting.org/) protocol suite to deploy [OSPF](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) dameons to propagate route updates across the topology.
#
# You might be familiar with the [Quagga](https://www.quagga.net/) router suite.  FRRouting is based on Quagga but has a more active upstream community including many large companies working on cloud networking.

# %% [markdown]
# ## Import the FABlib Library

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_b056e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b056e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b056e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_b056e_row0_col0, #T_b056e_row0_col1, #T_b056e_row1_col0, #T_b056e_row1_col1, #T_b056e_row2_col0, #T_b056e_row2_col1, #T_b056e_row3_col0, #T_b056e_row3_col1, #T_b056e_row4_col0, #T_b056e_row4_col1, #T_b056e_row5_col0, #T_b056e_row5_col1, #T_b056e_row6_col0, #T_b056e_row6_col1, #T_b056e_row7_col0, #T_b056e_row7_col1, #T_b056e_row8_col0, #T_b056e_row8_col1, #T_b056e_row9_col0, #T_b056e_row9_col1, #T_b056e_row10_col0, #T_b056e_row10_col1, #T_b056e_row11_col0, #T_b056e_row11_col1, #T_b056e_row12_col0, #T_b056e_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_b056e">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b056e_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_b056e_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_b056e_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_b056e_row2_col1" class="data row2 col1" >/home/fabric/work/fabric_config/tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_b056e_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_b056e_row4_col1" class="data row4 col1" >pruth_0031379841</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_b056e_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_b056e_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_b056e_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_b056e_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_b056e_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_b056e_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_b056e_row11_col1" class="data row11 col1" >/home/fabric/work/logs/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_b056e_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_b056e_row12_col1" class="data row12 col1" >DEBUG</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates private layer 2 networks on three sites including OSPF gateway routers that propagate routes across the topology.

# %%
slice_name = 'OSPF_Routing_Topology1'

sites= fablib.get_random_sites(count=4)
print(f"Sites: {sites}")

router_base_name='router'
router_link_base_name='router_link'

node_base_name='node'
local_network_base_name='net_local'

site_node_count=2
# Out:
# Sites: ['TACC', 'UCSD', 'NCSA', 'GPN']

# %%
slice = fablib.new_slice(name=slice_name)

# Create Routers
routers = []
frr_user_data = {}
for i, site in enumerate(sites):
    router_name = f"{router_base_name}{i+1}"
    frr_user_data[router_name] = {}
    local_subnet = IPv4Network(f"192.168.{i+1}.0/24")
    local_gateway = local_subnet[1]

    router = slice.add_node(name=router_name, site=site).enable_docker()
    iface_local = router.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]
    iface_local.set_mode('fablib')
    
    local_net = slice.add_l2network(name=f'{local_network_base_name}{i+1}', subnet=local_subnet, gateway=local_gateway)
    local_net.add_interface(iface_local)
    iface_local.set_ip_addr(local_gateway)
    
    frr_user_data[router_name]['local_iface'] = iface_local.get_name()
    frr_user_data[router_name]['link_ifaces'] = []
    
    routers.append(router)

# Create Links between routers (ring)
links = []
for i, site in enumerate(sites):
    link_info = {}
    link_info['name'] = f'{router_link_base_name}{i+1}'
    link_subnet = IPv4Network(f"192.168.10{i+1}.0/24")
    
    link = slice.add_l2network(name=link_info['name'], subnet=link_subnet)
    links.append(link)

    router1 = routers[i]
    router2 = routers[(i+1)%len(sites)]

    iface1 = router1.add_component(model='NIC_Basic', name=link_info['name']).get_interfaces()[0]
    iface2 = router2.add_component(model='NIC_Basic', name=link_info['name']).get_interfaces()[0]
    
    iface1.set_mode('fablib').set_network(link).set_ip_addr(link_subnet[1])
    iface2.set_mode('fablib').set_network(link).set_ip_addr(link_subnet[2])
    
    frr_user_data[router1.get_name()]['link_ifaces'].append(iface1.get_name()) 
    frr_user_data[router2.get_name()]['link_ifaces'].append(iface2.get_name()) 
  
    
# Set frr user_data
for router in slice.get_nodes():
    user_data = router.get_user_data()
    user_data['frr'] = frr_user_data[router.get_name()]
    router.set_user_data(user_data)
    
slice_id = slice.submit()
# Out:
# Retry: 0, Time: 33 sec
# <style type="text/css">
# #T_ea44c tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ea44c tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ea44c caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_ea44c_row0_col0, #T_ea44c_row0_col1, #T_ea44c_row1_col0, #T_ea44c_row1_col1, #T_ea44c_row2_col0, #T_ea44c_row2_col1, #T_ea44c_row3_col0, #T_ea44c_row3_col1, #T_ea44c_row4_col0, #T_ea44c_row4_col1, #T_ea44c_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_ea44c_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# </style>
# <table id="T_ea44c">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea44c_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_ea44c_row0_col1" class="data row0 col1" >5eb71691-8b5e-4868-a47d-6bf2eb152250</td>
#     </tr>
#     <tr>
#       <td id="T_ea44c_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_ea44c_row1_col1" class="data row1 col1" >OSPF_Routing_Topology1</td>
#     </tr>
#     <tr>
#       <td id="T_ea44c_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_ea44c_row2_col1" class="data row2 col1" >2023-02-25 16:33:27 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ea44c_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_ea44c_row3_col1" class="data row3 col1" >2023-02-24 16:33:28 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ea44c_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_ea44c_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_ea44c_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_ea44c_row5_col1" class="data row5 col1" >Configuring</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_38a69 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_38a69 th {
#   text-align: left;
# }
# #T_38a69 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_38a69 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_38a69 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_38a69_row0_col0, #T_38a69_row0_col1, #T_38a69_row0_col2, #T_38a69_row0_col3, #T_38a69_row0_col4, #T_38a69_row0_col5, #T_38a69_row0_col6, #T_38a69_row0_col7, #T_38a69_row0_col8, #T_38a69_row0_col9, #T_38a69_row0_col10, #T_38a69_row0_col13, #T_38a69_row0_col14, #T_38a69_row0_col15, #T_38a69_row1_col0, #T_38a69_row1_col1, #T_38a69_row1_col2, #T_38a69_row1_col3, #T_38a69_row1_col4, #T_38a69_row1_col5, #T_38a69_row1_col6, #T_38a69_row1_col7, #T_38a69_row1_col8, #T_38a69_row1_col9, #T_38a69_row1_col10, #T_38a69_row1_col13, #T_38a69_row1_col14, #T_38a69_row1_col15, #T_38a69_row2_col0, #T_38a69_row2_col1, #T_38a69_row2_col2, #T_38a69_row2_col3, #T_38a69_row2_col4, #T_38a69_row2_col5, #T_38a69_row2_col6, #T_38a69_row2_col7, #T_38a69_row2_col8, #T_38a69_row2_col9, #T_38a69_row2_col10, #T_38a69_row2_col13, #T_38a69_row2_col14, #T_38a69_row2_col15, #T_38a69_row3_col0, #T_38a69_row3_col1, #T_38a69_row3_col2, #T_38a69_row3_col3, #T_38a69_row3_col4, #T_38a69_row3_col5, #T_38a69_row3_col6, #T_38a69_row3_col7, #T_38a69_row3_col8, #T_38a69_row3_col9, #T_38a69_row3_col10, #T_38a69_row3_col13, #T_38a69_row3_col14, #T_38a69_row3_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_38a69_row0_col11, #T_38a69_row1_col11, #T_38a69_row2_col11, #T_38a69_row3_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# #T_38a69_row0_col12, #T_38a69_row1_col12, #T_38a69_row2_col12, #T_38a69_row3_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_38a69">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_38a69_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_38a69_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_38a69_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_38a69_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_38a69_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_38a69_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_38a69_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_38a69_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_38a69_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_38a69_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_38a69_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_38a69_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_38a69_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_38a69_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_38a69_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_38a69_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38a69_row0_col0" class="data row0 col0" >be4fd153-b9fd-4e04-9d61-ffe29be3f48d</td>
#       <td id="T_38a69_row0_col1" class="data row0 col1" >router1</td>
#       <td id="T_38a69_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_38a69_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_38a69_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_38a69_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_38a69_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_38a69_row0_col7" class="data row0 col7" >tacc-w2.fabric-testbed.net</td>
#       <td id="T_38a69_row0_col8" class="data row0 col8" >TACC</td>
#       <td id="T_38a69_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_38a69_row0_col10" class="data row0 col10" ></td>
#       <td id="T_38a69_row0_col11" class="data row0 col11" >Ticketed</td>
#       <td id="T_38a69_row0_col12" class="data row0 col12" ></td>
#       <td id="T_38a69_row0_col13" class="data row0 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@</td>
#       <td id="T_38a69_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_38a69_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_38a69_row1_col0" class="data row1 col0" >72f47e26-3ff5-48ab-91cf-e782e9ada6db</td>
#       <td id="T_38a69_row1_col1" class="data row1 col1" >router2</td>
#       <td id="T_38a69_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_38a69_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_38a69_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_38a69_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_38a69_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_38a69_row1_col7" class="data row1 col7" >ucsd-w1.fabric-testbed.net</td>
#       <td id="T_38a69_row1_col8" class="data row1 col8" >UCSD</td>
#       <td id="T_38a69_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_38a69_row1_col10" class="data row1 col10" ></td>
#       <td id="T_38a69_row1_col11" class="data row1 col11" >Ticketed</td>
#       <td id="T_38a69_row1_col12" class="data row1 col12" ></td>
#       <td id="T_38a69_row1_col13" class="data row1 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@</td>
#       <td id="T_38a69_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_38a69_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_38a69_row2_col0" class="data row2 col0" >a9a25848-4026-4412-9c15-73ac9a92250e</td>
#       <td id="T_38a69_row2_col1" class="data row2 col1" >router3</td>
#       <td id="T_38a69_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_38a69_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_38a69_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_38a69_row2_col5" class="data row2 col5" >default_rocky_8</td>
#       <td id="T_38a69_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_38a69_row2_col7" class="data row2 col7" >ncsa-w3.fabric-testbed.net</td>
#       <td id="T_38a69_row2_col8" class="data row2 col8" >NCSA</td>
#       <td id="T_38a69_row2_col9" class="data row2 col9" >rocky</td>
#       <td id="T_38a69_row2_col10" class="data row2 col10" ></td>
#       <td id="T_38a69_row2_col11" class="data row2 col11" >Ticketed</td>
#       <td id="T_38a69_row2_col12" class="data row2 col12" ></td>
#       <td id="T_38a69_row2_col13" class="data row2 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@</td>
#       <td id="T_38a69_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_38a69_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_38a69_row3_col0" class="data row3 col0" >72d1e52c-c5c0-40e7-983a-c895c7aeed60</td>
#       <td id="T_38a69_row3_col1" class="data row3 col1" >router4</td>
#       <td id="T_38a69_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_38a69_row3_col3" class="data row3 col3" >8</td>
#       <td id="T_38a69_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_38a69_row3_col5" class="data row3 col5" >default_rocky_8</td>
#       <td id="T_38a69_row3_col6" class="data row3 col6" >qcow2</td>
#       <td id="T_38a69_row3_col7" class="data row3
# <style type="text/css">
# #T_ecfb2 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_ecfb2 th {
#   text-align: left;
# }
# #T_ecfb2 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ecfb2 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ecfb2 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ecfb2_row0_col0, #T_ecfb2_row0_col1, #T_ecfb2_row0_col2, #T_ecfb2_row0_col3, #T_ecfb2_row0_col4, #T_ecfb2_row0_col5, #T_ecfb2_row0_col6, #T_ecfb2_row1_col0, #T_ecfb2_row1_col1, #T_ecfb2_row1_col2, #T_ecfb2_row1_col3, #T_ecfb2_row1_col4, #T_ecfb2_row1_col5, #T_ecfb2_row1_col6, #T_ecfb2_row2_col0, #T_ecfb2_row2_col1, #T_ecfb2_row2_col2, #T_ecfb2_row2_col3, #T_ecfb2_row2_col4, #T_ecfb2_row2_col5, #T_ecfb2_row2_col6, #T_ecfb2_row3_col0, #T_ecfb2_row3_col1, #T_ecfb2_row3_col2, #T_ecfb2_row3_col3, #T_ecfb2_row3_col4, #T_ecfb2_row3_col5, #T_ecfb2_row3_col6, #T_ecfb2_row4_col0, #T_ecfb2_row4_col1, #T_ecfb2_row4_col2, #T_ecfb2_row4_col3, #T_ecfb2_row4_col4, #T_ecfb2_row4_col5, #T_ecfb2_row4_col6, #T_ecfb2_row5_col0, #T_ecfb2_row5_col1, #T_ecfb2_row5_col2, #T_ecfb2_row5_col3, #T_ecfb2_row5_col4, #T_ecfb2_row5_col5, #T_ecfb2_row5_col6, #T_ecfb2_row6_col0, #T_ecfb2_row6_col1, #T_ecfb2_row6_col2, #T_ecfb2_row6_col3, #T_ecfb2_row6_col4, #T_ecfb2_row6_col5, #T_ecfb2_row6_col6, #T_ecfb2_row7_col0, #T_ecfb2_row7_col1, #T_ecfb2_row7_col2, #T_ecfb2_row7_col3, #T_ecfb2_row7_col4, #T_ecfb2_row7_col5, #T_ecfb2_row7_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_ecfb2_row0_col7, #T_ecfb2_row1_col7, #T_ecfb2_row2_col7, #T_ecfb2_row3_col7, #T_ecfb2_row4_col7, #T_ecfb2_row5_col7, #T_ecfb2_row6_col7, #T_ecfb2_row7_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# #T_ecfb2_row0_col8, #T_ecfb2_row1_col8, #T_ecfb2_row2_col8, #T_ecfb2_row3_col8, #T_ecfb2_row4_col8, #T_ecfb2_row5_col8, #T_ecfb2_row6_col8, #T_ecfb2_row7_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_ecfb2">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_ecfb2_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_ecfb2_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_ecfb2_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_ecfb2_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_ecfb2_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_ecfb2_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_ecfb2_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_ecfb2_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_ecfb2_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ecfb2_row0_col0" class="data row0 col0" >91fed7c4-0386-4aa2-b466-1b76c88e99b1</td>
#       <td id="T_ecfb2_row0_col1" class="data row0 col1" >net_local1</td>
#       <td id="T_ecfb2_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_ecfb2_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_ecfb2_row0_col4" class="data row0 col4" >TACC</td>
#       <td id="T_ecfb2_row0_col5" class="data row0 col5" >net_local1.subnet</td>
#       <td id="T_ecfb2_row0_col6" class="data row0 col6" >net_local1.gateway</td>
#       <td id="T_ecfb2_row0_col7" class="data row0 col7" >Ticketed</td>
#       <td id="T_ecfb2_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_ecfb2_row1_col0" class="data row1 col0" >61243fd9-ed09-4545-8bed-319b3cdeea03</td>
#       <td id="T_ecfb2_row1_col1" class="data row1 col1" >net_local2</td>
#       <td id="T_ecfb2_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_ecfb2_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_ecfb2_row1_col4" class="data row1 col4" >UCSD</td>
#       <td id="T_ecfb2_row1_col5" class="data row1 col5" >net_local2.subnet</td>
#       <td id="T_ecfb2_row1_col6" class="data row1 col6" >net_local2.gateway</td>
#       <td id="T_ecfb2_row1_col7" class="data row1 col7" >Ticketed</td>
#       <td id="T_ecfb2_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_ecfb2_row2_col0" class="data row2 col0" >c4ab01b6-693b-4801-a6ff-f016e69897b5</td>
#       <td id="T_ecfb2_row2_col1" class="data row2 col1" >net_local3</td>
#       <td id="T_ecfb2_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_ecfb2_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_ecfb2_row2_col4" class="data row2 col4" >NCSA</td>
#       <td id="T_ecfb2_row2_col5" class="data row2 col5" >net_local3.subnet</td>
#       <td id="T_ecfb2_row2_col6" class="data row2 col6" >net_local3.gateway</td>
#       <td id="T_ecfb2_row2_col7" class="data row2 col7" >Ticketed</td>
#       <td id="T_ecfb2_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_ecfb2_row3_col0" class="data row3 col0" >d9a735c8-a8f4-47c7-b80a-e3bafae21168</td>
#       <td id="T_ecfb2_row3_col1" class="data row3 col1" >net_local4</td>
#       <td id="T_ecfb2_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_ecfb2_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_ecfb2_row3_col4" class="data row3 col4" >GPN</td>
#       <td id="T_ecfb2_row3_col5" class="data row3 col5" >net_local4.subnet</td>
#       <td id="T_ecfb2_row3_col6" class="data row3 col6" >net_local4.gateway</td>
#       <td id="T_ecfb2_row3_col7" class="data row3 col7" >Ticketed</td>
#       <td id="T_ecfb2_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_ecfb2_row4_col0" class="data row4 col0" >d0c36b7d-ed37-4440-81c5-63d57eda1154</td>
#       <td id="T_ecfb2_row4_col1" class="data row4 col1" >router_link1</td>
#       <td id="T_ecfb2_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_ecfb2_row4_col3" class="data row4 col3" >L2STS</td>
#       <td id="T_ecfb2_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_ecfb2_row4_col5" class="data row4 col5" >router_link1.subnet</td>
#       <td id="T_ecfb2_row4_col6" class="data row4 col6" >router_link1.gateway</td>
#       <td id="T_ecfb2_row4_col7" class="data row4 col7" >Ticketed</td>
#       <td id="T_ecfb2_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_ecfb2_row5_col0" class="data row5 col0" >ca2a2b28-101d-4624-a0d4-12df2ba01674</td>
#       <td id="T_ecfb2_row5_col1" class="data row5 col1" >router_link2</td>
#       <td id="T_ecfb2_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_ecfb2_row5_col3" class="data row5 col3" >L2STS</td>
#       <td id="T_ecfb2_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_ecfb2_row5_col5" class="data row5 col5" >router_link2.subnet</td>
#       <td id="T_ecfb2_row5_col6" class="data row5 col6" >router_link2.gateway</td>
#       <td id="T_ecfb2_row5_col7" class="data row5 col7" >Ticketed</td>
#       <td id="T_ecfb2_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_ecfb2_row6_col0" class="data row6 col0" >6fce396d-75f6-48ef-8e3a-8844489adbc6</td>
#       <td id="T_ecfb2_row6_col1" class="data row6 col1" >router_link3</td>
#       <td id="T_ecfb2_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_ecfb2_row6_col3" class="data row6 col3" >L2STS</td>
#       <td id="T_ecfb2_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_ecfb2_row6_col5" class="data row6 col5" >router_link3.subnet</td>
#       <td id="T_ecfb2_row6_col6" class="data row6 col6" >router_link3.gateway</td>
#       <td id="T_ecfb2_row6_col7" class="data row6 col7" >Ticketed</td>
#       <td id="T_ecfb2_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_ecfb2_row7_col0" class="data row7 col0" >dafcc40b-6061-422c-a8c1-300af088fbbf</td>
#       <td id="T_ecfb2_row7_col1" class="data row7 col1" >router_link4</td>
#       <td id="T_ecfb2_row7_col2" class="

# %%
import json
#for router in slice.get_nodes():
#    print(f"{router.get_name()}, {json.dumps(router.get_user_data(), indent=4)}")

# %%
for node in slice.get_nodes():
    attributes = node.upload_directory('/home/fabric/work/docker_containers','.')
    node.execute("cd docker_containers/droppy ; docker compose up -d", quiet=True, output_file=f"{node.get_name()}.log");

    attributes = node.upload_file('frr_config_docker.sh','frr_config_docker.sh')
    
    frr_user_data = node.get_user_data()['frr']
    
    iface_local = slice.get_interface(frr_user_data['local_iface'])
    iface_link1 = slice.get_interface(frr_user_data['link_ifaces'][0])
    iface_link2 = slice.get_interface(frr_user_data['link_ifaces'][1])

    stdout, stderr = node.execute(f'chmod +x frr_config_docker.sh && sudo ./frr_config_docker.sh {iface_link1.get_device_name()} {iface_link1.get_ip_addr()} {iface_link2.get_device_name()} {iface_link2.get_ip_addr()} {iface_local.get_device_name()} {iface_local.get_ip_addr()} 192.168.0.0')

    node.execute("cd docker_containers/fabric_frrouting ; docker compose up -d", quiet=True, output_file=f"{node.get_name()}.log");

# %%
for i, site in enumerate(sites):
    for node_num in range(2):
        node_name = f"{site.lower()}{node_num+1}"
        node = slice.add_node(name=node_name, site=site).enable_docker()
        iface = node.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
        iface.set_mode('auto')
        network = slice.get_network(name=f'{local_network_base_name}{i+1}')
        network.add_interface(iface)
        node.add_route(subnet=IPv4Network('192.168.0.0/16'), next_hop=network.get_gateway())
        
slice.submit()

# %% [markdown]
# Pick the subnet for the local networks.  The /24 subnets can support up to 254 locally connected nodes plus the gateway.

# %% [markdown]
# ## Run the Experiment
#
# We will just test `ping` RTT and look at `tracepath`. Your experiment should be more interesting!
#
# Notice that if you run this quickly and repeatedly run this test against a specific target, you may see changes to the tracepath.  Initially the ping may even fail.  Why do you think this is happening?

# %%
try:
    source_node_name =  f'{node_base_name}_site1_1'
   
    source_node = slice.get_node(name=source_node_name)
    for node_name,target_ip in local_dataplane_ips.items():
        print(f"Testing target node: {node_name}, target IP: {target_ip}")
    
        stdout, stderr = node.execute(f'ping -c 5 {target_ip}')

        stdout, stderr = node.execute(f'tracepath {target_ip}')
    
except Exception as e:
    print(f"Exception: {e}")

# %%
try:
    slice.save("ospf.graphml")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
