# %% [markdown]
# # Routing Topology: OSPF using FRRouting
#
# This notebook is an example of how to create a FABRIC routing experiment topology comprising nodes at three different sites. Each site has a local layer 2 (Ethernet) network connecting a set of local nodes and one gateway router. The three gateway routers connect to each other and use the [FRRouting](https://frrouting.org/) protocol suite to deploy [OSPF](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) dameons to propagate route updates across the topology.
#
# You might be familiar with the [Quagga](https://www.quagga.net/) router suite.  FRRouting is based on Quagga but has a more active upstream community including many large companies working on cloud networking.

# %% [markdown]
# ## Import the FABlib Library

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_912ee tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_912ee tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_912ee caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_912ee_row0_col0, #T_912ee_row0_col1, #T_912ee_row1_col0, #T_912ee_row1_col1, #T_912ee_row2_col0, #T_912ee_row2_col1, #T_912ee_row3_col0, #T_912ee_row3_col1, #T_912ee_row4_col0, #T_912ee_row4_col1, #T_912ee_row5_col0, #T_912ee_row5_col1, #T_912ee_row6_col0, #T_912ee_row6_col1, #T_912ee_row7_col0, #T_912ee_row7_col1, #T_912ee_row8_col0, #T_912ee_row8_col1, #T_912ee_row9_col0, #T_912ee_row9_col1, #T_912ee_row10_col0, #T_912ee_row10_col1, #T_912ee_row11_col0, #T_912ee_row11_col1, #T_912ee_row12_col0, #T_912ee_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_912ee">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_912ee_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_912ee_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_912ee_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_912ee_row2_col1" class="data row2 col1" >/home/fabric/work/fabric_config/tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_912ee_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_912ee_row4_col1" class="data row4 col1" >pruth_0031379841</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_912ee_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_912ee_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_912ee_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_912ee_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_912ee_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_912ee_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_912ee_row11_col1" class="data row11 col1" >/home/fabric/work/logs/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_912ee_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_912ee_row12_col1" class="data row12 col1" >DEBUG</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates private layer 2 networks on three sites including OSPF gateway routers that propagate routes across the topology.

# %%
slice_name = 'OSPF_Routing_Topology2'

sites= fablib.get_random_sites(count=4)
print(f"Sites: {sites}")

router_base_name='router'
router_link_base_name='router_link'

node_base_name='node'
local_network_base_name='net_local'

site_node_count=2
# Out:
# Sites: ['NCSA', 'UTAH', 'DALL', 'CLEM']

# %%
slice = fablib.new_slice(name=slice_name)

# Create Routers
routers = []
for i, site in enumerate(sites):
    router_info = {}
    router_info['name'] = f"{router_base_name}{i+1}"
    local_subnet = IPv4Network(f"192.168.{i+1}.0/24")
    local_gateway = IPv4Address(f"192.168.{i+1}.1")

    router_info['node'] = router = slice.add_node(name=router_info['name'], site=site)
    router_info['link_iface_local'] = router.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]
    router_info['link_iface_local'].set_mode('fablib')

    
    router_info['local_net'] = slice.add_l2network(name=f'{local_network_base_name}{i+1}', subnet=local_subnet, gateway=local_gateway)
    router_info['local_net'].add_interface(router_info['link_iface_local'])
    router_info['link_iface_local'].set_ip_addr(local_gateway)

    router.enable_docker()
    
    routers.append(router_info)

# Create Links between routers (ring)
links = []
for i, site in enumerate(sites):
    link_info = {}
    link_info['name'] = f'{router_link_base_name}{i+1}'
    link_subnet = IPv4Network(f"192.168.10{i+1}.0/24")

    router1 = routers[i]
    router2 = routers[(i+1)%len(sites)]

    iface1 = router1['node'].add_component(model='NIC_Basic', name=link_info['name']).get_interfaces()[0]
    iface2 = router2['node'].add_component(model='NIC_Basic', name=link_info['name']).get_interfaces()[0]
    
    iface1.set_mode('auto')
    iface2.set_mode('auto')
    
    link = slice.add_l2network(name=link_info['name'], 
                               subnet=IPv4Network(f"192.168.10{i+1}.0/24"),
                               interfaces=[iface1,iface2] 
                              )
    links.append(link)
    
slice_id = slice.submit()
# Out:
# Retry: 8, Time: 668 sec
# <style type="text/css">
# #T_45128 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_45128 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_45128 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_45128_row0_col0, #T_45128_row0_col1, #T_45128_row1_col0, #T_45128_row1_col1, #T_45128_row2_col0, #T_45128_row2_col1, #T_45128_row3_col0, #T_45128_row3_col1, #T_45128_row4_col0, #T_45128_row4_col1, #T_45128_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_45128_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_45128">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_45128_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_45128_row0_col1" class="data row0 col1" >468b7680-6c67-467c-b745-a25202aa9034</td>
#     </tr>
#     <tr>
#       <td id="T_45128_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_45128_row1_col1" class="data row1 col1" >OSPF_Routing_Topology2</td>
#     </tr>
#     <tr>
#       <td id="T_45128_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_45128_row2_col1" class="data row2 col1" >2023-02-20 21:11:35 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_45128_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_45128_row3_col1" class="data row3 col1" >2023-02-19 21:11:36 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_45128_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_45128_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_45128_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_45128_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_18b32 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_18b32 th {
#   text-align: left;
# }
# #T_18b32 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_18b32 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_18b32 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_18b32_row0_col0, #T_18b32_row0_col1, #T_18b32_row0_col2, #T_18b32_row0_col3, #T_18b32_row0_col4, #T_18b32_row0_col5, #T_18b32_row0_col6, #T_18b32_row0_col7, #T_18b32_row0_col8, #T_18b32_row0_col9, #T_18b32_row0_col10, #T_18b32_row0_col13, #T_18b32_row0_col14, #T_18b32_row0_col15, #T_18b32_row1_col0, #T_18b32_row1_col1, #T_18b32_row1_col2, #T_18b32_row1_col3, #T_18b32_row1_col4, #T_18b32_row1_col5, #T_18b32_row1_col6, #T_18b32_row1_col7, #T_18b32_row1_col8, #T_18b32_row1_col9, #T_18b32_row1_col10, #T_18b32_row1_col13, #T_18b32_row1_col14, #T_18b32_row1_col15, #T_18b32_row2_col0, #T_18b32_row2_col1, #T_18b32_row2_col2, #T_18b32_row2_col3, #T_18b32_row2_col4, #T_18b32_row2_col5, #T_18b32_row2_col6, #T_18b32_row2_col7, #T_18b32_row2_col8, #T_18b32_row2_col9, #T_18b32_row2_col10, #T_18b32_row2_col13, #T_18b32_row2_col14, #T_18b32_row2_col15, #T_18b32_row3_col0, #T_18b32_row3_col1, #T_18b32_row3_col2, #T_18b32_row3_col3, #T_18b32_row3_col4, #T_18b32_row3_col5, #T_18b32_row3_col6, #T_18b32_row3_col7, #T_18b32_row3_col8, #T_18b32_row3_col9, #T_18b32_row3_col10, #T_18b32_row3_col13, #T_18b32_row3_col14, #T_18b32_row3_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_18b32_row0_col11, #T_18b32_row1_col11, #T_18b32_row2_col11, #T_18b32_row3_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_18b32_row0_col12, #T_18b32_row1_col12, #T_18b32_row2_col12, #T_18b32_row3_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_18b32">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_18b32_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_18b32_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_18b32_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_18b32_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_18b32_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_18b32_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_18b32_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_18b32_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_18b32_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_18b32_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_18b32_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_18b32_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_18b32_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_18b32_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_18b32_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_18b32_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_18b32_row0_col0" class="data row0 col0" >b1ffa84d-e816-4a5c-97a6-19b1da4e9364</td>
#       <td id="T_18b32_row0_col1" class="data row0 col1" >router1</td>
#       <td id="T_18b32_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_18b32_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_18b32_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_18b32_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_18b32_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_18b32_row0_col7" class="data row0 col7" >ncsa-w3.fabric-testbed.net</td>
#       <td id="T_18b32_row0_col8" class="data row0 col8" >NCSA</td>
#       <td id="T_18b32_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_18b32_row0_col10" class="data row0 col10" >2620:0:c80:1001:f816:3eff:fe1c:337c</td>
#       <td id="T_18b32_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_18b32_row0_col12" class="data row0 col12" ></td>
#       <td id="T_18b32_row0_col13" class="data row0 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2620:0:c80:1001:f816:3eff:fe1c:337c docker exec -it fabric_multitool bash</td>
#       <td id="T_18b32_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_18b32_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_18b32_row1_col0" class="data row1 col0" >91bf6436-7914-49d9-b6a1-530144e4fbbf</td>
#       <td id="T_18b32_row1_col1" class="data row1 col1" >router2</td>
#       <td id="T_18b32_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_18b32_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_18b32_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_18b32_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_18b32_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_18b32_row1_col7" class="data row1 col7" >utah-w4.fabric-testbed.net</td>
#       <td id="T_18b32_row1_col8" class="data row1 col8" >UTAH</td>
#       <td id="T_18b32_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_18b32_row1_col10" class="data row1 col10" >2001:1948:417:7:f816:3eff:febd:f6f3</td>
#       <td id="T_18b32_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_18b32_row1_col12" class="data row1 col12" ></td>
#       <td id="T_18b32_row1_col13" class="data row1 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:1948:417:7:f816:3eff:febd:f6f3 docker exec -it fabric_multitool bash</td>
#       <td id="T_18b32_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_18b32_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_18b32_row2_col0" class="data row2 col0" >1d91071f-4a5a-4c93-ac54-e59715377317</td>
#       <td id="T_18b32_row2_col1" class="data row2 col1" >router3</td>
#       <td id="T_18b32_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_18b32_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_18b32_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_18b32_row2_col5" class="data row2 col5" >default_rocky_8</td>
#       <td id="T_18b32_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_18b32_row2_col7" class="data row2 col7" >dall-w1.fabric-testbed.net</td>
#       <td id="T_18b32_row2_col8" class="data row2 col8" >DALL</td>
#       <td id="T_18b32_row2_col9" class="data row2 col9" >rocky</td>
#       <td id="T_18b32_row2_col10" class="data row2 col10" >2001:400:a100:3000:f816:3eff:fea8:212f</td>
#       <td id="T_18b32_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_18b32_row2_col12" class="data row2 col12" ></td>
#       <td id="T_18b32_row2_col13" class="data row2 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fea8:212f docker exec -it fabric_multitool bash</td>
#       <td id="T_18b32_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_18b32_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_18b32_row3_col0" class="data row3 col0" >bc001a44-7197-42c1-a9e7-24be27f292fc</td>
#       <td id="T_18b32_row3_col1" class="data row3 col1" >router4</td>
#       <td id="T_18b32_row3_col2" class="data row3 col2" >2</td>
# <style type="text/css">
# #T_46e3a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_46e3a th {
#   text-align: left;
# }
# #T_46e3a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_46e3a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_46e3a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_46e3a_row0_col0, #T_46e3a_row0_col1, #T_46e3a_row0_col2, #T_46e3a_row0_col3, #T_46e3a_row0_col4, #T_46e3a_row0_col5, #T_46e3a_row0_col6, #T_46e3a_row1_col0, #T_46e3a_row1_col1, #T_46e3a_row1_col2, #T_46e3a_row1_col3, #T_46e3a_row1_col4, #T_46e3a_row1_col5, #T_46e3a_row1_col6, #T_46e3a_row2_col0, #T_46e3a_row2_col1, #T_46e3a_row2_col2, #T_46e3a_row2_col3, #T_46e3a_row2_col4, #T_46e3a_row2_col5, #T_46e3a_row2_col6, #T_46e3a_row3_col0, #T_46e3a_row3_col1, #T_46e3a_row3_col2, #T_46e3a_row3_col3, #T_46e3a_row3_col4, #T_46e3a_row3_col5, #T_46e3a_row3_col6, #T_46e3a_row4_col0, #T_46e3a_row4_col1, #T_46e3a_row4_col2, #T_46e3a_row4_col3, #T_46e3a_row4_col4, #T_46e3a_row4_col5, #T_46e3a_row4_col6, #T_46e3a_row5_col0, #T_46e3a_row5_col1, #T_46e3a_row5_col2, #T_46e3a_row5_col3, #T_46e3a_row5_col4, #T_46e3a_row5_col5, #T_46e3a_row5_col6, #T_46e3a_row6_col0, #T_46e3a_row6_col1, #T_46e3a_row6_col2, #T_46e3a_row6_col3, #T_46e3a_row6_col4, #T_46e3a_row6_col5, #T_46e3a_row6_col6, #T_46e3a_row7_col0, #T_46e3a_row7_col1, #T_46e3a_row7_col2, #T_46e3a_row7_col3, #T_46e3a_row7_col4, #T_46e3a_row7_col5, #T_46e3a_row7_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_46e3a_row0_col7, #T_46e3a_row1_col7, #T_46e3a_row2_col7, #T_46e3a_row3_col7, #T_46e3a_row4_col7, #T_46e3a_row5_col7, #T_46e3a_row6_col7, #T_46e3a_row7_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_46e3a_row0_col8, #T_46e3a_row1_col8, #T_46e3a_row2_col8, #T_46e3a_row3_col8, #T_46e3a_row4_col8, #T_46e3a_row5_col8, #T_46e3a_row6_col8, #T_46e3a_row7_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_46e3a">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_46e3a_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_46e3a_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_46e3a_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_46e3a_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_46e3a_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_46e3a_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_46e3a_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_46e3a_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_46e3a_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46e3a_row0_col0" class="data row0 col0" >2824f7b0-2a4c-48db-952c-cea0d670dc35</td>
#       <td id="T_46e3a_row0_col1" class="data row0 col1" >net_local1</td>
#       <td id="T_46e3a_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_46e3a_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_46e3a_row0_col4" class="data row0 col4" >NCSA</td>
#       <td id="T_46e3a_row0_col5" class="data row0 col5" >192.168.1.0/24</td>
#       <td id="T_46e3a_row0_col6" class="data row0 col6" >192.168.1.1</td>
#       <td id="T_46e3a_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_46e3a_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_46e3a_row1_col0" class="data row1 col0" >c73a56b7-caaa-489d-8697-ceaa30209363</td>
#       <td id="T_46e3a_row1_col1" class="data row1 col1" >net_local2</td>
#       <td id="T_46e3a_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_46e3a_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_46e3a_row1_col4" class="data row1 col4" >UTAH</td>
#       <td id="T_46e3a_row1_col5" class="data row1 col5" >192.168.2.0/24</td>
#       <td id="T_46e3a_row1_col6" class="data row1 col6" >192.168.2.1</td>
#       <td id="T_46e3a_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_46e3a_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_46e3a_row2_col0" class="data row2 col0" >21ba4029-8416-423a-8d07-4fd0022abbb6</td>
#       <td id="T_46e3a_row2_col1" class="data row2 col1" >net_local3</td>
#       <td id="T_46e3a_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_46e3a_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_46e3a_row2_col4" class="data row2 col4" >DALL</td>
#       <td id="T_46e3a_row2_col5" class="data row2 col5" >192.168.3.0/24</td>
#       <td id="T_46e3a_row2_col6" class="data row2 col6" >192.168.3.1</td>
#       <td id="T_46e3a_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_46e3a_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_46e3a_row3_col0" class="data row3 col0" >07e701ff-5157-4994-9cba-7dd852c6a80b</td>
#       <td id="T_46e3a_row3_col1" class="data row3 col1" >net_local4</td>
#       <td id="T_46e3a_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_46e3a_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_46e3a_row3_col4" class="data row3 col4" >CLEM</td>
#       <td id="T_46e3a_row3_col5" class="data row3 col5" >192.168.4.0/24</td>
#       <td id="T_46e3a_row3_col6" class="data row3 col6" >192.168.4.1</td>
#       <td id="T_46e3a_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_46e3a_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_46e3a_row4_col0" class="data row4 col0" >af405b76-2213-42fe-a886-83cca4c10641</td>
#       <td id="T_46e3a_row4_col1" class="data row4 col1" >router_link1</td>
#       <td id="T_46e3a_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_46e3a_row4_col3" class="data row4 col3" >L2STS</td>
#       <td id="T_46e3a_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_46e3a_row4_col5" class="data row4 col5" >192.168.101.0/24</td>
#       <td id="T_46e3a_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_46e3a_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_46e3a_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_46e3a_row5_col0" class="data row5 col0" >f393a5d3-52a2-48be-988c-7070a8a93b09</td>
#       <td id="T_46e3a_row5_col1" class="data row5 col1" >router_link2</td>
#       <td id="T_46e3a_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_46e3a_row5_col3" class="data row5 col3" >L2STS</td>
#       <td id="T_46e3a_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_46e3a_row5_col5" class="data row5 col5" >192.168.102.0/24</td>
#       <td id="T_46e3a_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_46e3a_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_46e3a_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_46e3a_row6_col0" class="data row6 col0" >45665eef-929a-47a1-ad67-a49aa24dc32e</td>
#       <td id="T_46e3a_row6_col1" class="data row6 col1" >router_link3</td>
#       <td id="T_46e3a_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_46e3a_row6_col3" class="data row6 col3" >L2STS</td>
#       <td id="T_46e3a_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_46e3a_row6_col5" class="data row6 col5" >192.168.103.0/24</td>
#       <td id="T_46e3a_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_46e3a_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_46e3a_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_46e3a_row7_col0" class="data row7 col0" >b8479594-29b7-4539-ab8a-2aec3856ab89</td>
#       <td id="T_46e3a_row7_col1" class="data row7 col1" >router_link4</td>
#       <td id="T_46e3a_row7_col2" class="data row7 col2" >L2</td>
#       <td id="T_46e3a_row7_col3" class="data row7 col3" >L2STS</td>
#       <td id="T_4
# <style type="text/css">
# #T_3119d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_3119d th {
#   text-align: left;
# }
# #T_3119d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3119d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_3119d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3119d_row0_col0, #T_3119d_row0_col1, #T_3119d_row0_col2, #T_3119d_row0_col3, #T_3119d_row0_col4, #T_3119d_row0_col5, #T_3119d_row0_col6, #T_3119d_row0_col7, #T_3119d_row0_col8, #T_3119d_row0_col9, #T_3119d_row1_col0, #T_3119d_row1_col1, #T_3119d_row1_col2, #T_3119d_row1_col3, #T_3119d_row1_col4, #T_3119d_row1_col5, #T_3119d_row1_col6, #T_3119d_row1_col7, #T_3119d_row1_col8, #T_3119d_row1_col9, #T_3119d_row2_col0, #T_3119d_row2_col1, #T_3119d_row2_col2, #T_3119d_row2_col3, #T_3119d_row2_col4, #T_3119d_row2_col5, #T_3119d_row2_col6, #T_3119d_row2_col7, #T_3119d_row2_col8, #T_3119d_row2_col9, #T_3119d_row3_col0, #T_3119d_row3_col1, #T_3119d_row3_col2, #T_3119d_row3_col3, #T_3119d_row3_col4, #T_3119d_row3_col5, #T_3119d_row3_col6, #T_3119d_row3_col7, #T_3119d_row3_col8, #T_3119d_row3_col9, #T_3119d_row4_col0, #T_3119d_row4_col1, #T_3119d_row4_col2, #T_3119d_row4_col3, #T_3119d_row4_col4, #T_3119d_row4_col5, #T_3119d_row4_col6, #T_3119d_row4_col7, #T_3119d_row4_col8, #T_3119d_row4_col9, #T_3119d_row5_col0, #T_3119d_row5_col1, #T_3119d_row5_col2, #T_3119d_row5_col3, #T_3119d_row5_col4, #T_3119d_row5_col5, #T_3119d_row5_col6, #T_3119d_row5_col7, #T_3119d_row5_col8, #T_3119d_row5_col9, #T_3119d_row6_col0, #T_3119d_row6_col1, #T_3119d_row6_col2, #T_3119d_row6_col3, #T_3119d_row6_col4, #T_3119d_row6_col5, #T_3119d_row6_col6, #T_3119d_row6_col7, #T_3119d_row6_col8, #T_3119d_row6_col9, #T_3119d_row7_col0, #T_3119d_row7_col1, #T_3119d_row7_col2, #T_3119d_row7_col3, #T_3119d_row7_col4, #T_3119d_row7_col5, #T_3119d_row7_col6, #T_3119d_row7_col7, #T_3119d_row7_col8, #T_3119d_row7_col9, #T_3119d_row8_col0, #T_3119d_row8_col1, #T_3119d_row8_col2, #T_3119d_row8_col3, #T_3119d_row8_col4, #T_3119d_row8_col5, #T_3119d_row8_col6, #T_3119d_row8_col7, #T_3119d_row8_col8, #T_3119d_row8_col9, #T_3119d_row9_col0, #T_3119d_row9_col1, #T_3119d_row9_col2, #T_3119d_row9_col3, #T_3119d_row9_col4, #T_3119d_row9_col5, #T_3119d_row9_col6, #T_3119d_row9_col7, #T_3119d_row9_col8, #T_3119d_row9_col9, #T_3119d_row10_col0, #T_3119d_row10_col1, #T_3119d_row10_col2, #T_3119d_row10_col3, #T_3119d_row10_col4, #T_3119d_row10_col5, #T_3119d_row10_col6, #T_3119d_row10_col7, #T_3119d_row10_col8, #T_3119d_row10_col9, #T_3119d_row11_col0, #T_3119d_row11_col1, #T_3119d_row11_col2, #T_3119d_row11_col3, #T_3119d_row11_col4, #T_3119d_row11_col5, #T_3119d_row11_col6, #T_3119d_row11_col7, #T_3119d_row11_col8, #T_3119d_row11_col9 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_3119d">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_3119d_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_3119d_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_3119d_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_3119d_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_3119d_level0_col4" class="col_heading level0 col4" >Mode</th>
#       <th id="T_3119d_level0_col5" class="col_heading level0 col5" >VLAN</th>
#       <th id="T_3119d_level0_col6" class="col_heading level0 col6" >MAC</th>
#       <th id="T_3119d_level0_col7" class="col_heading level0 col7" >Physical Device</th>
#       <th id="T_3119d_level0_col8" class="col_heading level0 col8" >Device</th>
#       <th id="T_3119d_level0_col9" class="col_heading level0 col9" >IP Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3119d_row0_col0" class="data row0 col0" >router1-router_link1-p1</td>
#       <td id="T_3119d_row0_col1" class="data row0 col1" >router1</td>
#       <td id="T_3119d_row0_col2" class="data row0 col2" >router_link1</td>
#       <td id="T_3119d_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_3119d_row0_col4" class="data row0 col4" >auto</td>
#       <td id="T_3119d_row0_col5" class="data row0 col5" ></td>
#       <td id="T_3119d_row0_col6" class="data row0 col6" >06:85:CD:D6:13:B3</td>
#       <td id="T_3119d_row0_col7" class="data row0 col7" >eth1</td>
#       <td id="T_3119d_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_3119d_row0_col9" class="data row0 col9" >192.168.101.1</td>
#     </tr>
#     <tr>
#       <td id="T_3119d_row1_col0" class="data row1 col0" >router1-router_link4-p1</td>
#       <td id="T_3119d_row1_col1" class="data row1 col1" >router1</td>
#       <td id="T_3119d_row1_col2" class="data row1 col2" >router_link4</td>
#       <td id="T_3119d_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_3119d_row1_col4" class="data row1 col4" >auto</td>
#       <td id="T_3119d_row1_col5" class="data row1 col5" ></td>
#       <td id="T_3119d_row1_col6" class="data row1 col6" >0A:12:62:FD:B9:81</td>
#       <td id="T_3119d_row1_col7" class="data row1 col7" >eth2</td>
#       <td id="T_3119d_row1_col8" class="data row1 col8" >eth2</td>
#       <td id="T_3119d_row1_col9" class="data row1 col9" >192.168.104.1</td>
#     </tr>
#     <tr>
#       <td id="T_3119d_row2_col0" class="data row2 col0" >router1-nic_local-p1</td>
#       <td id="T_3119d_row2_col1" class="data row2 col1" >router1</td>
#       <td id="T_3119d_row2_col2" class="data row2 col2" >net_local1</td>
#       <td id="T_3119d_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_3119d_row2_col4" class="data row2 col4" >fablib</td>
#       <td id="T_3119d_row2_col5" class="data row2 col5" ></td>
#       <td id="T_3119d_row2_col6" class="data row2 col6" >0A:A6:98:56:67:38</td>
#       <td id="T_3119d_row2_col7" class="data row2 col7" >eth3</td>
#       <td id="T_3119d_row2_col8" class="data row2 col8" >eth3</td>
#       <td id="T_3119d_row2_col9" class="data row2 col9" >192.168.1.1</td>
#     </tr>
#     <tr>
#       <td id="T_3119d_row3_col0" class="data row3 col0" >router2-router_link1-p1</td>
#       <td id="T_3119d_row3_col1" class="data row3 col1" >router2</td>
#       <td id="T_3119d_row3_col2" class="data row3 col2" >router_link1</td>
#       <td id="T_3119d_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_3119d_row3_col4" class="data row3 col4" >auto</td>
#       <td id="T_3119d_row3_col5" class="data row3 col5" ></td>
#       <td id="T_3119d_row3_col6" class="data row3 col6" >02:4C:BD:CA:16:E8</td>
#       <td id="T_3119d_row3_col7" class="data row3 col7" >eth1</td>
#       <td id="T_3119d_row3_col8" class="data row3 col8" >eth1</td>
#       <td id="T_3119d_row3_col9" class="data row3 col9" >192.168.101.2</td>
#     </tr>
#     <tr>
#       <td id="T_3119d_row4_col0" class="data row4 col0" >router2-nic_local-p1</td>
#       <td id="T_3119d_row4_col1" class="data row4 col1" >router2</td>
#       <td id="T_3119d_row4_col2" class="data row4 col2" >net_local2</td>
#       <td id="T_3119d_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_3119d_row4_col4" class="data row4 col4" >fablib</td>
#       <td id="T_3119d_row4_col5" class="data row4 col5" ></td>
#       <td id="T_3119d_row4_col6" class="data row4 col6" >0E:F0:9C:F6:F3:1D</td>
#       <td id="T_3119d_row4_col7" class="data row4 col7" >eth3</td>
#       <td id="T_3119d_row4_col8" class="data row4 col8" >eth3</td>
#       <td id="T_3119d_row4_col9" class="data row4 col9" >192.168.2.1</td>
#     </tr>
#     <tr>
#       <td id="T_3119d_row5_col0" class="data row5 col0" >router2-router_link2-p1</td>
#       <td id="T_3119d_row5_col1" class="data row5 col1" >router2</td>
#       <td id="T_3119d_row5_col2" class="data row5 col2" >router_link2</td>
#       <td id="T_3119d_row5_col3" class="data row5 col3" >100</td>
#       <td id="T_3119d_row5_col4" class="data row5 col4" >auto</td>
#       <td id="T_3119d_row5_col5" class="data row5 col5" ></td>
#       <td id="T_3119d_row5_col6" class="data row5 col6" >0E:1F:C4:CA:81:4E</td>
# Time to print interfaces 681 seconds

# %% [markdown]
# ## Observe the Slice's Attributes

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.show()
    slice.list_nodes()
    slice.list_networks()
    slice.list_interfaces()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# Pick the subnet for the local networks.  The /24 subnets can support up to 254 locally connected nodes plus the gateway.

# %%
try:
    # Local Subnets
    net_local1_subnet = IPv4Network("192.168.1.0/24")
    net_local1_available_ips = list(net_local1_subnet)[1:]
    net_local1_gateway = net_local1_available_ips.pop(0)
        
    net_local2_subnet = IPv4Network("192.168.2.0/24")
    net_local2_available_ips = list(net_local2_subnet)[1:]
    net_local2_gateway = net_local2_available_ips.pop(0)


    net_local3_subnet = IPv4Network("192.168.3.0/24")
    net_local3_available_ips = list(net_local3_subnet)[1:]
    net_local3_gateway = net_local3_available_ips.pop(0)

    print(f"Site1: subnet: {net_local1_subnet}, gateway: {net_local1_gateway}")
    print(f"Site2: subnet: {net_local2_subnet}, gateway: {net_local2_gateway}")
    print(f"Site3: subnet: {net_local3_subnet}, gateway: {net_local3_gateway}")

except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Configure Router IPs
#
# Add the IPs to the corrisponing interfaces.

# %%
try:
    # Config Router1 IPs
    router1 = slice.get_node(name=router1_name)  
    router1_iface1 = router1.get_interface(network_name=route_link1_name)  
    router1_iface2 = router1.get_interface(network_name=route_link3_name)  
    router1_local_iface = router1.get_interface(network_name=site1_local_net_name)     
    router1_iface1.ip_addr_add(addr=route_link1_addr1, subnet=route_link1_subnet)
    router1_iface2.ip_addr_add(addr=route_link3_addr2, subnet=route_link3_subnet)
    router1_local_iface.ip_addr_add(addr=net_local1_gateway, subnet=net_local1_subnet)
    
    # Config Router2 IPs
    router2 = slice.get_node(name=router2_name)  
    router2_iface1 = router2.get_interface(network_name=route_link2_name)  
    router2_iface2 = router2.get_interface(network_name=route_link1_name)  
    router2_local_iface = router2.get_interface(network_name=site2_local_net_name)     
    router2_iface1.ip_addr_add(addr=route_link2_addr1, subnet=route_link2_subnet)
    router2_iface2.ip_addr_add(addr=route_link1_addr2, subnet=route_link1_subnet)
    router2_local_iface.ip_addr_add(addr=net_local2_gateway, subnet=net_local2_subnet)
    
    # Config Router3 IPs
    router3 = slice.get_node(name=router3_name) 
    router3_iface1 = router3.get_interface(network_name=route_link3_name)  
    router3_iface2 = router3.get_interface(network_name=route_link2_name)  
    router3_local_iface = router3.get_interface(network_name=site3_local_net_name)     
    router3_iface1.ip_addr_add(addr=route_link3_addr1, subnet=route_link3_subnet)
    router3_iface2.ip_addr_add(addr=route_link2_addr2, subnet=route_link2_subnet)
    router3_local_iface.ip_addr_add(addr=net_local3_gateway, subnet=net_local3_subnet)
except Exception as e:
    print(f"Exception: {e}")
    traceback.print_exc()

# %% [markdown]
# (Optional) Print the network interface configuration for each router.

# %%
try:
    for router in [router1, router2, router3]:
        print(f'{router.get_name()}:')
        stdout, stderr = router.execute(f'ip addr list')
except Exception as e:
    print(f"Exception: {e}")
    traceback.print_exc()

# %% [markdown]
# ### Configure Local Node IPs
#
# Configure the local nodes with addresses from the local subnet available address list. Add routes to the other local subnets via the local gateway.
#
# Add the router link subnets if you want to access the routers (i.e. if you want to `ping` the routers or find paths with `tracepath`)
#
# Collect a list of local dataplane IPs to target for testing

# %%
local_dataplane_ips = {}

# %%
try:    
    #Create Site1 Nodes
    for i in range(site_node_count):
        name=f'{node_base_name}_site1_{i+1}'
        node = slice.get_node(name=name)
        node_addr = net_local1_available_ips.pop(0)
        node_iface = node.get_interface(network_name=site1_local_net_name)  
        node_iface.ip_addr_add(addr=node_addr, subnet=net_local1_subnet)
        
        #Add routes to other local subnets
        node.ip_route_add(subnet=net_local2_subnet, gateway=net_local1_gateway)
        node.ip_route_add(subnet=net_local3_subnet, gateway=net_local1_gateway)
        
        #Add routes to router subnets (used for tracepath and pinging router interfaces)
        node.ip_route_add(subnet=route_link1_subnet, gateway=net_local1_gateway)
        node.ip_route_add(subnet=route_link2_subnet, gateway=net_local1_gateway)
        node.ip_route_add(subnet=route_link3_subnet, gateway=net_local1_gateway)
        
        #Collect dataplane IP for testing
        local_dataplane_ips[name] = node_addr
        
        print(f"Node {name} dataplane IP: {node_addr}")    
        stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')
except Exception as e:
    print(f"Exception: {e}")

# %%
try:
    #Create Site2 Nodes
    for i in range(site_node_count):
        name=f'{node_base_name}_site2_{i+1}'
        node = slice.get_node(name=name)
        node_addr = net_local2_available_ips.pop(0)
        node_iface = node.get_interface(network_name=site2_local_net_name)  
        node_iface.ip_addr_add(addr=node_addr, subnet=net_local2_subnet)
        
        #Add routes to other local subnets
        node.ip_route_add(subnet=net_local1_subnet, gateway=net_local2_gateway)
        node.ip_route_add(subnet=net_local3_subnet, gateway=net_local2_gateway)
        
         #Add routes to router subnets (used for tracepath and pinging router interfaces)
        node.ip_route_add(subnet=route_link1_subnet, gateway=net_local2_gateway)
        node.ip_route_add(subnet=route_link2_subnet, gateway=net_local2_gateway)
        node.ip_route_add(subnet=route_link3_subnet, gateway=net_local2_gateway)
        
        #Collect dataplane IP for testing
        local_dataplane_ips[name] = node_addr

        print(f"Node {name} dataplane IP: {node_addr}")
        stdout, stderr = node.execute(f'ip addr list')
        
        stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')
except Exception as e:
    print(f"Exception: {e}")

# %%
try:
    #Create Site3 Nodes
    for i in range(site_node_count):
        name=f'{node_base_name}_site3_{i+1}'
        node = slice.get_node(name=name)
        node_addr = net_local3_available_ips.pop(0)
        node_iface = node.get_interface(network_name=site3_local_net_name)  
        node_iface.ip_addr_add(addr=node_addr, subnet=net_local3_subnet)
        
        #Add routes to other local subnets
        node.ip_route_add(subnet=net_local1_subnet, gateway=net_local3_gateway)
        node.ip_route_add(subnet=net_local2_subnet, gateway=net_local3_gateway)
        
        #Add routes to router subnets (used for tracepath and pinging router interfaces)
        node.ip_route_add(subnet=route_link1_subnet, gateway=net_local3_gateway)
        node.ip_route_add(subnet=route_link2_subnet, gateway=net_local3_gateway)
        node.ip_route_add(subnet=route_link3_subnet, gateway=net_local3_gateway)
        
        #Collect dataplane IP for testing
        local_dataplane_ips[name] = node_addr
        
        print(f"Node {name} dataplane IP: {node_addr}")
        stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')    
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ##  Configure FRRouting on each router.
#
# This complex configuration is handled through a bash script `frr_config.sh` that resides in the folder containing this notebook. The script is executed by, first, uploading the script with the `node.upload_file()` FABLib method.  Then the script is executed using the `node.execute()` FABLib method.  Note that the script passes the OS interfaces names and configured IPs as arguments from the notebook to the script.
#
# These scripts take a while to run. You may wish to use a separate terminal window to ssh to the routers and tail the log file to watch the progress with: `tail -F frr_config.log`.

# %%
import os
for router in routers:
    print(f"{router['name']}")

    fablib_router = slice.get_node(router['name'])
    
    fablib_router.upload_directory(f'{os.environ["HOME"]}/work/docker_containers','.')
    fablib_router.execute(f"cd docker_containers/fabric_frrouting ; docker compose up -d", quiet=True, output_file=f"{fablib_router.get_name()}.log");
# Out:
# router1
# router2
# router3
# router4

# %%
try: 
    #thread1 = execute.thread()
    #stdout, stderr = thread1.result()
    
    # Config Router1
    print('Config Router1')
    router1.upload_file('./frr_config.sh','frr_config.sh')
    router1_config_thread = router1.execute_thread(f'chmod +x frr_config.sh && sudo ./frr_config.sh {router1_iface1.get_os_interface()} {route_link1_addr1} {router1_iface2.get_os_interface()} {route_link3_addr2} {router1_local_iface.get_os_interface()} {net_local1_gateway} 192.168.0.0')

    # Config Router2
    print('Config Router2')
    router2.upload_file('./frr_config.sh','frr_config.sh')   
    router2_config_thread = router2.execute_thread(f'chmod +x frr_config.sh && sudo ./frr_config.sh {router2_iface1.get_os_interface()} {route_link2_addr1} {router2_iface2.get_os_interface()} {route_link1_addr2} {router2_local_iface.get_os_interface()} {net_local2_gateway} 192.168.0.0')
    
    # Config Router3
    print('Config Router3')
    router3.upload_file('./frr_config.sh','frr_config.sh')
    router3_config_thread = router3.execute_thread(f'chmod +x frr_config.sh && sudo ./frr_config.sh {router3_iface1.get_os_interface()} {route_link3_addr1} {router3_iface2.get_os_interface()} {route_link2_addr2} {router3_local_iface.get_os_interface()} {net_local3_gateway} 192.168.0.0')

    #Join Threads
    print(f"Joining Threads")
    stdout, stderr = router1_config_thread.result() 
    print(f"Router1: ", stdout, stderr)
    stdout, stderr = router2_config_thread.result() 
    print(f"Router2: ", stdout, stderr)
    stdout, stderr = router3_config_thread.result() 
    print(f"Router3: ", stdout, stderr)

except Exception as e:
    print(f"Exception: {e}")
    traceback.print_exc()
# Out:
# Config Router1
# Exception: 'dict' object has no attribute 'upload_file'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 7
#       6 print('Config Router1')
# ----> 7 router1.upload_file('./frr_config.sh','frr_config.sh')
#       8 router1_config_thread = router1.execute_thread(f'chmod +x frr_config.sh && sudo ./frr_config.sh {router1_iface1.get_os_interface()} {route_link1_addr1} {router1_iface2.get_os_interface()} {route_link3_addr2} {router1_local_iface.get_os_interface()} {net_local1_gateway} 192.168.0.0')
#
# AttributeError: 'dict' object has no attribute 'upload_file'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 31
#      29 except Exception as e:
#      30     print(f"Exception: {e}")
# ---> 31     traceback.print_exc()
#
# NameError: name 'traceback' is not defined

# %% [markdown]
# ## Run the Experiment
#
# We will just test `ping` RTT and look at `tracepath`. Your experiment should be more interesting!
#
# Notice that if you run this quickly and repeatedly run this test against a specific target, you may see changes to the tracepath.  Initially the ping may even fail.  Why do you think this is happening?

# %%
try:
    source_node_name =  f'{node_base_name}_site1_1'
   
    source_node = slice.get_node(name=source_node_name)
    for node_name,target_ip in local_dataplane_ips.items():
        print(f"Testing target node: {node_name}, target IP: {target_ip}")
    
        stdout, stderr = node.execute(f'ping -c 5 {target_ip}')

        stdout, stderr = node.execute(f'tracepath {target_ip}')
    
except Exception as e:
    print(f"Exception: {e}")

# %%
try:
    slice.save("ospf.graphml")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
