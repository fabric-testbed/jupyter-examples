# %% [markdown]
# # Routing Topology: OSPF using FRRouting
#
# This notebook is an example of how to create a FABRIC routing experiment topology comprising nodes at three different sites. Each site has a local layer 2 (Ethernet) network connecting a set of local nodes and one gateway router. The three gateway routers connect to each other and use the [FRRouting](https://frrouting.org/) protocol suite to deploy [OSPF](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) dameons to propagate route updates across the topology.
#
# You might be familiar with the [Quagga](https://www.quagga.net/) router suite.  FRRouting is based on Quagga but has a more active upstream community including many large companies working on cloud networking.

# %% [markdown]
# ## Import the FABlib Library

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_392ed tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_392ed tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_392ed caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_392ed_row0_col0, #T_392ed_row0_col1, #T_392ed_row1_col0, #T_392ed_row1_col1, #T_392ed_row2_col0, #T_392ed_row2_col1, #T_392ed_row3_col0, #T_392ed_row3_col1, #T_392ed_row4_col0, #T_392ed_row4_col1, #T_392ed_row5_col0, #T_392ed_row5_col1, #T_392ed_row6_col0, #T_392ed_row6_col1, #T_392ed_row7_col0, #T_392ed_row7_col1, #T_392ed_row8_col0, #T_392ed_row8_col1, #T_392ed_row9_col0, #T_392ed_row9_col1, #T_392ed_row10_col0, #T_392ed_row10_col1, #T_392ed_row11_col0, #T_392ed_row11_col1, #T_392ed_row12_col0, #T_392ed_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_392ed">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_392ed_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_392ed_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_392ed_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_392ed_row2_col1" class="data row2 col1" >/home/fabric/work/fabric_config/tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_392ed_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_392ed_row4_col1" class="data row4 col1" >pruth_0031379841</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_392ed_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_392ed_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_392ed_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_392ed_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_392ed_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_392ed_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_392ed_row11_col1" class="data row11 col1" >/home/fabric/work/logs/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_392ed_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_392ed_row12_col1" class="data row12 col1" >DEBUG</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates private layer 2 networks on three sites including OSPF gateway routers that propagate routes across the topology.

# %%
slice_name = 'OSPF_Routing_Topology1'

sites= fablib.get_random_sites(count=3, avoid=[])
print(f"Sites: {sites}")

sites=['DALL','WASH','UTAH']

router_base_name='router'
router_link_base_name='link'

node_base_name='node'
local_network_base_name='net_local'

site_node_count=1


rocky_repo_ip=IPv4Address('10.133.130.2')
# Out:
# Sites: ['TACC', 'GPN', 'DALL']

# %%
slice = fablib.new_slice(name=slice_name)

# Create Routers
routers = []
frr_user_data = {}
for i, site in enumerate(sites):
    router_name = f"{router_base_name}{site}"
    frr_user_data[router_name] = {}
    local_subnet = IPv4Network(f"192.168.{i+1}.0/24")
    local_gateway = local_subnet[1]
    
    # Add control net
    control_net = slice.add_l3network(name=f'control_net_{site}', type='IPv4')
    router = slice.add_node(name=router_name, site=site, cores=16, ram=32, disk=100).enable_docker()
    iface_control = router.add_component(model='NIC_Basic', name='nic_control').get_interfaces()[0]
    control_net.add_interface(iface_control)
    iface_control.set_mode('auto')
    router.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=control_net.get_gateway())
    if rocky_repo_ip:
        router.set_rocky_repo(rocky_repo_ip)


    # Add experiment nets
    iface_local = router.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]
    iface_local.set_mode('fablib')
    
    local_net = slice.add_l2network(name=f'{local_network_base_name}{site}', subnet=local_subnet, gateway=local_gateway)
    local_net.add_interface(iface_local)
    iface_local.set_ip_addr(local_gateway)
    
    frr_user_data[router_name]['local_iface'] = iface_local.get_name()
    frr_user_data[router_name]['link_ifaces'] = []
    
    routers.append(router)

# Create Links between routers (ring)
links = []
for i, site in enumerate(sites):
    link_info = {}
    link_subnet = IPv4Network(f"192.168.10{i+1}.0/24")
    
    router1 = routers[i]
    router2 = routers[(i+1)%len(sites)]
    
    #link_info['name'] = f'{router_link_base_name}{i+1}'
    link_info['name'] = f'{router1.get_site()}-{router2.get_site()}-{router_link_base_name}{i+1}'

    
    link = slice.add_l2network(name=link_info['name'], subnet=link_subnet)
    links.append(link)

    iface1 = router1.add_component(model='NIC_Basic', name=link_info['name']).get_interfaces()[0]
    iface2 = router2.add_component(model='NIC_Basic', name=link_info['name']).get_interfaces()[0]
    
    iface1.set_mode('fablib')
    iface2.set_mode('fablib')
    
    link.add_interface(iface1)
    link.add_interface(iface2)
    
    iface1.set_ip_addr(link_subnet[1])
    iface2.set_ip_addr(link_subnet[2])
        
    frr_user_data[router1.get_name()]['link_ifaces'].append(iface1.get_name()) 
    frr_user_data[router2.get_name()]['link_ifaces'].append(iface2.get_name()) 

# Set frr user_data
for router in slice.get_nodes():
    user_data = router.get_user_data()
    user_data['frr'] = frr_user_data[router.get_name()]
    router.set_user_data(user_data)
    
#slice_id = slice.submit()

# %%
for i, site in enumerate(sites):
    for node_num in range(site_node_count):
        node_name = f"{site.lower()}{node_num+1}"
        node = slice.add_node(name=node_name, site=site, cores=16, ram=32, disk=100).enable_docker()
        
        iface = node.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
        network = slice.get_network(name=f'{local_network_base_name}{site}')
        network.add_interface(iface)
        iface.set_mode('auto')

        node.add_route(subnet=IPv4Network('192.168.0.0/16'), next_hop=network.get_gateway())
        
        # Add control net
        control_net = slice.get_network(f'control_net_{site}')
        iface_control = node.add_component(model='NIC_Basic', name='nic_control').get_interfaces()[0]
        control_net.add_interface(iface_control)
        iface_control.set_mode('auto')
        node.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=control_net.get_gateway())
        if rocky_repo_ip:
            node.set_rocky_repo(rocky_repo_ip)

        
slice.submit()
# Out:
# Retry: 5, Time: 1011 sec
# <style type="text/css">
# #T_44b17 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_44b17 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_44b17 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_44b17_row0_col0, #T_44b17_row0_col1, #T_44b17_row1_col0, #T_44b17_row1_col1, #T_44b17_row2_col0, #T_44b17_row2_col1, #T_44b17_row3_col0, #T_44b17_row3_col1, #T_44b17_row4_col0, #T_44b17_row4_col1, #T_44b17_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_44b17_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_44b17">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_44b17_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_44b17_row0_col1" class="data row0 col1" >d55472a4-e574-4391-9ea1-0c9427ea8686</td>
#     </tr>
#     <tr>
#       <td id="T_44b17_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_44b17_row1_col1" class="data row1 col1" >OSPF_Routing_Topology1</td>
#     </tr>
#     <tr>
#       <td id="T_44b17_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_44b17_row2_col1" class="data row2 col1" >2023-03-03 17:47:34 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_44b17_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_44b17_row3_col1" class="data row3 col1" >2023-03-02 17:47:36 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_44b17_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_44b17_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_44b17_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_44b17_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_59f75 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_59f75 th {
#   text-align: left;
# }
# #T_59f75 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_59f75 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_59f75 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_59f75_row0_col0, #T_59f75_row0_col1, #T_59f75_row0_col2, #T_59f75_row0_col3, #T_59f75_row0_col4, #T_59f75_row0_col5, #T_59f75_row0_col6, #T_59f75_row0_col7, #T_59f75_row0_col8, #T_59f75_row0_col9, #T_59f75_row0_col10, #T_59f75_row0_col13, #T_59f75_row0_col14, #T_59f75_row0_col15, #T_59f75_row1_col0, #T_59f75_row1_col1, #T_59f75_row1_col2, #T_59f75_row1_col3, #T_59f75_row1_col4, #T_59f75_row1_col5, #T_59f75_row1_col6, #T_59f75_row1_col7, #T_59f75_row1_col8, #T_59f75_row1_col9, #T_59f75_row1_col10, #T_59f75_row1_col13, #T_59f75_row1_col14, #T_59f75_row1_col15, #T_59f75_row2_col0, #T_59f75_row2_col1, #T_59f75_row2_col2, #T_59f75_row2_col3, #T_59f75_row2_col4, #T_59f75_row2_col5, #T_59f75_row2_col6, #T_59f75_row2_col7, #T_59f75_row2_col8, #T_59f75_row2_col9, #T_59f75_row2_col10, #T_59f75_row2_col13, #T_59f75_row2_col14, #T_59f75_row2_col15, #T_59f75_row3_col0, #T_59f75_row3_col1, #T_59f75_row3_col2, #T_59f75_row3_col3, #T_59f75_row3_col4, #T_59f75_row3_col5, #T_59f75_row3_col6, #T_59f75_row3_col7, #T_59f75_row3_col8, #T_59f75_row3_col9, #T_59f75_row3_col10, #T_59f75_row3_col13, #T_59f75_row3_col14, #T_59f75_row3_col15, #T_59f75_row4_col0, #T_59f75_row4_col1, #T_59f75_row4_col2, #T_59f75_row4_col3, #T_59f75_row4_col4, #T_59f75_row4_col5, #T_59f75_row4_col6, #T_59f75_row4_col7, #T_59f75_row4_col8, #T_59f75_row4_col9, #T_59f75_row4_col10, #T_59f75_row4_col13, #T_59f75_row4_col14, #T_59f75_row4_col15, #T_59f75_row5_col0, #T_59f75_row5_col1, #T_59f75_row5_col2, #T_59f75_row5_col3, #T_59f75_row5_col4, #T_59f75_row5_col5, #T_59f75_row5_col6, #T_59f75_row5_col7, #T_59f75_row5_col8, #T_59f75_row5_col9, #T_59f75_row5_col10, #T_59f75_row5_col13, #T_59f75_row5_col14, #T_59f75_row5_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_59f75_row0_col11, #T_59f75_row1_col11, #T_59f75_row2_col11, #T_59f75_row3_col11, #T_59f75_row4_col11, #T_59f75_row5_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_59f75_row0_col12, #T_59f75_row1_col12, #T_59f75_row2_col12, #T_59f75_row3_col12, #T_59f75_row4_col12, #T_59f75_row5_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_59f75">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_59f75_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_59f75_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_59f75_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_59f75_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_59f75_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_59f75_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_59f75_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_59f75_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_59f75_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_59f75_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_59f75_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_59f75_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_59f75_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_59f75_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_59f75_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_59f75_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_59f75_row0_col0" class="data row0 col0" >bbcafbde-11d2-4e32-bbc6-62245cf3a2dd</td>
#       <td id="T_59f75_row0_col1" class="data row0 col1" >routerDALL</td>
#       <td id="T_59f75_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_59f75_row0_col3" class="data row0 col3" >32</td>
#       <td id="T_59f75_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_59f75_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_59f75_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_59f75_row0_col7" class="data row0 col7" >dall-w2.fabric-testbed.net</td>
#       <td id="T_59f75_row0_col8" class="data row0 col8" >DALL</td>
#       <td id="T_59f75_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_59f75_row0_col10" class="data row0 col10" >2001:400:a100:3000:f816:3eff:feee:6e99</td>
#       <td id="T_59f75_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_59f75_row0_col12" class="data row0 col12" ></td>
#       <td id="T_59f75_row0_col13" class="data row0 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:feee:6e99</td>
#       <td id="T_59f75_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_59f75_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_59f75_row1_col0" class="data row1 col0" >a51d165d-adae-46b8-af02-f11897089ce9</td>
#       <td id="T_59f75_row1_col1" class="data row1 col1" >routerWASH</td>
#       <td id="T_59f75_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_59f75_row1_col3" class="data row1 col3" >32</td>
#       <td id="T_59f75_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_59f75_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_59f75_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_59f75_row1_col7" class="data row1 col7" >wash-w2.fabric-testbed.net</td>
#       <td id="T_59f75_row1_col8" class="data row1 col8" >WASH</td>
#       <td id="T_59f75_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_59f75_row1_col10" class="data row1 col10" >2001:400:a100:3020:f816:3eff:fe08:e227</td>
#       <td id="T_59f75_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_59f75_row1_col12" class="data row1 col12" ></td>
#       <td id="T_59f75_row1_col13" class="data row1 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3020:f816:3eff:fe08:e227</td>
#       <td id="T_59f75_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_59f75_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_59f75_row2_col0" class="data row2 col0" >c0da2c1c-e0e5-482f-8931-affe216645e8</td>
#       <td id="T_59f75_row2_col1" class="data row2 col1" >routerUTAH</td>
#       <td id="T_59f75_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_59f75_row2_col3" class="data row2 col3" >32</td>
#       <td id="T_59f75_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_59f75_row2_col5" class="data row2 col5" >default_rocky_8</td>
#       <td id="T_59f75_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_59f75_row2_col7" class="data row2 col7" >utah-w3.fabric-testbed.net</td>
#       <td id="T_59f75_row2_col8" class="data row2 col8" >UTAH</td>
#       <td id="T_59f75_row2_col9" class="data row2 col9" >rocky</td>
#       <td id="T_59f75_row2_col10" class="data row2 col10" >2001:1948:417:7:f816:3eff:fea4:39dc</td>
#       <td id="T_59f75_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_59f75_row2_col12" class="data row2 col12" ></td>
#       <td id="T_59f75_row2_col13" class="data row2 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key
# <style type="text/css">
# #T_53ae9 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_53ae9 th {
#   text-align: left;
# }
# #T_53ae9 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_53ae9 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_53ae9 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_53ae9_row0_col0, #T_53ae9_row0_col1, #T_53ae9_row0_col2, #T_53ae9_row0_col3, #T_53ae9_row0_col4, #T_53ae9_row0_col5, #T_53ae9_row0_col6, #T_53ae9_row1_col0, #T_53ae9_row1_col1, #T_53ae9_row1_col2, #T_53ae9_row1_col3, #T_53ae9_row1_col4, #T_53ae9_row1_col5, #T_53ae9_row1_col6, #T_53ae9_row2_col0, #T_53ae9_row2_col1, #T_53ae9_row2_col2, #T_53ae9_row2_col3, #T_53ae9_row2_col4, #T_53ae9_row2_col5, #T_53ae9_row2_col6, #T_53ae9_row3_col0, #T_53ae9_row3_col1, #T_53ae9_row3_col2, #T_53ae9_row3_col3, #T_53ae9_row3_col4, #T_53ae9_row3_col5, #T_53ae9_row3_col6, #T_53ae9_row4_col0, #T_53ae9_row4_col1, #T_53ae9_row4_col2, #T_53ae9_row4_col3, #T_53ae9_row4_col4, #T_53ae9_row4_col5, #T_53ae9_row4_col6, #T_53ae9_row5_col0, #T_53ae9_row5_col1, #T_53ae9_row5_col2, #T_53ae9_row5_col3, #T_53ae9_row5_col4, #T_53ae9_row5_col5, #T_53ae9_row5_col6, #T_53ae9_row6_col0, #T_53ae9_row6_col1, #T_53ae9_row6_col2, #T_53ae9_row6_col3, #T_53ae9_row6_col4, #T_53ae9_row6_col5, #T_53ae9_row6_col6, #T_53ae9_row7_col0, #T_53ae9_row7_col1, #T_53ae9_row7_col2, #T_53ae9_row7_col3, #T_53ae9_row7_col4, #T_53ae9_row7_col5, #T_53ae9_row7_col6, #T_53ae9_row8_col0, #T_53ae9_row8_col1, #T_53ae9_row8_col2, #T_53ae9_row8_col3, #T_53ae9_row8_col4, #T_53ae9_row8_col5, #T_53ae9_row8_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_53ae9_row0_col7, #T_53ae9_row1_col7, #T_53ae9_row2_col7, #T_53ae9_row3_col7, #T_53ae9_row4_col7, #T_53ae9_row5_col7, #T_53ae9_row6_col7, #T_53ae9_row7_col7, #T_53ae9_row8_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_53ae9_row0_col8, #T_53ae9_row1_col8, #T_53ae9_row2_col8, #T_53ae9_row3_col8, #T_53ae9_row4_col8, #T_53ae9_row5_col8, #T_53ae9_row6_col8, #T_53ae9_row7_col8, #T_53ae9_row8_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_53ae9">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_53ae9_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_53ae9_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_53ae9_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_53ae9_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_53ae9_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_53ae9_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_53ae9_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_53ae9_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_53ae9_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_53ae9_row0_col0" class="data row0 col0" >52423b3d-16be-4b16-b30c-a231e2d38b59</td>
#       <td id="T_53ae9_row0_col1" class="data row0 col1" >control_net_DALL</td>
#       <td id="T_53ae9_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_53ae9_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_53ae9_row0_col4" class="data row0 col4" >DALL</td>
#       <td id="T_53ae9_row0_col5" class="data row0 col5" >10.133.132.0/24</td>
#       <td id="T_53ae9_row0_col6" class="data row0 col6" >10.133.132.1</td>
#       <td id="T_53ae9_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_53ae9_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_53ae9_row1_col0" class="data row1 col0" >37cdbe51-88bd-4d86-8b0d-45a17232ebff</td>
#       <td id="T_53ae9_row1_col1" class="data row1 col1" >net_localDALL</td>
#       <td id="T_53ae9_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_53ae9_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_53ae9_row1_col4" class="data row1 col4" >DALL</td>
#       <td id="T_53ae9_row1_col5" class="data row1 col5" >192.168.1.0/24</td>
#       <td id="T_53ae9_row1_col6" class="data row1 col6" >192.168.1.1</td>
#       <td id="T_53ae9_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_53ae9_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_53ae9_row2_col0" class="data row2 col0" >b6a845e0-4bc0-44d4-b555-ba022893ac1c</td>
#       <td id="T_53ae9_row2_col1" class="data row2 col1" >control_net_WASH</td>
#       <td id="T_53ae9_row2_col2" class="data row2 col2" >L3</td>
#       <td id="T_53ae9_row2_col3" class="data row2 col3" >FABNetv4</td>
#       <td id="T_53ae9_row2_col4" class="data row2 col4" >WASH</td>
#       <td id="T_53ae9_row2_col5" class="data row2 col5" >10.133.2.0/24</td>
#       <td id="T_53ae9_row2_col6" class="data row2 col6" >10.133.2.1</td>
#       <td id="T_53ae9_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_53ae9_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_53ae9_row3_col0" class="data row3 col0" >c26ba511-d168-4acb-b975-d35cbd9d555c</td>
#       <td id="T_53ae9_row3_col1" class="data row3 col1" >net_localWASH</td>
#       <td id="T_53ae9_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_53ae9_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_53ae9_row3_col4" class="data row3 col4" >WASH</td>
#       <td id="T_53ae9_row3_col5" class="data row3 col5" >192.168.2.0/24</td>
#       <td id="T_53ae9_row3_col6" class="data row3 col6" >192.168.2.1</td>
#       <td id="T_53ae9_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_53ae9_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_53ae9_row4_col0" class="data row4 col0" >cd1f6c8e-d8eb-43c0-a48b-dc2ab89cbf04</td>
#       <td id="T_53ae9_row4_col1" class="data row4 col1" >control_net_UTAH</td>
#       <td id="T_53ae9_row4_col2" class="data row4 col2" >L3</td>
#       <td id="T_53ae9_row4_col3" class="data row4 col3" >FABNetv4</td>
#       <td id="T_53ae9_row4_col4" class="data row4 col4" >UTAH</td>
#       <td id="T_53ae9_row4_col5" class="data row4 col5" >10.132.1.0/24</td>
#       <td id="T_53ae9_row4_col6" class="data row4 col6" >10.132.1.1</td>
#       <td id="T_53ae9_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_53ae9_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_53ae9_row5_col0" class="data row5 col0" >d39d8d2d-8b3f-4aa7-93cf-97d47c42904d</td>
#       <td id="T_53ae9_row5_col1" class="data row5 col1" >net_localUTAH</td>
#       <td id="T_53ae9_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_53ae9_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_53ae9_row5_col4" class="data row5 col4" >UTAH</td>
#       <td id="T_53ae9_row5_col5" class="data row5 col5" >192.168.3.0/24</td>
#       <td id="T_53ae9_row5_col6" class="data row5 col6" >192.168.3.1</td>
#       <td id="T_53ae9_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_53ae9_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_53ae9_row6_col0" class="data row6 col0" >0f5e609a-d168-44bc-aec7-92c2dabc92db</td>
#       <td id="T_53ae9_row6_col1" class="data row6 col1" >DALL-WASH-link1</td>
#       <td id="T_53ae9_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_53ae9_row6_col3" class="data row6 col3" >L2STS</td>
#       <td id="T_53ae9_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_53ae9_row6_col5" class="data row6 col5" >192.168.101.0/24</td>
#       <td id="T_53ae9_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_53ae9_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_53ae9_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_53ae9_row7_col0" class="data row7 col0" >e0d73e01-34b4-4051-9dd2-eab0974fcf56</td>
# <style type="text/css">
# #T_4695a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_4695a th {
#   text-align: left;
# }
# #T_4695a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4695a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4695a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4695a_row0_col0, #T_4695a_row0_col1, #T_4695a_row0_col2, #T_4695a_row0_col3, #T_4695a_row0_col4, #T_4695a_row0_col5, #T_4695a_row0_col6, #T_4695a_row0_col7, #T_4695a_row0_col8, #T_4695a_row0_col9, #T_4695a_row1_col0, #T_4695a_row1_col1, #T_4695a_row1_col2, #T_4695a_row1_col3, #T_4695a_row1_col4, #T_4695a_row1_col5, #T_4695a_row1_col6, #T_4695a_row1_col7, #T_4695a_row1_col8, #T_4695a_row1_col9, #T_4695a_row2_col0, #T_4695a_row2_col1, #T_4695a_row2_col2, #T_4695a_row2_col3, #T_4695a_row2_col4, #T_4695a_row2_col5, #T_4695a_row2_col6, #T_4695a_row2_col7, #T_4695a_row2_col8, #T_4695a_row2_col9, #T_4695a_row3_col0, #T_4695a_row3_col1, #T_4695a_row3_col2, #T_4695a_row3_col3, #T_4695a_row3_col4, #T_4695a_row3_col5, #T_4695a_row3_col6, #T_4695a_row3_col7, #T_4695a_row3_col8, #T_4695a_row3_col9, #T_4695a_row4_col0, #T_4695a_row4_col1, #T_4695a_row4_col2, #T_4695a_row4_col3, #T_4695a_row4_col4, #T_4695a_row4_col5, #T_4695a_row4_col6, #T_4695a_row4_col7, #T_4695a_row4_col8, #T_4695a_row4_col9, #T_4695a_row5_col0, #T_4695a_row5_col1, #T_4695a_row5_col2, #T_4695a_row5_col3, #T_4695a_row5_col4, #T_4695a_row5_col5, #T_4695a_row5_col6, #T_4695a_row5_col7, #T_4695a_row5_col8, #T_4695a_row5_col9, #T_4695a_row6_col0, #T_4695a_row6_col1, #T_4695a_row6_col2, #T_4695a_row6_col3, #T_4695a_row6_col4, #T_4695a_row6_col5, #T_4695a_row6_col6, #T_4695a_row6_col7, #T_4695a_row6_col8, #T_4695a_row6_col9, #T_4695a_row7_col0, #T_4695a_row7_col1, #T_4695a_row7_col2, #T_4695a_row7_col3, #T_4695a_row7_col4, #T_4695a_row7_col5, #T_4695a_row7_col6, #T_4695a_row7_col7, #T_4695a_row7_col8, #T_4695a_row7_col9, #T_4695a_row8_col0, #T_4695a_row8_col1, #T_4695a_row8_col2, #T_4695a_row8_col3, #T_4695a_row8_col4, #T_4695a_row8_col5, #T_4695a_row8_col6, #T_4695a_row8_col7, #T_4695a_row8_col8, #T_4695a_row8_col9, #T_4695a_row9_col0, #T_4695a_row9_col1, #T_4695a_row9_col2, #T_4695a_row9_col3, #T_4695a_row9_col4, #T_4695a_row9_col5, #T_4695a_row9_col6, #T_4695a_row9_col7, #T_4695a_row9_col8, #T_4695a_row9_col9, #T_4695a_row10_col0, #T_4695a_row10_col1, #T_4695a_row10_col2, #T_4695a_row10_col3, #T_4695a_row10_col4, #T_4695a_row10_col5, #T_4695a_row10_col6, #T_4695a_row10_col7, #T_4695a_row10_col8, #T_4695a_row10_col9, #T_4695a_row11_col0, #T_4695a_row11_col1, #T_4695a_row11_col2, #T_4695a_row11_col3, #T_4695a_row11_col4, #T_4695a_row11_col5, #T_4695a_row11_col6, #T_4695a_row11_col7, #T_4695a_row11_col8, #T_4695a_row11_col9, #T_4695a_row12_col0, #T_4695a_row12_col1, #T_4695a_row12_col2, #T_4695a_row12_col3, #T_4695a_row12_col4, #T_4695a_row12_col5, #T_4695a_row12_col6, #T_4695a_row12_col7, #T_4695a_row12_col8, #T_4695a_row12_col9, #T_4695a_row13_col0, #T_4695a_row13_col1, #T_4695a_row13_col2, #T_4695a_row13_col3, #T_4695a_row13_col4, #T_4695a_row13_col5, #T_4695a_row13_col6, #T_4695a_row13_col7, #T_4695a_row13_col8, #T_4695a_row13_col9, #T_4695a_row14_col0, #T_4695a_row14_col1, #T_4695a_row14_col2, #T_4695a_row14_col3, #T_4695a_row14_col4, #T_4695a_row14_col5, #T_4695a_row14_col6, #T_4695a_row14_col7, #T_4695a_row14_col8, #T_4695a_row14_col9, #T_4695a_row15_col0, #T_4695a_row15_col1, #T_4695a_row15_col2, #T_4695a_row15_col3, #T_4695a_row15_col4, #T_4695a_row15_col5, #T_4695a_row15_col6, #T_4695a_row15_col7, #T_4695a_row15_col8, #T_4695a_row15_col9, #T_4695a_row16_col0, #T_4695a_row16_col1, #T_4695a_row16_col2, #T_4695a_row16_col3, #T_4695a_row16_col4, #T_4695a_row16_col5, #T_4695a_row16_col6, #T_4695a_row16_col7, #T_4695a_row16_col8, #T_4695a_row16_col9, #T_4695a_row17_col0, #T_4695a_row17_col1, #T_4695a_row17_col2, #T_4695a_row17_col3, #T_4695a_row17_col4, #T_4695a_row17_col5, #T_4695a_row17_col6, #T_4695a_row17_col7, #T_4695a_row17_col8, #T_4695a_row17_col9 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_4695a">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_4695a_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_4695a_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_4695a_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_4695a_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_4695a_level0_col4" class="col_heading level0 col4" >Mode</th>
#       <th id="T_4695a_level0_col5" class="col_heading level0 col5" >VLAN</th>
#       <th id="T_4695a_level0_col6" class="col_heading level0 col6" >MAC</th>
#       <th id="T_4695a_level0_col7" class="col_heading level0 col7" >Physical Device</th>
#       <th id="T_4695a_level0_col8" class="col_heading level0 col8" >Device</th>
#       <th id="T_4695a_level0_col9" class="col_heading level0 col9" >IP Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4695a_row0_col0" class="data row0 col0" >routerDALL-UTAH-DALL-link3-p1</td>
#       <td id="T_4695a_row0_col1" class="data row0 col1" >routerDALL</td>
#       <td id="T_4695a_row0_col2" class="data row0 col2" >UTAH-DALL-link3</td>
#       <td id="T_4695a_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_4695a_row0_col4" class="data row0 col4" >fablib</td>
#       <td id="T_4695a_row0_col5" class="data row0 col5" ></td>
#       <td id="T_4695a_row0_col6" class="data row0 col6" >12:9C:F6:96:97:57</td>
#       <td id="T_4695a_row0_col7" class="data row0 col7" >eth2</td>
#       <td id="T_4695a_row0_col8" class="data row0 col8" >eth2</td>
#       <td id="T_4695a_row0_col9" class="data row0 col9" >192.168.103.2</td>
#     </tr>
#     <tr>
#       <td id="T_4695a_row1_col0" class="data row1 col0" >routerDALL-nic_control-p1</td>
#       <td id="T_4695a_row1_col1" class="data row1 col1" >routerDALL</td>
#       <td id="T_4695a_row1_col2" class="data row1 col2" >control_net_DALL</td>
#       <td id="T_4695a_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_4695a_row1_col4" class="data row1 col4" >auto</td>
#       <td id="T_4695a_row1_col5" class="data row1 col5" ></td>
#       <td id="T_4695a_row1_col6" class="data row1 col6" >12:54:D2:91:70:D6</td>
#       <td id="T_4695a_row1_col7" class="data row1 col7" >eth1</td>
#       <td id="T_4695a_row1_col8" class="data row1 col8" >eth1</td>
#       <td id="T_4695a_row1_col9" class="data row1 col9" >10.133.132.3</td>
#     </tr>
#     <tr>
#       <td id="T_4695a_row2_col0" class="data row2 col0" >routerDALL-nic_local-p1</td>
#       <td id="T_4695a_row2_col1" class="data row2 col1" >routerDALL</td>
#       <td id="T_4695a_row2_col2" class="data row2 col2" >net_localDALL</td>
#       <td id="T_4695a_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_4695a_row2_col4" class="data row2 col4" >fablib</td>
#       <td id="T_4695a_row2_col5" class="data row2 col5" ></td>
#       <td id="T_4695a_row2_col6" class="data row2 col6" >12:CE:08:C6:E4:D0</td>
#       <td id="T_4695a_row2_col7" class="data row2 col7" >eth3</td>
#       <td id="T_4695a_row2_col8" class="data row2 col8" >eth3</td>
#       <td id="T_4695a_row2_col9" class="data row2 col9" >192.168.1.1</td>
#     </tr>
#     <tr>
#       <td id="T_4695a_row3_col0" class="data row3 col0" >routerDALL-DALL-WASH-link1-p1</td>
#       <td id="T_4695a_row3_col1" class="data row3 col1" >routerDALL</td>
#       <td id="T_4695a_row3_col2" class="data row3 col2" >DALL-WASH-link1</td>
#       <td id="T_4695a_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_4695a_row3_col4" class="data row3 col4" >fablib</td>
#       <td id="T_4695a_row3_col5" class="data row3 col5" ></td>
#       <td id="T_4695a_row3_col6" class="data row3 col6" >16:76:D8:95:48:68</td>
#       <td id="T_4695a_row3_col7" class="data row3 col7" >eth4</td>
#       <td id="T_4695a_row3_col8" class="data row3 col8" >eth4</td>
#       <td id="T_4695a_row3_col9"
# Time to print interfaces 1039 seconds
# 'd55472a4-e574-4391-9ea1-0c9427ea8686'

# %% [markdown]
# ## Config the Routers

# %%
for node in slice.get_nodes():
    if 'router' in node.get_name():

        print(node.get_name())
        attributes = node.upload_directory('docker_containers','.')
        #attributes = node.upload_directory('node_tools','.')
        
        frr_user_data = node.get_user_data()['frr']
        iface_local = slice.get_interface(frr_user_data['local_iface'])
        iface_link1 = slice.get_interface(frr_user_data['link_ifaces'][0])
        iface_link2 = slice.get_interface(frr_user_data['link_ifaces'][1])
        
        #stdout, stderr = node.execute(f'chmod +x node_tools/frr_config_docker.sh && ./node_tools/frr_config_docker.sh {iface_link1.get_device_name()} {iface_link1.get_ip_addr()} {iface_link2.get_device_name()} {iface_link2.get_ip_addr()} {iface_local.get_device_name()} {iface_local.get_ip_addr()} 192.168.0.0')
        
        devs = ' '.join([iface.get_device_name() for iface in node.get_interfaces()])
        
        print(f"./docker_containers/fabric_frrouting/start.sh {devs}")
        print(f"./docker_containers/fabric_frrouting/node_tools/frr_config_docker.sh {iface_link1.get_device_name()} {iface_link1.get_ip_addr()} {iface_link2.get_device_name()} {iface_link2.get_ip_addr()} {iface_local.get_device_name()} {iface_local.get_ip_addr()} 192.168.0.0")

        node.execute(f"./docker_containers/fabric_frrouting/node_tools/frr_config_docker.sh {iface_link1.get_device_name()} {iface_link1.get_ip_addr()} {iface_link2.get_device_name()} {iface_link2.get_ip_addr()} {iface_local.get_device_name()} {iface_local.get_ip_addr()} 192.168.0.0 ; "
                     f"./docker_containers/fabric_frrouting/start.sh {devs} ; "
                      , quiet=True, output_file=f"{node.get_name()}.log")
# Out:
# routerDALL
# ./docker_containers/fabric_frrouting/start.sh eth2 eth1 eth3 eth4
# ./docker_containers/fabric_frrouting/node_tools/frr_config_docker.sh eth4 192.168.101.1 eth2 192.168.103.2 eth3 192.168.1.1 192.168.0.0
# routerWASH
# ./docker_containers/fabric_frrouting/start.sh eth2 eth1 eth4 eth3
# ./docker_containers/fabric_frrouting/node_tools/frr_config_docker.sh eth2 192.168.101.2 eth4 192.168.102.1 eth1 192.168.2.1 192.168.0.0
# routerUTAH
# ./docker_containers/fabric_frrouting/start.sh eth1 eth3 eth4 eth2
# ./docker_containers/fabric_frrouting/node_tools/frr_config_docker.sh eth1 192.168.102.2 eth2 192.168.103.1 eth3 192.168.3.1 192.168.0.0

# %% [markdown]
# ## Config the Nodes

# %%
for node in slice.get_nodes():
    if 'router' not in node.get_name():
        print(node.get_name())
        attributes = node.upload_directory('docker_containers','.')
        #attributes = node.upload_directory('node_tools','.')
        
        devs = ' '.join([iface.get_device_name() for iface in node.get_interfaces()])
        node.execute(f"cd ~/docker_containers/fabric_multitool/; docker compose up -d ; "
                     f"docker exec fabric sudo ./tools/host_tune_redhat.sh ; "
                     #f"./start.sh {devs} ; "
                      , quiet=True, output_file=f"{node.get_name()}.log")
# Out:
# dall1
# wash1
# utah1

# %% [markdown]
# ## Run the Experiment
#
# We will just test `ping` RTT and look at `tracepath`. Your experiment should be more interesting!
#
# Notice that if you run this quickly and repeatedly run this test against a specific target, you may see changes to the tracepath.  Initially the ping may even fail.  Why do you think this is happening?

# %%
try:
    source_node_name =  f'{node_base_name}_site1_1'
   
    source_node = slice.get_node(name=source_node_name)
    for node_name,target_ip in local_dataplane_ips.items():
        print(f"Testing target node: {node_name}, target IP: {target_ip}")
    
        stdout, stderr = node.execute(f'ping -c 5 {target_ip}')

        stdout, stderr = node.execute(f'tracepath {target_ip}')
    
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
