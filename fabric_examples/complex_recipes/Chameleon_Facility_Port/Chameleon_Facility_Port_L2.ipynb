# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Chameleon Facility Ports: Layer 2 Stitching
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to connect FABRIC and [Chameleon](https://www.chameleoncloud.org/) testbeds using a **Layer 2 facility port**. You will create a stitched network where a FABRIC VM and Chameleon bare-metal servers share an isolated Ethernet segment, enabling direct low-level communication between the two testbeds.
#
# </div>
#
# <img src="./figs/stitching_triangle.png" width="60%"><br>
#
# Experimental topologies, like the one above, can connect multiple computational testbeds to a large instrument, or even your institution, with dedicated high-bandwidth network links and smart in-network processing.

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Configure the **Chameleon Python API** within a FABRIC Jupyter environment
# 2. Reserve a Chameleon **stitchable network** with the `fabric` stitch provider
# 3. Extract the **VLAN tag** from the Chameleon reservation for FABRIC stitching
# 4. Create a FABRIC slice with a **facility port** connected to Chameleon
# 5. Configure matching **Layer 2 subnets** on both testbeds
# 6. Verify end-to-end **connectivity** between FABRIC VMs and Chameleon bare-metal servers
# 7. Properly **clean up** resources on both testbeds
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../fablib_api/configure_environment/configure_environment.ipynb) notebook for FABRIC
# 2. Have an active **Chameleon account** with a project allocation at TACC or UC
# 3. Have a **Chameleon CLI password** (see [Chameleon CLI Authentication](https://chameleoncloud.readthedocs.io/en/latest/technical/cli.html#cli-authentication))
# 4. Have a Chameleon **openrc file** for the TACC site (see [OpenStack RC Script](https://chameleoncloud.readthedocs.io/en/latest/technical/cli.html#the-openstack-rc-script))
# 5. Have an active **Chameleon server reservation** and an SSH key uploaded to Chameleon
#
# **Tip:** Put your Chameleon openrc file in your `fabric_config` folder with your FABRIC keys. Then reference it with a full path.
#
# **Tip:** This notebook creates resources on **both** FABRIC and Chameleon. Make sure to run the cleanup cells at the end to avoid leaving orphaned resources on either testbed.
#
# </div>

# %% [markdown]
# ## Background: What is a Facility Port?
#
# A **facility port** is a dedicated physical connection between FABRIC and an external facility (like Chameleon, a campus network, or a scientific instrument). Unlike regular Internet connections, facility ports provide:
#
# - **Dedicated bandwidth** -- not shared with other traffic
# - **Low-level access** -- Layer 2 (Ethernet) connectivity for custom protocols
# - **VLAN-based isolation** -- each stitched connection gets its own VLAN
#
#
# **How stitching works:**
# 1. Chameleon reserves a network with `stitch_provider = 'fabric'` and gets a VLAN tag
# 2. FABRIC creates a facility port using that same VLAN tag
# 3. Both sides configure matching IP subnets
# 4. Traffic flows directly over the dedicated Layer 2 circuit

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a FABRIC node connected to Chameleon via a Layer 2 facility port.
#
# <img src="./figs/slice_topology.png" width="50%">

# %% [markdown]
# ---
#
# ## Step 1: Configure Chameleon Environment
#
# Set your Chameleon credentials as environment variables. You can either set them directly in the cell below, or load them from your openrc file.
#
# <div class="fab-danger">
#
# **Important:** Never commit your credentials to version control. Use the `load_dotenv` method (shown in the next cell) to keep your password out of the notebook.
#
# </div>

# %%
import os

# Set your Chameleon credentials
# Replace <username> and <password> with your actual Chameleon credentials
os.environ["OS_USERNAME"]='<username>'
os.environ["OS_PASSWORD"]='<password>'

# Chameleon UC (Chicago) authentication endpoint
os.environ["OS_AUTH_URL"]='https://chi.uc.chameleoncloud.org:5000/v3'
os.environ["OS_IDENTITY_API_VERSION"]='3'
os.environ["OS_INTERFACE"]='public'
os.environ["OS_PROTOCOL"]="openid"
os.environ["OS_AUTH_TYPE"]="v3oidcpassword"
os.environ["OS_IDENTITY_PROVIDER"]="chameleon"
os.environ["OS_DISCOVERY_ENDPOINT"]="https://auth.chameleoncloud.org/auth/realms/chameleon/.well-known/openid-configuration"
os.environ["OS_CLIENT_ID"]="keystone-uc-prod"
os.environ["OS_ACCESS_TOKEN_TYPE"]="access_token"
os.environ["OS_CLIENT_SECRET"]="none"
os.environ["OS_REGION_NAME"]="CHI@UC"

# %% [markdown]
# Alternatively, load credentials from your openrc file using `load_dotenv`. This keeps your password out of the notebook.
#
# <div class="fab-warning">
#
# **Tip:** Put your Chameleon openrc file in your fabric_config folder with your FABRIC keys. Then reference it here with a full path: `f'{os.environ["HOME"]}/work/fabric_config/chameleon-openrc-tacc.sh'`
#
# </div>

# %%
from dotenv import load_dotenv
import os

# Load the environment variables from your openrc file
load_dotenv(f'chameleon-openrc-tacc.sh');

# %% [markdown]
# ## Step 2: Import Libraries
#
# Import both the Chameleon and FABRIC Python libraries. Both are pre-installed in the FABRIC JupyterHub.

# %%
# General imports
import os
import json
import traceback
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
from datetime import datetime, timedelta
from dateutil import tz
import time

# Chameleon Library -- provides OpenStack-based API for bare-metal provisioning
import chi
import chi.lease 
from chi.server import *
from chi.lease import *
from chi.network import *

# FABRIC Library -- provides FABlib API for FABRIC testbed interaction
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# %% [markdown]
# ## Step 3: Define Experiment Variables
#
# ### Chameleon Variables
#
# Define naming conventions for Chameleon resources. Prefix names with your username to avoid conflicts with other users.
#
# <div class="fab-danger">
#
# **Important:** You must replace `<Your_Chameleon_Key>` and `<Your_Chameleon_Server_Reservation>` with your actual Chameleon SSH key name and server reservation ID.
#
# </div>

# %%
# Chameleon Config -- prefix all resource names with your username
chameleon_prefix =  f'{os.environ["OS_USERNAME"]}_fabric_stitch_l2'
chameleon_server_name = chameleon_prefix+'_server'
chameleon_network_name = chameleon_prefix+'_net'
chameleon_subnet_name = chameleon_prefix+'_subnet'
chameleon_router_name = chameleon_prefix+'_router'
chameleon_lease_name = chameleon_prefix+'_lease'

chameleon_image_name='CC-Ubuntu20.04'  # Chameleon bare-metal OS image
chameleon_server_count=1               # Number of Chameleon servers to create

# REPLACE these with your actual Chameleon SSH key name and server reservation ID
chameleon_key_name='<Your_Chameleon_Key>'
chameleon_server_reservation_id = '<Your_Chameleon_Server_Reservation>'

# %% [markdown]
# ### FABRIC Variables
#
# Configure the FABRIC side. We use the TACC facility port which connects to Chameleon at TACC. A Chicago (StarLight) option is also available.

# %%
# Create a FABlib manager and verify configuration
fablib = fablib_manager()
fablib.show_config()

# TACC facility port -- connects to Chameleon at TACC
fabric_site='TACC'
fabric_slice_name="chameleon_tacc_stitch_l2"
faciliy_port='Chameleon-TACC'

# OR Chicago facility port -- connects to Chameleon at StarLight
#fabric_site='STAR'
#fabric_slice_name="chameleon_chicagostitch_l2"
#faciliy_port='Chameleon-StarLight'

# %% [markdown]
# ### Network Configuration
#
# Define the shared subnet that both FABRIC and Chameleon will use. The IP address space is split so that each testbed gets its own range within the same /24 subnet.

# %%
# Shared subnet for the L2 stitched network
subnet = IPv4Network("192.168.100.0/24")

# FABRIC IP pool: 192.168.100.200 - 192.168.100.250
fabric_allocation_pool_start=IPv4Address('192.168.100.200')
fabric_allocation_pool_end=IPv4Address('192.168.100.250')
fabric_available_ips=[]
for ip_int in range(int(fabric_allocation_pool_start),int(fabric_allocation_pool_end)+1):
    fabric_available_ips.append(IPv4Address(ip_int))
    
# Chameleon IP pool: 192.168.100.100 - 192.168.100.150
chameleon_allocation_pool_start='192.168.100.100'
chameleon_allocation_pool_end='192.168.100.150'
chameleon_gateway_ip='192.168.100.1'  # Gateway for the Chameleon subnet

# %% [markdown]
# ---
#
# ## Step 4: Create the Chameleon Network
#
# Reserve a Chameleon network with the `fabric` stitch provider. This tells Chameleon to create a VLAN that can be stitched to FABRIC.
#
# The lease reserves the network resource for 24 hours.

# %%
BLAZAR_TIME_FORMAT = '%Y-%m-%d %H:%M'

# Set start/end date for lease
# Start one minute into future to avoid Blazar thinking lease is in past
# due to rounding to closest minute.
start_date = (datetime.now(tz=tz.tzutc()) + timedelta(minutes=1)).strftime(BLAZAR_TIME_FORMAT)
end_date   = (datetime.now(tz=tz.tzutc()) + timedelta(days=1)).strftime(BLAZAR_TIME_FORMAT)

# Build list of reservations (in this case there is only one reservation)
reservation_list = []
reservation_list.append(
        {
            "resource_type": "network",
            "network_name": chameleon_network_name,
            "network_properties": "",
            "resource_properties": json.dumps(
                ["==", "$stitch_provider", 'fabric']  # Request a FABRIC-stitchable network
            ),
        }
)

# Create the lease
chameleon_lease = chi.lease.create_lease(chameleon_lease_name,
                                  reservations=reservation_list,
                                  start_date=start_date,
                                  end_date=end_date)
    
# Extract the network reservation ID
chameleon_network_reservation_id = [reservation for reservation in chameleon_lease['reservations'] if reservation['resource_type'] == 'network'][0]['id']
print(f"chameleon_network_reservation_id: {chameleon_network_reservation_id}")

# %% [markdown]
# ### Get the Network and VLAN Tag
#
# Wait for the Chameleon network to become active, then extract the **VLAN tag**. This VLAN tag is the critical piece that links the Chameleon and FABRIC sides of the stitch.

# %%
# Poll until the network is active and we can read the VLAN tag
network_vlan = None
while network_vlan == None:
    try:
        # Get the network object from Chameleon
        chameleon_network = chi.network.get_network(chameleon_network_name)

        # Get the network ID
        chameleon_network_id = chameleon_network['id']
        print(f'Chameleon Network ID: {chameleon_network_id}')

        # Get the VLAN tag -- this is needed for FABRIC facility port stitching
        network_vlan = chameleon_network['provider:segmentation_id']
        print(f'network_vlan: {network_vlan}')
    except:
        print(f'Chameleon Network is not ready. Trying again!')
        time.sleep(10)

# %% [markdown]
# ### Add a Subnet to the Chameleon Network

# %%
# Create the subnet on the Chameleon side with the specified IP pool
chameleon_subnet = chi.network.create_subnet(chameleon_subnet_name, chameleon_network_id, 
                                             cidr=str(subnet),
                                             allocation_pool_start=chameleon_allocation_pool_start,
                                             allocation_pool_end=chameleon_allocation_pool_end,
                                             gateway_ip=chameleon_gateway_ip)

print(f"subnet name  : {chameleon_subnet['name']}")
print(f"subnet       : {chameleon_subnet['cidr']}")
print(f"gateway_ip   : {chameleon_subnet['gateway_ip']}")

# %% [markdown]
# ### Add a Router
#
# Add a router connected to Chameleon's public network and attach it to the subnet. This enables external access to Chameleon servers if needed.

# %%
# Create a router with a gateway to Chameleon's public network
chameleon_router = chi.network.create_router(chameleon_router_name, gw_network_name='public')

print(f"router name  : {chameleon_router['name']}")

# Attach the subnet to the router
connection_port = chi.network.add_subnet_to_router_by_name(chameleon_router_name, chameleon_subnet_name)

print(f"connection_port id  : {connection_port['port_id']}")

# %% [markdown]
# ---
#
# ## Step 5: Create the FABRIC Slice with Facility Port
#
# Now create the FABRIC side of the stitch. The key element is the **facility port** which uses the same VLAN tag as the Chameleon network. Both the FABRIC node and the facility port are connected to the same L2 network.

# %%
# Create a FABRIC slice
fabric_slice = fablib.new_slice(name=fabric_slice_name)

# Create a Layer 2 network with the shared subnet
net1 = fabric_slice.add_l2network(name='net1', subnet=subnet)

# Add a FABRIC node with a NIC_Basic interface
fabric_node = fabric_slice.add_node(name='Node1', site=fabric_site)
fabric_node_iface = fabric_node.add_component(model='NIC_Basic', name=f"nic1").get_interfaces()[0]
fabric_node_iface.set_mode('config')  # Manual IP configuration
net1.add_interface(fabric_node_iface)
fabric_node_iface.set_ip_addr(fabric_available_ips.pop(0))  # Assign first available IP
    
# Add the Facility Port using the VLAN from Chameleon
# This is the bridge between FABRIC and Chameleon
fabric_facility_port = fabric_slice.add_facility_port(name=faciliy_port, site=fabric_site, vlan=str(network_vlan))
fabric_facility_port_iface = fabric_facility_port.get_interfaces()[0]
fabric_facility_port_iface.set_mode('manual')  # No IP -- it's just an L2 bridge
net1.add_interface(fabric_facility_port_iface)

# Submit the FABRIC slice
fabric_slice.submit()

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC created a VM at the TACC site, connected it to an L2 network along with a facility port that bridges to the Chameleon VLAN. The FABRIC VM and any Chameleon servers on that VLAN can now communicate directly at Layer 2.
#
# </div>

# %% [markdown]
# ### (Optional) Test the Facility Port Link
#
# Test connectivity by pinging the Chameleon gateway IP from the FABRIC VM.

# %%
try:
    fabric_node = fabric_slice.get_node(name='Node1')     
    fabric_node_iface = fabric_node.get_interface(network_name=f'net1') 

    # Ping the Chameleon gateway to verify L2 connectivity
    stdout, stderr = fabric_node.execute(f'ping -c 5 {chameleon_gateway_ip}')
    
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Step 6: Start Chameleon Servers
#
# Launch bare-metal servers on Chameleon connected to the stitched network. These servers will take 10-20 minutes to become active.

# %%
# Create Chameleon bare-metal servers on the stitched network
servers = []

for i in range(chameleon_server_count):
    server_name=f"{chameleon_server_name}_{i+1}"
    # Create the server with the specified reservation, network, and image
    servers.append(chi.server.create_server(server_name, 
                                  reservation_id=chameleon_server_reservation_id, 
                                  network_name=chameleon_network_name, 
                                  image_name=chameleon_image_name,
                                  key_name=chameleon_key_name
                                 ))
    
# Wait until all servers are active (10-20 minutes for bare-metal)
for server in servers:
    print(f'Waiting for server: {server.name}')
    chi.server.wait_for_active(server.id)
print('Done!')

# %% [markdown]
# ### Get Chameleon Server IP Addresses

# %%
# Retrieve the fixed (private) IP address of each Chameleon server
fixed_ips={}
for i in range(chameleon_server_count):
    server_name=f"{chameleon_server_name}_{i+1}"
    server_id = get_server_id(server_name)
    fixed_ip = get_server(server_id).interface_list()[0].to_dict()["fixed_ips"][0]["ip_address"]
    fixed_ips[server_name]=fixed_ip

for server_name,fixed_ip in fixed_ips.items():
    print(f'{server_name}: {fixed_ip}')

# %% [markdown]
# ---
#
# ## Step 7: Test End-to-End Connectivity
#
# Ping the Chameleon servers from the FABRIC VM to verify that the Layer 2 stitch is working.

# %%
# Ping each Chameleon server from the FABRIC node
fabric_node = fabric_slice.get_node(name='Node1')     

for server_name,fixed_ip in fixed_ips.items():
    print(f'{server_name}: {fixed_ip}')
    
    stdout, stderr = fabric_node.execute(f'ping -c 5 {fixed_ip}')

# %% [markdown]
# <div class="fab-success">
#
# **Success!** If the pings succeed, you have a working Layer 2 connection between FABRIC and Chameleon. You can now run experiments that span both testbeds.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 8: Clean Up Resources
#
# <div class="fab-danger">
#
# **Important:** You must clean up resources on **both** testbeds. Chameleon bare-metal resources are especially scarce. Delete all resources in the correct order: servers first, then networking, then the lease.
#
# </div>
#
# ### Delete Chameleon Servers

# %%
# Delete all Chameleon servers
for i in range(chameleon_server_count):
    server_name=f"{chameleon_server_name}_{i+1}"
    chi.server.delete_server(get_server_id(server_name))

# %% [markdown]
# ### De-configure Chameleon Network

# %%
# Remove the Chameleon network resources in reverse order
router_id = chameleon_router['id']
subnet_id = chameleon_subnet['id']

try:
    result = chi.network.remove_subnet_from_router(router_id, subnet_id)
except Exception as e:
    print(f"detach_router_by_name error: {str(e)}")
    pass

try:
    result = chi.network.delete_router(router_id)
except Exception as e:
    print(f"delete_router_by_name error: {str(e)}")
    pass

try:
    result = chi.network.delete_subnet(subnet_id)
except Exception as e:
    print(f"delete_subnet_by_name error: {str(e)}")
    pass

try:
    result = chi.network.delete_network(network_id)
except Exception as e:
    print(f"delete_network_by_name error: {str(e)}")
    pass

# %% [markdown]
# ### Release Chameleon Lease

# %%
# Release the Chameleon network lease
chi.lease.delete_lease(chameleon_lease['id'])

# %% [markdown]
# ### Delete FABRIC Slice

# %%
# Delete the FABRIC slice and release all resources
try:
    fabric_slice.delete()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | Chameleon authentication fails | Wrong CLI password or expired token | Regenerate your CLI password on the Chameleon portal |
# | Network lease fails | No stitchable networks available | Wait and retry, or check Chameleon portal for availability |
# | VLAN tag not appearing | Network reservation still pending | Wait for the Chameleon network to become Active |
# | FABRIC facility port fails | Invalid VLAN tag or port unavailable | Verify the VLAN tag and ensure the facility port name is correct |
# | Ping to Chameleon gateway fails | Subnet mismatch or routing issue | Verify both sides use the same subnet and gateway IP |
# | Ping to Chameleon servers fails | Server not yet on the network | Wait for the Chameleon server to fully boot (10-20 min for bare metal) |
# | `get_server_id` fails | Server name mismatch | Check the exact server name in the Chameleon Horizon dashboard |
# | Cleanup fails | Resources already deleted or dependency order wrong | Delete servers before networks, networks before leases |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_l2network()` | Add a Layer 2 network to the slice | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `slice.add_node()` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component()` | Add a NIC or other component to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `slice.add_facility_port()` | Add a facility port to connect to external networks | [add_facility_port](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_facility_port) |
# | `interface.set_mode()` | Set interface configuration mode (auto/config/manual) | [set_mode](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_mode) |
# | `interface.set_ip_addr()` | Assign an IP address to an interface | [set_ip_addr](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_ip_addr) |
# | `node.execute()` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you understand Layer 2 facility port stitching, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Chameleon L3 Stitch** | [Chameleon FABnetv4](./Chameleon_Facility_Port_fabnetv4.ipynb) | Connect Chameleon to FABRIC's Layer 3 FABnetv4 network for multi-site routing |
# | **L2 Networking** | [Create L2 Network](../../fablib_api/create_l2network/create_l2network.ipynb) | Learn the fundamentals of Layer 2 networking on FABRIC |
# | **Network Performance** | [iPerf3 Optimized](../iPerf3/iperf3_optimized.ipynb) | Measure and optimize throughput with CPU pinning and NUMA tuning |
# | **One-Way Latency** | [OWL Measurements](../owl/owl.ipynb) | Measure one-way latency using PTP-synchronized clocks |
