# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Tailscale Mesh VPN on FABRIC
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to use [Tailscale](https://tailscale.com/), a zero-configuration mesh VPN, to create a secure overlay network across your FABRIC slice nodes. With Tailscale, you can SSH directly to your FABRIC VMs from your laptop, access web services, and transfer files -- all without going through the FABRIC bastion host.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Create a **Tailscale auth key** and use it to enroll FABRIC VMs into your personal mesh VPN
# 2. Automate Tailscale installation using **post-boot tasks** during slice creation
# 3. **SSH directly** to FABRIC VMs from your laptop via the Tailscale network
# 4. Deploy and access **web services** (Apache, Filebrowser) on FABRIC VMs through Tailscale
# 5. Properly **log out** VMs from Tailscale before deleting a slice to avoid stale entries
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be familiar with creating basic FABRIC slices (see [Hello FABRIC](../../fablib_api/hello_fabric/hello_fabric.ipynb))
# 3. **Install [Tailscale](https://tailscale.com/download)** on your laptop/workstation
# 4. Have a Tailscale account (free tier is sufficient)
# 5. Create a **Tailscale auth key** in your [admin console](https://login.tailscale.com/admin/settings/keys) -- it must be both **Reusable** and **Ephemeral**
#
# **Tip:** Ephemeral keys cause devices to be automatically removed from your Tailscale network when they go offline for an extended period, which is ideal for temporary FABRIC VMs.
#
# </div>

# %% [markdown]
# ## Background: What is Tailscale?
#
# [Tailscale](https://tailscale.com/) is a mesh VPN built on top of [WireGuard](https://www.wireguard.com/). It creates a secure, encrypted overlay network between all your devices without requiring any special network configuration, port forwarding, or firewall rules.
#
# Watch this video for more details: [Tailscale Overview](https://www.youtube.com/watch?v=oklvRBmEL4s&t=2s)
#
# ### Why Use Tailscale with FABRIC?
#
# Normally, accessing FABRIC VMs requires SSH through a **bastion host**, which adds complexity. With Tailscale:
#
# - **Direct SSH access**: Connect to your VMs by name (e.g., `ssh ubuntu@renc1`) without bastion hops
# - **Web service access**: Browse to `http://<node_name>:port` directly from your browser
# - **File transfer**: Use SCP, rsync, or a Filebrowser UI without tunneling
# - **Mesh connectivity**: All your enrolled devices (laptop + FABRIC VMs) can communicate directly
#
#
# <img src="./figs/mesh_vpn.png" width="30%"><br>

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create multiple nodes forming a Tailscale mesh VPN across FABRIC sites.
#
# <img src="./figs/slice_topology.png" width="50%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance
fablib = fablib_manager()

# Display current configuration (tokens, keys, project info)
fablib.show_config();

# %% [markdown]
# ## Step 2: Create the Experiment Slice
#
# We create a slice with nodes at **four random FABRIC sites**. Each node is enrolled into your Tailscale mesh VPN during the post-boot phase.
#
# ### 2a: Set Your Tailscale Auth Key
#
# First, create a Tailscale auth key in your [admin console](https://login.tailscale.com/admin/settings/keys). Make sure the key is both **Reusable** and **Ephemeral**.
#
# <img src="./figs/authkey.png" width="40%"><br>
#
# <div class="fab-danger">
#
# **Important:** Replace the placeholder auth key below with your actual Tailscale auth key. Do **not** share this key or commit it to version control.
#
# </div>

# %%
# REQUIRED CHANGE!!!
# Replace this with your Tailscale auth key from https://login.tailscale.com/admin/settings/keys
ts_key='tskey-auth-abcdefghijklCNTRL-abcdefghijklmnopqrstuvwxyz123456'

# %% [markdown]
# ### 2b: Select Random Sites
#
# Pick four random FABRIC sites to demonstrate that Tailscale works across geographically distributed nodes.

# %%
# Select 4 random FABRIC sites
sites=fablib.get_random_sites(count=4)

print(sites)

# %% [markdown]
# ### 2c: Create the Slice with Tailscale Post-Boot Tasks
#
# For each node, we add post-boot tasks that:
# 1. Upload and run `enable_docker.sh` (for optional Docker-based services like Filebrowser)
# 2. Install Tailscale using the official install script
# 3. Bring Tailscale up with your auth key
#
# <div class="fab-warning">
#
# **Tip:** The `add_fabnet()` call gives each node a FABnet IPv4 address for FABRIC-internal communication, while Tailscale provides an additional overlay network that includes your laptop.
#
# </div>

# %%
# Create a new slice
slice = fablib.new_slice(name="Tailscale_Mesh_VPN")

# Add a node at each of the 4 selected sites
for site in sites:
    node = slice.add_node(name=f"{site}1",
                          site=site,
                          image="default_ubuntu_22" )
    
    # Connect to FABnet IPv4 for FABRIC-internal L3 routing
    node.add_fabnet(net_type="IPv4", nic_type='NIC_Basic')

    # Upload and enable Docker (needed for Filebrowser in Step 3c)
    # Note: Tailscale itself does NOT require Docker
    node.add_post_boot_upload_directory('node_tools','.')
    node.add_post_boot_execute(f'node_tools/enable_docker.sh {node.get_image()}')
    
    # Install Tailscale and join the mesh VPN using your auth key
    node.add_post_boot_execute(f'curl -fsSL https://tailscale.com/install.sh | sh ;'
                                f'sudo tailscale up --authkey {ts_key}')


# Submit the slice and wait for provisioning
slice.submit();

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC provisioned VMs at four sites, configured FABnet networking, enabled Docker, installed Tailscale, and enrolled each VM into your personal mesh VPN. Check your [Tailscale admin console](https://login.tailscale.com/admin/machines) to see the new machines.
#
# </div>

# %% [markdown]
# ## Step 3: Run the Experiments
#
# ### Step 3a: SSH Directly from Your Laptop
#
# With Tailscale running on both your laptop and the FABRIC VMs, you can SSH directly without the bastion host:
#
# ```bash
# ssh -i /path/to/your/slice_key ubuntu@<node_name>
# ```
#
# The `<node_name>` is the Tailscale hostname, which matches the FABRIC node name (e.g., `renc1`). You can find the exact names in your [Tailscale admin console](https://login.tailscale.com/admin/machines).
#
# ### Step 3b: Install and Visit a Web Server
#
# Install Apache on each node and access it directly from your browser via Tailscale.

# %%
# Install Apache web server on all nodes
commands = ["sudo apt-get update",
            "sudo apt-get install -y apache2",
            "sudo systemctl start apache2",
            "sudo systemctl enable apache2"
           ]

for node in slice.get_nodes():
    print(f"Installing Apache on {node.get_name()}")
    for command in commands:
        print(f"   {command}")
        node.execute(command, quiet = True, output_file=f"{node.get_name()}.log")

# %%
# Create a custom webpage and configure the firewall on each node
for node in slice.get_nodes():
    print(f"Configuring Website on {node.get_name()}")
    
    # Create a simple HTML page identifying the node
    node.execute(f"echo 'Hello from {node.get_name()}! (Accessed through Tailscale!)' | sudo tee /var/www/html/index.html > /dev/null", 
                 quiet = True, 
                 output_file=f"{node.get_name()}.log")
    
    # Allow Apache through the firewall
    node.execute("sudo ufw allow 'Apache'", quiet = True, output_file=f"{node.get_name()}.log")
    node.execute("sudo ufw reload", quiet = True, output_file=f"{node.get_name()}.log")   
    
    # Print the URL you can visit from your laptop's browser
    print(f"url: http://{node.get_name()}")

# %% [markdown]
# ### Step 3c: Run a Filebrowser and Transfer Files
#
# [Filebrowser](https://filebrowser.org/) is a web-based file management service that runs in a Docker container. It allows you to browse, upload, and download files to/from your FABRIC VMs using a drag-and-drop interface.
#
# - Access each Filebrowser at `http://<node_name>:8989` from your laptop
# - Default credentials: `admin` / `admin`
#
# <div class="fab-danger">
#
# **Important:** This Filebrowser instance is also accessible from the FABnet data plane. If your VM uses FABnet, other FABRIC users could potentially access your Filebrowser. For real experiments, change the default password or use another authentication method.
#
# </div>

# %%
# Start a Filebrowser Docker container on each node
for node in slice.get_nodes():
    print(f"Start Filebrowser on {node.get_name()}")
    
    # Upload the Docker Compose file for Filebrowser
    node.upload_directory("filebrowser",".") 
    
    # Start the Filebrowser container in detached mode
    node.execute("cd filebrowser && docker compose up -d", quiet = True, output_file=f"{node.get_name()}.log")
    
    print(f"url: http://{node.get_name()}:8989")

# %% [markdown]
# ## Step 4: Log Out of Tailscale and Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always log each VM out of Tailscale **before** deleting the slice. If you skip this step, Tailscale will keep the stale VMs in your network until they time out (which can take a long time). If you reuse the same node names, Tailscale will assign modified names to the new VMs, causing confusion.
#
# </div>

# %%
# Log each VM out of Tailscale, then delete the slice
for node in slice.get_nodes():
     print(f'{node.get_name()}')
     stdout, stderr = node.execute(f'sudo tailscale logout')
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | `tailscale up` fails with auth error | Auth key expired or invalid | Generate a new key in your [Tailscale admin console](https://login.tailscale.com/admin/settings/keys); ensure it is Reusable and Ephemeral |
# | Cannot SSH to VM via Tailscale hostname | Tailscale not running on your laptop | Start Tailscale on your laptop and ensure it is connected |
# | VM appears with a modified name (e.g., `renc1-1`) | Previous VM with same name was not logged out | Log out the old entry in the Tailscale admin console; use unique node names |
# | Web service not accessible via browser | Firewall blocking the port | Run `sudo ufw allow <port>` on the target VM |
# | `docker: command not found` | Docker not enabled on the node | Run `node_tools/enable_docker.sh` manually on the affected node |
# | Filebrowser shows login page but default password fails | Password was changed or container restarted | Restart the container: `cd filebrowser && docker compose down && docker compose up -d` |
# | Node not appearing in Tailscale admin console | Post-boot task may have failed | SSH to the node via bastion and manually run: `curl -fsSL https://tailscale.com/install.sh \| sh && sudo tailscale up --authkey <key>` |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_sites(count)` | Select random available FABRIC sites | [get_random_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_sites) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_node(...)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_fabnet(net_type, nic_type)` | Attach node to FABnet L3 network | [add_fabnet](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_fabnet) |
# | `node.add_post_boot_upload_directory()` | Upload a directory after boot | [add_post_boot_upload_directory](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_post_boot_upload_directory) |
# | `node.add_post_boot_execute()` | Execute a command after boot | [add_post_boot_execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_post_boot_execute) |
# | `slice.submit()` | Submit the slice for provisioning | [submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `node.upload_directory(local, remote)` | Upload a local directory to a node | [upload_directory](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.upload_directory) |
# | `slice.get_nodes()` | Get all node objects in the slice | [get_nodes](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.get_nodes) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you have set up Tailscale mesh VPN, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Kubernetes on FABRIC** | [kubernetes_simple](../kubernetes/kubernetes_simple.ipynb) | Deploy a K8s cluster and access services through SSH tunnels |
# | **iPerf3 Bandwidth Testing** | [iperf3](../iPerf3/iperf3.ipynb) | Measure network bandwidth between FABRIC sites |
# | **OSPF Routing** | [frr_ospf_triangle](../FRRouting/frr_ospf_triangle.ipynb) | Deploy software routers across a multi-site topology |
# | **Docker Containers** | [docker_containers](../../fablib_api/docker_containers/docker_containers.ipynb) | Run containerized workloads on FABRIC nodes |
# | **Post Boot Tasks** | [post_boot_task_templates](../../fablib_api/post_boot_task_templates/post_boot_task_templates.ipynb) | Advanced automation with templated post-boot variables |
