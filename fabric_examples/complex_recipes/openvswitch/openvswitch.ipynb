# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Deploying Open vSwitch (OVS) on FABRIC
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to deploy **Open vSwitch (OVS)**, an open-source multi-layer virtual switch, on the FABRIC testbed. You will create a topology with a bridge node connecting two host VMs, configure an OVS bridge with Spanning Tree Protocol (STP), assign IP addresses, and verify connectivity with a ping test.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Design a FABRIC topology with a dedicated **bridge node** and multiple **host nodes**
# 2. Install and configure **Open vSwitch** on a FABRIC VM
# 3. Create an OVS bridge and add physical interfaces as ports
# 4. Enable **Spanning Tree Protocol (STP)** on an OVS bridge
# 5. Configure IP addresses on host nodes and verify Layer 2 connectivity through the bridge
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be familiar with creating basic FABRIC slices (see [Hello FABRIC](../../fablib_api/hello_fabric/hello_fabric.ipynb))
# 3. Have basic familiarity with Linux networking concepts (bridges, interfaces, IP addressing)
#
# **Tip:** This notebook places the bridge and host nodes on specific hosts within a single FABRIC site. This is required due to NIC_Basic constraints explained below.
#
# </div>

# %% [markdown]
# ## Background: What is Open vSwitch?
#
# [Open vSwitch (OVS)](https://www.openvswitch.org/) is an open-source, production-quality, multi-layer virtual switch. It is a critical component of many virtualization platforms and software-defined networking (SDN) solutions. OVS supports:
#
# - **Standard switching protocols**: VLANs, STP, LACP
# - **OpenFlow**: For SDN-based flow programming
# - **Tunneling**: GRE, VXLAN, Geneve
# - **Quality of Service (QoS)**: Traffic shaping and policing
#
# ### Topology Overview
#
# In this example, we create a simple topology with one **bridge node** running OVS and two **host nodes** connected through the bridge:
#
#
# The OVS bridge (`br0`) learns MAC addresses and forwards Ethernet frames between the two host nodes, just like a physical switch.
#
# ### Host Placement Constraints
#
# <div class="fab-danger">
#
# **Important:** When using `NIC_Basic` for an OVS bridge experiment, the bridge VM **must** be on a different physical host than the VMs connected to the bridge. This is a constraint imposed by NVIDIA/Mellanox SR-IOV. This constraint does **not** apply to `NIC_ConnectX_5` or `NIC_ConnectX_6` configurations.
#
# </div>

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create an OVS bridge node connecting two host nodes via L2 networks.
#
# <img src="./figs/slice_topology.png" width="50%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration
#
# Start by importing the FABlib library and the Python `ipaddress` module for IP address manipulation.

# %%
from ipaddress import ip_address, IPv4Address, IPv4Network
import ipaddress
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance and verify configuration
fablib = fablib_manager()
fablib.show_config();

# %% [markdown]
# ## Step 2: Define Slice Parameters
#
# Select a random FABRIC site and define the topology parameters. We need:
# - **1 bridge node**: Runs OVS with two NICs (one per host connection)
# - **2 host nodes**: End hosts that communicate through the bridge

# %%
# Slice and topology configuration
slice_name= "MySlice-openvswitch"

# Select one random site (all nodes will be at the same site)
sites = [site1] = fablib.get_random_sites(count=1)
print(f"Sites: {sites}")

# Number of host nodes to connect to the bridge
site_node_count = 2
bridge1_name = 'bridge1'

# %% [markdown]
# ## Step 3: Build the Topology
#
# ### 3a: Create the Slice and Add the Bridge Node
#
# The bridge node needs **two NIC_Basic** interfaces -- one for each L2 network connecting to a host. We place it on a specific physical host (`-w1`) to satisfy the placement constraint.

# %%
# Create a new empty slice
slice = fablib.new_slice(name=slice_name)
default_image= 'default_ubuntu_22'

# %%
# Add the bridge node on host -w1 (separate from host nodes)
# Two NICs are needed: one connection per host
bridge1 = slice.add_node(name=bridge1_name, site=site1, cores=4, ram=8, disk=50, image=default_image, host=f"{site1.lower()}-w1.fabric-testbed.net")
bridge1_nic1 = bridge1.add_component(model='NIC_Basic', name='nic_local_1')  # Will connect to Host1
bridge1_nic2 = bridge1.add_component(model='NIC_Basic', name='nic_local_2')  # Will connect to Host2

# %% [markdown]
# ### 3b: Add Host Nodes
#
# Each host node gets one NIC connected to its own L2 network. The other end of each L2 network connects to one of the bridge's interfaces.
#
# <div class="fab-warning">
#
# **Tip:** Host nodes are placed on a different physical host (`-w2`) than the bridge to satisfy the NIC_Basic constraint. They can share the same host with each other.
#
# </div>

# %%
# Add host nodes on a different physical host (-w2) than the bridge
i = 0
print(f"Adding nodes to {site1}")
for node_num in range(site_node_count):
    node_name = f"{site1.lower()}{node_num+1}"

    # Create the host node on host -w2
    node = slice.add_node(name=node_name, site=site1, cores=4, ram=8, disk=50, image=default_image, host=f"{site1.lower()}-w2.fabric-testbed.net")
    
    # Add a NIC to the host
    iface = node.add_component(model='NIC_Basic', name='nic_local').get_interfaces()[0]    
    
    # Create an L2 network connecting this host to the bridge
    net = slice.add_l2network(name=f"net{node_num}")
    net.add_interface(iface)                    # Host side of the link
    net.add_interface(bridge1.get_interfaces()[i])  # Bridge side of the link
    i += 1

# %% [markdown]
# ### 3c: Submit the Slice
#
# <img src="./figs/openvswitch-single.png" width="60%"><br>
#
# Submit the slice request to FABRIC for provisioning.

# %%
# Submit and wait for provisioning (~5-10 minutes)
slice.submit();

# %% [markdown]
# ## Step 4: Install and Configure Open vSwitch
#
# ### 4a: Install OVS on the Bridge Node
#
# We install the `openvswitch-switch` and `openvswitch-common` packages, along with `net-tools` for interface inspection.

# %%
# Install OVS and net-tools on all bridge nodes
try:
    for node in slice.get_nodes():
        if node.get_name().startswith("bridge"):
            # Update package lists and install OVS
            stdout, stderr = node.execute('yes | sudo apt-get -y update && sudo apt-get upgrade', quiet=True) 
            stdout, stderr = node.execute('yes | sudo apt-get -y install openvswitch-switch openvswitch-common', quiet=True)
            stdout, stderr = node.execute('sudo apt-get -y install net-tools', quiet=True)
            print(f"done bridge: {node.get_name()}")
    print("Done")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### 4b: Create the OVS Bridge and Add Ports
#
# Now we create an OVS bridge named `br0` and add both physical interfaces as ports. This makes the bridge act as a Layer 2 switch connecting the two hosts.
#
# Key steps:
# 1. **`ovs-vsctl add-br br0`** -- Create the bridge
# 2. **`ovs-vsctl add-port br0 <interface>`** -- Add each NIC as a bridge port
# 3. **Remove IP addresses** from the physical interfaces (the bridge handles forwarding, not the interfaces)
# 4. **Bring the bridge interface up**

# %%
# Get a reference to the bridge node
bridge1 = slice.get_node(name=bridge1_name)

# Create the OVS bridge
stdout, stderr = bridge1.execute('sudo ovs-vsctl add-br br0')

# Add each physical interface as a port on the bridge
for interface in bridge1.get_interfaces():
    # Add the interface to the bridge
    stdout, stderr = bridge1.execute(f'sudo ovs-vsctl add-port br0 {interface.get_physical_os_interface_name()}')
    # Remove any IP address from the physical interface (bridge handles L2 forwarding)
    stdout, stderr = bridge1.execute(f'sudo ifconfig {interface.get_physical_os_interface_name()} 0')
    
# Bring the bridge interface up
stdout, stderr = bridge1.execute('sudo ifconfig br0 up')

print("Done")

# %% [markdown]
# ### 4c: Enable Spanning Tree Protocol (STP)
#
# STP prevents Layer 2 loops in more complex topologies. While not strictly necessary for this simple two-host topology, enabling it demonstrates best practice for larger OVS deployments.

# %%
# Enable STP on the bridge
stdout, stderr = bridge1.execute('sudo ovs-vsctl set bridge br0 stp_enable=true')

# %%
# Verify STP status -- should show the bridge and its ports with STP roles
stdout, stderr = bridge1.execute('sudo ovs-appctl stp/show')

# %% [markdown]
# ## Step 5: Configure the Host Nodes
#
# Now we configure IP addresses on each host's interface so they can communicate through the OVS bridge. Both hosts are placed on the same `10.10.10.0/24` subnet.
#
# | Host | IP Address |
# |------|------------|
# | Host1 | 10.10.10.1/24 |
# | Host2 | 10.10.10.2/24 |

# %%
# Get references to the host nodes
host1 = slice.get_node(name=f'{site1.lower()}1')
host2 = slice.get_node(name=f'{site1.lower()}2')

# %%
# Install net-tools on both hosts for ifconfig/netstat
stdout, stderr = host1.execute('sudo apt-get -y install net-tools', quiet=True)
stdout, stderr = host2.execute('sudo apt-get -y install net-tools', quiet=True)

# %%
# Bring the data plane interfaces up on both hosts
stdout, stderr = host1.execute(f'sudo ip link set dev {host1.get_interfaces()[0].get_physical_os_interface_name()} up', quiet=True)
stdout, stderr = host2.execute(f'sudo ip link set dev {host2.get_interfaces()[0].get_physical_os_interface_name()} up', quiet=True)

# %%
# Assign IP addresses to the host interfaces
stdout, stderr = host1.execute(f'sudo ip addr add 10.10.10.1/24 dev {host1.get_interfaces()[0].get_physical_os_interface_name()}', quiet=True)
stdout, stderr = host2.execute(f'sudo ip addr add 10.10.10.2/24 dev {host2.get_interfaces()[0].get_physical_os_interface_name()}', quiet=True)

# %% [markdown]
# ## Step 6: Verify Connectivity with a Ping Test
#
# If everything is configured correctly, Host1 should be able to ping Host2 through the OVS bridge.
#
# <div class="fab-warning">
#
# **Tip:** If the first ping fails, wait a few seconds and retry. STP may still be converging and blocking ports temporarily (the default STP forward delay is 15 seconds).
#
# </div>

# %%
# Ping Host2 from Host1 through the OVS bridge
stdout, stderr = host1.execute('ping 10.10.10.2 -c 5')

# %% [markdown]
# <div class="fab-success">
#
# **Success!** If you see ping replies, the OVS bridge is correctly forwarding traffic between the two hosts. The round-trip times should be very low (sub-millisecond) since both hosts are at the same FABRIC site.
#
# </div>

# %% [markdown]
# ## Step 7: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. FABRIC is a shared resource -- leaving slices running prevents other researchers from using those resources.
#
# </div>

# %%
# Clean up: delete the slice and release all resources
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | Ping fails between hosts | STP still converging (ports in blocking state) | Wait 30 seconds for STP to converge, then retry |
# | `ovs-vsctl: command not found` | OVS not installed | Re-run the installation cell; check for package manager errors |
# | Bridge node and host on same physical host | NIC_Basic SR-IOV constraint | Ensure the bridge is on `-w1` and hosts are on `-w2` (or use NIC_ConnectX_5/6) |
# | `RTNETLINK answers: File exists` when adding IP | IP address already assigned | Run `sudo ip addr flush dev <interface>` first, then re-add |
# | Interface not found on bridge node | Wrong interface name | Use `bridge1.get_interfaces()` to list available interfaces and their OS names |
# | Slice provisioning fails | Site may be at capacity | Delete and recreate with a different site |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_sites(count)` | Select random available FABRIC sites | [get_random_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_sites) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_node(...)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component(model, name)` | Add a NIC or other component to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `slice.add_l2network(name)` | Create a Layer 2 network | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `network.add_interface(iface)` | Connect an interface to a network | [add_interface](https://fabric-fablib.readthedocs.io/en/latest/network_service.html#fabrictestbed_extensions.fablib.network_service.NetworkService.add_interface) |
# | `slice.submit()` | Submit the slice for provisioning | [submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit) |
# | `slice.get_node(name)` | Get a node object by name | [get_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.get_node) |
# | `node.get_interfaces()` | List all interfaces on a node | [get_interfaces](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.get_interfaces) |
# | `interface.get_physical_os_interface_name()` | Get the Linux device name of an interface | [get_physical_os_interface_name](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.get_physical_os_interface_name) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you have deployed a basic OVS bridge, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **OSPF Routing with FRRouting** | [frr_ospf_triangle](../FRRouting/frr_ospf_triangle.ipynb) | Deploy software routers with OSPF across a triangle topology |
# | **iPerf3 Bandwidth Testing** | [iperf3](../iPerf3/iperf3.ipynb) | Measure network bandwidth between FABRIC nodes |
# | **P4 Programmable Switches** | [P4 BMv2](../P4_bmv2/P4_bmv2.ipynb) | Program custom packet processing pipelines |
# | **L2 Networks** | [create_l2network](../../fablib_api/create_l2network_basic/create_l2network_basic.ipynb) | Create Layer 2 Ethernet networks on FABRIC |
# | **Kubernetes on FABRIC** | [kubernetes_simple](../kubernetes/kubernetes_simple.ipynb) | Deploy a Kubernetes cluster with custom networking |
