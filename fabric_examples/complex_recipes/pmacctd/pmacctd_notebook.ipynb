# %%
# Pilar Fernández Gayol
# Illinois Institute of Technology 
# ETS Ingenieros Informáticos, Universidad Politecnica de Madrid

# %% [markdown]
# <h1 style="font-size: 3em;">Integration and Tutorial of pmacctd Toolset on FABRIC Testbed</h1>

# %% [markdown]
# #  Introduction
# The FABRIC testbed is a central hub for large-scale networking experimentation and research, offering a platform for exploring innovative networking technologies. pmacct, a set of open-source passive monitoring tools by Paolo Lucente, is widely used for network traffic monitoring. Integrating pmacct into FABRIC enhances its monitoring capabilities, enabling real-time traffic analysis in an advanced research setting.
#
# This project leverages multiple technologies to develop and execute experiments, integrating pmacct into FABRIC to advance network monitoring and experimentation. The goal is to provide real-world tools and settings for computer science and engineering students to explore and innovate in networking.
#
# > Throughout this notebook we will show the integration of pmacctd in FABRIC, we will perform several experiments that show the multiple capabilities offered by this tool.
#
# <div style="text-align: center;">
#     <img src="./images/1.png" width="350px" alt="pmacctd integration on a FABRIC node"/>
# </div>

# %% [markdown]
# # Setup and Installation
#
# This section includes the necessary installations and configurations required to run the subsequent code. It ensures that all dependencies and environments are correctly set up.

# %% [markdown]
# ## Creation of the slice
#
# For this experiments we are going to create a slice named "pmacctd_slice" with two nodes (n1 and n2), each with specified resources, connected by a layer 2 network (L2Bridge). The architecture enables experimentation with network configurations and monitoring.
#
# Each node uses an Ubuntu 20.04 image, which allows the installation of the pmacctd tool on it. It also provides a robust and flexible operating system for experimenting with different network configurations and monitoring setups.
#
# <div style="text-align: center;">
#     <img src="./images/2.png" width="400px"/>
# </div>

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Initialize the FABRIC library manager
fablib = fablib_manager()

# Define the slice and node names
slice_name = "pmacctd_slice"
n1_name = "n1"
n2_name = "n2"

# Try to find an existing slice with the given name
slice = None
for slice_candidate in fablib.get_slices():
    if slice_candidate.get_name() == slice_name:
        slice = slice_candidate
        break

# If the slice does not exist, create a new one
if None == slice:
    image = 'default_ubuntu_20'
    site = fablib.get_random_sites(count=1)[0]
    slice = fablib.new_slice(name=slice_name)

    # Add the first node to the slice with specified resources
    n1 = slice.add_node(name=n1_name, image=image, cores=2, ram=4, disk=50, site=site)
    n1_iface1 = n1.add_component(model="NIC_Basic", name="iface1").get_interfaces()[0]

    # Add the second node to the slice with specified resources
    n2 = slice.add_node(name=n2_name, image=image, cores=2, ram=4, disk=50, site=site)
    n2_iface1 = n2.add_component(model="NIC_Basic", name="iface1").get_interfaces()[0]

    # Create a layer 2 network connecting both nodes
    net = slice.add_l2network(name="net", interfaces=[n1_iface1, n2_iface1], type="L2Bridge")
    slice.submit()

# Retrieve the nodes from the slice
n1 = slice.get_node(name=n1_name)
n2 = slice.get_node(name=n2_name)

# Display the slice information
slice.show()
# Out:
# <style type="text/css">
# #T_5f473 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5f473 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5f473 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_5f473_row0_col0, #T_5f473_row0_col1, #T_5f473_row1_col0, #T_5f473_row1_col1, #T_5f473_row2_col0, #T_5f473_row2_col1, #T_5f473_row3_col0, #T_5f473_row3_col1, #T_5f473_row4_col0, #T_5f473_row4_col1, #T_5f473_row5_col0, #T_5f473_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5f473">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f473_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_5f473_row0_col1" class="data row0 col1" >ee639505-2555-443c-a5f8-0c3a15891d31</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_5f473_row1_col1" class="data row1 col1" >pmacctd_slice</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_5f473_row2_col1" class="data row2 col1" >2024-07-18 08:47:24 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_5f473_row3_col1" class="data row3 col1" >2024-07-04 08:47:26 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_5f473_row4_col1" class="data row4 col1" >6bd91382-d009-4f0b-8269-158816ee381d</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_5f473_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5f473 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5f473 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5f473 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_5f473_row0_col0, #T_5f473_row0_col1, #T_5f473_row1_col0, #T_5f473_row1_col1, #T_5f473_row2_col0, #T_5f473_row2_col1, #T_5f473_row3_col0, #T_5f473_row3_col1, #T_5f473_row4_col0, #T_5f473_row4_col1, #T_5f473_row5_col0, #T_5f473_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5f473">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f473_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_5f473_row0_col1" class="data row0 col1" >ee639505-2555-443c-a5f8-0c3a15891d31</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_5f473_row1_col1" class="data row1 col1" >pmacctd_slice</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_5f473_row2_col1" class="data row2 col1" >2024-07-18 08:47:24 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_5f473_row3_col1" class="data row3 col1" >2024-07-04 08:47:26 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_5f473_row4_col1" class="data row4 col1" >6bd91382-d009-4f0b-8269-158816ee381d</td>
#     </tr>
#     <tr>
#       <td id="T_5f473_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_5f473_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Configuration of the slice

# %% [markdown]
# ##### Installing Essential Development and Network Tools on FABRIC Nodes
#
# The following code updates the package lists and installs essential development tools (build-essential), network utilities (net-tools), and the Python Scapy library (python3-scapy) on the two nodes (n1 and n2).
# These tools are necessary for compiling software, managing network configurations, and manipulating network packets, preparing the nodes for network experiments and monitoring tasks of pmacctd.

# %%
n1.execute("sudo apt update -y -qq && sudo apt install -y build-essential && sudo apt install -y net-tools && sudo apt install -y python3-scapy")
n2.execute("sudo apt update -y -qq && sudo apt install -y build-essential && sudo apt install -y net-tools && sudo apt install -y python3-scapy")
# Out:
# 36 packages can be upgraded. Run 'apt list --upgradable' to see them.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# build-essential is already the newest version (12.8ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
#
# WARNING: apt does not have a stable CLI interface.   Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-scapy is already the newest version (2.4.3-4).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
# 36 packages can be upgraded. Run 'apt list --upgradable' to see them.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# build-essential is already the newest version (12.8ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
#
#   WARNING: apt does not have a stable CLI interface.   Use with caution in scripts.
#  Reading package lists...
#
# Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
#
#   WARNING: apt does not have a stable CLI interface.   Use with caution in scripts.
#  Reading package lists...
#
# Building dependency tree...
# Reading state information...
# python3-scapy is already the newest version (2.4.3-4).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
# ("36 packages can be upgraded. Run 'apt list --upgradable' to see them.\nReading package lists...\nBuilding dependency tree...\nReading state information...\nbuild-essential is already the newest version (12.8ubuntu1.1).\n0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.\nReading package lists...\nBuilding dependency tree...\nReading state information...\nnet-tools is already the newest version (1.60+git20180626.aebd88e-1ubuntu1).\n0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.\nReading package lists...\nBuilding dependency tree...\nReading state information...\npython3-scapy is already the newest version (2.4.3-4).\n0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.\n",
#  '\nWARNING: apt does not have a stable CLI interface. Use with caution in scripts.\n\n\nWARNING: apt does not have a stable CLI interface. Use with caution in scripts.\n\n\nWARNING: apt does not have a stable CLI interface. Use with caution in scripts.\n\n\nWARNING: apt does not have a stable CLI interface. Use with caution in scripts.\n\n')

# %% [markdown]
# ##### Testing SSH Connectivity and Retrieving Commands for FABRIC Nodes
#
# This code tests the SSH connectivity on the two nodes (n1 and n2), printing whether SSH works on each node.
# It also retrieves and prints the SSH command for connecting to each node, these commands can be pasted on a terminal to gain access to the node ubuntu terminal for each node.
#
# If the result is False, an error has occurred during the creation of the slice; please delete it and try to create it again.

# %%
print("ssh works on n1: " + str(n1.test_ssh()))
print(n1.get_ssh_command())

print("ssh works on n2: " + str(n2.test_ssh()))
print(n2.get_ssh_command())
# Out:
# ssh works on n1: True
# ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3000:f816:3eff:febc:8269
# ssh works on n2: True
# ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3000:f816:3eff:feb1:d79f

# %% [markdown]
# ##### Displaying Network Interfaces on FABRIC Nodes
#
# This code prints the network configuration of two nodes (n1 and n2) by executing the ifconfig command on each node.

# %%
# Management vs Experiment interfaces.
print("ifconfig n1:")
n1.execute("ifconfig")
print("ifconfig n2:")
n2.execute("ifconfig")
# Out:
# ifconfig n1:
# enp3s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#         inet 10.30.6.165  netmask 255.255.254.0  broadcast 10.30.7.255
#         inet6 fe80::f816:3eff:febc:8269  prefixlen 64  scopeid 0x20<link>
#         inet6 2001:400:a100:3000:f816:3eff:febc:8269  prefixlen 64  scopeid 0x0<global>
#         ether fa:16:3e:bc:82:69  txqueuelen 1000  (Ethernet)
#         RX packets 650664  bytes 475685911 (475.6 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 108623  bytes 16304050 (16.3 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# enp7s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet6 fd3f:f209:c712::1  prefixlen 48  scopeid 0x0<global>
#         inet6 fe80::48d:91ff:fed1:234f  prefixlen 64  scopeid 0x20<link>
#         ether 06:8d:91:d1:23:4f  txqueuelen 1000  (Ethernet)
#         RX packets 26229097  bytes 39681313769 (39.6 GB)
#         RX errors 0  dropped 2073  overruns 0  frame 0
#         TX packets 280828  bytes 24170549 (24.1 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 131966  bytes 36734314 (36.7 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 131966  bytes 36734314 (36.7 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# ifconfig n2:
# enp3s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000
#         inet 10.30.6.20  netmask 255.255.254.0  broadcast 10.30.7.255
#         inet6 fe80::f816:3eff:feb1:d79f  prefixlen 64  scopeid 0x20<link>
#         inet6 2001:400:a100:3000:f816:3eff:feb1:d79f  prefixlen 64  scopeid 0x0<global>
#         ether fa:16:3e:b1:d7:9f  txqueuelen 1000  (Ethernet)
#         RX packets 629599  bytes 463579420 (463.5 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 88886  bytes 10270452 (10.2 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# enp7s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet6 fd3f:f209:c712::2  prefixlen 48  scopeid 0x0<global>
#         inet6 fe80::820:c4ff:fe71:4439  prefixlen 64  scopeid 0x20<link>
#         ether 0a:20:c4:71:44:39  txqueuelen 1000  (Ethernet)
#         RX packets 280579  bytes 24152207 (24.1 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 26231417  bytes 39684470493 (39.6 GB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 1388  bytes 142894 (142.8 KB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 1388  bytes 142894 (142.8 KB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
# ('enp3s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 9000\n        inet 10.30.6.20  netmask 255.255.254.0  broadcast 10.30.7.255\n        inet6 fe80::f816:3eff:feb1:d79f  prefixlen 64  scopeid 0x20<link>\n        inet6 2001:400:a100:3000:f816:3eff:feb1:d79f  prefixlen 64  scopeid 0x0<global>\n        ether fa:16:3e:b1:d7:9f  txqueuelen 1000  (Ethernet)\n        RX packets 629599  bytes 463579420 (463.5 MB)\n        RX errors 0  dropped 0  overruns 0  frame 0\n        TX packets 88886  bytes 10270452 (10.2 MB)\n        TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0\n\nenp7s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500\n        inet6 fd3f:f209:c712::2  prefixlen 48  scopeid 0x0<global>\n        inet6 fe80::820:c4ff:fe71:4439  prefixlen 64  scopeid 0x20<link>\n        ether 0a:20:c4:71:44:39  txqueuelen 1000  (Ethernet)\n        RX packets 280579  bytes 24152207 (24.1 MB)\n        RX errors 0  dropped 0  overruns 0  frame 0\n        TX packets 26231417  bytes 39684470493 (39.6 GB)\n        TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0\n\nlo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536\n        inet 127.0.0.1  netmask 255.0.0.0\n        inet6 ::1  prefixlen 128  scopeid 0x10<host>\n        loop  txqueuelen 1000  (Local Loopback)\n        RX packets 1388  bytes 142894 (142.8 KB)\n        RX errors 0  dropped 0  overruns 0  frame 0\n        TX packets 1388  bytes 142894 (142.8 KB)\n        TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0\n\n',
#  '')

# %% [markdown]
# ##### Configuring IPv6 Addresses on the Nodes
# This code configures IPv6 addresses for the interfaces on the two nodes (n1 and n2). It assigns local IPv6 addresses and then displays the interface configurations.

# %%
from ipaddress import IPv6Address, IPv6Network

n1_iface1 = n1.get_interface(name = "n1-iface1-p1")
n2_iface1 = n2.get_interface(name = "n2-iface1-p1")

n1_iface1.ip_addr_add(addr = IPv6Address("fd3f:f209:c712::1"), subnet = IPv6Network("fd3f:f209:c712::/48"))
n2_iface1.ip_addr_add(addr = IPv6Address("fd3f:f209:c712::2"), subnet = IPv6Network("fd3f:f209:c712::/48"))
n1_iface1.show()
n2_iface1.show()
# Out:
# <style type="text/css">
# #T_71914 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_71914 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_71914 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_71914_row0_col0, #T_71914_row0_col1, #T_71914_row1_col0, #T_71914_row1_col1, #T_71914_row2_col0, #T_71914_row2_col1, #T_71914_row3_col0, #T_71914_row3_col1, #T_71914_row4_col0, #T_71914_row4_col1, #T_71914_row5_col0, #T_71914_row5_col1, #T_71914_row6_col0, #T_71914_row6_col1, #T_71914_row7_col0, #T_71914_row7_col1, #T_71914_row8_col0, #T_71914_row8_col1, #T_71914_row9_col0, #T_71914_row9_col1, #T_71914_row10_col0, #T_71914_row10_col1, #T_71914_row11_col0, #T_71914_row11_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_71914">
#   <caption>Interface</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_71914_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_71914_row0_col1" class="data row0 col1" >n1-iface1-p1</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row1_col0" class="data row1 col0" >Short Name</td>
#       <td id="T_71914_row1_col1" class="data row1 col1" >p1</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row2_col0" class="data row2 col0" >Node</td>
#       <td id="T_71914_row2_col1" class="data row2 col1" >n1</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row3_col0" class="data row3 col0" >Network</td>
#       <td id="T_71914_row3_col1" class="data row3 col1" >net</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row4_col0" class="data row4 col0" >Bandwidth</td>
#       <td id="T_71914_row4_col1" class="data row4 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row5_col0" class="data row5 col0" >Mode</td>
#       <td id="T_71914_row5_col1" class="data row5 col1" >config</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row6_col0" class="data row6 col0" >VLAN</td>
#       <td id="T_71914_row6_col1" class="data row6 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_71914_row7_col0" class="data row7 col0" >MAC</td>
#       <td id="T_71914_row7_col1" class="data row7 col1" >06:8D:91:D1:23:4F</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row8_col0" class="data row8 col0" >Physical Device</td>
#       <td id="T_71914_row8_col1" class="data row8 col1" >enp7s0</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row9_col0" class="data row9 col0" >Device</td>
#       <td id="T_71914_row9_col1" class="data row9 col1" >enp7s0</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row10_col0" class="data row10 col0" >IP Address</td>
#       <td id="T_71914_row10_col1" class="data row10 col1" >fd3f:f209:c712::1</td>
#     </tr>
#     <tr>
#       <td id="T_71914_row11_col0" class="data row11 col0" >Numa Node</td>
#       <td id="T_71914_row11_col1" class="data row11 col1" >4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2d85b tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_2d85b tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2d85b caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_2d85b_row0_col0, #T_2d85b_row0_col1, #T_2d85b_row1_col0, #T_2d85b_row1_col1, #T_2d85b_row2_col0, #T_2d85b_row2_col1, #T_2d85b_row3_col0, #T_2d85b_row3_col1, #T_2d85b_row4_col0, #T_2d85b_row4_col1, #T_2d85b_row5_col0, #T_2d85b_row5_col1, #T_2d85b_row6_col0, #T_2d85b_row6_col1, #T_2d85b_row7_col0, #T_2d85b_row7_col1, #T_2d85b_row8_col0, #T_2d85b_row8_col1, #T_2d85b_row9_col0, #T_2d85b_row9_col1, #T_2d85b_row10_col0, #T_2d85b_row10_col1, #T_2d85b_row11_col0, #T_2d85b_row11_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_2d85b">
#   <caption>Interface</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2d85b_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_2d85b_row0_col1" class="data row0 col1" >n2-iface1-p1</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row1_col0" class="data row1 col0" >Short Name</td>
#       <td id="T_2d85b_row1_col1" class="data row1 col1" >p1</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row2_col0" class="data row2 col0" >Node</td>
#       <td id="T_2d85b_row2_col1" class="data row2 col1" >n2</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row3_col0" class="data row3 col0" >Network</td>
#       <td id="T_2d85b_row3_col1" class="data row3 col1" >net</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row4_col0" class="data row4 col0" >Bandwidth</td>
#       <td id="T_2d85b_row4_col1" class="data row4 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row5_col0" class="data row5 col0" >Mode</td>
#       <td id="T_2d85b_row5_col1" class="data row5 col1" >config</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row6_col0" class="data row6 col0" >VLAN</td>
#       <td id="T_2d85b_row6_col1" class="data row6 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row7_col0" class="data row7 col0" >MAC</td>
#       <td id="T_2d85b_row7_col1" class="data row7 col1" >0A:20:C4:71:44:39</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row8_col0" class="data row8 col0" >Physical Device</td>
#       <td id="T_2d85b_row8_col1" class="data row8 col1" >enp7s0</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row9_col0" class="data row9 col0" >Device</td>
#       <td id="T_2d85b_row9_col1" class="data row9 col1" >enp7s0</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row10_col0" class="data row10 col0" >IP Address</td>
#       <td id="T_2d85b_row10_col1" class="data row10 col1" >fd3f:f209:c712::2</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row11_col0" class="data row11 col0" >Numa Node</td>
#       <td id="T_2d85b_row11_col1" class="data row11 col1" >4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2d85b tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_2d85b tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2d85b caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_2d85b_row0_col0, #T_2d85b_row0_col1, #T_2d85b_row1_col0, #T_2d85b_row1_col1, #T_2d85b_row2_col0, #T_2d85b_row2_col1, #T_2d85b_row3_col0, #T_2d85b_row3_col1, #T_2d85b_row4_col0, #T_2d85b_row4_col1, #T_2d85b_row5_col0, #T_2d85b_row5_col1, #T_2d85b_row6_col0, #T_2d85b_row6_col1, #T_2d85b_row7_col0, #T_2d85b_row7_col1, #T_2d85b_row8_col0, #T_2d85b_row8_col1, #T_2d85b_row9_col0, #T_2d85b_row9_col1, #T_2d85b_row10_col0, #T_2d85b_row10_col1, #T_2d85b_row11_col0, #T_2d85b_row11_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_2d85b">
#   <caption>Interface</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2d85b_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_2d85b_row0_col1" class="data row0 col1" >n2-iface1-p1</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row1_col0" class="data row1 col0" >Short Name</td>
#       <td id="T_2d85b_row1_col1" class="data row1 col1" >p1</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row2_col0" class="data row2 col0" >Node</td>
#       <td id="T_2d85b_row2_col1" class="data row2 col1" >n2</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row3_col0" class="data row3 col0" >Network</td>
#       <td id="T_2d85b_row3_col1" class="data row3 col1" >net</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row4_col0" class="data row4 col0" >Bandwidth</td>
#       <td id="T_2d85b_row4_col1" class="data row4 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row5_col0" class="data row5 col0" >Mode</td>
#       <td id="T_2d85b_row5_col1" class="data row5 col1" >config</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row6_col0" class="data row6 col0" >VLAN</td>
#       <td id="T_2d85b_row6_col1" class="data row6 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row7_col0" class="data row7 col0" >MAC</td>
#       <td id="T_2d85b_row7_col1" class="data row7 col1" >0A:20:C4:71:44:39</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row8_col0" class="data row8 col0" >Physical Device</td>
#       <td id="T_2d85b_row8_col1" class="data row8 col1" >enp7s0</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row9_col0" class="data row9 col0" >Device</td>
#       <td id="T_2d85b_row9_col1" class="data row9 col1" >enp7s0</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row10_col0" class="data row10 col0" >IP Address</td>
#       <td id="T_2d85b_row10_col1" class="data row10 col1" >fd3f:f209:c712::2</td>
#     </tr>
#     <tr>
#       <td id="T_2d85b_row11_col0" class="data row11 col0" >Numa Node</td>
#       <td id="T_2d85b_row11_col1" class="data row11 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Configuring the Network Interface
# This code configurates the network interfaces of the two nodes (n1 and n2), bringing up the network interfaces using the ifconfig command with root priviledges.

# %%
n1.execute("sudo ifconfig " + n1_iface1.get_device_name() + " up")
n2.execute("sudo ifconfig " + n2_iface1.get_device_name() + " up")
# Out:
# ('', '')

# %% [markdown]
# ##### IPv6 Ping Test Between Nodes
# The following cell performs a single ICMPv6 ping test between network interfaces of nodes n1 and n2.
# The code executes these commands on both nodes to verify IPv6 connectivity between them.

# %%
command = "ping -c 1 -I " + n1_iface1.get_device_name() + " fd3f:f209:c712::2"
print(command)
n1.execute(command) 

command2 = "ping -c 1 -I " + n2_iface1.get_device_name() + " fd3f:f209:c712::1"
print(command2)
n2.execute(command2)
# Out:
# ping -c 1 -I enp7s0 fd3f:f209:c712::2
# PING fd3f:f209:c712::2(fd3f:f209:c712::2) from fd3f:f209:c712::1 enp7s0: 56 data bytes
# 64 bytes from fd3f:f209:c712::2: icmp_seq=1 ttl=64 time=0.188 ms
#
# --- fd3f:f209:c712::2 ping statistics ---
# 1 packets transmitted, 1 received, 0% packet loss, time 0ms
# rtt min/avg/max/mdev = 0.188/0.188/0.188/0.000 ms
# ping -c 1 -I enp7s0 fd3f:f209:c712::1
# PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes
# 64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.144 ms
#
# --- fd3f:f209:c712::1 ping statistics ---
# 1 packets transmitted, 1 received, 0% packet loss, time 0ms
# rtt min/avg/max/mdev = 0.144/0.144/0.144/0.000 ms
# ('PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes\n64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.144 ms\n\n--- fd3f:f209:c712::1 ping statistics ---\n1 packets transmitted, 1 received, 0% packet loss, time 0ms\nrtt min/avg/max/mdev = 0.144/0.144/0.144/0.000 ms\n',
#  '')

# %% [markdown]
# ##### Transfering files to the nodes
# The following cell defines two functions that will be subsequently used on the notebook to upload and download files between the JypyterHub workspace and the nodes.
#
# For performing each action it is necessary to place the file on the workspace, and specify the node and the file (its route may be added too).
#
# You just need to run this cell once to use the defined functions.

# %%
# Transferring files between your JupyterHub and your node

# NOTE could use n1.upload_file(...)
def cmd_upload_file_to(n, filename):
    scp_pre_command = (n.get_ssh_command()).split(" ")
    scp_pre_command[0] = 'scp'
    scp_pre_command[5] = scp_pre_command[5].split("@")
    scp_pre_command[5] = scp_pre_command[5][0] + "@[" + scp_pre_command[5][1] + "]:~/"
    scp_pre_command.insert(5, filename)
    return ' '.join(scp_pre_command)

def cmd_download_file_from(n, filename):
    scp_pre_command = (n.get_ssh_command()).split(" ")
    scp_pre_command[0] = 'scp'
    scp_pre_command[5] = scp_pre_command[5].split("@")
    scp_pre_command[5] = scp_pre_command[5][0] + "@[" + scp_pre_command[5][1] + "]:~/" + filename
    scp_pre_command.append(".")
    return ' '.join(scp_pre_command)

# %% [markdown]
# ## Installation
#
# This section includes the necessary installations and configurations required to run the pmacctd tool and to perform actions and experiments on it. It also ensures that all dependencies and environments are correctly set up.
#
# First, the zip files of the tool and the jansson library must be added to the workspace so that they can be transferred to the nodes.
#
# > Note: You can find the zip files on:
# >> pmacctd: http://www.pmacct.net/#downloads
# >> jansson library: https://digip.org/jansson/releases/
#
#
# > Note: You may need to change the names of the files in the cell

# %%
#Upload the zip files to the nodes, you may paste the commands on a terminal to upload the files to the nodes.
print(cmd_upload_file_to(n1, "pmacct-1.7.8.zip"))
print(cmd_upload_file_to(n1, "jansson-2.13.tar.gz"))
print(cmd_upload_file_to(n2, "pmacct-1.7.8.zip"))
print(cmd_upload_file_to(n2, "jansson-2.13.tar.gz"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config pmacct-1.7.8.zip ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config jansson-2.13.tar.gz ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config pmacct-1.7.8.zip ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config jansson-2.13.tar.gz ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# > The following code unzips the files loaded to the nodes, but first installs the neccessary software packages.

# %%
# Unzip both files
# First, install zip in the nodes
n1.execute("sudo apt-get install -y zip")
n1.execute("unzip pmacct-1.7.8.zip")
n1.execute("tar -xzf jansson-2.13.tar.gz")

n2.execute("sudo apt-get install -y zip")
n2.execute("unzip pmacct-1.7.8.zip")
n2.execute("tar -xzf jansson-2.13.tar.gz")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   unzip
# The following NEW packages will be installed:
#   unzip zip
# 0 upgraded, 2 newly installed, 0 to remove and 96 not upgraded.
# Need to get 336 kB of archives.
# After this operation, 1231 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 unzip amd64 6.0-25ubuntu1.2 [169 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 zip amd64 3.0-11build1 [167 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#  Fetched 336 kB in 0s (706 kB/s)
#  debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Selecting previously unselected package unzip.
# (Reading database ... 72275 files and directories currently installed.)
# Preparing to unpack .../unzip_6.0-25ubuntu1.2_amd64.deb ...
# Unpacking unzip (6.0-25ubuntu1.2) ...
# Selecting previously unselected package zip.
# Preparing to unpack .../zip_3.0-11build1_amd64.deb ...
# Unpacking zip (3.0-11build1) ...
# Setting up unzip (6.0-25ubuntu1.2) ...
# Setting up zip (3.0-11build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Archive:  pmacct-1.7.8.zip
#    creating: pmacct-1.7.8/
#   inflating: pmacct-1.7.8/result.txt
#   inflating: pmacct-1.7.8/pmacct.conf
#   inflating: pmacct-1.7.8/help.csv
#   inflating: pmacct-1.7.8/gmail.pcapng.cap
#   inflating: pmacct-1.7.8/ltmain.sh
#   inflating: pmacct-1.7.8/install-sh
#   inflating: pmacct-1.7.8/config.guess
#   inflating: pmacct-1.7.8/UPGRADE
#   inflating: pmacct-1.7.8/autogen.sh
#   inflating: pmacct-1.7.8/config.sub
#   inflating: pmacct-1.7.8/CONFIG-KEYS
#   inflating: pmacct-1.7.8/AUTHORS
#   inflating: pmacct-1.7.8/ChangeLog
#   inflating: pmacct-1.7.8/aclocal.m4
#   inflating: pmacct-1.7.8/FAQS
#   inflating: pmacct-1.7.8/VERSION
#   inflating: pmacct-1.7.8/COPYING
#   inflating: pmacct-1.7.8/configure.ac
#   inflating: pmacct-1.7.8/LICENSE.template
#   inflating: pmacct-1.7.8/configure~
#   inflating: pmacct-1.7.8/.dockerignore
#   inflating: pmacct-1.7.8/Makefile.in
#   inflating: pmacct-1.7.8/INSTALL
#   inflating: pmacct-1.7.8/QUICKSTART
#   inflating: pmacct-1.7.8/Makefile.am
#   inflating: pmacct-1.7.8/config.status
#   inflating: pmacct-1.7.8/config.log
#   inflating: pmacct-1.7.8/compile
#   inflating: pmacct-1.7.8/missing
#   inflating: pmacct-1.7.8/depcomp
#   inflating: pmacct-1.7.8/configure
#   inflating: pmacct-1.7.8/Makefile
#   inflating: pmacct-1.7.8/libtool
#    creating: pmacct-1.7.8/m4/
#   inflating: pmacct-1.7.8/m4/libtool.m4
#   inflating: pmacct-1.7.8/m4/ltoptions.m4
#   inflating: pmacct-1.7.8/m4/ltsugar.m4
#   inflating: pmacct-1.7.8/m4/ltversion.m4
#   inflating: pmacct-1.7.8/m4/lt~obsolete.m4
#   inflating: pmacct-1.7.8/m4/ac_linearize_path.m4
#   inflating: pmacct-1.7.8/m4/ax_lib_mysql.m4
#    creating: pmacct-1.7.8/bin/
#   inflating: pmacct-1.7.8/bin/configure-help-replace.txt
#   inflating: pmacct-1.7.8/bin/configure-help-replace.sh
#    creating: pmacct-1.7.8/autom4te.cache/
#   inflating: pmacct-1.7.8/autom4te.cache/requests
#   inflating: pmacct-1.7.8/autom4te.cache/output.0
#   inflating: pmacct-1.7.8/autom4te.cache/traces.0
#   inflating: pmacct-1.7.8/autom4te.cache/output.2
#   inflating: pmacct-1.7.8/autom4te.cache/traces.2
#   inflating: pmacct-1.7.8/autom4te.cache/output.1
#   inflating: pmacct-1.7.8/autom4te.cache/traces.1
#   inflating: pmacct-1.7.8/autom4te.cache/output.3
#   inflating: pmacct-1.7.8/autom4te.cache/traces.3
#    creating: pmacct-1.7.8/include/
#   inflating: pmacct-1.7.8/include/sll.h
#   inflating: pmacct-1.7.8/include/ah.h
#   inflating: pmacct-1.7.8/include/ieee802_11.h
#   inflating: pmacct-1.7.8/include/extract.h
#   inflating: pmacct-1.7.8/include/llc.h
#   inflating: pmacct-1.7.8/include/ip6.h
#    creating: pmacct-1.7.8/telemetry/
#   inflating: pmacct-1.7.8/telemetry/README.telemetry
#    creating: pmacct-1.7.8/telemetry/decoders/
#    creating: pmacct-1.7.8/telemetry/decoders/v3/
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/pmgrpcd.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/__init__.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/config.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/README.pmgrpcd
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/kafka_receiver.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/export_pmgrpcd.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/utils.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/CONFIG-KEYS.pmgrpcd
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/huawei_pmgrpcd.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/requirements.txt
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/cisco_pmgrpcd.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/lib_pmgrpcd.py
#    creating: pmacct-1.7.8/telemetry/decoders/v3/zmq_modules/
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/zmq_modules/__init__.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/zmq_modules/zmq_exporter.py
#    creating: pmacct-1.7.8/telemetry/decoders/v3/protos/
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/cisco_telemetry_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei_grpc_dialout_pb2_grpc.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/cisco_telemetry.proto
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/gnmi_ext_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/openconfig_interfaces_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei-telemetry.proto
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei_grpc_dialout_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/cisco_grpc_dialout_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei_ifm_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei_telemetry_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/cisco_grpc_dialout_pb2_grpc.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/gnmi.proto
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/cisco_grpc_dialout.proto
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei_devm_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei-grpc-dialout.proto
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/gnmi_ext.proto
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei-ifm.proto
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/gnmi_pb2.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/openconfig-interfaces.proto
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/gnmi_pb2_grpc.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/README.md
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/protos/huawei-devm.proto
#    creating: pmacct-1.7.8/telemetry/decoders/v3/kafka_modules/
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/kafka_modules/__init__.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/kafka_modules/kafka_avro_exporter.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/kafka_modules/kafka_simple_exporter.py
#    creating: pmacct-1.7.8/telemetry/decoders/v3/utils/
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/utils/huawei_generate_data.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/utils/kafka_consumer.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/utils/kafka_producer.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/utils/huawei_generator.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/utils/zmq_puller.py
#    creating: pmacct-1.7.8/telemetry/decoders/v3/config_files/
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/config_files/avscmapfile
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/config_files/mitigation.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/config_files/telemetry.conf
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/config_files/gpbmapfile.map
#    creating: pmacct-1.7.8/telemetry/decoders/v3/file_modules/
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/file_modules/__init__.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/file_modules/file_input.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v3/file_modules/file_producer.py
#    creating: pmacct-1.7.8/telemetry/decoders/v1/
#   inflating: pmacct-1.7.8/telemetry/decoders/v1/cisco_grpc_dialout_server.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v1/huawei_grpc_dialout_server.py
#   inflating: pmacct-1.7.8/telemetry/decoders/v1/README.grpc_dialout
#    creating: pmacct-1.7.8/telemetry/utils/
#   inflating: pmacct-1.7.8/telemetry/utils/decodeGPB.py
#    creating: pmacct-1.7.8/docs/
#   inflating: pmacct-1.7.8/docs/LOOKING_GLASS_FORMAT
#   inflating: pmacct-1.7.8/docs/TRIGGER_VARS
#   inflating: pmacct-1.7.8/docs/IPFIX
#   inflating: pmacct-1.7.8/docs/MSGLOG_DUMP_FORMATS
#   inflating: pmacct-1.7.8/docs/INTERNALS
#   inflating: pmacct-1.7.8/docs/PLUGINS
#   inflating: pmacct-1.7.8/docs/BGP_BMP_METRICS.md
#   inflating: pmacct-1.7.8/docs/SIGNALS
#   inflating: pmacct-1.7.8/docs/DOCKER.md
#   inflating: pmacct-1.7.8/docs/FLOW_AUGMENTATION_PROCESS_DESCRIPTION.md
#    creating: pmacct-1.7.8/docs/relicense_effort/
#   inflating: pmacct-1.7.8/docs/relicense_effort/initial_outreach.txt
#   inflating: pmacct-1.7.8/docs/relicense_effort/progress_report.txt
#   inflating: pmacct-1.7.8/docs/relicense_effort/README
#    creating: pmacct-1.7.8/sql/
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v2.sqlite3
#   inflating: pmacct-1.7.8/sql/pmacct-create-db.pgsql
#   inflating: pmacct-1.7.8/sql/README.export_proto
#   inflating: pmacct-1.7.8/sql/README.label
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v2.pgsql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v6.sqlite3
#   inflating: pmacct-1.7.8/sql/README.iface
#   inflating: pmacct-1.7.8/sql/README.pgsql
#   inflating: pmacct-1.7.8/sql/README.tunnel
#   inflating: pmacct-1.7.8/sql/README.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v9.sqlite3
#   inflating: pmacct-1.7.8/sql/README.sampling
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v1.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v3.pgsql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v4.pgsql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_bgp_v1.sqlite3
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v4.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v5.sqlite3
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v7.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v5.mysql
#   inflating: pmacct-1.7.8/sql/README.custom_primitives
#   inflating: pmacct-1.7.8/sql/README.GeoIP
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v9.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v6.mysql
#   inflating: pmacct-1.7.8/sql/README.nat
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_bgp_v1.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v4.sqlite3
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v6.pgsql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_bgp_v1.pgsql
#   inflating: pmacct-1.7.8/sql/README.etype
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v9.pgsql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v3.sqlite3
#   inflating: pmacct-1.7.8/sql/README.tag2
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v3.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v7.sqlite3
#   inflating: pmacct-1.7.8/sql/README.mpls
#   inflating: pmacct-1.7.8/sql/README.cos
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v7_v8.pgsql
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v2.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-db_v8.mysql
#   inflating: pmacct-1.7.8/sql/README.timestamp
#   inflating: pmacct-1.7.8/sql/pmacct-grant-db.mysql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v1.sqlite3
#   inflating: pmacct-1.7.8/sql/README.sqlite3
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v5.pgsql
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v8.sqlite3
#   inflating: pmacct-1.7.8/sql/pmacct-create-table_v1.pgsql
#   inflating: pmacct-1.7.8/sql/README.mask
#    creating: pmacct-1.7.8/examples/
#   inflating: pmacct-1.7.8/examples/allow.lst.example
#   inflating: pmacct-1.7.8/examples/pmacctd-sqlite3.conf.example
#   inflating: pmacct-1.7.8/examples/sampling.map.example
#   inflating: pmacct-1.7.8/examples/bgp_agent.map.example
#   inflating: pmacct-1.7.8/examples/bgp_md5.lst.example
#   inflating: pmacct-1.7.8/examples/tee_receivers.lst.example
#   inflating: pmacct-1.7.8/examples/probe_sflow.conf.example
#   inflating: pmacct-1.7.8/examples/pcap_interfaces.map.example
#   inflating: pmacct-1.7.8/examples/ports.lst.example
#   inflating: pmacct-1.7.8/examples/pmacctd-multiple-plugins.conf.example
#   inflating: pmacct-1.7.8/examples/primitives.lst.example
#   inflating: pmacct-1.7.8/examples/networks.lst.example
#   inflating: pmacct-1.7.8/examples/nfacctd-print.conf.example
#   inflating: pmacct-1.7.8/examples/probe_netflow.conf.example
#   inflating: pmacct-1.7.8/examples/peers.map.example
#   inflating: pmacct-1.7.8/examples/nfacctd-sql.conf.example
#   inflating: pmacct-1.7.8/examples/pmacctd-imt.conf.example
#   inflating: pmacct-1.7.8/examples/med.map.example
#   inflating: pmacct-1.7.8/examples/flow_to_rd.map.example
#   inflating: pmacct-1.7.8/examples/pmacctd-sql.conf.example
#   inflating: pmacct-1.7.8/examples/pretag.map.example
#   inflating: pmacct-1.7.8/examples/lpref.map.example
#   inflating: pmacct-1.7.8/examples/bgp_xconnects.map.example
#    creating: pmacct-1.7.8/examples/systemd/
#   inflating: pmacct-1.7.8/examples/systemd/systemd_service_file.md
#    creating: pmacct-1.7.8/examples/amqp/
#   inflating: pmacct-1.7.8/examples/amqp/amqp_receiver.py
#    creating: pmacct-1.7.8/examples/kafka/
#   inflating: pmacct-1.7.8/examples/kafka/kafka_consumer.py
#    creating: pmacct-1.7.8/examples/lg/
#   inflating: pmacct-1.7.8/examples/lg/pmbgp.c
#   inflating: pmacct-1.7.8/examples/lg/pmbgp.py
#   inflating: pmacct-1.7.8/examples/lg/Makefile.in
#   inflating: pmacct-1.7.8/examples/lg/pmbgp.h
#   inflating: pmacct-1.7.8/examples/lg/Makefile.am
#   inflating: pmacct-1.7.8/examples/lg/Makefile
#   inflating: pmacct-1.7.8/examples/lg/pmbgp
#   inflating: pmacct-1.7.8/examples/lg/pmbgp-pmbgp.o
#    creating: pmacct-1.7.8/examples/lg/.deps/
#   inflating: pmacct-1.7.8/examples/lg/.deps/pmbgp-pmbgp.Po
#    creating: pmacct-1.7.8/examples/lg/.libs/
#    creating: pmacct-1.7.8/examples/avro/
#   inflating: pmacct-1.7.8/examples/avro/avro_file_decoder.py
#    creating: pmacct-1.7.8/examples/misc/
#   inflating: pmacct-1.7.8/examples/misc/mrtg.conf.example
#   inflating: pmacct-1.7.8/examples/misc/rrdtool-example.sh
#   inflating: pmacct-1.7.8/examples/misc/gnuplot-example.sh
#   inflating: pmacct-1.7.8/examples/misc/mrtg-example.sh
#   inflating: pmacct-1.7.8/examples/misc/gnuplot.script.example
#    creating: pmacct-1.7.8/examples/custom/
#   inflating: pmacct-1.7.8/examples/custom/libcustom.c
#   inflating: pmacct-1.7.8/examples/custom/Makefile.in
#   inflating: pmacct-1.7.8/examples/custom/libcustom.h
#   inflating: pmacct-1.7.8/examples/custom/Makefile.am
#   inflating: pmacct-1.7.8/examples/custom/nfacctd-custom.conf.example
#   inflating: pmacct-1.7.8/examples/custom/Makefile
#   inflating: pmacct-1.7.8/examples/custom/libcustom.la
#   inflating: pmacct-1.7.8/examples/custom/libcustom_la-libcustom.o
#   inflating: pmacct-1.7.8/examples/custom/libcustom_la-libcustom.lo
#    creating: pmacct-1.7.8/examples/custom/.deps/
#   inflating: pmacct-1.7.8/examples/custom/.deps/libcustom_la-libcustom.Plo
#    creating: pmacct-1.7.8/examples/custom/.libs/
#   inflating: pmacct-1.7.8/examples/custom/.libs/libcustom.a
#   inflating: pmacct-1.7.8/examples/custom/.libs/libcustom_la-libcustom.o
#     linking: pmacct-1.7.8/examples/custom/.libs/libcustom.la  -> ../libcustom.la
#    creating: pmacct-1.7.8/src/
#   inflating: pmacct-1.7.8/src/net_aggr.h
#   inflating: pmacct-1.7.8/src/plugin_hooks.h
#   inflating: pmacct-1.7.8/src/pgsql_plugin.c
#   inflating: pmacct-1.7.8/src/plugin_common.c
#   inflating: pmacct-1.7.8/src/pmacctd.c
#   inflating: pmacct-1.7.8/src/imt_plugin.h
#   inflating: pmacct-1.7.8/src/xflow_status.h
#   inflating: pmacct-1.7.8/src/zmq_common.c
#   inflating: pmacct-1.7.8/src/setproctitle.c
#   inflating: pmacct-1.7.8/src/nfacctd.c
#   inflating: pmacct-1.7.8/src/pmsearch.h
#   inflating: pmacct-1.7.8/src/sqlite3_plugin.h
#   inflating: pmacct-1.7.8/src/print_plugin.h
#   inflating: pmacct-1.7.8/src/pmtelemetryd.c
#   inflating: pmacct-1.7.8/src/crc32.h
#   inflating: pmacct-1.7.8/src/once.h
#   inflating: pmacct-1.7.8/src/plugin_common.h
#   inflating: pmacct-1.7.8/src/pmacct-dlt.h
#   inflating: pmacct-1.7.8/src/pretag.c
#   inflating: pmacct-1.7.8/src/preprocess-internal.h
#   inflating: pmacct-1.7.8/src/pmacct-globals.c
#   inflating: pmacct-1.7.8/src/sql_handlers.c
#   inflating: pmacct-1.7.8/src/log.c
#   inflating: pmacct-1.7.8/src/jhash.h
#   inflating: pmacct-1.7.8/src/zmq_common.h
#   inflating: pmacct-1.7.8/src/pmbgpd.c
#   inflating: pmacct-1.7.8/src/pkt_handlers.h
#   inflating: pmacct-1.7.8/src/addr.c
#   inflating: pmacct-1.7.8/src/mysql_plugin.c
#   inflating: pmacct-1.7.8/src/net_aggr.c
#   inflating: pmacct-1.7.8/src/linklist.h
#   inflating: pmacct-1.7.8/src/redis_common.h
#   inflating: pmacct-1.7.8/src/sfv5_module.c
#   inflating: pmacct-1.7.8/src/uacctd.h
#   inflating: pmacct-1.7.8/src/pretag_handlers.h
#   inflating: pmacct-1.7.8/src/uacctd.c
#   inflating: pmacct-1.7.8/src/preprocess.c
#   inflating: pmacct-1.7.8/src/plugin_cmn_custom.h
#   inflating: pmacct-1.7.8/src/thread_pool.h
#   inflating: pmacct-1.7.8/src/conntrack.c
#   inflating: pmacct-1.7.8/src/classifier.c
#   inflating: pmacct-1.7.8/src/network.h
#   inflating: pmacct-1.7.8/src/redis_common.c
#   inflating: pmacct-1.7.8/src/mongodb_plugin.h
#   inflating: pmacct-1.7.8/src/ll.c
#   inflating: pmacct-1.7.8/src/server.c
#   inflating: pmacct-1.7.8/src/sflow.h
#   inflating: pmacct-1.7.8/src/ip_frag.c
#   inflating: pmacct-1.7.8/src/amqp_plugin.h
#   inflating: pmacct-1.7.8/src/network.c
#   inflating: pmacct-1.7.8/src/amqp_common.c
#   inflating: pmacct-1.7.8/src/pkt_handlers.c
#   inflating: pmacct-1.7.8/src/util-data.h
#   inflating: pmacct-1.7.8/src/plugin_cmn_json.c
#   inflating: pmacct-1.7.8/src/pmbmpd.c
#   inflating: pmacct-1.7.8/src/mpls.h
#   inflating: pmacct-1.7.8/src/linklist.c
#   inflating: pmacct-1.7.8/src/ip_frag.h
#   inflating: pmacct-1.7.8/src/mongodb_plugin.c
#   inflating: pmacct-1.7.8/src/pmacct-data.h
#   inflating: pmacct-1.7.8/src/strlcpy.c
#   inflating: pmacct-1.7.8/src/sqlite3_plugin.c
#   inflating: pmacct-1.7.8/src/pmacct.c
#   inflating: pmacct-1.7.8/src/plugin_cmn_avro.h
#   inflating: pmacct-1.7.8/src/mysql_plugin.h
#   inflating: pmacct-1.7.8/src/base64.c
#   inflating: pmacct-1.7.8/src/sql_common.h
#   inflating: pmacct-1.7.8/src/imt_plugin.c
#   inflating: pmacct-1.7.8/src/sql_common.c
#   inflating: pmacct-1.7.8/src/print_plugin.c
#   inflating: pmacct-1.7.8/src/sfv5_module.h
#   inflating: pmacct-1.7.8/src/nfacctd.h
#   inflating: pmacct-1.7.8/src/kafka_plugin.c
#   inflating: pmacct-1.7.8/src/sql_common_m.c
#   inflating: pmacct-1.7.8/src/kafka_common.c
#   inflating: pmacct-1.7.8/src/util.c
#   inflating: pmacct-1.7.8/src/amqp_plugin.c
#   inflating: pmacct-1.7.8/src/pmacct.h
#   inflating: pmacct-1.7.8/src/kafka_plugin.h
#   inflating: pmacct-1.7.8/src/sql_common_m.h
#   inflating: pmacct-1.7.8/src/xflow_status.c
#   inflating: pmacct-1.7.8/src/acct.c
#   inflating: pmacct-1.7.8/src/sfacctd.h
#   inflating: pmacct-1.7.8/src/pmsearch.c
#   inflating: pmacct-1.7.8/src/nfv9_template.c
#   inflating: pmacct-1.7.8/src/signals.c
#   inflating: pmacct-1.7.8/src/pmacct-defines.h
#   inflating: pmacct-1.7.8/src/plugin_cmn_json.h
#   inflating: pmacct-1.7.8/src/preprocess.h
#   inflating: pmacct-1.7.8/src/plugin_cmn_avro.c
#   inflating: pmacct-1.7.8/src/cfg.h
#   inflating: pmacct-1.7.8/src/pmbmpd.h
#   inflating: pmacct-1.7.8/src/addr.h
#   inflating: pmacct-1.7.8/src/sfacctd.c
#   inflating: pmacct-1.7.8/src/memory.c
#   inflating: pmacct-1.7.8/src/preprocess-data.h
#   inflating: pmacct-1.7.8/src/pmtelemetryd.h
#   inflating: pmacct-1.7.8/src/Makefile.in
#   inflating: pmacct-1.7.8/src/plugin_hooks.c
#   inflating: pmacct-1.7.8/src/nl.c
#   inflating: pmacct-1.7.8/src/pmacct-version.h.in
#   inflating: pmacct-1.7.8/src/sflow.c
#   inflating: pmacct-1.7.8/src/pgsql_plugin.h
#   inflating: pmacct-1.7.8/src/base64.h
#   inflating: pmacct-1.7.8/src/amqp_common.h
#   inflating: pmacct-1.7.8/src/conntrack.h
#   inflating: pmacct-1.7.8/src/pretag-data.h
#   inflating: pmacct-1.7.8/src/cfg_handlers.h
#   inflating: pmacct-1.7.8/src/log.h
#   inflating: pmacct-1.7.8/src/setproctitle.h
#   inflating: pmacct-1.7.8/src/plugin_cmn_custom.c
#   inflating: pmacct-1.7.8/src/thread_pool.c
#   inflating: pmacct-1.7.8/src/pretag_handlers.c
#   inflating: pmacct-1.7.8/src/cfg.c
#   inflating: pmacct-1.7.8/src/cfg_handlers.c
#   inflating: pmacct-1.7.8/src/Makefile.am
#   inflating: pmacct-1.7.8/src/util.h
#   inflating: pmacct-1.7.8/src/ip_flow.h
#   inflating: pmacct-1.7.8/src/ip_flow.c
#   inflating: pmacct-1.7.8/src/pmbgpd.h
#   inflating: pmacct-1.7.8/src/pretag.h
#   inflating: pmacct-1.7.8/src/kafka_common.h
#   inflating: pmacct-1.7.8/src/classifier.h
#   inflating: pmacct-1.7.8/src/pmacct-build.h
#   inflating: pmacct-1.7.8/src/pmacct-version.h
#   inflating: pmacct-1.7.8/src/Makefile
#   inflating: pmacct-1.7.8/src/libcommon.la
#   inflating: pmacct-1.7.8/src/libdaemons.la
#   inflating: pmacct-1.7.8/src/nfacctd
#   inflating: pmacct-1.7.8/src/pmacctd
#   inflating: pmacct-1.7.8/src/pmbgpd
#   inflating: pmacct-1.7.8/src/pmbmpd
#   inflating: pmacct-1.7.8/src/pmtelemetryd
#   inflating: pmacct-1.7.8/src/sfacctd
#   inflating: pmacct-1.7.8/src/pmacct.o
#   inflating: pmacct-1.7.8/src/libcommon_la-strlcpy.o
#   inflating: pmacct-1.7.8/src/libcommon_la-strlcpy.lo
#   inflating: pmacct-1.7.8/src/libcommon_la-addr.o
#   inflating: pmacct-1.7.8/src/libcommon_la-addr.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-signals.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-signals.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-util.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-util.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-plugin_hooks.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-plugin_hooks.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-server.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-server.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-acct.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-acct.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-memory.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-memory.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-cfg.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-cfg.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-imt_plugin.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-imt_plugin.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-log.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-log.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-pkt_handlers.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-pkt_handlers.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-cfg_handlers.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-cfg_handlers.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-net_aggr.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-net_aggr.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-print_plugin.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-print_plugin.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-pretag.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-pretag.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-ip_frag.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-ip_frag.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-pretag_handlers.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-pretag_handlers.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-ip_flow.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-ip_flow.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-setproctitle.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-setproctitle.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-classifier.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-classifier.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-conntrack.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-conntrack.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-xflow_status.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-xflow_status.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-plugin_common.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-plugin_common.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-preprocess.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-preprocess.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-ll.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-ll.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-nl.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-nl.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-base64.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-base64.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-pmsearch.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-pmsearch.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-linklist.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-linklist.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-thread_pool.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-thread_pool.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-plugin_cmn_custom.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-plugin_cmn_custom.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-network.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-network.lo
#   inflating: pmacct-1.7.8/src/libdaemons_la-pmacct-globals.o
#   inflating: pmacct-1.7.8/src/libdaemons_la-pmacct-globals.lo
#   inflating: pmacct-1.7.8/src/pmacct
#   inflating: pmacct-1.7.8/src/pmacctd.o
#   inflating: pmacct-1.7.8/src/nfacctd.o
#   inflating: pmacct-1.7.8/src/nfv9_template.o
#   inflating: pmacct-1.7.8/src/sfacctd.o
#   inflating: pmacct-1.7.8/src/sflow.o
#   inflating: pmacct-1.7.8/src/sfv5_module.o
#   inflating: pmacct-1.7.8/src/pmtelemetryd.o
#   inflating: pmacct-1.7.8/src/pmbgpd.o
#   inflating: pmacct-1.7.8/src/pmbmpd.o
#    creating: pmacct-1.7.8/src/rpki/
#   inflating: pmacct-1.7.8/src/rpki/rpki_util.c
#   inflating: pmacct-1.7.8/src/rpki/rpki_lookup.c
#   inflating: pmacct-1.7.8/src/rpki/rpki.c
#   inflating: pmacct-1.7.8/src/rpki/rpki_msg.h
#   inflating: pmacct-1.7.8/src/rpki/Makefile.in
#   inflating: pmacct-1.7.8/src/rpki/rpki.h
#   inflating: pmacct-1.7.8/src/rpki/rpki_util.h
#   inflating: pmacct-1.7.8/src/rpki/rpki_msg.c
#   inflating: pmacct-1.7.8/src/rpki/Makefile.am
#   inflating: pmacct-1.7.8/src/rpki/rpki_lookup.h
#   inflating: pmacct-1.7.8/src/rpki/Makefile
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki.la
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki_la-rpki.o
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki_la-rpki.lo
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki_la-rpki_msg.o
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki_la-rpki_msg.lo
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki_la-rpki_lookup.o
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki_la-rpki_lookup.lo
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki_la-rpki_util.o
#   inflating: pmacct-1.7.8/src/rpki/libpmrpki_la-rpki_util.lo
#    creating: pmacct-1.7.8/src/rpki/.deps/
#   inflating: pmacct-1.7.8/src/rpki/.deps/libpmrpki_la-rpki_lookup.Plo
#   inflating: pmacct-1.7.8/src/rpki/.deps/libpmrpki_la-rpki_util.Plo
#   inflating: pmacct-1.7.8/src/rpki/.deps/libpmrpki_la-rpki.Plo
#   inflating: pmacct-1.7.8/src/rpki/.deps/libpmrpki_la-rpki_msg.Plo
#    creating: pmacct-1.7.8/src/rpki/.libs/
#   inflating: pmacct-1.7.8/src/rpki/.libs/libpmrpki.a
#   inflating: pmacct-1.7.8/src/rpki/.libs/libpmrpki_la-rpki.o
#   inflating: pmacct-1.7.8/src/rpki/.libs/libpmrpki_la-rpki_msg.o
#   inflating: pmacct-1.7.8/src/rpki/.libs/libpmrpki_la-rpki_lookup.o
#   inflating: pmacct-1.7.8/src/rpki/.libs/libpmrpki_la-rpki_util.o
#     linking: pmacct-1.7.8/src/rpki/.libs/libpmrpki.la  -> ../libpmrpki.la
#    creating: pmacct-1.7.8/src/sfprobe_plugin/
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/sflow_api.h
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/sflow_sampler.c
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/sflow_poller.c
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/sflow_agent.c
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/sflow_receiver.c
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/Makefile.in
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/Makefile.am
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/sfprobe_plugin.c
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/Makefile
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin.la
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sflow_agent.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sflow_agent.lo
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sflow_poller.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sflow_poller.lo
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sflow_receiver.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sflow_receiver.lo
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sflow_sampler.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sflow_sampler.lo
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sfprobe_plugin.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/libsfprobe_plugin_la-sfprobe_plugin.lo
#    creating: pmacct-1.7.8/src/sfprobe_plugin/.deps/
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.deps/libsfprobe_plugin_la-sflow_poller.Plo
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.deps/libsfprobe_plugin_la-sflow_receiver.Plo
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.deps/libsfprobe_plugin_la-sflow_sampler.Plo
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.deps/libsfprobe_plugin_la-sflow_agent.Plo
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.deps/libsfprobe_plugin_la-sfprobe_plugin.Plo
#    creating: pmacct-1.7.8/src/sfprobe_plugin/.libs/
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.libs/libsfprobe_plugin.a
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.libs/libsfprobe_plugin_la-sflow_agent.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.libs/libsfprobe_plugin_la-sflow_poller.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.libs/libsfprobe_plugin_la-sflow_receiver.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.libs/libsfprobe_plugin_la-sflow_sampler.o
#   inflating: pmacct-1.7.8/src/sfprobe_plugin/.libs/libsfprobe_plugin_la-sfprobe_plugin.o
#     linking: pmacct-1.7.8/src/sfprobe_plugin/.libs/libsfprobe_plugin.la  -> ../libsfprobe_plugin.la
#    creating: pmacct-1.7.8/src/bgp/
#   inflating: pmacct-1.7.8/src/bgp/bgp_lcommunity.h
#   inflating: pmacct-1.7.8/src/bgp/bgp.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_msg.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_xcs-data.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_hash.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_table.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_aspath.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_ecommunity.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_lcommunity.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_msg.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_logdump.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_packet.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_logdump.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_hash.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_blackhole.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_xcs.c
#   inflating: pmacct-1.7.8/src/bgp/bgp.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_xcs.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_lookup.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_blackhole.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_ecommunity.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_community.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_prefix.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_table.c
#   inflating: pmacct-1.7.8/src/bgp/Makefile.in
#   inflating: pmacct-1.7.8/src/bgp/bgp_lookup.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_lg.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_lg.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_util.h
#   inflating: pmacct-1.7.8/src/bgp/bgp_util.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_aspath.c
#   inflating: pmacct-1.7.8/src/bgp/bgp_community.h
#   inflating: pmacct-1.7.8/src/bgp/Makefile.am
#   inflating: pmacct-1.7.8/src/bgp/bgp_prefix.h
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_prefix.o
#   inflating: pmacct-1.7.8/src/bgp/Makefile
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp.la
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_aspath.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_aspath.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_community.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_community.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_ecommunity.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_ecommunity.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_hash.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_hash.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_prefix.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_table.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_table.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_logdump.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_logdump.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_msg.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_lookup.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_lookup.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_lcommunity.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_lcommunity.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_xcs.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_xcs.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_lg.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_lg.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_blackhole.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_blackhole.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_util.o
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_util.lo
#   inflating: pmacct-1.7.8/src/bgp/libpmbgp_la-bgp_msg.lo
#    creating: pmacct-1.7.8/src/bgp/.deps/
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_lookup.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_community.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_ecommunity.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_hash.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_prefix.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_table.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_xcs.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_lcommunity.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_logdump.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_util.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_lg.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_aspath.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_msg.Plo
#   inflating: pmacct-1.7.8/src/bgp/.deps/libpmbgp_la-bgp_blackhole.Plo
#    creating: pmacct-1.7.8/src/bgp/.libs/
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp.a
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_lookup.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_aspath.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_community.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_ecommunity.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_hash.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_prefix.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_table.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_logdump.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_util.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_msg.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_lcommunity.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_xcs.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_blackhole.o
#   inflating: pmacct-1.7.8/src/bgp/.libs/libpmbgp_la-bgp_lg.o
#     linking: pmacct-1.7.8/src/bgp/.libs/libpmbgp.la  -> ../libpmbgp.la
#    creating: pmacct-1.7.8/src/bmp/
#   inflating: pmacct-1.7.8/src/bmp/bmp_msg.c
#   inflating: pmacct-1.7.8/src/bmp/bmp.c
#   inflating: pmacct-1.7.8/src/bmp/bmp_lookup.h
#   inflating: pmacct-1.7.8/src/bmp/bmp_util.c
#   inflating: pmacct-1.7.8/src/bmp/bmp_rpat.c
#   inflating: pmacct-1.7.8/src/bmp/bmp_logdump.c
#   inflating: pmacct-1.7.8/src/bmp/bmp_msg.h
#   inflating: pmacct-1.7.8/src/bmp/bmp.h
#   inflating: pmacct-1.7.8/src/bmp/bmp_rpat.h
#   inflating: pmacct-1.7.8/src/bmp/Makefile.in
#   inflating: pmacct-1.7.8/src/bmp/bmp_lookup.c
#   inflating: pmacct-1.7.8/src/bmp/bmp_tlv.h
#   inflating: pmacct-1.7.8/src/bmp/Makefile.am
#   inflating: pmacct-1.7.8/src/bmp/bmp_logdump.h
#   inflating: pmacct-1.7.8/src/bmp/bmp_tlv.c
#   inflating: pmacct-1.7.8/src/bmp/bmp_util.h
#   inflating: pmacct-1.7.8/src/bmp/bmp-globals.c
#   inflating: pmacct-1.7.8/src/bmp/Makefile
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp.la
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp.o
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp.lo
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_logdump.o
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_logdump.lo
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_msg.o
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_msg.lo
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_util.o
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_util.lo
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_lookup.o
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_lookup.lo
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_tlv.o
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_tlv.lo
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_rpat.o
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp_rpat.lo
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp-globals.o
#   inflating: pmacct-1.7.8/src/bmp/libpmbmp_la-bmp-globals.lo
#    creating: pmacct-1.7.8/src/bmp/.deps/
#   inflating: pmacct-1.7.8/src/bmp/.deps/libpmbmp_la-bmp_msg.Plo
#   inflating: pmacct-1.7.8/src/bmp/.deps/libpmbmp_la-bmp_util.Plo
#   inflating: pmacct-1.7.8/src/bmp/.deps/libpmbmp_la-bmp_rpat.Plo
#   inflating: pmacct-1.7.8/src/bmp/.deps/libpmbmp_la-bmp_lookup.Plo
#   inflating: pmacct-1.7.8/src/bmp/.deps/libpmbmp_la-bmp-globals.Plo
#   inflating: pmacct-1.7.8/src/bmp/.deps/libpmbmp_la-bmp_tlv.Plo
#   inflating: pmacct-1.7.8/src/bmp/.deps/libpmbmp_la-bmp.Plo
#   inflating: pmacct-1.7.8/src/bmp/.deps/libpmbmp_la-bmp_logdump.Plo
#    creating: pmacct-1.7.8/src/bmp/.libs/
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp.a
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp_la-bmp.o
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp_la-bmp_logdump.o
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp_la-bmp_msg.o
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp_la-bmp_util.o
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp_la-bmp_lookup.o
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp_la-bmp_tlv.o
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp_la-bmp_rpat.o
#   inflating: pmacct-1.7.8/src/bmp/.libs/libpmbmp_la-bmp-globals.o
#     linking: pmacct-1.7.8/src/bmp/.libs/libpmbmp.la  -> ../libpmbmp.la
#    creating: pmacct-1.7.8/src/filters/
#   inflating: pmacct-1.7.8/src/filters/bloom.h
#   inflating: pmacct-1.7.8/src/filters/Makefile.am
#   inflating: pmacct-1.7.8/src/filters/murmur2.c
#   inflating: pmacct-1.7.8/src/filters/bloom.c
#   inflating: pmacct-1.7.8/src/filters/Makefile.in
#   inflating: pmacct-1.7.8/src/filters/murmur2.h
#   inflating: pmacct-1.7.8/src/filters/Makefile
#   inflating: pmacct-1.7.8/src/filters/libpmfilters.la
#   inflating: pmacct-1.7.8/src/filters/libpmfilters_la-bloom.o
#   inflating: pmacct-1.7.8/src/filters/libpmfilters_la-bloom.lo
#   inflating: pmacct-1.7.8/src/filters/libpmfilters_la-murmur2.o
#   inflating: pmacct-1.7.8/src/filters/libpmfilters_la-murmur2.lo
#    creating: pmacct-1.7.8/src/filters/.deps/
#   inflating: pmacct-1.7.8/src/filters/.deps/libpmfilters_la-murmur2.Plo
#   inflating: pmacct-1.7.8/src/filters/.deps/libpmfilters_la-bloom.Plo
#    creating: pmacct-1.7.8/src/filters/.libs/
#   inflating: pmacct-1.7.8/src/filters/.libs/libpmfilters.a
#   inflating: pmacct-1.7.8/src/filters/.libs/libpmfilters_la-bloom.o
#   inflating: pmacct-1.7.8/src/filters/.libs/libpmfilters_la-murmur2.o
#     linking: pmacct-1.7.8/src/filters/.libs/libpmfilters.la  -> ../libpmfilters.la
#    creating: pmacct-1.7.8/src/ndpi/
#   inflating: pmacct-1.7.8/src/ndpi/ndpi.h
#   inflating: pmacct-1.7.8/src/ndpi/ndpi_util.h
#   inflating: pmacct-1.7.8/src/ndpi/ndpi.c
#   inflating: pmacct-1.7.8/src/ndpi/ndpi_util.c
#   inflating: pmacct-1.7.8/src/ndpi/Makefile.in
#   inflating: pmacct-1.7.8/src/ndpi/Makefile.am
#   inflating: pmacct-1.7.8/src/ndpi/Makefile
#    creating: pmacct-1.7.8/src/ndpi/.deps/
#   inflating: pmacct-1.7.8/src/ndpi/.deps/ndpi.Plo
#   inflating: pmacct-1.7.8/src/ndpi/.deps/ndpi_util.Plo
#    creating: pmacct-1.7.8/src/external_libs/
#   inflating: pmacct-1.7.8/src/external_libs/Makefile.in
#   inflating: pmacct-1.7.8/src/external_libs/Makefile.am
#   inflating: pmacct-1.7.8/src/external_libs/Makefile
#   inflating: pmacct-1.7.8/src/external_libs/.libcdada_mark
#    creating: pmacct-1.7.8/src/external_libs/rootfs/
#    creating: pmacct-1.7.8/src/external_libs/rootfs/include/
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada.h
#    creating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/version.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/bbitmap.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/list.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/list_custom_cc.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/map.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/map_custom_cc.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/queue.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/queue_custom_cc.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/set.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/set_custom_cc.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/stack.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/stack_custom_cc.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/str.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/utils.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/__common_internal.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/__list_internal.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/__map_internal.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/__queue_internal.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/__set_internal.h
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/include/cdada/__stack_internal.h
#    creating: pmacct-1.7.8/src/external_libs/rootfs/lib/
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.a
#    creating: pmacct-1.7.8/src/external_libs/rootfs/bin/
#   inflating: pmacct-1.7.8/src/external_libs/rootfs/bin/cdada-gen
#    creating: pmacct-1.7.8/src/external_libs/libcdada/
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/autogen.sh
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/aclocal.m4
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/AUTHORS
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/CHANGELOG.md
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/VERSION
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/configure.ac
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/configure~
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/README.md
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/Makefile.in
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/Makefile.am
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/LICENSE
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/configure
#    creating: pmacct-1.7.8/src/external_libs/libcdada/tools/
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/tools/cdada-gen
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/tools/Makefile.in
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/tools/Makefile.am
#    creating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/ltmain.sh
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/install-sh
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/ar-lib
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/config.guess
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/config.sub
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/compile
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/missing
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build-aux/depcomp
#    creating: pmacct-1.7.8/src/external_libs/libcdada/m4/
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/m4/libtool.m4
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/m4/ltoptions.m4
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/m4/ltsugar.m4
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/m4/ltversion.m4
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/m4/lt~obsolete.m4
#    creating: pmacct-1.7.8/src/external_libs/libcdada/build/
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/.empty
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/config.status
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/config.log
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/Makefile
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/libtool
#    creating: pmacct-1.7.8/src/external_libs/libcdada/build/include/
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/include/Makefile
#    creating: pmacct-1.7.8/src/external_libs/libcdada/build/include/cdada/
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/include/cdada/version.h
#    creating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/Makefile
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/bbitmap
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/list_u32
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/map_struct
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/queue_u32
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/stack_u32
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/str
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/custom_gen
#   inflating: pmacct-1.7.8/src/external_libs/libcdada/build/examples/custom_macro
# ...
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_tlv.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_tlv.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_csm.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_csm.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_flags.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_flags.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_misc.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_misc.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isisd.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isisd.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_adjacency.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_adjacency.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_dynhn.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_dynhn.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_spf.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_spf.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-iso_checksum.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-iso_checksum.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_lsp.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_lsp.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_pdu.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis_pdu.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis-globals.o
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-isis-globals.lo
#   inflating: pmacct-1.7.8/src/isis/libpmisis_la-sockunion.lo
#    creating: pmacct-1.7.8/src/isis/.deps/
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-table.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-prefix.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-thread.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-dict.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_spf.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_route.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_misc.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-iso_checksum.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_tlv.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isisd.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis-globals.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_adjacency.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_csm.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_lsp.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_flags.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_dynhn.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_pdu.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-hash.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_circuit.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis_events.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-stream.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-isis.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-checksum.Plo
#   inflating: pmacct-1.7.8/src/isis/.deps/libpmisis_la-sockunion.Plo
#    creating: pmacct-1.7.8/src/isis/.libs/
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis.a
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-checksum.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-dict.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-table.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-prefix.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-sockunion.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-hash.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-stream.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-thread.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_circuit.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_events.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_route.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_tlv.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_csm.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_flags.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_misc.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isisd.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_adjacency.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_dynhn.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_spf.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-iso_checksum.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_lsp.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis_pdu.o
#   inflating: pmacct-1.7.8/src/isis/.libs/libpmisis_la-isis-globals.o
#     linking: pmacct-1.7.8/src/isis/.libs/libpmisis.la  -> ../libpmisis.la
#    creating: pmacct-1.7.8/src/ebpf/
#   inflating: pmacct-1.7.8/src/ebpf/ebpf_rp_balancer.c
#   inflating: pmacct-1.7.8/src/ebpf/ebpf_rp_balancer.h
#   inflating: pmacct-1.7.8/src/ebpf/Makefile.in
#   inflating: pmacct-1.7.8/src/ebpf/Makefile.am
#   inflating: pmacct-1.7.8/src/ebpf/Makefile
#   inflating: pmacct-1.7.8/src/ebpf/libpmebpf_la-ebpf_rp_balancer.o
#   inflating: pmacct-1.7.8/src/ebpf/libpmebpf_la-ebpf_rp_balancer.lo
#   inflating: pmacct-1.7.8/src/ebpf/libpmebpf.la
#    creating: pmacct-1.7.8/src/ebpf/.deps/
#   inflating: pmacct-1.7.8/src/ebpf/.deps/libpmebpf_la-ebpf_rp_balancer.Plo
#    creating: pmacct-1.7.8/src/ebpf/.libs/
#   inflating: pmacct-1.7.8/src/ebpf/.libs/libpmebpf.a
#   inflating: pmacct-1.7.8/src/ebpf/.libs/libpmebpf_la-ebpf_rp_balancer.o
#     linking: pmacct-1.7.8/src/ebpf/.libs/libpmebpf.la  -> ../libpmebpf.la
#    creating: pmacct-1.7.8/src/nfprobe_plugin/
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/nfprobe_plugin.h
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/convtime.c
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/nfprobe_plugin.c
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/common.h
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/netflow5.c
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/treetype.h
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/sys-tree.h
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/netflow9.c
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/convtime.h
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/Makefile.in
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/Makefile.am
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/Makefile
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin.la
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin_la-nfprobe_plugin.o
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin_la-nfprobe_plugin.lo
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin_la-netflow5.o
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin_la-netflow5.lo
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin_la-netflow9.o
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin_la-netflow9.lo
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin_la-convtime.o
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/libnfprobe_plugin_la-convtime.lo
#    creating: pmacct-1.7.8/src/nfprobe_plugin/.deps/
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.deps/libnfprobe_plugin_la-nfprobe_plugin.Plo
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.deps/libnfprobe_plugin_la-netflow5.Plo
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.deps/libnfprobe_plugin_la-convtime.Plo
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.deps/libnfprobe_plugin_la-netflow9.Plo
#    creating: pmacct-1.7.8/src/nfprobe_plugin/.libs/
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.libs/libnfprobe_plugin.a
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.libs/libnfprobe_plugin_la-nfprobe_plugin.o
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.libs/libnfprobe_plugin_la-netflow5.o
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.libs/libnfprobe_plugin_la-netflow9.o
#   inflating: pmacct-1.7.8/src/nfprobe_plugin/.libs/libnfprobe_plugin_la-convtime.o
#     linking: pmacct-1.7.8/src/nfprobe_plugin/.libs/libnfprobe_plugin.la  -> ../libnfprobe_plugin.la
#    creating: pmacct-1.7.8/src/.deps/
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-cfg.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-amqp_common.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-amqp_plugin.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-linklist.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-log.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-print_plugin.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-xflow_status.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-plugin_common.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-pkt_handlers.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-classifier.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-ip_flow.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-kafka_common.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-kafka_plugin.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-plugin_cmn_custom.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-pmsearch.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-cfg_handlers.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-imt_plugin.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-mongodb_plugin.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-mysql_plugin.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-pretag.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-base64.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-pgsql_plugin.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-net_aggr.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-plugin_cmn_avro.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-pmacct-globals.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-plugin_cmn_json.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-ll.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-acct.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-thread_pool.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-nl.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-pretag_handlers.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-setproctitle.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-ip_frag.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-redis_common.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-memory.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-conntrack.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-plugin_hooks.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-sql_common.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-sql_common_m.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-sql_handlers.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-sqlite3_plugin.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-network.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-server.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-preprocess.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-zmq_common.Plo
#   inflating: pmacct-1.7.8/src/.deps/sfacctd.Po
#   inflating: pmacct-1.7.8/src/.deps/libcommon_la-strlcpy.Plo
#   inflating: pmacct-1.7.8/src/.deps/sfv5_module.Po
#   inflating: pmacct-1.7.8/src/.deps/pmtelemetryd.Po
#   inflating: pmacct-1.7.8/src/.deps/uacctd-uacctd.Po
#   inflating: pmacct-1.7.8/src/.deps/pmacct.Po
#   inflating: pmacct-1.7.8/src/.deps/libcommon_la-addr.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-signals.Plo
#   inflating: pmacct-1.7.8/src/.deps/libdaemons_la-util.Plo
#   inflating: pmacct-1.7.8/src/.deps/pmacctd.Po
#   inflating: pmacct-1.7.8/src/.deps/nfacctd.Po
#   inflating: pmacct-1.7.8/src/.deps/nfv9_template.Po
#   inflating: pmacct-1.7.8/src/.deps/sflow.Po
#   inflating: pmacct-1.7.8/src/.deps/pmbgpd.Po
#   inflating: pmacct-1.7.8/src/.deps/pmbmpd.Po
#    creating: pmacct-1.7.8/src/.libs/
#   inflating: pmacct-1.7.8/src/.libs/libcommon.a
#     linking: pmacct-1.7.8/src/.libs/libdaemons.la  -> ../libdaemons.la
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-pretag_handlers.o
#   inflating: pmacct-1.7.8/src/.libs/libcommon_la-strlcpy.o
#   inflating: pmacct-1.7.8/src/.libs/libcommon_la-addr.o
#     linking: pmacct-1.7.8/src/.libs/libcommon.la  -> ../libcommon.la
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-signals.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-util.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-plugin_hooks.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-server.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-acct.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-memory.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-cfg.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-imt_plugin.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-log.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-pkt_handlers.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-cfg_handlers.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-net_aggr.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-print_plugin.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-pretag.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-ip_frag.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-ip_flow.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-setproctitle.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-classifier.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-conntrack.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-xflow_status.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-plugin_common.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-preprocess.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-ll.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-nl.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-base64.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-pmsearch.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-linklist.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-thread_pool.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-plugin_cmn_custom.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-network.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons_la-pmacct-globals.o
#   inflating: pmacct-1.7.8/src/.libs/libdaemons.a
# finishing deferred symbolic links:
#   pmacct-1.7.8/examples/custom/.libs/libcustom.la -> ../libcustom.la
#   pmacct-1.7.8/src/rpki/.libs/libpmrpki.la -> ../libpmrpki.la
#   pmacct-1.7.8/src/sfprobe_plugin/.libs/libsfprobe_plugin.la -> ../libsfprobe_plugin.la
#   pmacct-1.7.8/src/bgp/.libs/libpmbgp.la -> ../libpmbgp.la
#   pmacct-1.7.8/src/bmp/.libs/libpmbmp.la -> ../libpmbmp.la
#   pmacct-1.7.8/src/filters/.libs/libpmfilters.la -> ../libpmfilters.la
#   pmacct-1.7.8/src/external_libs/libcdada/build/src/.libs/libcdada.la -> ../libcdada.la
#   pmacct-1.7.8/src/external_libs/libcdada/examples/custom-macro/bar.h -> ../custom-gen/bar.h
#   pmacct-1.7.8/src/external_libs/libcdada/examples/custom-macro/foo.h -> ../custom-gen/foo.h
#   pmacct-1.7.8/src/external_libs/libcdada/examples/custom-macro/my_program.c -> ../custom-gen/my_program_gen.c
#   pmacct-1.7.8/src/telemetry/.libs/libpmtelemetry.la -> ../libpmtelemetry.la
#   pmacct-1.7.8/src/tee_plugin/.libs/libtee_plugin.la -> ../libtee_plugin.la
#   pmacct-1.7.8/src/isis/.libs/libpmisis.la -> ../libpmisis.la
#   pmacct-1.7.8/src/ebpf/.libs/libpmebpf.la -> ../libpmebpf.la
#   pmacct-1.7.8/src/nfprobe_plugin/.libs/libnfprobe_plugin.la -> ../libnfprobe_plugin.la
#   pmacct-1.7.8/src/.libs/libdaemons.la -> ../libdaemons.la
#   pmacct-1.7.8/src/.libs/libcommon.la -> ../libcommon.la
# ('', '')

# %% [markdown]
# ##### Jansson library installation
# The following code installs the jansson library on the nodes. This library is needed so that the pmacctd tool can diplay the information of the results on the experiments in a JSON format.

# %%
## Installation of jansson library
n1.execute("cd jansson-2.13 && ./configure && make && sudo make install")
n2.execute("cd jansson-2.13 && ./configure && make && sudo make install")
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... gawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking whether make supports the include directive... yes (GNU style)
# checking dependency style of gcc... gcc3
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking how to print strings... printf
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s
#
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# checking for a working dd... /usr/bin/dd
# checking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1
# checking for mt... mt
# checking if mt is a manifest tool... no
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking how to run the C++ preprocessor... g++ -E
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC -DPIC
# checking if g++ PIC flag -fPIC -DPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking if g++ supports -c -o file.o... (cached) yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking endian.h usability... yes
# checking endian.h presence... yes
# checking for endian.h... yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking sched.h usability... yes
# checking sched.h presence... yes
# checking for sched.h... yes
# checking for unistd.h... (cached) yes
# checking sys/param.h usability... yes
# checking sys/param.h presence... yes
# checking for sys/param.h... yes
# checking for sys/stat.h... (cached) yes
# checking sys/time.h usability... yes
# checking sys/time.h presence... yes
# checking for sys/time.h... yes
# checking for sys/types.h... (cached) yes
# checking for int32_t... yes
# checking for uint32_t... yes
# checking for uint16_t... yes
# checking for uint8_t... yes
# checking for unsigned long long int... yes
# checking for long long int... yes
# checking for inline... inline
# checking for close... yes
# checking for getpid... yes
# checking for gettimeofday... yes
# checking for localeconv... yes
# checking for open... yes
# checking for read... yes
# checking for sched_yield... yes
# checking for strtoll... yes
# checking for gcc __sync builtins... yes
# checking for gcc __atomic builtins... yes
# checking for -Bsymbolic-functions linker flag... yes
# checking for -Wno-format-truncation... yes
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating jansson.pc
# config.status: creating Makefile
# config.status: creating doc/Makefile
# config.status: creating src/Makefile
# config.status: creating src/jansson_config.h
# config.status: creating test/Makefile
# config.status: creating test/bin/Makefile
# config.status: creating test/ossfuzz/Makefile
# config.status: creating test/suites/Makefile
# config.status: creating test/suites/api/Makefile
# config.status: creating jansson_private_config.h
# config.status: executing depfiles commands
# config.status: executing libtool commands
# make  all-recursive
# make[1]: Entering directory '/home/ubuntu/jansson-2.13'
# Making all in doc
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/doc'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/doc'
# Making all in src
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/src'
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT dump.lo -MD -MP -MF .deps/dump.Tpo -c -o dump.lo dump.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT dump.lo -MD -MP -MF .deps/dump.Tpo -c dump.c  -fPIC -DPIC -o .libs/dump.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT dump.lo -MD -MP -MF .deps/dump.Tpo -c dump.c -o dump.o >/dev/null 2>&1
# mv -f .deps/dump.Tpo .deps/dump.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT error.lo -MD -MP -MF .deps/error.Tpo -c -o error.lo error.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT error.lo -MD -MP -MF .deps/error.Tpo -c error.c  -fPIC -DPIC -o .libs/error.o
#  In file included from /usr/include/string.h:495,
#                  from error.c:2:
# In function ‘strncpy’,
#     inlined from ‘jsonp_error_set_source’ at error.c:25:9,
#     inlined from ‘jsonp_error_set_source’ at error.c:17:6:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:106:10: warning: ‘__builtin___strncpy_chk’ specified bound depends on the length of the source argument [-Wstringop-overflow=]
#   106 |   return __builtin___strncpy_chk (__dest, __src, __len, __bos (__dest));
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   error.c: In function ‘jsonp_error_set_source’:
# error.c:23:14: note: length computed here
#    23 |     length = strlen(source);
#       |              ^~~~~~~~~~~~~~
#  libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT error.lo -MD -MP -MF .deps/error.Tpo -c error.c -o error.o >/dev/null 2>&1
# mv -f .deps/error.Tpo .deps/error.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable.lo -MD -MP -MF .deps/hashtable.Tpo -c -o hashtable.lo hashtable.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable.lo -MD -MP -MF .deps/hashtable.Tpo -c hashtable.c  -fPIC -DPIC -o .libs/hashtable.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable.lo -MD -MP -MF .deps/hashtable.Tpo -c hashtable.c -o hashtable.o >/dev/null 2>&1
# mv -f .deps/hashtable.Tpo .deps/hashtable.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable_seed.lo -MD -MP -MF .deps/hashtable_seed.Tpo -c -o hashtable_seed.lo hashtable_seed.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable_seed.lo -MD -MP -MF .deps/hashtable_seed.Tpo -c hashtable_seed.c  -fPIC -DPIC -o .libs/hashtable_seed.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable_seed.lo -MD -MP -MF .deps/hashtable_seed.Tpo -c hashtable_seed.c -o hashtable_seed.o >/dev/null 2>&1
# mv -f .deps/hashtable_seed.Tpo .deps/hashtable_seed.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT load.lo -MD -MP -MF .deps/load.Tpo -c -o load.lo load.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT load.lo -MD -MP -MF .deps/load.Tpo -c load.c  -fPIC -DPIC -o .libs/load.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT load.lo -MD -MP -MF .deps/load.Tpo -c load.c -o load.o >/dev/null 2>&1
# mv -f .deps/load.Tpo .deps/load.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT memory.lo -MD -MP -MF .deps/memory.Tpo -c -o memory.lo memory.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT memory.lo -MD -MP -MF .deps/memory.Tpo -c memory.c  -fPIC -DPIC -o .libs/memory.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT memory.lo -MD -MP -MF .deps/memory.Tpo -c memory.c -o memory.o >/dev/null 2>&1
# mv -f .deps/memory.Tpo .deps/memory.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT pack_unpack.lo -MD -MP -MF .deps/pack_unpack.Tpo -c -o pack_unpack.lo pack_unpack.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT pack_unpack.lo -MD -MP -MF .deps/pack_unpack.Tpo -c pack_unpack.c  -fPIC -DPIC -o .libs/pack_unpack.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT pack_unpack.lo -MD -MP -MF .deps/pack_unpack.Tpo -c pack_unpack.c -o pack_unpack.o >/dev/null 2>&1
# mv -f .deps/pack_unpack.Tpo .deps/pack_unpack.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strbuffer.lo -MD -MP -MF .deps/strbuffer.Tpo -c -o strbuffer.lo strbuffer.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strbuffer.lo -MD -MP -MF .deps/strbuffer.Tpo -c strbuffer.c  -fPIC -DPIC -o .libs/strbuffer.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strbuffer.lo -MD -MP -MF .deps/strbuffer.Tpo -c strbuffer.c -o strbuffer.o >/dev/null 2>&1
# mv -f .deps/strbuffer.Tpo .deps/strbuffer.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strconv.lo -MD -MP -MF .deps/strconv.Tpo -c -o strconv.lo strconv.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strconv.lo -MD -MP -MF .deps/strconv.Tpo -c strconv.c  -fPIC -DPIC -o .libs/strconv.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strconv.lo -MD -MP -MF .deps/strconv.Tpo -c strconv.c -o strconv.o >/dev/null 2>&1
# mv -f .deps/strconv.Tpo .deps/strconv.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT utf.lo -MD -MP -MF .deps/utf.Tpo -c -o utf.lo utf.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT utf.lo -MD -MP -MF .deps/utf.Tpo -c utf.c  -fPIC -DPIC -o .libs/utf.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT utf.lo -MD -MP -MF .deps/utf.Tpo -c utf.c -o utf.o >/dev/null 2>&1
# mv -f .deps/utf.Tpo .deps/utf.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT value.lo -MD -MP -MF .deps/value.Tpo -c -o value.lo value.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT value.lo -MD -MP -MF .deps/value.Tpo -c value.c  -fPIC -DPIC -o .libs/value.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT value.lo -MD -MP -MF .deps/value.Tpo -c value.c -o value.o >/dev/null 2>&1
# mv -f .deps/value.Tpo .deps/value.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT version.lo -MD -MP -MF .deps/version.Tpo -c -o version.lo version.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT version.lo -MD -MP -MF .deps/version.Tpo -c version.c  -fPIC -DPIC -o .libs/version.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT version.lo -MD -MP -MF .deps/version.Tpo -c version.c -o version.o >/dev/null 2>&1
# mv -f .deps/version.Tpo .deps/version.Plo
# /bin/bash ../libtool  --tag=CC   --mode=link gcc -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -no-undefined -export-symbols-regex '^json_' -version-info 16:0:12 -Wl,-Bsymbolic-functions  -o libjansson.la -rpath /usr/local/lib dump.lo error.lo hashtable.lo hashtable_seed.lo load.lo memory.lo pack_unpack.lo strbuffer.lo strconv.lo utf.lo value.lo version.lo
# libtool: link: /usr/bin/nm -B  .libs/dump.o .libs/error.o .libs/hashtable.o .libs/hashtable_seed.o .libs/load.o .libs/memory.o .libs/pack_unpack.o .libs/strbuffer.o .libs/strconv.o .libs/utf.o .libs/value.o .libs/version.o   | sed -n -e 's/^.*[	 ]\([ABCDGIRSTW][ABCDGIRSTW]*\)[	 ][	 ]*\([_A-Za-z][_A-Za-z0-9]*\)$/\1 \2 \2/p' | sed '/ __gnu_lto/d' | /usr/bin/sed 's/.* //' | sort | uniq > .libs/libjansson.exp
# libtool: link: /usr/bin/grep -E -e "^json_" ".libs/libjansson.exp" > ".libs/libjansson.expT"
# libtool: link: mv -f ".libs/libjansson.expT" ".libs/libjansson.exp"
# libtool: link: echo "{ global:" > .libs/libjansson.ver
# libtool: link:  cat .libs/libjansson.exp | sed -e "s/\(.*\)/\1;/" >> .libs/libjansson.ver
# libtool: link:  echo "local: *; };" >> .libs/libjansson.ver
# libtool: link:  gcc -shared  -fPIC -DPIC  .libs/dump.o .libs/error.o .libs/hashtable.o .libs/hashtable_seed.o .libs/load.o .libs/memory.o .libs/pack_unpack.o .libs/strbuffer.o .libs/strconv.o .libs/utf.o .libs/value.o .libs/version.o    -g -O2 -Wl,-Bsymbolic-functions   -Wl,-soname -Wl,libjansson.so.4 -Wl,-version-script -Wl,.libs/libjansson.ver -o .libs/libjansson.so.4.12.0
# libtool: link: (cd ".libs" && rm -f "libjansson.so.4" && ln -s "libjansson.so.4.12.0" "libjansson.so.4")
# libtool: link: (cd ".libs" && rm -f "libjansson.so" && ln -s "libjansson.so.4.12.0" "libjansson.so")
# libtool: link: ar cr .libs/libjansson.a  dump.o error.o hashtable.o hashtable_seed.o load.o memory.o pack_unpack.o strbuffer.o strconv.o utf.o value.o version.o
# libtool: link: ranlib .libs/libjansson.a
# libtool: link: ( cd ".libs" && rm -f "libjansson.la" && ln -s "../libjansson.la" "libjansson.la" )
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/src'
# Making all in test
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test'
# Making all in bin
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/bin'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/bin'
# Making all in suites
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# Making all in api
# make[4]: Entering directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[4]: Nothing to be done for 'all'.
# make[4]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[4]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# make[4]: Nothing to be done for 'all-am'.
# make[4]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# Making all in ossfuzz
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test'
# make[3]: Nothing to be done for 'all-am'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13'
# Making install in doc
# make[1]: Entering directory '/home/ubuntu/jansson-2.13/doc'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/doc'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/doc'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13/doc'
# Making install in src
# make[1]: Entering directory '/home/ubuntu/jansson-2.13/src'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/src'
#  /usr/bin/mkdir -p '/usr/local/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libjansson.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libjansson.so.4.12.0 /usr/local/lib/libjansson.so.4.12.0
# libtool: install: (cd /usr/local/lib && { ln -s -f libjansson.so.4.12.0 libjansson.so.4 || { rm -f libjansson.so.4 && ln -s libjansson.so.4.12.0 libjansson.so.4; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libjansson.so.4.12.0 libjansson.so || { rm -f libjansson.so && ln -s libjansson.so.4.12.0 libjansson.so; }; })
# libtool: install: /usr/bin/install -c .libs/libjansson.lai /usr/local/lib/libjansson.la
# libtool: install: /usr/bin/install -c .libs/libjansson.a /usr/local/lib/libjansson.a
# libtool: install: chmod 644 /usr/local/lib/libjansson.a
# libtool: install: ranlib /usr/local/lib/libjansson.a
# libtool: finish: PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/sbin" ldconfig -n /usr/local/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/local/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /usr/bin/mkdir -p '/usr/local/include'
#  /usr/bin/install -c -m 644 jansson.h '/usr/local/include'
#  /usr/bin/mkdir -p '/usr/local/include'
#  /usr/bin/install -c -m 644 jansson_config.h '/usr/local/include'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/src'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13/src'
# Making install in test
# make[1]: Entering directory '/home/ubuntu/jansson-2.13/test'
# Making install in bin
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test/bin'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/bin'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/bin'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test/bin'
# Making install in suites
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# Making install in api
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[4]: Entering directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# make[4]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# Making install in ossfuzz
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[1]: Entering directory '/home/ubuntu/jansson-2.13'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13'
# make[2]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/lib/pkgconfig'
#  /usr/bin/install -c -m 644 jansson.pc '/usr/local/lib/pkgconfig'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13'
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... gawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking whether make supports the include directive... yes (GNU style)
# checking dependency style of gcc... gcc3
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking how to print strings... printf
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s
#
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# checking for a working dd... /usr/bin/dd
# checking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1
# checking for mt... mt
# checking if mt is a manifest tool... no
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking how to run the C++ preprocessor... g++ -E
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC -DPIC
# checking if g++ PIC flag -fPIC -DPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking if g++ supports -c -o file.o... (cached) yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking endian.h usability... yes
# checking endian.h presence... yes
# checking for endian.h... yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking sched.h usability... yes
# checking sched.h presence... yes
# checking for sched.h... yes
# checking for unistd.h... (cached) yes
# checking sys/param.h usability... yes
# checking sys/param.h presence... yes
# checking for sys/param.h... yes
# checking for sys/stat.h... (cached) yes
# checking sys/time.h usability... yes
# checking sys/time.h presence... yes
# checking for sys/time.h... yes
# checking for sys/types.h... (cached) yes
# checking for int32_t... yes
# checking for uint32_t... yes
# checking for uint16_t... yes
# checking for uint8_t... yes
# checking for unsigned long long int... yes
# checking for long long int... yes
# checking for inline... inline
# checking for close... yes
# checking for getpid... yes
# checking for gettimeofday... yes
# checking for localeconv... yes
# checking for open... yes
# checking for read... yes
# checking for sched_yield... yes
# checking for strtoll... yes
# checking for gcc __sync builtins... yes
# checking for gcc __atomic builtins... yes
# checking for -Bsymbolic-functions linker flag... yes
# checking for -Wno-format-truncation... yes
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating jansson.pc
# config.status: creating Makefile
# config.status: creating doc/Makefile
# config.status: creating src/Makefile
# config.status: creating src/jansson_config.h
# config.status: creating test/Makefile
# config.status: creating test/bin/Makefile
# config.status: creating test/ossfuzz/Makefile
# config.status: creating test/suites/Makefile
# config.status: creating test/suites/api/Makefile
# config.status: creating jansson_private_config.h
# config.status: executing depfiles commands
# config.status: executing libtool commands
# make  all-recursive
# make[1]: Entering directory '/home/ubuntu/jansson-2.13'
# Making all in doc
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/doc'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/doc'
# Making all in src
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/src'
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT dump.lo -MD -MP -MF .deps/dump.Tpo -c -o dump.lo dump.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT dump.lo -MD -MP -MF .deps/dump.Tpo -c dump.c  -fPIC -DPIC -o .libs/dump.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT dump.lo -MD -MP -MF .deps/dump.Tpo -c dump.c -o dump.o >/dev/null 2>&1
# mv -f .deps/dump.Tpo .deps/dump.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT error.lo -MD -MP -MF .deps/error.Tpo -c -o error.lo error.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT error.lo -MD -MP -MF .deps/error.Tpo -c error.c  -fPIC -DPIC -o .libs/error.o
#  In file included from /usr/include/string.h:495,
#                  from error.c:2:
# In function ‘strncpy’,
#     inlined from ‘jsonp_error_set_source’ at error.c:25:9,
#     inlined from ‘jsonp_error_set_source’ at error.c:17:6:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:106:10: warning: ‘__builtin___strncpy_chk’ specified bound depends on the length of the source argument [-Wstringop-overflow=]
#   106 |   return __builtin___strncpy_chk (__dest, __src, __len, __bos (__dest));
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# error.c: In function ‘jsonp_error_set_source’:
# error.c:23:14: note: length computed here
#    23 |     length = strlen(source);
#       |              ^~~~~~~~~~~~~~
#  libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT error.lo -MD -MP -MF .deps/error.Tpo -c error.c -o error.o >/dev/null 2>&1
# mv -f .deps/error.Tpo .deps/error.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable.lo -MD -MP -MF .deps/hashtable.Tpo -c -o hashtable.lo hashtable.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable.lo -MD -MP -MF .deps/hashtable.Tpo -c hashtable.c  -fPIC -DPIC -o .libs/hashtable.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable.lo -MD -MP -MF .deps/hashtable.Tpo -c hashtable.c -o hashtable.o >/dev/null 2>&1
# mv -f .deps/hashtable.Tpo .deps/hashtable.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable_seed.lo -MD -MP -MF .deps/hashtable_seed.Tpo -c -o hashtable_seed.lo hashtable_seed.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable_seed.lo -MD -MP -MF .deps/hashtable_seed.Tpo -c hashtable_seed.c  -fPIC -DPIC -o .libs/hashtable_seed.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT hashtable_seed.lo -MD -MP -MF .deps/hashtable_seed.Tpo -c hashtable_seed.c -o hashtable_seed.o >/dev/null 2>&1
# mv -f .deps/hashtable_seed.Tpo .deps/hashtable_seed.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT load.lo -MD -MP -MF .deps/load.Tpo -c -o load.lo load.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT load.lo -MD -MP -MF .deps/load.Tpo -c load.c  -fPIC -DPIC -o .libs/load.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT load.lo -MD -MP -MF .deps/load.Tpo -c load.c -o load.o >/dev/null 2>&1
# mv -f .deps/load.Tpo .deps/load.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT memory.lo -MD -MP -MF .deps/memory.Tpo -c -o memory.lo memory.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT memory.lo -MD -MP -MF .deps/memory.Tpo -c memory.c  -fPIC -DPIC -o .libs/memory.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT memory.lo -MD -MP -MF .deps/memory.Tpo -c memory.c -o memory.o >/dev/null 2>&1
# mv -f .deps/memory.Tpo .deps/memory.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT pack_unpack.lo -MD -MP -MF .deps/pack_unpack.Tpo -c -o pack_unpack.lo pack_unpack.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT pack_unpack.lo -MD -MP -MF .deps/pack_unpack.Tpo -c pack_unpack.c  -fPIC -DPIC -o .libs/pack_unpack.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT pack_unpack.lo -MD -MP -MF .deps/pack_unpack.Tpo -c pack_unpack.c -o pack_unpack.o >/dev/null 2>&1
# mv -f .deps/pack_unpack.Tpo .deps/pack_unpack.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strbuffer.lo -MD -MP -MF .deps/strbuffer.Tpo -c -o strbuffer.lo strbuffer.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strbuffer.lo -MD -MP -MF .deps/strbuffer.Tpo -c strbuffer.c  -fPIC -DPIC -o .libs/strbuffer.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strbuffer.lo -MD -MP -MF .deps/strbuffer.Tpo -c strbuffer.c -o strbuffer.o >/dev/null 2>&1
# mv -f .deps/strbuffer.Tpo .deps/strbuffer.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strconv.lo -MD -MP -MF .deps/strconv.Tpo -c -o strconv.lo strconv.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strconv.lo -MD -MP -MF .deps/strconv.Tpo -c strconv.c  -fPIC -DPIC -o .libs/strconv.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT strconv.lo -MD -MP -MF .deps/strconv.Tpo -c strconv.c -o strconv.o >/dev/null 2>&1
# mv -f .deps/strconv.Tpo .deps/strconv.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT utf.lo -MD -MP -MF .deps/utf.Tpo -c -o utf.lo utf.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT utf.lo -MD -MP -MF .deps/utf.Tpo -c utf.c  -fPIC -DPIC -o .libs/utf.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT utf.lo -MD -MP -MF .deps/utf.Tpo -c utf.c -o utf.o >/dev/null 2>&1
# mv -f .deps/utf.Tpo .deps/utf.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT value.lo -MD -MP -MF .deps/value.Tpo -c -o value.lo value.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT value.lo -MD -MP -MF .deps/value.Tpo -c value.c  -fPIC -DPIC -o .libs/value.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT value.lo -MD -MP -MF .deps/value.Tpo -c value.c -o value.o >/dev/null 2>&1
# mv -f .deps/value.Tpo .deps/value.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I..    -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT version.lo -MD -MP -MF .deps/version.Tpo -c -o version.lo version.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT version.lo -MD -MP -MF .deps/version.Tpo -c version.c  -fPIC -DPIC -o .libs/version.o
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -MT version.lo -MD -MP -MF .deps/version.Tpo -c version.c -o version.o >/dev/null 2>&1
# mv -f .deps/version.Tpo .deps/version.Plo
# /bin/bash ../libtool  --tag=CC   --mode=link gcc -Wall -Wextra -Wdeclaration-after-statement -Wshadow -Wno-format-truncation -g -O2 -no-undefined -export-symbols-regex '^json_' -version-info 16:0:12 -Wl,-Bsymbolic-functions  -o libjansson.la -rpath /usr/local/lib dump.lo error.lo hashtable.lo hashtable_seed.lo load.lo memory.lo pack_unpack.lo strbuffer.lo strconv.lo utf.lo value.lo version.lo
# libtool: link: /usr/bin/nm -B  .libs/dump.o .libs/error.o .libs/hashtable.o .libs/hashtable_seed.o .libs/load.o .libs/memory.o .libs/pack_unpack.o .libs/strbuffer.o .libs/strconv.o .libs/utf.o .libs/value.o .libs/version.o   | sed -n -e 's/^.*[	 ]\([ABCDGIRSTW][ABCDGIRSTW]*\)[	 ][	 ]*\([_A-Za-z][_A-Za-z0-9]*\)$/\1 \2 \2/p' | sed '/ __gnu_lto/d' | /usr/bin/sed 's/.* //' | sort | uniq > .libs/libjansson.exp
# libtool: link: /usr/bin/grep -E -e "^json_" ".libs/libjansson.exp" > ".libs/libjansson.expT"
# libtool: link: mv -f ".libs/libjansson.expT" ".libs/libjansson.exp"
# libtool: link: echo "{ global:" > .libs/libjansson.ver
# libtool: link:  cat .libs/libjansson.exp | sed -e "s/\(.*\)/\1;/" >> .libs/libjansson.ver
# libtool: link:  echo "local: *; };" >> .libs/libjansson.ver
# libtool: link:  gcc -shared  -fPIC -DPIC  .libs/dump.o .libs/error.o .libs/hashtable.o .libs/hashtable_seed.o .libs/load.o .libs/memory.o .libs/pack_unpack.o .libs/strbuffer.o .libs/strconv.o .libs/utf.o .libs/value.o .libs/version.o    -g -O2 -Wl,-Bsymbolic-functions   -Wl,-soname -Wl,libjansson.so.4 -Wl,-version-script -Wl,.libs/libjansson.ver -o .libs/libjansson.so.4.12.0
# libtool: link: (cd ".libs" && rm -f "libjansson.so.4" && ln -s "libjansson.so.4.12.0" "libjansson.so.4")
# libtool: link: (cd ".libs" && rm -f "libjansson.so" && ln -s "libjansson.so.4.12.0" "libjansson.so")
# libtool: link: ar cr .libs/libjansson.a  dump.o error.o hashtable.o hashtable_seed.o load.o memory.o pack_unpack.o strbuffer.o strconv.o utf.o value.o version.o
# libtool: link: ranlib .libs/libjansson.a
# libtool: link: ( cd ".libs" && rm -f "libjansson.la" && ln -s "../libjansson.la" "libjansson.la" )
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/src'
# Making all in test
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test'
# Making all in bin
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/bin'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/bin'
# Making all in suites
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# Making all in api
# make[4]: Entering directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[4]: Nothing to be done for 'all'.
# make[4]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[4]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# make[4]: Nothing to be done for 'all-am'.
# make[4]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# Making all in ossfuzz
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test'
# make[3]: Nothing to be done for 'all-am'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13'
# Making install in doc
# make[1]: Entering directory '/home/ubuntu/jansson-2.13/doc'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/doc'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/doc'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13/doc'
# Making install in src
# make[1]: Entering directory '/home/ubuntu/jansson-2.13/src'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/src'
#  /usr/bin/mkdir -p '/usr/local/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libjansson.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libjansson.so.4.12.0 /usr/local/lib/libjansson.so.4.12.0
# libtool: install: (cd /usr/local/lib && { ln -s -f libjansson.so.4.12.0 libjansson.so.4 || { rm -f libjansson.so.4 && ln -s libjansson.so.4.12.0 libjansson.so.4; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libjansson.so.4.12.0 libjansson.so || { rm -f libjansson.so && ln -s libjansson.so.4.12.0 libjansson.so; }; })
# libtool: install: /usr/bin/install -c .libs/libjansson.lai /usr/local/lib/libjansson.la
# libtool: install: /usr/bin/install -c .libs/libjansson.a /usr/local/lib/libjansson.a
# libtool: install: chmod 644 /usr/local/lib/libjansson.a
# libtool: install: ranlib /usr/local/lib/libjansson.a
# libtool: finish: PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/sbin" ldconfig -n /usr/local/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/local/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /usr/bin/mkdir -p '/usr/local/include'
#  /usr/bin/install -c -m 644 jansson.h '/usr/local/include'
#  /usr/bin/mkdir -p '/usr/local/include'
#  /usr/bin/install -c -m 644 jansson_config.h '/usr/local/include'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/src'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13/src'
# Making install in test
# make[1]: Entering directory '/home/ubuntu/jansson-2.13/test'
# Making install in bin
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test/bin'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/bin'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/bin'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test/bin'
# Making install in suites
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# Making install in api
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[4]: Entering directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites/api'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# make[4]: Entering directory '/home/ubuntu/jansson-2.13/test/suites'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test/suites'
# Making install in ossfuzz
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test/ossfuzz'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13/test'
# make[3]: Entering directory '/home/ubuntu/jansson-2.13/test'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13/test'
# make[1]: Entering directory '/home/ubuntu/jansson-2.13'
# make[2]: Entering directory '/home/ubuntu/jansson-2.13'
# make[2]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/lib/pkgconfig'
#  /usr/bin/install -c -m 644 jansson.pc '/usr/local/lib/pkgconfig'
# make[2]: Leaving directory '/home/ubuntu/jansson-2.13'
# make[1]: Leaving directory '/home/ubuntu/jansson-2.13'
# ('checking for a BSD-compatible install... /usr/bin/install -c\nchecking whether build environment is sane... yes\nchecking for a thread-safe mkdir -p... /usr/bin/mkdir -p\nchecking for gawk... gawk\nchecking whether make sets $(MAKE)... yes\nchecking whether make supports nested variables... yes\nchecking for gcc... gcc\nchecking whether the C compiler works... yes\nchecking for C compiler default output file name... a.out\nchecking for suffix of executables... \nchecking whether we are cross compiling... no\nchecking for suffix of object files... o\nchecking whether we are using the GNU C compiler... yes\nchecking whether gcc accepts -g... yes\nchecking for gcc option to accept ISO C89... none needed\nchecking whether gcc understands -c and -o together... yes\nchecking whether make supports the include directive... yes (GNU style)\nchecking dependency style of gcc... gcc3\nchecking for g++... g++\nchecking whether we are using the GNU C++ compiler... yes\nchecking whether g++ accepts -g... yes\nchecking dependency style of g++... gcc3\nchecking build system type... x86_64-pc-linux-gnu\nchecking host system type... x86_64-pc-linux-gnu\nchecking how to print strings... printf\nchecking for a sed that does not truncate output... /usr/bin/sed\nchecking for grep that handles long lines and -e... /usr/bin/grep\nchecking for egrep... /usr/bin/grep -E\nchecking for fgrep... /usr/bin/grep -F\nchecking for ld used by gcc... /usr/bin/ld\nchecking if the linker (/usr/bin/ld) is GNU ld... yes\nchecking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B\nchecking the name lister (/usr/bin/nm -B) interface... BSD nm\nchecking whether ln -s works... yes\nchecking the maximum length of command line arguments... 1572864\nchecking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop\nchecking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop\nchecking for /usr/bin/ld option to reload object files... -r\nchecking for objdump... objdump\nchecking how to recognize dependent libraries... pass_all\nchecking for dlltool... no\nchecking how to associate runtime and link libraries... printf %s\\n\nchecking for ar... ar\nchecking for archiver @FILE support... @\nchecking for strip... strip\nchecking for ranlib... ranlib\nchecking command to parse /usr/bin/nm -B output from gcc object... ok\nchecking for sysroot... no\nchecking for a working dd... /usr/bin/dd\nchecking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1\nchecking for mt... mt\nchecking if mt is a manifest tool... no\nchecking how to run the C preprocessor... gcc -E\nchecking for ANSI C header files... yes\nchecking for sys/types.h... yes\nchecking for sys/stat.h... yes\nchecking for stdlib.h... yes\nchecking for string.h... yes\nchecking for memory.h... yes\nchecking for strings.h... yes\nchecking for inttypes.h... yes\nchecking for stdint.h... yes\nchecking for unistd.h... yes\nchecking for dlfcn.h... yes\nchecking for objdir... .libs\nchecking if gcc supports -fno-rtti -fno-exceptions... no\nchecking for gcc option to produce PIC... -fPIC -DPIC\nchecking if gcc PIC flag -fPIC -DPIC works... yes\nchecking if gcc static flag -static works... yes\nchecking if gcc supports -c -o file.o... yes\nchecking if gcc supports -c -o file.o... (cached) yes\nchecking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes\nchecking whether -lc should be explicitly linked in... no\nchecking dynamic linker characteristics... GNU/Linux ld.so\nchecking how to hardcode library paths into programs... immediate\nchecking whether stripping libraries is possible... yes\nchecking if libtool supports shared libraries... yes\nchecking whether to build shared libraries... yes\nchecking whether to build static libraries... yes\nchecking how to run the C++ preprocessor... g++ -E\nchecking for ld used by g++... /usr/bin/ld -m elf_x86_64\nchecking if the linker (/usr/bin/ld -m elf_ ...
#  'In file included from /usr/include/string.h:495,\n                 from error.c:2:\nIn function ‘strncpy’,\n    inlined from ‘jsonp_error_set_source’ at error.c:25:9,\n    inlined from ‘jsonp_error_set_source’ at error.c:17:6:\n/usr/include/x86_64-linux-gnu/bits/string_fortified.h:106:10: warning: ‘__builtin___strncpy_chk’ specified bound depends on the length of the source argument [-Wstringop-overflow=]\n  106 |   return __builtin___strncpy_chk (__dest, __src, __len, __bos (__dest));\n      |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\nerror.c: In function ‘jsonp_error_set_source’:\nerror.c:23:14: note: length computed here\n   23 |     length = strlen(source);\n      |              ^~~~~~~~~~~~~~\n')

# %% [markdown]
# ##### pmacctd installation
# The following code installs the neccesary dependencies for the use of the tool and then installs it following the commands.
#
# 1. Place on the pmacct folder (cd pmacct-1.7.8)
# 2. Run the command ./autogen.sh
# 3. Run the command ./configure --enable-jansson (so that the results can be created on a JSON format too)
# 4. Run the command make
# 5. Run the command make install (superuser privileges)

# %%
## Installation of pmacctd 

n1.execute("sudo apt-get install -y libpcap-dev pkg-config libtool autoconf automake make bash libstdc++6 g++ libjansson4")
n1.execute("cd pmacct-1.7.8 && ./autogen.sh && ./configure --enable-jansson && make && sudo make install")

n2.execute("sudo apt-get install -y libpcap-dev pkg-config libtool autoconf automake make bash libstdc++6 g++ libjansson4")
n2.execute("cd pmacct-1.7.8 && ./autogen.sh && ./configure --enable-jansson && make && sudo make install")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# g++ is already the newest version (4:9.3.0-1ubuntu2).
# g++ set to manually installed.
# make is already the newest version (4.2.1-1.2).
# make set to manually installed.
# bash is already the newest version (5.0-6ubuntu1.2).
# libstdc++6 is already the newest version (10.5.0-1ubuntu1~20.04).
# libstdc++6 set to manually installed.
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc gettext libtool-doc gfortran
#   | fortran95-compiler gcj-jdk m4-doc
# The following NEW packages will be installed:
#   autoconf automake autotools-dev libjansson4 libltdl-dev libpcap-dev
#   libpcap0.8-dev libtool m4 pkg-config
# 0 upgraded, 10 newly installed, 0 to remove and 96 not upgraded.
# Need to get 1727 kB of archives.
# After this operation, 7306 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 m4 amd64 1.4.18-4 [199 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 autoconf all 2.69-11.1 [321 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 automake all 1:1.16.1-4ubuntu6 [522 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libjansson4 amd64 2.12-1build1 [28.9 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libltdl-dev amd64 2.4.6-14 [162 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libpcap0.8-dev amd64 1.9.1-3 [244 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libpcap-dev amd64 1.9.1-3 [3484 B]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libtool all 2.4.6-14 [161 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 pkg-config amd64 0.29.1-0ubuntu4 [45.5 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#  Fetched 1727 kB in 1s (2889 kB/s)
#  dpkg-preconfigure: unable to re-open stdin:
#  Selecting previously unselected package m4.
# (Reading database ... 72307 files and directories currently installed.)
# Preparing to unpack .../0-m4_1.4.18-4_amd64.deb ...
# Unpacking m4 (1.4.18-4) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../1-autoconf_2.69-11.1_all.deb ...
# Unpacking autoconf (2.69-11.1) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../2-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../3-automake_1%3a1.16.1-4ubuntu6_all.deb ...
# Unpacking automake (1:1.16.1-4ubuntu6) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../4-libjansson4_2.12-1build1_amd64.deb ...
# Unpacking libjansson4:amd64 (2.12-1build1) ...
# Selecting previously unselected package libltdl-dev:amd64.
# Preparing to unpack .../5-libltdl-dev_2.4.6-14_amd64.deb ...
# Unpacking libltdl-dev:amd64 (2.4.6-14) ...
# Selecting previously unselected package libpcap0.8-dev:amd64.
# Preparing to unpack .../6-libpcap0.8-dev_1.9.1-3_amd64.deb ...
# Unpacking libpcap0.8-dev:amd64 (1.9.1-3) ...
# Selecting previously unselected package libpcap-dev:amd64.
# Preparing to unpack .../7-libpcap-dev_1.9.1-3_amd64.deb ...
# Unpacking libpcap-dev:amd64 (1.9.1-3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../8-libtool_2.4.6-14_all.deb ...
# Unpacking libtool (2.4.6-14) ...
# Selecting previously unselected package pkg-config.
# Preparing to unpack .../9-pkg-config_0.29.1-0ubuntu4_amd64.deb ...
# Unpacking pkg-config (0.29.1-0ubuntu4) ...
# Setting up libpcap0.8-dev:amd64 (1.9.1-3) ...
# Setting up m4 (1.4.18-4) ...
# Setting up libjansson4:amd64 (2.12-1build1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up pkg-config (0.29.1-0ubuntu4) ...
# Setting up autoconf (2.69-11.1) ...
# Setting up automake (1:1.16.1-4ubuntu6) ...
# update-alternatives: using /usr/bin/automake-1.16 to provide /usr/bin/automake (automake) in auto mode
# Setting up libpcap-dev:amd64 (1.9.1-3) ...
# Setting up libtool (2.4.6-14) ...
# Setting up libltdl-dev:amd64 (2.4.6-14) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.14) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for install-info (6.7.0.dfsg.2-5) ...
# autogen.sh: reconfigure with autoreconf
#  autoreconf: Entering directory `.'
#   autoreconf: configure.ac: not using Gettext
#   autoreconf: running: aclocal -I m4 --force -I m4
#   autoreconf: configure.ac: tracing
#   autoreconf: running: libtoolize --copy --force
#  libtoolize: putting auxiliary files in '.'.
# libtoolize: copying file './ltmain.sh'
# libtoolize: putting macros in AC_CONFIG_MACRO_DIRS, 'm4'.
# libtoolize: copying file 'm4/libtool.m4'
# libtoolize: copying file 'm4/ltoptions.m4'
# libtoolize: copying file 'm4/ltsugar.m4'
# libtoolize: copying file 'm4/ltversion.m4'
# libtoolize: copying file 'm4/lt~obsolete.m4'
#  autoreconf: running: /usr/bin/autoconf --include=m4 --force
#   autoreconf: configure.ac: not using Autoheader
# autoreconf: running: automake --add-missing --copy --force-missing
#   configure.ac:8: installing './compile'
#   configure.ac:6: installing './missing'
#   examples/custom/Makefile.am: installing './depcomp'
#   autoreconf: Leaving directory `.'
#  autogen.sh: for the next step, run './configure' [or './configure --help' to check available options]
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... gawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking how to print strings... printf
# checking whether make supports the include directive... yes (GNU style)
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking dependency style of gcc... gcc3
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s
#
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# checking for a working dd... /usr/bin/dd
# checking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1
# checking for mt... mt
# checking if mt is a manifest tool... no
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking whether make supports nested variables... (cached) yes
# checking for gcc... (cached) gcc
# checking whether we are using the GNU C compiler... (cached) yes
# checking whether gcc accepts -g... (cached) yes
# checking for gcc option to accept ISO C89... (cached) none needed
# checking whether gcc understands -c and -o together... (cached) yes
# checking dependency style of gcc... (cached) gcc3
# checking for pkg-config... /usr/bin/pkg-config
# checking pkg-config is at least version 0.9.0... yes
# checking OS... linux-gnu
# checking hardware... x86_64
# checking whether to disable linking against shared objects... no
# checking for dlopen... no
# checking for dlopen in -ldl... yes
# checking for gmake... no
# checking for make... make
# checking whether make sets $(MAKE)... (cached) yes
# checking for __progname... yes
# checking endianess... little
# checking unaligned accesses... ok
# checking whether to enable L2 features... yes
# checking for inet_pton... yes
# checking for inet_ntop... yes
# checking for pcap-config... pcap-config
# checking using pcap-config for pcap.h... -I/usr/include
# checking default locations for libpcap... no
# checking using pcap-config for libpcap... -lpcap
# checking for pcap_dispatch in -lpcap... yes
# checking for pcap_set_protocol in -lpcap... no
# checking for pcap_setdirection in -lpcap... yes
# checking whether to enable MySQL support... no
# checking whether to enable PostgreSQL support... no
# checking whether to enable MongoDB support... no
# checking whether to enable SQLite3 support... no
# checking whether to enable RabbitMQ/AMQP support... no
# checking whether to enable ZeroMQ support... no
# checking whether to enable Kafka support... no
# checking whether to enable Redis support... no
# checking whether to enable GnuTLS support... no
# checking whether to enable GeoIP support... no
# checking whether to enable GeoIPv2 (libmaxminddb) support... no
# checking whether to enable Jansson support... yes
# checking for JANSSON... yes
# checking for json_object in -ljansson... yes
# checking jansson.h usability... yes
# checking jansson.h presence... yes
# checking for jansson.h... yes
# checking whether to enable Avro support... no
# checking whether to enable Confluent schema-registry support... no
# checking whether to enable nDPI support... no
# checking whether to enable Unyte UDP-Notif support... no
# checking whether to enable eBPF support... no
# checking for ANSI C header files... (cached) yes
# checking arpa/inet.h usability... yes
# checking arpa/inet.h presence... yes
# checking for arpa/inet.h... yes
# checking assert.h usability... yes
# checking assert.h presence... yes
# checking for assert.h... yes
# checking ctype.h usability... yes
# checking ctype.h presence... yes
# checking for ctype.h... yes
# checking dirent.h usability... yes
# checking dirent.h presence... yes
# checking for dirent.h... yes
# checking for dlfcn.h... (cached) yes
# checking errno.h usability... yes
# checking errno.h presence... yes
# checking for errno.h... yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking getopt.h usability... yes
# checking getopt.h presence... yes
# checking for getopt.h... yes
# checking grp.h usability... yes
# checking grp.h presence... yes
# checking for grp.h... yes
# checking for inttypes.h... (cached) yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
# checking malloc.h usability... yes
# checking malloc.h presence... yes
# checking for malloc.h... yes
# checking math.h usability... yes
# checking math.h presence... yes
# checking for math.h... yes
# checking netdb.h usability... yes
# checking netdb.h presence... yes
# checking for netdb.h... yes
# checking net/if.h usability... yes
# checking net/if.h presence... yes
# checking for net/if.h... yes
# checking netinet/in.h usability... yes
# checking netinet/in.h presence... yes
# checking for netinet/in.h... yes
# checking netinet/in_systm.h usability... yes
# checking netinet/in_systm.h presence... yes
# checking for netinet/in_systm.h... yes
# checking netinet/ip.h usability... yes
# checking netinet/ip.h presence... yes
# checking for netinet/ip.h... yes
# checking netinet/udp.h usability... yes
# checking netinet/udp.h presence... yes
# checking for netinet/udp.h... yes
# checking pthread.h usability... yes
# checking pthread.h presence... yes
# checking for pthread.h... yes
# checking pwd.h usability... yes
# checking pwd.h presence... yes
# checking for pwd.h... yes
# checking signal.h usability... yes
# checking signal.h presence... yes
# checking for signal.h... yes
# checking for string.h... (cached) yes
# checking sys/ansi.h usability... no
# checking sys/ansi.h presence... no
# checking for sys/ansi.h... no
# checking sys/errno.h usability... yes
# checking sys/errno.h presence... yes
# checking for sys/errno.h... yes
# checking sys/file.h usability... yes
# checking sys/file.h presence... yes
# checking for sys/file.h... yes
# checking sys/ioctl.h usability... yes
# checking sys/ioctl.h presence... yes
# checking for sys/ioctl.h... yes
# checking syslog.h usability... yes
# checking syslog.h presence... yes
# checking for syslog.h... yes
# checking sys/mbuf.h usability... no
# checking sys/mbuf.h presence... no
# checking for sys/mbuf.h... no
# checking sys/mman.h usability... yes
# checking sys/mman.h presence... yes
# checking for sys/mman.h... yes
# checking sys/param.h usability... yes
# checking sys/param.h presence... yes
# checking for sys/param.h... yes
# checking sys/poll.h usability... yes
# checking sys/poll.h presence... yes
# checking for sys/poll.h... yes
# checking sys/resource.h usability... yes
# checking sys/resource.h presence... yes
# checking for sys/resource.h... yes
# checking sys/select.h usability... yes
# checking sys/select.h presence... yes
# checking for sys/select.h... yes
# checking sys/socket.h usability... yes
# checking sys/socket.h presence... yes
# checking for sys/socket.h... yes
# checking for sys/stat.h... (cached) yes
# checking sys/time.h usability... yes
# checking sys/time.h presence... yes
# checking for sys/time.h... yes
# checking for sys/types.h... (cached) yes
# checking sys/un.h usability... yes
# checking sys/un.h presence... yes
# checking for sys/un.h... yes
# checking sys/utsname.h usability... yes
# checking sys/utsname.h presence... yes
# checking for sys/utsname.h... yes
# checking sys/wait.h usability... yes
# checking sys/wait.h presence... yes
# checking for sys/wait.h... yes
# checking time.h usability... yes
# checking time.h presence... yes
# checking for time.h... yes
# checking for unistd.h... (cached) yes
# checking for u_int64_t... yes
# checking for u_int32_t... yes
# checking for u_int16_t... yes
# checking for u_int8_t... yes
# checking for uint64_t... yes
# checking for uint32_t... yes
# checking for uint16_t... yes
# checking for uint8_t... yes
# checking whether to enable NFLOG support... no
# checking whether to link IPv4/IPv6 traffic accounting accounting binaries... yes
# checking whether to link BGP daemon binaries... yes
# checking whether to link BMP daemon binaries... yes
# checking whether to link Streaming Telemetry daemon binaries... yes
# checking return type of signal handlers... void
# checking for setproctitle... no
# checking for mallopt... yes
# checking for tdestroy... yes
# checking for strlcpy... no
# checking for vfork... yes
# checking whether SO_BINDTODEVICE is declared... yes
# checking whether SO_REUSEPORT is declared... yes
# checking whether SO_ATTACH_REUSEPORT_EBPF is declared... yes
# checking whether external dependencies (git submodules) should be compiled... yes
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# checking how to run the C++ preprocessor... g++ -E
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC -DPIC
# checking if g++ PIC flag -fPIC -DPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking if g++ supports -c -o file.o... (cached) yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for a valid C++ compiler... yes
# checking whether to enable debugging compiler options... no
#
# PLATFORM ..... : x86_64
# OS ........... : Linux 5.4.0-167-generic (n1)
# COMPILER ..... : gcc
# CFLAGS ....... : -O2 -g -O2 -I/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/include  -I/usr/include -lpcap  -I/home/ubuntu/pmacct-1.7.8/src
# LIBS ......... : -lcdada -lstdc++ -lpcap  -ldl -lm -lpthread
# LDFLAGS ...... : -L/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib
# PLUGINS ...... :
# SUPPORTS ..... :  jansson
#
# Now type 'make' to compile the source code.
#
# Wanting to get in touch with other pmacct users?
# Join the pmacct mailing-list with an email to pmacct-discussion-subscribe@pmacct.net
#
# Need for documentation and examples?
# Start by reading the README.md file
#
# Star, watch or contribute to the project on GitHub:
# https://github.com/pmacct/pmacct
#
#
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating src/pmacct-version.h
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating src/external_libs/Makefile
# config.status: creating src/nfprobe_plugin/Makefile
# config.status: creating src/sfprobe_plugin/Makefile
# config.status: creating src/bgp/Makefile
# config.status: creating src/tee_plugin/Makefile
# config.status: creating src/isis/Makefile
# config.status: creating src/bmp/Makefile
# config.status: creating src/rpki/Makefile
# config.status: creating src/telemetry/Makefile
# config.status: creating src/ndpi/Makefile
# config.status: creating src/filters/Makefile
# config.status: creating examples/lg/Makefile
# config.status: creating src/ebpf/Makefile
# config.status: creating examples/custom/Makefile
# config.status: executing depfiles commands
# config.status: executing libtool commands
# Making all in src
# make[1]: Entering directory '/home/ubuntu/pmacct-1.7.8/src'
# make  all-recursive
# make[2]: Entering directory '/home/ubuntu/pmacct-1.7.8/src'
# Making all in external_libs
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# [dep: libcdada] Checking...
#  fatal: not a git repository (or any of the parent directories): .git
#  [dep: libcdada] Up-to-date!
# make  all-am
# make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# make[4]: Nothing to be done for 'all-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# Making all in nfprobe_plugin
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/nfprobe_plugin'
#   CC       libnfprobe_plugin_la-nfprobe_plugin.lo
#  nfprobe_plugin.c: In function ‘check_expired’:
# nfprobe_plugin.c:207:34: warning: ‘%s’ directive output may be truncated writing up to 31 bytes into a region of size 20 [-Wformat-truncation=]
#   194 |  return (buf);
#       |         ~
# ......
#   207 |  snprintf(stime, sizeof(ftime), "%s", format_time(flow->flow_start.tv_sec));
#       |                                  ^~
#   In file included from /usr/include/stdio.h:867,
#                  from /usr/include/pcap/pcap.h:93,
#                  from ./../pmacct.h:27,
#                  from common.h:28,
#                  from nfprobe_plugin.c:50:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin_snprintf’ output between 1 and 32 bytes into a destination of size 20
#    67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# nfprobe_plugin.c:208:34: warning: ‘%s’ directive output may be truncated writing up to 31 bytes into a region of size 20 [-Wformat-truncation=]
#   194 |  return (buf);
#       |         ~
# ......
#   208 |  snprintf(ftime, sizeof(ftime), "%s", format_time(flow->flow_last.tv_sec));
#       |                                  ^~
# In file included from /usr/include/stdio.h:867,
#                  from /usr/include/pcap/pcap.h:93,
#                  from ./../pmacct.h:27,
#                  from common.h:28,
#                  from nfprobe_plugin.c:50:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin_snprintf’ output between 1 and 32 bytes into a destination of size 20
#    67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    CC       libnfprobe_plugin_la-netflow5.lo
#   CC       libnfprobe_plugin_la-netflow9.lo
#   CC       libnfprobe_plugin_la-convtime.lo
#   CCLD     libnfprobe_plugin.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/nfprobe_plugin'
# Making all in sfprobe_plugin
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/sfprobe_plugin'
#   CC       libsfprobe_plugin_la-sflow_agent.lo
#   CC       libsfprobe_plugin_la-sflow_poller.lo
#   CC       libsfprobe_plugin_la-sflow_receiver.lo
#   CC       libsfprobe_plugin_la-sflow_sampler.lo
#   CC       libsfprobe_plugin_la-sfprobe_plugin.lo
#   CCLD     libsfprobe_plugin.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/sfprobe_plugin'
# Making all in bgp
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/bgp'
#   CC       libpmbgp_la-bgp.lo
#   CC       libpmbgp_la-bgp_aspath.lo
#   CC       libpmbgp_la-bgp_community.lo
#   CC       libpmbgp_la-bgp_ecommunity.lo
#   CC       libpmbgp_la-bgp_hash.lo
#   CC       libpmbgp_la-bgp_prefix.lo
#   CC       libpmbgp_la-bgp_table.lo
#   CC       libpmbgp_la-bgp_logdump.lo
#   CC       libpmbgp_la-bgp_util.lo
#   CC       libpmbgp_la-bgp_msg.lo
#   CC       libpmbgp_la-bgp_lookup.lo
#   CC       libpmbgp_la-bgp_lcommunity.lo
#   CC       libpmbgp_la-bgp_xcs.lo
#   CC       libpmbgp_la-bgp_blackhole.lo
#   CC       libpmbgp_la-bgp_lg.lo
#   CCLD     libpmbgp.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/bgp'
# Making all in tee_plugin
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/tee_plugin'
#   CC       libtee_plugin_la-tee_plugin.lo
#   CC       libtee_plugin_la-tee_recvs.lo
#   CCLD     libtee_plugin.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/tee_plugin'
# Making all in isis
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/isis'
#   CC       libpmisis_la-isis.lo
#   CC       libpmisis_la-checksum.lo
#   CC       libpmisis_la-dict.lo
#   CC       libpmisis_la-table.lo
#   CC       libpmisis_la-prefix.lo
#   CC       libpmisis_la-sockunion.lo
#   CC       libpmisis_la-hash.lo
#   CC       libpmisis_la-stream.lo
#   CC       libpmisis_la-thread.lo
#   CC       libpmisis_la-isis_circuit.lo
#   CC       libpmisis_la-isis_events.lo
#   CC       libpmisis_la-isis_route.lo
#   CC       libpmisis_la-isis_tlv.lo
#   CC       libpmisis_la-isis_csm.lo
#   CC       libpmisis_la-isis_flags.lo
#   CC       libpmisis_la-isis_misc.lo
#   CC       libpmisis_la-isisd.lo
#   CC       libpmisis_la-isis_adjacency.lo
#   CC       libpmisis_la-isis_dynhn.lo
#   CC       libpmisis_la-isis_spf.lo
#   CC       libpmisis_la-iso_checksum.lo
#   CC       libpmisis_la-isis_lsp.lo
#   CC       libpmisis_la-isis_pdu.lo
#   CC       libpmisis_la-isis-globals.lo
#   CCLD     libpmisis.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/isis'
# Making all in bmp
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/bmp'
#   CC       libpmbmp_la-bmp.lo
#   CC       libpmbmp_la-bmp_logdump.lo
#   CC       libpmbmp_la-bmp_msg.lo
#   CC       libpmbmp_la-bmp_util.lo
#   CC       libpmbmp_la-bmp_lookup.lo
#   CC       libpmbmp_la-bmp_tlv.lo
#   CC       libpmbmp_la-bmp_rpat.lo
#   CC       libpmbmp_la-bmp-globals.lo
#   CCLD     libpmbmp.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/bmp'
# Making all in telemetry
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/telemetry'
#   CC       libpmtelemetry_la-telemetry.lo
#   CC       libpmtelemetry_la-telemetry_logdump.lo
#   CC       libpmtelemetry_la-telemetry_msg.lo
#   CC       libpmtelemetry_la-telemetry_util.lo
#   CCLD     libpmtelemetry.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/telemetry'
# Making all in rpki
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/rpki'
#   CC       libpmrpki_la-rpki.lo
#   CC       libpmrpki_la-rpki_msg.lo
#   CC       libpmrpki_la-rpki_lookup.lo
#   CC       libpmrpki_la-rpki_util.lo
#   CCLD     libpmrpki.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/rpki'
# Making all in filters
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/filters'
#   CC       libpmfilters_la-bloom.lo
#   CC       libpmfilters_la-murmur2.lo
#   CCLD     libpmfilters.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/filters'
# Making all in ebpf
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/ebpf'
#   CC       libpmebpf_la-ebpf_rp_balancer.lo
#   CCLD     libpmebpf.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/ebpf'
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src'
#   CC       pmacct.o
#   CC       libcommon_la-strlcpy.lo
#   CC       libcommon_la-addr.lo
#   CCLD     libcommon.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       libdaemons_la-signals.lo
#   CC       libdaemons_la-util.lo
#   CC       libdaemons_la-plugin_hooks.lo
#   CC       libdaemons_la-server.lo
#   CC       libdaemons_la-acct.lo
#   CC       libdaemons_la-memory.lo
#   CC       libdaemons_la-cfg.lo
#   CC       libdaemons_la-imt_plugin.lo
#   CC       libdaemons_la-log.lo
#   CC       libdaemons_la-pkt_handlers.lo
#   CC       libdaemons_la-cfg_handlers.lo
#   CC       libdaemons_la-net_aggr.lo
#   CC       libdaemons_la-print_plugin.lo
#   CC       libdaemons_la-pretag.lo
#   CC       libdaemons_la-ip_frag.lo
#   CC       libdaemons_la-pretag_handlers.lo
#   CC       libdaemons_la-ip_flow.lo
#   CC       libdaemons_la-setproctitle.lo
#   CC       libdaemons_la-classifier.lo
#   CC       libdaemons_la-conntrack.lo
#   CC       libdaemons_la-xflow_status.lo
#   CC       libdaemons_la-plugin_common.lo
#   CC       libdaemons_la-preprocess.lo
#   CC       libdaemons_la-ll.lo
#   CC       libdaemons_la-nl.lo
#   CC       libdaemons_la-base64.lo
#   CC       libdaemons_la-pmsearch.lo
#   CC       libdaemons_la-linklist.lo
#   CC       libdaemons_la-thread_pool.lo
#   CC       libdaemons_la-plugin_cmn_custom.lo
#   CC       libdaemons_la-network.lo
#  network.c: In function ‘parse_proxy_header’:
# network.c:65:45: warning: ‘%s’ directive output may be truncated writing up to 107 bytes into a region of size 46 [-Wformat-truncation=]
#    63 |     char *s = &hdr.v1.line[11];
#       |               ~~~~~~~~~~~~~~~~
#    64 |     char *e = strchr(s, ' ');
#    65 |     snprintf(ip_address, INET6_ADDRSTRLEN, "%s", s);
#       |                                             ^~
# In file included from /usr/include/stdio.h:867,
#                  from /usr/include/pcap/pcap.h:93,
#                  from pmacct.h:27,
#                  from network.c:22:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin_snprintf’ output between 1 and 108 bytes into a destination of size 46
#    67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    CC       libdaemons_la-pmacct-globals.lo
#   CC       libdaemons_la-plugin_cmn_json.lo
#  plugin_cmn_json.c: In function ‘compose_mpls_label_stack_json_data’:
# plugin_cmn_json.c:1486:37: warning: ‘%zu’ directive output may be truncated writing between 1 and 19 bytes into a region of size 4 [-Wformat-truncation=]
#  1486 |     snprintf(idx_buf, MAX_IDX_LEN, "%zu", idx_0);
#       |                                     ^~~
# plugin_cmn_json.c:1486:36: note: directive argument in the range [0, 4611686018427387903]
#  1486 |     snprintf(idx_buf, MAX_IDX_LEN, "%zu", idx_0);
#       |                                    ^~~~~
#   In file included from /usr/include/stdio.h:867,
#                  from /usr/include/pcap/pcap.h:93,
#                  from pmacct.h:27,
#                  from plugin_cmn_json.c:23:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin___snprintf_chk’ output between 2 and 20 bytes into a destination of size 4
#    67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    CCLD     libdaemons.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CCLD     pmacct
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       pmacctd.o
#   CCLD     pmacctd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       nfacctd.o
#   CC       nfv9_template.o
#   CCLD     nfacctd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       sfacctd.o
#   CC       sflow.o
#   CC       sfv5_module.o
#   CCLD     sfacctd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       pmtelemetryd.o
#   CCLD     pmtelemetryd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       pmbgpd.o
#   CCLD     pmbgpd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       pmbmpd.o
#   CCLD     pmbmpd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src'
# make[2]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src'
# make[1]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src'
# Making all in examples/custom
# make[1]: Entering directory '/home/ubuntu/pmacct-1.7.8/examples/custom'
#   CC       libcustom_la-libcustom.lo
#   CCLD     libcustom.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[1]: Leaving directory '/home/ubuntu/pmacct-1.7.8/examples/custom'
# Making all in examples/lg
# make[1]: Entering directory '/home/ubuntu/pmacct-1.7.8/examples/lg'
#   CC       pmbgp-pmbgp.o
#   CCLD     pmbgp
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[1]: Leaving directory '/home/ubuntu/pmacct-1.7.8/examples/lg'
# make[1]: Entering directory '/home/ubuntu/pmacct-1.7.8'
# make[1]: Nothing to be done for 'all-am'.
# make[1]: Leaving directory '/home/ubuntu/pmacct-1.7.8'
# Making install in src
# make[1]: Entering directory '/home/ubuntu/pmacct-1.7.8/src'
# make  install-recursive
# make[2]: Entering directory '/home/ubuntu/pmacct-1.7.8/src'
# Making install in external_libs
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# [dep: libcdada] Checking...
#  fatal: not a git repository (or any of the parent directories): .git
#  [dep: libcdada] Up-to-date!
# make  install-am
# make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# make[5]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/external_libs'
# Making install in nfprobe_plugin
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/nfprobe_plugin'
#   CC       libnfprobe_plugin_la-nfprobe_plugin.lo
#  nfprobe_plugin.c: In function ‘check_expired’:
# nfprobe_plugin.c:207:34: warning: ‘%s’ directive output may be truncated writing up to 31 bytes into a region of size 20 [-Wformat-truncation=]
#   194 |  return (buf);
#       |         ~
# ......
#   207 |  snprintf(stime, sizeof(ftime), "%s", format_time(flow->flow_start.tv_sec));
#       |                                  ^~
# In file included from /usr/include/stdio.h:867,
#                  from /usr/include/pcap/pcap.h:93,
#                  from ./../pmacct.h:27,
#                  from common.h:28,
#                  from nfprobe_plugin.c:50:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin_snprintf’ output between 1 and 32 bytes into a destination of size 20
#    67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   nfprobe_plugin.c:208:34: warning: ‘%s’ directive output may be truncated writing up to 31 bytes into a region of size 20 [-Wformat-truncation=]
#   194 |  return (buf);
#       |         ~
# ......
#   208 |  snprintf(ftime, sizeof(ftime), "%s", format_time(flow->flow_last.tv_sec));
#       |                                  ^~
# In file included from /usr/include/stdio.h:867,
#                  from /usr/include/pcap/pcap.h:93,
#                  from ./../pmacct.h:27,
#                  from common.h:28,
#                  from nfprobe_plugin.c:50:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin_snprintf’ output between 1 and 32 bytes into a destination of size 20
#    67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    CC       libnfprobe_plugin_la-netflow5.lo
#   CC       libnfprobe_plugin_la-netflow9.lo
#   CC       libnfprobe_plugin_la-convtime.lo
#   CCLD     libnfprobe_plugin.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/nfprobe_plugin'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/nfprobe_plugin'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/nfprobe_plugin'
# Making install in sfprobe_plugin
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/sfprobe_plugin'
#   CC       libsfprobe_plugin_la-sflow_agent.lo
#   CC       libsfprobe_plugin_la-sflow_poller.lo
#   CC       libsfprobe_plugin_la-sflow_receiver.lo
#   CC       libsfprobe_plugin_la-sflow_sampler.lo
#   CC       libsfprobe_plugin_la-sfprobe_plugin.lo
#   CCLD     libsfprobe_plugin.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/sfprobe_plugin'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/sfprobe_plugin'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/sfprobe_plugin'
# Making install in bgp
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/bgp'
#   CC       libpmbgp_la-bgp.lo
#   CC       libpmbgp_la-bgp_aspath.lo
#   CC       libpmbgp_la-bgp_community.lo
#   CC       libpmbgp_la-bgp_ecommunity.lo
#   CC       libpmbgp_la-bgp_hash.lo
#   CC       libpmbgp_la-bgp_prefix.lo
#   CC       libpmbgp_la-bgp_table.lo
#   CC       libpmbgp_la-bgp_logdump.lo
#   CC       libpmbgp_la-bgp_util.lo
#   CC       libpmbgp_la-bgp_msg.lo
#   CC       libpmbgp_la-bgp_lookup.lo
#   CC       libpmbgp_la-bgp_lcommunity.lo
#   CC       libpmbgp_la-bgp_xcs.lo
#   CC       libpmbgp_la-bgp_blackhole.lo
#   CC       libpmbgp_la-bgp_lg.lo
#   CCLD     libpmbgp.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/bgp'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/bgp'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/bgp'
# Making install in tee_plugin
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/tee_plugin'
#   CC       libtee_plugin_la-tee_plugin.lo
#   CC       libtee_plugin_la-tee_recvs.lo
#   CCLD     libtee_plugin.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/tee_plugin'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/tee_plugin'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/tee_plugin'
# Making install in isis
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/isis'
#   CC       libpmisis_la-isis.lo
#   CC       libpmisis_la-checksum.lo
#   CC       libpmisis_la-dict.lo
#   CC       libpmisis_la-table.lo
#   CC       libpmisis_la-prefix.lo
#   CC       libpmisis_la-sockunion.lo
#   CC       libpmisis_la-hash.lo
#   CC       libpmisis_la-stream.lo
#   CC       libpmisis_la-thread.lo
#   CC       libpmisis_la-isis_circuit.lo
#   CC       libpmisis_la-isis_events.lo
#   CC       libpmisis_la-isis_route.lo
#   CC       libpmisis_la-isis_tlv.lo
#   CC       libpmisis_la-isis_csm.lo
#   CC       libpmisis_la-isis_flags.lo
#   CC       libpmisis_la-isis_misc.lo
#   CC       libpmisis_la-isisd.lo
#   CC       libpmisis_la-isis_adjacency.lo
#   CC       libpmisis_la-isis_dynhn.lo
#   CC       libpmisis_la-isis_spf.lo
#   CC       libpmisis_la-iso_checksum.lo
#   CC       libpmisis_la-isis_lsp.lo
#   CC       libpmisis_la-isis_pdu.lo
#   CC       libpmisis_la-isis-globals.lo
#   CCLD     libpmisis.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/isis'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/isis'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/isis'
# Making install in bmp
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/bmp'
#   CC       libpmbmp_la-bmp.lo
#   CC       libpmbmp_la-bmp_logdump.lo
#   CC       libpmbmp_la-bmp_msg.lo
#   CC       libpmbmp_la-bmp_util.lo
#   CC       libpmbmp_la-bmp_lookup.lo
#   CC       libpmbmp_la-bmp_tlv.lo
#   CC       libpmbmp_la-bmp_rpat.lo
#   CC       libpmbmp_la-bmp-globals.lo
#   CCLD     libpmbmp.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/bmp'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/bmp'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/bmp'
# Making install in telemetry
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/telemetry'
#   CC       libpmtelemetry_la-telemetry.lo
#   CC       libpmtelemetry_la-telemetry_logdump.lo
#   CC       libpmtelemetry_la-telemetry_msg.lo
#   CC       libpmtelemetry_la-telemetry_util.lo
#   CCLD     libpmtelemetry.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/telemetry'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/telemetry'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/telemetry'
# Making install in rpki
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/rpki'
#   CC       libpmrpki_la-rpki.lo
#   CC       libpmrpki_la-rpki_msg.lo
#   CC       libpmrpki_la-rpki_lookup.lo
#   CC       libpmrpki_la-rpki_util.lo
#   CCLD     libpmrpki.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/rpki'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/rpki'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/rpki'
# Making install in filters
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/filters'
#   CC       libpmfilters_la-bloom.lo
#   CCLD     libpmfilters.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/filters'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/filters'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/filters'
# Making install in ebpf
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/ebpf'
# make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src/ebpf'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/ebpf'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src/ebpf'
# make[3]: Entering directory '/home/ubuntu/pmacct-1.7.8/src'
#   CC       pmacct.o
#   CC       libcommon_la-addr.lo
#   CCLD     libcommon.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       libdaemons_la-signals.lo
#   CC       libdaemons_la-util.lo
#   CC       libdaemons_la-plugin_hooks.lo
#   CC       libdaemons_la-server.lo
#   CC       libdaemons_la-acct.lo
#   CC       libdaemons_la-memory.lo
#   CC       libdaemons_la-cfg.lo
#   CC       libdaemons_la-imt_plugin.lo
#   CC       libdaemons_la-log.lo
#   CC       libdaemons_la-pkt_handlers.lo
#   CC       libdaemons_la-cfg_handlers.lo
#   CC       libdaemons_la-net_aggr.lo
#   CC       libdaemons_la-print_plugin.lo
#   CC       libdaemons_la-pretag.lo
#   CC       libdaemons_la-ip_frag.lo
#   CC       libdaemons_la-pretag_handlers.lo
#   CC       libdaemons_la-ip_flow.lo
#   CC       libdaemons_la-setproctitle.lo
#   CC       libdaemons_la-classifier.lo
#   CC       libdaemons_la-conntrack.lo
#   CC       libdaemons_la-xflow_status.lo
#   CC       libdaemons_la-plugin_common.lo
#   CC       libdaemons_la-preprocess.lo
#   CC       libdaemons_la-ll.lo
#   CC       libdaemons_la-nl.lo
#   CC       libdaemons_la-pmsearch.lo
#   CC       libdaemons_la-linklist.lo
#   CC       libdaemons_la-thread_pool.lo
#   CC       libdaemons_la-plugin_cmn_custom.lo
#   CC       libdaemons_la-network.lo
#  network.c: In function ‘parse_proxy_header’:
# network.c:65:45: warning: ‘%s’ directive output may be truncated writing up to 107 bytes into a region of size 46 [-Wformat-truncation=]
#    63 |     char *s = &hdr.v1.line[11];
#       |               ~~~~~~~~~~~~~~~~
#    64 |     char *e = strchr(s, ' ');
#    65 |     snprintf(ip_address, INET6_ADDRSTRLEN, "%s", s);
#       |                                             ^~
# In file included from /usr/include/stdio.h:867,
#                  from /usr/include/pcap/pcap.h:93,
#                  from pmacct.h:27,
#                  from network.c:22:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin_snprintf’ output between 1 and 108 bytes into a destination of size 46
#    67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    CC       libdaemons_la-pmacct-globals.lo
#   CC       libdaemons_la-plugin_cmn_json.lo
#  plugin_cmn_json.c: In function ‘compose_mpls_label_stack_json_data’:
# plugin_cmn_json.c:1486:37: warning: ‘%zu’ directive output may be truncated writing between 1 and 19 bytes into a region of size 4 [-Wformat-truncation=]
#  1486 |     snprintf(idx_buf, MAX_IDX_LEN, "%zu", idx_0);
#       |                                     ^~~
# plugin_cmn_json.c:1486:36: note: directive argument in the range [0, 4611686018427387903]
#  1486 |     snprintf(idx_buf, MAX_IDX_LEN, "%zu", idx_0);
#       |                                    ^~~~~
# In file included from /usr/include/stdio.h:867,
# ...
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    CC       libdaemons_la-pmacct-globals.lo
#   CC       libdaemons_la-plugin_cmn_json.lo
#  plugin_cmn_json.c: In function ‘compose_mpls_label_stack_json_data’:
# plugin_cmn_json.c:1486:37: warning: ‘%zu’ directive output may be truncated writing between 1 and 19 bytes into a region of size 4 [-Wformat-truncation=]
#  1486 |     snprintf(idx_buf, MAX_IDX_LEN, "%zu", idx_0);
#       |                                     ^~~
# plugin_cmn_json.c:1486:36: note: directive argument in the range [0, 4611686018427387903]
#  1486 |     snprintf(idx_buf, MAX_IDX_LEN, "%zu", idx_0);
#       |                                    ^~~~~
# In file included from /usr/include/stdio.h:867,
#                  from /usr/include/pcap/pcap.h:93,
#                  from pmacct.h:27,
#                  from plugin_cmn_json.c:23:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin___snprintf_chk’ output between 2 and 20 bytes into a destination of size 4
#    67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    68 |        __bos (__s), __fmt, __va_arg_pack ());
#       |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    CCLD     libdaemons.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CCLD     pmacct
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       pmacctd.o
#   CCLD     pmacctd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       nfacctd.o
#   CC       nfv9_template.o
#   CCLD     nfacctd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       sfacctd.o
#   CC       sflow.o
#   CC       sfv5_module.o
#   CCLD     sfacctd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       pmtelemetryd.o
#   CCLD     pmtelemetryd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       pmbgpd.o
#   CCLD     pmbgpd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#    CC       pmbmpd.o
#   CCLD     pmbmpd
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[4]: Entering directory '/home/ubuntu/pmacct-1.7.8/src'
#  /usr/bin/mkdir -p '/usr/local/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c pmacct '/usr/local/bin'
# libtool: install: /usr/bin/install -c pmacct /usr/local/bin/pmacct
#  /usr/bin/mkdir -p '/usr/local/sbin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c pmacctd nfacctd sfacctd pmtelemetryd pmbgpd pmbmpd '/usr/local/sbin'
# libtool: install: /usr/bin/install -c pmacctd /usr/local/sbin/pmacctd
# libtool: install: /usr/bin/install -c nfacctd /usr/local/sbin/nfacctd
# libtool: install: /usr/bin/install -c sfacctd /usr/local/sbin/sfacctd
# libtool: install: /usr/bin/install -c pmtelemetryd /usr/local/sbin/pmtelemetryd
# libtool: install: /usr/bin/install -c pmbgpd /usr/local/sbin/pmbgpd
# libtool: install: /usr/bin/install -c pmbmpd /usr/local/sbin/pmbmpd
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src'
# make[3]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src'
# make[2]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src'
# make[1]: Leaving directory '/home/ubuntu/pmacct-1.7.8/src'
# Making install in examples/custom
# make[1]: Entering directory '/home/ubuntu/pmacct-1.7.8/examples/custom'
#   CC       libcustom_la-libcustom.lo
#   CCLD     libcustom.la
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[2]: Entering directory '/home/ubuntu/pmacct-1.7.8/examples/custom'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/home/ubuntu/pmacct-1.7.8/examples/custom'
# make[1]: Leaving directory '/home/ubuntu/pmacct-1.7.8/examples/custom'
# Making install in examples/lg
# make[1]: Entering directory '/home/ubuntu/pmacct-1.7.8/examples/lg'
#   CC       pmbgp-pmbgp.o
#   CCLD     pmbgp
#  libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#   libtool: warning: library '/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la' was moved.
#  make[2]: Entering directory '/home/ubuntu/pmacct-1.7.8/examples/lg'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/home/ubuntu/pmacct-1.7.8/examples/lg'
# make[1]: Leaving directory '/home/ubuntu/pmacct-1.7.8/examples/lg'
# make[1]: Entering directory '/home/ubuntu/pmacct-1.7.8'
# make[2]: Entering directory '/home/ubuntu/pmacct-1.7.8'
# make[2]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/share/pmacct'
#  /usr/bin/install -c -m 644 CONFIG-KEYS FAQS QUICKSTART UPGRADE '/usr/local/share/pmacct'
#  /usr/bin/mkdir -p '/usr/local/share/pmacct/docs'
#  /usr/bin/install -c -m 644 docs/IPFIX docs/LOOKING_GLASS_FORMAT docs/SIGNALS docs/MSGLOG_DUMP_FORMATS docs/TRIGGER_VARS '/usr/local/share/pmacct/docs'
#  /usr/bin/mkdir -p '/usr/local/share/pmacct/examples'
#  /usr/bin/install -c -m 644 examples/allow.lst.example examples/bgp_agent.map.example examples/bgp_md5.lst.example examples/bgp_xconnects.map.example examples/flow_to_rd.map.example examples/networks.lst.example examples/peers.map.example examples/pcap_interfaces.map.example examples/pmacctd-imt.conf.example examples/pmacctd-multiple-plugins.conf.example examples/ports.lst.example examples/pretag.map.example examples/primitives.lst.example examples/probe_netflow.conf.example examples/probe_sflow.conf.example examples/sampling.map.example examples/tee_receivers.lst.example examples/nfacctd-sql.conf.example examples/pmacctd-sql.conf.example examples/pmacctd-sqlite3.conf.example '/usr/local/share/pmacct/examples'
#  /usr/bin/mkdir -p '/usr/local/share/pmacct/examples/amqp'
#  /usr/bin/install -c -m 644 examples/amqp/amqp_receiver.py '/usr/local/share/pmacct/examples/amqp'
#  /usr/bin/mkdir -p '/usr/local/share/pmacct/examples/avro'
#  /usr/bin/install -c -m 644 examples/avro/avro_file_decoder.py '/usr/local/share/pmacct/examples/avro'
#  /usr/bin/mkdir -p '/usr/local/lib/pmacct/examples/custom'
#  /usr/bin/install -c -m 644 examples/custom/libcustom.la '/usr/local/lib/pmacct/examples/custom'
#  /usr/bin/mkdir -p '/usr/local/share/pmacct/examples/kafka'
#  /usr/bin/install -c -m 644 examples/kafka/kafka_consumer.py '/usr/local/share/pmacct/examples/kafka'
#  /usr/bin/mkdir -p '/usr/local/share/pmacct/examples/lg'
#  /usr/bin/install -c -m 644 examples/lg/pmbgp.py '/usr/local/share/pmacct/examples/lg'
#  /usr/bin/mkdir -p '/usr/local/lib/pmacct/examples/lg'
#  /usr/bin/install -c -m 644 examples/lg/pmbgp '/usr/local/lib/pmacct/examples/lg'
# make[2]: Leaving directory '/home/ubuntu/pmacct-1.7.8'
# make[1]: Leaving directory '/home/ubuntu/pmacct-1.7.8'
# ("autogen.sh: reconfigure with autoreconf\nlibtoolize: putting auxiliary files in '.'.\nlibtoolize: copying file './ltmain.sh'\nlibtoolize: putting macros in AC_CONFIG_MACRO_DIRS, 'm4'.\nlibtoolize: copying file 'm4/libtool.m4'\nlibtoolize: copying file 'm4/ltoptions.m4'\nlibtoolize: copying file 'm4/ltsugar.m4'\nlibtoolize: copying file 'm4/ltversion.m4'\nlibtoolize: copying file 'm4/lt~obsolete.m4'\nautogen.sh: for the next step, run './configure' [or './configure --help' to check available options]\nchecking for a BSD-compatible install... /usr/bin/install -c\nchecking whether build environment is sane... yes\nchecking for a thread-safe mkdir -p... /usr/bin/mkdir -p\nchecking for gawk... gawk\nchecking whether make sets $(MAKE)... yes\nchecking whether make supports nested variables... yes\nchecking build system type... x86_64-pc-linux-gnu\nchecking host system type... x86_64-pc-linux-gnu\nchecking how to print strings... printf\nchecking whether make supports the include directive... yes (GNU style)\nchecking for gcc... gcc\nchecking whether the C compiler works... yes\nchecking for C compiler default output file name... a.out\nchecking for suffix of executables... \nchecking whether we are cross compiling... no\nchecking for suffix of object files... o\nchecking whether we are using the GNU C compiler... yes\nchecking whether gcc accepts -g... yes\nchecking for gcc option to accept ISO C89... none needed\nchecking whether gcc understands -c and -o together... yes\nchecking dependency style of gcc... gcc3\nchecking for a sed that does not truncate output... /usr/bin/sed\nchecking for grep that handles long lines and -e... /usr/bin/grep\nchecking for egrep... /usr/bin/grep -E\nchecking for fgrep... /usr/bin/grep -F\nchecking for ld used by gcc... /usr/bin/ld\nchecking if the linker (/usr/bin/ld) is GNU ld... yes\nchecking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B\nchecking the name lister (/usr/bin/nm -B) interface... BSD nm\nchecking whether ln -s works... yes\nchecking the maximum length of command line arguments... 1572864\nchecking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop\nchecking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop\nchecking for /usr/bin/ld option to reload object files... -r\nchecking for objdump... objdump\nchecking how to recognize dependent libraries... pass_all\nchecking for dlltool... no\nchecking how to associate runtime and link libraries... printf %s\\n\nchecking for ar... ar\nchecking for archiver @FILE support... @\nchecking for strip... strip\nchecking for ranlib... ranlib\nchecking command to parse /usr/bin/nm -B output from gcc object... ok\nchecking for sysroot... no\nchecking for a working dd... /usr/bin/dd\nchecking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1\nchecking for mt... mt\nchecking if mt is a manifest tool... no\nchecking how to run the C preprocessor... gcc -E\nchecking for ANSI C header files... yes\nchecking for sys/types.h... yes\nchecking for sys/stat.h... yes\nchecking for stdlib.h... yes\nchecking for string.h... yes\nchecking for memory.h... yes\nchecking for strings.h... yes\nchecking for inttypes.h... yes\nchecking for stdint.h... yes\nchecking for unistd.h... yes\nchecking for dlfcn.h... yes\nchecking for objdir... .libs\nchecking if gcc supports -fno-rtti -fno-exceptions... no\nchecking for gcc option to produce PIC... -fPIC -DPIC\nchecking if gcc PIC flag -fPIC -DPIC works... yes\nchecking if gcc static flag -static works... yes\nchecking if gcc supports -c -o file.o... yes\nchecking if gcc supports -c -o file.o... (cached) yes\nchecking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes\nchecking whether -lc should be explicitly linked in... no\nchecking dynamic linker characteristics... GNU/Linux ld.so\nchecking how to hardcode library paths into programs... immediate\nchecking whether stripping ...
#  'autoreconf: Entering directory `.\'\nautoreconf: configure.ac: not using Gettext\nautoreconf: running: aclocal -I m4 --force -I m4\nautoreconf: configure.ac: tracing\nautoreconf: running: libtoolize --copy --force\nautoreconf: running: /usr/bin/autoconf --include=m4 --force\nautoreconf: configure.ac: not using Autoheader\nautoreconf: running: automake --add-missing --copy --force-missing\nconfigure.ac:8: installing \'./compile\'\nconfigure.ac:6: installing \'./missing\'\nexamples/custom/Makefile.am: installing \'./depcomp\'\nautoreconf: Leaving directory `.\'\nfatal: not a git repository (or any of the parent directories): .git\nnfprobe_plugin.c: In function ‘check_expired’:\nnfprobe_plugin.c:207:34: warning: ‘%s’ directive output may be truncated writing up to 31 bytes into a region of size 20 [-Wformat-truncation=]\n  194 |  return (buf);\n      |         ~                         \n......\n  207 |  snprintf(stime, sizeof(ftime), "%s", format_time(flow->flow_start.tv_sec));\n      |                                  ^~\nIn file included from /usr/include/stdio.h:867,\n                 from /usr/include/pcap/pcap.h:93,\n                 from ./../pmacct.h:27,\n                 from common.h:28,\n                 from nfprobe_plugin.c:50:\n/usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin_snprintf’ output between 1 and 32 bytes into a destination of size 20\n   67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,\n      |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n   68 |        __bos (__s), __fmt, __va_arg_pack ());\n      |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\nnfprobe_plugin.c:208:34: warning: ‘%s’ directive output may be truncated writing up to 31 bytes into a region of size 20 [-Wformat-truncation=]\n  194 |  return (buf);\n      |         ~                         \n......\n  208 |  snprintf(ftime, sizeof(ftime), "%s", format_time(flow->flow_last.tv_sec));\n      |                                  ^~\nIn file included from /usr/include/stdio.h:867,\n                 from /usr/include/pcap/pcap.h:93,\n                 from ./../pmacct.h:27,\n                 from common.h:28,\n                 from nfprobe_plugin.c:50:\n/usr/include/x86_64-linux-gnu/bits/stdio2.h:67:10: note: ‘__builtin_snprintf’ output between 1 and 32 bytes into a destination of size 20\n   67 |   return __builtin___snprintf_chk (__s, __n, __USE_FORTIFY_LEVEL - 1,\n      |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n   68 |        __bos (__s), __fmt, __va_arg_pack ());\n      |        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nlibtool: warning: library \'/home/ubuntu/pmacct-1.7.8/src/external_libs/rootfs/lib/libcdada.la\' was moved.\nnetwork.c: In function ‘parse_proxy_header’:\nnetwork.c:65:45: warning: ‘%s’ directive output may be truncated writing up to 107 bytes into a region of siz ...

# %% [markdown]
# # Experiments and use of the tool
# The following sections describe different experiments performed on the pmacctd tool to know more about its capabilities. The experiments are performed both using .pcap files and live traffic captured by pmacctd.
#
# > You can use any .pcap file but I would be using the following one for the experiments gmail.pcapng.cap, which can be found in: https://packetlife.net/captures/
# You need to first upload it to the node using the upload function and then move it to the pmacctd folder: print(cmd_upload_file_to(n1, "gmail.pcapng.cap"))
#
# > We are going to use different configurations of the tool so that it works properly. These configurations can be found on the configuration-files folder and placed on the Jupyter Workspace. You can play with them so that you can learn how the tool works.

# %% [markdown]
# ## Experiment of the pmacctd tool using a pcap file.
# In this section we are going to perform three different experiments using the same pcap file but with different configurations of the tool. We are going to show the results obtained from processing the pmacctd tool on a pcap file in three different formats: CSV, JSON and .txt.
#
# For the execution of the tool a configuration file is needed, in this section the following fields are necessary:
#
# daemonize: false \
# debug: true \
# pcap_savefile: file.pcap \
# aggregate: src_host, dst_host, src_port, dst_port, proto, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: csv/formatted/json \
# print_output_file: result_file.format \
# print_history_roundoff: m
#
#
#  - daemonize: This field indicates whether the process should run in the background or not. In this case, will set to false, meaning the process will run in the foreground.
#   - debug: This field controls the debug mode. When set to true, it enables debugging output, which is be helpful for these first exeperiments.
#   - pcap_savefile: This field specifies the path where the tool obtains the data. It will set to $PATH_of_pmacct_tool/pmacct-1.7.8/file.pcap. The file contains captured network traffic data.
#   - aggregate: This field specifies the fields by which to aggregate the captured data. In this case, it will aggregate data based on source host, destination host, source port, destination port, and protocol.
#     > The output would look like this:
#     <div style="text-align: center;">
#     <img src="./images/3.png" width="1000px"/>
# </div>
#   - plugin_buffer_size: This field defines the buffer size used by plugins.
#   - plugins: This field specifies the plugins to be used. In this example, the print plugin is specified, which likely indicates that the captured data will be printed.
#   - print_output: This field specifies the output format for the printed data. It will be set to csv for the first experiment since we want our output in this format.
#   - print_history_roundoff: This field specifies the rounding-off interval for historical data.

# %% [markdown]
# ### CSV format
# The configuration file will have the following data:
#
# daemonize: false \
# debug: true \
# pcap_savefile: gmail.pcapng.cap \
# aggregate: src_host, dst_host, src_port, dst_port, proto, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: csv \
# print_output_file: result_pcap_csv.csv \
# print_history_roundoff: m
#
# For this, we are going to upload to the node the following configuration file pcap_csv.conf which contains the information shown.
# The gmail.pcapng.cap is already uploaded on the node and placed on the pmacctd folder.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/pcap_csv.conf"))
print(cmd_upload_file_to(n2, "configuration-files/pcap_csv.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_csv.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_csv.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Create the result csv file and move it to the pmacctd folder.
# 3. Execute pmacctd.
# 4. Show the results.
# 5. You can execute the last cell of the section to download the csv result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("mv pcap_csv.conf pmacct-1.7.8")
n2.execute("mv pcap_csv.conf pmacct-1.7.8")
n1.execute("touch result_pcap_csv.csv && mv result_pcap_csv.csv pmacct-1.7.8")
n1.execute("cd pmacct-1.7.8 && sudo pmacctd -f pcap_csv.conf && cat result_pcap_csv.csv")
# Out:
#  mv: cannot stat 'pcap_csv.conf': No such file or directory
#   mv: cannot stat 'pcap_csv.conf': No such file or directory
FO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)\nINFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'\nINFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/pcap_csv.conf'.\nINFO ( default/core ): [,0] link type is: 1\nINFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=4096 bytes\nINFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=8000 bytes\nINFO ( default/core ): PCAP capture file, sleeping for 2 seconds\nINFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes\nINFO ( default_print/print ): *** Purging cache - START (PID: 85051) ***\nINFO ( default_print/print ): *** Purging cache - END (PID: 85051, QN: 106/106, ET: 0) ***\nINFO ( default/core ): OK, Exiting ...\n")

# %%
print(cmd_download_file_from(n1, "pmacct-1.7.8/result_pcap_csv.csv"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/result_pcap_csv.csv .

# %% [markdown]
# ### JSON format
# The configuration file will have the following data:
#
# daemonize: false \
# debug: true \
# pcap_savefile: gmail.pcapng.cap \
# aggregate: src_host, dst_host, src_port, dst_port, proto, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: csv \
# print_output_file: result_pcap_json.json \
# print_history_roundoff: m
#
# For this, we are going to upload to the node the following configuration file pcap_json.conf which contains the information shown.
# The gmail.pcapng.cap is already uploaded on the node and placed on the pmacctd folder.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/pcap_json.conf"))
print(cmd_upload_file_to(n2, "configuration-files/pcap_json.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_json.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_json.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Create the result .json file and move it to the pmacctd folder.
# 3. Execute pmacctd.
# 4. Show the results.
# 5. You can execute the last cell of the section to download the json result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("mv pcap_json.conf pmacct-1.7.8")
n2.execute("mv pcap_json.conf pmacct-1.7.8")
n1.execute("touch result_pcap_json.json && mv result_pcap_json.json pmacct-1.7.8")
n1.execute("cd pmacct-1.7.8 && sudo pmacctd -f pcap_json.conf && cat result_pcap_json.json")
# Out:
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "178.123.13.120", "port_src": 42559, "port_dst": 26895, "ip_proto": "udp", "packets": 1, "bytes": 95}
# {"event_type": "purge", "ip_src": "208.117.231.17", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56561, "ip_proto": "tcp", "packets": 71, "bytes": 102240}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "208.117.231.17", "port_src": 56562, "port_dst": 443, "ip_proto": "tcp", "packets": 47, "bytes": 2212}
# {"event_type": "purge", "ip_src": "208.117.231.17", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56562, "ip_proto": "tcp", "packets": 54, "bytes": 77760}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "208.117.231.17", "port_src": 56561, "port_dst": 443, "ip_proto": "tcp", "packets": 53, "bytes": 2444}
# {"event_type": "purge", "ip_src": "208.117.231.17", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56563, "ip_proto": "tcp", "packets": 63, "bytes": 90720}
# {"event_type": "purge", "ip_src": "178.123.13.120", "ip_dst": "192.168.1.101", "port_src": 26895, "port_dst": 42559, "ip_proto": "udp", "packets": 1, "bytes": 98}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "208.117.231.17", "port_src": 56563, "port_dst": 443, "ip_proto": "tcp", "packets": 45, "bytes": 2188}
# {"event_type": "purge", "ip_src": "93.184.221.133", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56668, "ip_proto": "tcp", "packets": 15, "bytes": 20212}
# {"event_type": "purge", "ip_src": "192.168.1.100", "ip_dst": "239.255.255.250", "port_src": 54714, "port_dst": 1900, "ip_proto": "udp", "packets": 2, "bytes": 322}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.130", "port_src": 56671, "port_dst": 443, "ip_proto": "tcp", "packets": 4, "bytes": 161}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "93.184.221.133", "port_src": 56668, "port_dst": 80, "ip_proto": "tcp", "packets": 11, "bytes": 501}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.53", "port_src": 56643, "port_dst": 443, "ip_proto": "tcp", "packets": 21, "bytes": 5083}
# {"event_type": "purge", "ip_src": "90.84.136.33", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56582, "ip_proto": "tcp", "packets": 4, "bytes": 5760}
# {"event_type": "purge", "ip_src": "173.194.35.53", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56643, "ip_proto": "tcp", "packets": 23, "bytes": 13572}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.33", "port_src": 56582, "port_dst": 80, "ip_proto": "tcp", "packets": 4, "bytes": 196}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.32", "port_src": 56600, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "68.232.35.139", "port_src": 56659, "port_dst": 443, "ip_proto": "tcp", "packets": 3, "bytes": 151}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.66.84", "port_src": 56651, "port_dst": 443, "ip_proto": "tcp", "packets": 5, "bytes": 2114}
# {"event_type": "purge", "ip_src": "68.232.35.139", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56659, "ip_proto": "tcp", "packets": 4, "bytes": 191}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "157.56.106.184", "port_src": 59656, "port_dst": 3544, "ip_proto": "udp", "packets": 1, "bytes": 89}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "67.252.131.62", "port_src": 49690, "port_dst": 55645, "ip_proto": "udp", "packets": 4, "bytes": 348}
# {"event_type": "purge", "ip_src": "173.194.66.84", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56651, "ip_proto": "tcp", "packets": 7, "bytes": 4599}
# {"event_type": "purge", "ip_src": "157.56.106.184", "ip_dst": "192.168.1.101", "port_src": 3544, "port_dst": 59656, "ip_proto": "udp", "packets": 1, "bytes": 137}
# {"event_type": "purge", "ip_src": "208.117.231.17", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56564, "ip_proto": "tcp", "packets": 51, "bytes": 73440}
# {"event_type": "purge", "ip_src": "fe80::6d49:f772:ed9b:d16a", "ip_dst": "ff02::1:2", "port_src": 546, "port_dst": 547, "ip_proto": "udp", "packets": 1, "bytes": 131}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "208.117.231.17", "port_src": 56564, "port_dst": 443, "ip_proto": "tcp", "packets": 42, "bytes": 2036}
# {"event_type": "purge", "ip_src": "74.125.206.125", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 54760, "ip_proto": "tcp", "packets": 1, "bytes": 66}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.39", "port_src": 56655, "port_dst": 443, "ip_proto": "tcp", "packets": 6, "bytes": 1534}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "74.125.206.125", "port_src": 54760, "port_dst": 443, "ip_proto": "tcp", "packets": 1, "bytes": 40}
# {"event_type": "purge", "ip_src": "173.194.35.39", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56655, "ip_proto": "tcp", "packets": 5, "bytes": 2195}
# {"event_type": "purge", "ip_src": "90.84.59.104", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56638, "ip_proto": "tcp", "packets": 1, "bytes": 1440}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.104", "port_src": 56638, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "192.168.1.1", "port_src": 57311, "port_dst": 53, "ip_proto": "udp", "packets": 2, "bytes": 132}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "192.168.1.1", "port_src": 55365, "port_dst": 53, "ip_proto": "udp", "packets": 5, "bytes": 335}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "95.79.81.24", "port_src": 42559, "port_dst": 20101, "ip_proto": "udp", "packets": 1, "bytes": 95}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.91", "port_src": 56595, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "95.79.81.24", "ip_dst": "192.168.1.101", "port_src": 20101, "port_dst": 42559, "ip_proto": "udp", "packets": 1, "bytes": 98}
# {"event_type": "purge", "ip_src": "90.84.59.91", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56595, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.33", "port_src": 56586, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "192.168.1.1", "ip_dst": "192.168.1.101", "port_src": 53, "port_dst": 57311, "ip_proto": "udp", "packets": 1, "bytes": 406}
# {"event_type": "purge", "ip_src": "90.84.136.33", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56586, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.33", "port_src": 56583, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "fe80::35d0:b39e:c3f7:e20f", "ip_dst": "ff02::1:2", "port_src": 546, "port_dst": 547, "ip_proto": "udp", "packets": 1, "bytes": 137}
# {"event_type": "purge", "ip_src": "90.84.136.33", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56583, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.33", "port_src": 56584, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.33", "port_src": 56585, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "90.84.136.33", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56584, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "90.84.136.33", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56585, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "fe80::6d49:f772:ed9b:d16a", "ip_dst": "ff02::1:3", "port_src": 60775, "port_dst": 5355, "ip_proto": "udp", "packets": 2, "bytes": 152}
# {"event_type": "purge", "ip_src": "192.168.1.106", "ip_dst": "192.168.1.255", "port_src": 137, "port_dst": 137, "ip_proto": "udp", "packets": 3, "bytes": 234}
# {"event_type": "purge", "ip_src": "fe80::895a:cc69:a63f:3594", "ip_dst": "ff02::1:2", "port_src": 546, "port_dst": 547, "ip_proto": "udp", "packets": 1, "bytes": 140}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.252.102.24", "port_src": 56157, "port_dst": 443, "ip_proto": "tcp", "packets": 4, "bytes": 948}
# {"event_type": "purge", "ip_src": "173.252.102.24", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56157, "ip_proto": "tcp", "packets": 5, "bytes": 1040}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "31.13.80.33", "port_src": 56575, "port_dst": 443, "ip_proto": "tcp", "packets": 8, "bytes": 1986}
# {"event_type": "purge", "ip_src": "31.13.80.33", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56575, "ip_proto": "tcp", "packets": 9, "bytes": 3929}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.53", "port_src": 56644, "port_dst": 443, "ip_proto": "tcp", "packets": 5, "bytes": 399}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.33", "port_src": 56609, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "90.84.136.33", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56609, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.58", "port_src": 56588, "port_dst": 80, "ip_proto": "tcp", "packets": 4, "bytes": 161}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.83", "port_src": 56596, "port_dst": 443, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "67.252.131.62", "port_src": 56526, "port_dst": 23754, "ip_proto": "tcp", "packets": 3, "bytes": 128}
# {"event_type": "purge", "ip_src": "90.84.59.83", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56596, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "67.252.131.62", "ip_dst": "192.168.1.101", "port_src": 23754, "port_dst": 56526, "ip_proto": "tcp", "packets": 2, "bytes": 96}
# {"event_type": "purge", "ip_src": "192.168.1.103", "ip_dst": "192.168.1.255", "port_src": 137, "port_dst": 137, "ip_proto": "udp", "packets": 3, "bytes": 234}
# {"event_type": "purge", "ip_src": "173.194.35.53", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56644, "ip_proto": "tcp", "packets": 3, "bytes": 132}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "188.235.139.124", "port_src": 42559, "port_dst": 6881, "ip_proto": "udp", "packets": 1, "bytes": 95}
# {"event_type": "purge", "ip_src": "fe80::6db5:b22e:b0d3:9273", "ip_dst": "ff02::1:2", "port_src": 546, "port_dst": 547, "ip_proto": "udp", "packets": 5, "bytes": 680}
# {"event_type": "purge", "ip_src": "192.168.1.1", "ip_dst": "192.168.1.101", "port_src": 53, "port_dst": 55365, "ip_proto": "udp", "packets": 1, "bytes": 67}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "199.16.156.38", "port_src": 55914, "port_dst": 443, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.32", "port_src": 56603, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.44", "port_src": 56654, "port_dst": 443, "ip_proto": "tcp", "packets": 4, "bytes": 318}
# {"event_type": "purge", "ip_src": "90.84.59.91", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56592, "ip_proto": "tcp", "packets": 31, "bytes": 44640}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.91", "port_src": 56592, "port_dst": 80, "ip_proto": "tcp", "packets": 24, "bytes": 1204}
# {"event_type": "purge", "ip_src": "90.84.136.32", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56603, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "fe80::809b:914:6399:11e3", "ip_dst": "ff02::1:2", "port_src": 546, "port_dst": 547, "ip_proto": "udp", "packets": 1, "bytes": 134}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.66.84", "port_src": 56652, "port_dst": 443, "ip_proto": "tcp", "packets": 7, "bytes": 438}
# {"event_type": "purge", "ip_src": "173.194.35.44", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56654, "ip_proto": "tcp", "packets": 3, "bytes": 132}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "211.194.165.18", "port_src": 42559, "port_dst": 34443, "ip_proto": "udp", "packets": 1, "bytes": 95}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "192.168.1.1", "port_src": 52244, "port_dst": 53, "ip_proto": "udp", "packets": 1, "bytes": 61}
# {"event_type": "purge", "ip_src": "192.168.1.1", "ip_dst": "192.168.1.101", "port_src": 53, "port_dst": 52244, "ip_proto": "udp", "packets": 1, "bytes": 125}
# {"event_type": "purge", "ip_src": "173.194.66.84", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56652, "ip_proto": "tcp", "packets": 4, "bytes": 282}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.55", "port_src": 56675, "port_dst": 443, "ip_proto": "tcp", "packets": 6, "bytes": 765}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.55", "port_src": 56676, "port_dst": 443, "ip_proto": "tcp", "packets": 6, "bytes": 765}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.32", "port_src": 56604, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "173.194.35.55", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56675, "ip_proto": "tcp", "packets": 4, "bytes": 305}
# {"event_type": "purge", "ip_src": "173.194.35.55", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56676, "ip_proto": "tcp", "packets": 4, "bytes": 305}
# {"event_type": "purge", "ip_src": "90.84.136.32", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56604, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.55", "port_src": 56677, "port_dst": 443, "ip_proto": "tcp", "packets": 8, "bytes": 1458}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.55", "port_src": 56678, "port_dst": 443, "ip_proto": "tcp", "packets": 6, "bytes": 917}
# {"event_type": "purge", "ip_src": "173.194.35.55", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56677, "ip_proto": "tcp", "packets": 10, "bytes": 2547}
# {"event_type": "purge", "ip_src": "173.194.35.55", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56678, "ip_proto": "tcp", "packets": 6, "bytes": 516}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "67.252.131.62", "port_src": 59656, "port_dst": 55645, "ip_proto": "udp", "packets": 2, "bytes": 160}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "157.56.144.215", "port_src": 59656, "port_dst": 3544, "ip_proto": "udp", "packets": 1, "bytes": 88}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.91", "port_src": 56593, "port_dst": 80, "ip_proto": "tcp", "packets": 2, "bytes": 81}
# {"event_type": "purge", "ip_src": "67.252.131.62", "ip_dst": "192.168.1.101", "port_src": 55645, "port_dst": 49690, "ip_proto": "udp", "packets": 4, "bytes": 340}
# {"event_type": "purge", "ip_src": "90.84.59.91", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56593, "ip_proto": "tcp", "packets": 1, "bytes": 1440}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.32", "port_src": 56343, "port_dst": 443, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "173.194.35.32", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56343, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "173.194.35.58", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56588, "ip_proto": "tcp", "packets": 1, "bytes": 40}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.32", "port_src": 56599, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "70.78.196.95", "port_src": 42559, "port_dst": 34569, "ip_proto": "udp", "packets": 1, "bytes": 95}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.130", "port_src": 56669, "port_dst": 443, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.130", "port_src": 56670, "port_dst": 443, "ip_proto": "tcp", "packets": 1, "bytes": 41}
# {"event_type": "purge", "ip_src": "90.84.59.130", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56669, "ip_proto": "tcp", "packets": 1, "bytes": 52}
# {"event_type": "purge", "ip_src": "90.84.59.130", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56670, "ip_proto": "tcp", "packets": 1, "bytes": 52}
#  INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)
# INFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'
# INFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/pcap_json.conf'.
# INFO ( default/core ): [,0] link type is: 1
# INFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=4096 bytes
# INFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=8000 bytes
# INFO ( default/core ): PCAP capture file, sleeping for 2 seconds
# INFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes
# INFO ( default_print/print ): JSON: setting object handlers.
# INFO ( default_print/print ): *** Purging cache - START (PID: 68417) ***
# INFO ( default_print/print ): *** Purging cache - END (PID: 68417, QN: 106/106, ET: 0) ***
# INFO ( default/core ): OK, Exiting ...
# ('{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "178.123.13.120", "port_src": 42559, "port_dst": 26895, "ip_proto": "udp", "packets": 1, "bytes": 95}\n{"event_type": "purge", "ip_src": "208.117.231.17", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56561, "ip_proto": "tcp", "packets": 71, "bytes": 102240}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "208.117.231.17", "port_src": 56562, "port_dst": 443, "ip_proto": "tcp", "packets": 47, "bytes": 2212}\n{"event_type": "purge", "ip_src": "208.117.231.17", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56562, "ip_proto": "tcp", "packets": 54, "bytes": 77760}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "208.117.231.17", "port_src": 56561, "port_dst": 443, "ip_proto": "tcp", "packets": 53, "bytes": 2444}\n{"event_type": "purge", "ip_src": "208.117.231.17", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56563, "ip_proto": "tcp", "packets": 63, "bytes": 90720}\n{"event_type": "purge", "ip_src": "178.123.13.120", "ip_dst": "192.168.1.101", "port_src": 26895, "port_dst": 42559, "ip_proto": "udp", "packets": 1, "bytes": 98}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "208.117.231.17", "port_src": 56563, "port_dst": 443, "ip_proto": "tcp", "packets": 45, "bytes": 2188}\n{"event_type": "purge", "ip_src": "93.184.221.133", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56668, "ip_proto": "tcp", "packets": 15, "bytes": 20212}\n{"event_type": "purge", "ip_src": "192.168.1.100", "ip_dst": "239.255.255.250", "port_src": 54714, "port_dst": 1900, "ip_proto": "udp", "packets": 2, "bytes": 322}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.59.130", "port_src": 56671, "port_dst": 443, "ip_proto": "tcp", "packets": 4, "bytes": 161}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "93.184.221.133", "port_src": 56668, "port_dst": 80, "ip_proto": "tcp", "packets": 11, "bytes": 501}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.35.53", "port_src": 56643, "port_dst": 443, "ip_proto": "tcp", "packets": 21, "bytes": 5083}\n{"event_type": "purge", "ip_src": "90.84.136.33", "ip_dst": "192.168.1.101", "port_src": 80, "port_dst": 56582, "ip_proto": "tcp", "packets": 4, "bytes": 5760}\n{"event_type": "purge", "ip_src": "173.194.35.53", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56643, "ip_proto": "tcp", "packets": 23, "bytes": 13572}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.33", "port_src": 56582, "port_dst": 80, "ip_proto": "tcp", "packets": 4, "bytes": 196}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "90.84.136.32", "port_src": 56600, "port_dst": 80, "ip_proto": "tcp", "packets": 1, "bytes": 41}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "68.232.35.139", "port_src": 56659, "port_dst": 443, "ip_proto": "tcp", "packets": 3, "bytes": 151}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "173.194.66.84", "port_src": 56651, "port_dst": 443, "ip_proto": "tcp", "packets": 5, "bytes": 2114}\n{"event_type": "purge", "ip_src": "68.232.35.139", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56659, "ip_proto": "tcp", "packets": 4, "bytes": 191}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "157.56.106.184", "port_src": 59656, "port_dst": 3544, "ip_proto": "udp", "packets": 1, "bytes": 89}\n{"event_type": "purge", "ip_src": "192.168.1.101", "ip_dst": "67.252.131.62", "port_src": 49690, "port_dst": 55645, "ip_proto": "udp", "packets": 4, "bytes": 348}\n{"event_type": "purge", "ip_src": "173.194.66.84", "ip_dst": "192.168.1.101", "port_src": 443, "port_dst": 56651, "ip_proto": "tcp", "packets": 7, "bytes": 4599}\n{"event_type": "purge", "ip_src": "157.56.106.184", "ip_dst": "192.168.1.101", "port_src": 3544, "port_dst": 59656, "ip_proto": "udp", "packets": 1, "bytes": 137}\n{"event_type": "purge", "ip_src": "208.117.231.17", "ip_dst": "192.168.1 ...
#  "INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)\nINFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'\nINFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/pcap_json.conf'.\nINFO ( default/core ): [,0] link type is: 1\nINFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=4096 bytes\nINFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=8000 bytes\nINFO ( default/core ): PCAP capture file, sleeping for 2 seconds\nINFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes\nINFO ( default_print/print ): JSON: setting object handlers.\nINFO ( default_print/print ): *** Purging cache - START (PID: 68417) ***\nINFO ( default_print/print ): *** Purging cache - END (PID: 68417, QN: 106/106, ET: 0) ***\nINFO ( default/core ): OK, Exiting ...\n")

# %%
print(cmd_download_file_from(n1, "pmacct-1.7.8/result_pcap_json.json"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/result_pcap_json.json .

# %% [markdown]
# ### TXT Format
#
#
#
# The configuration file will have the following data: \
#
# daemonize: false \
# debug: true \
# pcap_savefile: gmail.pcapng.cap \
# aggregate: src_host, dst_host, src_port, dst_port, proto, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: formatted \
# print_output_file: result_pcap_formatted.txt\
# print_history_roundoff: m
#
# For this, we are going to upload to the node the following configuration file pcap_formatted.conf which contains the information shown.
# The gmail.pcapng.cap is already uploaded on the node and placed on the pmacctd folder.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/pcap_formatted.conf"))
print(cmd_upload_file_to(n2, "configuration-files/pcap_formatted.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_formatted.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_formatted.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Create the result txt file and move it to the pmacctd folder.
# 3. Execute pmacctd.
# 4. Show the results.
# 5. You can execute the last cell of the section to download the .txt result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("mv pcap_formatted.conf pmacct-1.7.8")
n2.execute("mv pcap_formatted.conf pmacct-1.7.8")
n1.execute("touch result_pcap_formatted.txt && mv result_pcap_formatted.txt pmacct-1.7.8")
n1.execute("cd pmacct-1.7.8 && sudo pmacctd -f pcap_formatted.conf && cat result_pcap_formatted.txt")
# Out:
# SRC_IP                                         DST_IP                                         SRC_PORT  DST_PORT  PROTOCOL    PACKETS               BYTES
# 192.168.1.101                                  178.123.13.120                                 42559     26895     udp         1                     95
# 208.117.231.17                                 192.168.1.101                                  443       56561     tcp         71                    102240
# 192.168.1.101                                  208.117.231.17                                 56562     443       tcp         47                    2212
# 208.117.231.17                                 192.168.1.101                                  443       56562     tcp         54                    77760
582     80        tcp         4                     196\n192.168.1.101                                  90.84.136.32                                   56600     80        tcp         1                     41\n192.168.1.101                                  68.232.35.139                                  56659     443       tcp         3                     151\n192.168.1.101                                  173.194.66.84                                  56651     443       tcp         5                     2114\n68.232.35.139                                  192.168.1.101                                  443       56659     tcp         4                     191\n192.168.1.101                                  157.56.106.184                                 59656     3544      udp         1                     89\n192.168.1.101                                  67.252.131.62                                  49690     55645     udp         4                     348\n173.194.66.84                                  192.168.1.101                                  443       56651     tcp         7                     4599\n157.56.106.184                                 192.168.1.101                                  3544      59656     udp         1                     137\n208.117.231.17                                 192.168.1.101                                  443       56564     tcp         51                    73440\nfe ...
#  "INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)\nINFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'\nINFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/pcap_formatted.conf'.\nINFO ( default/core ): [,0] link type is: 1\nINFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=4096 bytes\nINFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=8000 bytes\nINFO ( default/core ): PCAP capture file, sleeping for 2 seconds\nINFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes\nINFO ( default_print/print ): *** Purging cache - START (PID: 69163) ***\nINFO ( default_print/print ): *** Purging cache - END (PID: 69163, QN: 106/106, ET: 0) ***\nINFO ( default/core ): OK, Exiting ...\n")

# %%
print(cmd_download_file_from(n1, "pmacct-1.7.8/result_pcap_formatted.txt"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/result_pcap_formatted.txt .

# %% [markdown]
# ### Customization
#
# Pmacctd offers an important characteristic, which is that enables the user to choose which fields wants to obtain from the captured data. This can be done using the "aggregate" field on the configuration file.
#
# All the available aggregate fields are: src_mac, dst_mac, vlan, in_vlan, out_vlan, cos, etype, src_host, dst_host,src_net, dst_net, src_mask, dst_mask, src_as,    dst_as, src_port, dst_port, tos, proto, none, sum_mac, sum_host, sum_net, sum_as, sum_port, flows, tag, tag2, label, class, tcpflags, in_iface, out_iface, std_comm, ext_comm, lrg_comm, as_path, peer_src_ip, peer_dst_ip, peer_src_as, peer_dst_as, local_pref, med, dst_roa, src_std_comm, src_ext_comm, src_lrg_comm, src_as_path, src_local_pref, src_med, src_roa, mpls_vpn_rd, mpls_pw_id, mpls_label_top, mpls_label_bottom, mpls_label_stack, sampling_rate, sampling_direction, src_host_country, dst_host_country, src_host_pocode, dst_host_pocode, src_host_coords, dst_host_coords, nat_event, fw_event, post_nat_src_host, post_nat_dst_host, post_nat_src_port, post_nat_dst_port, tunnel_src_mac, tunnel_dst_mac, tunnel_src_host, tunnel_dst_host, tunnel_proto, tunnel_tos, tunnel_src_port, tunnel_dst_port, tunnel_tcpflags, fwd_status, vxlan, timestamp_start, timestamp_end, timestamp_arrival, timestamp_export, export_proto_seqno, export_proto_version, export_proto_sysid.
#
# Some of them may not be supported by some packets but we can make a small example to test some of them (the most used ones).
#
# daemonize: false \
# debug: true \
# pcap_interface: any \
# aggregate: src_host, dst_host, src_port, dst_port, proto, src_mac, dst_mac, etype, in_iface, out_iface, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: formatted \
# print_output_file: result_custom.txt \
# print_history_roundoff: m
#
#
# For this, we are going to upload to the node the following configuration file live_custom.conf which contains the information shown.
# The gmail.pcapng.cap is already uploaded on the node and placed on the pmacctd folder.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/pcap_custom.conf"))
print(cmd_upload_file_to(n2, "configuration-files/pcap_custom.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_custom.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_custom.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Create the result txt file and move it to the pmacctd folder.
# 3. Execute pmacctd.
# 4. Show the results.
# 5. You can execute the last cell of the section to download the .txt result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch result_custom.txt")
n1.execute("mv pcap_custom.conf result_custom.txt pmacct-1.7.8")
n2.execute("mv pcap_custom.conf pmacct-1.7.8")
n1.execute("cd pmacct-1.7.8 && sudo pmacctd -f pcap_custom.conf && cat result_custom.txt")
# Out:
#  mv: cannot stat 'pcap_custom.conf': No such file or directory
#   mv: cannot stat 'pcap_custom.conf': No such file or directory
#  SRC_MAC            DST_MAC            ETYPE  IN_IFACE    OUT_IFACE   SRC_IP                                         DST_IP                                         SRC_PORT  DST_PORT  PROTOCOL    PACKETS               BYTES
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  178.123.13.120                                 42559     26895     udp         1                     95
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           208.117.231.17                                 192.168.1.101                                  443       56561     tcp         71                    102240
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  208.117.231.17                                 56562     443       tcp         47                    2212
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           208.117.231.17                                 192.168.1.101                                  443       56562     tcp         54                    77760
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  208.117.231.17                                 56561     443       tcp         53                    2444
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           208.117.231.17                                 192.168.1.101                                  443       56563     tcp         63                    90720
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           178.123.13.120                                 192.168.1.101                                  26895     42559     udp         1                     98
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  208.117.231.17                                 56563     443       tcp         45                    2188
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           93.184.221.133                                 192.168.1.101                                  80        56668     tcp         15                    20212
# c4:46:19:0a:4a:c9  01:00:5e:7f:ff:fa  800    0           0           192.168.1.100                                  239.255.255.250                                54714     1900      udp         2                     322
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.59.130                                   56671     443       tcp         4                     161
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  93.184.221.133                                 56668     80        tcp         11                    501
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.35.53                                  56643     443       tcp         21                    5083
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           90.84.136.33                                   192.168.1.101                                  80        56582     tcp         4                     5760
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.53                                  192.168.1.101                                  443       56643     tcp         23                    13572
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.136.33                                   56582     80        tcp         4                     196
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.136.32                                   56600     80        tcp         1                     41
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  68.232.35.139                                  56659     443       tcp         3                     151
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.66.84                                  56651     443       tcp         5                     2114
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           68.232.35.139                                  192.168.1.101                                  443       56659     tcp         4                     191
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  157.56.106.184                                 59656     3544      udp         1                     89
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  67.252.131.62                                  49690     55645     udp         4                     348
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.66.84                                  192.168.1.101                                  443       56651     tcp         7                     4599
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           157.56.106.184                                 192.168.1.101                                  3544      59656     udp         1                     137
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           208.117.231.17                                 192.168.1.101                                  443       56564     tcp         51                    73440
# b8:03:05:40:f5:6a  33:33:00:01:00:02  86dd   0           0           fe80::6d49:f772:ed9b:d16a                      ff02::1:2                                      546       547       udp         1                     131
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  208.117.231.17                                 56564     443       tcp         42                    2036
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.136.32                                   56603     80        tcp         1                     41
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.35.44                                  56654     443       tcp         4                     318
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           90.84.59.91                                    192.168.1.101                                  80        56592     tcp         31                    44640
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.59.91                                    56592     80        tcp         24                    1204
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           90.84.136.32                                   192.168.1.101                                  80        56603     tcp         1                     52
# c4:46:19:0a:4a:c9  33:33:00:01:00:02  86dd   0           0           fe80::809b:914:6399:11e3                       ff02::1:2                                      546       547       udp         1                     134
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.66.84                                  56652     443       tcp         7                     438
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.44                                  192.168.1.101                                  443       56654     tcp         3                     132
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  211.194.165.18                                 42559     34443     udp         1                     95
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  192.168.1.1                                    52244     53        udp         1                     61
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           192.168.1.1                                    192.168.1.101                                  53        52244     udp         1                     125
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.66.84                                  192.168.1.101                                  443       56652     tcp         4                     282
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.35.55                                  56675     443       tcp         6                     765
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.35.55                                  56676     443       tcp         6                     765
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.136.32                                   56604     80        tcp         1                     41
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.55                                  192.168.1.101                                  443       56675     tcp         4                     305
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.55                                  192.168.1.101                                  443       56676     tcp         4                     305
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           90.84.136.32                                   192.168.1.101                                  80        56604     tcp         1                     52
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.35.55                                  56677     443       tcp         8                     1458
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.35.55                                  56678     443       tcp         6                     917
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.55                                  192.168.1.101                                  443       56677     tcp         10                    2547
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.55                                  192.168.1.101                                  443       56678     tcp         6                     516
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  67.252.131.62                                  59656     55645     udp         2                     160
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  157.56.144.215                                 59656     3544      udp         1                     88
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.59.91                                    56593     80        tcp         2                     81
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           67.252.131.62                                  192.168.1.101                                  55645     49690     udp         4                     340
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           90.84.59.91                                    192.168.1.101                                  80        56593     tcp         1                     1440
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.35.32                                  56343     443       tcp         1                     41
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.32                                  192.168.1.101                                  443       56343     tcp         1                     52
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.58                                  192.168.1.101                                  80        56588     tcp         1                     40
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.136.32                                   56599     80        tcp         1                     41
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  70.78.196.95                                   42559     34569     udp         1                     95
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.59.130                                   56669     443       tcp         1                     41
# 00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.59.130                                   56670     443       tcp         1                     41
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           90.84.59.130                                   192.168.1.101                                  443       56669     tcp         1                     52
# d0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           90.84.59.130                                   192.168.1.101                                  443       56670     tcp         1                     52
#  INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)
# INFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'
# INFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/pcap_custom.conf'.
# INFO ( default/core ): [,0] link type is: 1
# INFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=4096 bytes
# INFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=8000 bytes
# INFO ( default/core ): PCAP capture file, sleeping for 2 seconds
# INFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes
# INFO ( default_print/print ): *** Purging cache - START (PID: 232418) ***
# INFO ( default_print/print ): *** Purging cache - END (PID: 232418, QN: 106/106, ET: 0) ***
# INFO ( default/core ): OK, Exiting ...
# ('SRC_MAC            DST_MAC            ETYPE  IN_IFACE    OUT_IFACE   SRC_IP                                         DST_IP                                         SRC_PORT  DST_PORT  PROTOCOL    PACKETS               BYTES\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  178.123.13.120                                 42559     26895     udp         1                     95\nd0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           208.117.231.17                                 192.168.1.101                                  443       56561     tcp         71                    102240\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  208.117.231.17                                 56562     443       tcp         47                    2212\nd0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           208.117.231.17                                 192.168.1.101                                  443       56562     tcp         54                    77760\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  208.117.231.17                                 56561     443       tcp         53                    2444\nd0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           208.117.231.17                                 192.168.1.101                                  443       56563     tcp         63                    90720\nd0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           178.123.13.120                                 192.168.1.101                                  26895     42559     udp         1                     98\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  208.117.231.17                                 56563     443       tcp         45                    2188\nd0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           93.184.221.133                                 192.168.1.101                                  80        56668     tcp         15                    20212\nc4:46:19:0a:4a:c9  01:00:5e:7f:ff:fa  800    0           0           192.168.1.100                                  239.255.255.250                                54714     1900      udp         2                     322\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.59.130                                   56671     443       tcp         4                     161\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  93.184.221.133                                 56668     80        tcp         11                    501\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  173.194.35.53                                  56643     443       tcp         21                    5083\nd0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           90.84.136.33                                   192.168.1.101                                  80        56582     tcp         4                     5760\nd0:7a:b5:96:cd:0a  00:14:0b:33:33:27  800    0           0           173.194.35.53                                  192.168.1.101                                  443       56643     tcp         23                    13572\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.136.33                                   56582     80        tcp         4                     196\n00:14:0b:33:33:27  d0:7a:b5:96:cd:0a  800    0           0           192.168.1.101                                  90.84.136.32                                   56600     80        tcp         1             ...
#  "INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)\nINFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'\nINFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/pcap_custom.conf'.\nINFO ( default/core ): [,0] link type is: 1\nINFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=4096 bytes\nINFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=8000 bytes\nINFO ( default/core ): PCAP capture file, sleeping for 2 seconds\nINFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes\nINFO ( default_print/print ): *** Purging cache - START (PID: 232418) ***\nINFO ( default_print/print ): *** Purging cache - END (PID: 232418, QN: 106/106, ET: 0) ***\nINFO ( default/core ): OK, Exiting ...\n")

# %%
#Download results
print(cmd_download_file_from(n1, "pmacct-1.7.8/result_custom.txt"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/result_custom.txt .

# %% [markdown]
# ### Filtering data
# Pmacctd allow filtering the data captured using the pcap_filter field on the configuration file.
#
# This filter must be written as in tcpdump, in order to work properly. The following configuration file shows an example of it.
#
# daemonize: false \
# debug: true \
# pcap_savefile: gmail.pcapng.cap \
# pcap_filter: tcp \
# aggregate: src_host, dst_host, src_port, dst_port, proto, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: csv \
# print_output_file: result_pcap_filter.csv \
# print_history_roundoff: m
#
#
# For this, we are going to upload to the node the following configuration file pcap_filter.conf which contains the information shown.
# The gmail.pcapng.cap is already uploaded on the node and placed on the pmacctd folder.
#
# The expected output is a csv file which only contains information about tcp packets.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/pcap_filter.conf"))
print(cmd_upload_file_to(n2, "configuration-files/pcap_filter.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_filter.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/pcap_filter.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Create the result csv file and move it to the pmacctd folder.
# 3. Execute pmacctd.
# 4. Show the results.
# 5. You can execute the last cell of the section to download the .csv result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch result_pcap_filter.csv")
n1.execute("mv pcap_filter.conf result_pcap_filter.csv pmacct-1.7.8")
n1.execute("cd pmacct-1.7.8 && sudo pmacctd -f pcap_filter.conf && cat result_pcap_filter.csv")
# Out:
#  mv: cannot stat 'pcap_filter.conf': No such file or directory
#  SRC_IP,DST_IP,SRC_PORT,DST_PORT,PROTOCOL,PACKETS,BYTES
# 208.117.231.17,192.168.1.101,443,56561,tcp,71,102240
# 192.168.1.101,208.117.231.17,56562,443,tcp,47,2212
# 208.117.231.17,192.168.1.101,443,56562,tcp,54,77760
# 192.168.1.101,208.117.231.17,56561,443,tcp,53,2444
# 208.117.231.17,192.168.1.101,443,56563,tcp,63,90720
# 192.168.1.101,208.117.231.17,56563,443,tcp,45,2188
# 93.184.221.133,192.168.1.101,80,56668,tcp,15,20212
# 192.168.1.101,90.84.59.130,56671,443,tcp,4,161
# 192.168.1.101,93.184.221.133,56668,80,tcp,11,501
# 192.168.1.101,173.194.35.53,56643,443,tcp,21,5083
# 90.84.136.33,192.168.1.101,80,56582,tcp,4,5760
# 173.194.35.53,192.168.1.101,443,56643,tcp,23,13572
# 192.168.1.101,90.84.136.33,56582,80,tcp,4,196
# 192.168.1.101,90.84.136.32,56600,80,tcp,1,41
# 192.168.1.101,68.232.35.139,56659,443,tcp,3,151
# 192.168.1.101,173.194.66.84,56651,443,tcp,5,2114
# 68.232.35.139,192.168.1.101,443,56659,tcp,4,191
# 173.194.66.84,192.168.1.101,443,56651,tcp,7,4599
# 208.117.231.17,192.168.1.101,443,56564,tcp,51,73440
# 192.168.1.101,208.117.231.17,56564,443,tcp,42,2036
# 74.125.206.125,192.168.1.101,443,54760,tcp,1,66
# 192.168.1.101,173.194.35.39,56655,443,tcp,6,1534
# 192.168.1.101,74.125.206.125,54760,443,tcp,1,40
# 173.194.35.39,192.168.1.101,443,56655,tcp,5,2195
# 90.84.59.104,192.168.1.101,80,56638,tcp,1,1440
# 192.168.1.101,90.84.59.104,56638,80,tcp,1,52
# 192.168.1.101,90.84.59.91,56595,80,tcp,1,41
# 90.84.59.91,192.168.1.101,80,56595,tcp,1,52
# 192.168.1.101,90.84.136.33,56586,80,tcp,1,41
# 90.84.136.33,192.168.1.101,80,56586,tcp,1,52
# 192.168.1.101,90.84.136.33,56583,80,tcp,1,41
# 90.84.136.33,192.168.1.101,80,56583,tcp,1,52
# 192.168.1.101,90.84.136.33,56584,80,tcp,1,41
# 192.168.1.101,90.84.136.33,56585,80,tcp,1,41
# 90.84.136.33,192.168.1.101,80,56584,tcp,1,52
# 90.84.136.33,192.168.1.101,80,56585,tcp,1,52
# 192.168.1.101,173.252.102.24,56157,443,tcp,4,948
# 173.252.102.24,192.168.1.101,443,56157,tcp,5,1040
# 192.168.1.101,31.13.80.33,56575,443,tcp,8,1986
# 31.13.80.33,192.168.1.101,443,56575,tcp,9,3929
# 192.168.1.101,173.194.35.53,56644,443,tcp,5,399
# 192.168.1.101,90.84.136.33,56609,80,tcp,1,41
.1.101,90.84.59.91,56592,80,tcp,24,1204\n90.84.136.32,192.168.1.101,80,56603,tcp,1,52\n192.168.1.101,173.194.66.84,56652,443,tcp,7,438\n173.194.35.44,192.168.1.101,443,56654,tcp,3,132\n173.194.66.84,192.168.1.101,443,56652,tcp,4,282\n192.168.1.101,173.194.35.55,56675,443,tcp,6,765\n192.168.1.101,173.194.35.55,56676,443,tcp,6,765\n192.168.1.101,90.84.136.32,56604,80,tcp,1,41\n173.194.35.55,192.168.1.101,443,56675,tcp,4,305\n173.194.35.55,192.168.1.101,443,56676,tcp,4,305\n90.84.136.32,192.168.1.101,80,56604,tcp,1,52\n192.168.1.101,173.194.35.55,56677,443,tcp,8,1458\n192.168.1.101,173.194.35.55,56678,443,tcp,6,917\n173.194.35.55,192.168.1.101,443,56677,tcp,10,2547\n173.194.35.55,192.168.1.101,443,56678,tcp,6,516\n192.168.1.101,90.84.59.91,56593,80,tcp,2,81\n90.84.59.91,192.168.1.101,80,56593,tcp,1,1440\n192.168.1.101,173.194.35.32,56343,443,tcp,1,41\n173.194.35.32,192.168.1.101,443,56343,tcp,1,52\n173.194.35.58,192.168.1.101,80,56588,tcp,1,40\n192.168.1.101,90.84.136.32,56599,80,tcp,1,41\n192.168.1.101,90.84.59.130,56669,443,tcp,1,41\n192.168.1.101,90.84.59.130,56670,443,tcp,1,41\n90.84.59.130,192.168.1.101,443,56669,tcp,1,52\n90.84.59.130,192.168.1.101,443,56670,tcp,1,52\n',
#  "INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)\nINFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'\nINFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/pcap_filter.conf'.\nINFO ( default/core ): [,0] link type is: 1\nINFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=4096 bytes\nINFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=8000 bytes\nINFO ( default/core ): PCAP capture file, sleeping for 2 seconds\nINFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes\nINFO ( default_print/print ): *** Purging cache - START (PID: 226114) ***\nINFO ( default_print/print ): *** Purging cache - END (PID: 226114, QN: 78/78, ET: 0) ***\nINFO ( default/core ): OK, Exiting ...\n")

# %%
#Download results
print(cmd_download_file_from(n1, "pmacct-1.7.8/result_pcap_filter.csv"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/result_pcap_filter.csv .

# %% [markdown]
# ## Experiment of the pmacctd tool using live traffic
# In this section we are going to perform an experiment using live traffic sending ICMP packets between nodes by using the "ping" command. We are going to show the results obtained from processing the pmacctd tool on a file in the formatted different format. This format can be changed to any different one as we did on the last section, you just have to change its value on the configuration file and re-uploaded it to the node.
#
# For the execution of the tool a configuration file is needed, in this section the forllowing fields are necessary:
#
# daemonize: false \
# debug: true \
# pcap_interface: any/eth3s0 \
# aggregate: src_host, dst_host, src_port, dst_port, proto, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: csv/formatted/json \
# print_output_file: result_file.format \
# print_history_roundoff: m
#
#   - pcap_interface: This field specifies the interface where the tool captures the data from. The value can be "any" or the name of the interface itself.
#
# For this, we are going to upload to the node the following configuration file live.conf which contains the information shown.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/live.conf"))
print(cmd_upload_file_to(n2, "configuration-files/live.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/live.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/live.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Create the result result file.
# 2. Move the configuration file and the result file to the pmacctd folder.
# 3. Create live traffic betweeen the nodes.
# 4. Execute pmacctd.
# 5. Show the results.
# 6. You can execute the last cell of the section to download the .txt result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch result_live.txt")
n1.execute("mv live.conf result_live.txt pmacct-1.7.8")
n2.execute("mv live.conf pmacct-1.7.8")
# Out:
#  mv: cannot stat 'live.conf': No such file or directory
#   mv: cannot stat 'live.conf': No such file or directory
# ('', "mv: cannot stat 'live.conf': No such file or directory\n")

# %% [markdown]
# ##### Concurrent Execution
# The following cell uses the Python's threading module for concurrent execution of tasks. Two threads are created to run functions run_pmacctd on nodes n1 and n2, executing commands command_n1 and command_n2 respectively. This allows simultaneous operation of network monitoring (pmacctd) and IPv6 ping testing. The use of join() ensures synchronization, waiting for completion of the second thread before ending execution.
#
# This is used because when using live traffic pmacctd acts as a demon so it needs to be stopped manually. Since we are testing the live traffic capabilities of pmacctd, we can use threads so that first the node n1 starts the daemon of pmacctd and then n2 pings 20 times to n1. Then when the second command finishes also the pmacctd tool stops so that we can see the results.

# %%
import threading 
def run_pmacctd(node, command):
    result = node.execute(command)
    print(result)
command_n1 = "cd pmacct-1.7.8 && sudo pmacctd -f live.conf"
command_n2 = "ping -c 20 fd3f:f209:c712::1"

thread_h1 = threading.Thread(target=run_pmacctd, args=(n1, command_n1))
thread_h2 = threading.Thread(target=run_pmacctd, args=(n2, command_n2))

thread_h1.start()
thread_h2.start()

thread_h2.join()
# Out:
# PING fd3f:f209:c712::1(fd3f:f209:c712::1) 56 data bytes
# 64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.095 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.106 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.114 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.077 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.121 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.081 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.075 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.081 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.075 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.102 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.100 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.079 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.103 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.102 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.087 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.098 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.118 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.102 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.094 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.118 ms
#
# --- fd3f:f209:c712::1 ping statistics ---
# 20 packets transmitted, 20 received, 0% packet loss, time 19460ms
# rtt min/avg/max/mdev = 0.075/0.096/0.121/0.014 ms
# ('PING fd3f:f209:c712::1(fd3f:f209:c712::1) 56 data bytes\n64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.095 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.106 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.114 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.077 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.121 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.081 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.075 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.081 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.075 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.102 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.100 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.079 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.103 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.102 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.087 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.098 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.118 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.102 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.094 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.118 ms\n\n--- fd3f:f209:c712::1 ping statistics ---\n20 packets transmitted, 20 received, 0% packet loss, time 19460ms\nrtt min/avg/max/mdev = 0.075/0.096/0.121/0.014 ms\n', '')

# %%
#Show results
n1.execute("cd pmacct-1.7.8 && cat result_live.txt")
print(cmd_download_file_from(n1, "pmacct-1.7.8/result_live.txt"))
# Out:
# SRC_IP                                         DST_IP                                         SRC_PORT  DST_PORT  PROTOCOL    PACKETS               BYTES
# fe80::f816:3eff:febb:9db7                      2001:400:a100:3000:f816:3eff:febc:8269         0         0         ipv6-icmp   2                     144
# 2001:400:a100:3000:f816:3eff:febc:8269         fe80::f816:3eff:febb:9db7                      0         0         ipv6-icmp   2                     128
# 2600:2701:5000:a902::c                         2001:400:a100:3000:f816:3eff:febc:8269         47776     22        tcp         176                   16140
# 2001:400:a100:3000:f816:3eff:febc:8269         2600:2701:5000:a902::c                         22        47776     tcp         109                   26668
# 2001:400:a100:3000:f816:3eff:febc:8269         2600:2701:5000:a902::c                         22        33070     tcp         2                     416
# 2001:400:a100:3000:f816:3eff:febc:8269         2600:2701:5000:a902::c                         22        56250     tcp         2                     416
# 2600:2701:5000:a902::c                         2001:400:a100:3000:f816:3eff:febc:8269         33070     22        tcp         2                     144
# 2600:2701:5000:a902::c                         2001:400:a100:3000:f816:3eff:febc:8269         56250     22        tcp         2                     144
# 2001:400:a100:3000:f816:3eff:febc:8269         2600:2701:5000:a902::c                         22        52154     tcp         2                     416
# 2001:400:a100:3000:f816:3eff:febc:8269         2600:2701:5000:a902::c                         22        47980     tcp         2                     416
# 2600:2701:5000:a902::c                         2001:400:a100:3000:f816:3eff:febc:8269         52154     22        tcp         2                     144
# 2600:2701:5000:a902::c                         2001:400:a100:3000:f816:3eff:febc:8269         47980     22        tcp         2                     144
# 2001:400:a100:3000:f816:3eff:febc:8269         2600:2701:5000:a902::c                         22        41018     tcp         2                     416
# 2600:2701:5000:a902::c                         2001:400:a100:3000:f816:3eff:febc:8269         41018     22        tcp         2                     144
# 2001:400:a100:3000:f816:3eff:febc:8269         2610:1e0:1700:202::7                           22        50188     tcp         2                     416
# 127.0.0.1                                      127.0.0.6                                      55448     4739      udp         5                     2128
# 127.0.0.1                                      127.0.0.4                                      40777     4738      udp         5                     2108
# 127.0.0.4                                      127.0.0.1                                      0         0         icmp        10                    4496
# 127.0.0.1                                      127.0.0.6                                      35630     4739      udp         5                     2128
# 127.0.0.1                                      127.0.0.4                                      43598     4739      udp         5                     2108
# 127.0.0.1                                      127.0.0.1                                      55864     4739      udp         5                     2108
# 127.0.0.1                                      127.0.0.1                                      0         0         icmp        10                    4496
      ff02::16                                       0         0         ipv6-icmp   2                     152
# fe80::f816:3eff:fe6d:519b                      ff02::16                                       0         0         ipv6-icmp   2                     152
# fe80::f816:3eff:fe90:cf9                       ff02::16                                       0         0         ipv6-icmp   2                     152
# 2600:2701:5000:a902::c                         2001:400:a100:3000:f816:3eff:febc:8269         41800     22        tcp         9                     2008
# 2001:400:a100:3000:f816:3eff:febc:8269         2600:2701:5000:a902::c                         22        41800     tcp         10                    2378
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/result_live.txt .

# %% [markdown]
# ### Filtering data
# The pmacctd tool allows for data filtering through the pcap_filter field in its configuration file. This feature is particularly useful when working with live traffic, as it enables you to focus on specific data of interest or identify anomalies. By applying filters, you can streamline your data analysis, making it easier to pinpoint relevant information or troubleshoot issues.
#
# This filter must be written as in tcpdump, in order to work properly. The following configuration file shows an example of it. This time we are going to implement a mmore complex filter. We are going to filter by the ip of the host and the type protocol. We can also delete that information from the aggregation field since all the data collected will present the same data of them.
#
# daemonize: false \
# debug: true \
# pcap_interface: any \
# pcap_filter: icmp6 and src host fd3f:f209:c712::2 \
# aggregate: src_port, dst_port, etype, in_iface, out_iface, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: csv \
# print_output_file: result_live_filter.csv \
# print_history_roundoff: m
#
#
# For this, we are going to upload to the node the following configuration file live_filter.conf which contains the information shown.
# The gmail.pcapng.cap is already uploaded on the node and placed on the pmacctd folder.
#
# The expected output is a csv file which only contains information about icmp packets with source IP address fd3f:f209:c712::2 (n2).

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/live_filter.conf"))
print(cmd_upload_file_to(n2, "configuration-files/live_filter.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/live_filter.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/live_filter.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Create the result result file.
# 2. Move the configuration file and the result file to the pmacctd folder.
# 3. Create live traffic betweeen the nodes.
# 4. Execute pmacctd.
# 5. Show the results.
# 6. You can execute the last cell of the section to download the .csv result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch result_live_filter.csv")
n1.execute("mv live_filter.conf result_live_filter.csv pmacct-1.7.8")
# Out:
# ('', '')

# %% [markdown]
# ##### Concurrent Execution
# The following cell uses the Python's threading module for concurrent execution of tasks. Two threads are created to run functions run_pmacctd on nodes n1 and n2, executing commands command_n1 and command_n2 respectively. This allows simultaneous operation of network monitoring (pmacctd) and IPv6 ping testing. The use of join() ensures synchronization, waiting for completion of the second thread before ending execution.
#
# This is used because when using live traffic pmacctd acts as a demon so it needs to be stopped manually. Since we are testing the live traffic capabilities of pmacctd, we can use threads so that first the node n1 starts the daemon of pmacctd and then n2 pings 20 times to n1. Then when the second command finishes also the pmacctd tool stops so that we can see the results.

# %%
import threading 
def run_pmacctd(node, command):
    result = node.execute(command)
    print(result)
command_n1 = "cd pmacct-1.7.8 && sudo pmacctd -f live_filter.conf"
command_n2 = "ping -c 20 fd3f:f209:c712::1"

thread_h1 = threading.Thread(target=run_pmacctd, args=(n1, command_n1))
thread_h2 = threading.Thread(target=run_pmacctd, args=(n2, command_n2))

thread_h1.start()
thread_h2.start()

thread_h2.join()
# Out:
# PING fd3f:f209:c712::1(fd3f:f209:c712::1) 56 data bytes
# 64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.123 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.136 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.084 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.084 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.177 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.118 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.081 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.100 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.082 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.114 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.115 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.122 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.080 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.094 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.115 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.076 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.097 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.080 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.085 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.115 ms
#
# --- fd3f:f209:c712::1 ping statistics ---
# 20 packets transmitted, 20 received, 0% packet loss, time 19446ms
# rtt min/avg/max/mdev = 0.076/0.103/0.177/0.024 ms
# ('PING fd3f:f209:c712::1(fd3f:f209:c712::1) 56 data bytes\n64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.123 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.136 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.084 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.084 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.177 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.118 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.081 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.100 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.082 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.114 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.115 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.122 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.080 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.094 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.115 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.076 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.097 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.080 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.085 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.115 ms\n\n--- fd3f:f209:c712::1 ping statistics ---\n20 packets transmitted, 20 received, 0% packet loss, time 19446ms\nrtt min/avg/max/mdev = 0.076/0.103/0.177/0.024 ms\n', '')

# %%
# Show results
n1.execute("cd pmacct-1.7.8 && cat result_live_filter.csv")
# Out:
# ETYPE,IN_IFACE,OUT_IFACE,SRC_PORT,DST_PORT,PACKETS,BYTES
# 86dd,0,0,0,0,17,1728
# ('ETYPE,IN_IFACE,OUT_IFACE,SRC_PORT,DST_PORT,PACKETS,BYTES\n86dd,0,0,0,0,17,1728\n',
#  '')

# %%
# Download results
print(cmd_download_file_from(n1, "pmacct-1.7.8/result_live_filter.csv"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/result_live_filter.csv .

# %% [markdown]
# ## Experiment of the pmacctd tool using live traffic with iPerf
#
# In this section we are going to continue to use live traffic to test the pmacctd tool, but this time we are going to use iPerf.
# iPerf is a network performance testing tool used to measure bandwidth between two hosts over a TCP or UDP connection. iPerf works by establishing a client-server model where one instance of iPerf acts as the server and another as the client.
#
# The objective of this is to test the pmacctd tool this time with UDP and TCP packets, instead of ICMP ones.
#
# For the execution of the tool a configuration file is needed, in this section the following fields are necessary:
#
# daemonize: false \
# debug: true \
# pcap_interface: any \
# aggregate: src_host, dst_host, src_port, dst_port, proto, \
# plugin_buffer_size: 4096 \
# plugins: print \
# print_output: csv/formatted/json \
# print_output_file: result_file.format \
# print_history_roundoff: m
#
#
# For this, we are going to upload to the node the following configuration file iperf.conf which contains the information shown.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/iperf.conf"))
print(cmd_upload_file_to(n2, "configuration-files/iperf.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/iperf.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/iperf.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# > We need to install iperf on the nodes, since we use IPV6 we will use iperf3, which supports it.

# %%
#Install iperf3
n1.execute("sudo apt-get install -y iperf3")
n2.execute("sudo apt-get install -y iperf3")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libiperf0 libsctp1
# Suggested packages:
#   lksctp-tools
# The following NEW packages will be installed:
#   iperf3 libiperf0 libsctp1
# 0 upgraded, 3 newly installed, 0 to remove and 96 not upgraded.
# Need to get 94.1 kB of archives.
# After this operation, 331 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libsctp1 amd64 1.0.18+dfsg-1 [7876 B]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 libiperf0 amd64 3.7-3 [72.0 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 iperf3 amd64 3.7-3 [14.2 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 94.1 kB in 1s (146 kB/s)
# Selecting previously unselected package libsctp1:amd64.
# (Reading database ... 72790 files and directories currently installed.)
# Preparing to unpack .../libsctp1_1.0.18+dfsg-1_amd64.deb ...
# Unpacking libsctp1:amd64 (1.0.18+dfsg-1) ...
# Selecting previously unselected package libiperf0:amd64.
# Preparing to unpack .../libiperf0_3.7-3_amd64.deb ...
# Unpacking libiperf0:amd64 (3.7-3) ...
# Selecting previously unselected package iperf3.
# Preparing to unpack .../iperf3_3.7-3_amd64.deb ...
# Unpacking iperf3 (3.7-3) ...
# Setting up libsctp1:amd64 (1.0.18+dfsg-1) ...
# Setting up libiperf0:amd64 (3.7-3) ...
# Setting up iperf3 (3.7-3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.14) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libiperf0 libsctp1
# Suggested packages:
#   lksctp-tools
# The following NEW packages will be installed:
#   iperf3 libiperf0 libsctp1
# 0 upgraded, 3 newly installed, 0 to remove and 96 not upgraded.
# Need to get 94.1 kB of archives.
# After this operation, 331 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libsctp1 amd64 1.0.18+dfsg-1 [7876 B]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 libiperf0 amd64 3.7-3 [72.0 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 iperf3 amd64 3.7-3 [14.2 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#  Fetched 94.1 kB in 1s (143 kB/s)
#  debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Selecting previously unselected package libsctp1:amd64.
# (Reading database ... 72790 files and directories currently installed.)
# Preparing to unpack .../libsctp1_1.0.18+dfsg-1_amd64.deb ...
# Unpacking libsctp1:amd64 (1.0.18+dfsg-1) ...
# Selecting previously unselected package libiperf0:amd64.
# Preparing to unpack .../libiperf0_3.7-3_amd64.deb ...
# Unpacking libiperf0:amd64 (3.7-3) ...
# Selecting previously unselected package iperf3.
# Preparing to unpack .../iperf3_3.7-3_amd64.deb ...
# Unpacking iperf3 (3.7-3) ...
# Setting up libsctp1:amd64 (1.0.18+dfsg-1) ...
# Setting up libiperf0:amd64 (3.7-3) ...
# Setting up iperf3 (3.7-3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.14) ...
# ('Reading package lists...\nBuilding dependency tree...\nReading state information...\nThe following additional packages will be installed:\n  libiperf0 libsctp1\nSuggested packages:\n  lksctp-tools\nThe following NEW packages will be installed:\n  iperf3 libiperf0 libsctp1\n0 upgraded, 3 newly installed, 0 to remove and 96 not upgraded.\nNeed to get 94.1 kB of archives.\nAfter this operation, 331 kB of additional disk space will be used.\nGet:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libsctp1 amd64 1.0.18+dfsg-1 [7876 B]\nGet:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 libiperf0 amd64 3.7-3 [72.0 kB]\nGet:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 iperf3 amd64 3.7-3 [14.2 kB]\nFetched 94.1 kB in 1s (143 kB/s)\nSelecting previously unselected package libsctp1:amd64.\r\n(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 72790 files and directories currently installed.)\r\nPreparing to unpack .../libsctp1_1.0.18+dfsg-1_amd64.deb ...\r\nUnpacking libsctp1:amd64 (1.0.18+dfsg-1) ...\r\nSelecting previously unselected package libiperf0:amd64.\r\nPreparing to unpack .../libiperf0_3.7-3_amd64.deb ...\r\nUnpacking libiperf0:amd64 (3.7-3) ...\r\nSelecting previously unselected package iperf3.\r\nPreparing to unpack .../iperf3_3.7-3_amd64.deb ...\r\nUnpacking iperf3 (3.7-3) ...\r\nSetting up libsctp1:amd64 (1.0.18+dfsg-1) ...\r\nSetting up libiperf0:amd64 (3.7-3) ...\r\nSetting up iperf3 (3.7-3) ...\r\nProcessing triggers for man-db (2.9.1-1) ...\r\nProcessing triggers for libc-bin (2.31-0ubuntu9.14) ...\r\n',
#  'debconf: unable to initialize frontend: Dialog\ndebconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)\ndebconf: falling back to frontend: Readline\ndebconf: unable to initialize frontend: Readline\ndebconf: (This frontend requires a controlling tty.)\ndebconf: falling back to frontend: Teletype\ndpkg-preconfigure: unable to re-open stdin: \n')

# %% [markdown]
# ##### Execution
#
# 1. Create the result result file.
# 2. Move the configuration file and the result file to the pmacctd folder.
# 3. Create live traffic betweeen the nodes.
# 4. Execute pmacctd.
# 5. Show the results.
# 6. You can execute the last cell of the section to download the .txt result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch result_iperf.csv")
n1.execute("mv iperf.conf result_iperf.csv pmacct-1.7.8")
n2.execute("mv iperf.conf pmacct-1.7.8")
# Out:
#  mv: cannot stat 'iperf.conf': No such file or directory
#   mv: cannot stat 'iperf.conf': No such file or directory
# ('', "mv: cannot stat 'iperf.conf': No such file or directory\n")

# %% [markdown]
# ##### iPerf
#
# This time we are going to use the same thread approach to test the tool, but using iPerf. n1 will act as the server node and n2 wil act as the client, but first we need to execute the daemon tool on the server node, which will finish when the last command finishes.
#
# > Note: It must work, but if not, you will need to look for the PID of the process by getting into the terminal of the node and put the command ps aux | grep iperf and then use the command sudo kill -9 "PID" so that the address gets free and you can execute the iPerf again.

# %%
import threading

def run_iperf(node, command):
    result = node.execute(command)
    print(result)
command = "cd pmacct-1.7.8 && sudo pmacctd -f iperf.conf"
command_n1 = "iperf3 -s"
command_n2 = "iperf3 -c fd3f:f209:c712::1 -6"

thread = threading.Thread(target=run_iperf, args=(n1, command))
thread_n1 = threading.Thread(target=run_iperf, args=(n1, command_n1))
thread_n2 = threading.Thread(target=run_iperf, args=(n2, command_n2))

thread.start()
thread_n1.start()
thread_n2.start()

thread_n2.join()
# Out:
#  iperf3: error - unable to start listener for connections: Address already in use
# iperf3: exiting
#  ('', 'iperf3: error - unable to start listener for connections: Address already in use\niperf3: exiting\n')
# Connecting to host fd3f:f209:c712::1, port 5201
# [  5] local fd3f:f209:c712::2 port 51486 connected to fd3f:f209:c712::1 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  1.48 GBytes  12.7 Gbits/sec  173   1.48 MBytes
# [  5]   1.00-2.00   sec  1.40 GBytes  12.0 Gbits/sec    0   1.52 MBytes
# [  5]   2.00-3.00   sec  1.42 GBytes  12.2 Gbits/sec    0   1.52 MBytes
# [  5]   3.00-4.00   sec  1.44 GBytes  12.4 Gbits/sec    9   1.07 MBytes
# [  5]   4.00-5.00   sec  1.42 GBytes  12.2 Gbits/sec    0   1.37 MBytes
# [  5]   5.00-6.00   sec  1.28 GBytes  11.0 Gbits/sec   35   1.10 MBytes
# [  5]   6.00-7.00   sec  1.29 GBytes  11.1 Gbits/sec    0   1.29 MBytes
# [  5]   7.00-8.00   sec  1.44 GBytes  12.4 Gbits/sec    0   1.29 MBytes
# [  5]   8.00-9.00   sec  1.42 GBytes  12.2 Gbits/sec    0   1.29 MBytes
# [  5]   9.00-10.00  sec  1.42 GBytes  12.2 Gbits/sec    0   1.29 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  14.0 GBytes  12.0 Gbits/sec  217             sender
# [  5]   0.00-10.00  sec  14.0 GBytes  12.0 Gbits/sec                  receiver
#
# iperf Done.
# ('Connecting to host fd3f:f209:c712::1, port 5201\n[  5] local fd3f:f209:c712::2 port 51486 connected to fd3f:f209:c712::1 port 5201\n[ ID] Interval           Transfer     Bitrate         Retr  Cwnd\n[  5]   0.00-1.00   sec  1.48 GBytes  12.7 Gbits/sec  173   1.48 MBytes       \n[  5]   1.00-2.00   sec  1.40 GBytes  12.0 Gbits/sec    0   1.52 MBytes       \n[  5]   2.00-3.00   sec  1.42 GBytes  12.2 Gbits/sec    0   1.52 MBytes       \n[  5]   3.00-4.00   sec  1.44 GBytes  12.4 Gbits/sec    9   1.07 MBytes       \n[  5]   4.00-5.00   sec  1.42 GBytes  12.2 Gbits/sec    0   1.37 MBytes       \n[  5]   5.00-6.00   sec  1.28 GBytes  11.0 Gbits/sec   35   1.10 MBytes       \n[  5]   6.00-7.00   sec  1.29 GBytes  11.1 Gbits/sec    0   1.29 MBytes       \n[  5]   7.00-8.00   sec  1.44 GBytes  12.4 Gbits/sec    0   1.29 MBytes       \n[  5]   8.00-9.00   sec  1.42 GBytes  12.2 Gbits/sec    0   1.29 MBytes       \n[  5]   9.00-10.00  sec  1.42 GBytes  12.2 Gbits/sec    0   1.29 MBytes       \n- - - - - - - - - - - - - - - - - - - - - - - - -\n[ ID] Interval           Transfer     Bitrate         Retr\n[  5]   0.00-10.00  sec  14.0 GBytes  12.0 Gbits/sec  217             sender\n[  5]   0.00-10.00  sec  14.0 GBytes  12.0 Gbits/sec                  receiver\n\niperf Done.\n', '')

# fe80::f816:3eff:fe69:f180,ff02::16,0,0,ipv6-icmp,2,152
# fe80::f816:3eff:feb7:167f,ff02::16,0,0,ipv6-icmp,2,152
# fe80::f816:3eff:fe86:6a88,ff02::16,0,0,ipv6-icmp,1,76
# fe80::f816:3eff:fe27:f059,ff02::16,0,0,ipv6-icmp,2,152
# fe80::f816:3eff:fea3:6b3d,ff02::16,0,0,ipv6-icmp,2,152
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/result_iperf.csv .

# %%
print(cmd_download_file_from(n1, "pmacct-1.7.8/result_iperf.csv"))

# %% [markdown]
# ## Experiment of the pmacctd tool using a pcap file with IPFIX flows
#
# IPFIX (IP Flow Information Export) flows are a standard method for exporting detailed information about IP traffic flows from network devices like routers and switches. They capture metadata including packet counts, timestamps, protocol types, ports, source and destination IP addresses, and so on. Security, traffic analysis, and network monitoring are all done with this data. IPFIX assists in anomaly detection and performance optimization. It is also a more advanced and flexible version of NetFlow, allowing for more detailed and customizable flow information export.
#
# We are going to first work producing IPFIX flows with pmacctd using a pcap file, this will include first print the result on a terminal, then on a log file at pmacctd then we are going to create an .ipfix file which will be opened and analyzed with tshark and lastly we are going to send the flows to a collector using the Netflow Python library.

# %% [markdown]
# ### Print the result on the terminal
#
# For this first and easiest experiment we will use the following configuration file:
#
# daemonize: false \
# debug: true \
# pcap_savefile: gmail.pcapng.cap \
# plugins: nfprobe, print \
# nfprobe_version: 10
#
# - nfprobe: This plugin is used for exporting network flow data using the NetFlow/IPFIX protocol.
# - print: This plugin is used for printing the collected data, in this case to standard output since we have not specified an output file.
# - nfprobe_version: 10 refers to IPFIX, which is also known as NetFlow version 10.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/ipfix_1.conf"))
print(cmd_upload_file_to(n2, "configuration-files/ipfix_1.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_1.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_1.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Execute pmacctd.
# 3. Show the results.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("mv ipfix_1.conf pmacct-1.7.8")
n2.execute("mv ipfix_1.conf pmacct-1.7.8")
# Out:
# ('', '')

# %%
n1.execute("cd pmacct-1.7.8 && sudo pmacctd -f ipfix_1.conf")
# Out:
# SRC_IP                                         PACKETS               BYTES
# 192.168.1.101                                  366                   30583
# 208.117.231.17                                 239                   344160
# 178.123.13.120                                 1                     98
# 93.184.221.133                                 15                    20212
# 192.168.1.100                                  2                     322
# 90.84.136.33                                   9                     6020
# 173.194.35.53                                  26                    13704
# 68.232.35.139                                  4                     191
# 173.194.66.84                                  11                    4881
# 157.56.106.184                                 1                     137
# fe80::6d49:f772:ed9b:d16a                      3                     283
# 74.125.206.125                                 1                     66
# 173.194.35.39                                  5                     2195
# 90.84.59.104                                   1                     1440
# 95.79.81.24                                    1                     98
# 90.84.59.91                                    33                    46132
# 192.168.1.1                                    3                     598
# fe80::35d0:b39e:c3f7:e20f                      1                     137
# 192.168.1.106                                  3                     234
# fe80::895a:cc69:a63f:3594                      1                     140
# 173.252.102.24                                 5                     1040
# 31.13.80.33                                    9                     3929
# 90.84.59.83                                    1                     52
# 67.252.131.62                                  6                     436
# 192.168.1.103                                  3                     234
# fe80::6db5:b22e:b0d3:9273                      5                     680
# 90.84.136.32                                   2                     104
# fe80::809b:914:6399:11e3                       1                     134
# 173.194.35.44                                  3                     132
# 173.194.35.55                                  24                    3673
# 173.194.35.32                                  1                     52
# 173.194.35.58                                  1                     40
# 90.84.59.130                                   2                     104
#  INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)
# INFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'
# INFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/ipfix_1.conf'.
# WARN ( default_print/print ): defaulting to SRC HOST aggregation.
# INFO ( default/core ): [,0] link type is: 1
# INFO ( default_nfprobe/nfprobe ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes
# INFO ( default_nfprobe/nfprobe ): ctrl channel: obtained=212992 bytes target=3200 bytes
# INFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes
# INFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=3200 bytes
# INFO ( default_nfprobe/nfprobe ): NetFlow probe plugin is originally based on softflowd 0.9.7 software, Copyright 2002 Damien Miller <djm@mindrot.org> All rights reserved.
# INFO ( default_nfprobe/nfprobe ):           TCP timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):  TCP post-RST timeout: 120s
# INFO ( default_nfprobe/nfprobe ):  TCP post-FIN timeout: 300s
# INFO ( default_nfprobe/nfprobe ):           UDP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):          ICMP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):       General timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):      Maximum lifetime: 604800s
# INFO ( default_nfprobe/nfprobe ):       Expiry interval: 60s
# INFO ( default_nfprobe/nfprobe ): Exporting flows to [127.0.0.1]:2100
# INFO ( default/core ): PCAP capture file, sleeping for 2 seconds
# INFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes
# WARN ( default_print/print ): no print_output_file and no print_output_lock_file defined.
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:1 [178.123.13.120]:26895 <> [192.168.1.101]:42559 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:2 [192.168.1.101]:56561 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:3 [192.168.1.101]:56562 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:4 [192.168.1.101]:56563 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:5 [93.184.221.133]:80 <> [192.168.1.101]:56668 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:6 [192.168.1.100]:54714 <> [239.255.255.250]:1900 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:7 [90.84.59.130]:443 <> [192.168.1.101]:56671 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:8 [173.194.35.53]:443 <> [192.168.1.101]:56643 proto:6
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:9 [90.84.136.33]:80 <> [192.168.1.101]:56582 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:10 [90.84.136.32]:80 <> [192.168.1.101]:56600 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:12 [173.194.66.84]:443 <> [192.168.1.101]:56651 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:13 [157.56.106.184]:3544 <> [192.168.1.101]:59656 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:14 [67.252.131.62]:55645 <> [192.168.1.101]:49690 proto:17
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:15 [192.168.1.101]:56564 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:16 [fe80::6d49:f772:ed9b:d16a]:546 <> [ff02::1:2]:547 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:17 [74.125.206.125]:443 <> [192.168.1.101]:54760 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:18 [173.194.35.39]:443 <> [192.168.1.101]:56655 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:19 [90.84.59.104]:80 <> [192.168.1.101]:56638 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:20 [192.168.1.1]:53 <> [192.168.1.101]:57311 proto:17
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq
FO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)\nINFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'\nINFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/ipfix_1.conf'.\nWARN ( default_print/print ): defaulting to SRC HOST aggregation.\nINFO ( default/core ): [,0] link type is: 1\nINFO ( default_nfprobe/nfprobe ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes\nINFO ( default_nfprobe/nfprobe ): ctrl channel: obtained=212992 bytes target=3200 bytes\nINFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes\nINFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=3200 bytes\nINFO ( default_nfprobe/nfprobe ): NetFlow probe plugin is originally based on softflowd 0.9.7 software, Copyright 2002 Damien Miller <djm@mindrot.org> All rights reserved.\nINFO ( default_nfprobe/nfprobe ):           TCP timeout: 3600s\nINFO ( default_nfprobe/nfprobe ):  TCP post-RST timeout: 120s\nINFO ( default_nfprobe/nfprobe ):  TCP post-FIN timeout: 300s\nINFO ( default_nfprobe/nfprobe ):           UDP timeout: 300s\nINFO ( default_nfprobe/nfprobe ):          ICMP timeout: 300s\nINFO ( default_nfprobe/nfprobe ):       General timeout: 3600s\nINFO ( default_nfprobe/nfprobe ):      Maximum lifetime: 604800s\nINFO ( default_nfprobe/nfprobe ):       Expiry interval: 60s\nINFO ( default_nfprobe/nfprobe ): Exporting flows to [127.0.0.1]:2100\nINFO ( default/core ): PCAP capture file, sleeping for 2 seconds\nINFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes\nWARN ( default_print/print ): no print_output_file and no print_output_lock_file defined.\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:1 [178.123.13.120]:26895 <> [192.168.1.101]:42559 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:2 [192.168.1.101]:56561 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:3 [192.168.1.101]:56562 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:4 [192.168.1.101]:56563 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:5 [93.184.221.133]:80 <> [192.168.1.101]:56668 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:6 [192.168.1.100]:54714 <> [239.255.255.250]:1900 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:7 [90.84.59.130]:443 <> [192.168.1.101]:56671 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:8 [173.194.35.53]:443 <> [192.168.1.101]:56643 proto:6\nDEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1\nDEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:9 [90.84.136.33]:80 <> [192.168.1.101]:56582 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:10 [90.84.136.32]:80 <> [192.168.1.101]:56600 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:12 [173.194.66.84]:443 <> [192.168.1.101]:56651 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:13 [157.56.106.184]:3544 <> [192.168.1.101]:59656 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:14 [67.252.131.62]:55645 <> [192.168.1.101]:49690 proto:17\nDEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1\nDEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:15 [192.168.1.101]:56564 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:16 [fe80::6d49:f772:ed9b:d16a]:546 <> [ff02::1:2]:547 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:17 [74.125.206.125]:443 <> [192.168.1.101]:54760 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:18 [173.194.35.39]:443 <> [192.168.1.101]:56655 proto:6\nDEBUG ( default_nfprobe/nfp ...

# %% [markdown]
# ### Print the result on a log file
#
# For this second experiment we will use the following configuration file:
#
# daemonize: false \
# debug: true \
# pcap_savefile: gmail.pcapng.cap \
# plugins: nfprobe, print \
# nfprobe_version: 10 \
# print_output_file: ipfix_2.log
#
# - print: This plugin is used for printing the collected data, in this case to a log file since we have specified an output file.
# - print_output_file: refers to the log output file.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/ipfix_2.conf"))
print(cmd_upload_file_to(n2, "configuration-files/ipfix_2.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_2.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_2.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Create the result result log file.
# 2. Move the configuration file and the result file to the pmacctd folder.
# 3. Execute pmacctd.
# 4. Show the results.
# 5. You can execute the last cell of the section to download the .log result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch ipfix_2.log")
n1.execute("mv ipfix_2.conf ipfix_2.log pmacct-1.7.8")
n2.execute("mv ipfix_2.conf pmacct-1.7.8")
# Out:
# ('', '')

# %%
n1.execute("cd pmacct-1.7.8 && sudo pmacctd -f ipfix_2.conf")
n1.execute("cd pmacct-1.7.8 && cat ipfix_2.log")
# Out:
#  INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)
# INFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'
# INFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/ipfix_2.conf'.
# WARN ( default_print/print ): defaulting to SRC HOST aggregation.
# INFO ( default/core ): [,0] link type is: 1
# INFO ( default_nfprobe/nfprobe ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes
# INFO ( default_nfprobe/nfprobe ): ctrl channel: obtained=212992 bytes target=3200 bytes
# INFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes
# INFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=3200 bytes
# INFO ( default_nfprobe/nfprobe ): NetFlow probe plugin is originally based on softflowd 0.9.7 software, Copyright 2002 Damien Miller <djm@mindrot.org> All rights reserved.
# INFO ( default_nfprobe/nfprobe ):           TCP timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):  TCP post-RST timeout: 120s
# INFO ( default_nfprobe/nfprobe ):  TCP post-FIN timeout: 300s
# INFO ( default_nfprobe/nfprobe ):           UDP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):          ICMP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):       General timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):      Maximum lifetime: 604800s
# INFO ( default_nfprobe/nfprobe ):       Expiry interval: 60s
# INFO ( default_nfprobe/nfprobe ): Exporting flows to [127.0.0.1]:2100
# INFO ( default/core ): PCAP capture file, sleeping for 2 seconds
# INFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:1 [178.123.13.120]:26895 <> [192.168.1.101]:42559 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:2 [192.168.1.101]:56561 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:3 [192.168.1.101]:56562 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:4 [192.168.1.101]:56563 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:5 [93.184.221.133]:80 <> [192.168.1.101]:56668 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:6 [192.168.1.100]:54714 <> [239.255.255.250]:1900 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:7 [90.84.59.130]:443 <> [192.168.1.101]:56671 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:8 [173.194.35.53]:443 <> [192.168.1.101]:56643 proto:6
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:9 [90.84.136.33]:80 <> [192.168.1.101]:56582 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:10 [90.84.136.32]:80 <> [192.168.1.101]:56600 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:12 [173.194.66.84]:443 <> [192.168.1.101]:56651 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:13 [157.56.106.184]:3544 <> [192.168.1.101]:59656 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq
# 90.84.59.91                                    33                    46132
# 192.168.1.1                                    3                     598
# fe80::35d0:b39e:c3f7:e20f                      1                     137
# 192.168.1.106                                  3                     234
# fe80::895a:cc69:a63f:3594                      1                     140
# 173.252.102.24                                 5                     1040
# 31.13.80.33                                    9                     3929
# 90.84.59.83                                    1                     52
# 67.252.131.62                                  6                     436
# 192.168.1.103                                  3                     234
# fe80::6db5:b22e:b0d3:9273                      5                     680
# 90.84.136.32                                   2                     104
# fe80::809b:914:6399:11e3                       1                     134
# 173.194.35.44                                  3                     132
# 173.194.35.55                                  24                    3673
# 173.194.35.32                                  1                     52
# 173.194.35.58                                  1                     40
# 90.84.59.130                                   2                     104
# ('SRC_IP                                         PACKETS               BYTES\n192.168.1.101                                  366                   30583\n208.117.231.17                                 239                   344160\n178.123.13.120                                 1                     98\n93.184.221.133                                 15                    20212\n192.168.1.100                                  2                     322\n90.84.136.33                                   9                     6020\n173.194.35.53                                  26                    13704\n68.232.35.139                                  4                     191\n173.194.66.84                                  11                    4881\n157.56.106.184                                 1                     137\nfe80::6d49:f772:ed9b:d16a                      3                     283\n74.125.206.125                                 1                     66\n173.194.35.39                                  5                     2195\n90.84.59.104                                   1                     1440\n95.79.81.24                                    1                     98\n90.84.59.91                                    33                    46132\n192.168.1.1                                    3                     598\nfe80::35d0:b39e:c3f7:e20f                      1                     137\n192.168.1.106                                  3                     234\nfe80::895a:cc69:a63f:3594                      1                     140\n173.252.102.24                                 5                     1040\n31.13.80.33                                    9                     3929\n90.84.59.83                                    1                     52\n67.252.131.62                                  6                     436\n192.168.1.103                                  3                     234\nfe80::6db5:b22e:b0d3:9273                      5                     680\n90.84.136.32                                   2                     104\nfe80::809b:914:6399:11e3                       1                     134\n173.194.35.44                                  3                     132\n173.194.35.55                                  24                    3673\n173.194.35.32                                  1                     52\n173.194.35.58                                  1                     40\n90.84.59.130                                   2                     104\n',
#  '')

# %%
print(cmd_download_file_from(n1, "pmacct-1.7.8/ipfix_2.log"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/ipfix_2.log .

# %% [markdown]
# ### Send the IPFIX flows to an .ipfix file
#
# For this experiment we will use the following configuration file:
#
# daemonize: false \
# debug: true \
# pcap_savefile: gmail.pcapng.cap \
# plugins: nfprobe \
# nfprobe_receiver: 127.0.0.1:4739 \
# nfprobe_version: 10
#
# - nfprobe_receiver: it configures pmacct to send the collected network flow data to a local collector on IP address 127.0.0.1 (local) running on port 4739.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/ipfix_3.conf"))
print(cmd_upload_file_to(n2, "configuration-files/ipfix_3.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_3.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_3.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Create the result result IPFIX file.
# 2. Move the configuration file and the result file to the pmacctd folder.
# 3. Redirect the network flow of 127.0.0.1 port 4739 to the file
# 4. Execute pmacctd.
# 5. Show the results.
# 6. You can execute the last cell of the section to download the .log result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch ipfix_flows_3.ipfix")
n1.execute("mv ipfix_3.conf ipfix_flows_3.ipfix pmacct-1.7.8")
n2.execute("mv ipfix_3.conf pmacct-1.7.8")
# Out:
# ('', '')

# %% [markdown]
# ##### Redirecting the flow of 127.0.0.1 port 4739 to the file.
# We are going to do that using netcat. So we first need to download it and then use the following command to redirect the ipfix flows created to it: nc -u -l 4739 > pmacct-1.7.8/ipfix_flows_3.ipfix.
#
# This command means that we are using the NetCat utility using UDP which listens for incoming connections on port 4739 and which redirects the output to the file specified on the path, in this cas ipfix_flows_3.ipfix

# %%
n1.execute("sudo apt-get install netcat")
n2.execute("sudo apt-get install netcat")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   netcat
# 0 upgraded, 1 newly installed, 0 to remove and 96 not upgraded.
# Need to get 2172 B of archives.
# After this operation, 15.4 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 netcat all 1.206-1ubuntu1 [2172 B]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Fetched 2172 B in 0s (6732 B/s)
# Selecting previously unselected package netcat.
# (Reading database ... 72809 files and directories currently installed.)
# Preparing to unpack .../netcat_1.206-1ubuntu1_all.deb ...
# Unpacking netcat (1.206-1ubuntu1) ...
# Setting up netcat (1.206-1ubuntu1) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   netcat
# 0 upgraded, 1 newly installed, 0 to remove and 96 not upgraded.
# Need to get 2172 B of archives.
# After this operation, 15.4 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 netcat all 1.206-1ubuntu1 [2172 B]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#  Fetched 2172 B in 0s (6794 B/s)
#  dpkg-preconfigure: unable to re-open stdin:
#  Selecting previously unselected package netcat.
# (Reading database ... 72809 files and directories currently installed.)
# Preparing to unpack .../netcat_1.206-1ubuntu1_all.deb ...
# Unpacking netcat (1.206-1ubuntu1) ...
# Setting up netcat (1.206-1ubuntu1) ...
# ('Reading package lists...\nBuilding dependency tree...\nReading state information...\nThe following NEW packages will be installed:\n  netcat\n0 upgraded, 1 newly installed, 0 to remove and 96 not upgraded.\nNeed to get 2172 B of archives.\nAfter this operation, 15.4 kB of additional disk space will be used.\nGet:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal/universe amd64 netcat all 1.206-1ubuntu1 [2172 B]\nFetched 2172 B in 0s (6794 B/s)\nSelecting previously unselected package netcat.\r\n(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 72809 files and directories currently installed.)\r\nPreparing to unpack .../netcat_1.206-1ubuntu1_all.deb ...\r\nUnpacking netcat (1.206-1ubuntu1) ...\r\nSetting up netcat (1.206-1ubuntu1) ...\r\n',
#  'debconf: unable to initialize frontend: Dialog\ndebconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)\ndebconf: falling back to frontend: Readline\ndebconf: unable to initialize frontend: Readline\ndebconf: (This frontend requires a controlling tty.)\ndebconf: falling back to frontend: Teletype\ndpkg-preconfigure: unable to re-open stdin: \n')

# %%
import threading

def run_iperf(node, command):
    result = node.execute(command)
    print(result)
command_1 = "nc -u -l 4739 > pmacct-1.7.8/ipfix_flows_3.ipfix"
command_2 = "cd pmacct-1.7.8 && sudo pmacctd -f ipfix_3.conf"

thread_1 = threading.Thread(target=run_iperf, args=(n1, command_1))
thread_2 = threading.Thread(target=run_iperf, args=(n1, command_2))

thread_1.start()
thread_2.start()

thread_2.join()
# Out:
#  INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)
# INFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'
# INFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/ipfix_3.conf'.
# INFO ( default/core ): [,0] link type is: 1
# INFO ( default_nfprobe/nfprobe ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes
# INFO ( default_nfprobe/nfprobe ): ctrl channel: obtained=212992 bytes target=3200 bytes
# INFO ( default/core ): PCAP capture file, sleeping for 2 seconds
# INFO ( default_nfprobe/nfprobe ): NetFlow probe plugin is originally based on softflowd 0.9.7 software, Copyright 2002 Damien Miller <djm@mindrot.org> All rights reserved.
# INFO ( default_nfprobe/nfprobe ):           TCP timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):  TCP post-RST timeout: 120s
# INFO ( default_nfprobe/nfprobe ):  TCP post-FIN timeout: 300s
# INFO ( default_nfprobe/nfprobe ):           UDP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):          ICMP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):       General timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):      Maximum lifetime: 604800s
# INFO ( default_nfprobe/nfprobe ):       Expiry interval: 60s
# INFO ( default_nfprobe/nfprobe ): Exporting flows to [127.0.0.1]:4739
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:1 [178.123.13.120]:26895 <> [192.168.1.101]:42559 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:2 [192.168.1.101]:56561 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:3 [192.168.1.101]:56562 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:4 [192.168.1.101]:56563 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:5 [93.184.221.133]:80 <> [192.168.1.101]:56668 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:6 [192.168.1.100]:54714 <> [239.255.255.250]:1900 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:7 [90.84.59.130]:443 <> [192.168.1.101]:56671 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:8 [173.194.35.53]:443 <> [192.168.1.101]:56643 proto:6
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:9 [90.84.136.33]:80 <> [192.168.1.101]:56582 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:10 [90.84.136.32]:80 <> [192.168.1.101]:56600 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:12 [173.194.66.84]:443 <> [192.168.1.101]:56651 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:13 [157.56.106.184]:3544 <> [192.168.1.101]:59656 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:14 [67.252.131.62]:55645 <> [192.168.1.101]:49690 proto:17
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:15 [192.168.1.101]:56564 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:16 [fe80::6d49:f772:ed9b:d16a]:546 <> [ff02::1:2]:547 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:17 [74.125.206.125]:443 <> [192.168.1.101]:54760 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:18 [173.194.35.39]:443 <> [192.168.1.101]:56655 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:19 [90.84.59.104]:80 <> [192.168.1.101]:56638 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:20 [192.168.1.1]:53 <> [192.168.1.101]:57311 proto:17
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:21 [192.168.1.1]:53 <> [192.168.1.101]:55365 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:22 [95.79.81.24]:20101 <> [192.168.1.101]:42559 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:23 [90.84.59.91]:80 <> [192.168.1.101]:56595 proto:6
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:24 [90.84.136.33]:80 <> [192.168.1.101]:56586 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:25 [90.84.136.33]:80 <> [192.168.1.101]:56583 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:26 [fe80::35d0:b39e:c3f7:e20f]:546 <> [ff02::1:2]:547 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:27 [90.84.136.33]:80 <> [192.168.1.101]:56584 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:28 [90.84.136.33]:80 <> [192.168.1.101]:56585 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:29 [fe80::6d49:f772:ed9b:d16a]:60775 <> [ff02::1:3]:5355 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:30 [192.168.1.106]:137 <> [192.168.1.255]:137 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:31 [fe80::895a:cc69:a63f:3594]:546 <> [ff02::1:2]:547 proto:17
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:32 [173.252.102.24]:443 <> [192.168.1.101]:56157 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq
for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:35 (0x564d2cd7ba00) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:37 (0x564d2cd7bd00) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:38 (0x564d2cd7be80) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:32 (0x564d2cd7b580) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:33 (0x564d2cd7b700) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:42 (0x564d2cd7c480) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:43 (0x564d2cd7c600) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:5 (0x564d2cd75f10) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:52 (0x564d2cd7d380) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:53 (0x564d2cd7d500) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:54 (0x564d2cd7d680) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:57 (0x564d2cd7db00) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:58 (0x564d2cd7dc80) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:59 (0x564d2cd7de00) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:8 (0x564d2cd79180) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:61 (0x564d2cd7e100) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:62 (0x564d2cd7e280) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:4 (0x564d2cd75d90) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:2 (0x564d2cd75a90) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:3 (0x564d2cd75c10) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:7 (0x564d2cd79000) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:15 (0x564d2cd79c00) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:45 (0x564d2cd7c900) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 62 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 406, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 408
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 248, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 362, template ID = 1024, total len = 346
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 476, template ID = 1024, total len = 460
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 476
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 248, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 362, template ID = 1024, total len = 346
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 476, template ID = 1024, total len = 460
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 476
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 77, template ID = 1024, total len = 61
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 165, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 286, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 400, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 485, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 488
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 101, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 182, template ID = 2048, total len = 166
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 245, template ID = 1024, total len = 61
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 302, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 359, template ID = 1024, total len = 175
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 473, template ID = 1024, total len = 289
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 476
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 101, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 165, template ID = 1024, total len = 61
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 279, template ID = 1024, total len = 175
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 336, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 393, template ID = 1024, total len = 289
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 507, template ID = 1024, total len = 403
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 508
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 101, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 165, template ID = 1024, total len = 61
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 222, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 336, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 450, template ID = 1024, total len = 346
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 452
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 248, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 362, template ID = 1024, total len = 346
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 476, template ID = 1024, total len = 460
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 476
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 248, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 362, template ID = 1024, total len = 346
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 476, template ID = 1024, total len = 460
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 476
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 248, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 362, template ID = 1024, total len = 346
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 476, template ID = 1024, total len = 460
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 476
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 191, template ID = 1024, total len = 175
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 305, template ID = 1024, total len = 289
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 419, template ID = 1024, total len = 403
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 420
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 248, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 362, template ID = 1024, total len = 346
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 476, template ID = 1024, total len = 460
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 476
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 191, template ID = 1024, total len = 175
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 305, template ID = 1024, total len = 289
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 419, template ID = 1024, total len = 403
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 420
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 134, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 248, template ID = 1024, total len = 232
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 362, template ID = 1024, total len = 346
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 476, template ID = 1024, total len = 460
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 476
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 77, template ID = 1024, total len = 61
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 191, template ID = 1024, total len = 175
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 305, template ID = 1024, total len = 289
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 308
# DEBUG ( default_nfprobe/nfprobe ): Sent 15 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6 octets>:191 packets>:4 octets<:151 packets<:3 start:2014-08-08T01:02:04.014 finish:2014-08-08T01:02:04.329 tcp>:19 tcp<:1d flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd79600)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:34 [173.194.35.53]:443 <> [192.168.1.101]:56644 proto:6 octets>:132 packets>:3 octets<:399 packets<:5 start:2014-08-08T01:02:12.108 finish:2014-08-08T01:02:16.276 tcp>:14 tcp<:19 flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd7b880)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:50 [173.194.35.55]:443 <> [192.168.1.101]:56675 proto:6 octets>:305 packets>:4 octets<:765 packets<:6 start:2014-08-08T01:02:22.432 finish:2014-08-08T01:02:23.066 tcp>:1b tcp<:1f flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd7d080)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:51 [173.194.35.55]:443 <> [192.168.1.101]:56676 proto:6 octets>:305 packets>:4 octets<:765 packets<:6 start:2014-08-08T01:02:22.721 finish:2014-08-08T01:02:23.349 tcp>:1b tcp<:1f flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd7d200)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:47 [173.194.66.84]:443 <> [192.168.1.101]:56652 proto:6 octets>:282 packets>:4 octets<:438 packets<:7 start:2014-08-08T01:02:21.174 finish:2014-08-08T01:02:25.223 tcp>:19 tcp<:1d flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd7cc00)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:44 [173.194.35.44]:443 <> [192.168.1.101]:56654 proto:6 octets>:132 packets>:3 octets<:318 packets<:4 start:2014-08-08T01:02:20.223 finish:2014-08-08T01:02:28.690 tcp>:14 tcp<:19 flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd
tcp>:10 tcp<:18 flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd75d90)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:2 [192.168.1.101]:56561 <> [208.117.231.17]:443 proto:6 octets>:2444 packets>:53 octets<:102240 packets<:71 start:2014-08-08T01:02:01.053 finish:2014-08-08T01:02:32.613 tcp>:10 tcp<:18 flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd75a90)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:3 [192.168.1.101]:56562 <> [208.117.231.17]:443 proto:6 octets>:2212 packets>:47 octets<:77760 packets<:54 start:2014-08-08T01:02:01.054 finish:2014-08-08T01:02:32.513 tcp>:10 tcp<:18 flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd75c10)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:7 [90.84.59.130]:443 <> [192.168.1.101]:56671 proto:6 octets>:0 packets>:0 octets<:161 packets<:4 start:2014-08-08T01:02:02.155 finish:2014-08-08T01:02:32.013 tcp>:00 tcp<:11 flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd79000)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:15 [192.168.1.101]:56564 <> [208.117.231.17]:443 proto:6 octets>:2036 packets>:42 octets<:73440 packets<:51 start:2014-08-08T01:02:05.019 finish:2014-08-08T01:02:32.545 tcp>:10 tcp<:18 flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd79c00)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:45 [90.84.59.91]:80 <> [192.168.1.101]:56592 proto:6 octets>:44640 packets>:31 octets<:1204 packets<:24 start:2014-08-08T01:02:20.232 finish:2014-08-08T01:02:32.215 tcp>:18 tcp<:10 flowlabel>:00000000 flowlabel<:00000000  (0x564d2cd7c900)
# INFO ( default/core ): OK, Exiting ...
#  ('', "INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)\nINFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'\nINFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/ipfix_3.conf'.\nINFO ( default/core ): [,0] link type is: 1\nINFO ( default_nfprobe/nfprobe ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes\nINFO ( default_nfprobe/nfprobe ): ctrl channel: obtained=212992 bytes target=3200 bytes\nINFO ( default/core ): PCAP capture file, sleeping for 2 seconds\nINFO ( default_nfprobe/nfprobe ): NetFlow probe plugin is originally based on softflowd 0.9.7 software, Copyright 2002 Damien Miller <djm@mindrot.org> All rights reserved.\nINFO ( default_nfprobe/nfprobe ):           TCP timeout: 3600s\nINFO ( default_nfprobe/nfprobe ):  TCP post-RST timeout: 120s\nINFO ( default_nfprobe/nfprobe ):  TCP post-FIN timeout: 300s\nINFO ( default_nfprobe/nfprobe ):           UDP timeout: 300s\nINFO ( default_nfprobe/nfprobe ):          ICMP timeout: 300s\nINFO ( default_nfprobe/nfprobe ):       General timeout: 3600s\nINFO ( default_nfprobe/nfprobe ):      Maximum lifetime: 604800s\nINFO ( default_nfprobe/nfprobe ):       Expiry interval: 60s\nINFO ( default_nfprobe/nfprobe ): Exporting flows to [127.0.0.1]:4739\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:1 [178.123.13.120]:26895 <> [192.168.1.101]:42559 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:2 [192.168.1.101]:56561 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:3 [192.168.1.101]:56562 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:4 [192.168.1.101]:56563 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:5 [93.184.221.133]:80 <> [192.168.1.101]:56668 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:6 [192.168.1.100]:54714 <> [239.255.255.250]:1900 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:7 [90.84.59.130]:443 <> [192.168.1.101]:56671 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:8 [173.194.35.53]:443 <> [192.168.1.101]:56643 proto:6\nDEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1\nDEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:9 [90.84.136.33]:80 <> [192.168.1.101]:56582 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:10 [90.84.136.32]:80 <> [192.168.1.101]:56600 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:12 [173.194.66.84]:443 <> [192.168.1.101]:56651 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:13 [157.56.106.184]:3544 <> [192.168.1.101]:59656 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:14 [67.252.131.62]:55645 <> [192.168.1.101]:49690 proto:17\nDEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1\nDEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:15 [192.168.1.101]:56564 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:16 [fe80::6d49:f772:ed9b:d16a]:546 <> [ff02::1:2]:547 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:17 [74.125.206.125]:443 <> [192.168.1.101]:54760 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:18 [173.194.35.39]:443 <> [192.168.1.101]:56655 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:19 [90.84.59.104]:80 <> [192.168.1.101]:56638 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:20 [192.168.1.1]:53 <> [192.168.1.101]:57311 proto:17\nDEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1\nDEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:21 [192.168.1.1]:53 <> [192.168.1.101]:55365 prot ...

# %%
print(cmd_download_file_from(n1, "pmacct-1.7.8/ipfix_flows_3.ipfix"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/ipfix_flows_3.ipfix .

# %% [markdown]
# ##### We need to download t-shark so that we can se the content of the flows in the result file.
# First, we need to download the file to inspect its content and the different flows. Since downloading TShark requires granting some permissions, we cannot automate this process. Please refer to the cell where the SSH command for node n1 is shown in the section. Execute that command in a terminal (so that that terminal is now the terminal of the node), and then run the following command: "sudo apt-get install -y tshark"

# %%
#n1.execute("sudo apt-get install -y tshark")
#n2.execute("sudo apt-get install -y tshark")
# Out:
#  E: Could not get lock /var/lib/dpkg/lock-frontend. It is held by process 74499 (apt-get)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), is another process using it?
#   E: Could not get lock /var/lib/dpkg/lock-frontend. It is held by process 72208 (apt-get)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), is another process using it?
# ('',
#  'E: Could not get lock /var/lib/dpkg/lock-frontend. It is held by process 72208 (apt-get)\nE: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), is another process using it?\n')

# %% [markdown]
# ##### Summary
# The following command will read and display the packet summary information from the IPFIX file, showing a list of packets captured in the file.

# %%
n1.execute("tshark -r pmacct-1.7.8/ipfix_flows_3.ipfix")
# Out:
#     1          0              →              CFLOW 408 IPFIX flow ( 408 bytes) Obs-Domain-ID=    0 [Data-Template:1024] [Data-Template:1025] [Data-Template:2048] [Data-Template:2049] [Data:1024]
#     2          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]
#     3          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]
#     4          0              →              CFLOW 488 IPFIX flow ( 488 bytes) Obs-Domain-ID=    0 [Data:1024] [Data:2048] [Data:1024] [Data:2048]
#     5          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:2048] [Data:1024]
#     6          0              →              CFLOW 508 IPFIX flow ( 508 bytes) Obs-Domain-ID=    0 [Data:2048] [Data:1024]
#     7          0              →              CFLOW 452 IPFIX flow ( 452 bytes) Obs-Domain-ID=    0 [Data:2048] [Data:1024]
#     8          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]
#     9          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]
#    10          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]
#    11          0              →              CFLOW 420 IPFIX flow ( 420 bytes) Obs-Domain-ID=    0 [Data:1024]
#    12          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]
#    13          0              →              CFLOW 420 IPFIX flow ( 420 bytes) Obs-Domain-ID=    0 [Data:1024]
#    14          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]
#    15          0              →              CFLOW 308 IPFIX flow ( 308 bytes) Obs-Domain-ID=    0 [Data:1024]
# ('    1          0              →              CFLOW 408 IPFIX flow ( 408 bytes) Obs-Domain-ID=    0 [Data-Template:1024] [Data-Template:1025] [Data-Template:2048] [Data-Template:2049] [Data:1024]\n    2          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]\n    3          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]\n    4          0              →              CFLOW 488 IPFIX flow ( 488 bytes) Obs-Domain-ID=    0 [Data:1024] [Data:2048] [Data:1024] [Data:2048]\n    5          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:2048] [Data:1024]\n    6          0              →              CFLOW 508 IPFIX flow ( 508 bytes) Obs-Domain-ID=    0 [Data:2048] [Data:1024]\n    7          0              →              CFLOW 452 IPFIX flow ( 452 bytes) Obs-Domain-ID=    0 [Data:2048] [Data:1024]\n    8          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]\n    9          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]\n   10          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]\n   11          0              →              CFLOW 420 IPFIX flow ( 420 bytes) Obs-Domain-ID=    0 [Data:1024]\n   12          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]\n   13          0              →              CFLOW 420 IPFIX flow ( 420 bytes) Obs-Domain-ID=    0 [Data:1024]\n   14          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]\n   15          0              →              CFLOW 308 IPFIX flow ( 308 bytes) Obs-Domain-ID=    0 [Data:1024]\n',
#  '')

# %% [markdown]
# ##### In detail
# This command reads the IPFIX file and provides a detailed hex and ASCII representation of the first packet's data. This is useful for in-depth analysis of the packet's structure and content.
#
# You can change the number of the packet and execute the command again to inspect different ones.

# %%
# Look one packet of a flow in detail
n1.execute("tshark -r pmacct-1.7.8/ipfix_flows_3.ipfix -x -c 1")
# Out:
# 0000  00 0a 01 98 66 86 6c a6 00 00 00 00 00 00 00 00   ....f.l.........
# 0010  00 02 00 44 04 00 00 0f 00 99 00 08 00 98 00 08   ...D............
# 0020  00 01 00 08 00 02 00 08 00 3c 00 01 00 0a 00 04   .........<......
# 0030  00 0e 00 04 00 3d 00 01 00 08 00 04 00 0c 00 04   .....=..........
# 0040  00 07 00 02 00 0b 00 02 00 05 00 01 00 06 00 01   ................
# 0050  00 04 00 01 00 02 00 44 04 01 00 0f 00 99 00 08   .......D........
# 0060  00 98 00 08 00 01 00 08 00 02 00 08 00 3c 00 01   .............<..
# 0070  00 0a 00 04 00 0e 00 04 00 3d 00 01 00 08 00 04   .........=......
# 0080  00 0c 00 04 00 07 00 02 00 0b 00 02 00 05 00 01   ................
# 0090  00 06 00 01 00 04 00 01 00 02 00 44 08 00 00 0f   ...........D....
# 00a0  00 99 00 08 00 98 00 08 00 01 00 08 00 02 00 08   ................
# 00b0  00 3c 00 01 00 0a 00 04 00 0e 00 04 00 3d 00 01   .<...........=..
# 00c0  00 1b 00 10 00 1c 00 10 00 05 00 01 00 07 00 02   ................
# 00d0  00 0b 00 02 00 06 00 01 00 04 00 01 00 02 00 44   ...............D
# 00e0  08 01 00 0f 00 99 00 08 00 98 00 08 00 01 00 08   ................
# 00f0  00 02 00 08 00 3c 00 01 00 0a 00 04 00 0e 00 04   .....<..........
# 0100  00 3d 00 01 00 1b 00 10 00 1c 00 10 00 05 00 01   .=..............
# 0110  00 07 00 02 00 0b 00 02 00 06 00 01 00 04 00 01   ................
# 0120  04 00 00 78 00 00 01 47 b3 23 0c 28 00 00 01 47   ...x...G.#.(...G
# 0130  b3 23 0a ee 00 00 00 00 00 00 00 bf 00 00 00 00   .#..............
# 0140  00 00 00 04 04 00 00 00 00 00 00 00 00 00 44 e8   ..............D.
# 0150  23 8b c0 a8 01 65 01 bb dd 53 00 19 06 00 00 01   #....e...S......
# 0160  47 b3 23 0c 28 00 00 01 47 b3 23 0a ee 00 00 00   G.#.(...G.#.....
# 0170  00 00 00 00 97 00 00 00 00 00 00 00 03 04 00 00   ................
# 0180  00 00 00 00 00 00 00 c0 a8 01 65 44 e8 23 8b dd   ..........eD.#..
# 0190  53 01 bb 00 1d 06 00 00                           S.......
# ('0000  00 0a 01 98 66 86 6c a6 00 00 00 00 00 00 00 00   ....f.l.........\n0010  00 02 00 44 04 00 00 0f 00 99 00 08 00 98 00 08   ...D............\n0020  00 01 00 08 00 02 00 08 00 3c 00 01 00 0a 00 04   .........<......\n0030  00 0e 00 04 00 3d 00 01 00 08 00 04 00 0c 00 04   .....=..........\n0040  00 07 00 02 00 0b 00 02 00 05 00 01 00 06 00 01   ................\n0050  00 04 00 01 00 02 00 44 04 01 00 0f 00 99 00 08   .......D........\n0060  00 98 00 08 00 01 00 08 00 02 00 08 00 3c 00 01   .............<..\n0070  00 0a 00 04 00 0e 00 04 00 3d 00 01 00 08 00 04   .........=......\n0080  00 0c 00 04 00 07 00 02 00 0b 00 02 00 05 00 01   ................\n0090  00 06 00 01 00 04 00 01 00 02 00 44 08 00 00 0f   ...........D....\n00a0  00 99 00 08 00 98 00 08 00 01 00 08 00 02 00 08   ................\n00b0  00 3c 00 01 00 0a 00 04 00 0e 00 04 00 3d 00 01   .<...........=..\n00c0  00 1b 00 10 00 1c 00 10 00 05 00 01 00 07 00 02   ................\n00d0  00 0b 00 02 00 06 00 01 00 04 00 01 00 02 00 44   ...............D\n00e0  08 01 00 0f 00 99 00 08 00 98 00 08 00 01 00 08   ................\n00f0  00 02 00 08 00 3c 00 01 00 0a 00 04 00 0e 00 04   .....<..........\n0100  00 3d 00 01 00 1b 00 10 00 1c 00 10 00 05 00 01   .=..............\n0110  00 07 00 02 00 0b 00 02 00 06 00 01 00 04 00 01   ................\n0120  04 00 00 78 00 00 01 47 b3 23 0c 28 00 00 01 47   ...x...G.#.(...G\n0130  b3 23 0a ee 00 00 00 00 00 00 00 bf 00 00 00 00   .#..............\n0140  00 00 00 04 04 00 00 00 00 00 00 00 00 00 44 e8   ..............D.\n0150  23 8b c0 a8 01 65 01 bb dd 53 00 19 06 00 00 01   #....e...S......\n0160  47 b3 23 0c 28 00 00 01 47 b3 23 0a ee 00 00 00   G.#.(...G.#.....\n0170  00 00 00 00 97 00 00 00 00 00 00 00 03 04 00 00   ................\n0180  00 00 00 00 00 00 00 c0 a8 01 65 44 e8 23 8b dd   ..........eD.#..\n0190  53 01 bb 00 1d 06 00 00                           S.......\n\n',
#  '')

# %% [markdown]
# ### Send the IPFIX flows to a collector

# %% [markdown]
# First, we need to download the netflow Python library from  https://pypi.org/project/netflow/ and place on the work directory.
# Also it is necessary to download python3 on the node: sudo apt-get install python3 to be able to use the library. Then we will uploade it to the nodes.

# %%
# Please, place the resulting command on a terminal
print(cmd_upload_file_to(n1, "netflow-0.12.2.tar.gz"))
print(cmd_upload_file_to(n2, "netflow-0.12.2.tar.gz"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config netflow-0.12.2.tar.gz ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config netflow-0.12.2.tar.gz ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %%
# Unzip the netflow library file, you can install the zip library by executing the command sudo apt-get zip, you can uncomment the following line and execute it
# If you follow this notebook from the beggining you should have the software package already installed.
#n1.execute("sudo apt-get zip")
n1.execute("tar -xzf netflow-0.12.2.tar.gz")
n2.execute("tar -xzf netflow-0.12.2.tar.gz")
# Out:
# ('', '')

# %% [markdown]
# It is necessary to download python3 and pip on the node to be able to use the library.

# %%
# Download pyython at the nodes and also netflow
n1.execute("sudo apt-get install -y python3")
n2.execute("sudo apt-get install -y python3")
n1.execute("sudo apt-get install -y pip")
n2.execute("sudo apt-get install -y pip")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 96 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 96 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev
#   python3-wheel python3.8-dev zlib1g-dev
# The following NEW packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev
#   python3-pip python3-wheel python3.8-dev zlib1g-dev
# 0 upgraded, 9 newly installed, 0 to remove and 96 not upgraded.
# Need to get 6804 kB of archives.
# After this operation, 25.6 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libexpat1-dev amd64 2.2.9-1ubuntu0.6 [116 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [3950 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libpython3-dev amd64 3.8.2-0ubuntu2 [7236 B]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.10 [1805 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 zlib1g-dev amd64 1:1.2.11.dfsg-2ubuntu1.5 [155 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [514 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 python3-dev amd64 3.8.2-0ubuntu2 [1212 B]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.10 [231 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#  Fetched 6804 kB in 2s (4533 kB/s)
#  debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Selecting previously unselected package libexpat1-dev:amd64.
# (Reading database ... 73329 files and directories currently installed.)
# Preparing to unpack .../0-libexpat1-dev_2.2.9-1ubuntu0.6_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../1-libpython3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../2-libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python-pip-whl.
# Preparing to unpack .../3-python-pip-whl_20.0.2-5ubuntu1.10_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.10) ...
# Selecting previously unselected package zlib1g-dev:amd64.
# Preparing to unpack .../4-zlib1g-dev_1%3a1.2.11.dfsg-2ubuntu1.5_amd64.deb ...
# Unpacking zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../5-python3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../6-python3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-dev (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../7-python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../8-python3-pip_20.0.2-5ubuntu1.10_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.10) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Setting up libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Setting up zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.10) ...
# Setting up libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Setting up python3-pip (20.0.2-5ubuntu1.10) ...
# Setting up python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Setting up python3-dev (3.8.2-0ubuntu2) ...
# Processing triggers for man-db (2.9.1-1) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev
#   python3-wheel python3.8-dev zlib1g-dev
# The following NEW packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev
#   python3-pip python3-wheel python3.8-dev zlib1g-dev
# 0 upgraded, 9 newly installed, 0 to remove and 96 not upgraded.
# Need to get 6804 kB of archives.
# After this operation, 25.6 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libexpat1-dev amd64 2.2.9-1ubuntu0.6 [116 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [3950 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libpython3-dev amd64 3.8.2-0ubuntu2 [7236 B]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.10 [1805 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 zlib1g-dev amd64 1:1.2.11.dfsg-2ubuntu1.5 [155 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [514 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 python3-dev amd64 3.8.2-0ubuntu2 [1212 B]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.10 [231 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Fetched 6804 kB in 1s (9319 kB/s)
# Selecting previously unselected package libexpat1-dev:amd64.
# (Reading database ... 72812 files and directories currently installed.)
# Preparing to unpack .../0-libexpat1-dev_2.2.9-1ubuntu0.6_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../1-libpython3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../2-libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python-pip-whl.
# Preparing to unpack .../3-python-pip-whl_20.0.2-5ubuntu1.10_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.10) ...
# Selecting previously unselected package zlib1g-dev:amd64.
# Preparing to unpack .../4-zlib1g-dev_1%3a1.2.11.dfsg-2ubuntu1.5_amd64.deb ...
# Unpacking zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../5-python3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../6-python3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-dev (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../7-python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../8-python3-pip_20.0.2-5ubuntu1.10_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.10) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Setting up libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Setting up zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.10) ...
# Setting up libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Setting up python3-pip (20.0.2-5ubuntu1.10) ...
# Setting up python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Setting up python3-dev (3.8.2-0ubuntu2) ...
# Processing triggers for man-db (2.9.1-1) ...
# ('Reading package lists...\nBuilding dependency tree...\nReading state information...\nThe following additional packages will be installed:\n  libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev\n  python3-wheel python3.8-dev zlib1g-dev\nThe following NEW packages will be installed:\n  libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev\n  python3-pip python3-wheel python3.8-dev zlib1g-dev\n0 upgraded, 9 newly installed, 0 to remove and 96 not upgraded.\nNeed to get 6804 kB of archives.\nAfter this operation, 25.6 MB of additional disk space will be used.\nGet:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libexpat1-dev amd64 2.2.9-1ubuntu0.6 [116 kB]\nGet:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [3950 kB]\nGet:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libpython3-dev amd64 3.8.2-0ubuntu2 [7236 B]\nGet:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.10 [1805 kB]\nGet:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 zlib1g-dev amd64 1:1.2.11.dfsg-2ubuntu1.5 [155 kB]\nGet:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [514 kB]\nGet:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 python3-dev amd64 3.8.2-0ubuntu2 [1212 B]\nGet:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]\nGet:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.10 [231 kB]\nFetched 6804 kB in 1s (9319 kB/s)\nSelecting previously unselected package libexpat1-dev:amd64.\r\n(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 72812 files and directories currently installed.)\r\nPreparing to unpack .../0-libexpat1-dev_2.2.9-1ubuntu0.6_amd64.deb ...\r\nUnpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...\r\nSelecting previously unselected package libpython3.8-dev:amd64.\r\nPreparing to unpack .../1-libpython3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...\r\nUnpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...\r\nSelecting previously unselected package libpython3-dev:amd64.\r\nPreparing to unpack .../2-libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...\r\nUnpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...\r\nSelecting previously unselected package python-pip-whl.\r\nPreparing to unpack .../3-python-pip-whl_20.0.2-5ubuntu1.10_all.deb ...\r\nUnpacking python-pip-whl (20.0.2-5ubuntu1.10) ...\r\nSelecting previously unselected package zlib1g-dev:amd64.\r\nPreparing to unpack .../4-zlib1g-dev_1%3a1.2.11.dfsg-2ubuntu1.5_amd64.deb ...\r\nUnpacking zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...\r\nSelecting previously unselected package python3.8-dev.\r\nPreparing to unpack .../5-python3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...\r\nUnpacking python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...\r\nSelecting previously unselected package python3-dev.\r\nPreparing to unpack .../6-python3-dev_3.8.2-0ubuntu2_amd64.deb ...\r\nUnpacking python3-dev (3.8.2-0ubuntu2) ...\r\nSelecting previously unselected package python3-wheel.\r\nPreparing to unpack .../7-python3-wheel_0.34.2-1ubuntu0.1_all.deb ...\r\nUnpacking python3-wheel (0.34.2-1ubuntu0.1) ...\r\nSelecting previously unselected package python3-pip.\r\n ...
#  'debconf: unable to initialize frontend: Dialog\ndebconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)\ndebconf: falling back to frontend: Readline\ndebconf: unable to initialize frontend: Readline\ndebconf: (This frontend requires a controlling tty.)\ndebconf: falling back to frontend: Teletype\ndpkg-preconfigure: unable to re-open stdin: \n')

# %% [markdown]
# We also need to install the netflow Python package so that the library works properly.

# %%
n1.execute("pip install netflow")
# Out:
# Collecting netflow
#   Downloading netflow-0.12.2-py3-none-any.whl (34 kB)
# Installing collected packages: netflow
# Successfully installed netflow-0.12.2
# ('Collecting netflow\n  Downloading netflow-0.12.2-py3-none-any.whl (34 kB)\nInstalling collected packages: netflow\nSuccessfully installed netflow-0.12.2\n',
#  '')

# %% [markdown]
# ##### Configuration file
#
# For this experiment we will use the following configuration file:
#
# daemonize: false \
# debug: true \
# pcap_savefile: gmail.pcapng.cap \
# plugins: nfprobe \
# nfprobe_receiver: 127.0.0.2:4739 \
# nfprobe_version: 9
#
# - nfprobe_version: 9 refers to NetFlow, since we are using its Python version we need to specify it.

# %%
# Please, place the resulting command on a terminal
print(cmd_upload_file_to(n1, "configuration-files/ipfix_4.conf"))
print(cmd_upload_file_to(n2, "configuration-files/ipfix_4.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_4.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_4.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Execute the python program collector.py specifying the host and the port
# 3. Redirect the network flow of 127.0.0.2 port 4739 to the file
# 4. Execute pmacctd.
# 5. Show the results.
# 6. You can execute the last cell of the section to download the .log result file into your computer.

# %%
n1.execute("mv ipfix_4.conf pmacct-1.7.8")
n2.execute("mv ipfix_4.conf pmacct-1.7.8")
# Out:
#  mv: cannot stat 'ipfix_4.conf': No such file or directory
#   mv: cannot stat 'ipfix_4.conf': No such file or directory
# ('', "mv: cannot stat 'ipfix_4.conf': No such file or directory\n")

# %%
import threading

def run_iperf(node, command):
    result = node.execute(command)
    print(result)
command_1 = "cd netflow-0.12.2/netflow && python3 collector.py --host 127.0.0.2 --port 4739"
command_2 = "cd pmacct-1.7.8 && sudo pmacctd -f ipfix_4.conf"

thread_1 = threading.Thread(target=run_iperf, args=(n1, command_1))
thread_2 = threading.Thread(target=run_iperf, args=(n1, command_2))

thread_1.start()
thread_2.start()

thread_2.join()
# Out:
#  INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)
# INFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'
# INFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/ipfix_4.conf'.
# INFO ( default/core ): [,0] link type is: 1
# INFO ( default_nfprobe/nfprobe ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes
# INFO ( default_nfprobe/nfprobe ): ctrl channel: obtained=212992 bytes target=3200 bytes
# INFO ( default/core ): PCAP capture file, sleeping for 2 seconds
# INFO ( default_nfprobe/nfprobe ): NetFlow probe plugin is originally based on softflowd 0.9.7 software, Copyright 2002 Damien Miller <djm@mindrot.org> All rights reserved.
# INFO ( default_nfprobe/nfprobe ):           TCP timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):  TCP post-RST timeout: 120s
# INFO ( default_nfprobe/nfprobe ):  TCP post-FIN timeout: 300s
# INFO ( default_nfprobe/nfprobe ):           UDP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):          ICMP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):       General timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):      Maximum lifetime: 604800s
# INFO ( default_nfprobe/nfprobe ):       Expiry interval: 60s
# INFO ( default_nfprobe/nfprobe ): Exporting flows to [127.0.0.2]:4739
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:1 [178.123.13.120]:26895 <> [192.168.1.101]:42559 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:2 [192.168.1.101]:56561 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:3 [192.168.1.101]:56562 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:4 [192.168.1.101]:56563 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:5 [93.184.221.133]:80 <> [192.168.1.101]:56668 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:6 [192.168.1.100]:54714 <> [239.255.255.250]:1900 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:7 [90.84.59.130]:443 <> [192.168.1.101]:56671 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:8 [173.194.35.53]:443 <> [192.168.1.101]:56643 proto:6
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:9 [90.84.136.33]:80 <> [192.168.1.101]:56582 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:10 [90.84.136.32]:80 <> [192.168.1.101]:56600 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:12 [173.194.66.84]:443 <> [192.168.1.101]:56651 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:13 [157.56.106.184]:3544 <> [192.168.1.101]:59656 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:14 [67.252.131.62]:55645 <> [192.168.1.101]:49690 proto:17
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:15 [192.168.1.101]:56564 <> [208.117.231.17]:443 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:16 [fe80::6d49:f772:ed9b:d16a]:546 <> [ff02::1:2]:547 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:17 [74.125.206.125]:443 <> [192.168.1.101]:54760 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:18 [173.194.35.39]:443 <> [192.168.1.101]:56655 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:19 [90.84.59.104]:80 <> [192.168.1.101]:56638 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:20 [192.168.1.1]:53 <> [192.168.1.101]:57311 proto:17
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:21 [192.168.1.1]:53 <> [192.168.1.101]:55365 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:22 [95.79.81.24]:20101 <> [192.168.1.101]:42559 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:23 [90.84.59.91]:80 <> [192.168.1.101]:56595 proto:6
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:24 [90.84.136.33]:80 <> [192.168.1.101]:56586 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:25 [90.84.136.33]:80 <> [192.168.1.101]:56583 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:26 [fe80::35d0:b39e:c3f7:e20f]:546 <> [ff02::1:2]:547 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:27 [90.84.136.33]:80 <> [192.168.1.101]:56584 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:28 [90.84.136.33]:80 <> [192.168.1.101]:56585 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:29 [fe80::6d49:f772:ed9b:d16a]:60775 <> [ff02::1:3]:5355 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:30 [192.168.1.106]:137 <> [192.168.1.255]:137 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:31 [fe80::895a:cc69:a63f:3594]:546 <> [ff02::1:2]:547 proto:17
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:32 [173.252.102.24]:443 <> [192.168.1.101]:56157 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:33 [31.13.80.33]:443 <> [192.168.1.101]:56575 proto:6
# DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:34 [173.194.35.53]:443 <> [192.168.1.101]:56644 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:35 [90.84.136.33]:80 <> [192.168.1.101]:56609 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:36 [173.194.35.58]:80 <> [192.168.1.101]:56588 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 195, template ID = 1024, total len = 175, # elements = 3
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 309, template ID = 1024, total len = 289, # elements = 5
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 423, template ID = 1024, total len = 403, # elements = 7
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 424
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 138, template ID = 1024, total len = 118, # elements = 2
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 252, template ID = 1024, total len = 232, # elements = 4
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 366, template ID = 1024, total len = 346, # elements = 6
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 480, template ID = 1024, total len = 460, # elements = 8
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 480
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 81, template ID = 1024, total len = 61, # elements = 1
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 195, template ID = 1024, total len = 175, # elements = 3
# DEBUG ( default_nfprobe/nfprobe ): Building NetFlow v9 packet: offset = 309, template ID = 1024, total len = 289, # elements = 5
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 312
# DEBUG ( default_nfprobe/nfprobe ): Sent 15 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6 octets>:191 packets>:4 octets<:151 packets<:3 start:2014-08-08T01:02:04.014 finish:2014-08-08T01:02:04.329 tcp>:19 tcp<:1d flowlabel>:00000000 flowlabel<:00000000  (0x562e64af5600)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:34 [173.194.35.53]:443 <> [192.168.1.101]:56644 proto:6 octets>:132 packets>:3 octets<:399 packets<:5 start:2014-08-08T01:02:12.108 finish:2014-08-08T01:02:16.276 tcp>:14 tcp<:19 flowlabel>:00000000 flowlabel<:00000000  (0x562e64af7880)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:50 [173.194.35.55]:443 <> [192.168.1.101]:56675 proto:6 octets>:305 packets>:4 octets<:765 packets<:6 start:2014-08-08T01:02:22.432 finish:2014-08-08T01:02:23.066 tcp>:1b tcp<:1f flowlabel>:00000000 flowlabel<:00000000  (0x562e64af9080)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:51 [173.194.35.55]:443 <> [192.168.1.101]:56676 proto:6 octets>:305 packets>:4 octets<:765 packets<:6 start:2014-08-08T01:02:22.721 finish:2014-08-08T01:02:23.349 tcp>:1b tcp<:1f flowlabel>:00000000 flowlabel<:00000000  (0x562e64af9200)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:47 [173.194.66.84]:443 <> [192.168.1.101]:56652 proto:6 octets>:282 packets>:4 octets<:438 packets<:7 start:2014-08-08T01:02:21.174 finish:2014-08-08T01:02:25.223 tcp>:19 tcp<:1d flowlabel>:00000000 flowlabel<:00000000  (0x562e64af8c00)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:44 [173.194.35.44]:443 <> [192.168.1.101]:56654 proto:6 octets>:132 packets>:3 octets<:318 packets<:4 start:2014-08-08T01:02:20.223 finish:2014-08-08T01:02:28.690 tcp>:14 tcp<:19 flowlabel>:00000000 flowlabel<:00000000  (0x562e64af8780)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:36 [173.194.35.58]:80 <> [192.168.1.101]:56588 proto:6 octets>:40 packets>:1 octets<:161 packets<:4 start:2014-08-08T01:02:12.755 finish:2014-08-08T01:02:29.352 tcp>:11 tcp<:15 flowlabel>:00000000 flowlabel<:00000000  (0x562e64af7b80)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:1 [178.123.13.120]:26895 <> [192.168.1.101]:42559 proto:17 octets>:98 packets>:1 octets<:95 packets<:1 start:2014-08-08T01:02:00.966 finish:2014-08-08T01:02:01.314 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x562e64af1910)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:13 [157.56.106.184]:3544 <> [192.168.1.101]:59656 proto:17 octets>:137 packets>:1 octets<:89 packets<:1 start:2014-08-08T01:02:04.414 finish:2014-08-08T01:02:04.863 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x562e64af5900)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:6 [192.168.1.100]:54714 <> [239.255.255.250]:1900 proto:17 octets>:322 packets>:2 octets<:0 packets<:0 start:2014-08-08T01:02:02.098 finish:2014-08-08T01:02:05.153 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x562e64af2090)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq
flowlabel>:00000000 flowlabel<:00000000  (0x562e64af5000)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:15 [192.168.1.101]:56564 <> [208.117.231.17]:443 proto:6 octets>:2036 packets>:42 octets<:73440 packets<:51 start:2014-08-08T01:02:05.019 finish:2014-08-08T01:02:32.545 tcp>:10 tcp<:18 flowlabel>:00000000 flowlabel<:00000000  (0x562e64af5c00)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:45 [90.84.59.91]:80 <> [192.168.1.101]:56592 proto:6 octets>:44640 packets>:31 octets<:1204 packets<:24 start:2014-08-08T01:02:20.232 finish:2014-08-08T01:02:32.215 tcp>:18 tcp<:10 flowlabel>:00000000 flowlabel<:00000000  (0x562e64af8900)
# INFO ( default/core ): OK, Exiting ...
#  ('', "INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)\nINFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'\nINFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/ipfix_4.conf'.\nINFO ( default/core ): [,0] link type is: 1\nINFO ( default_nfprobe/nfprobe ): plugin_pipe_size=4096000 bytes plugin_buffer_size=10240 bytes\nINFO ( default_nfprobe/nfprobe ): ctrl channel: obtained=212992 bytes target=3200 bytes\nINFO ( default/core ): PCAP capture file, sleeping for 2 seconds\nINFO ( default_nfprobe/nfprobe ): NetFlow probe plugin is originally based on softflowd 0.9.7 software, Copyright 2002 Damien Miller <djm@mindrot.org> All rights reserved.\nINFO ( default_nfprobe/nfprobe ):           TCP timeout: 3600s\nINFO ( default_nfprobe/nfprobe ):  TCP post-RST timeout: 120s\nINFO ( default_nfprobe/nfprobe ):  TCP post-FIN timeout: 300s\nINFO ( default_nfprobe/nfprobe ):           UDP timeout: 300s\nINFO ( default_nfprobe/nfprobe ):          ICMP timeout: 300s\nINFO ( default_nfprobe/nfprobe ):       General timeout: 3600s\nINFO ( default_nfprobe/nfprobe ):      Maximum lifetime: 604800s\nINFO ( default_nfprobe/nfprobe ):       Expiry interval: 60s\nINFO ( default_nfprobe/nfprobe ): Exporting flows to [127.0.0.2]:4739\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:1 [178.123.13.120]:26895 <> [192.168.1.101]:42559 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:2 [192.168.1.101]:56561 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:3 [192.168.1.101]:56562 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:4 [192.168.1.101]:56563 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:5 [93.184.221.133]:80 <> [192.168.1.101]:56668 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:6 [192.168.1.100]:54714 <> [239.255.255.250]:1900 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:7 [90.84.59.130]:443 <> [192.168.1.101]:56671 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:8 [173.194.35.53]:443 <> [192.168.1.101]:56643 proto:6\nDEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1\nDEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:9 [90.84.136.33]:80 <> [192.168.1.101]:56582 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:10 [90.84.136.32]:80 <> [192.168.1.101]:56600 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:11 [68.232.35.139]:443 <> [192.168.1.101]:56659 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:12 [173.194.66.84]:443 <> [192.168.1.101]:56651 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:13 [157.56.106.184]:3544 <> [192.168.1.101]:59656 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:14 [67.252.131.62]:55645 <> [192.168.1.101]:49690 proto:17\nDEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1\nDEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:15 [192.168.1.101]:56564 <> [208.117.231.17]:443 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:16 [fe80::6d49:f772:ed9b:d16a]:546 <> [ff02::1:2]:547 proto:17\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:17 [74.125.206.125]:443 <> [192.168.1.101]:54760 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:18 [173.194.35.39]:443 <> [192.168.1.101]:56655 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:19 [90.84.59.104]:80 <> [192.168.1.101]:56638 proto:6\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:20 [192.168.1.1]:53 <> [192.168.1.101]:57311 proto:17\nDEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 1\nDEBUG ( default_nfprobe/nfprobe ): Finished scan 0 flow(s) to be evicted\nDEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:21 [192.168.1.1]:53 <> [192.168.1.101]:55365 prot ...

# %% [markdown]
# ##### Results
#
# The results will be obtained on a .tar file, containing a JSON file placed on the netflow folder as you can see on the following picture:
#
# <div style="text-align: center;">
#     <img src="./images/4.png" width="700px"/>
# </div>
#
# You can unzip them using the command: gzip -d filename.gz
#
# You can see the results using the command: cat filename
#
# You can download the results using the command "print(cmd_download_file_from(n1, "filename"))" on a new cell of this Notebook

# %% [markdown]
# ##  Experiment of the pmacctd tool using live traffic with IPFIX flows
# Now we are going to work producing IPFIX flows with pmacctd using the live traffic captured by pmacctd, this will include first printing the result on a terminal, then in a log file at pmacctd then we are going to create an .ipfix file which will be opened and analyzed with tshark and lastly we are going to send the flows to a collector using the Netflow Python library.

# %% [markdown]
# ### Print the result on the terminal
# For this first and easiest experiment we will use the following configuration file:
#
# daemonize: false \
# debug: true \
# pcap_interface: any \
# plugins: nfprobe, print \
# nfprobe_version: 10 \
# nfprobe_receiver: localhost:4739
#
# - nfprobe: This plugin is used for exporting network flow data using the NetFlow/IPFIX protocol.
# - print: This plugin is used for printing the collected data, in this case to standard output since we have not specified an output file.
# - nfprobe_version: 10 refers to IPFIX, which is also known as NetFlow version 10.
# - pcap_interface: refers to the interface or interfaces where the tool will collect the data from.
# - nfprobe_receiver: specifies the destination to which NetFlow/IPFIX data should be sent.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/ipfix_live_1.conf"))
print(cmd_upload_file_to(n2, "configuration-files/ipfix_live_1.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_live_1.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_live_1.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Start the pmacctd daemon using threads.
# 3. Execute ICMP live traffic to the n1 so that it can be collected.
# 4. Show the results on the terminal.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("mv ipfix_live_1.conf pmacct-1.7.8")
n2.execute("mv ipfix_live_1.conf pmacct-1.7.8")
# Out:
# ('', '')

# %%
import threading 
def run_pmacctd(node, command):
    result = node.execute(command)
    print(result)
command_n1 = "cd pmacct-1.7.8 && sudo pmacctd -f ipfix_live_1.conf"
command_n2 = "ping -c 20 -I " + n1_iface1.get_device_name() + " fd3f:f209:c712::1"

thread_h1 = threading.Thread(target=run_pmacctd, args=(n1, command_n1))
thread_h2 = threading.Thread(target=run_pmacctd, args=(n2, command_n2))

thread_h1.start()
thread_h2.start()

thread_h2.join()
# Out:
# PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes
# 64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.115 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.115 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.067 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.078 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.634 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.068 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.061 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.061 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.060 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.081 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.071 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.064 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.062 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.072 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.074 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.065 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.060 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.074 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.065 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.091 ms
#
# --- fd3f:f209:c712::1 ping statistics ---
# 20 packets transmitted, 20 received, 0% packet loss, time 19448ms
# rtt min/avg/max/mdev = 0.060/0.101/0.634/0.123 ms
# ('PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes\n64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.115 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.115 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.067 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.078 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.634 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.068 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.061 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.061 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.060 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.081 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.071 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.064 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.062 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.072 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.074 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.065 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.060 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.074 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.065 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.091 ms\n\n--- fd3f:f209:c712::1 ping statistics ---\n20 packets transmitted, 20 received, 0% packet loss, time 19448ms\nrtt min/avg/max/mdev = 0.060/0.101/0.634/0.123 ms\n', '')
# SRC_IP                                         PACKETS               BYTES
# 2001:400:a100:3000:f816:3eff:febc:8269         16                    6296
# 2600:2701:5000:a902::c                         11                    792
# fd3f:f209:c712::2                              20                    2040
# fd3f:f209:c712::1                              20                    2040
# fe80::f816:3eff:febb:9db7                      2                     256
# fe80::48d:91ff:fed1:234f                       3                     208
# fe80::820:c4ff:fe71:4439                       3                     208
# fe80::f816:3eff:fef8:383d                      2                     152
# fe80::f816:3eff:fe60:613f                      2                     152
# fe80::f816:3eff:fe6d:519b                      2                     152
# fe80::f816:3eff:fe74:44d5                      2                     152
# fe80::f816:3eff:fe2e:9d7a                      2                     152
# fe80::f816:3eff:feb7:167f                      2                     152
# fe80::f816:3eff:fe33:b599                      2                     152
# fe80::f816:3eff:febc:8269                      2                     152
# fe80::f816:3eff:fe84:4d18                      2                     152
# fe80::f816:3eff:fe69:f180                      2                     152
# fe80::f816:3eff:fe86:6a88                      2                     152
# fe80::f816:3eff:fe95:17ba                      2                     152
# fe80::f816:3eff:fe27:f059                      2                     152
# fe80::f816:3eff:feb1:d79f                      2                     152
# fe80::f816:3eff:fe1b:80fc                      2                     152
# fe80::f816:3eff:fea3:6b3d                      2                     152
# fe80::f816:3eff:feeb:75d6                      2                     272
# fe80::f816:3eff:fe90:cf9                       2                     152
# fe80::f816:3eff:fe4d:d1ec                      2                     152
# fe80::f816:3eff:fe58:aabb                      2                     152
#  INFO ( default/core ): Promiscuous Mode Accounting Daemon, pmacctd 1.7.8-git (RELEASE)
# INFO ( default/core ):  '--enable-jansson' '--enable-l2' '--enable-traffic-bins' '--enable-bgp-bins' '--enable-bmp-bins' '--enable-st-bins'
# INFO ( default/core ): Reading configuration file '/home/ubuntu/pmacct-1.7.8/ipfix_live_1.conf'.
# WARN ( default_print/print ): defaulting to SRC HOST aggregation.
# INFO ( default/core ): [any,0] link type is: 113
# INFO ( default_nfprobe/nfprobe ): plugin_pipe_size=4096000 bytes plugin_buffer_size=251 bytes
# INFO ( default_nfprobe/nfprobe ): ctrl channel: obtained=212992 bytes target=130544 bytes
# INFO ( default_print/print ): plugin_pipe_size=4096000 bytes plugin_buffer_size=248 bytes
# INFO ( default_print/print ): ctrl channel: obtained=212992 bytes target=132128 bytes
# INFO ( default_nfprobe/nfprobe ): NetFlow probe plugin is originally based on softflowd 0.9.7 software, Copyright 2002 Damien Miller <djm@mindrot.org> All rights reserved.
# INFO ( default_nfprobe/nfprobe ):           TCP timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):  TCP post-RST timeout: 120s
# INFO ( default_nfprobe/nfprobe ):  TCP post-FIN timeout: 300s
# INFO ( default_nfprobe/nfprobe ):           UDP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):          ICMP timeout: 300s
# INFO ( default_nfprobe/nfprobe ):       General timeout: 3600s
# INFO ( default_nfprobe/nfprobe ):      Maximum lifetime: 604800s
# INFO ( default_nfprobe/nfprobe ):       Expiry interval: 60s
# INFO ( default_nfprobe/nfprobe ): Exporting flows to [127.0.0.1]:4739
# INFO ( default_print/print ): cache entries=16411 base cache memory=54878384 bytes
# WARN ( default_print/print ): no print_output_file and no print_output_lock_file defined.
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:1 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2600:2701:5000:a902::c]:39754 proto:6
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:2 [fd3f:f209:c712::1]:0 <> [fd3f:f209:c712::2]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:3 [2001:400:a100:3000:f816:3eff:febc:8269]:0 <> [fe80::f816:3eff:febb:9db7]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:4 [fd3f:f209:c712::2]:0 <> [fe80::48d:91ff:fed1:234f]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:5 [fd3f:f209:c712::1]:0 <> [fe80::820:c4ff:fe71:4439]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:6 [fe80::48d:91ff:fed1:234f]:0 <> [fe80::820:c4ff:fe71:4439]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:7 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:8 [fe80::f816:3eff:fef8:383d]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:9 [fe80::f816:3eff:fe60:613f]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:10 [fe80::f816:3eff:fe6d:519b]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:11 [fe80::f816:3eff:fe74:44d5]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:12 [fe80::f816:3eff:fe2e:9d7a]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:13 [fe80::f816:3eff:feb7:167f]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:14 [fe80::f816:3eff:fe33:b599]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:15 [fe80::f816:3eff:febc:8269]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:16 [fe80::f816:3eff:fe84:4d18]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:17 [fe80::f816:3eff:fe69:f180]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:18 [fe80::f816:3eff:fe86:6a88]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:19 [fe80::f816:3eff:fe95:17ba]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:20 [fe80::f816:3eff:fe27:f059]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:21 [fe80::f816:3eff:feb1:d79f]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:22 [fe80::f816:3eff:fe1b:80fc]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:23 [fe80::f816:3eff:fea3:6b3d]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:24 [fe80::f816:3eff:feeb:75d6]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:25 [fe80::f816:3eff:fe90:cf9]:0 <> [ff02::16]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:58 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:fff8:383d]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:59 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2610:1e0:1700:202::7]:57938 proto:6
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:60 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff3a:c203]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:61 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff27:f059]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:62 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff74:44d5]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:63 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2600:2701:5000:a902::c]:44778 proto:6
#   INFO ( default_print/print ): *** Purging cache - START (PID: 77630) ***
#  2001:400:a100:3000:f816:3eff:febc:8269         73                    22434
# 2600:2701:5000:a902::c                         48                    7429
# 2610:1e0:1700:202::7                           23                    4200
# fe80::f816:3eff:febb:9db7                      6                     432
# fe80::f816:3eff:fe6b:dc89                      1                     48
#  INFO ( default_print/print ): *** Purging cache - END (PID: 77630, QN: 5/5, ET: 0) ***
#   DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 0
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:31 (0x5650d08e3ce0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 1 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 373, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 376
# DEBUG ( default_nfprobe/nfprobe ): Sent 1 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:31 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ffa3:4429]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:20:11.866 finish:2024-07-04T10:20:11.866 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e3ce0)
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:64 [127.0.0.1]:55864 <> [127.0.0.1]:4739 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:65 [127.0.0.1]:0 <> [127.0.0.1]:771 proto:1
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:66 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff10:540b]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:67 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ffb7:167f]:0 proto:58
#  2001:400:a100:3000:f816:3eff:febc:8269         21                    5548
# 2600:2701:5000:a902::c                         15                    1080
# 127.0.0.1                                      2                     836
# 2610:1e0:1700:202::7                           6                     484
# fe80::f816:3eff:febb:9db7                      4                     400
# fe80::f816:3eff:fef8:383d                      2                     152
# fe80::f816:3eff:febc:8269                      2                     152
# fe80::f816:3eff:feb1:d79f                      2                     152
# fe80::f816:3eff:fe27:f059                      2                     152
# fe80::f816:3eff:feeb:75d6                      2                     272
# fe80::f816:3eff:fe1b:80fc                      2                     152
# fe80::f816:3eff:fea3:6b3d                      2                     152
# fe80::f816:3eff:fe60:613f                      2                     152
# fe80::f816:3eff:fe6d:519b                      2                     152
# fe80::f816:3eff:fe74:44d5                      2                     152
# fe80::f816:3eff:feb7:167f                      2                     152
# fe80::f816:3eff:fe2e:9d7a                      2                     152
# fe80::f816:3eff:fe4d:d1ec                      2                     152
# fe80::f816:3eff:fe86:6a88                      2                     152
# fe80::f816:3eff:fe58:aabb                      2                     152
# fe80::f816:3eff:fe69:f180                      2                     152
# fe80::f816:3eff:fe84:4d18                      2                     152
# fe80::f816:3eff:fe95:17ba                      2                     152
# fe80::f816:3eff:fe90:cf9                       2                     152
# fe80::f816:3eff:fe33:b599                      2                     152
# fe80::f816:3eff:fe6b:dc89                      1                     48
#  INFO ( default_print/print ): *** Purging cache - START (PID: 77639) ***
# INFO ( default_print/print ): *** Purging cache - END (PID: 77639, QN: 26/26, ET: 0) ***
#   DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 0
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:37 (0x5650d08e45e0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 1 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 101, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 104
# DEBUG ( default_nfprobe/nfprobe ): Sent 1 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:37 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:fffb:ecf3]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:21:19.807 finish:2024-07-04T10:21:19.807 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e45e0)
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:68 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2600:2701:5000:a902::c]:33198 proto:6
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:69 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2600:2701:5000:a902::c]:53538 proto:6
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:70 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2610:1e0:1700:202::7]:35152 proto:6
#  2001:400:a100:3000:f816:3eff:febc:8269         90                    24947
# 2610:1e0:1700:202::7                           26                    5973
# 2600:2701:5000:a902::c                         55                    9048
# 127.0.0.1                                      2                     292
# fe80::f816:3eff:fef8:383d                      7                     504
# fe80::f816:3eff:fe77:162d                      1                     48
# fe80::f816:3eff:febb:9db7                      3                     440
# fe80::f816:3eff:fe90:cf9                       4                     304
# fe80::f816:3eff:fe6d:519b                      4                     304
# fe80::f816:3eff:fe74:44d5                      4                     304
# fe80::f816:3eff:feb7:167f                      4                     304
# fe80::f816:3eff:fe86:6a88                      4                     304
# fe80::f816:3eff:fe2e:9d7a                      4                     304
# fe80::f816:3eff:fe58:aabb                      4                     304
# fe80::f816:3eff:febc:8269                      4                     304
# fe80::f816:3eff:fe84:4d18                      4                     304
# fe80::f816:3eff:fe95:17ba                      4                     304
# fe80::f816:3eff:feb1:d79f                      4                     304
# fe80::f816:3eff:fe27:f059                      4                     304
# fe80::f816:3eff:fe1b:80fc                      4                     304
# fe80::f816:3eff:fea3:6b3d                      4                     304
# fe80::f816:3eff:fe60:613f                      4                     304
# fe80::f816:3eff:fe33:b599                      4                     304
# fe80::f816:3eff:fe4d:d1ec                      4                     304
# fe80::f816:3eff:fe69:f180                      4                     304
# fe80::f816:3eff:feeb:75d6                      4                     544
#  INFO ( default_print/print ): *** Purging cache - START (PID: 77906) ***
# INFO ( default_print/print ): *** Purging cache - END (PID: 77906, QN: 26/26, ET: 0) ***
#   DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 0
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:38 (0x5650d08e4760) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:39 (0x5650d08e48e0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:40 (0x5650d08e4a60) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:41 (0x5650d08e4be0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:42 (0x5650d08e4d60) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 5 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 182, template ID = 2048, total len = 166
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 344, template ID = 2048, total len = 328
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 506, template ID = 2048, total len = 490
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 508
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 101, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 182, template ID = 2048, total len = 166
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 184
# DEBUG ( default_nfprobe/nfprobe ): Sent 2 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:38 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2610:1e0:1700:202::7]:57730 proto:6 octets>:6401 packets>:22 octets<:3912 packets<:19 start:2024-07-04T10:22:01.121 finish:2024-07-04T10:22:02.005 tcp>:1b tcp<:1b flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e4760)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:39 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2600:2701:5000:a902::c]:53890 proto:6 octets>:6401 packets>:22 octets<:4056 packets<:21 start:2024-07-04T10:22:04.104 finish:2024-07-04T10:22:05.224 tcp>:1b tcp<:1b flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e48e0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:40 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2610:1e0:1700:202::7]:42602 proto:6 octets>:5305 packets>:26 octets<:5693 packets<:22 start:2024-07-04T10:22:11.693 finish:2024-07-04T10:22:12.783 tcp>:1b tcp<:1b flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e4a60)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:41 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff30:e6]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:22:25.407 finish:2024-07-04T10:22:25.407 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e4be0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:42 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff90:cf9]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:22:55.690 finish:2024-07-04T10:22:55.690 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e4d60)
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:71 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff67:1ec3]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:72 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff4d:d1ec]:0 proto:58
#  2001:400:a100:3000:f816:3eff:febc:8269         19                    8316
# 2600:2701:5000:a902::c                         13                    936
# 127.0.0.1                                      4                     1552
# 2610:1e0:1700:202::7                           6                     484
# fe80::f816:3eff:febb:9db7                      4                     400
# fe80::f816:3eff:fef8:383d                      5                     352
# fe80::f816:3eff:fe6b:dc89                      1                     48
# fe80::f816:3eff:fe77:162d                      1                     48
# fe80::f816:3eff:fe6d:519b                      2                     152
# fe80::f816:3eff:fe4d:d1ec                      2                     152
# fe80::f816:3eff:fe2e:9d7a                      2                     152
# fe80::f816:3eff:fe69:f180                      2                     152
# fe80::f816:3eff:fe86:6a88                      2                     152
# fe80::f816:3eff:fe58:aabb                      2                     152
# fe80::f816:3eff:fe84:4d18                      2                     152
# fe80::f816:3eff:feb1:d79f                      2                     152
# fe80::f816:3eff:fe1b:80fc                      2                     152
# fe80::f816:3eff:fe27:f059                      2                     152
# fe80::f816:3eff:fea3:6b3d                      2                     152
# fe80::f816:3eff:feeb:75d6                      2                     272
# fe80::f816:3eff:fe90:cf9                       2                     152
# fe80::f816:3eff:fe60:613f                      2                     152
# fe80::f816:3eff:feb7:167f                      2                     152
# fe80::f816:3eff:fe74:44d5                      2                     152
# fe80::f816:3eff:fe33:b599                      2                     152
# fe80::f816:3eff:fe95:17ba                      2                     152
# fe80::f816:3eff:febc:8269                      2                     152
#  INFO ( default_print/print ): *** Purging cache - START (PID: 77911) ***
# INFO ( default_print/print ): *** Purging cache - END (PID: 77911, QN: 27/27, ET: 0) ***
#   DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 0
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:43 (0x5650d08e4ee0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:44 (0x5650d08e5060) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:46 (0x5650d08e5360) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 3 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 101, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 182, template ID = 2048, total len = 166
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 263, template ID = 2048, total len = 247
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 264
# DEBUG ( default_nfprobe/nfprobe ): Sent 1 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:43 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff33:b599]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:23:05.889 finish:2024-07-04T10:23:05.889 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e4ee0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:44 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ffbf:2847]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:23:11.965 finish:2024-07-04T10:23:11.965 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e5060)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:46 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff2c:aa44]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:23:27.824 finish:2024-07-04T10:23:27.824 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e5360)
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:73 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff01:755d]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:74 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff2d:f1e9]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:75 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2610:1e0:1700:202::7]:42750 proto:6
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:76 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff39:3357]:0 proto:58
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:77 [127.0.0.1]:58828 <> [127.0.0.53]:53 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:78 [2001:400:a100:3000:f816:3eff:febc:8269]:54145 <> [2600:2701:5000:a902::5]:53 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:79 [2001:400:a100:3000:f816:3eff:febc:8269]:38302 <> [2600:2701:5000:a902::5]:53 proto:17
# DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:80 [127.0.0.1]:43715 <> [127.0.0.53]:53 proto:17
#  2001:400:a100:3000:f816:3eff:febc:8269         53                    15059
# 2600:2701:5000:a902::c                         17                    1224
# 2610:1e0:1700:202::7                           28                    4576
# 127.0.0.1                                      6                     878
# fe80::f816:3eff:febb:9db7                      5                     360
# 2600:2701:5000:a902::5                         4                     654
# 127.0.0.53                                     4                     394
#  INFO ( default_print/print ): *** Purging cache - START (PID: 78015) ***
# INFO ( default_print/print ): *** Purging cache - END (PID:
tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e1460)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:5 [fd3f:f209:c712::1]:0 <> [fe80::820:c4ff:fe71:4439]:0 proto:58 octets>:128 packets>:2 octets<:144 packets<:2 start:2024-07-04T10:19:36.085 finish:2024-07-04T10:24:34.581 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e15e0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:6 [fe80::48d:91ff:fed1:234f]:0 <> [fe80::820:c4ff:fe71:4439]:0 proto:58 octets>:272 packets>:4 octets<:272 packets<:4 start:2024-07-04T10:19:40.949 finish:2024-07-04T10:24:39.781 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e1760)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:45 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff77:162d]:0 proto:58 octets>:144 packets>:2 octets<:0 packets<:0 start:2024-07-04T10:23:17.777 finish:2024-07-04T10:24:43.780 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e51e0)
# ...
# 127.0.0.1                                      32                    13852
# 127.0.0.4                                      8                     3736
# 2610:1e0:1700:202::7                           4                     288
# 127.0.0.3                                      4                     1868
# fe80::f816:3eff:febb:9db7                      5                     472
# fe80::f816:3eff:fef8:383d                      2                     152
# fe80::f816:3eff:fe84:4d18                      2                     152
# fe80::f816:3eff:feeb:75d6                      2                     272
# fe80::f816:3eff:fe4d:d1ec                      2                     152
# fe80::f816:3eff:fe60:613f                      2                     152
# fe80::f816:3eff:fe27:f059                      2                     152
# fe80::f816:3eff:fea3:6b3d                      2                     152
# fe80::f816:3eff:fe1b:80fc                      2                     152
# fe80::f816:3eff:fe74:44d5                      2                     152
# fe80::f816:3eff:fe90:cf9                       2                     152
# fe80::f816:3eff:febc:8269                      2                     152
# fe80::f816:3eff:fe33:b599                      2                     152
# fe80::f816:3eff:feb1:d79f                      2                     152
# fe80::f816:3eff:fe69:f180                      2                     152
# fe80::f816:3eff:fe6d:519b                      2                     152
# fe80::f816:3eff:fe58:aabb                      2                     152
# fe80::f816:3eff:fe86:6a88                      2                     152
# fe80::f816:3eff:fe95:17ba                      2                     152
# fe80::f816:3eff:fe2e:9d7a                      2                     152
# fe80::f816:3eff:feb7:167f                      2                     152
#  INFO ( default_print/print ): *** Purging cache - START (PID: 81060) ***
# INFO ( default_print/print ): *** Purging cache - END (PID: 81060, QN: 27/27, ET: 0) ***
#   DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 0
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:203 (0x5650d08e74c0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:204 (0x5650d08e4ee0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:207 (0x5650d08e15e0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:208 (0x5650d08e71c0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:209 (0x5650d08e6860) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:210 (0x5650d08ebcb0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:93 (0x5650d08e63e0) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:92 (0x5650d08e1460) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:94 (0x5650d08e6260) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 9 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 101, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 263, template ID = 2048, total len = 247
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 382, template ID = 1024, total len = 118
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 384
#   DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 182, template ID = 2048, total len = 166
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 344, template ID = 2048, total len = 328
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 462, template ID = 1024, total len = 118
#   DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 464
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 182, template ID = 2048, total len = 166
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 344, template ID = 2048, total len = 328
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 506, template ID = 2048, total len = 490
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 508
# DEBUG ( default_nfprobe/nfprobe ): Sent 3 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:203 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ffeb:1b32]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:39:04.315 finish:2024-07-04T10:39:04.315 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e74c0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:204 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2600:2701:5000:a902::c]:58800 proto:6 octets>:4361 packets>:21 octets<:4288 packets<:24 start:2024-07-04T10:39:39.432 finish:2024-07-04T10:39:40.677 tcp>:1b tcp<:1b flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e4ee0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:207 [127.0.0.1]:44086 <> [127.0.0.53]:53 proto:17 octets>:148 packets>:2 octets<:148 packets<:2 start:2024-07-04T10:39:44.305 finish:2024-07-04T10:39:44.391 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e15e0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:208 [2001:400:a100:3000:f816:3eff:febc:8269]:38777 <> [2600:2701:5000:a902::5]:53 proto:17 octets>:177 packets>:2 octets<:327 packets<:2 start:2024-07-04T10:39:44.305 finish:2024-07-04T10:39:44.391 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e71c0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:209 [2001:400:a100:3000:f816:3eff:febc:8269]:45476 <> [2600:2701:5000:a902::5]:53 proto:17 octets>:177 packets>:2 octets<:327 packets<:2 start:2024-07-04T10:39:44.305 finish:2024-07-04T10:39:44.391 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e6860)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:210 [127.0.0.1]:59821 <> [127.0.0.53]:53 proto:17 octets>:118 packets>:2 octets<:246 packets<:2 start:2024-07-04T10:39:44.391 finish:2024-07-04T10:39:44.391 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08ebcb0)
#   DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:93 [fd3f:f209:c712::2]:0 <> [fe80::48d:91ff:fed1:234f]:0 proto:58 octets>:256 packets>:4 octets<:288 packets<:4 start:2024-07-04T10:30:42.277 finish:2024-07-04T10:39:48.837 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e63e0)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:92 [fd3f:f209:c712::1]:0 <> [fe80::820:c4ff:fe71:4439]:0 proto:58 octets>:256 packets>:4 octets<:288 packets<:4 start:2024-07-04T10:30:42.197 finish:2024-07-04T10:39:49.013 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e1460)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:94 [fe80::48d:91ff:fed1:234f]:0 <> [fe80::820:c4ff:fe71:4439]:0 proto:58 octets>:544 packets>:8 octets<:544 packets<:8 start:2024-07-04T10:30:47.317 finish:2024-07-04T10:39:54.213 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e6260)
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:259 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:fff8:383d]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:260 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff77:162d]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:261 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff74:39d]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:262 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff39:d7b8]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:263 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff95:17ba]:0 proto:58
#  2001:400:a100:3000:f816:3eff:febc:8269         58                    39940
# 2600:2701:5000:a902::c                         52                    3744
# 127.0.0.1                                      23                    11116
# 127.0.0.4                                      7                     3404
# 2610:1e0:1700:202::7                           6                     484
# 127.0.0.3                                      3                     1524
# fe80::f816:3eff:fe6b:dc89                      1                     48
# fe80::f816:3eff:fef8:383d                      3                     200
# fe80::f816:3eff:febb:9db7                      9                     648
# fe80::f816:3eff:fe77:162d                      1                     48
#  INFO ( default_print/print ): *** Purging cache - START (PID: 81069) ***
# INFO ( default_print/print ): *** Purging cache - END (PID: 81069, QN: 10/10, ET: 0) ***
#   DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 0
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:90 (0x5650d08e1760) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:211 (0x5650d08ed330) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 2 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 182, template ID = 2048, total len = 166
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 263, template ID = 2048, total len = 247
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 264
# DEBUG ( default_nfprobe/nfprobe ): Sent 1 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:90 [fd3f:f209:c712::1]:0 <> [fd3f:f209:c712::2]:0 proto:58 octets>:8320 packets>:80 octets<:8320 packets<:80 start:2024-07-04T10:30:37.150 finish:2024-07-04T10:40:03.221 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e1760)
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:211 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff69:f180]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:40:51.521 finish:2024-07-04T10:40:51.521 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08ed330)
#   INFO ( default_print/print ): *** Purging cache - START (PID: 81072) ***
#  2001:400:a100:3000:f816:3eff:febc:8269         17                    11208
# 2610:1e0:1700:202::7                           4                     288
# 2600:2701:5000:a902::c                         13                    936
# 127.0.0.1                                      8                     2396
# 127.0.0.4                                      2                     640
# 127.0.0.3                                      1                     320
# fe80::f816:3eff:febb:9db7                      1                     184
# fe80::f816:3eff:fef8:383d                      5                     352
# fe80::f816:3eff:feeb:75d6                      2                     272
# fe80::f816:3eff:fea3:6b3d                      2                     152
# fe80::f816:3eff:fe60:613f                      2                     152
# fe80::f816:3eff:fe4d:d1ec                      2                     152
# fe80::f816:3eff:fe27:f059                      2                     152
# fe80::f816:3eff:fe1b:80fc                      2                     152
# fe80::f816:3eff:fe74:44d5                      2                     152
# fe80::f816:3eff:febc:8269                      2                     152
# fe80::f816:3eff:fe90:cf9                       2                     152
# fe80::f816:3eff:feb1:d79f                      2                     152
# fe80::f816:3eff:fe6d:519b                      2                     152
# fe80::f816:3eff:fe95:17ba                      2                     152
# fe80::f816:3eff:fe86:6a88                      2                     152
# fe80::f816:3eff:fe58:aabb                      2                     152
# fe80::f816:3eff:fe2e:9d7a                      2                     152
# fe80::f816:3eff:fe84:4d18                      2                     152
# fe80::f816:3eff:fe33:b599                      2                     152
# fe80::f816:3eff:fe69:f180                      2                     152
# fe80::f816:3eff:feb7:167f                      2                     152
# fe80::f816:3eff:fe6b:dc89                      1                     48
# fe80::f816:3eff:fe77:162d                      1                     48
#  INFO ( default_print/print ): *** Purging cache - END (PID: 81072, QN: 29/29, ET: 0) ***
#   DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 0
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:232 (0x5650d08ec130) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 1 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 182, template ID = 2048, total len = 166
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 184
# DEBUG ( default_nfprobe/nfprobe ): Sent 1 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:232 [2001:400:a100:3000:f816:3eff:febc:8269]:22 <> [2600:2701:5000:a902::c]:45780 proto:6 octets>:4801 packets>:22 octets<:4376 packets<:25 start:2024-07-04T10:41:07.657 finish:2024-07-04T10:41:09.061 tcp>:1b tcp<:1b flowlabel>:00000000 flowlabel<:00000000  (0x5650d08ec130)
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:264 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff74:44d5]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:265 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:fff6:9946]:0 proto:58
#   DEBUG ( default_nfprobe/nfprobe ): ADD FLOW seq:266 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff86:6a88]:0 proto:58
#  2001:400:a100:3000:f816:3eff:febc:8269         36                    14420
# 2600:2701:5000:a902::c                         30                    2160
# 2610:1e0:1700:202::7                           6                     484
# 127.0.0.1                                      8                     1756
# 127.0.0.4                                      2                     480
# 127.0.0.3                                      1                     240
# fe80::f816:3eff:febb:9db7                      5                     472
# fe80::f816:3eff:fef8:383d                      2                     152
# fe80::f816:3eff:febc:8269                      2                     152
# fe80::f816:3eff:fe33:b599                      2                     152
# fe80::f816:3eff:feb1:d79f                      2                     152
# fe80::f816:3eff:fe69:f180                      2                     152
# fe80::f816:3eff:fe95:17ba                      2                     152
# fe80::f816:3eff:fe86:6a88                      2                     152
# fe80::f816:3eff:fe6d:519b                      2                     152
# fe80::f816:3eff:feb7:167f                      2                     152
# fe80::f816:3eff:fe58:aabb                      2                     152
# fe80::f816:3eff:fe2e:9d7a                      2                     152
# fe80::f816:3eff:fe84:4d18                      2                     152
# fe80::f816:3eff:feeb:75d6                      2                     272
# fe80::f816:3eff:fe4d:d1ec                      2                     152
# fe80::f816:3eff:fe60:613f                      2                     152
# fe80::f816:3eff:fe27:f059                      2                     152
# fe80::f816:3eff:fe74:44d5                      2                     152
# fe80::f816:3eff:fe1b:80fc                      2                     152
# fe80::f816:3eff:fe90:cf9                       2                     152
# fe80::f816:3eff:fea3:6b3d                      2                     152
#  INFO ( default_print/print ): *** Purging cache - START (PID: 81078) ***
#   INFO ( default_print/print ): *** Purging cache - END (PID: 81078, QN: 27/27, ET: 0) ***
#   DEBUG ( default_nfprobe/nfprobe ): Starting expiry scan: mode 0
# DEBUG ( default_nfprobe/nfprobe ): Queuing flow seq:254 (0x5650d08e5660) for expiry
# DEBUG ( default_nfprobe/nfprobe ): Finished scan 1 flow(s) to be evicted
# DEBUG ( default_nfprobe/nfprobe ): Building IPFIX packet: offset = 101, template ID = 2048, total len = 85
# DEBUG ( default_nfprobe/nfprobe ): Sending NetFlow v9/IPFIX packet: len = 104
# DEBUG ( default_nfprobe/nfprobe ): Sent 1 netflow packets
# DEBUG ( default_nfprobe/nfprobe ): EXPIRED: seq:254 [fe80::f816:3eff:febb:9db7]:0 <> [ff02::1:ff1a:28f1]:0 proto:58 octets>:72 packets>:1 octets<:0 packets<:0 start:2024-07-04T10:42:26.275 finish:2024-07-04T10:42:26.275 tcp>:00 tcp<:00 flowlabel>:00000000 flowlabel<:00000000  (0x5650d08e5660)
#   INFO ( default_print/print ): *** Purging cache - START (PID: 81084) ***

# %% [markdown]
# ### Print the result on a log file
#
# For this second experiment we will use the following configuration file:
#
# daemonize: false \
# debug: true \
# pcap_interface: any \
# plugins: nfprobe, print \
# nfprobe_version: 10 \
# print_output_file: ipfix_live_2.log
#
# - print: This plugin is used for printing the collected data, in this case to a log file since we have specified an output file.
# - pcap_interface: refers to the interface or interfaces where the tool will collect the data from.
# - print_output_file: refers to the log output file.

# %%
# You need to paste the resulting commands into the terminal to upload the files
print(cmd_upload_file_to(n1, "configuration-files/ipfix_live_2.conf"))
print(cmd_upload_file_to(n2, "configuration-files/ipfix_live_2.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_live_2.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_live_2.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Create the result result log file.
# 2. Move the configuration file and the result log file to the pmacctd folder.
# 3. Execute pmacctd.
# 4. Create live traffic betweeen the nodes.
# 5. Show the results.
# 6. You can execute the last cell of the section to download the .log result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch ipfix_live_2.log")
n1.execute("mv ipfix_live_2.conf ipfix_live_2.log pmacct-1.7.8")
n2.execute("mv ipfix_live_2.conf pmacct-1.7.8")
# Out:
# ('', '')

# %%
import threading 
def run_pmacctd(node, command):
    result = node.execute(command)
    print(result)
command_n1 = "cd pmacct-1.7.8 && sudo pmacctd -f ipfix_live_2.conf"
command_n2 = "ping -c 20 -I " + n1_iface1.get_device_name() + " fd3f:f209:c712::1"

thread_h1 = threading.Thread(target=run_pmacctd, args=(n1, command_n1))
thread_h2 = threading.Thread(target=run_pmacctd, args=(n2, command_n2))

thread_h1.start()
thread_h2.start()

thread_h2.join()
# Out:
# PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes
# 64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.089 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.081 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.061 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.074 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.112 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.088 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.069 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.068 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.064 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.083 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.060 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.069 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.068 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.098 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.085 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.072 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.071 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.064 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.092 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.071 ms
#
# --- fd3f:f209:c712::1 ping statistics ---
# 20 packets transmitted, 20 received, 0% packet loss, time 19452ms
# rtt min/avg/max/mdev = 0.060/0.076/0.112/0.013 ms
# ('PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes\n64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.089 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.081 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.061 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.074 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.112 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.088 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.069 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.068 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.064 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.083 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.060 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.069 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.068 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.098 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.085 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.072 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.071 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.064 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.092 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.071 ms\n\n--- fd3f:f209:c712::1 ping statistics ---\n20 packets transmitted, 20 received, 0% packet loss, time 19452ms\nrtt min/avg/max/mdev = 0.060/0.076/0.112/0.013 ms\n', '')

# %%
print(cmd_download_file_from(n1, "pmacct-1.7.8/ipfix_live_2.log"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/ipfix_live_2.log .

# %% [markdown]
# ### Send the IPFIX flows to an .ipfix file
# For this experiment we will use the following configuration file:
#
# daemonize: false \
# debug: true \
# pcap_interface: any \
# plugins: nfprobe \
# nfprobe_receiver: 127.0.0.4:4738 \
# nfprobe_version: 10
#
# - nfprobe_receiver: it configures pmacct to send the collected network flow data to a local collector on IP address 127.0.0.4 running on port 4739.

# %%
# Please, paste the resulting commands to upload the configuration files to the nodes

print(cmd_upload_file_to(n1, "configuration-files/ipfix_live_3.conf"))
print(cmd_upload_file_to(n2, "configuration-files/ipfix_live_3.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_live_3.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_live_3.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Redirecting the flow of 127.0.0.4 port 4739 to the file.
# We are going to do that using netcat. So we first need to download it and then use the following command to redirect the ipfix flows created to it: nc -u -l 4739 > pmacct-1.7.8/ipfix_flows_live_3.ipfix.
#
# This command means that we are using the NetCat utility using UDP which listens for incoming connections on port 4739 and which redirects the output to the file specified on the path, in this cas ipfix_flows_3.ipfix

# %%
n1.execute("sudo apt-get install -y netcat")
n2.execute("sudo apt-get install -y netcat")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# netcat is already the newest version (1.206-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 96 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# netcat is already the newest version (1.206-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 96 not upgraded.
# ('Reading package lists...\nBuilding dependency tree...\nReading state information...\nnetcat is already the newest version (1.206-1ubuntu1).\n0 upgraded, 0 newly installed, 0 to remove and 96 not upgraded.\n',
#  '')

# %% [markdown]
# ##### Execution
#
# 1. Create the result result IPFIX file.
# 2. Move the configuration file and the result file to the pmacctd folder.
# 3. Redirect the network flow of 127.0.0.4 port 4739 to the file
# 4. Execute pmacctd.
# 5. Show the results.
# 6. You can execute the last cell of the section to download the .log result file into your computer.

# %%
#Move configuration file to pmacctd directory, execute experiment and see results
n1.execute("touch ipfix_flows_live_3.ipfix")
n1.execute("mv ipfix_live_3.conf ipfix_flows_live_3.ipfix pmacct-1.7.8")
n2.execute("mv ipfix_live_3.conf pmacct-1.7.8")
# Out:
# ('', '')

# %%
import threading

def run_iperf(node, command):
    result = node.execute(command)
    print(result)
command_1 = "nc -u -l 4738 > pmacct-1.7.8/ipfix_flows_live_3.ipfix"
command_2 = "cd pmacct-1.7.8 && sudo pmacctd -f ipfix_live_3.conf"
command_3 = "ping -c 20 -I " + n1_iface1.get_device_name() + " fd3f:f209:c712::1"

thread_1 = threading.Thread(target=run_iperf, args=(n1, command_1))
thread_2 = threading.Thread(target=run_iperf, args=(n1, command_2))
thread_3 = threading.Thread(target=run_iperf, args=(n2, command_3))

thread_1.start()
thread_2.start()
thread_3.start()

thread_3.join()
# Out:
# PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes
# 64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.117 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.118 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.072 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.083 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.133 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.068 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.073 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.079 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.092 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.074 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.081 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.066 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.067 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.073 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.070 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.071 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.080 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.068 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.085 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.069 ms
#
# --- fd3f:f209:c712::1 ping statistics ---
# 20 packets transmitted, 20 received, 0% packet loss, time 19434ms
# rtt min/avg/max/mdev = 0.066/0.081/0.133/0.018 ms
# ('PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes\n64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.117 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.118 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.072 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.083 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.133 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.068 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.073 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.079 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.092 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.074 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.081 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.066 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.067 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.073 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.070 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.071 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.080 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.068 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.085 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.069 ms\n\n--- fd3f:f209:c712::1 ping statistics ---\n20 packets transmitted, 20 received, 0% packet loss, time 19434ms\nrtt min/avg/max/mdev = 0.066/0.081/0.133/0.018 ms\n', '')

# %%
print(cmd_download_file_from(n1, "pmacct-1.7.8/ipfix_flows_live_3.ipfix"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/pmacct-1.7.8/ipfix_flows_live_3.ipfix .

# %% [markdown]
# ##### We need to download t-shark so that we can se the content of the flows in the result file.
# First, we need to download the file to inspect its content and the different flows. Since downloading TShark requires granting some permissions, we cannot automate this process. Please refer to the cell where the SSH command for node n1 is shown in the section. Execute that command in a terminal, and then run the following command: "sudo apt-get install -y tshark"

# %% [markdown]
# ##### Summary
# The following command will read and display the packet summary information from the IPFIX file, showing a list of packets captured in the file.

# %%
n1.execute("tshark -r pmacct-1.7.8/ipfix_flows_live_3.ipfix")
# Out:
#     1          0              →              CFLOW 464 IPFIX flow ( 464 bytes) Obs-Domain-ID=    0 [Data-Template:1024] [Data-Template:1025] [Data-Template:2048] [Data-Template:2049] [Data:1024]
#     2          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]
# ('    1          0              →              CFLOW 464 IPFIX flow ( 464 bytes) Obs-Domain-ID=    0 [Data-Template:1024] [Data-Template:1025] [Data-Template:2048] [Data-Template:2049] [Data:1024]\n    2          0              →              CFLOW 476 IPFIX flow ( 476 bytes) Obs-Domain-ID=    0 [Data:1024]\n',
#  '')

# %% [markdown]
# ##### In detail
# This command reads the IPFIX file and provides a detailed hex and ASCII representation of the first packet's data. This is useful for in-depth analysis of the packet's structure and content.
#
# You can change the number of the packet and execute the command again to inspect different ones.

# %%
# Look one packet of a flow in detai
n1.execute("tshark -r pmacct-1.7.8/ipfix_flows_live_3.ipfix -x -c 1")
# Out:
# ('', '')

# %% [markdown]
# ### Send the IPFIX flows to a collector

# %% [markdown]
# First, we need to download the netflow Python library from  https://pypi.org/project/netflow/ and place on the work directory.
# Also it is necessary to download python3 on the node: sudo apt-get install python3 to be able to use the library. Then we will uploade it to the nodes.

# %%
# Upload the netflow library to the nodes.
print(cmd_upload_file_to(n1, "netflow-0.12.2.tar.gz"))
print(cmd_upload_file_to(n2, "netflow-0.12.2.tar.gz"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config netflow-0.12.2.tar.gz ubuntu@[2001:48e8:6401:3:f816:3eff:fe5b:5ef4]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config netflow-0.12.2.tar.gz ubuntu@[2001:48e8:6401:3:f816:3eff:fef8:a33f]:~/

# %%
# Unzip the netflow library file, you can install the zip library by executing the command sudo apt-get zip, you can uncomment the following line and execute it
# If you follow this notebook from the beggining you should have the software package already installed.
#n1.execute("sudo apt-get zip")
n1.execute("tar -xzf netflow-0.12.2.tar.gz")
n2.execute("tar -xzf netflow-0.12.2.tar.gz")
# Out:
# ('', '')

# %% [markdown]
# It is necessary to download python3 and pip on the node to be able to use the library.

# %%
# Download pyython at the nodes and also netflow
n1.execute("sudo apt-get install -y python3")
n2.execute("sudo apt-get install -y python3")
n1.execute("sudo apt-get install -y pip")
n2.execute("sudo apt-get install -y pip")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 96 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 96 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev
#   python3-wheel python3.8-dev zlib1g-dev
# The following NEW packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev
#   python3-pip python3-wheel python3.8-dev zlib1g-dev
# 0 upgraded, 9 newly installed, 0 to remove and 96 not upgraded.
# Need to get 6804 kB of archives.
# After this operation, 25.6 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libexpat1-dev amd64 2.2.9-1ubuntu0.6 [116 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [3950 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libpython3-dev amd64 3.8.2-0ubuntu2 [7236 B]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.10 [1805 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 zlib1g-dev amd64 1:1.2.11.dfsg-2ubuntu1.5 [155 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [514 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 python3-dev amd64 3.8.2-0ubuntu2 [1212 B]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.10 [231 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Fetched 6804 kB in 0s (47.4 MB/s)
# Selecting previously unselected package libexpat1-dev:amd64.
# (Reading database ... 72793 files and directories currently installed.)
# Preparing to unpack .../0-libexpat1-dev_2.2.9-1ubuntu0.6_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../1-libpython3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../2-libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python-pip-whl.
# Preparing to unpack .../3-python-pip-whl_20.0.2-5ubuntu1.10_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.10) ...
# Selecting previously unselected package zlib1g-dev:amd64.
# Preparing to unpack .../4-zlib1g-dev_1%3a1.2.11.dfsg-2ubuntu1.5_amd64.deb ...
# Unpacking zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../5-python3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../6-python3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-dev (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../7-python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../8-python3-pip_20.0.2-5ubuntu1.10_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.10) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Setting up libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Setting up zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.10) ...
# Setting up libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Setting up python3-pip (20.0.2-5ubuntu1.10) ...
# Setting up python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Setting up python3-dev (3.8.2-0ubuntu2) ...
# Processing triggers for man-db (2.9.1-1) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev
#   python3-wheel python3.8-dev zlib1g-dev
# The following NEW packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev
#   python3-pip python3-wheel python3.8-dev zlib1g-dev
# 0 upgraded, 9 newly installed, 0 to remove and 96 not upgraded.
# Need to get 6804 kB of archives.
# After this operation, 25.6 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libexpat1-dev amd64 2.2.9-1ubuntu0.6 [116 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [3950 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libpython3-dev amd64 3.8.2-0ubuntu2 [7236 B]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.10 [1805 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 zlib1g-dev amd64 1:1.2.11.dfsg-2ubuntu1.5 [155 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [514 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 python3-dev amd64 3.8.2-0ubuntu2 [1212 B]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.10 [231 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 6804 kB in 0s (44.7 MB/s)
# Selecting previously unselected package libexpat1-dev:amd64.
# (Reading database ... 72793 files and directories currently installed.)
# Preparing to unpack .../0-libexpat1-dev_2.2.9-1ubuntu0.6_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../1-libpython3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../2-libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python-pip-whl.
# Preparing to unpack .../3-python-pip-whl_20.0.2-5ubuntu1.10_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.10) ...
# Selecting previously unselected package zlib1g-dev:amd64.
# Preparing to unpack .../4-zlib1g-dev_1%3a1.2.11.dfsg-2ubuntu1.5_amd64.deb ...
# Unpacking zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../5-python3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../6-python3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-dev (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../7-python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../8-python3-pip_20.0.2-5ubuntu1.10_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.10) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Setting up libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Setting up zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.10) ...
# Setting up libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Setting up python3-pip (20.0.2-5ubuntu1.10) ...
# Setting up python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Setting up python3-dev (3.8.2-0ubuntu2) ...
# Processing triggers for man-db (2.9.1-1) ...
# ('Reading package lists...\nBuilding dependency tree...\nReading state information...\nThe following additional packages will be installed:\n  libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev\n  python3-wheel python3.8-dev zlib1g-dev\nThe following NEW packages will be installed:\n  libexpat1-dev libpython3-dev libpython3.8-dev python-pip-whl python3-dev\n  python3-pip python3-wheel python3.8-dev zlib1g-dev\n0 upgraded, 9 newly installed, 0 to remove and 96 not upgraded.\nNeed to get 6804 kB of archives.\nAfter this operation, 25.6 MB of additional disk space will be used.\nGet:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libexpat1-dev amd64 2.2.9-1ubuntu0.6 [116 kB]\nGet:2 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [3950 kB]\nGet:3 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 libpython3-dev amd64 3.8.2-0ubuntu2 [7236 B]\nGet:4 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.10 [1805 kB]\nGet:5 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 zlib1g-dev amd64 1:1.2.11.dfsg-2ubuntu1.5 [155 kB]\nGet:6 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [514 kB]\nGet:7 http://nova.clouds.archive.ubuntu.com/ubuntu focal/main amd64 python3-dev amd64 3.8.2-0ubuntu2 [1212 B]\nGet:8 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]\nGet:9 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.10 [231 kB]\nFetched 6804 kB in 0s (44.7 MB/s)\nSelecting previously unselected package libexpat1-dev:amd64.\r\n(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 72793 files and directories currently installed.)\r\nPreparing to unpack .../0-libexpat1-dev_2.2.9-1ubuntu0.6_amd64.deb ...\r\nUnpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...\r\nSelecting previously unselected package libpython3.8-dev:amd64.\r\nPreparing to unpack .../1-libpython3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...\r\nUnpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...\r\nSelecting previously unselected package libpython3-dev:amd64.\r\nPreparing to unpack .../2-libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...\r\nUnpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...\r\nSelecting previously unselected package python-pip-whl.\r\nPreparing to unpack .../3-python-pip-whl_20.0.2-5ubuntu1.10_all.deb ...\r\nUnpacking python-pip-whl (20.0.2-5ubuntu1.10) ...\r\nSelecting previously unselected package zlib1g-dev:amd64.\r\nPreparing to unpack .../4-zlib1g-dev_1%3a1.2.11.dfsg-2ubuntu1.5_amd64.deb ...\r\nUnpacking zlib1g-dev:amd64 (1:1.2.11.dfsg-2ubuntu1.5) ...\r\nSelecting previously unselected package python3.8-dev.\r\nPreparing to unpack .../5-python3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...\r\nUnpacking python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...\r\nSelecting previously unselected package python3-dev.\r\nPreparing to unpack .../6-python3-dev_3.8.2-0ubuntu2_amd64.deb ...\r\nUnpacking python3-dev (3.8.2-0ubuntu2) ...\r\nSelecting previously unselected package python3-wheel.\r\nPreparing to unpack .../7-python3-wheel_0.34.2-1ubuntu0.1_all.deb ...\r\nUnpacking python3-wheel (0.34.2-1ubuntu0.1) ...\r\nSelecting previously unselected package python3-pip.\r\n ...
#  'debconf: unable to initialize frontend: Dialog\ndebconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)\ndebconf: falling back to frontend: Readline\ndebconf: unable to initialize frontend: Readline\ndebconf: (This frontend requires a controlling tty.)\ndebconf: falling back to frontend: Teletype\ndpkg-preconfigure: unable to re-open stdin: \n')

# %% [markdown]
# We also need to install the netflow Python package so that the library works properly.

# %%
n1.execute("pip install netflow")
# Out:
# Requirement already satisfied: netflow in ./.local/lib/python3.8/site-packages (0.12.2)
# ('Requirement already satisfied: netflow in ./.local/lib/python3.8/site-packages (0.12.2)\n',
#  '')

# %% [markdown]
# ##### Configuration file
#
# For this experiment we will use the following configuration file:
#
# daemonize: false \
# debug: true \
# pcap_interface: any \
# plugins: nfprobe \
# nfprobe_receiver: 127.0.0.6:4739 \
# nfprobe_version: 9
#
# - nfprobe_version: 9 refers to NetFlow, since we are using its Python version we need to specify it.

# %%
# Please, paste the commands on the terminal to upload the files to the node
print(cmd_upload_file_to(n1, "configuration-files/ipfix_live_4.conf"))
print(cmd_upload_file_to(n2, "configuration-files/ipfix_live_4.conf"))
# Out:
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_live_4.conf ubuntu@[2001:400:a100:3000:f816:3eff:febc:8269]:~/
# scp -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config configuration-files/ipfix_live_4.conf ubuntu@[2001:400:a100:3000:f816:3eff:feb1:d79f]:~/

# %% [markdown]
# ##### Execution
#
# 1. Move the configuration file to the pmacctd folder.
# 2. Execute the python program collector.py specifying the host and the port
# 3. Redirect the network flow of 127.0.0.6 port 4739 to the file
# 4. Execute pmacctd daemon.
# 5. Create ICMP live traffic
# 6. Show the results.

# %%
n1.execute("mv ipfix_live_4.conf pmacct-1.7.8")
n2.execute("mv ipfix_live_4.conf pmacct-1.7.8")
# Out:
# ('', '')

# %%
import threading

def run_iperf(node, command):
    result = node.execute(command)
    print(result)
command_1 = "cd netflow-0.12.2/netflow && python3 collector.py --host 127.0.0.6 --port 4739"
command_2 = "cd pmacct-1.7.8 && sudo pmacctd -f ipfix_live_4.conf"
command_3 = "ping -c 40 -I " + n1_iface1.get_device_name() + " fd3f:f209:c712::1"

thread_1 = threading.Thread(target=run_iperf, args=(n1, command_1))
thread_2 = threading.Thread(target=run_iperf, args=(n1, command_2))
thread_3 = threading.Thread(target=run_iperf, args=(n2, command_3))

thread_1.start()
thread_2.start()
thread_3.start()

thread_3.join()
# Out:
# PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes
# 64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.120 ms
#  Traceback (most recent call last):
#   File "collector.py", line 231, in <module>
#     for ts, client, export in get_export_packets(args.host, args.port):
#   File "collector.py", line 182, in get_export_packets
#     listener = ThreadedNetFlowListener(host, port)
#   File "collector.py", line 95, in __init__
#     self.server = QueuingUDPListener((host, port), self.input)
#   File "collector.py", line 60, in __init__
#     super().__init__(interface, QueuingRequestHandler)
#   File "/usr/lib/python3.8/socketserver.py", line 452, in __init__
#     self.server_bind()
#   File "/usr/lib/python3.8/socketserver.py", line 466, in server_bind
#     self.socket.bind(self.server_address)
# OSError: [Errno 98] Address already in use
#  ('', 'Traceback (most recent call last):\n  File "collector.py", line 231, in <module>\n    for ts, client, export in get_export_packets(args.host, args.port):\n  File "collector.py", line 182, in get_export_packets\n    listener = ThreadedNetFlowListener(host, port)\n  File "collector.py", line 95, in __init__\n    self.server = QueuingUDPListener((host, port), self.input)\n  File "collector.py", line 60, in __init__\n    super().__init__(interface, QueuingRequestHandler)\n  File "/usr/lib/python3.8/socketserver.py", line 452, in __init__\n    self.server_bind()\n  File "/usr/lib/python3.8/socketserver.py", line 466, in server_bind\n    self.socket.bind(self.server_address)\nOSError: [Errno 98] Address already in use\n')
# 64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.100 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.094 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.111 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.097 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.115 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.075 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.077 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.090 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.090 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.067 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.083 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.067 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.102 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.072 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.069 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.081 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.073 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.076 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.087 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=21 ttl=64 time=0.090 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=22 ttl=64 time=0.071 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=23 ttl=64 time=0.086 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=24 ttl=64 time=0.068 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=25 ttl=64 time=0.092 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=26 ttl=64 time=0.097 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=27 ttl=64 time=0.093 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=28 ttl=64 time=0.086 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=29 ttl=64 time=0.071 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=30 ttl=64 time=0.075 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=31 ttl=64 time=0.077 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=32 ttl=64 time=0.093 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=33 ttl=64 time=0.102 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=34 ttl=64 time=0.073 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=35 ttl=64 time=0.080 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=36 ttl=64 time=0.079 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=37 ttl=64 time=0.082 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=38 ttl=64 time=0.079 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=39 ttl=64 time=0.073 ms
# 64 bytes from fd3f:f209:c712::1: icmp_seq=40 ttl=64 time=0.076 ms
#
# --- fd3f:f209:c712::1 ping statistics ---
# 40 packets transmitted, 40 received, 0% packet loss, time 39926ms
# rtt min/avg/max/mdev = 0.067/0.084/0.120/0.013 ms
# ('PING fd3f:f209:c712::1(fd3f:f209:c712::1) from fd3f:f209:c712::2 enp7s0: 56 data bytes\n64 bytes from fd3f:f209:c712::1: icmp_seq=1 ttl=64 time=0.120 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=2 ttl=64 time=0.100 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=3 ttl=64 time=0.094 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=4 ttl=64 time=0.111 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=5 ttl=64 time=0.097 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=6 ttl=64 time=0.115 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=7 ttl=64 time=0.075 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=8 ttl=64 time=0.077 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=9 ttl=64 time=0.090 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=10 ttl=64 time=0.090 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=11 ttl=64 time=0.067 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=12 ttl=64 time=0.083 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=13 ttl=64 time=0.067 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=14 ttl=64 time=0.102 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=15 ttl=64 time=0.072 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=16 ttl=64 time=0.069 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=17 ttl=64 time=0.081 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=18 ttl=64 time=0.073 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=19 ttl=64 time=0.076 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=20 ttl=64 time=0.087 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=21 ttl=64 time=0.090 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=22 ttl=64 time=0.071 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=23 ttl=64 time=0.086 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=24 ttl=64 time=0.068 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=25 ttl=64 time=0.092 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=26 ttl=64 time=0.097 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=27 ttl=64 time=0.093 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=28 ttl=64 time=0.086 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=29 ttl=64 time=0.071 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=30 ttl=64 time=0.075 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=31 ttl=64 time=0.077 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=32 ttl=64 time=0.093 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=33 ttl=64 time=0.102 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=34 ttl=64 time=0.073 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=35 ttl=64 time=0.080 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=36 ttl=64 time=0.079 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=37 ttl=64 time=0.082 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=38 ttl=64 time=0.079 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=39 ttl=64 time=0.073 ms\n64 bytes from fd3f:f209:c712::1: icmp_seq=40 ttl=64 time=0.076 ms\n\n--- fd3f:f209:c712::1 ping statistics ---\n40 packets transmitted, 40 received, 0% packet loss, time 39926ms\nrtt min/avg/max/mdev = 0.067/0.084/0.120/0.013 ms\n', '')

# %% [markdown]
# ##### Results
#
# The results will be obtained on a .tar file, containing a JSON file placed on the netflow folder as you can see on the following picture:
#
# <div style="text-align: center;">
#     <img src="./images/4.png" width="700px"/>
# </div>
#
# You can unzip them using the command: gzip -d filename.gz
#
# You can see the results using the command: cat filename
#
# You can download the results using the command: print(cmd_download_file_from(n1, "filename"))

# %% [markdown]
# # Future work
# This notebook focuses on the integration of pmacctd with FABRIC, but this is not its ultimate goal. The aim is to create an opportunity for future students and individuals interested in networking within the field of computer science to experiment and learn by leveraging the combined capabilities of these two tools. Therefore, I encourage users to continue contributing to this notebook by modifying experiments, tweaking the pmacctd configuration files, experimenting with different topologies, incorporating pmacctd into their own projects, or simply exploring the numerous functionalities that pmacct offers.
