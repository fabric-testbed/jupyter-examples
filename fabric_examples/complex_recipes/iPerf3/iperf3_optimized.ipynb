# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # iPerf3 with CPU Pinning and NUMA Tuning (Basic NIC)
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to create a FABRIC slice with multiple nodes connected via a Layer 2 network, run iPerf3 network performance tests, and then apply **CPU pinning** and **NUMA tuning** to dramatically improve throughput. You will see the performance difference before and after tuning by running iPerf3 benchmarks in both scenarios.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Create a multi-node FABRIC slice with **NIC_Basic** interfaces on specific worker hosts
# 2. Configure an isolated **Layer 2 network** connecting all nodes
# 3. Run **iPerf3** network throughput tests using Docker containers
# 4. Apply **CPU pinning** to align vCPUs with the physical NUMA node hosting the NIC
# 5. Apply **NUMA memory tuning** to ensure memory allocation matches the NIC's NUMA domain
# 6. Compare network performance **before and after** tuning to quantify the improvement
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../fablib_api/configure_environment/configure_environment.ipynb) notebook
# 2. Be familiar with creating basic FABRIC slices (see [Hello, FABRIC](../../fablib_api/hello_fabric/hello_fabric.ipynb))
# 3. Have a project with sufficient resource allocation for 3 nodes with 16 cores and 32 GB RAM each
#
# **Tip:** This experiment requires a site with at least 3 worker hosts. The notebook automatically selects a suitable site, but if provisioning fails, try a larger site like TACC, STAR, or DALL.
#
# **Tip:** The `node_tools/` directory must be present in the same folder as this notebook. It contains `host_tune.sh` and `enable_docker.sh` scripts used during post-boot configuration.
#
# </div>

# %% [markdown]
# ## Background: CPU Pinning and NUMA Tuning
#
# Modern servers have a **Non-Uniform Memory Access (NUMA)** architecture where CPUs and memory are organized into NUMA nodes. Each NUMA node has its own local memory and is physically closer to certain PCIe devices (like NICs).
#
#
# **Why does this matter for network performance?**
#
# - **Without tuning:** The VM's vCPUs may be scheduled on physical CPUs in a different NUMA node than the NIC. Every network packet must cross the inter-NUMA interconnect, adding latency and reducing throughput.
# - **With CPU pinning:** vCPUs are locked to physical CPUs on the same NUMA node as the NIC, eliminating cross-NUMA traffic.
# - **With NUMA memory tuning:** The VM's memory is allocated on the same NUMA node, keeping data close to both the CPU and NIC.
#
# The combination of these optimizations can yield **significant throughput improvements** (often 20-50% or more) for network-intensive workloads.

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create two nodes on different sites connected for bandwidth measurement with iPerf3.
#
# <img src="./figs/slice_topology.png" width="50%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration
#
# Start by importing the FABlib library and verifying your configuration is correct.

# %%
# Import networking utilities for IP address and subnet management
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

# Import the FABlib library for FABRIC testbed interaction
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance and display configuration
fablib = fablib_manager()

# Verify tokens, project, and SSH key paths are correct
fablib.show_config();

# %% [markdown]
# ## Step 2: Select a Site and Define Experiment Variables
#
# We need a site with multiple worker hosts so that each node runs on a **different physical server**. This ensures that network traffic actually traverses the physical network infrastructure rather than being looped back within a single host.
#
# We select a site that has at least one available worker host. The experiment will place nodes on three different workers (w1, w2, w3) at that site.

# %%
# Select a random site that has available worker hosts
# The filter ensures we pick a site with at least 1 host reported available
hosts_column_name = 'hosts'

site1 = fablib.get_random_site(filter_function=lambda x: x[hosts_column_name] > 0)
print(f"Site: {site1}")

# %%
# Define experiment variables
slice_name = 'iPerf3-tuned-basic'  # Name for this experiment slice

node1_name='Node1'
node2_name='Node2'

network_name='net1'      # Name for the L2 network connecting all nodes
nic_name = 'nic1'        # Name for the NIC component on each node
model_name = 'NIC_Basic' # Use basic virtual NIC (SR-IOV virtual function)

# %% [markdown]
# ## Step 3: Define the Network Subnet
#
# We define a private IPv4 subnet for the isolated Layer 2 network. All nodes will receive IP addresses from this subnet automatically via the `auto` mode.

# %%
# Define a /24 subnet for the L2 network
# This gives us 254 usable IP addresses (192.168.1.1 - 192.168.1.254)
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

subnet = IPv4Network("192.168.1.0/24")
available_ips = list(subnet)[1:]  # Skip the network address (192.168.1.0)

# %% [markdown]
# ## Step 4: Create the Experiment Slice
#
# This step creates a slice with **three nodes**, each placed on a different worker host at the selected site. All nodes are connected through an isolated Layer 2 Ethernet network.
#
# Each node is configured with:
# - **16 cores** and **32 GB RAM** for sufficient processing power
# - A **NIC_Basic** interface connected to the shared L2 network
# - **Rocky Linux 9** operating system
# - Post-boot scripts that apply host-level tuning and install Docker
#
# <div class="fab-danger">
#
# **Important:** This slice requests significant resources (3 nodes x 16 cores x 32 GB RAM). Ensure your project has sufficient allocation. Slice creation may take 5-10 minutes.
#
# </div>

# %%
# Create a new slice
slice = fablib.new_slice(name=slice_name)

# Create an L2 (Layer 2) network with the defined subnet
# L2 networks provide raw Ethernet connectivity between nodes
net1 = slice.add_l2network(name=network_name, subnet=subnet)

# Define the three worker hosts where nodes will be placed
# Each node goes on a different physical server to ensure real network traffic
hosts = [f"{site1.lower()}-w1", f"{site1.lower()}-w2", f"{site1.lower()}-w3"]

for h in hosts:
    # Create a node on the specific worker host
    # Using 16 cores and 32GB RAM for sufficient iPerf3 performance
    node1 = slice.add_node(name=f"{h}-a", cores=16, ram=32, site=site1, 
                           image='default_rocky_9', 
                           host=f"{h}.fabric-testbed.net")

    # Add a NIC_Basic interface and connect it to the L2 network
    # 'auto' mode lets FABRIC automatically assign IP addresses from the subnet
    iface1 = node1.add_component(model=model_name, name=nic_name).get_interfaces()[0]
    iface1.set_mode('auto')
    net1.add_interface(iface1)

    # Upload the node_tools directory containing tuning and Docker scripts
    node1.add_post_boot_upload_directory('node_tools','.')
    # Apply host-level network tuning (buffer sizes, interrupt coalescing, etc.)
    node1.add_post_boot_execute('sudo node_tools/host_tune.sh')
    # Install and enable Docker using the appropriate method for the OS image
    node1.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }} ')
    # Pre-pull the Docker image containing iPerf3 and other network tools
    node1.add_post_boot_execute('docker pull fabrictestbed/slice-vm-rocky8-multitool:0.0.2 ')

# Submit the slice request and wait for provisioning to complete
slice.submit();

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC provisioned three VMs on separate physical hosts at the same site, connected them via an isolated Layer 2 Ethernet network, configured IP addresses, applied host-level tuning, and installed Docker with the iPerf3 multitool image.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 5: Run iPerf3 **Before** Performance Tuning (Baseline)
#
# Before applying CPU pinning and NUMA tuning, we run iPerf3 between every pair of nodes to establish a **baseline** measurement. This allows us to quantify exactly how much improvement the tuning provides.
#
# **iPerf3 parameters used:**
# - `-P 10` : Use 10 parallel streams to saturate the link
# - `-t 30` : Run each test for 30 seconds
# - `-i 10` : Report results every 10 seconds
# - `-O 10` : Omit the first 10 seconds (warm-up period) from the final result
# - `-s -1` : Server mode, accept one connection then exit

# %%
# Re-fetch the slice to ensure we have the latest state
slice = fablib.get_slice(slice_name)

# Get the first node's IP as the initial source
source_name = f"{site1.lower()}-w1-a"
source_node = slice.get_node(name=source_name)
source_addr = source_node.get_interface(network_name=network_name).get_ip_addr()

# Build the list of all node names for pairwise testing
node_names = [f"{site1.lower()}-w1-a", f"{site1.lower()}-w2-a", f"{site1.lower()}-w3-a"]

# Run iPerf3 between every pair of nodes (all-to-all)
for i in range(len(node_names)):
    source_node = slice.get_node(name=node_names[i])
    source_addr = source_node.get_interface(network_name=network_name).get_ip_addr()
    
    for j in range(len(node_names)):
        if i==j:
            continue  # Skip self-to-self tests
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
        # Start iPerf3 server in a Docker container (detached, single-connection mode)
        stdout1, stderr1 = source_node.execute("docker run -d --rm "
                                            "--network host "
                                            "fabrictestbed/slice-vm-rocky8-multitool:0.0.2 "
                                            "iperf3 -s -1"
                                            , quiet=True, output_file=f"{source_node.get_name()}-no-tune.log");

        print(f"Source:  {node_names[i]} to Dest: {node_names[j]}")
        dest_node = slice.get_node(name=node_names[j])

        # Run iPerf3 client connecting to the source node's server
        # -P 10: 10 parallel streams, -t 30: 30 second test, -O 10: omit first 10s
        stdout2, stderr2 = dest_node.execute("docker run --rm "
                                            "--network host "
                                            "fabrictestbed/slice-vm-rocky8-multitool:0.0.2 "
                                            f"iperf3 -c {source_addr} -P 10 -t 30 -i 10 -O 10"
                                            , quiet=False, output_file=f"{dest_node.get_name()}-no-tune.log");
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")

# %% [markdown]
# <div class="fab-warning">
#
# **Tip:** Note the throughput values from these baseline tests. You will compare them with the tuned results later to see the improvement.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 6: Perform CPU Pinning and NUMA Tuning
#
# Now we apply the performance optimizations:
#
# 1. **`pin_cpu(component_name)`** -- Pins all vCPUs to physical CPUs on the same NUMA node as the specified NIC. This eliminates cross-NUMA latency for packet processing.
#
# 2. **`numa_tune()`** -- Configures the VM's memory allocation policy to prefer the NUMA node closest to the NIC. This keeps memory buffers physically close to both the CPU and the NIC.
#
# 3. **`os_reboot()`** -- Reboots the VM so the new CPU and memory pinning takes effect.
#
# <div class="fab-danger">
#
# **Important:** The reboot is required for the NUMA tuning to take effect. After reboot, network interfaces and Docker will need to be reconfigured.
#
# </div>

# %%
# Re-fetch the slice
slice = fablib.get_slice(slice_name)

for node in slice.get_nodes():
    # Pin all vCPUs for VM to same Numa node as the component
    node.pin_cpu(component_name=nic_name)
    
    # User can also pass in the range of the vCPUs to be pinned 
    #node.pin_cpu(component_name=nic_name, cpu_range_to_pin="0-3")
    
    # Pin memmory for VM to same Numa node as the components
    node.numa_tune()
    
    # Reboot the VM
    node.os_reboot()

# %% [markdown]
# ## Step 7: Re-configure Network Interfaces and Docker After Reboot
#
# After the reboot, we need to:
# 1. Wait for SSH connectivity to be restored
# 2. Re-apply network interface configuration (IP addresses)
# 3. Re-enable and start the Docker service
# 4. Re-pull the iPerf3 Docker image

# %%
# Re-fetch the slice after reboot
slice = fablib.get_slice(slice_name)

# Wait for the SSH Connectivity to be back
slice.wait_ssh()

# Re-configuring the Network
for node in slice.get_nodes():
    # Re-apply network interface configuration (IP addresses, routes)
    node.config()
    # Enable Docker to start on boot and start it now
    stdout1, stderr1 = node.execute("sudo systemctl enable docker")
    stdout1, stderr1 = node.execute("sudo systemctl start docker")    
    # Re-pull the Docker image (may already be cached)
    stdout1, stderr1 = node.execute("sudo docker pull fabrictestbed/slice-vm-rocky8-multitool:0.0.2 ")
    # Ensure Docker is running (repeat for reliability)
    stdout1, stderr1 = node.execute("sudo systemctl enable docker")
    stdout1, stderr1 = node.execute("sudo systemctl start docker")

# %% [markdown]
# ## Step 8: Verify IP Addresses Are Configured
#
# After reconfiguration, confirm that all interfaces have their IP addresses correctly assigned.

# %%
# List all interfaces and their IP assignments
slice = fablib.get_slice(slice_name)
slice.list_interfaces();

# %% [markdown]
# ---
#
# ## Step 9: Run iPerf3 **After** Performance Tuning
#
# Now we repeat the exact same iPerf3 tests to measure the impact of CPU pinning and NUMA tuning. Compare these results with the baseline values from Step 5.
#
# You should observe **higher throughput** and **lower CPU utilization** in the tuned results.

# %%
# Re-fetch the slice
slice = fablib.get_slice(slice_name)

# Get the first node's IP as the initial source
source_name = f"{site1.lower()}-w1-a"
source_node = slice.get_node(name=source_name)
source_addr = source_node.get_interface(network_name=network_name).get_ip_addr()

# Build the list of all node names
node_names = [f"{site1.lower()}-w1-a", f"{site1.lower()}-w2-a", f"{site1.lower()}-w3-a"]

# Run iPerf3 between every pair of nodes (all-to-all) -- AFTER tuning
for i in range(len(node_names)):
    source_node = slice.get_node(name=node_names[i])
    source_addr = source_node.get_interface(network_name=network_name).get_ip_addr()
    
    for j in range(len(node_names)):
        if i==j:
            continue  # Skip self-to-self tests
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
        # Start iPerf3 server in Docker (detached, single-connection mode)
        stdout1, stderr1 = source_node.execute("docker run -d --rm "
                                            "--network host "
                                            "fabrictestbed/slice-vm-rocky8-multitool:0.0.2 "
                                            "iperf3 -s -1"
                                            , quiet=True, output_file=f"{source_node.get_name()}.log");

        print(f"Source:  {node_names[i]} to Dest: {node_names[j]}")
        dest_node = slice.get_node(name=node_names[j])

        # Run iPerf3 client with same parameters as baseline for fair comparison
        stdout2, stderr2 = dest_node.execute("docker run --rm "
                                            "--network host "
                                            "fabrictestbed/slice-vm-rocky8-multitool:0.0.2 "
                                            f"iperf3 -c {source_addr} -P 10 -t 30 -i 10 -O 10"
                                            , quiet=False, output_file=f"{dest_node.get_name()}.log");
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")

# %% [markdown]
# <div class="fab-success">
#
# **Compare your results!** Look at the aggregate throughput (SUM line) in both the baseline and tuned runs. The tuned results should show a meaningful improvement, especially for the NIC_Basic which benefits significantly from proper NUMA alignment.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 10: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. This experiment uses significant resources (48 cores, 96 GB RAM total) that other researchers need.
#
# </div>

# %%
# Delete the slice and release all resources
slice = fablib.get_slice(slice_name)
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | No site found with enough hosts | Sites may be at capacity | Try specifying a large site manually: `site1 = 'TACC'` |
# | Slice submission fails | Insufficient project allocation | Request more resources from your project lead |
# | Docker not running after reboot | Service did not start | Run `sudo systemctl start docker` manually on the node |
# | iPerf3 connection refused | Server container not ready | Add a `time.sleep(5)` between starting server and client |
# | No improvement after tuning | NIC may already be on the same NUMA node | Run `numactl --hardware` on the node to verify NUMA topology |
# | Network interfaces have no IP after reboot | `node.config()` may have failed | Re-run `node.config()` or manually assign IPs |
# | `node_tools` directory not found | Missing helper scripts | Ensure the `node_tools/` directory is in the same folder as this notebook |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_site()` | Select a random site matching filter criteria | [get_random_site](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_site) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_l2network()` | Add a Layer 2 network to the slice | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `slice.add_node()` | Add a compute node with specific resources | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component()` | Add a NIC or other component to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `node.pin_cpu()` | Pin vCPUs to the NUMA node of a component | [pin_cpu](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.pin_cpu) |
# | `node.numa_tune()` | Tune VM memory to match component NUMA node | [numa_tune](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.numa_tune) |
# | `node.os_reboot()` | Reboot the node's operating system | [os_reboot](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.os_reboot) |
# | `node.execute()` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `slice.wait_ssh()` | Wait until SSH is available on all nodes | [wait_ssh](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.wait_ssh) |
# | `slice.list_interfaces()` | List all network interfaces in the slice | [list_interfaces](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.list_interfaces) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you understand CPU pinning and NUMA tuning with Basic NICs, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Smart NIC Tuning** | [iPerf3 Optimized Smart NIC](./iperf3_optimized_smart_nic.ipynb) | CPU pinning and NUMA tuning with ConnectX-5 25Gbps NICs across sites |
# | **One-Way Latency** | [OWL Measurements](../owl/owl.ipynb) | Measure one-way latency between FABRIC nodes using PTP-synchronized clocks |
# | **L2 Networking** | [Create L2 Network](../../fablib_api/create_l2network/create_l2network.ipynb) | Learn the fundamentals of Layer 2 networking on FABRIC |
# | **Customizing Nodes** | [Customizing Nodes](../../fablib_api/customizing_nodes/customizing_nodes.ipynb) | Set site, cores, RAM, disk, and OS image for your nodes |
