# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # iPerf3 with CPU Pinning and NUMA Tuning (Smart NIC - ConnectX-5)
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to achieve maximum network throughput on FABRIC by combining **ConnectX-5 Smart NICs** (25 Gbps) with **CPU pinning** and **NUMA tuning**. You will create a two-node slice spanning two different FABRIC sites, run iPerf3 benchmarks before and after applying performance tuning, and observe the throughput improvement.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Create a multi-site FABRIC slice with **NIC_ConnectX_5** (Smart NIC) interfaces
# 2. Configure an **inter-site Layer 2 network** between two FABRIC sites
# 3. Run **iPerf3** network throughput tests over 25 Gbps dedicated links
# 4. Apply **CPU pinning** to align vCPUs with the Smart NIC's NUMA node
# 5. Apply **NUMA memory tuning** for optimal DMA performance
# 6. Quantify the performance difference before and after tuning on high-speed links
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../fablib_api/configure_environment/configure_environment.ipynb) notebook
# 2. Be familiar with creating basic FABRIC slices (see [Hello, FABRIC](../../fablib_api/hello_fabric/hello_fabric.ipynb))
# 3. Understand the basics of CPU pinning and NUMA tuning (see [iPerf3 Optimized Basic NIC](./iperf3_optimized.ipynb))
# 4. Have a project with sufficient allocation for 2 nodes with 16 cores, 32 GB RAM, and ConnectX-5 NICs
#
# **Tip:** ConnectX-5 NICs are a limited resource. If no sites have them available, try again later or check availability with `fablib.list_sites()`.
#
# **Tip:** The `node_tools/` directory must be present in the same folder as this notebook.
#
# </div>

# %% [markdown]
# ## Background: Smart NICs and NUMA Optimization
#
# **Smart NICs** like the Mellanox ConnectX-5 provide dedicated 25 Gbps bandwidth with hardware-level features such as RDMA, SR-IOV, and advanced offloading. Unlike `NIC_Basic` (which shares the host NIC via SR-IOV virtual functions), a `NIC_ConnectX_5` gives your VM a **dedicated physical NIC**.
#
#
# **Why NUMA tuning matters even more for Smart NICs:**
#
# At 25 Gbps, the CPU must process packets extremely quickly. Any cross-NUMA memory access adds latency that directly reduces achievable throughput. With proper NUMA alignment:
# - PCIe DMA transfers land in local memory (no inter-NUMA hops)
# - CPU cache coherency is maintained efficiently
# - Interrupt handling stays on local CPUs
#
# The performance impact is typically even more pronounced than with Basic NICs because the bottleneck shifts from the NIC to the CPU/memory subsystem.

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create two nodes on different sites connected for bandwidth measurement with iPerf3.
#
# <img src="./figs/slice_topology.png" width="50%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration
#
# Start by importing the FABlib library and verifying your configuration.

# %%
# Import networking utilities for IP address and subnet management
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

# Import the FABlib library for FABRIC testbed interaction
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance and display configuration
fablib = fablib_manager()

# Verify tokens, project, and SSH key paths are correct
fablib.show_config();

# %% [markdown]
# ## Step 2: Select Two Sites with ConnectX-5 NICs
#
# We need two different FABRIC sites, each with an available ConnectX-5 NIC. Using two sites means traffic will traverse FABRIC's wide-area network, making this a realistic inter-site performance test.

# %%
# Filter for sites that have available ConnectX-5 (CX5) Smart NICs
cx5_column_name = 'nic_connectx_5_available'

# Select 2 random sites with at least one available ConnectX-5 NIC each
sites = fablib.get_random_sites(count=2, filter_function=lambda x: x[cx5_column_name] > 0)
print(f"Sites: {sites}")

# %%
# Define experiment variables
slice_name = 'iPerf3-tuned-smart-nic'  # Name for this experiment slice

node1_name='Node1'
node2_name='Node2'

network_name='net1'            # Name for the L2 network
nic_name = 'nic1'              # Name for the NIC component on each node
model_name = 'NIC_ConnectX_5'  # ConnectX-5 Smart NIC (25 Gbps dedicated)

# %% [markdown]
# ## Step 3: Define the Network Subnet
#
# Define a private IPv4 subnet for the Layer 2 network connecting both nodes across the two sites.

# %%
# Define a /24 subnet for the inter-site L2 network
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

subnet = IPv4Network("192.168.1.0/24")
available_ips = list(subnet)[1:]  # Skip the network address

# %% [markdown]
# ## Step 4: Create the Experiment Slice
#
# This creates a two-node slice with one node at each selected site. Each node gets a dedicated ConnectX-5 NIC, and they are connected via a Layer 2 network that spans the FABRIC backbone.
#
# <div class="fab-danger">
#
# **Important:** ConnectX-5 NICs are a limited resource. If submission fails due to unavailability, try different sites or wait for resources to be released.
#
# </div>

# %%
# Create a new slice
slice = fablib.new_slice(name=slice_name)

# Create an L2 network with the defined subnet
# This L2 network will span two sites via FABRIC's backbone
net1 = slice.add_l2network(name=network_name, subnet=subnet)

# Create one node at each site
for s in sites:
    # Create a node with 16 cores and 32 GB RAM at the given site
    node1 = slice.add_node(name=f"Node-{s}", cores=16, ram=32, site=s, image='default_rocky_9')

    # Add a ConnectX-5 Smart NIC and connect it to the L2 network
    # 'auto' mode lets FABRIC assign IP addresses from the subnet
    iface1 = node1.add_component(model=model_name, name=nic_name).get_interfaces()[0]
    iface1.set_mode('auto')
    net1.add_interface(iface1)

    # Upload host tuning scripts and configure Docker during post-boot
    node1.add_post_boot_upload_directory('node_tools','.')
    node1.add_post_boot_execute('sudo node_tools/host_tune.sh')
    node1.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }} ')
    node1.add_post_boot_execute('docker pull fabrictestbed/slice-vm-rocky8-multitool:0.0.2 ')

# Submit the slice request and wait for provisioning
slice.submit();

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC provisioned two VMs at different sites, each with a dedicated ConnectX-5 25 Gbps NIC, connected them via a dedicated Layer 2 circuit across the FABRIC backbone, and installed Docker with the iPerf3 multitool image.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 5: Run iPerf3 **Before** Performance Tuning (Baseline)
#
# Run iPerf3 between the two nodes to establish a baseline measurement before applying NUMA optimizations.

# %%
# Re-fetch the slice to ensure we have the latest state
slice = fablib.get_slice(slice_name)

# Run iPerf3 between the two nodes in both directions
for i in range(len(sites)):
    node_name = f"Node-{sites[i]}"
    source_node = slice.get_node(name=node_name)
    source_addr = source_node.get_interface(network_name=network_name).get_ip_addr()
    
    for j in range(len(sites)):
        if i==j:
            continue  # Skip self-to-self tests
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
        # Start iPerf3 server in Docker container (detached, single-connection mode)
        stdout1, stderr1 = source_node.execute("docker run -d --rm "
                                            "--network host "
                                            "fabrictestbed/slice-vm-rocky8-multitool:0.0.2 "
                                            "iperf3 -s -1"
                                            , quiet=True, output_file=f"{source_node.get_name()}-no-tune.log");

        dest_node_name = f"Node-{sites[j]}"
        print(f"Source:  {node_name} to Dest: {dest_node_name}")
        dest_node = slice.get_node(name=dest_node_name)

        # Run iPerf3 client with 10 parallel streams for 30 seconds
        # -O 10: omit first 10 seconds (warm-up) from final result
        stdout2, stderr2 = dest_node.execute("docker run --rm "
                                            "--network host "
                                            "fabrictestbed/slice-vm-rocky8-multitool:0.0.2 "
                                            f"iperf3 -c {source_addr} -P 10 -t 30 -i 10 -O 10"
                                            , quiet=False, output_file=f"{dest_node.get_name()}-no-tune.log");
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")

# %% [markdown]
# <div class="fab-warning">
#
# **Tip:** Note the aggregate throughput (SUM line) from these baseline tests. With a 25 Gbps link and no NUMA tuning, you may see significantly less than the theoretical maximum.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 6: Perform CPU Pinning and NUMA Tuning
#
# Apply the same three-step optimization process as the Basic NIC notebook, but now targeting the ConnectX-5 Smart NIC:
#
# 1. **`pin_cpu(component_name='nic1')`** -- Pins vCPUs to the NUMA node hosting the ConnectX-5
# 2. **`numa_tune()`** -- Pins memory allocation to the same NUMA node
# 3. **`os_reboot()`** -- Reboots to apply changes
#
# <div class="fab-danger">
#
# **Important:** After reboot, network interfaces and Docker must be reconfigured (see next step).
#
# </div>

# %%
# Re-fetch the slice
slice = fablib.get_slice(slice_name)

for node in slice.get_nodes():
    # Pin all vCPUs for VM to same Numa node as the component
    node.pin_cpu(component_name=nic_name)
    
    # User can also pass in the range of the vCPUs to be pinned 
    #node.pin_cpu(component_name=nic_name, cpu_range_to_pin="0-3")
    
    # Pin memmory for VM to same Numa node as the components
    node.numa_tune()
    
    # Reboot the VM
    node.os_reboot()

# %% [markdown]
# ## Step 7: Re-configure Network Interfaces and Docker After Reboot
#
# After the reboot, re-establish network configuration and Docker services.

# %%
# Re-fetch the slice after reboot
slice = fablib.get_slice(slice_name)

# Wait for the SSH Connectivity to be back
slice.wait_ssh()

# Re-configuring the Network
for node in slice.get_nodes():
    # Re-apply network interface configuration (IP addresses, routes)
    node.config()
    # Enable and start Docker
    stdout1, stderr1 = node.execute("sudo systemctl enable docker")
    stdout1, stderr1 = node.execute("sudo systemctl start docker")    
    # Re-pull the Docker image (may already be cached)
    stdout1, stderr1 = node.execute("sudo docker pull fabrictestbed/slice-vm-rocky8-multitool:0.0.2 ")
    # Ensure Docker is running (repeat for reliability)
    stdout1, stderr1 = node.execute("sudo systemctl enable docker")
    stdout1, stderr1 = node.execute("sudo systemctl start docker")

# %% [markdown]
# ## Step 8: Verify IP Addresses Are Configured
#
# Confirm that all interfaces have their IP addresses correctly assigned after the reboot.

# %%
# List all interfaces and verify IP assignments
slice = fablib.get_slice(slice_name)
slice.list_interfaces();

# %% [markdown]
# ---
#
# ## Step 9: Run iPerf3 **After** Performance Tuning
#
# Repeat the same iPerf3 tests to measure the impact of CPU pinning and NUMA tuning on the 25 Gbps Smart NIC link.
#
# You should see **higher throughput** and the results should be closer to the theoretical 25 Gbps line rate.

# %%
# Re-fetch the slice
slice = fablib.get_slice(slice_name)

# Run iPerf3 between the two nodes in both directions -- AFTER tuning
for i in range(len(sites)):
    node_name = f"Node-{sites[i]}"
    source_node = slice.get_node(name=node_name)
    source_addr = source_node.get_interface(network_name=network_name).get_ip_addr()
    
    for j in range(len(sites)):
        if i==j:
            continue  # Skip self-to-self tests
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
        # Start iPerf3 server in Docker (detached, single-connection mode)
        stdout1, stderr1 = source_node.execute("docker run -d --rm "
                                            "--network host "
                                            "fabrictestbed/slice-vm-rocky8-multitool:0.0.2 "
                                            "iperf3 -s -1"
                                            , quiet=True, output_file=f"{source_node.get_name()}.log");

        dest_node_name = f"Node-{sites[j]}"
        print(f"Source:  {node_name} to Dest: {dest_node_name}")
        dest_node = slice.get_node(name=dest_node_name)

        # Run iPerf3 client with same parameters as baseline for fair comparison
        stdout2, stderr2 = dest_node.execute("docker run --rm "
                                            "--network host "
                                            "fabrictestbed/slice-vm-rocky8-multitool:0.0.2 "
                                            f"iperf3 -c {source_addr} -P 10 -t 30 -i 10 -O 10"
                                            , quiet=False, output_file=f"{dest_node.get_name()}.log");
        print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")

# %% [markdown]
# <div class="fab-success">
#
# **Compare your results!** The tuned throughput should be significantly higher than the baseline. With proper NUMA alignment on a ConnectX-5, you should be able to approach the 25 Gbps line rate.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 10: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when finished. ConnectX-5 NICs are a scarce shared resource -- releasing them promptly helps other researchers.
#
# </div>

# %%
# Delete the slice and release all resources
slice = fablib.get_slice(slice_name)
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | No sites found with ConnectX-5 | All CX5 NICs are in use | Check availability with `fablib.list_sites()` and try again later |
# | Slice submission fails | ConnectX-5 was reserved between selection and submission | Re-run the site selection cell and try again |
# | Low throughput even after tuning | Network congestion on the backbone | Try different site pairs or test at off-peak times |
# | Docker not running after reboot | Service did not start | Run `sudo systemctl start docker` manually on the node |
# | iPerf3 connection refused | Server container not ready or firewall | Add `time.sleep(5)` between starting server and client |
# | Network interfaces have no IP after reboot | `node.config()` may have failed | Re-run `node.config()` or manually assign IPs |
# | Throughput asymmetric between directions | Different NUMA configurations per site | Verify pinning with `numactl --hardware` on each node |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_sites(count)` | Select random sites matching filter criteria | [get_random_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_sites) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_l2network()` | Add a Layer 2 network to the slice | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `slice.add_node()` | Add a compute node with specific resources | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component(model='NIC_ConnectX_5')` | Add a ConnectX-5 Smart NIC | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `node.pin_cpu()` | Pin vCPUs to the NUMA node of a component | [pin_cpu](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.pin_cpu) |
# | `node.numa_tune()` | Tune VM memory to match component NUMA node | [numa_tune](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.numa_tune) |
# | `node.os_reboot()` | Reboot the node's operating system | [os_reboot](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.os_reboot) |
# | `node.execute()` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `slice.wait_ssh()` | Wait until SSH is available on all nodes | [wait_ssh](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.wait_ssh) |
# | `slice.list_interfaces()` | List all network interfaces in the slice | [list_interfaces](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.list_interfaces) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you have optimized network throughput with Smart NICs, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Basic NIC Tuning** | [iPerf3 Optimized Basic NIC](./iperf3_optimized.ipynb) | CPU pinning and NUMA tuning with Basic NICs on a single site |
# | **One-Way Latency** | [OWL Measurements](../owl/owl.ipynb) | Measure one-way latency between FABRIC nodes using PTP-synchronized clocks |
# | **Facility Ports** | [Chameleon L2 Stitch](../Chameleon_Facility_Port/Chameleon_Facility_Port_L2.ipynb) | Connect FABRIC to Chameleon using facility ports |
# | **L2 Networking** | [Create L2 Network](../../fablib_api/create_l2network/create_l2network.ipynb) | Learn the fundamentals of Layer 2 networking on FABRIC |
