# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Customizing Nodes: Site, CPU, RAM, Disk, and OS Image
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **What this notebook covers:** The [Hello, FABRIC](../hello_fabric/hello_fabric.ipynb) notebook creates a node with default settings on a random site. Most real experiments need more control over where nodes are placed and how they are configured. This notebook shows you how to customize every major property of a FABRIC node: **site**, **host worker**, **CPU cores**, **RAM**, **disk size**, and **OS image**.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Specify the **FABRIC site** where your node is provisioned
# 2. Set custom **CPU core count**, **RAM**, and **disk** sizes for a node
# 3. Choose a specific **OS image** for your VM
# 4. Use a named **instance type** instead of individual resource hints
# 5. Pin a VM to a specific **worker host** at a site
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you should:
#
# 1. Complete the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Successfully run the [Hello, FABRIC](../hello_fabric/hello_fabric.ipynb) notebook
#
# **Tip:** Your project must have the `VM.NoLimit` permission tag to allocate VMs larger than **2 cores, 10 GB RAM, and 10 GB disk**. Without it you will receive an authorization error. Contact your project lead if you need this permission.
#
# </div>

# %% [markdown]
# ## Background: How VM Sizing Works in FABRIC
#
# FABRIC does not give you the exact CPU/RAM/disk values you request. Instead, the values you specify are treated as **minimum hints**, and FABRIC rounds up to the nearest matching **instance type**. Think of instance types as pre-defined T-shirt sizes:
#
#
# For example, if you request `cores=3, ram=12, disk=50`, FABRIC will provision a `fabric.c4.m16.d100` instance (the smallest type that meets or exceeds all three values).
#
# For a complete list of instance types, see the [FABRIC VM sizing article](https://learn.fabric-testbed.net/knowledge-base/how-vms-are-sized-in-fabric/) and the [instance sizes JSON](https://github.com/fabric-testbed/InformationModel/blob/master/fim/slivers/data/instance_sizes.json).

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a single compute node with default resources.
#
# <img src="./figs/slice_topology.png" width="40%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration
#
# Every FABRIC notebook begins by importing the FABlib library and displaying the current configuration.

# %%
# Import the FABlib library
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance (reads config from fabric_rc)
fablib = fablib_manager()

# Display current configuration (tokens, keys, project info)
fablib.show_config();

# %% [markdown]
# ---
#
# ## Step 2: Create a Node with Custom Resources (Hints)
#
# The most common way to customize a node is to pass `site`, `cores`, `ram`, `disk`, and `image` as parameters to `add_node()`. These values act as **minimum hints** -- FABRIC will round up to the nearest instance type.
#
# <div class="fab-danger">
#
# **Important:** Your project must have the `VM.NoLimit` permission tag to allocate VMs with more than 2 cores, 10 GB RAM, or 10 GB disk. Without it you will receive an error like: `PDP Authorization check failed - Policy Violation: Your project is lacking VM.NoLimitCPU or VM.NoLimit tag to provision VM with more than 2 cores.`
#
# </div>

# %%
slice_name = 'MySlice1'

# Create a new empty slice
slice = fablib.new_slice(slice_name)

# Add a node with specific resource requirements:
#   site  = 'MAX'             -- place the VM at the MAX site
#   cores = 4                 -- request at least 4 CPU cores
#   ram   = 16                -- request at least 16 GB of RAM
#   disk  = 100               -- request at least 100 GB of local disk
#   image = 'default_ubuntu_20' -- use Ubuntu 20.04 as the OS
node = slice.add_node(name='Node1', 
                      site='MAX',
                      cores=4, 
                      ram=16, 
                      disk=100, 
                      image='default_ubuntu_20')

# Submit the slice request and wait for provisioning (~2-5 minutes)
slice.submit()

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC found a `fabric.c4.m16.d100` instance type at the MAX site (the smallest type that satisfies 4 cores / 16 GB RAM / 100 GB disk), provisioned the VM with Ubuntu 20.04, and configured SSH access.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 3: Create a Node Using a Named Instance Type
#
# Instead of specifying individual core/RAM/disk hints, you can request a specific **instance type** by name. This gives you precise control over what you get.
#
# You can also query the list of available OS images using `fablib.get_image_names()`.

# %%
# Query all available OS images on FABRIC
available_images = fablib.get_image_names()
print(f'Available images are: {available_images}')

slice_name = 'MySlice2'

# Create a new slice
slice = fablib.new_slice(slice_name)

# Add a node using a named instance type instead of individual hints:
#   instance_type = 'fabric.c8.m32.d100' -- exactly 8 cores, 32 GB RAM, 100 GB disk
#   This removes ambiguity about which instance type will be selected
node = slice.add_node(name='Node1', 
                      site='MAX',
                      instance_type='fabric.c8.m32.d100',
                      image='default_ubuntu_20')

# Submit the slice request and wait for provisioning
slice.submit()

# %% [markdown]
# <div class="fab-warning">
#
# **Tip:** Using named instance types is recommended when you need reproducible experiments, since you get exactly the resources you specify rather than relying on the rounding-up behavior.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 4: Pin a Node to a Specific Worker Host
#
# Each FABRIC site has multiple **worker nodes** (physical servers) named `<site>-w<index>.fabric-testbed.net`. In rare cases you may need to place your VM on a specific worker -- for example, to access a particular PCI device attached to that machine.
#
# Use the `host` parameter to pin your VM to a specific worker.
#
# <div class="fab-warning">
#
# **Tip:** Different workers have different hardware (GPUs, FPGAs, SmartNICs). Pinning to a specific worker may cause your slice to fail if the requested resources are not available on that machine. In general, let FABRIC choose the worker automatically unless you have a specific reason.
#
# </div>

# %%
slice_name = 'MySlice3'

# Create a new slice
slice = fablib.new_slice(slice_name)

# Add a node pinned to a specific worker host:
#   host = 'max-w2.fabric-testbed.net' -- force placement on worker w2 at MAX
#   This is useful when a specific PCI device is only on that worker
node = slice.add_node(name='Node1', 
                      site='MAX',
                      host='max-w2.fabric-testbed.net',
                      cores=4, 
                      ram=16, 
                      disk=100, 
                      image='default_ubuntu_20')

# Submit the slice request and wait for provisioning
slice.submit()

# %% [markdown]
# <div class="fab-success">
#
# **Verify:** Look at the `Host` column in the Nodes table above. It should show `max-w2.fabric-testbed.net`, confirming the VM was placed on the requested worker.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 5: Delete the Slices
#
# <div class="fab-danger">
#
# **Important:** Always delete your slices when you are done. FABRIC is a shared resource -- leaving slices running unnecessarily prevents other researchers from using those resources.
#
# </div>

# %%
# Delete all three slices created in this notebook
for slice_index in range(1,4):
    print(f'Deleting slice MySlice{slice_index}')
    try:
        fablib.delete_slice("MySlice" + str(slice_index))
    except:
        pass

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | `PDP Authorization check failed` with `VM.NoLimit` message | Project lacks `VM.NoLimit` permission | Contact your project lead to request the `VM.NoLimit` tag |
# | Slice stuck in `Configuring` state | Site may be busy or the requested resources are unavailable | Try a different site or smaller instance type |
# | `Host` column shows a different worker than requested | The specified host may not exist or may be full | Verify the host name follows the pattern `<site>-w<N>.fabric-testbed.net` |
# | `image not found` error | Image name is misspelled or unavailable | Run `fablib.get_image_names()` to see available images |
# | Slice fails with resource error | Requested resources exceed site capacity | Use `fablib.list_sites()` to check current availability |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `fablib.get_image_names()` | List available OS image names | [get_image_names](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_image_names) |
# | `fablib.delete_slice(name)` | Delete a slice by name | [delete_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.delete_slice) |
# | `slice.add_node(name, site, cores, ram, disk, image, host, instance_type)` | Add a compute node with custom properties | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `slice.submit()` | Submit the slice for provisioning | [submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit) |

# %% [markdown]
# ## What's Next?
#
# Now that you know how to customize nodes, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Running Commands** | [execute_commands](../ssh_to_nodes/execute_commands.ipynb) | Execute commands on nodes, capture output, use threads |
# | **Local Disk** | [local_disk](../local_disk/local_disk.ipynb) | Customize and compare local disk sizes |
# | **NVMe Storage** | [basic_nvme_devices](../basic_nvme_devices/basic_nvme_devices.ipynb) | Add fast NVMe storage devices to your nodes |
# | **Persistent Storage** | [persistent_storage](../persistent_storage/persistent_storage.ipynb) | Attach project-level persistent storage volumes |
# | **GPUs** | [fabric_gpu](../fabric_all_gpus/fabric_gpu.ipynb) | Use NVIDIA GPUs (T4, RTX6000, A30, A40) |
