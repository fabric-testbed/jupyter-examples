# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Port Mirroring: Snoop on Dataplane Traffic Within Your Slice
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **What this notebook does:** Demonstrates **in-slice port mirroring** -- a simpler approach where the traffic generator and listener are in the **same slice**. This creates a FABnet IPv4 network between two nodes, then adds a third listener node with a PortMirror service that mirrors traffic from one of the existing nodes.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Create a single slice with both traffic generation and port mirroring capabilities
# 2. Use `slice.add_port_mirror_service()` with VLAN-aware mirroring within a slice
# 3. Add a listener node to an existing slice using `slice.submit()` for modification
# 4. Discover both the port name **and** VLAN of the interface to mirror
# 5. Capture mirrored traffic with `tcpdump` using background threads
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Run the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be familiar with FABnet -- see [FABnet IPv4 Auto](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb)
# 3. **Have the `Net.PortMirror` project permission tag** on your project
#
# **For cross-slice port mirroring** (monitoring other users' traffic), see [Port Mirror Infrastructure](port_mirror.ipynb).
#
# </div>

# %% [markdown]
# ## Background: In-Slice Port Mirroring
#
# Unlike the [cross-slice approach](port_mirror.ipynb), in-slice port mirroring keeps everything in a **single slice**. The workflow is:
#
# 1. Create a slice with traffic-generating nodes and a FABnet network
# 2. **After** the initial slice is active, add a listener node with a PortMirror service
# 3. Resubmit the slice to deploy the listener
#
#
# When mirroring within a slice, you also need the **VLAN** of the interface being mirrored. This is because shared NICs (SR-IOV VFs) use VLANs to isolate traffic, and you need to specify which VLAN's traffic to capture.

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create nodes within a slice with in-slice port mirroring for traffic analysis.
#
# <img src="./figs/slice_topology.png" width="55%">

# %% [markdown]
# ---
#
# ## Step 0: Import FABlib and Verify Configuration

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance
fablib = fablib_manager()

# Display current configuration
fablib.show_config();

# %% [markdown]
# ---
#
# ## Step 1: Create the Initial Slice with Traffic-Generating Nodes
#
# ### Step 1a: Define Variables

# %%
slice_name = 'MySlice-generator-listener-basic'

node1_name = 'Node1'
node2_name = 'Node2'

network1_name = 'net1'
network2_name = 'net2'

listener_node_name = 'listener_node'
listener_pm_service = 'pmservice'
listener_direction = 'both'    # Options: 'rx', 'tx', or 'both'

# %% [markdown]
# ### Step 1b: Find Sites with Required Hardware
#
# Site1 needs **two** ConnectX-5 NICs (one for the traffic node, one for the listener). Site2 just needs basic NIC availability.

# %%
# Site1 needs 2 CX-5 NICs: one for Node1 traffic and one for the listener
cx5_column_name = 'nic_connectx_5_available'

# Find a site with at least 2 ConnectX-5 cards available
site1 = fablib.get_random_site(filter_function=lambda x: x[cx5_column_name] == 2)

# Site2 can be any other site
site2 = fablib.get_random_site(avoid=[site1])

print(f'Will create "{slice_name}" on {site1} and {site2}')

# %% [markdown]
# ### Step 1c: Build and Submit the Initial Slice
#
# We create the traffic-generating nodes first. Node1 uses a **dedicated ConnectX-5** NIC (since we need to mirror its physical port), while Node2 uses a basic NIC.

# %%
# Create the initial slice with traffic-generating nodes
slice = fablib.new_slice(name=slice_name)

# --- FABnet IPv4 networks (one per site) ---
net1 = slice.add_l3network(name=network1_name, type='IPv4')
net2 = slice.add_l3network(name=network2_name, type='IPv4')

# --- Node1 (site1) with dedicated ConnectX-5 NIC ---
# We use a dedicated NIC so we can mirror its physical port
node1 = slice.add_node(name=node1_name, site=site1)
iface1 = node1.add_component(model='NIC_ConnectX_5', name='nic1').get_interfaces()[0]
iface1.set_mode('auto')
net1.add_interface(iface1)
node1.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net1.get_gateway())

# --- Node2 (site2) with basic NIC ---
node2 = slice.add_node(name=node2_name, site=site2)
iface2 = node2.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface2.set_mode('auto')
net2.add_interface(iface2)
node2.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net2.get_gateway())

# Submit the initial slice
slice.submit();

# %% [markdown]
# ---
#
# ## Step 2: Add the Listener Node to the Slice
#
# Now we modify the existing slice by adding a listener node with a PortMirror service. We need to discover both the **port name** and **VLAN** of Node1's interface.
#
# <div class="fab-warning">
#
# **Tip:** When mirroring within a slice, you need both `mirror_interface_name` (the port name) and `mirror_interface_vlan` (the VLAN tag). This differs from cross-slice mirroring where only the port name is needed.
#
# </div>

# %%
# Retrieve the slice and discover mirror port details
slice = fablib.get_slice(slice_name)
node1 = slice.get_node(node1_name)

# Get both the port name AND VLAN of Node1's interface
mirror_port_name = node1.get_interfaces()[0].get_peer_port_name()
mirror_port_vlan = node1.get_interfaces()[0].get_peer_port_vlan()

# Add the listener node with a dedicated ConnectX-5 NIC
listener_node = slice.add_node(name=listener_node_name, site=site1)
listener_interface = listener_node.add_component(model='NIC_ConnectX_5', name='pmnic').get_interfaces()[0]

# Create the PortMirror service with VLAN-aware mirroring
# The mirror_interface_vlan parameter tells the switch which VLAN's traffic to copy
pmnet = slice.add_port_mirror_service(name=listener_pm_service,
                                      mirror_interface_name=mirror_port_name,
                                      mirror_interface_vlan=mirror_port_vlan,
                                      receive_interface=listener_interface,
                                      mirror_direction=listener_direction)

# Resubmit the slice to deploy the listener node
slice.submit();

# %% [markdown]
# ## Step 3: Verify Traffic Generator Connectivity
#
# Make sure Node1 and Node2 can communicate before setting up the listener.

# %%
# Verify connectivity between the traffic generator nodes
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)
node2 = slice.get_node(name=node2_name)

node2_addr = node2.get_interface(network_name=network2_name).get_ip_addr()

stdout, stderr = node1.execute(f'ping -c 5 {node2_addr}')

# %% [markdown]
# ## Step 4: Set Up the Listener
#
# Install `tcpdump` on the listener node for packet capture.

# %%
# Retrieve the slice and install tcpdump on the listener
slice = fablib.get_slice(slice_name)

listener_node = slice.get_node(name=listener_node_name)

# Install tcpdump for packet capture
command = 'sudo dnf install -y tcpdump'

stdout, stderr = listener_node.execute(command)

# %% [markdown]
# ---
#
# ## Step 5: Run the Experiment
#
# We start a `ping` between Node1 and Node2, and simultaneously capture the mirrored ICMP packets on the listener node using `tcpdump`.

# %%
# Retrieve all nodes
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)
node2 = slice.get_node(name=node2_name)
listener_node = slice.get_node(name=listener_node_name)

# Get addresses and interface names
node2_addr = node2.get_interface(network_name=network2_name).get_ip_addr()
listener_node_intf_name = listener_node.get_interface(network_name=listener_pm_service).get_device_name()

print(f'Will run tcpdump on {listener_node.get_name()} interface {listener_node_intf_name}, listening to ping in Traffic Generator Slice')

# Traffic generation: ping for 10 seconds
traffic_command = f'timeout 10s ping -c 100 {node2_addr}'
# Packet capture: filter for ICMP packets (see libpcap docs for filter syntax)
listen_command = f'sudo timeout 10s tcpdump -i {listener_node_intf_name} icmp'

# Start traffic generation in a background thread
node2_thread = node1.execute_thread(traffic_command, output_file='node1_ping.log')
# Run tcpdump in the foreground to see captured packets
listener_node_thread = listener_node.execute(listen_command)

# Check for errors
stdout, stderr = node2_thread.result()
if stderr and len(stderr):
    print(f'Error output from Traffic Generator Slice: {stderr}')

print(f'Done')

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** The tcpdump output should show ICMP packets between Node1 and Node2. The PortMirror service copied traffic from Node1's switch port (filtered to the specific VLAN) to the listener node's NIC.
#
# </div>

# %% [markdown]
# ## Step 6: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. This releases all NICs and the PortMirror service.
#
# </div>

# %%
# Delete the slice (contains both traffic generators and listener)
try:
    fablib.delete_slice(slice_name)
except Exception as e:
    print(e)

print('Done')

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | `add_port_mirror_service()` fails | Missing `Net.PortMirror` project permission | Contact FABRIC operations to request the permission tag |
# | `get_peer_port_vlan()` returns None | Topology info not available | Re-query the slice with `fablib.get_slice()` |
# | tcpdump shows no packets | VLAN not specified correctly | Ensure `mirror_interface_vlan` matches the interface VLAN |
# | Listener node fails to deploy | Not enough CX-5 NICs at the site | Choose a site with at least 2 CX-5 NICs available |
# | Second `submit()` fails | Slice modification conflict | Delete and recreate the slice |
# | Traffic generator ping fails | FABnet routing issue | Verify `add_route()` was called with `fablib.FABNETV4_SUBNET` |

# %% [markdown]
# ## FABlib API Reference
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.get_random_site(filter_function)` | Find a site matching hardware requirements | [get_random_site](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_site) |
# | `iface.get_peer_port_name()` | Get the switch port name for this interface | [get_peer_port_name](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.get_peer_port_name) |
# | `iface.get_peer_port_vlan()` | Get the VLAN tag for this interface | [get_peer_port_vlan](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.get_peer_port_vlan) |
# | `slice.add_port_mirror_service(...)` | Create a PortMirror service (with optional VLAN) | [add_port_mirror_service](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_port_mirror_service) |
# | `node.execute_thread(command)` | Execute a command in a background thread | [execute_thread](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute_thread) |
# | `iface.get_device_name()` | Get the Linux device name of the interface | [get_device_name](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.get_device_name) |
# | `fablib.delete_slice(name)` | Delete a slice by name | [delete_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.delete_slice) |

# %% [markdown]
# ## What's Next?
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Port Mirror Infrastructure** | [port_mirror](port_mirror.ipynb) | Cross-slice port mirroring (monitor other experiments) |
# | **FABnet IPv4 Auto** | [ipv4_auto](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb) | Layer 3 IPv4 networking with auto configuration |
# | **Sub Interfaces** | [sub_interfaces](../sub_interfaces/sub_interfaces.ipynb) | Multiple virtual interfaces on a single dedicated NIC |
# | **Facility Ports** | [facility_port](../facility_port/facility_port.ipynb) | Connect to external facilities via dedicated links |
