# %% [markdown]
# # Create a PortMirror service to snoop on dataplane traffic with your slice

# %% [markdown]
# FABRIC provides a special PortMirror Network Service that allows experimenters to snoop on traffic within a the slice. This service requires a __Net.PortMirror__ project permission tag on the project and granting this permission requires a review by the FABRIC team to ensure the project takes proper security precautions to prevent the misuse of this feature.
#
# In this notebook we demonstrate the process by creating a slice with a FABNetv4 service and PortMirror service where traffic from FABNetv4 service is mirrored.

# %% [markdown]
# ## Step 0: Import the FABlib Library

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_97e12 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_97e12 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_97e12 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_97e12_row0_col0, #T_97e12_row0_col1, #T_97e12_row1_col0, #T_97e12_row1_col1, #T_97e12_row2_col0, #T_97e12_row2_col1, #T_97e12_row3_col0, #T_97e12_row3_col1, #T_97e12_row4_col0, #T_97e12_row4_col1, #T_97e12_row5_col0, #T_97e12_row5_col1, #T_97e12_row6_col0, #T_97e12_row6_col1, #T_97e12_row7_col0, #T_97e12_row7_col1, #T_97e12_row8_col0, #T_97e12_row8_col1, #T_97e12_row9_col0, #T_97e12_row9_col1, #T_97e12_row10_col0, #T_97e12_row10_col1, #T_97e12_row11_col0, #T_97e12_row11_col1, #T_97e12_row12_col0, #T_97e12_row12_col1, #T_97e12_row13_col0, #T_97e12_row13_col1, #T_97e12_row14_col0, #T_97e12_row14_col1, #T_97e12_row15_col0, #T_97e12_row15_col1, #T_97e12_row16_col0, #T_97e12_row16_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_97e12">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_97e12_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_97e12_row0_col1" class="data row0 col1" >beta-7.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_97e12_row1_col1" class="data row1 col1" >beta-2.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_97e12_row2_col1" class="data row2 col1" >beta-3.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_97e12_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_97e12_row4_col1" class="data row4 col1" >b9847fa1-13ef-49f9-9e07-ae6ad06cda3f</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row5_col0" class="data row5 col0" >Bastion Host</td>
#       <td id="T_97e12_row5_col1" class="data row5 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row6_col0" class="data row6 col0" >Bastion Username</td>
#       <td id="T_97e12_row6_col1" class="data row6 col1" >kthare10_0011904101</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row7_col0" class="data row7 col0" >Bastion Private Key File</td>
#       <td id="T_97e12_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/bastion-prod-2</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_97e12_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/id_rsa.pub</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_97e12_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/id_rsa</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row10_col0" class="data row10 col0" >Sites to avoid</td>
#       <td id="T_97e12_row10_col1" class="data row10 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row11_col0" class="data row11 col0" >SSH Command Line</td>
#       <td id="T_97e12_row11_col1" class="data row11 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_97e12_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row13_col0" class="data row13 col0" >Log File</td>
#       <td id="T_97e12_row13_col1" class="data row13 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row14_col0" class="data row14 col0" >Bastion SSH Config File</td>
#       <td id="T_97e12_row14_col1" class="data row14 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row15_col0" class="data row15 col0" >Version</td>
#       <td id="T_97e12_row15_col1" class="data row15 col1" >1.7.2</td>
#     </tr>
#     <tr>
#       <td id="T_97e12_row16_col0" class="data row16 col0" >Data directory</td>
#       <td id="T_97e12_row16_col1" class="data row16 col1" >/tmp/fablib</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 1: Create the slice that generates traffic and also monitors traffic
# We will use the same approach as a [FABNetv4 full-auto notebook](../create_l3network_fabnet_ipv4_auto/create_l3network_fabnet_ipv4_auto.ipynb) here.
#
# ### Initialize variables
# The following code is split up into two cells so they can be executed separately, if needed.

# %%
slice_name = 'Traffic Generator_Listener Slice'

[site1, site2] = fablib.get_random_sites(2)
# you can use the below line to override site locations
#site1 = ('CLEM')

print(f'Will create "{slice_name}" on {site1} and {site2}')

node1_name = 'Node1'
node2_name = 'Node2'

network1_name='net1'
network2_name='net2'

listener_node_name = 'listener_node'
listener_pm_service = 'pmservice'
listener_direction = 'both' # can also be 'rx' and 'tx'
# Out:
# Will create "Traffic Generator_Listener Slice" on RENC and UKY

# %% [markdown]
# ### Create the slice

# %%
# Create Traffic generator slice

slice = fablib.new_slice(name=slice_name)

# Networks
net1 = slice.add_l3network(name=network1_name, type='IPv4')
net2 = slice.add_l3network(name=network2_name, type='IPv4')

# Node1
node1 = slice.add_node(name=node1_name, site=site1)
iface1 = node1.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface1.set_mode('auto')
net1.add_interface(iface1)
node1.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net1.get_gateway())

# Node2
node2 = slice.add_node(name=node2_name, site=site2)
iface2  = node2.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface2.set_mode('auto')
net2.add_interface(iface2)
node2.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net2.get_gateway())


#Submit Slice Request
slice.submit();
# Out:
# Retry: 9, Time: 312 sec
# <style type="text/css">
# #T_e457f tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e457f tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e457f caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_e457f_row0_col0, #T_e457f_row0_col1, #T_e457f_row1_col0, #T_e457f_row1_col1, #T_e457f_row2_col0, #T_e457f_row2_col1, #T_e457f_row3_col0, #T_e457f_row3_col1, #T_e457f_row4_col0, #T_e457f_row4_col1, #T_e457f_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_e457f_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_e457f">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e457f_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_e457f_row0_col1" class="data row0 col1" >b3c38986-639c-42e3-860a-35d3fc3fa594</td>
#     </tr>
#     <tr>
#       <td id="T_e457f_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_e457f_row1_col1" class="data row1 col1" >Traffic Generator_Listener Slice</td>
#     </tr>
#     <tr>
#       <td id="T_e457f_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_e457f_row2_col1" class="data row2 col1" >2024-07-31 21:19:22 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_e457f_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_e457f_row3_col1" class="data row3 col1" >2024-07-30 21:19:22 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_e457f_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_e457f_row4_col1" class="data row4 col1" >b9847fa1-13ef-49f9-9e07-ae6ad06cda3f</td>
#     </tr>
#     <tr>
#       <td id="T_e457f_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_e457f_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b2aaf caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_b2aaf th {
#   text-align: left;
# }
# #T_b2aaf tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b2aaf tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b2aaf .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b2aaf_row0_col0, #T_b2aaf_row0_col1, #T_b2aaf_row0_col2, #T_b2aaf_row0_col3, #T_b2aaf_row0_col4, #T_b2aaf_row0_col5, #T_b2aaf_row0_col6, #T_b2aaf_row0_col7, #T_b2aaf_row0_col8, #T_b2aaf_row0_col9, #T_b2aaf_row0_col10, #T_b2aaf_row0_col13, #T_b2aaf_row0_col14, #T_b2aaf_row0_col15, #T_b2aaf_row1_col0, #T_b2aaf_row1_col1, #T_b2aaf_row1_col2, #T_b2aaf_row1_col3, #T_b2aaf_row1_col4, #T_b2aaf_row1_col5, #T_b2aaf_row1_col6, #T_b2aaf_row1_col7, #T_b2aaf_row1_col8, #T_b2aaf_row1_col9, #T_b2aaf_row1_col10, #T_b2aaf_row1_col13, #T_b2aaf_row1_col14, #T_b2aaf_row1_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_b2aaf_row0_col11, #T_b2aaf_row1_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_b2aaf_row0_col12, #T_b2aaf_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_b2aaf">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_b2aaf_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b2aaf_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_b2aaf_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_b2aaf_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_b2aaf_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_b2aaf_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_b2aaf_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_b2aaf_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_b2aaf_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_b2aaf_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_b2aaf_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_b2aaf_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_b2aaf_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_b2aaf_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_b2aaf_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_b2aaf_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b2aaf_row0_col0" class="data row0 col0" >2e640c4f-d444-41a8-85e8-ace38ce17015</td>
#       <td id="T_b2aaf_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_b2aaf_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_b2aaf_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_b2aaf_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_b2aaf_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_b2aaf_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_b2aaf_row0_col7" class="data row0 col7" >renc-w1.fabric-testbed.net</td>
#       <td id="T_b2aaf_row0_col8" class="data row0 col8" >RENC</td>
#       <td id="T_b2aaf_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_b2aaf_row0_col10" class="data row0 col10" >152.54.15.39</td>
#       <td id="T_b2aaf_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_b2aaf_row0_col12" class="data row0 col12" ></td>
#       <td id="T_b2aaf_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/id_rsa -F /home/fabric/work/fabric_config/ssh_config rocky@152.54.15.39</td>
#       <td id="T_b2aaf_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/id_rsa.pub</td>
#       <td id="T_b2aaf_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/id_rsa</td>
#     </tr>
#     <tr>
#       <td id="T_b2aaf_row1_col0" class="data row1 col0" >8360385c-c21c-4f34-a27d-3c77d6aac2f1</td>
#       <td id="T_b2aaf_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_b2aaf_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_b2aaf_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_b2aaf_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_b2aaf_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_b2aaf_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_b2aaf_row1_col7" class="data row1 col7" >uky-w1.fabric-testbed.net</td>
#       <td id="T_b2aaf_row1_col8" class="data row1 col8" >UKY</td>
#       <td id="T_b2aaf_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_b2aaf_row1_col10" class="data row1 col10" >128.163.179.49</td>
#       <td id="T_b2aaf_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_b2aaf_row1_col12" class="data row1 col12" ></td>
#       <td id="T_b2aaf_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/id_rsa -F /home/fabric/work/fabric_config/ssh_config rocky@128.163.179.49</td>
#       <td id="T_b2aaf_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/id_rsa.pub</td>
#       <td id="T_b2aaf_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/id_rsa</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0dc91 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0dc91 th {
#   text-align: left;
# }
# #T_0dc91 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0dc91 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0dc91 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0dc91_row0_col0, #T_0dc91_row0_col1, #T_0dc91_row0_col2, #T_0dc91_row0_col3, #T_0dc91_row0_col4, #T_0dc91_row0_col5, #T_0dc91_row0_col6, #T_0dc91_row1_col0, #T_0dc91_row1_col1, #T_0dc91_row1_col2, #T_0dc91_row1_col3, #T_0dc91_row1_col4, #T_0dc91_row1_col5, #T_0dc91_row1_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_0dc91_row0_col7, #T_0dc91_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_0dc91_row0_col8, #T_0dc91_row1_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_0dc91">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_0dc91_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0dc91_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0dc91_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_0dc91_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_0dc91_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_0dc91_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_0dc91_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_0dc91_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_0dc91_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0dc91_row0_col0" class="data row0 col0" >505b620d-b7d1-4b47-ba4e-15d26ae5787c</td>
#       <td id="T_0dc91_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_0dc91_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_0dc91_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_0dc91_row0_col4" class="data row0 col4" >RENC</td>
#       <td id="T_0dc91_row0_col5" class="data row0 col5" >10.128.1.0/24</td>
#       <td id="T_0dc91_row0_col6" class="data row0 col6" >10.128.1.1</td>
#       <td id="T_0dc91_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_0dc91_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_0dc91_row1_col0" class="data row1 col0" >acecd0b0-5b68-409c-9579-f9674becb657</td>
#       <td id="T_0dc91_row1_col1" class="data row1 col1" >net2</td>
#       <td id="T_0dc91_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_0dc91_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_0dc91_row1_col4" class="data row1 col4" >UKY</td>
#       <td id="T_0dc91_row1_col5" class="data row1 col5" >10.128.129.0/24</td>
#       <td id="T_0dc91_row1_col6" class="data row1 col6" >10.128.129.1</td>
#       <td id="T_0dc91_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_0dc91_row1_col8" class="data row1 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f0c1d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_f0c1d th {
#   text-align: left;
# }
# #T_f0c1d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f0c1d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_f0c1d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f0c1d_row0_col0, #T_f0c1d_row0_col1, #T_f0c1d_row0_col2, #T_f0c1d_row0_col3, #T_f0c1d_row0_col4, #T_f0c1d_row0_col5, #T_f0c1d_row0_col6, #T_f0c1d_row0_col7, #T_f0c1d_row0_col8, #T_f0c1d_row0_col9, #T_f0c1d_row0_col10, #T_f0c1d_row0_col11, #T_f0c1d_row0_col12, #T_f0c1d_row1_col0, #T_f0c1d_row1_col1, #T_f0c1d_row1_col2, #T_f0c1d_row1_col3, #T_f0c1d_row1_col4, #T_f0c1d_row1_col5, #T_f0c1d_row1_col6, #T_f0c1d_row1_col7, #T_f0c1d_row1_col8, #T_f0c1d_row1_col9, #T_f0c1d_row1_col10, #T_f0c1d_row1_col11, #T_f0c1d_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_f0c1d">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_f0c1d_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_f0c1d_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_f0c1d_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_f0c1d_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_f0c1d_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_f0c1d_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_f0c1d_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_f0c1d_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_f0c1d_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_f0c1d_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_f0c1d_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_f0c1d_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_f0c1d_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f0c1d_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_f0c1d_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_f0c1d_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_f0c1d_row0_col3" class="data row0 col3" >net1</td>
#       <td id="T_f0c1d_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_f0c1d_row0_col5" class="data row0 col5" >auto</td>
#       <td id="T_f0c1d_row0_col6" class="data row0 col6" ></td>
#       <td id="T_f0c1d_row0_col7" class="data row0 col7" >02:37:BE:04:DE:BF</td>
#       <td id="T_f0c1d_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_f0c1d_row0_col9" class="data row0 col9" >eth1</td>
#       <td id="T_f0c1d_row0_col10" class="data row0 col10" >10.128.1.2</td>
#       <td id="T_f0c1d_row0_col11" class="data row0 col11" >4</td>
#       <td id="T_f0c1d_row0_col12" class="data row0 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_f0c1d_row1_col0" class="data row1 col0" >Node2-nic1-p1</td>
#       <td id="T_f0c1d_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_f0c1d_row1_col2" class="data row1 col2" >Node2</td>
#       <td id="T_f0c1d_row1_col3" class="data row1 col3" >net2</td>
#       <td id="T_f0c1d_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_f0c1d_row1_col5" class="data row1 col5" >auto</td>
#       <td id="T_f0c1d_row1_col6" class="data row1 col6" ></td>
#       <td id="T_f0c1d_row1_col7" class="data row1 col7" >02:34:83:E8:AE:A3</td>
#       <td id="T_f0c1d_row1_col8" class="data row1 col8" >eth1</td>
#       <td id="T_f0c1d_row1_col9" class="data row1 col9" >eth1</td>
#       <td id="T_f0c1d_row1_col10" class="data row1 col10" >10.128.129.2</td>
#       <td id="T_f0c1d_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_f0c1d_row1_col12" class="data row1 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 313 seconds

# %% [markdown]
# ## Add the Listener to the Slice
# Add a listener node to the slice which mirrors the traffic received on `Node1`

# %%
slice = fablib.get_slice(slice_name)
node1 = slice.get_node(node1_name)

mirror_port_name = node1.get_interfaces()[0].get_peer_port_name()
mirror_port_vlan = node1.get_interfaces()[0].get_peer_port_vlan()

listener_node = slice.add_node(name=listener_node_name, site=site1)
# the first (index 0) interface will be connected into the switch to receive mirror traffic
listener_interface = listener_node.add_component(model='NIC_Basic', name='pmnic').get_interfaces()[0]

# port mirroring is a network service of a special kind
# it mirrors one or both directions of traffic ('rx', 'tx' or 'both') of a port that we identified in
# Traffic Generator Topology into a port of a card we allocated in this slice (listener_interface)
# NOTE: if you select 'both' directions that results in potentially 200Gbps of traffic, which
# of course is impossible to fit into a single 100Gbps port of a ConnectX_6 card - be mindful of the
# data rates.
pmnet = slice.add_port_mirror_service(name=listener_pm_service, 
                                      mirror_interface_name=mirror_port_name,
                                      mirror_interface_vlan=mirror_port_vlan,
                                      receive_interface=listener_interface,
                                      mirror_direction = listener_direction)


#Submit Slice Request
slice.submit();
# Out:
# Retry: 77, Time: 1821 sec
# <style type="text/css">
# #T_330f1 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_330f1 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_330f1 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_330f1_row0_col0, #T_330f1_row0_col1, #T_330f1_row1_col0, #T_330f1_row1_col1, #T_330f1_row2_col0, #T_330f1_row2_col1, #T_330f1_row3_col0, #T_330f1_row3_col1, #T_330f1_row4_col0, #T_330f1_row4_col1, #T_330f1_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_330f1_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_330f1">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_330f1_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_330f1_row0_col1" class="data row0 col1" >b3c38986-639c-42e3-860a-35d3fc3fa594</td>
#     </tr>
#     <tr>
#       <td id="T_330f1_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_330f1_row1_col1" class="data row1 col1" >Traffic Generator_Listener Slice</td>
#     </tr>
#     <tr>
#       <td id="T_330f1_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_330f1_row2_col1" class="data row2 col1" >2024-07-31 21:19:22 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_330f1_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_330f1_row3_col1" class="data row3 col1" >2024-07-30 21:19:22 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_330f1_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_330f1_row4_col1" class="data row4 col1" >b9847fa1-13ef-49f9-9e07-ae6ad06cda3f</td>
#     </tr>
#     <tr>
#       <td id="T_330f1_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_330f1_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_26fa3 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_26fa3 th {
#   text-align: left;
# }
# #T_26fa3 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_26fa3 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_26fa3 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_26fa3_row0_col0, #T_26fa3_row0_col1, #T_26fa3_row0_col2, #T_26fa3_row0_col3, #T_26fa3_row0_col4, #T_26fa3_row0_col5, #T_26fa3_row0_col6, #T_26fa3_row0_col7, #T_26fa3_row0_col8, #T_26fa3_row0_col9, #T_26fa3_row0_col10, #T_26fa3_row0_col13, #T_26fa3_row0_col14, #T_26fa3_row0_col15, #T_26fa3_row1_col0, #T_26fa3_row1_col1, #T_26fa3_row1_col2, #T_26fa3_row1_col3, #T_26fa3_row1_col4, #T_26fa3_row1_col5, #T_26fa3_row1_col6, #T_26fa3_row1_col7, #T_26fa3_row1_col8, #T_26fa3_row1_col9, #T_26fa3_row1_col10, #T_26fa3_row1_col13, #T_26fa3_row1_col14, #T_26fa3_row1_col15, #T_26fa3_row2_col0, #T_26fa3_row2_col1, #T_26fa3_row2_col2, #T_26fa3_row2_col3, #T_26fa3_row2_col4, #T_26fa3_row2_col5, #T_26fa3_row2_col6, #T_26fa3_row2_col7, #T_26fa3_row2_col8, #T_26fa3_row2_col9, #T_26fa3_row2_col10, #T_26fa3_row2_col13, #T_26fa3_row2_col14, #T_26fa3_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_26fa3_row0_col11, #T_26fa3_row1_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_26fa3_row0_col12, #T_26fa3_row1_col12, #T_26fa3_row2_col11, #T_26fa3_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_26fa3">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_26fa3_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_26fa3_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_26fa3_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_26fa3_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_26fa3_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_26fa3_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_26fa3_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_26fa3_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_26fa3_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_26fa3_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_26fa3_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_26fa3_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_26fa3_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_26fa3_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_26fa3_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_26fa3_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_26fa3_row0_col0" class="data row0 col0" >2e640c4f-d444-41a8-85e8-ace38ce17015</td>
#       <td id="T_26fa3_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_26fa3_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_26fa3_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_26fa3_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_26fa3_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_26fa3_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_26fa3_row0_col7" class="data row0 col7" >renc-w1.fabric-testbed.net</td>
#       <td id="T_26fa3_row0_col8" class="data row0 col8" >RENC</td>
#       <td id="T_26fa3_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_26fa3_row0_col10" class="data row0 col10" >152.54.15.39</td>
#       <td id="T_26fa3_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_26fa3_row0_col12" class="data row0 col12" ></td>
#       <td id="T_26fa3_row0_col13" class="data row0 col13" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#       <td id="T_26fa3_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/id_rsa.pub</td>
#       <td id="T_26fa3_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/id_rsa</td>
#     </tr>
#     <tr>
#       <td id="T_26fa3_row1_col0" class="data row1 col0" >8360385c-c21c-4f34-a27d-3c77d6aac2f1</td>
#       <td id="T_26fa3_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_26fa3_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_26fa3_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_26fa3_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_26fa3_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_26fa3_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_26fa3_row1_col7" class="data row1 col7" >uky-w1.fabric-testbed.net</td>
#       <td id="T_26fa3_row1_col8" class="data row1 col8" >UKY</td>
#       <td id="T_26fa3_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_26fa3_row1_col10" class="data row1 col10" >128.163.179.49</td>
#       <td id="T_26fa3_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_26fa3_row1_col12" class="data row1 col12" ></td>
#       <td id="T_26fa3_row1_col13" class="data row1 col13" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#       <td id="T_26fa3_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/id_rsa.pub</td>
#       <td id="T_26fa3_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/id_rsa</td>
#     </tr>
#     <tr>
#       <td id="T_26fa3_row2_col0" class="data row2 col0" >None</td>
#       <td id="T_26fa3_row2_col1" class="data row2 col1" >listener_node</td>
#       <td id="T_26fa3_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_26fa3_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_26fa3_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_26fa3_row2_col5" class="data row2 col5" >default_rocky_8</td>
#       <td id="T_26fa3_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_26fa3_row2_col7" class="data row2 col7" >None</td>
#       <td id="T_26fa3_row2_col8" class="data row2 col8" >RENC</td>
#       <td id="T_26fa3_row2_col9" class="data row2 col9" >rocky</td>
#       <td id="T_26fa3_row2_col10" class="data row2 col10" ></td>
#       <td id="T_26fa3_row2_col11" class="data row2 col11" >None</td>
#       <td id="T_26fa3_row2_col12" class="data row2 col12" ></td>
#       <td id="T_26fa3_row2_col13" class="data row2 col13" ></td>
#       <td id="T_26fa3_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/id_rsa.pub</td>
#       <td id="T_26fa3_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/id_rsa</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8c530 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_8c530 th {
#   text-align: left;
# }
# #T_8c530 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8c530 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_8c530 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8c530_row0_col0, #T_8c530_row0_col1, #T_8c530_row0_col2, #T_8c530_row0_col3, #T_8c530_row0_col4, #T_8c530_row0_col5, #T_8c530_row0_col6, #T_8c530_row1_col0, #T_8c530_row1_col1, #T_8c530_row1_col2, #T_8c530_row1_col3, #T_8c530_row1_col4, #T_8c530_row1_col5, #T_8c530_row1_col6, #T_8c530_row2_col0, #T_8c530_row2_col1, #T_8c530_row2_col2, #T_8c530_row2_col3, #T_8c530_row2_col4, #T_8c530_row2_col5, #T_8c530_row2_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_8c530_row0_col7, #T_8c530_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_8c530_row0_col8, #T_8c530_row1_col8, #T_8c530_row2_col7, #T_8c530_row2_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_8c530">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_8c530_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_8c530_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_8c530_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_8c530_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_8c530_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_8c530_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_8c530_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_8c530_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_8c530_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8c530_row0_col0" class="data row0 col0" >505b620d-b7d1-4b47-ba4e-15d26ae5787c</td>
#       <td id="T_8c530_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_8c530_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_8c530_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_8c530_row0_col4" class="data row0 col4" >RENC</td>
#       <td id="T_8c530_row0_col5" class="data row0 col5" >10.128.1.0/24</td>
#       <td id="T_8c530_row0_col6" class="data row0 col6" >10.128.1.1</td>
#       <td id="T_8c530_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_8c530_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8c530_row1_col0" class="data row1 col0" >acecd0b0-5b68-409c-9579-f9674becb657</td>
#       <td id="T_8c530_row1_col1" class="data row1 col1" >net2</td>
#       <td id="T_8c530_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_8c530_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_8c530_row1_col4" class="data row1 col4" >UKY</td>
#       <td id="T_8c530_row1_col5" class="data row1 col5" >10.128.129.0/24</td>
#       <td id="T_8c530_row1_col6" class="data row1 col6" >10.128.129.1</td>
#       <td id="T_8c530_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_8c530_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8c530_row2_col0" class="data row2 col0" >None</td>
#       <td id="T_8c530_row2_col1" class="data row2 col1" >pmservice</td>
#       <td id="T_8c530_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_8c530_row2_col3" class="data row2 col3" >PortMirror</td>
#       <td id="T_8c530_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_8c530_row2_col5" class="data row2 col5" >pmservice.subnet</td>
#       <td id="T_8c530_row2_col6" class="data row2 col6" >pmservice.gateway</td>
#       <td id="T_8c530_row2_col7" class="data row2 col7" >None</td>
#       <td id="T_8c530_row2_col8" class="data row2 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 25
#      17 pmnet = slice.add_port_mirror_service(name=listener_pm_service,
#      18                                       mirror_interface_name=mirror_port_name,
#      19                                       mirror_interface_vlan=mirror_port_vlan,
#      20                                       receive_interface=listener_interface,
#      21                                       mirror_direction = listener_direction)
#      24 #Submit Slice Request
# ---> 25 slice.submit();
#
# File ~/fabrictestbed-extensions/fabrictestbed_extensions/fablib/slice.py:2292, in Slice.submit(self, wait, wait_timeout, wait_interval, progress, wait_jupyter, post_boot_config, wait_ssh, extra_ssh_keys, lease_start_time, lease_in_days, validate)
#    2281     raise Exception(
#    2282         "Failed to submit slice: {}, {}".format(
#    2283             return_status, slice_reservations
#    2284         )
#    2285     )
#    2287 if (
#    2288     progress
#    2289     and wait_jupyter == "text"
#    2290     and self.fablib_manager.is_jupyter_notebook()
#    2291 ):
# -> 2292     self.wait_jupyter(timeout=wait_timeout, interval=wait_interval)
#    2293     return self.slice_id
#    2295 elif wait:
#
# File ~/fabrictestbed-extensions/fabrictestbed_extensions/fablib/slice.py:1998, in Slice.wait_jupyter(self, timeout, interval, verbose)
#    1996 while True:
#    1997     if time.time() > start + timeout:
# -> 1998         raise Exception(f"Timeout {timeout} sec exceeded in Jupyter wait")
#    2000     time.sleep(interval)
#    2002     stable = False
#
# Exception: Timeout 1800 sec exceeded in Jupyter wait

# %% [markdown]
# ### Test the slice
#
# Let's make sure the two nodes i.e. `Node1` and `Node2` can communicate as expected.

# %%
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)        
node2 = slice.get_node(name=node2_name)           

node2_addr = node2.get_interface(network_name=network2_name).get_ip_addr()

stdout, stderr = node1.execute(f'ping -c 5 {node2_addr}')

# %% [markdown]
# ### Query the Listener slice
#
# This cell is useful if you are coming back to the experiment after a while.

# %%
pmslice = fablib.get_slice(listener_slice_name)

listener_node = pmslice.get_node(name=listener_node_name)   

pmslice.list_nodes()
pmslice.list_networks()

# %% [markdown]
# ## Deal with IPv4/IPv6 and install missing packages
#
# On this slice we will need to install tcpdump so we can watch the mirrored traffic. This means we need to update DNS to use NAT64 in case the site is IPv6.

# %%
from ipaddress import ip_address, IPv6Address    

isipv6_site = False
# If the node is an IPv6 Node then configure NAT64
if type(ip_address(listener_node.get_management_ip())) is IPv6Address:
    isipv6_site = True
    print(f'Node {listener_node.get_name()} has an IPv6 management address, will update DNS configuration')
    
# this code will be executed if the node uses an IPv6 site. See the notebook 
# 'Access non-IPv6 services (i.e. GitHub) from IPv6 FABRIC nodes' for more details

if isipv6_site:
    listener_node.upload_file('../accessing_ipv4_services_from_ipv6_nodes/nat64.sh', 'nat64.sh')
    stdout, stderr = listener_node.execute(f'chmod +x nat64.sh && ./nat64.sh')
    print(f'Uploaded and executed NAT64 DNS setup script to node {listener_node.get_name()}')

# %% [markdown]
# And install tcpdump package

# %%
command = 'sudo dnf install -y tcpdump'

stdout, stderr = listener_node.execute(command)

# %% [markdown]
# ## Run the experiment
#
# As a trivial experiment we start a `ping` between the two nodes in the Traffic Generator Slice and see if we can see it in the Lister Slice.

# %%
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)        
node2 = slice.get_node(name=node2_name)           
listener_node = pmslice.get_node(name=listener_node_name)

node2_addr = node2.get_interface(network_name=network2_name).get_ip_addr()
listener_node_intf_name = listener_node.get_interface(network_name=listener_pm_service).get_device_name()

print(f'Will run tcpdump on {listener_node.get_name()} interface {listener_node_intf_name}, listening to ping in Traffic Generator Slice')

# run everything for 10 seconds
traffic_command = f'timeout 10s ping -c 100 {node2_addr}'
# look at libpcap documentation for more info on how to filter packets
listen_command = f'sudo timeout 10s tcpdump -i {listener_node_intf_name} icmp'

# start traffic generation in the background
node2_thread = node1.execute_thread(traffic_command, output_file='node1_ping.log')
# start tcpdump in the foreground
listener_node_thread = listener_node.execute(listen_command)

# check for errors
stdout, stderr = node2_thread.result()
if stderr and len(stderr):
    print(f'Error output from Traffic Generator Slice: {stderr}')
    
print(f'Done')

# %% [markdown]
# ## Delete both slices

# %%
try:
    fablib.delete_slice(slice_name)
except Exception as e:
    print(e)

print('Done')
