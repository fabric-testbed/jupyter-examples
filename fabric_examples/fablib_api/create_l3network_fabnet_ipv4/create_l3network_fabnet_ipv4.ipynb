# %% [markdown]
# # Creating FABnet IPv4 Network
#
# FABRIC provides a pair of layer 3 IP networking services across every FABRIC site (FABnetv4 and FABnetv6). You can think of this service as a private internet that connects experiments across the testbed using FABRIC's high-performance network links.
#
# This notebook describes how to use the FABnetv4 service which is FABRIC's private IPv4 internet.

# %% [markdown]
# ## Import the FABlib Library

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_fc595 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_fc595 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_fc595 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_fc595_row0_col0, #T_fc595_row0_col1, #T_fc595_row1_col0, #T_fc595_row1_col1, #T_fc595_row2_col0, #T_fc595_row2_col1, #T_fc595_row3_col0, #T_fc595_row3_col1, #T_fc595_row4_col0, #T_fc595_row4_col1, #T_fc595_row5_col0, #T_fc595_row5_col1, #T_fc595_row6_col0, #T_fc595_row6_col1, #T_fc595_row7_col0, #T_fc595_row7_col1, #T_fc595_row8_col0, #T_fc595_row8_col1, #T_fc595_row9_col0, #T_fc595_row9_col1, #T_fc595_row10_col0, #T_fc595_row10_col1, #T_fc595_row11_col0, #T_fc595_row11_col1, #T_fc595_row12_col0, #T_fc595_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_fc595">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fc595_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_fc595_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_fc595_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_fc595_row2_col1" class="data row2 col1" >/home/fabric/work/fabric_config/tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_fc595_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_fc595_row4_col1" class="data row4 col1" >pruth_0031379841</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_fc595_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_fc595_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_fc595_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_fc595_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_fc595_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_fc595_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_fc595_row11_col1" class="data row11 col1" >/home/fabric/work/logs/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_fc595_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_fc595_row12_col1" class="data row12 col1" >DEBUG</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates two nodes, on different sites, with basic NICs connected to FABRIC's FABnetv4 internet.
#
# Two nodes are created and one NIC component is added to each node.  This example uses components of model `NIC_Basic` which are SR-IOV Virtual Function on a 100 Gpbs Mellanox ConnectX-6 PCI device. The VF is accessed by the node via PCI passthrough. Other NIC models are listed below. When using dedicated PCI devices the whole physical device is allocated to one node and the device is accessed by the node using PCI passthrough. Calling the `get_interfaces()` method on a component will return a list of interfaces. Many dedicated NIC components may have more than one port.  Either port can be connected to the network.
#
# Next, add a separate `l3network` for each site and pass the list of interfaces on that site that you want to connect to FABnetv4. All interfaces passed to `l3network` must be on the same site and each network will be placed on that site.  By default, a node is put on a random site.  If you want to ensure that your nodes are all on different sites you can specify the name of the sites in the `add_node` methode.  You can use the `fablib.get_random_site()` method to get a set of random site names that guarantee that the sites are different.
#
#
# NIC component models options:
# - NIC_Basic: 100 Gbps Mellanox ConnectX-6 SR-IOV VF (1 Port)
# - NIC_ConnectX_5: 25 Gbps Dedicated Mellanox ConnectX-5 PCI Device (2 Ports)
# - NIC_ConnectX_6: 100 Gbps Dedicated Mellanox ConnectX-6 PCI Device (2 Ports)

# %%
slice_name = 'MySlice100'
[site1,site2] = fablib.get_random_sites(count=2)
print(f"Sites: {site1}, {site2}")

node1_name = 'Node1'
node2_name = 'Node2'

network1_name='net1'
network2_name='net2'
# Out:
# Sites: MASS, UCSD

# %%
#Create Slice
slice = fablib.new_slice(name=slice_name)

# Networks
net1 = slice.add_l3network(name=network1_name, type='IPv4')
net2 = slice.add_l3network(name=network2_name, type='IPv4')

# Node1
node1 = slice.add_node(name=node1_name, site=site1).enable_docker()
node1.set_rocky_repo(IPv4Address('10.133.130.2'))
iface1 = node1.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface1.set_mode('auto')
net1.add_interface(iface1)
node1.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net1.get_gateway())

user_data = { 'myappdata': { 'item1': 1, 'item': 2 }

node1.set_user_data(user_data)

# Node2
node2 = slice.add_node(name=node2_name, site=site2).enable_docker()
node2.set_rocky_repo(IPv4Address('10.133.130.2'))
iface2  = node2.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface2.set_mode('auto')
net2.add_interface(iface2)
node2.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net2.get_gateway())

#Submit Slice Request
slice.submit();
# Out:
# Retry: 10, Time: 405 sec
# <style type="text/css">
# #T_ab299 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ab299 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ab299 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_ab299_row0_col0, #T_ab299_row0_col1, #T_ab299_row1_col0, #T_ab299_row1_col1, #T_ab299_row2_col0, #T_ab299_row2_col1, #T_ab299_row3_col0, #T_ab299_row3_col1, #T_ab299_row4_col0, #T_ab299_row4_col1, #T_ab299_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_ab299_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_ab299">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ab299_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_ab299_row0_col1" class="data row0 col1" >bdcc57f6-f621-4844-b6da-7f65317d0683</td>
#     </tr>
#     <tr>
#       <td id="T_ab299_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_ab299_row1_col1" class="data row1 col1" >MySlice100</td>
#     </tr>
#     <tr>
#       <td id="T_ab299_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_ab299_row2_col1" class="data row2 col1" >2023-03-02 21:43:51 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ab299_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_ab299_row3_col1" class="data row3 col1" >2023-03-01 21:43:53 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ab299_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_ab299_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_ab299_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_ab299_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e1f1c caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e1f1c th {
#   text-align: left;
# }
# #T_e1f1c tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e1f1c tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e1f1c .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e1f1c_row0_col0, #T_e1f1c_row0_col1, #T_e1f1c_row0_col2, #T_e1f1c_row0_col3, #T_e1f1c_row0_col4, #T_e1f1c_row0_col5, #T_e1f1c_row0_col6, #T_e1f1c_row0_col7, #T_e1f1c_row0_col8, #T_e1f1c_row0_col9, #T_e1f1c_row0_col10, #T_e1f1c_row0_col13, #T_e1f1c_row0_col14, #T_e1f1c_row0_col15, #T_e1f1c_row1_col0, #T_e1f1c_row1_col1, #T_e1f1c_row1_col2, #T_e1f1c_row1_col3, #T_e1f1c_row1_col4, #T_e1f1c_row1_col5, #T_e1f1c_row1_col6, #T_e1f1c_row1_col7, #T_e1f1c_row1_col8, #T_e1f1c_row1_col9, #T_e1f1c_row1_col10, #T_e1f1c_row1_col13, #T_e1f1c_row1_col14, #T_e1f1c_row1_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_e1f1c_row0_col11, #T_e1f1c_row1_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_e1f1c_row0_col12, #T_e1f1c_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_e1f1c">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_e1f1c_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_e1f1c_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_e1f1c_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_e1f1c_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_e1f1c_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_e1f1c_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_e1f1c_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_e1f1c_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_e1f1c_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_e1f1c_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_e1f1c_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_e1f1c_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_e1f1c_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_e1f1c_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_e1f1c_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_e1f1c_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e1f1c_row0_col0" class="data row0 col0" >1f4b5a7d-f721-4eb1-9b1c-98a7658c7f46</td>
#       <td id="T_e1f1c_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_e1f1c_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_e1f1c_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_e1f1c_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_e1f1c_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_e1f1c_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_e1f1c_row0_col7" class="data row0 col7" >mass-w3.fabric-testbed.net</td>
#       <td id="T_e1f1c_row0_col8" class="data row0 col8" >MASS</td>
#       <td id="T_e1f1c_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_e1f1c_row0_col10" class="data row0 col10" >205.172.170.125</td>
#       <td id="T_e1f1c_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_e1f1c_row0_col12" class="data row0 col12" ></td>
#       <td id="T_e1f1c_row0_col13" class="data row0 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@205.172.170.125</td>
#       <td id="T_e1f1c_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_e1f1c_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_e1f1c_row1_col0" class="data row1 col0" >8e852cf0-2e52-4713-bdde-dbb62f372047</td>
#       <td id="T_e1f1c_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_e1f1c_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_e1f1c_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_e1f1c_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_e1f1c_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_e1f1c_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_e1f1c_row1_col7" class="data row1 col7" >ucsd-w1.fabric-testbed.net</td>
#       <td id="T_e1f1c_row1_col8" class="data row1 col8" >UCSD</td>
#       <td id="T_e1f1c_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_e1f1c_row1_col10" class="data row1 col10" >132.249.252.173</td>
#       <td id="T_e1f1c_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_e1f1c_row1_col12" class="data row1 col12" ></td>
#       <td id="T_e1f1c_row1_col13" class="data row1 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@132.249.252.173</td>
#       <td id="T_e1f1c_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_e1f1c_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ec09b caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_ec09b th {
#   text-align: left;
# }
# #T_ec09b tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ec09b tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ec09b .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ec09b_row0_col0, #T_ec09b_row0_col1, #T_ec09b_row0_col2, #T_ec09b_row0_col3, #T_ec09b_row0_col4, #T_ec09b_row0_col5, #T_ec09b_row0_col6, #T_ec09b_row1_col0, #T_ec09b_row1_col1, #T_ec09b_row1_col2, #T_ec09b_row1_col3, #T_ec09b_row1_col4, #T_ec09b_row1_col5, #T_ec09b_row1_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_ec09b_row0_col7, #T_ec09b_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_ec09b_row0_col8, #T_ec09b_row1_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_ec09b">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_ec09b_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_ec09b_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_ec09b_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_ec09b_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_ec09b_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_ec09b_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_ec09b_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_ec09b_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_ec09b_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ec09b_row0_col0" class="data row0 col0" >866987b0-c977-400e-ad5a-117d7c571bcf</td>
#       <td id="T_ec09b_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_ec09b_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_ec09b_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_ec09b_row0_col4" class="data row0 col4" >MASS</td>
#       <td id="T_ec09b_row0_col5" class="data row0 col5" >10.131.130.0/24</td>
#       <td id="T_ec09b_row0_col6" class="data row0 col6" >10.131.130.1</td>
#       <td id="T_ec09b_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_ec09b_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_ec09b_row1_col0" class="data row1 col0" >0cb83e62-d9a9-4f0b-8301-15a0d50d3699</td>
#       <td id="T_ec09b_row1_col1" class="data row1 col1" >net2</td>
#       <td id="T_ec09b_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_ec09b_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_ec09b_row1_col4" class="data row1 col4" >UCSD</td>
#       <td id="T_ec09b_row1_col5" class="data row1 col5" >10.134.132.0/24</td>
#       <td id="T_ec09b_row1_col6" class="data row1 col6" >10.134.132.1</td>
#       <td id="T_ec09b_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_ec09b_row1_col8" class="data row1 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5b380 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_5b380 th {
#   text-align: left;
# }
# #T_5b380 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5b380 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5b380 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5b380_row0_col0, #T_5b380_row0_col1, #T_5b380_row0_col2, #T_5b380_row0_col3, #T_5b380_row0_col4, #T_5b380_row0_col5, #T_5b380_row0_col6, #T_5b380_row0_col7, #T_5b380_row0_col8, #T_5b380_row0_col9, #T_5b380_row1_col0, #T_5b380_row1_col1, #T_5b380_row1_col2, #T_5b380_row1_col3, #T_5b380_row1_col4, #T_5b380_row1_col5, #T_5b380_row1_col6, #T_5b380_row1_col7, #T_5b380_row1_col8, #T_5b380_row1_col9 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5b380">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_5b380_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_5b380_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_5b380_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_5b380_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_5b380_level0_col4" class="col_heading level0 col4" >Mode</th>
#       <th id="T_5b380_level0_col5" class="col_heading level0 col5" >VLAN</th>
#       <th id="T_5b380_level0_col6" class="col_heading level0 col6" >MAC</th>
#       <th id="T_5b380_level0_col7" class="col_heading level0 col7" >Physical Device</th>
#       <th id="T_5b380_level0_col8" class="col_heading level0 col8" >Device</th>
#       <th id="T_5b380_level0_col9" class="col_heading level0 col9" >IP Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b380_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_5b380_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_5b380_row0_col2" class="data row0 col2" >net1</td>
#       <td id="T_5b380_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_5b380_row0_col4" class="data row0 col4" >auto</td>
#       <td id="T_5b380_row0_col5" class="data row0 col5" ></td>
#       <td id="T_5b380_row0_col6" class="data row0 col6" >02:00:03:10:A1:2F</td>
#       <td id="T_5b380_row0_col7" class="data row0 col7" >eth1</td>
#       <td id="T_5b380_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_5b380_row0_col9" class="data row0 col9" >10.131.130.2</td>
#     </tr>
#     <tr>
#       <td id="T_5b380_row1_col0" class="data row1 col0" >Node2-nic1-p1</td>
#       <td id="T_5b380_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_5b380_row1_col2" class="data row1 col2" >net2</td>
#       <td id="T_5b380_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_5b380_row1_col4" class="data row1 col4" >auto</td>
#       <td id="T_5b380_row1_col5" class="data row1 col5" ></td>
#       <td id="T_5b380_row1_col6" class="data row1 col6" >06:EF:18:C6:68:D7</td>
#       <td id="T_5b380_row1_col7" class="data row1 col7" >eth1</td>
#       <td id="T_5b380_row1_col8" class="data row1 col8" >eth1</td>
#       <td id="T_5b380_row1_col9" class="data row1 col9" >10.134.132.2</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 410 seconds

# %%
slice = fablib.get_slice(slice_name)
net1 = slice.get_network('net1')
# Node1
node1 = slice.add_node(name='new1', site=site1).enable_docker()
node1.set_rocky_repo(IPv4Address('10.133.130.2'))
iface1 = node1.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface1.set_mode('auto')
net1.add_interface(iface1)
node1.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net1.get_gateway())

slice.submit()
# Out:
# Retry: 5, Time: 679 sec
# <style type="text/css">
# #T_d6ed5 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_d6ed5 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d6ed5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_d6ed5_row0_col0, #T_d6ed5_row0_col1, #T_d6ed5_row1_col0, #T_d6ed5_row1_col1, #T_d6ed5_row2_col0, #T_d6ed5_row2_col1, #T_d6ed5_row3_col0, #T_d6ed5_row3_col1, #T_d6ed5_row4_col0, #T_d6ed5_row4_col1, #T_d6ed5_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_d6ed5_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_d6ed5">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d6ed5_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_d6ed5_row0_col1" class="data row0 col1" >bdcc57f6-f621-4844-b6da-7f65317d0683</td>
#     </tr>
#     <tr>
#       <td id="T_d6ed5_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_d6ed5_row1_col1" class="data row1 col1" >MySlice100</td>
#     </tr>
#     <tr>
#       <td id="T_d6ed5_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_d6ed5_row2_col1" class="data row2 col1" >2023-03-02 21:43:51 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_d6ed5_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_d6ed5_row3_col1" class="data row3 col1" >2023-03-01 21:43:53 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_d6ed5_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_d6ed5_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_d6ed5_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_d6ed5_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6e789 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_6e789 th {
#   text-align: left;
# }
# #T_6e789 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6e789 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6e789 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6e789_row0_col0, #T_6e789_row0_col1, #T_6e789_row0_col2, #T_6e789_row0_col3, #T_6e789_row0_col4, #T_6e789_row0_col5, #T_6e789_row0_col6, #T_6e789_row0_col7, #T_6e789_row0_col8, #T_6e789_row0_col9, #T_6e789_row0_col10, #T_6e789_row0_col13, #T_6e789_row0_col14, #T_6e789_row0_col15, #T_6e789_row1_col0, #T_6e789_row1_col1, #T_6e789_row1_col2, #T_6e789_row1_col3, #T_6e789_row1_col4, #T_6e789_row1_col5, #T_6e789_row1_col6, #T_6e789_row1_col7, #T_6e789_row1_col8, #T_6e789_row1_col9, #T_6e789_row1_col10, #T_6e789_row1_col13, #T_6e789_row1_col14, #T_6e789_row1_col15, #T_6e789_row2_col0, #T_6e789_row2_col1, #T_6e789_row2_col2, #T_6e789_row2_col3, #T_6e789_row2_col4, #T_6e789_row2_col5, #T_6e789_row2_col6, #T_6e789_row2_col7, #T_6e789_row2_col8, #T_6e789_row2_col9, #T_6e789_row2_col10, #T_6e789_row2_col13, #T_6e789_row2_col14, #T_6e789_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_6e789_row0_col11, #T_6e789_row1_col11, #T_6e789_row2_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_6e789_row0_col12, #T_6e789_row1_col12, #T_6e789_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_6e789">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_6e789_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_6e789_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_6e789_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_6e789_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_6e789_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_6e789_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_6e789_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_6e789_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_6e789_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_6e789_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_6e789_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_6e789_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_6e789_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_6e789_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_6e789_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_6e789_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6e789_row0_col0" class="data row0 col0" >1f4b5a7d-f721-4eb1-9b1c-98a7658c7f46</td>
#       <td id="T_6e789_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_6e789_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_6e789_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_6e789_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_6e789_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_6e789_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_6e789_row0_col7" class="data row0 col7" >mass-w3.fabric-testbed.net</td>
#       <td id="T_6e789_row0_col8" class="data row0 col8" >MASS</td>
#       <td id="T_6e789_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_6e789_row0_col10" class="data row0 col10" >205.172.170.125</td>
#       <td id="T_6e789_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_6e789_row0_col12" class="data row0 col12" ></td>
#       <td id="T_6e789_row0_col13" class="data row0 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@205.172.170.125</td>
#       <td id="T_6e789_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_6e789_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_6e789_row1_col0" class="data row1 col0" >8e852cf0-2e52-4713-bdde-dbb62f372047</td>
#       <td id="T_6e789_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_6e789_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_6e789_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_6e789_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_6e789_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_6e789_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_6e789_row1_col7" class="data row1 col7" >ucsd-w1.fabric-testbed.net</td>
#       <td id="T_6e789_row1_col8" class="data row1 col8" >UCSD</td>
#       <td id="T_6e789_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_6e789_row1_col10" class="data row1 col10" >132.249.252.173</td>
#       <td id="T_6e789_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_6e789_row1_col12" class="data row1 col12" ></td>
#       <td id="T_6e789_row1_col13" class="data row1 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@132.249.252.173</td>
#       <td id="T_6e789_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_6e789_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_6e789_row2_col0" class="data row2 col0" >a6e8a7ab-98dd-4832-9144-546878282fee</td>
#       <td id="T_6e789_row2_col1" class="data row2 col1" >new1</td>
#       <td id="T_6e789_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_6e789_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_6e789_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_6e789_row2_col5" class="data row2 col5" >default_rocky_8</td>
#       <td id="T_6e789_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_6e789_row2_col7" class="data row2 col7" >mass-w3.fabric-testbed.net</td>
#       <td id="T_6e789_row2_col8" class="data row2 col8" >MASS</td>
#       <td id="T_6e789_row2_col9" class="data row2 col9" >rocky</td>
#       <td id="T_6e789_row2_col10" class="data row2 col10" >205.172.170.123</td>
#       <td id="T_6e789_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_6e789_row2_col12" class="data row2 col12" ></td>
#       <td id="T_6e789_row2_col13" class="data row2 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@205.172.170.123</td>
#       <td id="T_6e789_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_6e789_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b5f13 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_b5f13 th {
#   text-align: left;
# }
# #T_b5f13 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b5f13 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b5f13 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b5f13_row0_col0, #T_b5f13_row0_col1, #T_b5f13_row0_col2, #T_b5f13_row0_col3, #T_b5f13_row0_col4, #T_b5f13_row0_col5, #T_b5f13_row0_col6, #T_b5f13_row1_col0, #T_b5f13_row1_col1, #T_b5f13_row1_col2, #T_b5f13_row1_col3, #T_b5f13_row1_col4, #T_b5f13_row1_col5, #T_b5f13_row1_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_b5f13_row0_col7, #T_b5f13_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_b5f13_row0_col8, #T_b5f13_row1_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_b5f13">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_b5f13_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b5f13_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_b5f13_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_b5f13_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_b5f13_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_b5f13_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_b5f13_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_b5f13_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_b5f13_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b5f13_row0_col0" class="data row0 col0" >866987b0-c977-400e-ad5a-117d7c571bcf</td>
#       <td id="T_b5f13_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_b5f13_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_b5f13_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_b5f13_row0_col4" class="data row0 col4" >MASS</td>
#       <td id="T_b5f13_row0_col5" class="data row0 col5" >10.131.130.0/24</td>
#       <td id="T_b5f13_row0_col6" class="data row0 col6" >10.131.130.1</td>
#       <td id="T_b5f13_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_b5f13_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_b5f13_row1_col0" class="data row1 col0" >0cb83e62-d9a9-4f0b-8301-15a0d50d3699</td>
#       <td id="T_b5f13_row1_col1" class="data row1 col1" >net2</td>
#       <td id="T_b5f13_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_b5f13_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_b5f13_row1_col4" class="data row1 col4" >UCSD</td>
#       <td id="T_b5f13_row1_col5" class="data row1 col5" >10.134.132.0/24</td>
#       <td id="T_b5f13_row1_col6" class="data row1 col6" >10.134.132.1</td>
#       <td id="T_b5f13_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_b5f13_row1_col8" class="data row1 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7e7f8 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_7e7f8 th {
#   text-align: left;
# }
# #T_7e7f8 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7e7f8 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7e7f8 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7e7f8_row0_col0, #T_7e7f8_row0_col1, #T_7e7f8_row0_col2, #T_7e7f8_row0_col3, #T_7e7f8_row0_col4, #T_7e7f8_row0_col5, #T_7e7f8_row0_col6, #T_7e7f8_row0_col7, #T_7e7f8_row0_col8, #T_7e7f8_row0_col9, #T_7e7f8_row1_col0, #T_7e7f8_row1_col1, #T_7e7f8_row1_col2, #T_7e7f8_row1_col3, #T_7e7f8_row1_col4, #T_7e7f8_row1_col5, #T_7e7f8_row1_col6, #T_7e7f8_row1_col7, #T_7e7f8_row1_col8, #T_7e7f8_row1_col9, #T_7e7f8_row2_col0, #T_7e7f8_row2_col1, #T_7e7f8_row2_col2, #T_7e7f8_row2_col3, #T_7e7f8_row2_col4, #T_7e7f8_row2_col5, #T_7e7f8_row2_col6, #T_7e7f8_row2_col7, #T_7e7f8_row2_col8, #T_7e7f8_row2_col9 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_7e7f8">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_7e7f8_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_7e7f8_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_7e7f8_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_7e7f8_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_7e7f8_level0_col4" class="col_heading level0 col4" >Mode</th>
#       <th id="T_7e7f8_level0_col5" class="col_heading level0 col5" >VLAN</th>
#       <th id="T_7e7f8_level0_col6" class="col_heading level0 col6" >MAC</th>
#       <th id="T_7e7f8_level0_col7" class="col_heading level0 col7" >Physical Device</th>
#       <th id="T_7e7f8_level0_col8" class="col_heading level0 col8" >Device</th>
#       <th id="T_7e7f8_level0_col9" class="col_heading level0 col9" >IP Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7e7f8_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_7e7f8_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_7e7f8_row0_col2" class="data row0 col2" >net1</td>
#       <td id="T_7e7f8_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_7e7f8_row0_col4" class="data row0 col4" >auto</td>
#       <td id="T_7e7f8_row0_col5" class="data row0 col5" ></td>
#       <td id="T_7e7f8_row0_col6" class="data row0 col6" >02:00:03:10:A1:2F</td>
#       <td id="T_7e7f8_row0_col7" class="data row0 col7" >eth1</td>
#       <td id="T_7e7f8_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_7e7f8_row0_col9" class="data row0 col9" >10.131.130.3</td>
#     </tr>
#     <tr>
#       <td id="T_7e7f8_row1_col0" class="data row1 col0" >Node2-nic1-p1</td>
#       <td id="T_7e7f8_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_7e7f8_row1_col2" class="data row1 col2" >net2</td>
#       <td id="T_7e7f8_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_7e7f8_row1_col4" class="data row1 col4" >auto</td>
#       <td id="T_7e7f8_row1_col5" class="data row1 col5" ></td>
#       <td id="T_7e7f8_row1_col6" class="data row1 col6" >06:EF:18:C6:68:D7</td>
#       <td id="T_7e7f8_row1_col7" class="data row1 col7" >eth1</td>
#       <td id="T_7e7f8_row1_col8" class="data row1 col8" >eth1</td>
#       <td id="T_7e7f8_row1_col9" class="data row1 col9" >10.134.132.2</td>
#     </tr>
#     <tr>
#       <td id="T_7e7f8_row2_col0" class="data row2 col0" >new1-nic1-p1</td>
#       <td id="T_7e7f8_row2_col1" class="data row2 col1" >new1</td>
#       <td id="T_7e7f8_row2_col2" class="data row2 col2" >net1</td>
#       <td id="T_7e7f8_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_7e7f8_row2_col4" class="data row2 col4" >auto</td>
#       <td id="T_7e7f8_row2_col5" class="data row2 col5" ></td>
#       <td id="T_7e7f8_row2_col6" class="data row2 col6" >02:CD:B5:61:5B:9E</td>
#       <td id="T_7e7f8_row2_col7" class="data row2 col7" >eth1</td>
#       <td id="T_7e7f8_row2_col8" class="data row2 col8" >eth1</td>
#       <td id="T_7e7f8_row2_col9" class="data row2 col9" >10.131.130.2</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 686 seconds
# 'bdcc57f6-f621-4844-b6da-7f65317d0683'

# %%
import json
#for node in slice.get_nodes():
#    print(json.dumps(node.get_user_data(), indent=4))

for iface in slice.get_interfaces():
    print(json.dumps(iface
                     .get_user_data(), indent=4))
# Out:
# {
#     "fablib_data": {
#         "mode": "auto",
#         "base_dev": "eth1",
#         "dev": "eth1",
#         "configured": "True",
#         "addr": "10.131.130.2"
#     }
# }
# {
#     "fablib_data": {
#         "mode": "auto",
#         "base_dev": "eth1",
#         "dev": "eth1",
#         "configured": "True",
#         "addr": "10.134.132.2"
#     }
# }

# %% [markdown]
# ## Run the Experiment
#
# We will find the ping round trip time for this pair of sites.  Your experiment should be more interesting!

# %%
for node in slice.get_nodes():
    print(node.get_name())
    
    directory = "/etc/yum.repos.d/"
    
    string_to_comment = "mirrorlist"
    cmd = f"sudo bash -c 'for file in {directory}*; do sed -i \"/^{string_to_comment}/s/^/# /g\" \"$file\"; done'"
    node.execute(cmd)

    string_to_uncomment = "#baseurl"
    cmd = f"sudo bash -c 'for file in {directory}*; do sed -i \"/^{string_to_uncomment}/s/^#//g\" \"$file\"; done'"
    node.execute(cmd)
    
    old_string = "dl.rockylinux.org"
    new_string = "10.133.130.2" # current fabnetv4 ip of my rocky repo mirror
    cmd = f"sudo bash -c 'for file in \"{directory}\"*; do sed -i \"s/{old_string}/{new_string}/g\" \"$file\"; done'"
    node.execute(cmd)

    #node.execute(f"sudo sh -c \"echo 10.133.130.2 dl.rockylinux.org >> /etc/hosts \" ; ")
    #echo '10.133.130.2 dl.rockylinux.org >> /etc/hosts'

# %%
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)        
node2 = slice.get_node(name=node2_name)           

node2_addr = node2.get_interface(network_name=network2_name).get_ip_addr()

stdout, stderr = node1.execute(f'ping -c 5 {node2_addr}')

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
slice.delete()
