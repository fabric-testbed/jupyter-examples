# %% [markdown]
# # Creating FABnet IPv4 Network
#
# FABRIC provides a pair of layer 3 IP networking services across every FABRIC site (FABnetv4 and FABnetv6). You can think of this service as a private internet that connects experiments across the testbed using FABRIC's high-performance network links.
#
# This notebook describes how to use the FABnetv4 service which is FABRIC's private IPv4 internet.

# %% [markdown]
# ## Import the FABlib Library

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_793a6 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_793a6 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_793a6 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_793a6_row0_col0, #T_793a6_row0_col1, #T_793a6_row1_col0, #T_793a6_row1_col1, #T_793a6_row2_col0, #T_793a6_row2_col1, #T_793a6_row3_col0, #T_793a6_row3_col1, #T_793a6_row4_col0, #T_793a6_row4_col1, #T_793a6_row5_col0, #T_793a6_row5_col1, #T_793a6_row6_col0, #T_793a6_row6_col1, #T_793a6_row7_col0, #T_793a6_row7_col1, #T_793a6_row8_col0, #T_793a6_row8_col1, #T_793a6_row9_col0, #T_793a6_row9_col1, #T_793a6_row10_col0, #T_793a6_row10_col1, #T_793a6_row11_col0, #T_793a6_row11_col1, #T_793a6_row12_col0, #T_793a6_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_793a6">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_793a6_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_793a6_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_793a6_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_793a6_row2_col1" class="data row2 col1" >/home/fabric/work/fabric_config/tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_793a6_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_793a6_row4_col1" class="data row4 col1" >pruth_0031379841</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_793a6_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_793a6_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_793a6_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_793a6_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_793a6_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_793a6_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_793a6_row11_col1" class="data row11 col1" >/home/fabric/work/logs/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_793a6_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_793a6_row12_col1" class="data row12 col1" >DEBUG</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates two nodes, on different sites, with basic NICs connected to FABRIC's FABnetv4 internet.
#
# Two nodes are created and one NIC component is added to each node.  This example uses components of model `NIC_Basic` which are SR-IOV Virtual Function on a 100 Gpbs Mellanox ConnectX-6 PCI device. The VF is accessed by the node via PCI passthrough. Other NIC models are listed below. When using dedicated PCI devices the whole physical device is allocated to one node and the device is accessed by the node using PCI passthrough. Calling the `get_interfaces()` method on a component will return a list of interfaces. Many dedicated NIC components may have more than one port.  Either port can be connected to the network.
#
# Next, add a separate `l3network` for each site and pass the list of interfaces on that site that you want to connect to FABnetv4. All interfaces passed to `l3network` must be on the same site and each network will be placed on that site.  By default, a node is put on a random site.  If you want to ensure that your nodes are all on different sites you can specify the name of the sites in the `add_node` methode.  You can use the `fablib.get_random_site()` method to get a set of random site names that guarantee that the sites are different.
#
#
# NIC component models options:
# - NIC_Basic: 100 Gbps Mellanox ConnectX-6 SR-IOV VF (1 Port)
# - NIC_ConnectX_5: 25 Gbps Dedicated Mellanox ConnectX-5 PCI Device (2 Ports)
# - NIC_ConnectX_6: 100 Gbps Dedicated Mellanox ConnectX-6 PCI Device (2 Ports)

# %%
slice_name = 'MySliceXXXXX2'
[site1,site2] = fablib.get_random_sites(count=2)
print(f"Sites: {site1}, {site2}")

node1_name = 'Node1'
node2_name = 'Node2'

network1_name='net1'
network2_name='net2'
# Out:
# Sites: MICH, CLEM

# %%
#Create Slice
slice = fablib.new_slice(name=slice_name)

# Networks
net1 = slice.add_l3network(name=network1_name, type='IPv4')
net2 = slice.add_l3network(name=network2_name, type='IPv4')

# Node1
node1 = slice.add_node(name=node1_name, site=site1).enable_docker()
node1.set_rocky_repo(IPv4Address('10.133.130.2'))
iface1 = node1.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface1.set_mode('auto')
net1.add_interface(iface1)
node1.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net1.get_gateway())

# Node2
node2 = slice.add_node(name=node2_name, site=site2).enable_docker()
node2.set_rocky_repo(IPv4Address('10.133.130.2'))
iface2  = node2.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface2.set_mode('auto')
net2.add_interface(iface2)
node2.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net2.get_gateway())

#Submit Slice Request
slice.submit();
# Out:
# Retry: 12, Time: 443 sec
# <style type="text/css">
# #T_87590 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_87590 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_87590 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_87590_row0_col0, #T_87590_row0_col1, #T_87590_row1_col0, #T_87590_row1_col1, #T_87590_row2_col0, #T_87590_row2_col1, #T_87590_row3_col0, #T_87590_row3_col1, #T_87590_row4_col0, #T_87590_row4_col1, #T_87590_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_87590_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_87590">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87590_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_87590_row0_col1" class="data row0 col1" >4b9226db-6e59-4580-b5ff-1679532b4479</td>
#     </tr>
#     <tr>
#       <td id="T_87590_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_87590_row1_col1" class="data row1 col1" >MySliceXXXXX2</td>
#     </tr>
#     <tr>
#       <td id="T_87590_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_87590_row2_col1" class="data row2 col1" >2023-02-27 18:04:17 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_87590_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_87590_row3_col1" class="data row3 col1" >2023-02-26 18:04:18 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_87590_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_87590_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_87590_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_87590_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c92cd caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_c92cd th {
#   text-align: left;
# }
# #T_c92cd tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_c92cd tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_c92cd .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_c92cd_row0_col0, #T_c92cd_row0_col1, #T_c92cd_row0_col2, #T_c92cd_row0_col3, #T_c92cd_row0_col4, #T_c92cd_row0_col5, #T_c92cd_row0_col6, #T_c92cd_row0_col7, #T_c92cd_row0_col8, #T_c92cd_row0_col9, #T_c92cd_row0_col10, #T_c92cd_row0_col13, #T_c92cd_row0_col14, #T_c92cd_row0_col15, #T_c92cd_row1_col0, #T_c92cd_row1_col1, #T_c92cd_row1_col2, #T_c92cd_row1_col3, #T_c92cd_row1_col4, #T_c92cd_row1_col5, #T_c92cd_row1_col6, #T_c92cd_row1_col7, #T_c92cd_row1_col8, #T_c92cd_row1_col9, #T_c92cd_row1_col10, #T_c92cd_row1_col13, #T_c92cd_row1_col14, #T_c92cd_row1_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_c92cd_row0_col11, #T_c92cd_row1_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_c92cd_row0_col12, #T_c92cd_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_c92cd">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_c92cd_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_c92cd_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_c92cd_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_c92cd_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_c92cd_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_c92cd_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_c92cd_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_c92cd_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_c92cd_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_c92cd_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_c92cd_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_c92cd_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_c92cd_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_c92cd_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_c92cd_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_c92cd_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c92cd_row0_col0" class="data row0 col0" >cbe29724-1fd6-42d3-bc19-257dc21987b5</td>
#       <td id="T_c92cd_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_c92cd_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_c92cd_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_c92cd_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_c92cd_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_c92cd_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_c92cd_row0_col7" class="data row0 col7" >mich-w1.fabric-testbed.net</td>
#       <td id="T_c92cd_row0_col8" class="data row0 col8" >MICH</td>
#       <td id="T_c92cd_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_c92cd_row0_col10" class="data row0 col10" >2607:f018:110:11:f816:3eff:feac:d9e3</td>
#       <td id="T_c92cd_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_c92cd_row0_col12" class="data row0 col12" ></td>
#       <td id="T_c92cd_row0_col13" class="data row0 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2607:f018:110:11:f816:3eff:feac:d9e3</td>
#       <td id="T_c92cd_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_c92cd_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_c92cd_row1_col0" class="data row1 col0" >ca02d0bd-b368-4000-aa9a-ea6d451a69c5</td>
#       <td id="T_c92cd_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_c92cd_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_c92cd_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_c92cd_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_c92cd_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_c92cd_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_c92cd_row1_col7" class="data row1 col7" >clem-w2.fabric-testbed.net</td>
#       <td id="T_c92cd_row1_col8" class="data row1 col8" >CLEM</td>
#       <td id="T_c92cd_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_c92cd_row1_col10" class="data row1 col10" >2620:103:a006:12:f816:3eff:fe04:37fb</td>
#       <td id="T_c92cd_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_c92cd_row1_col12" class="data row1 col12" ></td>
#       <td id="T_c92cd_row1_col13" class="data row1 col13" >ssh -t -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2620:103:a006:12:f816:3eff:fe04:37fb</td>
#       <td id="T_c92cd_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_c92cd_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4c979 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_4c979 th {
#   text-align: left;
# }
# #T_4c979 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4c979 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4c979 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4c979_row0_col0, #T_4c979_row0_col1, #T_4c979_row0_col2, #T_4c979_row0_col3, #T_4c979_row0_col4, #T_4c979_row0_col5, #T_4c979_row0_col6, #T_4c979_row1_col0, #T_4c979_row1_col1, #T_4c979_row1_col2, #T_4c979_row1_col3, #T_4c979_row1_col4, #T_4c979_row1_col5, #T_4c979_row1_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_4c979_row0_col7, #T_4c979_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_4c979_row0_col8, #T_4c979_row1_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_4c979">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_4c979_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_4c979_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_4c979_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_4c979_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_4c979_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_4c979_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_4c979_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_4c979_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_4c979_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4c979_row0_col0" class="data row0 col0" >e189d46a-2004-4bc6-b78d-92ad74610602</td>
#       <td id="T_4c979_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_4c979_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_4c979_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_4c979_row0_col4" class="data row0 col4" >MICH</td>
#       <td id="T_4c979_row0_col5" class="data row0 col5" >10.131.1.0/24</td>
#       <td id="T_4c979_row0_col6" class="data row0 col6" >10.131.1.1</td>
#       <td id="T_4c979_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_4c979_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_4c979_row1_col0" class="data row1 col0" >94a9b6eb-d1ea-489d-82ac-9fc14dc6f9d4</td>
#       <td id="T_4c979_row1_col1" class="data row1 col1" >net2</td>
#       <td id="T_4c979_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_4c979_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_4c979_row1_col4" class="data row1 col4" >CLEM</td>
#       <td id="T_4c979_row1_col5" class="data row1 col5" >10.136.1.0/24</td>
#       <td id="T_4c979_row1_col6" class="data row1 col6" >10.136.1.1</td>
#       <td id="T_4c979_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_4c979_row1_col8" class="data row1 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_35c67 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_35c67 th {
#   text-align: left;
# }
# #T_35c67 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_35c67 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_35c67 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_35c67_row0_col0, #T_35c67_row0_col1, #T_35c67_row0_col2, #T_35c67_row0_col3, #T_35c67_row0_col4, #T_35c67_row0_col5, #T_35c67_row0_col6, #T_35c67_row0_col7, #T_35c67_row0_col8, #T_35c67_row0_col9, #T_35c67_row1_col0, #T_35c67_row1_col1, #T_35c67_row1_col2, #T_35c67_row1_col3, #T_35c67_row1_col4, #T_35c67_row1_col5, #T_35c67_row1_col6, #T_35c67_row1_col7, #T_35c67_row1_col8, #T_35c67_row1_col9 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_35c67">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_35c67_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_35c67_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_35c67_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_35c67_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_35c67_level0_col4" class="col_heading level0 col4" >Mode</th>
#       <th id="T_35c67_level0_col5" class="col_heading level0 col5" >VLAN</th>
#       <th id="T_35c67_level0_col6" class="col_heading level0 col6" >MAC</th>
#       <th id="T_35c67_level0_col7" class="col_heading level0 col7" >Physical Device</th>
#       <th id="T_35c67_level0_col8" class="col_heading level0 col8" >Device</th>
#       <th id="T_35c67_level0_col9" class="col_heading level0 col9" >IP Address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_35c67_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_35c67_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_35c67_row0_col2" class="data row0 col2" >net1</td>
#       <td id="T_35c67_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_35c67_row0_col4" class="data row0 col4" >auto</td>
#       <td id="T_35c67_row0_col5" class="data row0 col5" ></td>
#       <td id="T_35c67_row0_col6" class="data row0 col6" >02:B3:F5:DB:97:7C</td>
#       <td id="T_35c67_row0_col7" class="data row0 col7" >eth1</td>
#       <td id="T_35c67_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_35c67_row0_col9" class="data row0 col9" >10.131.1.2</td>
#     </tr>
#     <tr>
#       <td id="T_35c67_row1_col0" class="data row1 col0" >Node2-nic1-p1</td>
#       <td id="T_35c67_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_35c67_row1_col2" class="data row1 col2" >net2</td>
#       <td id="T_35c67_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_35c67_row1_col4" class="data row1 col4" >auto</td>
#       <td id="T_35c67_row1_col5" class="data row1 col5" ></td>
#       <td id="T_35c67_row1_col6" class="data row1 col6" >02:7B:2E:86:34:1B</td>
#       <td id="T_35c67_row1_col7" class="data row1 col7" >eth1</td>
#       <td id="T_35c67_row1_col8" class="data row1 col8" >eth1</td>
#       <td id="T_35c67_row1_col9" class="data row1 col9" >10.136.1.2</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 450 seconds

# %% [markdown]
# ## Run the Experiment
#
# We will find the ping round trip time for this pair of sites.  Your experiment should be more interesting!

# %%
for node in slice.get_nodes():
    print(node.get_name())
    
    directory = "/etc/yum.repos.d/"
    
    string_to_comment = "mirrorlist"
    cmd = f"sudo bash -c 'for file in {directory}*; do sed -i \"/^{string_to_comment}/s/^/# /g\" \"$file\"; done'"
    node.execute(cmd)

    string_to_uncomment = "#baseurl"
    cmd = f"sudo bash -c 'for file in {directory}*; do sed -i \"/^{string_to_uncomment}/s/^#//g\" \"$file\"; done'"
    node.execute(cmd)
    
    old_string = "dl.rockylinux.org"
    new_string = "10.133.130.2" # current fabnetv4 ip of my rocky repo mirror
    cmd = f"sudo bash -c 'for file in \"{directory}\"*; do sed -i \"s/{old_string}/{new_string}/g\" \"$file\"; done'"
    node.execute(cmd)

    #node.execute(f"sudo sh -c \"echo 10.133.130.2 dl.rockylinux.org >> /etc/hosts \" ; ")
    #echo '10.133.130.2 dl.rockylinux.org >> /etc/hosts'

# %%
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)        
node2 = slice.get_node(name=node2_name)           

node2_addr = node2.get_interface(network_name=network2_name).get_ip_addr()

stdout, stderr = node1.execute(f'ping -c 5 {node2_addr}')

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
slice.delete()
