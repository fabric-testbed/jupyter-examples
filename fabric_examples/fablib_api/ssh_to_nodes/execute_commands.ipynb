# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Execute Commands on FABRIC Nodes
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **What this notebook covers:** Once you have provisioned nodes on FABRIC, you need to run commands on them to configure software, launch experiments, and collect results. This notebook demonstrates several ways to execute commands on FABRIC nodes -- from basic single-command execution to parallel threaded execution across multiple nodes.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Generate the **SSH command** for terminal access to a node
# 2. Execute commands programmatically using `node.execute()`
# 3. Capture and process **stdout** and **stderr** output
# 4. Suppress live output with the `quiet` parameter
# 5. Log command output to a **file** for later review
# 6. Run commands on multiple nodes **in parallel** using `execute_thread()`
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you should:
#
# 1. Complete the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Successfully run the [Hello, FABRIC](../hello_fabric/hello_fabric.ipynb) notebook
#
# **Tip:** All `execute()` commands must be **non-interactive** (no prompts for user input). If your command requires interaction (e.g., `apt install` without `-y`), it will hang.
#
# </div>

# %% [markdown]
# ## Background: How Remote Execution Works
#
# When you call `node.execute()`, FABlib opens an SSH connection through the FABRIC **bastion host** to your VM and runs the command. The bastion host acts as a secure gateway -- you never connect directly to VMs.
#
#
# Key behaviors:
# - By default, output is printed **live** as the command runs
# - The method returns a tuple of `(stdout, stderr)` strings
# - Commands run as the default VM user (typically `ubuntu` or `rocky`)
# - Use `sudo` for privileged operations

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a single compute node with default resources.
#
# <img src="./figs/slice_topology.png" width="40%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration

# %%
# Import the FABlib library
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance
fablib = fablib_manager()

# Display current configuration (tokens, keys, project info)
fablib.show_config();

# %% [markdown]
# ---
#
# ## Step 2: Create a Slice with Two Nodes
#
# We create two nodes so we can later demonstrate parallel command execution.

# %%
# Define names for the slice and nodes
slice_name="MySlice"
node1_name="Node1"
node2_name="Node2"

# Create a new slice
slice = fablib.new_slice(name=slice_name)

# Add two nodes with default settings (random sites, 2 cores, 8 GB RAM)
slice.add_node(name=node1_name)
slice.add_node(name=node2_name)

# Submit the slice and wait for provisioning (~2-5 minutes)
slice.submit();

# %% [markdown]
# ---
#
# ## Step 3: Retrieve Node Objects
#
# After the slice is ready, retrieve references to the individual node objects. These objects provide the `execute()` method and other node-level operations.

# %%
# Retrieve the slice by name (useful if reconnecting in a later session)
slice = fablib.get_slice(slice_name)
slice.show()

# Get individual node objects by name
node1 = slice.get_node(name=node1_name)
node1.show()

node2 = slice.get_node(name=node2_name)
node2.show();

# %% [markdown]
# ---
#
# ## Step 4: Get the SSH Command for Terminal Access
#
# If you prefer to SSH into a node from a terminal (outside Jupyter), FABlib can generate the full SSH command for you. This is useful for interactive debugging sessions.
#
# <div class="fab-warning">
#
# **Tip:** If you are using the FABRIC JupyterHub, you may need to replace the `-F` path in the SSH command with `/home/fabric/work/fabric_config/ssh_config`.
#
# </div>

# %%
# Print the SSH command you would use from a terminal
print(f"SSH Command: {node1.get_ssh_command()}")

# %% [markdown]
# ---
#
# ## Step 5: Basic Command Execution
#
# The `node.execute()` method runs a shell command on your VM. By default it prints output live as it arrives, and returns the complete `(stdout, stderr)` tuple when finished.
#
# <div class="fab-danger">
#
# **Important:** The command must be **non-interactive**. Commands that prompt for user input (like `apt install` without `-y`) will hang indefinitely.
#
# </div>

# %%
# Run a ping command on Node1
# Output is printed live as each ping response arrives
command = 'ping -c 10 www.google.com'

stdout, stderr = node1.execute(command)

# %% [markdown]
# ---
#
# ## Step 6: Suppress Live Output with `quiet=True`
#
# Sometimes you want to capture the output without printing it live -- for example, when processing the result programmatically. Set `quiet=True` to suppress the live output.

# %%
# Run the same command but suppress live output
command = 'ping -c 10 www.google.com'

# quiet=True prevents output from being printed as it arrives
stdout, stderr = node1.execute(command, quiet=True)

# Now print the captured output manually
print(f"stdout: {stdout}")
print(f"stderr: {stderr}")

# %% [markdown]
# ---
#
# ## Step 7: Log Output to a File
#
# Use the `output_file` parameter to append command output to a local file as it is generated. This is especially useful for logging the configuration of nodes during automated setup.

# %%
# Run a command and log output to a file in the same directory as this notebook
command = 'ping -c 10 www.google.com'

# output_file='node1.log' appends stdout to the specified file
stdout, stderr = node1.execute(command, output_file='node1.log')

# %%
# Verify the log file was created with the command output
# !cat node1.log

# %% [markdown]
# ---
#
# ## Step 8: Parallel Execution with Threads
#
# When you need to configure or run commands on multiple nodes simultaneously, use `node.execute_thread()`. This starts the command in a background thread and returns a future object. Call `.result()` on the future to block until the command completes and retrieve the output.
#
#
# <div class="fab-warning">
#
# **Tip:** Use a unique `output_file` for each thread so you can monitor progress of parallel operations in real time by watching the log files.
#
# </div>

# %%
command = 'ping -c 10 www.google.com'

# Start commands on both nodes simultaneously in background threads
# Each thread logs to its own file for independent monitoring
node1_thread = node1.execute_thread(command, output_file='node1.log')
node2_thread = node2.execute_thread(command, output_file='node2.log')

# Block until both threads complete and retrieve results
# .result() returns the same (stdout, stderr) tuple as execute()
stdout1, stderr1 = node1_thread.result()
stdout2, stderr2 = node2_thread.result()

# Print results from both nodes
print(f"stdout1: {stdout1}")
print(f"stderr1: {stderr1}")
print(f"stdout2: {stdout2}")
print(f"stderr2: {stderr2}")

# %%
# Review the log files from both parallel executions
# !cat node1.log

# !cat node2.log

# %% [markdown]
# ---
#
# ## Step 9: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. FABRIC is a shared resource -- leaving slices running unnecessarily prevents other researchers from using those resources.
#
# </div>

# %%
# Delete the slice and release all resources
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | `execute()` hangs indefinitely | Command is interactive (prompts for input) | Add `-y` flag or use non-interactive alternatives |
# | `Permission denied` on SSH | Bastion key not configured correctly | Verify your bastion private key path in `fabric_rc` |
# | `Connection refused` or timeout | Node is still booting or SSH not ready | Wait a moment and retry; use `slice.wait_ssh()` |
# | `stdout` is empty but command should produce output | Output went to `stderr` instead | Check the `stderr` return value |
# | Log file is empty | Command produced no stdout | Check if output went to stderr; also verify the file path |
# | Thread `.result()` raises an exception | SSH connection dropped during execution | Retry the command; check node health with `node.show()` |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `fablib.get_slice(name)` | Retrieve an existing slice by name | [get_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_slice) |
# | `slice.add_node(name)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `slice.submit()` | Submit the slice for provisioning | [submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit) |
# | `slice.show()` | Display slice attributes | [show](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.show) |
# | `slice.get_node(name)` | Get a specific node by name | [get_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.get_node) |
# | `node.show()` | Display node attributes | [show](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.show) |
# | `node.get_ssh_command()` | Get the SSH command string for terminal access | [get_ssh_command](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.get_ssh_command) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `node.execute_thread(command)` | Execute a command in a background thread | [execute_thread](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute_thread) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you can execute commands on nodes, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Upload/Download Files** | [upload_and_execute](../ssh_to_nodes/upload_and_execute.ipynb) | Transfer files to and from FABRIC nodes |
# | **Customizing Nodes** | [customizing_nodes](../customizing_nodes/customizing_nodes.ipynb) | Set site, cores, RAM, disk, and OS image |
# | **Local Disk** | [local_disk](../local_disk/local_disk.ipynb) | Customize and compare local disk sizes |
# | **Networking** | [FABnet IPv4 (auto)](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb) | Connect nodes across sites with Layer 3 networking |
# | **GPUs** | [fabric_gpu](../fabric_all_gpus/fabric_gpu.ipynb) | Use NVIDIA GPUs (T4, RTX6000, A30, A40) |
