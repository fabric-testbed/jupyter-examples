# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Sub-Interfaces over Dedicated Network Interface Cards
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **What this notebook does:** Demonstrates how to create **sub-interfaces** (VLAN-tagged virtual interfaces) on dedicated NIC cards (`NIC_ConnectX_5` or `NIC_ConnectX_6`). A single physical NIC port is split into multiple virtual interfaces, each connected to a different network. This example connects sub-interfaces to both a **FABnet IPv4** (Layer 3) network and a **Layer 2 wide-area** network simultaneously.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Understand what sub-interfaces are and when to use them
# 2. Create VLAN-tagged sub-interfaces on a dedicated NIC using `add_sub_interface()`
# 3. Connect different sub-interfaces to different network types (Layer 2 and Layer 3)
# 4. Use a single physical NIC port for multiple isolated network connections
# 5. Verify connectivity through each sub-interface independently
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Run the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be familiar with FABnet -- see [FABnet IPv4 Auto](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb)
# 3. Be familiar with Layer 2 networks -- see [L2 Network notebooks](../create_l2network_basic/create_l2network_basic.ipynb)
#
# **Tip:** Sub-interfaces require **dedicated** NIC cards (`NIC_ConnectX_5` or `NIC_ConnectX_6`). They do **not** work with `NIC_Basic` (SR-IOV VF) interfaces.
#
# </div>

# %% [markdown]
# ## Background: What are Sub-Interfaces?
#
# A **sub-interface** is a virtual network interface created on top of a physical NIC port, tagged with a specific **VLAN ID**. This allows a single physical port to carry traffic for multiple isolated networks simultaneously.
#
# Sub-interfaces are useful when:
# - You need multiple network connections but have limited NIC slots
# - You want to connect to both Layer 2 and Layer 3 networks from the same NIC
# - You need VLAN isolation between different traffic types
#
#
# Each sub-interface gets its own VLAN tag and can be connected to any FABRIC network service (FABnet IPv4/IPv6, L2 networks, etc.).
#
# **Dedicated NIC options:**
#
# | Model | Speed | Ports | Sub-interface support |
# |-------|-------|-------|-----------------------|
# | `NIC_ConnectX_5` | 25 Gbps | 2 | Yes |
# | `NIC_ConnectX_6` | 100 Gbps | 2 | Yes |
# | `NIC_Basic` | 100 Gbps | 1 | **No** (SR-IOV VF) |

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create two nodes with Smart NICs using VLAN sub-interfaces for multiple network connections.
#
# <img src="./figs/slice_topology.png" width="55%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance
fablib = fablib_manager()

# Display current configuration
fablib.show_config();

# %% [markdown]
# ## Step 2: Define Slice Parameters

# %%
slice_name = 'MySlice'

node1_name = 'Node1'
node2_name = 'Node2'

# Three networks: two FABnet IPv4 (one per site) and one L2 WAN
network1_name = 'net1'
network2_name = 'net2'
network3_name = 'net3'

# NIC model -- must be a dedicated NIC for sub-interface support
model = "NIC_ConnectX_6"

# %% [markdown]
# ## Step 3: Find Sites with Dedicated NICs Available

# %%
# Column names for filtering site availability
cx5_column_name = 'nic_connectx_5_available'
cx6_column_name = 'nic_connectx_6_available'

# Find two sites with available ConnectX-6 cards
(site1, site2) = fablib.get_random_sites(count=2, filter_function=lambda x: x[cx6_column_name] > 0)

print(f"Sites chosen: {site1} {site2}")

# %% [markdown]
# ## Step 4: Create the Slice
#
# We build the slice in several steps to clearly show how sub-interfaces work.
#
# ### Step 4a: Create the Slice Object

# %%
# Create a new empty slice
slice = fablib.new_slice(name=slice_name)

# %% [markdown]
# ### Step 4b: Create the Networks
#
# We define three networks:
# - **net1** and **net2**: FABnet IPv4 (Layer 3) networks, one per site
# - **net3**: A Layer 2 wide-area network that spans both sites

# %%
# Layer 3 networks for FABnet IPv4 (one per site)
net1 = slice.add_l3network(name=network1_name, type='IPv4')
net2 = slice.add_l3network(name=network2_name, type='IPv4')

# Layer 2 wide-area network spanning both sites
net3 = slice.add_l2network(name=network3_name, subnet="192.168.1.0/24")

# %% [markdown]
# ### Step 4c: Configure Node1 with Sub-Interfaces
#
# We add a dedicated NIC to Node1, then create **two sub-interfaces** on its first port:
# - **child1 (VLAN 100)**: Connected to `net1` (FABnet IPv4) with auto IP configuration
# - **child2 (VLAN 200)**: Connected to `net3` (Layer 2 WAN) with auto IP configuration

# %%
# Add Node1 at site1 with a dedicated ConnectX-6 NIC
node1 = slice.add_node(name=node1_name, site=site1)
node1_iface1 = node1.add_component(model=model, name='nic1').get_interfaces()[0]

# --- Sub-interface 1 (VLAN 100): FABnet IPv4 ---
# Create a sub-interface tagged with VLAN 100 on the physical port
node1_ch_iface1 = node1_iface1.add_sub_interface("child1", vlan="100")
# Set auto mode for IP configuration
node1_ch_iface1.set_mode('auto')
# Connect to the FABnet IPv4 network at this site
net1.add_interface(node1_ch_iface1)
# Add a route for all FABnet traffic via net1's gateway
node1.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net1.get_gateway())

# --- Sub-interface 2 (VLAN 200): Layer 2 WAN ---
# Create a second sub-interface tagged with VLAN 200 on the SAME physical port
node1_ch_iface2 = node1_iface1.add_sub_interface("child2", vlan="200")
# Set auto mode for IP configuration
node1_ch_iface2.set_mode('auto')
# Connect to the Layer 2 WAN network
net3.add_interface(node1_ch_iface2)

# %% [markdown]
# ### Step 4d: Configure Node2 with Sub-Interfaces
#
# Repeat the same pattern for Node2 at site2.

# %%
# Add Node2 at site2 with a dedicated ConnectX-6 NIC
node2 = slice.add_node(name=node2_name, site=site2)
node2_iface1 = node2.add_component(model=model, name='nic1').get_interfaces()[0]

# --- Sub-interface 1 (VLAN 100): FABnet IPv4 ---
node2_ch_iface1 = node2_iface1.add_sub_interface("child1", vlan="100")
node2_ch_iface1.set_mode('auto')
net2.add_interface(node2_ch_iface1)
node2.add_route(subnet=fablib.FABNETV4_SUBNET, next_hop=net2.get_gateway())

# --- Sub-interface 2 (VLAN 200): Layer 2 WAN ---
node2_ch_iface2 = node2_iface1.add_sub_interface("child2", vlan="200")
node2_ch_iface2.set_mode('auto')
net3.add_interface(node2_ch_iface2)

# %% [markdown]
# ### Step 4e: Submit the Slice

# %%
# Submit the slice -- blocks until provisioning is complete
slice.submit()

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC created two nodes, each with a single physical NIC port split into two sub-interfaces. VLAN 100 carries FABnet IPv4 traffic (routed across the backbone), while VLAN 200 carries Layer 2 WAN traffic (switched directly between sites). Both use the same physical NIC.
#
# </div>

# %% [markdown]
# ---
#
# ## Step 5: Run the Experiment
#
# We verify connectivity through both sub-interfaces independently.
#
# ### Test 1: FABnet IPv4 (Layer 3, VLAN 100)
#
# Ping Node2 through the FABnet IPv4 network.

# %%
# Retrieve the slice
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)
node2 = slice.get_node(name=node2_name)

# Get Node2's IP on the FABnet IPv4 network (net2)
node2_addr = node2.get_interface(network_name=network2_name).get_ip_addr()

# Ping through FABnet IPv4 (VLAN 100 sub-interface)
stdout, stderr = node1.execute(f'ping -c 5 {node2_addr}')

# %% [markdown]
# ### Test 2: Layer 2 WAN (VLAN 200)
#
# Ping Node2 through the Layer 2 wide-area network.

# %%
# Retrieve the slice
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)
node2 = slice.get_node(name=node2_name)

# Get Node2's IP on the Layer 2 WAN network (net3)
node2_addr = node2.get_interface(network_name=network3_name).get_ip_addr()

# Ping through the L2 WAN (VLAN 200 sub-interface)
stdout, stderr = node1.execute(f'ping -c 5 {node2_addr}')

# %% [markdown]
# ## Step 6: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. Dedicated NICs are a limited resource.
#
# </div>

# %%
# Delete the slice and release all resources
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | `add_sub_interface()` fails | Using `NIC_Basic` instead of dedicated NIC | Sub-interfaces require `NIC_ConnectX_5` or `NIC_ConnectX_6` |
# | VLAN conflicts | Same VLAN ID used for both sub-interfaces | Each sub-interface on the same port must have a unique VLAN |
# | FABnet ping fails but L2 ping works | FABnet routing not configured | Verify `add_route()` was called with `fablib.FABNETV4_SUBNET` |
# | L2 ping fails but FABnet works | L2 network not spanning both sites | Verify both nodes' VLAN 200 sub-interfaces are on the same L2 network |
# | No dedicated NICs available | All CX-5/CX-6 cards in use | Try a different site with `get_random_sites(filter_function=...)` |
# | Slice submission fails | Incompatible sub-interface configuration | Check that VLANs are string values (e.g., `"100"` not `100`) |

# %% [markdown]
# ## FABlib API Reference
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `node.add_component(model, name)` | Add a dedicated NIC to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `iface.add_sub_interface(name, vlan)` | Create a VLAN-tagged sub-interface | [add_sub_interface](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.add_sub_interface) |
# | `sub_iface.set_mode('auto')` | Enable automatic IP configuration | [set_mode](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_mode) |
# | `slice.add_l3network(name, type)` | Add a Layer 3 network | [add_l3network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l3network) |
# | `slice.add_l2network(name, subnet)` | Add a Layer 2 network | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `network.add_interface(iface)` | Attach an interface (or sub-interface) to a network | [add_interface](https://fabric-fablib.readthedocs.io/en/latest/network_service.html#fabrictestbed_extensions.fablib.network_service.NetworkService.add_interface) |
# | `node.add_route(subnet, next_hop)` | Add a static route on the node | [add_route](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_route) |
# | `fablib.FABNETV4_SUBNET` | The FABnet IPv4 supernet (for routing) | [FABNETV4_SUBNET](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.FABNETV4_SUBNET) |
# | `iface.get_ip_addr()` | Get the IP address assigned to the interface | [get_ip_addr](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.get_ip_addr) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **FABnet IPv4 Auto** | [ipv4_auto](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb) | Layer 3 IPv4 networking with auto configuration |
# | **L2 Networks** | [create_l2network_basic](../create_l2network_basic/create_l2network_basic.ipynb) | Basic Layer 2 networking between FABRIC nodes |
# | **Port Mirroring** | [port_mirror](../create_port_mirror/port_mirror.ipynb) | Monitor dataplane traffic with port mirroring |
# | **Facility Ports** | [facility_port](../facility_port/facility_port.ipynb) | Connect to external facilities via dedicated links |
# | **FABnet IPv4 Ext** | [ipv4_ext](../create_l3network_fabnet_ipv4ext_manual/create_l3network_fabnet_ipv4ext_manual.ipynb) | Layer 3 IPv4 with external internet access |
