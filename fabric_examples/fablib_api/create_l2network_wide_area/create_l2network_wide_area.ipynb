# %% [markdown]
# # Create a Wide-Area Ethernet (Layer 2) Network
#
# This notebook shows how to create an isolated local Ethernet and connect compute nodes to it.

# %% [markdown]
# ## Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
                     
    fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_5735c tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5735c tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5735c caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_5735c_row0_col0, #T_5735c_row0_col1, #T_5735c_row1_col0, #T_5735c_row1_col1, #T_5735c_row2_col0, #T_5735c_row2_col1, #T_5735c_row3_col0, #T_5735c_row3_col1, #T_5735c_row4_col0, #T_5735c_row4_col1, #T_5735c_row5_col0, #T_5735c_row5_col1, #T_5735c_row6_col0, #T_5735c_row6_col1, #T_5735c_row7_col0, #T_5735c_row7_col1, #T_5735c_row8_col0, #T_5735c_row8_col1, #T_5735c_row9_col0, #T_5735c_row9_col1, #T_5735c_row10_col0, #T_5735c_row10_col1, #T_5735c_row11_col0, #T_5735c_row11_col1, #T_5735c_row12_col0, #T_5735c_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5735c">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5735c_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_5735c_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_5735c_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_5735c_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_5735c_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_5735c_row4_col1" class="data row4 col1" >pruth_0031379841</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_5735c_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_5735c_row6_col1" class="data row6 col1" >bastion-1.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_5735c_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_5735c_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_5735c_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_5735c_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_5735c_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_5735c_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_5735c_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## (Optional): Query for Available Testbed Resources and Settings
#
# This optional command queries the FABRIC services to find the available resources. It may be useful for finding a site with available capacity.

# %%
try:    
    output = fablib.list_sites()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_46db8 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_46db8 th {
#   text-align: left;
# }
# #T_46db8 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_46db8 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_46db8 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_46db8_row0_col0, #T_46db8_row0_col1, #T_46db8_row0_col2, #T_46db8_row0_col3, #T_46db8_row0_col4, #T_46db8_row0_col5, #T_46db8_row0_col6, #T_46db8_row0_col7, #T_46db8_row0_col8, #T_46db8_row0_col9, #T_46db8_row0_col10, #T_46db8_row0_col11, #T_46db8_row0_col12, #T_46db8_row0_col13, #T_46db8_row0_col14, #T_46db8_row0_col15, #T_46db8_row0_col16, #T_46db8_row0_col17, #T_46db8_row0_col18, #T_46db8_row0_col19, #T_46db8_row0_col20, #T_46db8_row0_col21, #T_46db8_row0_col22, #T_46db8_row0_col23, #T_46db8_row0_col24, #T_46db8_row0_col25, #T_46db8_row0_col26, #T_46db8_row0_col27, #T_46db8_row0_col28, #T_46db8_row0_col29, #T_46db8_row0_col30, #T_46db8_row0_col31, #T_46db8_row1_col0, #T_46db8_row1_col1, #T_46db8_row1_col2, #T_46db8_row1_col3, #T_46db8_row1_col4, #T_46db8_row1_col5, #T_46db8_row1_col6, #T_46db8_row1_col7, #T_46db8_row1_col8, #T_46db8_row1_col9, #T_46db8_row1_col10, #T_46db8_row1_col11, #T_46db8_row1_col12, #T_46db8_row1_col13, #T_46db8_row1_col14, #T_46db8_row1_col15, #T_46db8_row1_col16, #T_46db8_row1_col17, #T_46db8_row1_col18, #T_46db8_row1_col19, #T_46db8_row1_col20, #T_46db8_row1_col21, #T_46db8_row1_col22, #T_46db8_row1_col23, #T_46db8_row1_col24, #T_46db8_row1_col25, #T_46db8_row1_col26, #T_46db8_row1_col27, #T_46db8_row1_col28, #T_46db8_row1_col29, #T_46db8_row1_col30, #T_46db8_row1_col31, #T_46db8_row2_col0, #T_46db8_row2_col1, #T_46db8_row2_col2, #T_46db8_row2_col3, #T_46db8_row2_col4, #T_46db8_row2_col5, #T_46db8_row2_col6, #T_46db8_row2_col7, #T_46db8_row2_col8, #T_46db8_row2_col9, #T_46db8_row2_col10, #T_46db8_row2_col11, #T_46db8_row2_col12, #T_46db8_row2_col13, #T_46db8_row2_col14, #T_46db8_row2_col15, #T_46db8_row2_col16, #T_46db8_row2_col17, #T_46db8_row2_col18, #T_46db8_row2_col19, #T_46db8_row2_col20, #T_46db8_row2_col21, #T_46db8_row2_col22, #T_46db8_row2_col23, #T_46db8_row2_col24, #T_46db8_row2_col25, #T_46db8_row2_col26, #T_46db8_row2_col27, #T_46db8_row2_col28, #T_46db8_row2_col29, #T_46db8_row2_col30, #T_46db8_row2_col31, #T_46db8_row3_col0, #T_46db8_row3_col1, #T_46db8_row3_col2, #T_46db8_row3_col3, #T_46db8_row3_col4, #T_46db8_row3_col5, #T_46db8_row3_col6, #T_46db8_row3_col7, #T_46db8_row3_col8, #T_46db8_row3_col9, #T_46db8_row3_col10, #T_46db8_row3_col11, #T_46db8_row3_col12, #T_46db8_row3_col13, #T_46db8_row3_col14, #T_46db8_row3_col15, #T_46db8_row3_col16, #T_46db8_row3_col17, #T_46db8_row3_col18, #T_46db8_row3_col19, #T_46db8_row3_col20, #T_46db8_row3_col21, #T_46db8_row3_col22, #T_46db8_row3_col23, #T_46db8_row3_col24, #T_46db8_row3_col25, #T_46db8_row3_col26, #T_46db8_row3_col27, #T_46db8_row3_col28, #T_46db8_row3_col29, #T_46db8_row3_col30, #T_46db8_row3_col31, #T_46db8_row4_col0, #T_46db8_row4_col1, #T_46db8_row4_col2, #T_46db8_row4_col3, #T_46db8_row4_col4, #T_46db8_row4_col5, #T_46db8_row4_col6, #T_46db8_row4_col7, #T_46db8_row4_col8, #T_46db8_row4_col9, #T_46db8_row4_col10, #T_46db8_row4_col11, #T_46db8_row4_col12, #T_46db8_row4_col13, #T_46db8_row4_col14, #T_46db8_row4_col15, #T_46db8_row4_col16, #T_46db8_row4_col17, #T_46db8_row4_col18, #T_46db8_row4_col19, #T_46db8_row4_col20, #T_46db8_row4_col21, #T_46db8_row4_col22, #T_46db8_row4_col23, #T_46db8_row4_col24, #T_46db8_row4_col25, #T_46db8_row4_col26, #T_46db8_row4_col27, #T_46db8_row4_col28, #T_46db8_row4_col29, #T_46db8_row4_col30, #T_46db8_row4_col31, #T_46db8_row5_col0, #T_46db8_row5_col1, #T_46db8_row5_col2, #T_46db8_row5_col3, #T_46db8_row5_col4, #T_46db8_row5_col5, #T_46db8_row5_col6, #T_46db8_row5_col7, #T_46db8_row5_col8, #T_46db8_row5_col9, #T_46db8_row5_col10, #T_46db8_row5_col11, #T_46db8_row5_col12, #T_46db8_row5_col13, #T_46db8_row5_col14, #T_46db8_row5_col15, #T_46db8_row5_col16, #T_46db8_row5_col17, #T_46db8_row5_col18, #T_46db8_row5_col19, #T_46db8_row5_col20, #T_46db8_row5_col21, #T_46db8_row5_col22, #T_46db8_row5_col23, #T_46db8_row5_col24, #T_46db8_row5_col25, #T_46db8_row5_col26, #T_46db8_row5_col27, #T_46db8_row5_col28, #T_46db8_row5_col29, #T_46db8_row5_col30, #T_46db8_row5_col31, #T_46db8_row6_col0, #T_46db8 ...

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates two nodes with basic NICs connected to an isolated WAN Ethernet.
#
# Two nodes are created and one NIC component is added to each node.  This example uses components of model `NIC_Basic` which are SR-IOV Virtual Function on a 100 Gpbs Mellanox ConnectX-6 PCI device. The VF is accessed by the node via PCI passthrough. Other NIC models are listed below. When using dedicated PCI devices the whole physical device is allocated to one node and the device is accessed by the node using PCI passthrough. Calling the `get_interfaces()` method on a component will return a list of interfaces. Many dedicated NIC components may have more than one port.  Either port can be connected to the network.
#
# Next, add an `l2network` to the slice and pass the list of interfaces you want connected to this Ethernet. If the interfaces in the list are located on two sites, the network will automatically create a wide-area layer 2 circuit.  By default, a node is put on a random site.  If you want to ensure that your nodes are all on different sites you can specify the name of the sites in the `add_node` methode.  You can use the `fablib.get_random_site()` method to get a set of random site names that guarantee that the sites are different.
#
# NIC component models options:
# - NIC_Basic: 100 Gbps Mellanox ConnectX-6 SR-IOV VF (1 Port)
# - NIC_ConnectX_5: 25 Gbps Dedicated Mellanox ConnectX-5 PCI Device (2 Ports)
# - NIC_ConnectX_6: 100 Gbps Dedicated Mellanox ConnectX-6 PCI Device (2 Ports)

# %%
slice_name = 'MySliceDALL_UCSD'
#[site1,site2]  = fablib.get_random_sites(count=2)

site1 = 'DALL'
site2 = 'UCSD'
print(f"Sites: {site1}, {site2}")

node1_name = 'Node1'
node2_name = 'Node2'
network_name='net1'
node1_nic_name = 'nic1'
node2_nic_name = 'nic2'
# Out:
# Sites: DALL, UCSD

# %%
try:
    #Create Slice
    slice = fablib.new_slice(name=slice_name)

    # Node1
    node1 = slice.add_node(name=node1_name, site=site1)
    iface1 = node1.add_component(model='NIC_Basic', name=node1_nic_name).get_interfaces()[0]
    
    # Node2
    node2 = slice.add_node(name=node2_name, site=site2)
    iface2 = node2.add_component(model='NIC_Basic', name=node2_nic_name).get_interfaces()[0]
    
    # Network
    net1 = slice.add_l2network(name=network_name, interfaces=[iface1, iface2])

    #Submit Slice Request
    slice.submit()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Retry: 7, Time: 188 sec
# <style type="text/css">
# #T_3fe47 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_3fe47 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3fe47 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_3fe47_row0_col0, #T_3fe47_row0_col1, #T_3fe47_row1_col0, #T_3fe47_row1_col1, #T_3fe47_row2_col0, #T_3fe47_row2_col1, #T_3fe47_row3_col0, #T_3fe47_row3_col1, #T_3fe47_row4_col0, #T_3fe47_row4_col1, #T_3fe47_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_3fe47_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_3fe47">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3fe47_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_3fe47_row0_col1" class="data row0 col1" >b1dee6d4-b7c4-4dda-a8b1-75343e5bce0a</td>
#     </tr>
#     <tr>
#       <td id="T_3fe47_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_3fe47_row1_col1" class="data row1 col1" >MySliceDALL_UCSD</td>
#     </tr>
#     <tr>
#       <td id="T_3fe47_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_3fe47_row2_col1" class="data row2 col1" >2022-11-11 13:59:22 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_3fe47_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_3fe47_row3_col1" class="data row3 col1" >2022-11-10 13:59:24 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_3fe47_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_3fe47_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_3fe47_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_3fe47_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_46347 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_46347 th {
#   text-align: left;
# }
# #T_46347 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_46347 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_46347 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_46347_row0_col0, #T_46347_row0_col1, #T_46347_row0_col2, #T_46347_row0_col3, #T_46347_row0_col4, #T_46347_row0_col5, #T_46347_row0_col6, #T_46347_row0_col7, #T_46347_row0_col8, #T_46347_row0_col9, #T_46347_row0_col10, #T_46347_row0_col13, #T_46347_row0_col14, #T_46347_row0_col15, #T_46347_row1_col0, #T_46347_row1_col1, #T_46347_row1_col2, #T_46347_row1_col3, #T_46347_row1_col4, #T_46347_row1_col5, #T_46347_row1_col6, #T_46347_row1_col7, #T_46347_row1_col8, #T_46347_row1_col9, #T_46347_row1_col10, #T_46347_row1_col13, #T_46347_row1_col14, #T_46347_row1_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_46347_row0_col11, #T_46347_row1_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_46347_row0_col12, #T_46347_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_46347">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_46347_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_46347_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_46347_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_46347_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_46347_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_46347_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_46347_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_46347_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_46347_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_46347_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_46347_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_46347_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_46347_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_46347_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_46347_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_46347_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46347_row0_col0" class="data row0 col0" >ae134133-f4cc-401d-b3d3-051f41c1b272</td>
#       <td id="T_46347_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_46347_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_46347_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_46347_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_46347_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_46347_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_46347_row0_col7" class="data row0 col7" >dall-w3.fabric-testbed.net</td>
#       <td id="T_46347_row0_col8" class="data row0 col8" >DALL</td>
#       <td id="T_46347_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_46347_row0_col10" class="data row0 col10" >2001:400:a100:3000:f816:3eff:fe1e:b875</td>
#       <td id="T_46347_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_46347_row0_col12" class="data row0 col12" ></td>
#       <td id="T_46347_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fe1e:b875</td>
#       <td id="T_46347_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_46347_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_46347_row1_col0" class="data row1 col0" >4f26bebc-a3b9-4f5f-833e-d193f9f9884f</td>
#       <td id="T_46347_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_46347_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_46347_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_46347_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_46347_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_46347_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_46347_row1_col7" class="data row1 col7" >ucsd-w4.fabric-testbed.net</td>
#       <td id="T_46347_row1_col8" class="data row1 col8" >UCSD</td>
#       <td id="T_46347_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_46347_row1_col10" class="data row1 col10" >132.249.252.177</td>
#       <td id="T_46347_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_46347_row1_col12" class="data row1 col12" ></td>
#       <td id="T_46347_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@132.249.252.177</td>
#       <td id="T_46347_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_46347_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e6835 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e6835 th {
#   text-align: left;
# }
# #T_e6835 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e6835 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e6835 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e6835_row0_col0, #T_e6835_row0_col1, #T_e6835_row0_col2, #T_e6835_row0_col3, #T_e6835_row0_col4, #T_e6835_row0_col5, #T_e6835_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_e6835_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_e6835_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_e6835">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_e6835_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_e6835_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_e6835_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_e6835_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_e6835_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_e6835_level0_col5" class="col_heading level0 col5" >Gateway</th>
#       <th id="T_e6835_level0_col6" class="col_heading level0 col6" >Subnet</th>
#       <th id="T_e6835_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_e6835_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e6835_row0_col0" class="data row0 col0" >7adca63d-d27f-4f74-9b5c-72f7cdea81c4</td>
#       <td id="T_e6835_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_e6835_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_e6835_row0_col3" class="data row0 col3" >L2STS</td>
#       <td id="T_e6835_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_e6835_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_e6835_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_e6835_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_e6835_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# Time to stable 188 seconds
# Running post_boot_config ... Time to post boot config 193 seconds
# <style type="text/css">
# #T_053c0 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_053c0 th {
#   text-align: left;
# }
# #T_053c0 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_053c0 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_053c0 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_053c0_row0_col0, #T_053c0_row0_col1, #T_053c0_row0_col2, #T_053c0_row0_col3, #T_053c0_row0_col4, #T_053c0_row0_col5, #T_053c0_row0_col6, #T_053c0_row0_col7, #T_053c0_row1_col0, #T_053c0_row1_col1, #T_053c0_row1_col2, #T_053c0_row1_col3, #T_053c0_row1_col4, #T_053c0_row1_col5, #T_053c0_row1_col6, #T_053c0_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_053c0">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_053c0_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_053c0_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_053c0_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_053c0_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_053c0_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_053c0_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_053c0_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_053c0_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_053c0_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_053c0_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_053c0_row0_col2" class="data row0 col2" >net1</td>
#       <td id="T_053c0_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_053c0_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_053c0_row0_col5" class="data row0 col5" >1E:1E:AD:1F:D2:9D</td>
#       <td id="T_053c0_row0_col6" class="data row0 col6" >eth1</td>
#       <td id="T_053c0_row0_col7" class="data row0 col7" >eth1</td>
#     </tr>
#     <tr>
#       <td id="T_053c0_row1_col0" class="data row1 col0" >Node2-nic2-p1</td>
#       <td id="T_053c0_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_053c0_row1_col2" class="data row1 col2" >net1</td>
#       <td id="T_053c0_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_053c0_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_053c0_row1_col5" class="data row1 col5" >16:E7:68:5C:0E:B8</td>
#       <td id="T_053c0_row1_col6" class="data row1 col6" >eth1</td>
#       <td id="T_053c0_row1_col7" class="data row1 col7" >eth1</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 199 seconds

# %% [markdown]
# ## Observe the Slice's Attributes

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.show()
    slice.list_nodes()
    slice.list_networks()
    slice.list_interfaces()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_4391b tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4391b tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4391b caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_4391b_row0_col0, #T_4391b_row0_col1, #T_4391b_row1_col0, #T_4391b_row1_col1, #T_4391b_row2_col0, #T_4391b_row2_col1, #T_4391b_row3_col0, #T_4391b_row3_col1, #T_4391b_row4_col0, #T_4391b_row4_col1, #T_4391b_row5_col0, #T_4391b_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_4391b">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4391b_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_4391b_row0_col1" class="data row0 col1" >b1dee6d4-b7c4-4dda-a8b1-75343e5bce0a</td>
#     </tr>
#     <tr>
#       <td id="T_4391b_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_4391b_row1_col1" class="data row1 col1" >MySliceDALL_UCSD</td>
#     </tr>
#     <tr>
#       <td id="T_4391b_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_4391b_row2_col1" class="data row2 col1" >2022-11-11 13:59:22 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_4391b_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_4391b_row3_col1" class="data row3 col1" >2022-11-10 13:59:24 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_4391b_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_4391b_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_4391b_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_4391b_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_81ef4 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_81ef4 th {
#   text-align: left;
# }
# #T_81ef4 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_81ef4 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_81ef4 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_81ef4_row0_col0, #T_81ef4_row0_col1, #T_81ef4_row0_col2, #T_81ef4_row0_col3, #T_81ef4_row0_col4, #T_81ef4_row0_col5, #T_81ef4_row0_col6, #T_81ef4_row0_col7, #T_81ef4_row0_col8, #T_81ef4_row0_col9, #T_81ef4_row0_col10, #T_81ef4_row0_col11, #T_81ef4_row0_col12, #T_81ef4_row0_col13, #T_81ef4_row0_col14, #T_81ef4_row0_col15, #T_81ef4_row1_col0, #T_81ef4_row1_col1, #T_81ef4_row1_col2, #T_81ef4_row1_col3, #T_81ef4_row1_col4, #T_81ef4_row1_col5, #T_81ef4_row1_col6, #T_81ef4_row1_col7, #T_81ef4_row1_col8, #T_81ef4_row1_col9, #T_81ef4_row1_col10, #T_81ef4_row1_col11, #T_81ef4_row1_col12, #T_81ef4_row1_col13, #T_81ef4_row1_col14, #T_81ef4_row1_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_81ef4">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_81ef4_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_81ef4_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_81ef4_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_81ef4_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_81ef4_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_81ef4_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_81ef4_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_81ef4_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_81ef4_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_81ef4_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_81ef4_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_81ef4_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_81ef4_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_81ef4_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_81ef4_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_81ef4_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_81ef4_row0_col0" class="data row0 col0" >ae134133-f4cc-401d-b3d3-051f41c1b272</td>
#       <td id="T_81ef4_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_81ef4_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_81ef4_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_81ef4_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_81ef4_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_81ef4_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_81ef4_row0_col7" class="data row0 col7" >dall-w3.fabric-testbed.net</td>
#       <td id="T_81ef4_row0_col8" class="data row0 col8" >DALL</td>
#       <td id="T_81ef4_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_81ef4_row0_col10" class="data row0 col10" >2001:400:a100:3000:f816:3eff:fe1e:b875</td>
#       <td id="T_81ef4_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_81ef4_row0_col12" class="data row0 col12" ></td>
#       <td id="T_81ef4_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fe1e:b875</td>
#       <td id="T_81ef4_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_81ef4_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_81ef4_row1_col0" class="data row1 col0" >4f26bebc-a3b9-4f5f-833e-d193f9f9884f</td>
#       <td id="T_81ef4_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_81ef4_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_81ef4_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_81ef4_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_81ef4_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_81ef4_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_81ef4_row1_col7" class="data row1 col7" >ucsd-w4.fabric-testbed.net</td>
#       <td id="T_81ef4_row1_col8" class="data row1 col8" >UCSD</td>
#       <td id="T_81ef4_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_81ef4_row1_col10" class="data row1 col10" >132.249.252.177</td>
#       <td id="T_81ef4_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_81ef4_row1_col12" class="data row1 col12" ></td>
#       <td id="T_81ef4_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@132.249.252.177</td>
#       <td id="T_81ef4_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_81ef4_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4bc7b caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_4bc7b th {
#   text-align: left;
# }
# #T_4bc7b tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4bc7b tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4bc7b .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4bc7b_row0_col0, #T_4bc7b_row0_col1, #T_4bc7b_row0_col2, #T_4bc7b_row0_col3, #T_4bc7b_row0_col4, #T_4bc7b_row0_col5, #T_4bc7b_row0_col6, #T_4bc7b_row0_col7, #T_4bc7b_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_4bc7b">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_4bc7b_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_4bc7b_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_4bc7b_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_4bc7b_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_4bc7b_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_4bc7b_level0_col5" class="col_heading level0 col5" >Gateway</th>
#       <th id="T_4bc7b_level0_col6" class="col_heading level0 col6" >Subnet</th>
#       <th id="T_4bc7b_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_4bc7b_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4bc7b_row0_col0" class="data row0 col0" >7adca63d-d27f-4f74-9b5c-72f7cdea81c4</td>
#       <td id="T_4bc7b_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_4bc7b_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_4bc7b_row0_col3" class="data row0 col3" >L2STS</td>
#       <td id="T_4bc7b_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_4bc7b_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_4bc7b_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_4bc7b_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_4bc7b_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_368bf caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_368bf th {
#   text-align: left;
# }
# #T_368bf tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_368bf tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_368bf .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_368bf_row0_col0, #T_368bf_row0_col1, #T_368bf_row0_col2, #T_368bf_row0_col3, #T_368bf_row0_col4, #T_368bf_row0_col5, #T_368bf_row0_col6, #T_368bf_row0_col7, #T_368bf_row1_col0, #T_368bf_row1_col1, #T_368bf_row1_col2, #T_368bf_row1_col3, #T_368bf_row1_col4, #T_368bf_row1_col5, #T_368bf_row1_col6, #T_368bf_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_368bf">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_368bf_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_368bf_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_368bf_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_368bf_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_368bf_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_368bf_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_368bf_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_368bf_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_368bf_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_368bf_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_368bf_row0_col2" class="data row0 col2" >net1</td>
#       <td id="T_368bf_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_368bf_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_368bf_row0_col5" class="data row0 col5" >1E:1E:AD:1F:D2:9D</td>
#       <td id="T_368bf_row0_col6" class="data row0 col6" >eth1</td>
#       <td id="T_368bf_row0_col7" class="data row0 col7" >eth1</td>
#     </tr>
#     <tr>
#       <td id="T_368bf_row1_col0" class="data row1 col0" >Node2-nic2-p1</td>
#       <td id="T_368bf_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_368bf_row1_col2" class="data row1 col2" >net1</td>
#       <td id="T_368bf_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_368bf_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_368bf_row1_col5" class="data row1 col5" >16:E7:68:5C:0E:B8</td>
#       <td id="T_368bf_row1_col6" class="data row1 col6" >eth1</td>
#       <td id="T_368bf_row1_col7" class="data row1 col7" >eth1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Configure IP Addresses
#
# Some experiments use FABRIC layer 2 networks to enable deploying non-IP layer 3 networks.  If this describes your exepriment, your nodes and network are ready. You can now login to the nodes and deploy your experiemnt.
#
# Most users will want to configure IP addresses on there new nodes.  FABlib provides some useful methods to help you configure basic IP addreses.
#
# ### Pick a Subnet
#
# Create subnet and list of available IP addresses. All object are Python IP managment objects. You can use either IPv4 or IPv6 subents and addresses.

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

try:
    subnet = IPv4Network("192.168.1.0/24")
    available_ips = list(subnet)[1:]
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Configure Node1
#
# Get the node and the interface you wish to configure.  You can use `node.get_interface` to get the interface that is connected to the specified network.  Then `pop` an IP address from the list of available IPs and call `iface.ip_addr_add` to set the IP and subnet.
#
# Optionally, use the `node.execute()` method to show the results of adding the IP address.

# %%
try:
    node1 = slice.get_node(name=node1_name)        
    node1_iface = node1.get_interface(network_name=network_name) 
    node1_addr = available_ips.pop(0)
    node1_iface.ip_addr_add(addr=node1_addr, subnet=subnet)
    
    stdout, stderr = node1.execute(f'ip addr show {node1_iface.get_os_interface()}')
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# 3: eth1: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 1e:1e:ad:1f:d2:9d brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.1/24 scope global eth1
#        valid_lft forever preferred_lft forever
#     inet6 fe80::2b65:7a6c:1b2:43b9/64 scope link noprefixroute
#        valid_lft forever preferred_lft forever

# %% [markdown]
# ### Configure Node2
#
# Repeat the steps to add the next available IP to the second node.

# %%
try:
    node2 = slice.get_node(name=node2_name)        
    node2_iface = node2.get_interface(network_name=network_name)  
    node2_addr = available_ips.pop(0)
    node2_iface.ip_addr_add(addr=node2_addr, subnet=subnet)
    
    stdout, stderr = node2.execute(f'ip addr show {node2_iface.get_os_interface()}')
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# 3: eth1: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 16:e7:68:5c:0e:b8 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.2/24 scope global eth1
#        valid_lft forever preferred_lft forever
#     inet6 fe80::d066:e5e5:e6bd:5bfd/64 scope link noprefixroute
#        valid_lft forever preferred_lft forever

# %% [markdown]
# ## Run the Experiment
#
# We will find the ping round trip time for this pair of sites.  Your experiment should be more interesting!

# %%
try:
    node1 = slice.get_node(name=node1_name)        

    stdout, stderr = node1.execute(f'ping -c 5 {node2_addr}')

except Exception as e:
    print(f"Exception: {e}")
# Out:
# PING 192.168.1.2 (192.168.1.2) 56(84) bytes of data.
# From 192.168.1.1 icmp_seq=1 Destination Host Unreachable
# From 192.168.1.1 icmp_seq=2 Destination Host Unreachable
# From 192.168.1.1 icmp_seq=3 Destination Host Unreachable
# From 192.168.1.1 icmp_seq=4 Destination Host Unreachable
# From 192.168.1.1 icmp_seq=5 Destination Host Unreachable
#
# --- 192.168.1.2 ping statistics ---
# 5 packets transmitted, 0 received, +5 errors, 100% packet loss, time 4128ms
# pipe 4

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
