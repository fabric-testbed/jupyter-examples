# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Create a Wide-Area L2 Network with Explicit Route Options (ERO)
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to create wide-area Layer 2 networks with **Explicit Route Options (ERO)** on FABRIC. ERO lets you control the physical path your traffic takes through FABRIC's backbone, enabling you to compare different routes, set bandwidth guarantees, and observe how path selection affects latency and throughput.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Create **two parallel L2 networks** between the same pair of nodes, each with a different explicit route
# 2. Use **Explicit Route Options (ERO)** with `set_l2_route_hops()` to control traffic paths
# 3. Set **bandwidth reservations** on L2 networks using `set_bandwidth()`
# 4. Use **dedicated NICs** with multiple ports and VLAN tagging
# 5. Compare **latency and throughput** across different network paths using `ping` and `iperf3`
# 6. Run **Docker containers** on FABRIC nodes for network testing tools
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Run the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be familiar with wide-area L2 networks (see [Wide-Area L2 - User Defined Config](./create_l2network_wide_area_config.ipynb))
#
# **Tip:** This notebook uses **dedicated NIC components** (`NIC_ConnectX_5`) rather than SR-IOV VFs (`NIC_Basic`). Dedicated NICs are required for point-to-point connections and provide two physical ports per device.
#
# **Note:** This notebook uses specific FABRIC sites (ATLA, WASH, STAR, NEWY) that must be available. If any site is down, you may need to modify the site selections.
#
# </div>

# %% [markdown]
# ## Background: Explicit Route Options (ERO)
#
# ### What are Explicit Route Options?
#
# By default, FABRIC chooses the shortest path through its backbone to connect two sites. **Explicit Route Options (ERO)** let you override this default and specify intermediate sites (hops) that your traffic must traverse. This is useful for:
#
# - **Path diversity**: Testing how different routes affect performance
# - **Quality of Service (QoS)**: Reserving specific bandwidth along a chosen path
# - **Research**: Studying network behavior under controlled routing conditions
#
# ### This Experiment's Topology
#
# We create two nodes (at ATLA and NEWY) connected by **two separate L2 networks**, each taking a different path through FABRIC's backbone:
#
#
# - **Path 1** (via WASH): Higher bandwidth reservation (8 Gbps)
# - **Path 2** (via STAR): Lower bandwidth reservation (2 Gbps)
#
# ### Dedicated NICs and VLAN Tagging
#
# Each node uses a `NIC_ConnectX_5` dedicated NIC with **two ports**. Each port connects to a different L2 network using VLAN tags (100 and 200) to isolate traffic. This allows a single physical NIC to participate in multiple networks simultaneously.
#
# ### Post-Boot Setup
#
# This notebook uses `add_post_boot_upload_directory()` and `add_post_boot_execute()` to automatically upload tuning scripts and pull Docker images (for iperf3) when the slice becomes active.

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create two nodes on different sites connected by a wide-area L2 Ethernet link (L2STS).
#
# <img src="./figs/slice_topology.png" width="50%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration
#
# Import the FABlib library and the `ipaddress` module for subnet management.

# %%
# Import Python's ipaddress module for subnet and IP address manipulation
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

# Import the FABlib library and create a manager instance
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

# Display current configuration (tokens, keys, project info)
fablib.show_config();

# %% [markdown]
# ## Step 2: Define Slice Parameters
#
# We use **four specific FABRIC sites**: ATLA and NEWY for the endpoints, and WASH and STAR as intermediate hops for the two different paths. Each L2 network uses a separate subnet to keep traffic isolated.

# %%
# Slice name
slice_name = 'MySlice-ero'

# Define the four sites:
# site1 (ATLA) and site4 (NEWY) are the endpoints
# site2 (WASH) and site3 (STAR) are intermediate hops for the two paths
[site1, site2, site3, site4] = ["ATLA", "WASH", "STAR", "NEWY"]
print(f"Sites: {site1}, {site2}, {site3}, {site4}")

# Node names
node1_name = 'Node1'
node2_name = 'Node2'

# Network names -- one for each explicit route path
# Path1 : ATLA -> WASH -> NEWY
# Path2 : ATLA -> STAR -> NEWY
net1_name = 'net-with-ero-path1' 
net2_name = 'net-with-ero-path2'

# OS image to use for both nodes
image="default_rocky_9"

# %% [markdown]
# ## Step 3: Create the Slice with Two ERO Networks
#
# This step creates a more advanced topology:
#
# 1. Two L2 networks on separate subnets (`192.168.1.0/24` and `192.168.2.0/24`)
# 2. Each node gets a **dedicated NIC** (`NIC_ConnectX_5`) with **two ports**
# 3. Each port is assigned a **VLAN tag** to isolate traffic between the two networks
# 4. `set_l2_route_hops()` specifies the intermediate site for each network
# 5. `set_bandwidth()` reserves different bandwidth levels for each path
# 6. Post-boot scripts upload host tuning tools and pull a Docker image for iperf3
#
# <div class="fab-danger">
#
# **Important:** ERO requires **dedicated NICs** (e.g., `NIC_ConnectX_5` or `NIC_ConnectX_6`). SR-IOV VFs (`NIC_Basic`) do not support point-to-point connections needed for ERO.
#
# </div>

# %%
# Create a new empty slice
slice = fablib.new_slice(name=slice_name)

# --- Create two L2 networks, each on a different subnet ---
net1 = slice.add_l2network(name=net1_name, subnet=IPv4Network("192.168.1.0/24"))

net2 = slice.add_l2network(name=net2_name, subnet=IPv4Network("192.168.2.0/24"))

# --- Node 1 (at ATLA) ---
node1 = slice.add_node(name=node1_name, site=site1, image=image)
# Add a dedicated NIC with 2 ports
n1_nic1 = node1.add_component(model='NIC_ConnectX_5', name='nic1')
# Port 0: auto-configured, VLAN 100 -> connected to net1 (Path 1)
n1_nic1.get_interfaces()[0].set_mode('auto')
n1_nic1.get_interfaces()[0].set_vlan('100')
# Port 1: auto-configured, VLAN 200 -> connected to net2 (Path 2)
n1_nic1.get_interfaces()[1].set_mode('auto')
n1_nic1.get_interfaces()[1].set_vlan('200')

# Connect Node1's ports to the respective networks
net1.add_interface(n1_nic1.get_interfaces()[0])

net2.add_interface(n1_nic1.get_interfaces()[1])

# Upload host tuning scripts and pull Docker image for iperf3
node1.add_post_boot_upload_directory('node_tools','.')
node1.add_post_boot_execute('node_tools/host_tune_enable_docker.sh')
node1.add_post_boot_execute('docker pull fabrictestbed/slice-vm-rocky9-multitool:0.1.0')

# --- Node 2 (at NEWY) ---
node2 = slice.add_node(name=node2_name, site=site4, image=image)
# Add a dedicated NIC with 2 ports
n2_nic1 = node2.add_component(model='NIC_ConnectX_5', name='nic1')

# Port 0: auto-configured, VLAN 100 -> connected to net1 (Path 1)
n2_nic1.get_interfaces()[0].set_mode('auto')
n2_nic1.get_interfaces()[0].set_vlan('100')
# Port 1: auto-configured, VLAN 200 -> connected to net2 (Path 2)
n2_nic1.get_interfaces()[1].set_mode('auto')
n2_nic1.get_interfaces()[1].set_vlan('200')

# Connect Node2's ports to the respective networks
net1.add_interface(n2_nic1.get_interfaces()[0])

net2.add_interface(n2_nic1.get_interfaces()[1])

# Upload host tuning scripts and pull Docker image for iperf3
node2.add_post_boot_upload_directory('node_tools','.')
node2.add_post_boot_execute('sudo node_tools/host_tune_enable_docker.sh')
node2.add_post_boot_execute('docker pull fabrictestbed/slice-vm-rocky9-multitool:0.1.0')

# --- Set Explicit Route Options ---
# Path 1: ATLA -> WASH -> NEWY
net1.set_l2_route_hops(hops=[site2])

# Path 2: ATLA -> STAR -> NEWY
net2.set_l2_route_hops(hops=[site3])

# --- Set Bandwidth Reservations ---
# Path 1 gets 8 Gbps, Path 2 gets 2 Gbps
net1.set_bandwidth(8)

net2.set_bandwidth(2)

# Submit the slice request to FABRIC
# This may take longer than usual due to the ERO path setup
slice.submit()

# %% [markdown]
# ## Step 4: Run the Experiment
#
# We will compare the two paths by running connectivity tests (ping) and throughput tests (iperf3) on each. The differences in latency and bandwidth demonstrate the effect of explicit route selection.
#
# <div class="fab-warning">
#
# **What to look for:**
# - **Ping latency** should differ between paths since they traverse different intermediate sites
# - **iperf3 throughput** should approach the reserved bandwidth (8 Gbps for Path 1, 2 Gbps for Path 2)
#
# </div>

# %%
# Get Slice and Nodes
slice = fablib.get_slice(slice_name)

node1 = slice.get_node(name=node1_name)        
node2 = slice.get_node(name=node2_name)

# %% [markdown]
# ### Ping on Path 1 (via WASH)
#
# This test verifies basic connectivity and measures round-trip latency over Path 1. The latency reflects the physical distance ATLA -> WASH -> NEWY.

# %%
# Get Node2's IP address on the Path 1 network (192.168.1.x)
node2_net1_addr = node2.get_interface(network_name=net1_name).get_ip_addr()

# Ping Node2 via Path 1 to measure latency
stdout, stderr = node1.execute(f'ping -c 5 {node2_net1_addr}')

# %% [markdown]
# ### Bandwidth Test on Path 1 (via WASH) Using iPerf3
#
# This test measures achievable throughput over Path 1 using iPerf3 in Docker containers. The iperf3 server runs on Node2 and the client runs on Node1. We use 10 parallel streams (`-P 10`) for 30 seconds (`-t 30`) with a 10-second omit period (`-O 10`) to let TCP ramp up.
#
# Path 1 has an 8 Gbps bandwidth reservation, so throughput should approach that limit.

# %%
print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Start iperf3 server on Node2 in a Docker container (single-shot mode: -1)
stdout1, stderr1 = node2.execute("docker run -d --rm "
                                 "--network host "
                                 "fabrictestbed/slice-vm-rocky9-multitool:0.1.0 "
                                 "iperf3 -s -1",
                                 quiet=True, output_file=f"{node2.get_name()}.log");

print(f"Source:  {node2.get_name()} to Dest: {node1.get_name()}")

# Run iperf3 client on Node1, targeting Node2's Path 1 address
# -P 10: 10 parallel streams  -t 30: 30 seconds  -i 10: report every 10s  -O 10: omit first 10s
stdout2, stderr2 = node1.execute("docker run --rm "
                                 "--network host "
                                 "fabrictestbed/slice-vm-rocky9-multitool:0.1.0 "
                                 f"iperf3 -c {node2_net1_addr} -P 10 -t 30 -i 10 -O 10",
                                 quiet=False, output_file=f"{node1.get_name()}.log");
print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")

# %% [markdown]
# ### Ping on Path 2 (via STAR)
#
# This test verifies connectivity and measures latency over Path 2. Compare the round-trip time with Path 1 to see how routing affects latency.

# %%
# Get Node2's IP address on the Path 2 network (192.168.2.x)
node2_net2_addr = node2.get_interface(network_name=net2_name).get_ip_addr()

# Ping Node2 via Path 2 to measure latency
stdout, stderr = node1.execute(f'ping -c 5 {node2_net2_addr}')

# %% [markdown]
# ### Bandwidth Test on Path 2 (via STAR) Using iPerf3
#
# Same test as Path 1, but on the second network. Path 2 has a 2 Gbps bandwidth reservation, so throughput should be significantly lower than Path 1.

# %%
print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Start iperf3 server on Node2 in a Docker container (single-shot mode: -1)
stdout1, stderr1 = node2.execute("docker run -d --rm "
                                 "--network host "
                                 "fabrictestbed/slice-vm-rocky9-multitool:0.1.0 "
                                 "iperf3 -s -1",
                                 quiet=True, output_file=f"{node2.get_name()}.log");

print(f"Source:  {node2.get_name()} to Dest: {node1.get_name()}")

# Run iperf3 client on Node1, targeting Node2's Path 2 address
# -P 10: 10 parallel streams  -t 30: 30 seconds  -i 10: report every 10s  -O 10: omit first 10s
stdout2, stderr2 = node1.execute("docker run --rm "
                                 "--network host "
                                 "fabrictestbed/slice-vm-rocky9-multitool:0.1.0 "
                                 f"iperf3 -c {node2_net2_addr} -P 10 -t 30 -i 10 -O 10",
                                 quiet=False, output_file=f"{node1.get_name()}.log");
print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")

# %% [markdown]
# ## Step 5: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. Dedicated NICs are a limited resource -- leaving slices running prevents other researchers from using them.
#
# </div>

# %%
# Delete the slice and release all resources
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | Slice creation fails | Site lacks dedicated NIC capacity | Check `fablib.list_sites()` for available `NIC_ConnectX_5` resources |
# | `ping` fails on one path | ERO path not fully established | Wait a few minutes; complex paths may take extra time to converge |
# | iperf3 shows 0 throughput | Docker image not pulled | SSH into the node and run `docker pull` manually |
# | iperf3 server not reachable | Server container exited | Re-run the server cell; `-1` flag means it exits after one client |
# | Bandwidth lower than reserved | TCP not fully ramped up | Increase `-t` (duration) and `-O` (omit) parameters |
# | `post_boot_execute` failed | Script not found or permission denied | Ensure `node_tools/` directory exists in the notebook's directory |
# | Both paths show same latency | Paths may overlap geographically | Try different intermediate sites for more distinct paths |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_l2network(name, subnet)` | Add a Layer 2 network to the slice | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `slice.add_node(name, site, image)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component(model, name)` | Add a dedicated NIC to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `iface.set_mode(mode)` | Set interface configuration mode | [set_mode](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_mode) |
# | `iface.set_vlan(vlan)` | Set VLAN tag on an interface | [set_vlan](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_vlan) |
# | `net.add_interface(iface)` | Connect an interface to a network | [add_interface](https://fabric-fablib.readthedocs.io/en/latest/network_service.html#fabrictestbed_extensions.fablib.network_service.NetworkService.add_interface) |
# | `net.set_l2_route_hops(hops)` | Set explicit route hops for the L2 network | [set_l2_route_hops](https://fabric-fablib.readthedocs.io/en/latest/network_service.html#fabrictestbed_extensions.fablib.network_service.NetworkService.set_l2_route_hops) |
# | `net.set_bandwidth(bw)` | Set bandwidth reservation (Gbps) | [set_bandwidth](https://fabric-fablib.readthedocs.io/en/latest/network_service.html#fabrictestbed_extensions.fablib.network_service.NetworkService.set_bandwidth) |
# | `node.add_post_boot_upload_directory(local, remote)` | Upload a directory after boot | [add_post_boot_upload_directory](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_post_boot_upload_directory) |
# | `node.add_post_boot_execute(command)` | Run a command after boot | [add_post_boot_execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_post_boot_execute) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you understand explicit routing on FABRIC, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **WAN L2 (User Config)** | [create_l2network_wide_area_config](./create_l2network_wide_area_config.ipynb) | Wide-area L2 without ERO, using user-defined IPs |
# | **Local L2 Network** | [create_l2network_basic_config](../create_l2network_basic/create_l2network_basic_config.ipynb) | Single-site L2 network with user-defined config |
# | **FABnet IPv4 (L3)** | [create_l3network_fabnet_ipv4_auto](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb) | FABRIC's managed Layer 3 networking |
# | **Storage Benchmarking** | [benchmarking_storage](../benchmarking_storage/benchmarking_storage.ipynb) | Benchmark local disk and NVMe storage |
# | **GPUs** | [fabric_gpu](../fabric_all_gpus/fabric_gpu.ipynb) | Use NVIDIA GPUs on FABRIC |
