# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Create and Submit a Slice
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **What this notebook covers:** This notebook demonstrates how to create and submit slices on the FABRIC testbed. You will learn multiple submission strategies -- from simple blocking calls to advanced non-blocking and future-scheduled reservations -- as well as how to validate your slice topology before submitting.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Create and submit a slice using the default **blocking** mode
# 2. Submit a slice **silently** (without progress output)
# 3. Submit a slice in **non-blocking** mode and manually check its state
# 4. Schedule a slice for **future provisioning** with `lease_start_time`
# 5. **Validate** a slice topology before submitting to catch configuration errors early
# 6. Customize **timeout** and **retry interval** for blocking submissions
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Run the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook to create your `fabric_rc` and `ssh_config` files
# 2. Have a valid FABRIC project with sufficient resource allocations
#
# **Tip:** If you are new to FABRIC, start with the [Hello, FABRIC](../hello_fabric/hello_fabric.ipynb) notebook first.
#
# </div>

# %% [markdown]
# ## Background: The Slice Lifecycle
#
# Creating a slice on FABRIC follows a **design-then-submit** pattern. You first build a topology description in memory, then send it to FABRIC for provisioning.
#
#
# The `submit()` method has several options that control **how you wait** for the slice to become ready:
#
# | Mode | Parameters | Behavior |
# |------|-----------|----------|
# | **Blocking (default)** | `submit()` | Waits until slice is ready, shows progress |
# | **Silent** | `submit(progress=False)` | Waits until ready, no progress output |
# | **Non-blocking** | `submit(wait=False)` | Returns immediately, you check state manually |
# | **Future** | `submit(lease_start_time=...)` | Reserves resources for a future time |
# | **Custom timeout** | `submit(wait_timeout=600, wait_interval=60)` | Blocking with custom timing |

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a single compute node with default resources.
#
# <img src="./figs/slice_topology.png" width="40%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration
#
# Every FABRIC notebook starts by importing the **FABlib** library and creating a `FablibManager` instance. The `show_config()` call prints your current configuration so you can verify that tokens, keys, and paths are set correctly.

# %%
# Import the FABlib library
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance -- this initializes the connection to FABRIC
fablib = fablib_manager()

# Display current configuration (tokens, keys, project info)
fablib.show_config();

# %% [markdown]
# ---
#
# ## Option 1: Create a Slice -- Basic (Blocking)
#
# The simplest way to create a slice. Calling `submit()` with no parameters will:
#
# 1. Send the topology request to FABRIC
# 2. **Block** (wait) until the slice is fully provisioned
# 3. Display a **progress indicator** as resources are allocated
# 4. Verify SSH access and test dataplane interfaces
#
# This is the recommended approach for most use cases.

# %%
# Create a new empty slice with the given name
slice = fablib.new_slice(name="MySlice1")

# Add a single node with default settings
# (random site, 2 cores, 8 GB RAM, 10 GB disk, default Ubuntu image)
node = slice.add_node(name="Node1")

# Submit the slice request to FABRIC
# This blocks until the slice is ready (~2-5 minutes) and shows progress
slice.submit();

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC received your request, found a site with available resources, created a virtual machine, installed the operating system, configured SSH access through the bastion host, and verified connectivity. The slice is now in the `StableOK` state and ready to use.
#
# </div>

# %% [markdown]
# ---
#
# ## Option 2: Create a Slice -- Wait Silently
#
# If you do not want the progress output (for example, in automated scripts), set `progress=False`. The call still **blocks** until the slice is ready, but does not print intermediate status updates.

# %%
# Create a new slice
slice = fablib.new_slice(name="MySlice2")

# Add a node with default settings
node = slice.add_node(name="Node1")

# Submit and wait silently (no progress output)
# The call still blocks until the slice is fully provisioned
slice_id = slice.submit(progress=False)

# Print the slice ID -- useful for referencing this slice later
print(f"slice_id: {slice_id}")

# %% [markdown]
# ---
#
# ## Option 3: Create a Slice -- Non-blocking Submit
#
# Setting `wait=False` makes the `submit()` call return **immediately** after sending the request to FABRIC. The slice will still be provisioning in the background. This is useful when:
#
# - You want to submit multiple slices in parallel
# - You want to do other work while the slice builds
# - You need fine-grained control over the waiting process
#
# <div class="fab-danger">
#
# **Important:** When using `wait=False`, the slice is **not ready** when `submit()` returns. You must manually wait for SSH access and run post-boot configuration before using the slice.
#
# </div>

# %%
# Create a new slice
slice = fablib.new_slice(name="MySlice3")

# Add a node with default settings
node = slice.add_node(name="Node1")

# Submit the request without waiting -- returns immediately
slice.submit(wait=False)

# Save the slice ID so we can retrieve it later
slice_id = slice.get_slice_id()

print(f"slice_id: {slice_id}")

# %% [markdown]
# ### Manually Check the Slice State
#
# After a non-blocking submit, you need to:
# 1. **Retrieve** the slice (to refresh its state from FABRIC)
# 2. **Wait for SSH** to become available on all nodes
# 3. **Run post-boot configuration** (e.g., dataplane network tests)

# %%
# Retrieve the slice by its ID (refreshes state from FABRIC)
slice = fablib.get_slice(slice_id=slice_id)

# Wait until SSH access is available on all nodes
# This blocks until you can SSH into every node in the slice
slice_id = slice.wait_ssh(progress=True)

print(f"slice_id: {slice_id}")

# Run post-boot configuration (e.g., test dataplane interfaces)
slice.post_boot_config();

# %% [markdown]
# ---
#
# ## Option 4: Create a Slice -- Requesting Resources in the Future
#
# You can reserve resources for a **future start time** using the `lease_start_time` parameter. This is useful when:
#
# - The resources you need are currently in use but will be available later
# - You want to schedule an experiment for a specific date/time
# - You need specialized hardware (e.g., SmartNICs) that is in high demand
#
# When submitted with a future start time, the slice enters the `AllocatedOK` state. When the lease becomes current, FABRIC provisions the resources and the slice transitions to `StableOK`.

# %% [markdown]
# ### Query Available Sites in the Future
#
# First, check which sites will have `NIC_ConnectX_5` or `NIC_ConnectX_6` SmartNICs available one day from now, then randomly select one of those sites.

# %%
from datetime import datetime
from datetime import timezone
from datetime import timedelta

# Calculate a start time one day in the future (UTC)
start = (datetime.now(timezone.utc) + timedelta(days=1))

# %%
# Specify which fields to display -- we only care about SmartNIC availability
fields=['name','nic_connectx_5_available','nic_connectx_6_available']

# %%
# List sites that have SmartNICs available at the future start time
smart_nic_sites = fablib.list_sites(fields=fields, start=start)

# Extract just the site names into a Python list
smart_nic_sites = smart_nic_sites.data['Name'].values.tolist()
print(f'All sites with NIC_ConnectX_5/NIC_ConnectX_6 available: {smart_nic_sites}')

# %%
import random

# Randomly select one of the available sites
if len(smart_nic_sites)==0:
    print('Warning - no sites with available NIC_ConnectX_5/NIC_ConnectX_6 found')
else:    
    print(f'Selecting a site at random among {smart_nic_sites}')
    site = random.choice(smart_nic_sites)

    print(f"Site chosen: {site}")

# %% [markdown]
# ### Submit the Slice with a Future Lease Start Time
#
# Pass the `lease_start_time` parameter to `submit()`. The slice will enter `AllocatedOK` state immediately. When the lease becomes current, the resources will be provisioned and the slice transitions to `StableOK`.

# %%
# Create a new slice
slice = fablib.new_slice(name="MySlice4")

# Add a node at the chosen site with two ConnectX-6 SmartNICs
node = slice.add_node(name="Node1", site=site)
node.add_component(model="NIC_ConnectX_6", name='nic1')  # First SmartNIC
node.add_component(model="NIC_ConnectX_6", name='nic2')  # Second SmartNIC

# Submit with a future start time -- resources are reserved, not yet provisioned
slice.submit(lease_start_time=start)

# Save the slice ID for later reference
slice_id = slice.get_slice_id()

print(f"slice_id: {slice_id}")

# %% [markdown]
# ---
#
# ## Additional Options: Validate a Slice Before Submitting
#
# Validation lets you catch configuration errors **before** sending the request to FABRIC. This saves time and avoids wasted resource reservations. There are two approaches:
#
# - **Inline validation** -- Validate each node as you add it (using `validate=True` in `add_node`)
# - **Batch validation** -- Build the entire topology first, then call `slice.validate()`
#
# <div class="fab-warning">
#
# **Tip:** Validation checks for errors like requesting a host that does not belong to the specified site, or combining incompatible GPU models on a single node. It does **not** guarantee resource availability at submit time.
#
# </div>

# %% [markdown]
# ### Inline Validation: Validate as Resources Are Added
#
# The following example demonstrates two validation behaviors:
#
# - **Node1**: Added with `validate=True` and `raise_exception=False`. If the node is invalid, it is **silently removed** from the slice (no exception thrown).
# - **Node2**: Added with `validate=True` and `raise_exception=True`. If the node is invalid, an **exception is raised** so you can handle the error.
#
# After both calls, `list_nodes()` confirms which nodes remain in the slice.

# %%
# Create a new slice for validation demonstration
slice = fablib.new_slice(name="MySlice")

# %%
# Add Node1 with inline validation -- raise_exception=False means:
# if invalid, remove the node silently instead of crashing
# This node requests a host that does not belong to the "MAX" site, so it is invalid

node1 = slice.add_node(name="Node1", site="MAX", host="gpn-w1.fabric-testbed.net", validate=True, raise_exception=False)

# %%
# Add Node2 with inline validation -- raise_exception=True means:
# if invalid, throw an exception so the error is visible
# This node requests both T4 and RTX6000 GPUs, which cannot coexist on the same host

node2 = slice.add_node(name="Node2", site="MAX", validate=True, raise_exception=True)
node2.add_component(model='NIC_Basic', name='nic2')
node2.add_component(model='GPU_RTX6000', name='gpu1')
node2.add_component(model='GPU_TeslaT4', name='gpu3')

# %%
# Verify which nodes remain in the slice
# Node1 was silently removed (invalid host); Node2 remains as requested
slice.list_nodes();

# %% [markdown]
# ### Batch Validation: Build Topology Then Validate
#
# Alternatively, you can build the entire topology first and then call `slice.validate()` to check everything at once. This approach reports **all** errors in a single call, which is convenient for complex topologies.

# %%
# Create a new slice
slice = fablib.new_slice(name="MySlice")

# Add Node1 -- invalid because the host does not belong to the "MAX" site
node1 = slice.add_node(name="Node1", site="MAX", host="gpn-w1.fabric-testbed.net")
# Here node1 is invalid request would be errored and removed from the slice

# Add Node2 -- invalid because T4 and RTX6000 GPUs cannot coexist on one worker
node2 = slice.add_node(name="Node2", site="MAX")
node2.add_component(model='NIC_Basic', name='nic2')
node2.add_component(model='GPU_RTX6000', name='gpu1')
node2.add_component(model='GPU_TeslaT4', name='gpu3')
# Here node2 is invalid request as you can not have T4 and RTX600 both on a single worker

# Validate the entire slice -- reports all errors found
# This call will report both the errors identified above
slice.validate()

# %% [markdown]
# ---
#
# ## Additional Options: Custom Timeouts and Retry Intervals
#
# For blocking submissions, you can customize how long to wait and how often to check:
#
# - `wait_timeout` -- Maximum time (in seconds) to wait for the slice to be ready (default: ~600s)
# - `wait_interval` -- Time (in seconds) between status checks (default: ~10s)
#
# Increasing the timeout is helpful for large, multi-node slices that take longer to provision.

# %%
# Create a new slice
slice = fablib.new_slice(name="MySlice5")

# Add a node with default settings
node = slice.add_node(name="Node1")

# Submit with a custom timeout of 600 seconds (10 minutes)
# and check status every 60 seconds instead of the default interval
slice_id = slice.submit(wait_timeout=600, wait_interval=60)

print(f"slice_id: {slice_id}")

# %% [markdown]
# ---
#
# ## Clean Up: Delete All Slices Created in This Notebook
#
# <div class="fab-danger">
#
# **Important:** Always delete your slices when you are done. FABRIC is a shared resource -- leaving slices running unnecessarily prevents other researchers from using those resources.
#
# </div>

# %%
# Delete all slices created in this notebook
# Each deletion is wrapped in try/except in case the slice was already deleted or never created

try:
    fablib.delete_slice("MySlice1")
except:
    pass

try:
    fablib.delete_slice("MySlice2")
except:
    pass

try:
    fablib.delete_slice("MySlice3")
except:
    pass

try:
    fablib.delete_slice("MySlice4")
except:
    pass

try:
    fablib.delete_slice("MySlice5")
except:
    pass

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | `submit()` times out | Site is busy or resources unavailable | Try a different site with `add_node(site='SITENAME')` or increase `wait_timeout` |
# | Slice stuck in `Configuring` | Large slice or slow site | Wait longer or check site status with `fablib.list_sites()` |
# | `validate()` reports host error | Host does not belong to the specified site | Verify site/host combinations using `fablib.list_sites()` |
# | `validate()` reports GPU conflict | Incompatible GPU models on same node | Check which GPU models are available per-host at each site |
# | `PDP Authorization check failed` | Project permissions issue | Contact your project lead or FABRIC support |
# | `Permission denied` on SSH after submit | Bastion key not configured | Check bastion private key path in `show_config()` output |
# | Future slice stays in `AllocatedOK` | Lease start time has not arrived yet | Wait until the scheduled start time; slice will auto-transition to `StableOK` |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `fablib.list_sites()` | List all FABRIC sites and available resources | [list_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.list_sites) |
# | `fablib.get_slice(slice_id)` | Retrieve an existing slice by ID | [get_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_slice) |
# | `fablib.delete_slice(name)` | Delete a slice by name | [delete_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.delete_slice) |
# | `slice.add_node(name)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `slice.validate()` | Validate the slice topology for errors | [validate](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.validate) |
# | `slice.submit()` | Submit the slice for provisioning | [submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit) |
# | `slice.get_slice_id()` | Get the slice's unique ID | [get_slice_id](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.get_slice_id) |
# | `slice.wait_ssh()` | Wait until SSH is available on all nodes | [wait_ssh](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.wait_ssh) |
# | `slice.post_boot_config()` | Run post-boot configuration tasks | [post_boot_config](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.post_boot_config) |
# | `slice.list_nodes()` | List all nodes in the slice | [list_nodes](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.list_nodes) |
# | `node.add_component()` | Add a component (NIC, GPU, etc.) to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |

# %% [markdown]
# ## What's Next?
#
# Now that you know how to create slices, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Customizing Nodes** | [customizing_nodes](../customizing_nodes/customizing_nodes.ipynb) | Set site, cores, RAM, disk, and OS image |
# | **Listing Slices** | [list_slices](../slices/list_slices.ipynb) | View and filter your active slices |
# | **Showing Slice Details** | [show_slice](../slices/show_slice.ipynb) | Inspect individual slice properties |
# | **Deleting Slices** | [delete_slice](../delete_slice/delete_slice.ipynb) | Multiple ways to delete slices |
# | **Renewing Slices** | [renew_slice](../renew_slice/renew_slice.ipynb) | Extend your slice's lease end date |
# | **Networking** | [FABnet IPv4](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb) | Connect nodes across sites with Layer 3 networking |
