# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Create a Local Ethernet (Layer 2) Network: Automatic Configuration
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **What this notebook does:** This notebook shows how to create an isolated **local Layer 2 Ethernet** network connecting two nodes on the **same** FABRIC site, using **automatic** IP configuration. FABlib assigns IP addresses from a subnet you specify and configures the interfaces during the post-boot phase.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Explain the difference between Layer 2 and Layer 3 networks in FABRIC
# 2. Create a local L2 network with `add_l2network()` and specify a subnet
# 3. Use **automatic configuration** (`set_mode('auto')`) for IP assignment on L2 networks
# 4. Verify connectivity between nodes on the same local Ethernet
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be comfortable creating basic slices (see [Hello, FABRIC](../../hello_fabric/hello_fabric.ipynb))
#
# **Tip -- Auto vs. Manual:** FABRIC offers two configuration approaches for L2 networks:
# - **Auto** (this notebook): You specify a subnet, FABlib assigns IPs from it and configures interfaces
# - **Manual** ([manual notebook](./create_l2network_basic_manual.ipynb)): You assign IPs yourself after the slice is active
#
# </div>

# %% [markdown]
# ## Background: Layer 2 vs. Layer 3 Networks
#
# FABRIC supports two types of networks:
#
# | Feature | Layer 2 (L2) | Layer 3 (L3 / FABnet) |
# |---------|-------------|----------------------|
# | **Scope** | Single site (local) or two sites (WAN) | All FABRIC sites |
# | **Protocol** | Raw Ethernet frames | IP routing |
# | **Addressing** | You choose the subnet | FABRIC assigns subnets |
# | **Routing** | No built-in routing | FABRIC backbone routing |
# | **Use case** | Custom protocols, VLANs, isolated experiments | Standard IP connectivity |
#
# A **local L2 network** is an isolated Ethernet segment within a single FABRIC site. It behaves like plugging two machines into the same switch -- they can communicate directly at Layer 2.
#
#
# ### Key Difference from L3 (FABnet)
# - L2 networks require you to **specify your own subnet** (e.g., `192.168.1.0/24`)
# - L3 FABnet networks have subnets **assigned by FABRIC**
# - L2 networks do **not** have a gateway or backbone routing
#
# ### NIC Component Models
#
# | Model | Speed | Type | Ports |
# |-------|-------|------|-------|
# | `NIC_Basic` | 100 Gbps | Mellanox ConnectX-6 SR-IOV VF | 1 |
# | `NIC_ConnectX_5` | 25 Gbps | Dedicated Mellanox ConnectX-5 | 2 |
# | `NIC_ConnectX_6` | 100 Gbps | Dedicated Mellanox ConnectX-6 | 2 |

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create two nodes on the same site connected by a local L2 Ethernet bridge.
#
# <img src="./figs/slice_topology.png" width="50%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration

# %%
# Import Python IP address management libraries
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

# Import the FABlib library
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance
fablib = fablib_manager()

# Display current configuration (tokens, keys, project info)
fablib.show_config();

# %% [markdown]
# ## Step 2: Define Slice Parameters
#
# For a local L2 network, both nodes must be on the **same site**. We pick one random site and place both nodes there.

# %%
# Name for the slice
slice_name = 'MySlice'

# Pick a single random site (both nodes will be on this site)
site = fablib.get_random_site()
print(f"Site: {site}")

# Node and network names
node1_name = 'Node1'
node2_name = 'Node2'

network_name='net1'

# %% [markdown]
# ## Step 3: Create the Slice with a Local L2 Network
#
# We create a local Ethernet by calling `add_l2network()` with a **subnet** parameter. This tells FABlib to use automatic configuration -- it will allocate IPs from this subnet and assign them during post-boot.
#
# Each node gets a NIC with its interface mode set to `auto`.
#
# <div class="fab-danger">
#
# **Important:** For a **local** L2 network, all interfaces must be on the **same site**. If you place interfaces on different sites, FABRIC will automatically create a **wide-area** L2 circuit instead (see the [WAN L2 notebook](../create_l2network_wide_area/create_l2network_wide_area_auto.ipynb)).
#
# </div>

# %%
# Create a new empty slice
slice = fablib.new_slice(name=slice_name)

# --- Create the L2 network with a user-defined subnet ---
# The subnet parameter enables auto-configuration: FABlib will assign IPs from this range
net1 = slice.add_l2network(name=network_name, subnet=IPv4Network("192.168.1.0/24"))

# --- Node1 ---
node1 = slice.add_node(name=node1_name, site=site)
# Add a NIC_Basic component and get its first (only) interface
iface1 = node1.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
# Set to 'auto' so FABlib assigns an IP from the subnet automatically
iface1.set_mode('auto')
# Connect the interface to the L2 network
net1.add_interface(iface1)

# --- Node2 ---
node2 = slice.add_node(name=node2_name, site=site)
iface2 = node2.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface2.set_mode('auto')
net1.add_interface(iface2)


# Submit the slice request -- blocks until ready (~3-5 min)
slice.submit();

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC created two VMs on the same site, connected them to a local Ethernet switch, and during post-boot, FABlib assigned IP addresses from the `192.168.1.0/24` subnet and configured the network interfaces inside each VM.
#
# </div>

# %% [markdown]
# ## Step 4: Run the Experiment
#
# With automatic configuration, the slice is ready for experimentation as soon as it becomes active. We verify connectivity by pinging Node2 from Node1.
#
# <div class="fab-warning">
#
# **Tip:** Automatic configuration works well when saving slices to a file and reinstantiating them. Configuration tasks are stored in the saved slice, reducing the complexity of notebooks and other runtime steps.
#
# </div>

# %%
# Retrieve the slice (useful if running this cell independently)
slice = fablib.get_slice(slice_name)

# Get the node objects
node1 = slice.get_node(name=node1_name)        
node2 = slice.get_node(name=node2_name)           

# Get Node2's automatically assigned IP address
node2_addr = node2.get_interface(network_name=network_name).get_ip_addr()

# Ping Node2 from Node1 over the local L2 network
stdout, stderr = node1.execute(f'ping -c 5 {node2_addr}')

# %% [markdown]
# ## Step 5: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. FABRIC is a shared resource -- leaving slices running unnecessarily prevents other researchers from using those resources.
#
# </div>

# %%
# Delete the slice and release all resources
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | Slice stuck in `Configuring` | Site may be busy or down | Try a different site by re-running `get_random_site()` |
# | `ping` fails between nodes | Interfaces not configured or wrong subnet | Check `ip addr show` on both nodes; verify `set_mode('auto')` was called |
# | `No resources available` | Site lacks NIC_Basic capacity | Choose a different site or try `NIC_ConnectX_6` |
# | `submit()` times out | Network issue or high demand | Retry with `slice.submit(wait_timeout=600)` |
# | Nodes on different sites unexpectedly | Forgot to specify the `site` parameter | Ensure both `add_node()` calls use the same `site` value |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_site()` | Get a random site name | [get_random_site](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_site) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `fablib.get_slice(name)` | Retrieve an existing slice by name | [get_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_slice) |
# | `slice.add_l2network(name, subnet)` | Add a Layer 2 network with a subnet | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `slice.add_node(name, site)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `slice.submit()` | Submit the slice for provisioning | [submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |
# | `node.add_component(model, name)` | Add a NIC or other component | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `iface.set_mode('auto')` | Enable automatic IP configuration | [set_mode](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_mode) |
# | `iface.get_ip_addr()` | Get the IP address assigned to an interface | [get_ip_addr](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.get_ip_addr) |
# | `network.add_interface(iface)` | Connect an interface to a network | [add_interface](https://fabric-fablib.readthedocs.io/en/latest/network_service.html#fabrictestbed_extensions.fablib.network_service.NetworkService.add_interface) |

# %% [markdown]
# ## What's Next?
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **L2 Basic Manual** | [create_l2network_basic_manual](./create_l2network_basic_manual.ipynb) | Assign IPs yourself for full control |
# | **L2 Wide-Area Auto** | [create_l2network_wide_area_auto](../create_l2network_wide_area/create_l2network_wide_area_auto.ipynb) | Extend L2 Ethernet across two sites |
# | **L2 Wide-Area Manual** | [create_l2network_wide_area_manual](../create_l2network_wide_area/create_l2network_wide_area_manual.ipynb) | WAN L2 with manual IP configuration |
# | **FABnet IPv4** | [create_l3network_fabnet_ipv4_auto](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb) | Layer 3 networking across all sites |
# | **Hello FABRIC** | [hello_fabric](../../hello_fabric/hello_fabric.ipynb) | Start from the basics |
