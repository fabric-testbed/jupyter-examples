# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # FABRIC Storage: Reserve and Benchmark
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to reserve and benchmark the different types of storage available on FABRIC. You will learn about local VM disks and dedicated NVMe drives, understand how OS and hypervisor caching affects performance measurements, and run progressively more accurate benchmarks to determine true storage throughput.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Reserve a FABRIC node with an **NVMe storage device**
# 2. **Partition, format, and mount** an NVMe PCI device using FABlib
# 3. Understand the difference between **local VM disk** and **dedicated NVMe** storage
# 4. Use `dd` to benchmark storage write performance
# 5. Understand how **OS file system caching** and **hypervisor block device caching** affect benchmarks
# 6. Use `oflag=direct` to bypass the VM's file system buffer
# 7. Write large files to amortize cache effects and measure true disk throughput
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Run the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be familiar with creating basic slices (see [Hello, FABRIC](../hello_fabric/hello_fabric.ipynb))
#
# **Tip:** Some benchmark tests in this notebook write very large files and may take **tens of minutes** to complete. Be patient and let them finish -- the longer tests produce the most accurate results.
#
# **Note:** Not all FABRIC sites have NVMe storage available. If slice creation fails, try a different site.
#
# </div>

# %% [markdown]
# ## Background: FABRIC Storage Types
#
# FABRIC provides three types of reservable storage:
#
# | Storage Type | Description | Performance | Access Method |
# |-------------|-------------|-------------|---------------|
# | **Local Disk (VM)** | Virtual disk provided by the hypervisor | ~200 MB/s write | Mounted at `/` by default |
# | **NVMe (dedicated PCI)** | Physical NVMe SSD passed through to your VM | 1-3 GB/s write | Raw PCI device, needs setup |
# | **Network Storage** | Coming Soon | TBD | TBD |
#
# ### Understanding Storage Caching
#
# When benchmarking storage, you must understand the caching layers that can inflate performance numbers:
#
#
# - **Local disk**: Has both caching layers. Use `oflag=direct` and large files to measure real performance.
# - **NVMe (PCI passthrough)**: Your VM controls the device directly -- no hypervisor cache. `oflag=direct` bypasses only the VM OS cache.

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a node with NVMe and local disk for benchmarking with fio.
#
# <img src="./figs/slice_topology.png" width="40%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration

# %%
# Import the FABlib library and create a manager instance
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

# Display current configuration (tokens, keys, project info)
fablib.show_config()

# %% [markdown]
# ## Step 2: Define Slice Parameters
#
# We create a single node with extra resources (4 cores, 16 GB RAM, 100 GB local disk) and attach an NVMe drive. The NVMe model `NVME_P4510` is an Intel P4510 1TB enterprise SSD.

# %%
# Slice and node configuration
slice_name="MySlice"
site=fablib.get_random_site()
node_name='Node1'
cores=4        # 4 CPU cores
ram=16         # 16 GB RAM
disk = 100     # 100 GB local disk

# NVMe component name
nvme_name='nvme1'

# %% [markdown]
# ## Step 3: Create the Slice with NVMe Storage
#
# We add the node and attach an NVMe drive using `add_component()` with the `NVME_P4510` model. The NVMe device is allocated as a dedicated PCI device passed through to your VM.

# %%
try:
    # Create a new slice
    slice = fablib.new_slice(name=slice_name)

    # Add a node with specified resources
    node = slice.add_node(name=node_name, cores=cores, ram=ram, disk=disk)
    
    # Add an NVMe drive (Intel P4510 1TB) as a dedicated PCI device
    node.add_component(model='NVME_P4510', name=nvme_name)

    # Submit the slice request (~2-5 minutes)
    slice.submit()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 4: Verify the Slice and Node
#
# Retrieve the slice and inspect the node and its NVMe component.

# %%
try:
    # Retrieve the slice by name
    slice = fablib.get_slice(name=slice_name)
    print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")

# %%
try:
    # Get the node and its NVMe component
    node = slice.get_node(node_name) 
    print(f"{node}")
  
    # Display NVMe component details (PCI address, device name, etc.)
    nvme1 = node.get_component(nvme_name)
    print(f"{nvme1}")
    
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 5: Configure the NVMe Device
#
# NVMe storage is provided as a bare PCI block device. Before use, it needs to be **partitioned, formatted, and mounted**. The `configure_nvme()` method handles all of this automatically, mounting the device at `/mnt/nvme_mount`.
#
# <div class="fab-warning">
#
# **Tip:** If you need custom partitioning or file system options, you can skip `configure_nvme()` and run the partition/format/mount commands manually via `node.execute()`.
#
# </div>

# %%
try:
    # Automatically partition, format (ext4), and mount the NVMe device
    # Mounts at /mnt/nvme_mount by default
    nvme1.configure_nvme()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Step 6: Benchmark Storage Devices
#
# We use `dd` to perform write benchmarks on both the local disk and the NVMe drive. While `dd` is not a comprehensive storage benchmark tool (consider `fio` for production testing), it effectively demonstrates the performance characteristics and caching behavior of FABRIC storage.
#
# ### 6a: Local Disk Benchmarks
#
# The local disk (`/dev/vda1`) is mounted at `/`. We write to `/tmp` to benchmark it. First, let's verify that `/tmp` is on the local disk.

# %%
# Verify that /tmp is on the local disk (/dev/vda1)
command = 'df /tmp'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Test 1: Write 1 GB to local disk (with OS cache)
#
# This first test writes a 1 GB file using default `dd` options. The result will likely show speeds **over 1 GB/s** -- much faster than the actual disk. This is because both the VM's OS file system cache and the hypervisor's block device cache absorb the write into RAM.

# %%
# Write 1 GB with default caching -- result will be inflated by OS buffer
command='dd if=/dev/zero of=/tmp/output bs=1G count=1'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Test 2: Write 1 GB to local disk (bypass VM OS cache)
#
# Adding `oflag=direct` bypasses the VM's file system cache, but the **hypervisor's block device cache** still applies. You may see speeds over 2.5 GB/s -- counterintuitively faster than Test 1, because the hypervisor cache can achieve higher bandwidth on its own than when combined with the VM's cache.

# %%
# Write 1 GB bypassing the VM's file system cache (hypervisor cache still active)
command='dd if=/dev/zero of=/tmp/output bs=1G count=1 oflag=direct'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Test 3: Write 5 GB to local disk
#
# To get closer to true disk performance, we need to write enough data to **fill the hypervisor cache** early in the write. The amortized performance over a larger file approaches the real block device speed.
#
# <div class="fab-warning">
#
# **Tip:** Larger writes produce more accurate results but take longer. Be patient!
#
# </div>

# %%
# Write 5 GB to start overwhelming the hypervisor cache
command='dd if=/dev/zero of=/tmp/output bs=5G count=1 oflag=direct'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Test 4: Write 25 GB to local disk

# %%
# Write 25 GB -- should show performance closer to true disk speed
command='dd if=/dev/zero of=/tmp/output bs=25G count=1 oflag=direct'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Test 5: Write a very large file (400 GB) to local disk
#
# The maximum `bs` value is limited by the VM's memory. For very large writes, use a reasonable `bs` with increased `count`. This test may take considerable time.
#
# <div class="fab-danger">
#
# **Warning:** This test writes 400 GB and may take **tens of minutes**. Be patient. If your tests are large enough, you should approach the true write bandwidth of the local disk, which is typically **a bit under 200 MB/s**.
#
# </div>

# %%
# Write 400 GB (25 GB x 16) to measure steady-state disk throughput
command='dd if=/dev/zero of=/tmp/output bs=25G count=16 oflag=direct'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### 6b: NVMe Benchmarks
#
# Now we benchmark the NVMe drive. Unlike the local disk, your VM has **direct control** of the NVMe PCI device (via PCI passthrough), so there is **no hypervisor cache**. Using `oflag=direct` bypasses only the VM OS cache, giving you measurements very close to true NVMe performance.
#
# ### Test 6: Write 1 GB to NVMe (with OS cache)

# %%
# Write 1 GB to NVMe with OS caching -- will be fast due to RAM buffer
command='sudo dd if=/dev/zero of=/mnt/nvme_mount/output bs=1G count=1'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Test 7: Write 1 GB to NVMe (bypass OS cache)

# %%
# Write 1 GB to NVMe bypassing OS cache -- closer to true NVMe speed
command='sudo dd if=/dev/zero of=/mnt/nvme_mount/output bs=1G count=1 oflag=direct'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Test 8: Write 5 GB to NVMe (bypass OS cache)

# %%
# Write 5 GB to NVMe bypassing OS cache
command='sudo dd if=/dev/zero of=/mnt/nvme_mount/output bs=5G count=1 oflag=direct'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Test 9: Write 100 GB to NVMe (bypass OS cache)
#
# This larger test confirms the NVMe's sustained write throughput. You should see **much higher bandwidths** than the local disk -- typically 1-3 GB/s depending on the specific drive and site.

# %%
# Write 100 GB to NVMe to measure sustained throughput
command='sudo dd if=/dev/zero of=/mnt/nvme_mount/output bs=1G count=100 oflag=direct'
try:
    stdout, stderr = node.execute(command)
    print(f"stdout: {stdout}")
    print(f"stderr: {stderr}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Step 7: Clean Up
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. NVMe devices are a limited resource -- leaving slices running prevents other researchers from using them.
#
# </div>

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | Slice creation fails with NVMe | Site has no NVMe available | Try a different site; use `fablib.list_sites()` to check NVMe availability |
# | `configure_nvme()` fails | Device not detected after boot | Wait a minute and retry; check `lsblk` output on the node |
# | `dd` reports `No space left on device` | Output file exceeds disk capacity | Reduce `bs` or `count`; local disk is limited to the `disk` parameter size |
# | `dd` hangs or is very slow | Writing extremely large file | This is expected for large writes to local disk (~200 MB/s); be patient |
# | NVMe write speed is low | OS cache not bypassed | Add `oflag=direct` to the `dd` command |
# | Permission denied on NVMe | Need root for `/mnt/nvme_mount` | Prefix command with `sudo` |
# | `bs` value too large error | Block size exceeds available RAM | Reduce `bs` and increase `count` to achieve the same total write size |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_site()` | Select a random FABRIC site | [get_random_site](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_site) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_node(name, cores, ram, disk)` | Add a compute node with specified resources | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component(model, name)` | Add an NVMe or other component to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `fablib.get_slice(name)` | Retrieve an existing slice by name | [get_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_slice) |
# | `slice.get_node(name)` | Get a node from the slice | [get_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.get_node) |
# | `node.get_component(name)` | Get a component from the node | [get_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.get_component) |
# | `component.configure_nvme()` | Partition, format, and mount an NVMe device | [configure_nvme](https://fabric-fablib.readthedocs.io/en/latest/component.html#fabrictestbed_extensions.fablib.component.Component.configure_nvme) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you understand FABRIC storage options and benchmarking, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Customizing Nodes** | [customizing_nodes](../customizing_nodes/customizing_nodes.ipynb) | Set site, cores, RAM, disk, and OS image |
# | **GPUs** | [fabric_gpu](../fabric_all_gpus/fabric_gpu.ipynb) | Reserve and use NVIDIA GPUs on FABRIC |
# | **L2 Networking** | [create_l2network_basic_config](../create_l2network_basic/create_l2network_basic_config.ipynb) | Create isolated L2 networks between nodes |
# | **Wide-Area Networking** | [create_l2network_wide_area_config](../create_l2network_wide_area/create_l2network_wide_area_config.ipynb) | Connect nodes across FABRIC sites |
# | **Running Commands** | [execute_commands](../ssh_to_nodes/execute_commands.ipynb) | Execute commands, capture output, use threads |
