# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # Provisioning a Xilinx FPGA U280 on FABRIC
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to reserve a single **Xilinx Alveo U280 FPGA** on the FABRIC testbed. You will create a slice containing a VM with a PCI-passthrough FPGA device, verify the FPGA is accessible via PCI and USB (JTAG), and learn about key constraints around FPGA programming on shared infrastructure.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Find FABRIC sites that have available Xilinx U280 FPGAs
# 2. Create a slice with a VM that has a PCI-passthrough FPGA attached
# 3. Verify FPGA presence using `lspci` and `lsusb` commands
# 4. Understand the constraints of FPGA bitfile programming on shared servers
# 5. Clean up FPGA slices properly
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Have a project with the **`Component.FPGA`** permission tag (contact your project lead to request this)
# 3. **Optional but recommended**: Set up a persistent storage volume for Xilinx tools using the [FPGA Tools Storage](fpga_tools_storage.ipynb) notebook -- transferring large tool packages over the network is slow, and persistent storage keeps them inside FABRIC
#
# **Xilinx Toolchain**: Programming FPGAs requires a licensed toolchain from Xilinx/AMD. FABRIC staff cannot help you obtain licenses. You or your research lead must either purchase tools from Xilinx or register with the [AMD University Program (AUP/XUP)](https://www.xilinx.com/support/university.html) and request a donation.
#
# </div>

# %% [markdown]
# ## Background: FPGAs on FABRIC
#
# **Field-Programmable Gate Arrays (FPGAs)** are reconfigurable silicon devices that can implement custom hardware logic. Unlike CPUs that execute software instructions sequentially, FPGAs execute operations in parallel on dedicated hardware circuits, making them ideal for:
#
# - **Network packet processing** at line rate (100 Gbps+)
# - **Machine learning inference** with custom precision
# - **Scientific computing** with application-specific accelerators
# - **Cryptography** and security research
#
# The **Xilinx Alveo U280** is a data-center-class FPGA card with:
# - Xilinx UltraScale+ architecture
# - 8 GB HBM2 memory + 32 GB DDR4
# - Two 100 GbE QSFP28 network ports
# - PCIe Gen3/Gen4 host interface
# - JTAG-over-USB for programming and debugging
#
# ```
# +-------------------------------------------------+
# |                  Your Slice                      |
# |                                                  |
# |   +------------+       +-----------------+       |
# |   |  fpga-node |------>| Xilinx U280     |       |
# |   |  (VM)      | PCI   | - 2x 100GbE     |       |
# |   |  100G disk |       | - HBM2 + DDR4   |       |
# |   +------------+       | - JTAG-over-USB  |       |
# |                        +-----------------+       |
# +-------------------------------------------------+
# ```
#
# FABRIC makes FPGAs available via **PCI passthrough**, giving your VM direct hardware access to the FPGA device.

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a single node with a Xilinx U280 FPGA.
#
# <img src="./figs/slice_topology.png" width="40%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration
#
# Every FABRIC notebook starts by importing the FABlib library and verifying your configuration.

# %%
# Import the FABlib library
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance
fablib = fablib_manager()

# Display current configuration (tokens, keys, project info)
fablib.show_config();

# %% [markdown]
# ## Step 2: Select a Site with an Available FPGA
#
# Not all FABRIC sites have FPGAs. We use `list_sites()` with a filter function to find sites that currently have a Xilinx U280 available. The filter checks the `fpga_u280_available` column, which reports real-time availability.

# %%
# Define which FPGA model we want
FPGA_CHOICE='FPGA_Xilinx_U280'

# Map the FPGA model name to the corresponding availability column
# in the site listing dataframe
choice_to_column = {
    "FPGA_Xilinx_U280": "fpga_u280_available",
}

column_name = choice_to_column.get(FPGA_CHOICE, "Unknown")
print(f'{column_name=}')

# %% [markdown]
# Give the slice and node meaningful names so they are easy to identify later.

# %%
# Name the slice and the node
slice_name=f'My Simple FPGA Slice with {FPGA_CHOICE}'
node_name='fpga-node'

print(f'Will create slice "{slice_name}" with node "{node_name}"')

# %% [markdown]
# Query available sites and randomly select one that has a free FPGA. You can optionally restrict the search to specific sites by setting `allowed_sites`.

# %%
import random

# Optionally restrict to specific sites (set to None for all sites)
#allowed_sites = ['MAX', 'INDI']
allowed_sites = None

# Query sites, filtering for those with at least one available FPGA
fpga_sites_df = fablib.list_sites(output='pandas', quiet=True, filter_function=lambda x: x[column_name] > 0)

# Extract site names from the styled dataframe
# Note: list_sites with 'pandas' returns a Styler object, not a raw DataFrame;
# access the underlying data via .data
fpga_sites = fpga_sites_df.data['Name'].values.tolist()
print(f'All sites with FPGA available: {fpga_sites}')

if len(fpga_sites)==0:
    print('Warning - no sites with available FPGAs found')
else:
    # If allowed_sites is set, intersect with available sites
    if allowed_sites and len(allowed_sites) > 0:
        fpga_sites = list(set(fpga_sites) & set(allowed_sites))
    
    print('Selecting a site at random' + f' among {allowed_sites}' if allowed_sites else '')
    site = random.choice(fpga_sites)
    print(f'Preparing to create slice "{slice_name}" with node {node_name} in site {site}')

# %% [markdown]
# ## Step 3: Create the Slice with an FPGA
#
# We create a slice with a single VM node that has:
# - **100 GB disk** -- enough space for Xilinx tools and build artifacts
# - **An attached FPGA** component using `add_component(model=FPGA_CHOICE)`
#
# The FPGA is connected to the VM via PCI passthrough, giving your VM direct hardware access.

# %%
# Create a new slice
slice = fablib.new_slice(name=slice_name)

# Add a node with a 100 GB disk at the selected site
# (default CPU cores and RAM are sufficient for basic FPGA work)
node = slice.add_node(name=node_name, site=site, disk=100)

# Attach the Xilinx U280 FPGA to the node via PCI passthrough
node.add_component(model=FPGA_CHOICE, name='fpga1')

# Submit the slice request and wait for provisioning (~2-5 minutes)
slice.submit();

# %% [markdown]
# <div class="fab-success">
#
# **What just happened?** FABRIC provisioned a VM at the selected site and attached the Xilinx U280 FPGA to it via PCI passthrough. The VM has direct hardware access to the FPGA's PCI device(s) and its JTAG-over-USB interface.
#
# </div>

# %% [markdown]
# ## Step 4: Inspect the Slice and Node
#
# Retrieve the slice and verify it is active, then inspect the node and the FPGA component.

# %%
# Retrieve the slice by name
slice = fablib.get_slice(name=slice_name)
slice.show();

# %%
# Get the node and display its details
node = slice.get_node(node_name) 
node.show()

# Get the FPGA component and display its details
# This shows the PCI device address, VLAN tags, and other metadata
fpga = node.get_component('fpga1')
fpga.show();

# %% [markdown]
# ## Step 5: Verify FPGA PCI and USB Devices
#
# We use standard Linux tools to confirm the FPGA is properly attached:
#
# - **`lspci`** lists PCI devices -- you should see one or more Xilinx entries (the number depends on the currently loaded bitfile and its PCI configuration)
# - **`lsusb`** lists USB devices -- you should see an FTDI device (`0403:6011`) which is the JTAG-over-USB interface used for FPGA programming

# %%
# Install PCI and USB utilities (if not already present)
command = "sudo dnf install -q -y pciutils usbutils"
stdout, stderr = node.execute(command)

# Check for Xilinx PCI devices
print('Checking to see if Xilinx PCI device(s) are present')
command = "lspci | grep 'Xilinx'"
stdout, stderr = node.execute(command)

# Check for JTAG-over-USB (FTDI FT4232H chip used by Xilinx)
print('Checking to see if JTAG-over-USB is available')
command = "lsusb -d 0403:6011"
stdout, stderr = node.execute(command)

# %% [markdown]
# <div class="fab-success">
#
# **Success!** If you see Xilinx PCI device(s) and the FTDI USB device above, your FPGA is properly attached and accessible from your VM.
#
# </div>

# %% [markdown]
# ## Important: FPGA Programming Constraints
#
# <div class="fab-danger">
#
# **Do NOT reprogram the FPGA bitfile** unless you have previously discussed this with FABRIC staff. Here is why:
#
# - Changing the bitfile may alter the **PCI BAR sizes and functions** of the FPGA device
# - This can cause the underlying Dell server to **automatically reboot**
# - A server reboot affects **all VMs on that server**, disrupting other users' experiments
#
# **When is it safe to change the bitfile?**
#
# It is safe if you know that the new bitfile has the **same PCI functions and BAR sizes** as the currently loaded bitfile. In that case:
# 1. Load the new bitfile
# 2. Reboot the VM (not the server) to activate it
# 3. Your experiment can proceed
#
# </div>

# %% [markdown]
# ## Step 6: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are finished. FPGAs are scarce resources on FABRIC -- leaving a slice running prevents other researchers from using the FPGA.
#
# </div>

# %%
# Delete the slice and release all resources (including the FPGA)
fablib.delete_slice(slice_name)

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | No sites with available FPGAs found | All FPGAs are currently in use | Wait and retry later, or check the [FABRIC portal](https://portal.fabric-testbed.net/) for resource availability |
# | `lspci` shows no Xilinx devices | PCI passthrough not configured correctly | Delete the slice and recreate it; if persistent, contact FABRIC support |
# | `lsusb` shows no FTDI device | JTAG-over-USB not available | The JTAG interface may not be passed through on all configurations; contact FABRIC support |
# | Slice submission fails with permission error | Missing `Component.FPGA` tag | Ask your project lead to request the FPGA permission tag |
# | Server rebooted unexpectedly | Bitfile change altered PCI BAR sizes | Do not reprogram the FPGA without coordinating with FABRIC staff |
# | Slow file transfers to/from VM | Large Xilinx tool packages | Use [persistent storage](fpga_tools_storage.ipynb) to keep tools inside FABRIC |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.list_sites()` | List FABRIC sites with optional filtering | [list_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.list_sites) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_node(name, site, disk)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component(model, name)` | Attach a component (FPGA, GPU, NIC) to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `slice.submit()` | Submit the slice for provisioning | [submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit) |
# | `fablib.get_slice(name)` | Retrieve an existing slice by name | [get_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_slice) |
# | `node.get_component(name)` | Get a component attached to a node | [get_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.get_component) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `fablib.delete_slice(name)` | Delete a slice and release resources | [delete_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.delete_slice) |

# %% [markdown]
# ## What's Next?
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **FPGA Tools Storage** | [fpga_tools_storage](fpga_tools_storage.ipynb) | Create persistent storage for Xilinx tool packages |
# | **FPGA with P4** | [fpga_simple_p4](fpga_simple_p4.ipynb) | Use an FPGA with P4 networking and ESnet workflow |
# | **GPUs on FABRIC** | [fabric_gpu](../fabric_all_gpus/fabric_gpu.ipynb) | Use NVIDIA GPUs for accelerated computing |
# | **Customizing Nodes** | [customizing_nodes](../customizing_nodes/customizing_nodes.ipynb) | Set site, cores, RAM, disk, and OS image |
