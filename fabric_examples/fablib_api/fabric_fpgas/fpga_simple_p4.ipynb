# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # FPGA with P4 Networking Using ESnet Workflow
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to provision a **Xilinx U280 FPGA** alongside a **ConnectX-6 SmartNIC** on FABRIC, connect them via L2Bridge networks, and deploy a P4 application using the **ESnet SmartNIC firmware workflow**. By the end, you will have a working setup that can generate and capture network traffic between the FPGA and the SmartNIC.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Create a two-node slice with an FPGA and a ConnectX-6 NIC connected via L2Bridge networks
# 2. Configure IOMMU and hugepages for DPDK-based FPGA operation
# 3. Install Docker Compose and load pre-built ESnet containers
# 4. Build and deploy a P4 application using the ESnet SmartNIC firmware workflow
# 5. Test FPGA CMACs and run packet generation (pktgen) experiments
# 6. Capture traffic on the ConnectX-6 node using tcpdump
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Complete the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Have a project with the **`Component.FPGA`** permission tag
# 3. Have familiarity with the [basic FPGA provisioning](fpga_u280_simple.ipynb) workflow
# 4. **Optional**: Set up a persistent storage volume for pre-built Docker containers and P4 artifacts using the [FPGA Tools Storage](fpga_tools_storage.ipynb) notebook
#
# **Important**: This notebook uses the `docker_ubuntu_20` image and requires Docker Compose. The ESnet SmartNIC firmware build process requires pre-built `smartnic-dpdk-docker` and `xilinx-labtools-docker` container images, as well as a P4 artifact file.
#
# </div>

# %% [markdown]
# ## Background: FPGA P4 Networking with ESnet
#
# The **ESnet SmartNIC firmware** project provides an open-source framework for running P4 programs on Xilinx Alveo U280 FPGAs. The workflow involves:
#
# 1. **P4 Compilation** -- A P4 program is compiled into a hardware artifact (bitfile) that programs the FPGA's packet-processing pipeline
# 2. **Docker-based Deployment** -- ESnet packages the tools into Docker containers:
#    - `xilinx-labtools-docker` -- Xilinx JTAG/programming tools
#    - `smartnic-dpdk-docker` -- DPDK-based packet generation and capture
#    - `esnet-smartnic-fw` -- The firmware stack that ties everything together
# 3. **VFIO/DPDK** -- The FPGA is accessed from userspace via VFIO (Virtual Function I/O), which requires IOMMU and hugepages
#
# ### Slice Topology
#
# ```
# +-----------------------------------------------------------+
# |                     Your Slice (same site)                |
# |                                                           |
# |  +-----------+    L2Bridge 1    +------------+            |
# |  | fpga-node |---- port 0 ---->| cx-6-node  |            |
# |  | (U280)    |    L2Bridge 2    | (CX-6 NIC) |            |
# |  |           |---- port 1 ---->|            |            |
# |  +-----------+                  +------------+            |
# |                                                           |
# +-----------------------------------------------------------+
# ```
#
# Both the U280 FPGA and the ConnectX-6 NIC have **two ports each**. We connect them with two separate L2Bridge networks, creating two independent data paths for bidirectional traffic testing.

# %% [markdown]
# ## What We're Building
#
# In this notebook we will create a single node with a Xilinx U280 FPGA programmed using P4 and the ESnet framework.
#
# <img src="./figs/slice_topology.png" width="40%">

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration

# %%
# Import the FABlib library
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Create a FABlib manager instance
fablib = fablib_manager()

# Display current configuration
fablib.show_config();

# %% [markdown]
# ## Step 2: Select a Site with an Available FPGA
#
# Find sites that have at least one Xilinx U280 FPGA available. Both nodes must be at the same site since L2Bridge is a local (intra-site) network service.

# %%
# Define the FPGA and SmartNIC models
FPGA_CHOICE='FPGA_Xilinx_U280'
SMART_NIC_CHOICE='NIC_ConnectX_6'

# Map FPGA model to the availability column name used in site listings
choice_to_column = {
    "FPGA_Xilinx_U280": "fpga_u280_available",
}

column_name = choice_to_column.get(FPGA_CHOICE, "Unknown")
print(f'{column_name=}')

# %% [markdown]
# Define slice, node, and network names. Optionally enable persistent storage for pre-built containers and artifacts.

# %%
# Name the slice and the nodes
slice_name=f'My Simple FPGA with P4 Slice with {FPGA_CHOICE}'

# Set to True if your project has a persistent storage volume with
# pre-built Docker containers and P4 artifacts at the target site
use_storage = False

if use_storage:
    storage_name='xilinx-tools'
    mount_point = 'xilinx-tools'
    
# Node and network names
fpga_node_name='fpga-node'
cx6_node_name='cx-6-node'
l2bridge1_name='l2bridge1'
l2bridge2_name='l2bridge2'

print(f'Will create slice "{slice_name}" with node "{fpga_node_name}" and node "{cx6_node_name}"')

# %% [markdown]
# Query available sites and select one. The `allowed_sites` list can restrict the search (e.g., `['CLEM']` for a site known to work with this workflow).

# %%
import random

# Restrict to specific sites if needed (set to None for all sites)
allowed_sites = ['CLEM']
#allowed_sites = None

# Query sites with available FPGAs
fpga_sites_df = fablib.list_sites(output='pandas', quiet=True, filter_function=lambda x: x[column_name] > 0, force_refresh=True)

# Extract site names from the styled dataframe
if fpga_sites_df:
    fpga_sites = fpga_sites_df.data['Name'].values.tolist()
else:
    fpga_sites = []
print(f'All sites with FPGA available: {fpga_sites}')

if len(fpga_sites)==0:
    print('Warning - no sites with available FPGAs found')
else:
    # Intersect with allowed sites if specified
    if allowed_sites and len(allowed_sites) > 0:
        fpga_sites = list(set(fpga_sites) & set(allowed_sites))
    if len(fpga_sites) == 0:
        print('Unable to find sites with available FPGAs')
    else:
        print('Selecting a site at random ' + f'among {allowed_sites}' if allowed_sites else '')

        site = random.choice(fpga_sites)
        print(f'Preparing to create slice "{slice_name}" with nodes {fpga_node_name} and {cx6_node_name} in site {site}')
        
# Uncomment to override site selection:
#site = 'RENC'

# %% [markdown]
# ## Step 3: Create the Slice
#
# This slice has two VMs at the same site:
# - **fpga-node**: Has the U280 FPGA attached (2 ports) and 8 CPU cores for running Docker builds
# - **cx-6-node**: Has a ConnectX-6 NIC attached (2 ports) for traffic reception
#
# The two FPGA ports and two CX-6 ports are connected pairwise via **L2Bridge** networks. L2Bridge provides a Layer 2 bridged connection between interfaces at the same site.

# %%
# Create the slice
slice = fablib.new_slice(name=slice_name)
image = 'docker_ubuntu_20'

# --- FPGA Node ---
# 8 cores needed for Docker builds; 100G disk for containers and artifacts
node1 = slice.add_node(name=fpga_node_name, site=site, cores=8, ram=8, disk=100, image=image)
if use_storage:
    node1.add_storage(name=storage_name)

# Attach the FPGA -- it exposes two 100GbE interfaces
fpga_comp = node1.add_component(model=FPGA_CHOICE, name='fpga1')
fpga_p1 = fpga_comp.get_interfaces()[0]  # FPGA port 0 (CMAC 0)
fpga_p2 = fpga_comp.get_interfaces()[1]  # FPGA port 1 (CMAC 1)

# --- ConnectX-6 Node ---
# This node receives/sends traffic to/from the FPGA
node2 = slice.add_node(name=cx6_node_name, site=site, cores=8, disk=100, image=image)
cx6_comp = node2.add_component(model=SMART_NIC_CHOICE, name='nic1')
cx6_p1 = cx6_comp.get_interfaces()[0]  # CX-6 port 0
cx6_p2 = cx6_comp.get_interfaces()[1]  # CX-6 port 1

# --- L2Bridge Networks ---
# Connect FPGA port 0 <-> CX-6 port 0 (bridge 1)
net1 = slice.add_l2network(name=l2bridge1_name, interfaces=[fpga_p1, cx6_p1], type='L2Bridge')
# Connect FPGA port 1 <-> CX-6 port 1 (bridge 2)
net2 = slice.add_l2network(name=l2bridge2_name, interfaces=[fpga_p2, cx6_p2], type='L2Bridge')

# Submit and wait for provisioning
slice.submit();

# %% [markdown]
# ## Step 4: Configure IOMMU and Hugepages
#
# **DPDK** (Data Plane Development Kit) requires two kernel features to function:
#
# - **IOMMU** (Input-Output Memory Management Unit) -- Allows safe userspace access to hardware devices by translating device memory addresses
# - **Hugepages** -- Pre-allocates large memory pages (1 GB each) to reduce TLB misses and improve DMA performance
#
# We modify the GRUB boot configuration and reboot the FPGA node to activate these settings.

# %%
# Retrieve the slice and FPGA node
slice = fablib.get_slice(name=slice_name)
node1 = slice.get_node(name=fpga_node_name)

# Modify GRUB to enable IOMMU and allocate 8x 1GB hugepages
commands = list()
commands.append("sudo sed -i 's/GRUB_CMDLINE_LINUX=\"\"/GRUB_CMDLINE_LINUX=\"amd_iommu=on iommu=pt default_hugepagesz=1G hugepagesz=1G hugepages=8\"/' /etc/default/grub")
commands.append("sudo grub-mkconfig -o /boot/grub/grub.cfg")
commands.append("sudo update-grub")

for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node1.execute(command)
    
print('Done')

# %% [markdown]
# ### Reboot to Apply GRUB Changes
#
# <div class="fab-warning">
#
# **Tip:** The reboot command may generate an `EOFError` exception because the SSH connection drops. This is expected -- ignore it and continue. The `wait_ssh()` call will block until the node is accessible again.
#
# </div>

# %%
# Reboot the FPGA node to apply kernel boot parameters
reboot = 'sudo reboot'

print(reboot)
node1.execute(reboot)

# Wait for SSH to become available again (up to 6 minutes)
slice.wait_ssh(timeout=360,interval=10,progress=True)

# Verify SSH connectivity after reboot
print("Now testing SSH abilites to reconnect...",end="")
slice.update()
slice.test_ssh()
print("Reconnected!")

# %% [markdown]
# ### Verify IOMMU Is Active
#
# Check the kernel ring buffer (`dmesg`) for IOMMU detection messages.

# %%
# Verify IOMMU is detected in the kernel log
command = 'dmesg | grep -i IOMMU'

print('Observe that the modifications to boot configuration took place and IOMMU is detected')
stdout, stderr = node1.execute(command)

# Apply any post-boot network configuration
node1.config()

# %% [markdown]
# ### Enable VFIO No-IOMMU Mode
#
# Although we enabled IOMMU in the kernel, the VFIO passthrough in the VM does not fully support it. We enable **unsafe no-IOMMU mode** for VFIO, which allows DPDK to bind to the FPGA device without full IOMMU translation.

# %%
# Enable unsafe_noiommu_mode for the VFIO module
# This is required because full IOMMU passthrough does not work in the VM
command = "echo 1 | sudo tee /sys/module/vfio/parameters/enable_unsafe_noiommu_mode"

stdout, stderr = node1.execute(command)

# %% [markdown]
# ## Step 5: Install Docker Compose
#
# The ESnet SmartNIC firmware uses Docker Compose to orchestrate multiple containers. We install Docker Compose v2 and Docker Buildx as CLI plugins.

# %%
# Install Docker Compose and Buildx as CLI plugins
commands = ["sudo usermod -G docker ubuntu", 
            "mkdir -p ~/.docker/cli-plugins/",
            "curl -SL https://github.com/docker/compose/releases/download/v2.17.2/docker-compose-linux-x86_64 -o ~/.docker/cli-plugins/docker-compose",
            "chmod +x ~/.docker/cli-plugins/docker-compose",
            "curl -SL https://github.com/docker/buildx/releases/download/v0.11.2/buildx-v0.11.2.linux-amd64 -o ~/.docker/cli-plugins/docker-buildx",
            "chmod +x ~/.docker/cli-plugins/docker-buildx",
            "docker compose version",
            "docker container ps"
           ]

for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node1.execute(command)
    
print('Done')

# %% [markdown]
# ## Step 6: Mount Persistent Storage (If Used)
#
# If you have a persistent storage volume with pre-built containers and artifacts, mount it now.

# %%
# Mount the persistent storage volume if configured
if use_storage:

    storage = node1.get_storage(storage_name)

    stdout,stderr = node1.execute(f"sudo mkdir -p /mnt/{mount_point}; sudo chmod go+rw /mnt/{mount_point};"
                                  f"sudo mount {storage.get_device_name()} /mnt/{mount_point}; "
                                  f"df -h")
else:
    print("Storage not specified, skipping")

# %% [markdown]
# ## Step 7: Load Docker Containers and P4 Artifacts
#
# The ESnet workflow requires three Docker images:
# 1. **smartnic-dpdk-docker** -- DPDK-based packet generator
# 2. **xilinx-labtools-docker** -- Xilinx JTAG and programming tools
# 3. **esnet-smartnic-fw** -- The firmware container (built in the next step)
#
# If using persistent storage, we load pre-built images. Otherwise, you must build or download them manually.

# %%
# Load pre-built Docker containers from persistent storage,
# or instruct the user to build them manually
if use_storage:
    # Container image tarballs and P4 artifact stored on the volume
    dpdk_docker = 'smartnic-dpdk-docker.tar.gz'
    xilinx_labtools_docker = 'xilinx-labtools-docker-2023.1_0507_1903.tar.gz'
    artifact = '/mnt/xilinx-tools/artifacts/msada/v0/artifacts.au280.p4_only.0.zip'
    
    commands = [
        f"docker load < /mnt/{mount_point}/esnet-dockers/{dpdk_docker}",
        f"docker load < /mnt/{mount_point}/esnet-dockers/{xilinx_labtools_docker}",
        f"docker image ls",
        f"cp {artifact} ~/"
    ]
    for command in commands:
        print(f'Executing {command}')
        stdout, stderr = node1.execute(command)
else:
    print('Please build dpdk, xilinx-labtools dockers and install them on fpga-node manually, also place your artifact file in ~/')

# %% [markdown]
# ## Step 8: Clone ESnet SmartNIC Firmware and Build
#
# We clone the [esnet-smartnic-fw](https://github.com/esnet/esnet-smartnic-fw) repository, configure the environment file with the P4 artifact parameters, and build the firmware container.
#
# The `.env` file tells the build system:
# - `SN_HW_VER` -- Hardware version (from the artifact filename)
# - `SN_HW_BOARD` -- Board type (`au280` for Alveo U280)
# - `SN_HW_APP_NAME` -- Application name (e.g., `p4_only`)

# %%
# Clone the ESnet SmartNIC firmware repo and configure it
# The artifact filename (e.g., artifacts.au280.p4_only.0.zip) encodes
# the board, app name, and version that must match the .env file

env_file = """
SN_HW_VER=0
SN_HW_BOARD=au280
SN_HW_APP_NAME=p4_only
"""

# Update artifact name to match your file
artifact = '~/artifacts.au280.p4_only.0.zip'

commands = [
    "git clone https://github.com/esnet/esnet-smartnic-fw.git",
    "cd ~/esnet-smartnic-fw; git submodule init; git submodule update",
    f"cp {artifact} ~/esnet-smartnic-fw/sn-hw/",
    f"echo '{env_file}' | sudo tee ~/esnet-smartnic-fw/.env",
]

for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node1.execute(command)

# %% [markdown]
# ### Build the Firmware Container
#
# The `build.sh` script builds the `esnet-smartnic-fw` Docker container. This may take several minutes. We use `execute_thread()` to run it asynchronously and log output to a file.

# %%
# Build the esnet-smartnic-fw container (may take several minutes)
# Output is logged to esnet-smartnic-fw-docker.log
node_thread = node1.execute_thread("cd ~/esnet-smartnic-fw/; ./build.sh", output_file='esnet-smartnic-fw-docker.log')
stdout, stderr = node_thread.result()

# %% [markdown]
# ### Verify the Build
#
# You should see three Docker images: `esnet-smartnic-fw`, `smartnic-dpdk`, and `xilinx-labtools`.

# %%
# List Docker images to verify the build succeeded
command = "docker image ls"
stdout, stderr = node1.execute(command)

# %% [markdown]
# ## Step 9: Flash the FPGA and Test CMACs
#
# We use the `smartnic-mgr-vfio-unlock` Docker Compose profile to:
# 1. Flash the FPGA with the compiled P4 bitfile
# 2. Bind the FPGA to VFIO for userspace access
# 3. Access `sn-cli` to verify CMAC (100GbE MAC) status
#
# The `FPGA_PCIE_DEV` environment variable tells the stack which PCI device to target.

# %%
# Configure the Docker Compose environment and start the stack
env_file = """
FPGA_PCIE_DEV=0000:00:1f
COMPOSE_PROFILES=smartnic-mgr-vfio-unlock
"""

# Append FPGA PCI device and profile to the existing .env file
commands = [
    f"echo '{env_file}' | tee -a ~/esnet-smartnic-fw/sn-stack/.env",
    "cd ~/esnet-smartnic-fw/sn-stack; docker compose up -d"
]

for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node1.execute(command)

# %% [markdown]
# ### Run Health Checks
#
# Check the container logs for errors. A clean output means the FPGA binding succeeded.

# %%
# Check container logs for binding errors
stdout, stderr = node1.execute("cd esnet-smartnic-fw/sn-stack/; docker container logs sn-stack-ubuntu-smartnic-devbind-1")

# %% [markdown]
# ### Test sn-cli and Configure CMACs
#
# The `sn-cli` tool provides direct access to the FPGA's SmartNIC registers. If the output shows `0x0000` or `0xffff` values, the VFIO binding did not work correctly.

# %%
# Check the FPGA device version via sn-cli
# If you see all 0x0000 or 0xffff, VFIO binding failed
command = "cd esnet-smartnic-fw/sn-stack/; docker compose exec smartnic-fw sn-cli dev version"

stdout, stderr = node1.execute(command)

# %% [markdown]
# ### Configure CMACs
#
# Upload and run the `sn-cli` configuration script to enable both CMACs (100GbE MACs). After running, you should see **`MAC ENABLED/PHY UP -> UP`** for both CMACs' Rx and Tx.
#
# <div class="fab-warning">
#
# **Tip:** If the CMACs do not come up, FEC (Forward Error Correction) may not be disabled in the dataplane switch. Contact FABRIC support.
#
# </div>

# %%
# Upload the sn-cli configuration script to the FPGA node
sn_cli_script = 'sn-cli-setup'

result = node1.upload_file(sn_cli_script, sn_cli_script)

# Move the script into the Docker scratch directory and execute it
commands = [
    f"chmod a+x {sn_cli_script}",
    f"mv {sn_cli_script} ~/esnet-smartnic-fw/sn-stack/scratch",
    f"cd ~/esnet-smartnic-fw/sn-stack/; docker compose exec smartnic-fw scratch/{sn_cli_script}"
]

for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node1.execute(command)

# %% [markdown]
# ## Step 10: Run Pktgen (Packet Generation)
#
# Now we switch to the `smartnic-mgr-dpdk-manual` profile, which enables DPDK-based packet generation. The workflow is:
#
# 1. Shut down the current Docker stack
# 2. Change the Compose profile to `smartnic-mgr-dpdk-manual`
# 3. Restart the stack
# 4. Run `pktgen` from the console to generate traffic
# 5. On the CX-6 node, use `tcpdump` to capture the packets

# %%
# Shut down the current Docker stack
command = "cd esnet-smartnic-fw/sn-stack/; docker compose down"

stdout, stderr = node1.execute(command)

# %% [markdown]
# Modify the Docker Compose profile in the `.env` file.

# %%
# Switch the Compose profile from vfio-unlock to dpdk-manual
commands = [
    "sed -i 's/COMPOSE_PROFILES=smartnic-mgr-vfio-unlock/COMPOSE_PROFILES=smartnic-mgr-dpdk-manual/' ~/esnet-smartnic-fw/sn-stack/.env",
    "tail ~/esnet-smartnic-fw/sn-stack/.env"
]

for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node1.execute(command)

# %% [markdown]
# Restart the stack with the new profile.

# %%
# Start the Docker stack with the DPDK manual profile
command = "cd ~/esnet-smartnic-fw/sn-stack; docker compose up -d"
stdout, stderr = node1.execute(command)

# %% [markdown]
# ### Start Pktgen (Manual Step)
#
# <div class="fab-warning">
#
# **This step must be executed from an SSH console session.** SSH into the fpga-node and run:
#
# ```bash
# cd ~/esnet-smartnic-fw/sn-stack
# docker compose exec smartnic-dpdk bash
# pktgen -a $SN_PCIE_DEV.0 -a $SN_PCIE_DEV.1 -l 3-7 -n 3 -d librte_net_qdma.so --file-prefix $SN_PCIE_DEV- -- -v -m [4:5].0 -m [6:7].1
# ```
#
# Then at the pktgen prompt, configure unicast packet flows on both CMACs:
#
# ```
# set 0-1 dst mac 04:16:17:18:19:1a
# set 0-1 src mac 14:16:17:18:19:10
# set 0-1 size 128
# set 0-1 rate 1
# start 0
# start 1
# ```
#
# </div>

# %% [markdown]
# ### Enable CX-6 Dataplane Interfaces
#
# On the ConnectX-6 node, bring up the dataplane interfaces so they can receive traffic from the FPGA.

# %%
# Bring up the CX-6 dataplane interfaces
node2 = slice.get_node(name=cx6_node_name)
cx_6_port0 = "ens7"
cx_6_port1 = "ens8"

commands = [
    f"sudo ip link set up {cx_6_port0}",
    f"sudo ip link set up {cx_6_port1}"
]

for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node2.execute(command)

# %% [markdown]
# ### Capture Traffic with tcpdump
#
# Use `tcpdump` on the CX-6 interfaces to verify that packets generated by pktgen on the FPGA are arriving.

# %%
# Capture packets on both CX-6 interfaces
pktcount = 10

print(f"LISTENING ON {cx_6_port0}")
command = f"sudo tcpdump -nlvvxx -i {cx_6_port0} -c {pktcount} tcp"
stdout, stderr = node2.execute(command)

print("LISTENING ON {cx_6_port1}")
command = f"sudo tcpdump -nlvvxx -i {cx_6_port1} -c {pktcount} tcp"
stdout, stderr = node2.execute(command)

# %% [markdown]
# ### Shut Down the Docker Stack

# %%
# Bring down the Docker stack when done with traffic tests
command = "cd ~/esnet-smartnic-fw/sn-stack; docker compose down"

stdout, stderr = node1.execute(command)

# %% [markdown]
# ## Step 11: Extend the Slice (Optional)
#
# If your experiment needs more time, you can extend the slice expiration. The default maximum extension is 14 days from the current time.

# %%
# Display current slice status and expiration
slice = fablib.get_slice(name=slice_name)
a = slice.show()
nets = slice.list_networks()
nodes = slice.list_nodes()

# %%
# Renew the slice for 14 more days
from datetime import datetime
from datetime import timezone
from datetime import timedelta

# Set end date to now plus 14 days
end_date = (datetime.now(timezone.utc) + timedelta(days=14)).strftime("%Y-%m-%d %H:%M:%S %z")

try:
    slice = fablib.get_slice(name=slice_name)

    slice.renew(end_date)
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 12: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. FPGAs and ConnectX-6 NICs are scarce resources -- leaving slices running prevents other researchers from using them.
#
# </div>

# %%
# Delete the slice and release all resources
slice = fablib.get_slice(name=slice_name)
slice.delete()

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | No sites with available FPGAs | All FPGAs in use | Wait and retry; check the [FABRIC portal](https://portal.fabric-testbed.net/) |
# | `dmesg` shows no IOMMU messages | GRUB changes did not take effect | Re-run the GRUB modification and reboot |
# | sn-cli shows `0x0000` or `0xffff` | VFIO binding failed | Verify no-IOMMU mode is enabled; restart the Docker stack |
# | CMACs show `DWN` instead of `UP` | FEC not disabled in dataplane switch | Contact FABRIC support to verify switch configuration |
# | tcpdump shows no packets | Pktgen not started or wrong interfaces | Verify pktgen is running on the FPGA node; check interface names |
# | Docker build fails | Missing base images | Ensure dpdk and xilinx-labtools images are loaded before building |
# | EOFError during reboot | Expected SSH disconnection | Ignore the error; `wait_ssh()` handles reconnection |

# %% [markdown]
# ## FABlib API Reference
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.list_sites()` | List sites with optional filtering | [list_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.list_sites) |
# | `fablib.new_slice(name)` | Create a new slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_node(...)` | Add a compute node | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component(model, name)` | Attach an FPGA/NIC component | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `slice.add_l2network(...)` | Create a Layer 2 network | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `node.execute(command)` | Execute a shell command | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `node.execute_thread(...)` | Execute a command asynchronously | [execute_thread](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute_thread) |
# | `node.upload_file(local, remote)` | Upload a file to a node | [upload_file](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.upload_file) |
# | `slice.wait_ssh()` | Wait for SSH connectivity | [wait_ssh](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.wait_ssh) |
# | `slice.renew(end_date)` | Extend the slice expiration | [renew](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.renew) |
# | `slice.delete()` | Delete the slice | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Simple FPGA Provisioning** | [fpga_u280_simple](fpga_u280_simple.ipynb) | Reserve a single FPGA without P4 |
# | **FPGA Tools Storage** | [fpga_tools_storage](fpga_tools_storage.ipynb) | Persistent storage for Xilinx tools |
# | **P4 Tofino Switches** | [fabric_p4_tofino_l2_network](../fabric_p4_tofino_l2_network/fabric_p4_tofino_l2_network.ipynb) | Program P4 on Intel Tofino hardware switches |
# | **BlueField DPUs** | [bluefield_dpus](../bluefields/bluefield_dpus_l2_network_basic_auto.ipynb) | Use NVIDIA BlueField-3 SmartNICs |
