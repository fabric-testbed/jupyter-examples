# %% [markdown]
# <style>
# /* FABRIC notebook  adaptive theme */
# .fab-info    { background-color: #f0f7fb; border-left: 4px solid #1f6a8c; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-success { background-color: #e8f5e9; border-left: 4px solid #008e7a; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-warning { background-color: #fff8e1; border-left: 4px solid #ff8542; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-danger  { background-color: #fce4ec; border-left: 4px solid #b00020; padding: 12px 15px; margin: 15px 0; border-radius: 4px; }
# .fab-footer  { background-color: #374955; color: white; padding: 15px 20px; margin: 20px 0; border-radius: 4px; text-align: center; }
#
# @media (prefers-color-scheme: dark) {
#   .fab-info    { background-color: #1a2a35; border-color: #5798bc; color: #d0e0eb; }
#   .fab-success { background-color: #1a2e25; border-color: #00b89a; color: #c0e0d5; }
#   .fab-warning { background-color: #2e2518; border-color: #ff9a5c; color: #e0d0b8; }
#   .fab-danger  { background-color: #2e1a1e; border-color: #e53950; color: #e0c0c8; }
#   .fab-footer  { background-color: #2a3a45; color: #b0c4d0; }
# }
# </style>
#
# # DHCP on a FABRIC L2 Network
#
# <picture>
#   <source srcset="../../images/fabric_logo_light.png" media="(prefers-color-scheme: dark)">
#   <img src="../../images/fabric_logo.png" width="300" style="margin-bottom:10px;"/>
# </picture>
#
# <div class="fab-info">
#
# **Welcome!** This notebook demonstrates how to set up and configure a **DHCP server** on a FABRIC Layer 2 network to dynamically allocate IP addresses to client nodes. You will deploy a DHCP server on one node and configure two client nodes to obtain their addresses automatically via DHCP -- a common pattern for experiments that need dynamic IP management.
#
# </div>

# %% [markdown]
# ## Learning Objectives
#
# <div class="fab-success">
#
# After completing this notebook you will be able to:
#
# 1. Create a FABRIC L2 network with **three nodes** (one server, two clients)
# 2. Install and configure the **ISC DHCP server** on a FABRIC node
# 3. Configure DHCP lease settings including **subnet range, lease duration, and interface binding**
# 4. Use `dhclient` on client nodes to **request IP addresses** from the DHCP server
# 5. Verify connectivity between clients using their DHCP-assigned addresses
# 6. Use **threaded execution** to run commands on multiple nodes in parallel
#
# </div>

# %% [markdown]
# ## Prerequisites
#
# <div class="fab-warning">
#
# Before running this notebook you **must**:
#
# 1. Run the [Configure Environment](../../../configure_and_validate/configure_and_validate.ipynb) notebook
# 2. Be familiar with L2 networks on FABRIC (see [Local L2 Network](../create_l2network_basic/create_l2network_basic_config.ipynb))
#
# **Tip:** This notebook uses Ubuntu 22.04 and the `isc-dhcp-server` package. The DHCP configuration uses interface name `ens7`, which is the typical name for the first SR-IOV VF interface on FABRIC nodes. If your interface has a different name, you will need to adjust the configuration.
#
# </div>

# %% [markdown]
# ## Background: DHCP on Layer 2 Networks
#
# ### What is DHCP?
#
# **Dynamic Host Configuration Protocol (DHCP)** automatically assigns IP addresses and network parameters to devices on a network. Instead of manually configuring each node's IP address, a DHCP server manages a pool of addresses and leases them to clients on request.
#
# ### Why Use DHCP on FABRIC?
#
# While FABRIC's `auto` and `config` modes handle IP assignment for most experiments, DHCP is useful when:
# - You are testing DHCP-related software or protocols
# - Your experiment involves nodes joining and leaving the network dynamically
# - You want to simulate a more realistic enterprise network environment
#
# ### Experiment Topology
#
#
# The DHCP server assigns addresses from the `192.168.1.100-200` range to clients.

# %% [markdown]
# ---
#
# ## Step 1: Import FABlib and Verify Configuration

# %%
# Import the FABlib library and create a manager instance
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
                     
    fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Clean Up Log Directory
#
# This notebook uses threaded execution which writes output to log files. We clean up any existing logs to avoid large files accumulating.

# %%
# Clean up log directory to avoid large files
import os
for item in os.scandir(os.path.join(os.getcwd(), 'logs')):
    if '.' != item.name[0]:
        os.remove(item.path)

# %% [markdown]
# ## Step 2: Define Slice Parameters and Create the Slice
#
# We create three nodes on the same FABRIC site, all connected to a single L2 network. The interfaces use `auto` mode for initial setup; we will manually configure the DHCP server's IP later.

# %%
# Slice and node configuration
slice_name = 'DHCPSlice'

# Pick a random FABRIC site
site = fablib.get_random_site()
print(f"Site: {site}")

# Node names: one server and two clients
node1_name = 'Server'
node2_name = 'Client1'
node3_name = 'Client2'

# Network and NIC names
network_name='DHCP-demo-net'
node1_nic_name = 'nic1'
node2_nic_name = 'nic2'
node3_nic_name = 'nic3'

# Use Ubuntu 22.04 for isc-dhcp-server compatibility
image = 'default_ubuntu_22'

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

# Define the initial subnet for the L2 network
subnet = IPv4Network("10.0.0.0/24")
available_ips = list(subnet)[1:]

try:
    # Create the slice
    slice = fablib.new_slice(name=slice_name)
    
    # Add the L2 network
    net = slice.add_l2network(name=network_name, subnet=subnet)
    
    # Server node -- will host the DHCP server
    node1 = slice.add_node(name=node1_name, site=site, image=image)
    iface1 = node1.add_component(model='NIC_Basic', name=node1_nic_name).get_interfaces()[0]
    iface1.set_mode('auto')
    net.add_interface(iface1)
    
    # Client 1 -- will request an IP via DHCP
    node2 = slice.add_node(name=node2_name, site=site, image=image)
    iface2 = node2.add_component(model='NIC_Basic', name=node2_nic_name).get_interfaces()[0]
    iface2.set_mode('auto')
    net.add_interface(iface2)
    
    # Client 2 -- will request an IP via DHCP
    node3 = slice.add_node(name=node3_name, site=site, image=image)
    iface3 = node3.add_component(model='NIC_Basic', name=node3_nic_name).get_interfaces()[0]
    iface3.set_mode('auto')
    net.add_interface(iface3)

    # Submit the slice request (~2-5 minutes)
    slice.submit()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 3: Define a Threading Helper Function
#
# Since we need to run the same commands on multiple nodes (e.g., package updates), we define a helper function that executes commands in parallel using FABlib's `execute_thread()` method. This significantly speeds up multi-node operations.

# %%
def thread_ripper(command):
    """Execute a command on all nodes in parallel using threads.
    
    Args:
        command: Shell command string to execute on each node
    """
    nodes = slice.get_nodes()
    threads = {}
    
    # Launch a thread for each node
    for node in nodes:
        print(f'Create thread for node: {node.get_name()}')
        threads[node] = node.execute_thread(command, output_file=f'logs/{node.get_name()}.log')

    print('Done creating threads!')

    # Wait for all threads to complete
    for node, thread in threads.items():
        print(f'node: {node.get_name()}... ', end='')
        stdout, stderr = thread.result()
        print('done!')

# %% [markdown]
# ## Step 4: Install DHCP Server
#
# First we update packages on all nodes and install required networking tools. Then we install the ISC DHCP server on the server node.
#
# <div class="fab-warning">
#
# **Tip:** You can monitor the progress of each node's installation by tailing its log file:
# ```bash
# tail -f logs/{node_name}.log
# ```
#
# </div>

# %%
# Get references to server and client nodes
server = slice.get_node(name=node1_name)    # DHCP server
client1 = slice.get_node(name=node2_name)   # DHCP client 1
client2 = slice.get_node(name=node3_name)   # DHCP client 2

# Update packages on all nodes in parallel
thread_ripper('sudo apt-get update')

# Install networking tools on all nodes
thread_ripper('sudo apt-get install -y net-tools network-manager')

# %% [markdown]
# ## Step 5: Configure the DHCP Network
#
# We now set up the DHCP infrastructure:
#
# 1. Assign a **static IP** to the server's interface on the DHCP subnet (192.168.1.0/24)
# 2. Install the ISC DHCP server package
# 3. Write the DHCP configuration file with subnet range and lease settings
# 4. Bind the DHCP server to the correct network interface
#
# ### 5a: Assign a static IP to the DHCP server

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

try:
    # Define the DHCP subnet (different from the initial L2 network subnet)
    subnet = IPv4Network("192.168.1.0/24")
    available_ips = list(subnet)[1:]
except Exception as e:
    print(f"Exception: {e}")

# %%
# Assign a static IP (192.168.1.1) to the server's experiment interface
try:
    server_iface = server.get_interface(network_name=network_name) 
    server_addr = available_ips.pop(0)  # 192.168.1.1
    server_iface.ip_addr_add(addr=server_addr, subnet=subnet)

    # Bring the interface up and verify the IP assignment
    stdout, stderr = server.execute(f'sudo ifconfig {server_iface.get_os_interface()} up')
    stdout, stderr = server.execute(f'ip addr show {server_iface.get_os_interface()}')
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### 5b: Install and configure the ISC DHCP server

# %%
# Install the ISC DHCP server package
stdout, stderr = server.execute('sudo apt-get install -y isc-dhcp-server', quiet=True, output_file=f'logs/server.log')
# If installation fails, uncomment the next line to reconfigure:
# server.execute('sudo rm /etc/dhcp/dhcpd.conf && sudo dpkg --configure -a')

# %%
# Write the DHCP server configuration file
# - default-lease-time: 600 seconds (10 minutes)
# - max-lease-time: 7200 seconds (2 hours)
# - authoritative: this server is the authority for this subnet
# - range: DHCP will assign addresses from 192.168.1.100 to 192.168.1.200
stdout, stderr = server.execute('''sudo bash -c 'echo "default-lease-time 600;
max-lease-time 7200;
authoritative;
 
subnet 192.168.1.0 netmask 255.255.255.0 {
 range 192.168.1.100 192.168.1.200;
 option subnet-mask 255.255.255.0;
}
" >> /etc/dhcp/dhcpd.conf'
''')

# Bind the DHCP server to the experiment interface (ens7)
server.execute(r'''sudo sed -i 's/INTERFACESv4=""/INTERFACESv4="ens7"/' /etc/default/isc-dhcp-server''', quiet=True, output_file='logs/server.log');

# %%
# Restart the DHCP server to apply the new configuration
server.execute('sudo systemctl restart isc-dhcp-server.service');

# Verify the DHCP server is running
server.execute('sudo systemctl status isc-dhcp-server.service');

# %% [markdown]
# ## Step 6: Request IP Addresses (Client-Side)
#
# Each client uses `dhclient` to broadcast a DHCP request on its experiment interface (`ens7`). The DHCP server responds with an IP from the configured pool (192.168.1.100-200).

# %%
# Request DHCP addresses for both clients and record the assigned IPs
clients = {}
for client in (client1, client2,):
    # Send a DHCP request on the experiment interface
    client.execute('sudo dhclient ens7');
    
    # Extract the assigned IP address from the interface
    stdout, stderr = client.execute('''ip addr show ens7 | grep "inet " | awk '{print $2}' | cut -d/ -f1''', quiet=True);
    clients[client.get_name() + '_address'] = stdout[:-1].split('\n')[1]  # Parse the DHCP-assigned IP
    
# Display the assigned addresses
clients

# %% [markdown]
# ## Step 7: Run the Experiment
#
# Verify that the DHCP-assigned addresses work by pinging Client2 from Client1.
#
# <div class="fab-success">
#
# **What to expect:** Both clients should have addresses in the `192.168.1.100-200` range, and the ping should succeed, confirming that DHCP-assigned addresses enable full L2 connectivity.
#
# </div>

# %%
try:        
    # Ping Client2 from Client1 using the DHCP-assigned address
    stdout, stderr = client1.execute(f"ping -c 5 {clients['Client2_address']}")
    
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 8: Delete the Slice
#
# <div class="fab-danger">
#
# **Important:** Always delete your slice when you are done. FABRIC is a shared resource -- leaving slices running unnecessarily prevents other researchers from using those resources.
#
# </div>

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# | Problem | Possible Cause | Solution |
# |---------|---------------|----------|
# | `isc-dhcp-server` fails to start | Configuration syntax error | Check `/var/log/syslog` on the server for DHCP error messages |
# | `dhclient` gets no address | Server not listening on correct interface | Verify `INTERFACESv4="ens7"` in `/etc/default/isc-dhcp-server` |
# | `dhclient` gets no address | Server interface has no IP | Ensure the server's static IP was assigned in Step 5a |
# | Interface name is not `ens7` | Different FABRIC site or NIC model | Run `ip link show` to find the correct interface name and update the config |
# | `ping` fails between clients | Firewall blocking traffic | Run `sudo ufw disable` on all nodes |
# | Clients get addresses outside expected range | Stale DHCP leases | Restart the DHCP server and run `sudo dhclient -r ens7` then `sudo dhclient ens7` on clients |
# | `apt-get install` fails | Package mirror unreachable | Run `sudo apt-get update` again, or try a different FABRIC site |

# %% [markdown]
# ## FABlib API Reference
#
# The following FABlib methods were used in this notebook:
#
# | Method | Description | Documentation |
# |--------|-------------|---------------|
# | `fablib.show_config()` | Display current FABlib configuration | [show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config) |
# | `fablib.get_random_site()` | Select a random FABRIC site | [get_random_site](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.get_random_site) |
# | `fablib.new_slice(name)` | Create a new empty slice | [new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice) |
# | `slice.add_l2network(name, subnet)` | Add a Layer 2 network to the slice | [add_l2network](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_l2network) |
# | `slice.add_node(name, site, image)` | Add a compute node to the slice | [add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node) |
# | `node.add_component(model, name)` | Add a NIC component to a node | [add_component](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.add_component) |
# | `iface.set_mode(mode)` | Set interface configuration mode | [set_mode](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.set_mode) |
# | `iface.ip_addr_add(addr, subnet)` | Manually add an IP address to an interface | [ip_addr_add](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.ip_addr_add) |
# | `iface.get_os_interface()` | Get the OS-level interface name (e.g., ens7) | [get_os_interface](https://fabric-fablib.readthedocs.io/en/latest/interface.html#fabrictestbed_extensions.fablib.interface.Interface.get_os_interface) |
# | `node.execute(command)` | Execute a shell command on a node | [execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute) |
# | `node.execute_thread(command)` | Execute a command asynchronously in a thread | [execute_thread](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute_thread) |
# | `slice.delete()` | Delete the slice and release resources | [delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete) |

# %% [markdown]
# ## What's Next?
#
# Now that you can set up DHCP on FABRIC L2 networks, explore these related notebooks:
#
# | Topic | Notebook | What You'll Learn |
# |-------|----------|-------------------|
# | **Local L2 Network** | [create_l2network_basic_config](../create_l2network_basic/create_l2network_basic_config.ipynb) | Create L2 networks with user-defined IP config |
# | **Wide-Area L2 Network** | [create_l2network_wide_area_config](../create_l2network_wide_area/create_l2network_wide_area_config.ipynb) | Connect nodes across different FABRIC sites |
# | **FABnet IPv4 (L3)** | [create_l3network_fabnet_ipv4_auto](../create_l3network_fabnet_ipv4/create_l3network_fabnet_ipv4_auto.ipynb) | Use FABRIC's managed Layer 3 networking |
# | **Running Commands** | [execute_commands](../ssh_to_nodes/execute_commands.ipynb) | Execute commands, capture output, use threads |
# | **Customizing Nodes** | [customizing_nodes](../customizing_nodes/customizing_nodes.ipynb) | Set site, cores, RAM, disk, and OS image |
